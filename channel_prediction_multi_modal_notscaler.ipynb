# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# #  Import

# %%
import os
import sys

import numpy as  np
from lwm_multi_model import multi_modal_lwm  # 클래스 import
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Settings

# %%
# Scenes 2000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(100))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print("현재 사용 중인 장치:", device)
# Out:
# 현재 사용 중인 장치: cuda:1

# %% [markdown]
# # Generate a dataset

# %%
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (0.86s)
# Generating radar dataset: ⏳ In progress
# Generating radar dataset: ✅ Completed (196.64s)

# %% [markdown]
# # location dataset
#  지금 실험에서는 안쓰임

# %%
# comm = dataset.comm_dataset
# location =  comm

# location = [
#     {
#         "bs_loc": d["bs_loc"],                      # (3,)
#         "ue_loc": np.asarray(d["ue_loc"]).squeeze() # (3,)  (원래 (1,3)이면 squeeze)
#     }
#     for row in comm.data      # row: [dict] 형태
#     for d in row              # d: dict
# ]

# print(ue_location)  #)

# %% [markdown]
# # communication  dataset

# %%
# UE 정보
comm = dataset.comm_dataset
ch = comm.data[0][0]['ue'][0]
print(ch.coeffs.shape)
# Out:
# (1, 16, 64)

# %% [markdown]
# # preprocessing

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
# min_max normalization를 하지않고 실험ㅇ르 진행하기 위해서 coeffs를 그대로 사용
def preprocess_channel_coeffs_raw(coeffs_np, device=device):
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex128)
    r = coeffs.real.to(torch.float64)
    i = coeffs.imag.to(torch.float64)
    H = torch.cat([r, i], dim=-1).to(device)
    return H

# %%
# def get_train_min_max_realimag(frames, train_idx, us_idx=0):

#     rmin, rmax =  float('inf'), float('-inf')
#     imin, imax =  float('inf'), float('-inf')

#     print("Calculating min/max over training set...")

#     for t  in train_idx:
#         frame  = frames[t]
#         cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

#         rmin = min(rmin, float(cooeffs.real.min()))
#         rmax = max(rmax, float(cooeffs.real.max()))
#         imin = min(imin, float(cooeffs.imag.min()))
#         imax = max(imax, float(cooeffs.imag.max()))

#     print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
#     return (rmin, rmax), (imin, imax)

# %%
# def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device=device, eps=1e-16):
#     # Convert Numpy to Tensor
#     coeffs = torch.from_numpy(coeffs_np).to(torch.complex128)
    
#     r = coeffs.real
#     i = coeffs.imag
    
#     # Min-Max Scaling [0, 1]
#     # Add eps to denominator to prevent division by zero
#     r_scaled = (r - r_min) / max(r_max - r_min, eps)
#     i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
#     # Concat (Maintains shape like (..., 2*subcarriers))
#     H = torch.cat([r_scaled, i_scaled], dim=-1).to(device)
#     return H

# %%
# # 사용예시
# H = preprocess_channel_coeffs_minmax(ch.coeffs, r_min=-0.5, r_max=0.5, i_min=-0.5, i_max=0.5)
# print(H.shape)  # (1, 16, 128) 64 subcar

# %% [markdown]
# ### image dataset

# %%
sensor = dataset.camera_dataset.sensors["unit1_cam1"]
path0 = sensor.files[0]
img = Image.open(path0).convert("RGB")
arr = np.array(img)

print("path:", path0)
print("PIL size (W,H):", img.size)
print("np shape:", arr.shape, "dtype:", arr.dtype)  # 보통 (H,W,3), uint8
# Out:
# path: scenarios/DT31/RGB_images/unit1_cam1/7.png
# PIL size (W,H): (1920, 1080)
# np shape: (1080, 1920, 3) dtype: uint8

# %%
IMG_SIZE = 224

def preprocess_img(path, img_size=IMG_SIZE, device=device):
    # 1) load (H,W,3) uint8
    img = Image.open(path).convert("RGB")
    arr = np.array(img)

    # 2) numpy -> torch, (3,H,W), float32
    x = torch.from_numpy(arr).permute(2, 0, 1).contiguous().double()  # (3,H,W), double for ImageNet stats
    x = x / 255.0  # [0,1]

    # 3) add batch dim -> (1,3,H,W)
    x = x.unsqueeze(0)

    # 4) resize -> (1,3,224,224)
    x = F.interpolate(x, size=(img_size, img_size),
                      mode="bilinear", align_corners=False)

    # 5) normalize (ImageNet)
    mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float64).view(1, 3, 1, 1)
    std  = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float64).view(1, 3, 1, 1)
    x = (x - mean) / std

    # 6) move to device (GPU)
    x = x.to(device, non_blocking=True)

    return x  # (1,3,224,224) on device

# %%
# 사용예시
cd = dataset.camera_dataset
sensor = cd.sensors['unit1_cam1']
path0 = sensor.files[0]
img = preprocess_img(path0, device=device)
print(img.shape, img.device)  # torch.Size([1,3,224,224]) cuda:0
print(path0)
# Out:
# torch.Size([1, 3, 224, 224]) cuda:1
# scenarios/DT31/RGB_images/unit1_cam1/7.png

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class MultiModalNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, cam_files, ue_idx=0, past_len=16, device=device,
                 # Arguments for statistical values (initialized with default values)
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        
        self.comm_frames = comm_frames
        self.cam_files = list(cam_files)
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device
        
        # Save statistical values
        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = min(len(self.comm_frames), len(self.cam_files))
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2 

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1. Image Past (Apply Preprocessing)
        img_list = []
        for k in range(t - self.past_len + 1, t + 1):
            img_path = self.cam_files[k]
            img_k = preprocess_img(img_path, device=self.device).squeeze(0)
            img_list.append(img_k)
        img = torch.stack(img_list, dim=0)  # Shape: (past_len

        
        # 2. Channel Past (Apply Scaling)
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            
            # change minmax preprocessing to raw (no scaling)
            h = preprocess_channel_coeffs_raw(
                coeffs_np,
                device=self.device
            ).reshape(-1)
           
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)

        # 3. Target (Apply Scaling) - Target must also be scaled for model training!
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_raw(
            coeffs_np_next,
            device=self.device
        ).reshape(-1)

        return channel_past, img, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
sensor = dataset.camera_dataset.sensors["unit1_cam1"]

ds = MultiModalNextStepDatasetGPU(
    comm_frames=comm_frames,
    cam_files=sensor.files,
    ue_idx=0,
    past_len=16,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   # ✅ 의미 없음 (이미 GPU)
)

ch, img, y = next(iter(loader))
print(ch.shape, img.shape, y.shape)
print(ch.device, img.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 16, 3, 224, 224]) torch.Size([8, 2048])
# cuda:1 cuda:1 cuda:1

# %% [markdown]
# # Fine-tuning
# data shape 맞추기 위해

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from lwm_multi_model import multi_modal_lwm  # 너가 올린 backbone

class FinetuneChannelPredictor(nn.Module):
    """
    직접 구현한 lwm_multi_model(channel + image)에 맞는 파인튜닝 모델
    Input:
      ch:  (B, T, F_in)  e.g., (B,16,2048) 16: past Length, 2048: feature dim
      img: (B, 3, 224, 224)
    Output:
      yhat: (B, F_out)  e.g., (B,2048)
    """
    def __init__(
        self,
        backbone: nn.Module,
        F_in: int,
        F_out: int,
        pool: str = "last",          # "last" or "mean"
        freeze_image: bool = False,
        freeze_backbone: bool = False,
        element_length: int = 16,    # 채널 벡터 차원 (backbone 기대값)
        d_model: int = 64            # backbone 내부 feature dim
    ):
        super().__init__()
        self.backbone = backbone
        self.pool = pool

        # backbone이 기대하는 channel feature dim = ELEMENT_LENGTH
        # (backbone 내부 Channel_Embedding: Linear(ELEMENT_LENGTH -> D_MODEL))
        if element_length is None:
            element_length = backbone.channel_embedding.element_length
        if d_model is None:
            d_model = backbone.channel_embedding.d_model

        # 입력 차원 정렬: F_in -> ELEMENT_LENGTH
        self.in_proj = nn.Sequential(
            nn.Linear(F_in, 512),
            nn.GELU(),
            nn.Linear(512, 128),
            nn.GELU(),
            nn.Linear(128, element_length)
        )

        # 출력 head: D_MODEL -> F_out
        self.head = nn.Linear(d_model, F_out)

        if freeze_image:
            for p in self.backbone.image_embedding.parameters():
                p.requires_grad = False

        if freeze_backbone:
            for p in self.backbone.parameters():
                p.requires_grad = False
            # 그래도 projection/head는 학습되게 다시 켜기
            for p in self.in_proj.parameters():
                p.requires_grad = True
            for p in self.head.parameters():
                p.requires_grad = True

    def forward(self, ch, img):
        # ch: (B,T,F_in) -> (B,T,ELEMENT_LENGTH)
        ch = self.in_proj(ch)

        # backbone: (B,T,D_MODEL)
        tokens = self.backbone(ch, img)

        # pooling -> (B,D_MODEL)
        if self.pool == "last":
            z = tokens[:, -1, :]
        elif self.pool == "mean":
            z = tokens.mean(dim=1)
        else:
            raise ValueError(f"Unknown pool={self.pool}")

        # head -> (B,F_out)
        yhat = self.head(z)
        return yhat

# %% [markdown]
# ## NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# %% [markdown]
# # Train/Val split

# %%
n = len(ds)
n_train = int(0.75 * n)
train_idx = list(range(0, n_train))
val_idx = list(range(n_train, n))

# train_ts = [ds.valid_start + i for i in train_idx]

# (real_min,  real_max), (imag_min, imag_max) = get_train_min_max_realimag(
#     comm_frames, train_ts, us_idx=0
# )

# ds.r_min = real_min
# ds.r_max = real_max
# ds.i_min = imag_min
# ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)

# Verify
ch, img, y = next(iter(train_loader))
print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")

print("====")
print("check the type float 32 or float 64?")
print("ch dtype:", ch.dtype, "y dtype:", y.dtype)
# Out:
# Dataset statistical values set in the dataset.
#
# === Data Check ===
# y stats | min: -0.0000, max: 0.0000
# If scaling worked correctly, values should be within [0, 1].
# ====
# check the type float 32 or float 64?
# ch dtype: torch.float64 y dtype: torch.float64

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
cam_files = list(dataset.camera_dataset.sensors["unit1_cam1"].files)

print("len(comm_frames):", len(comm_frames))
print("len(cam_files):", len(cam_files))
print("first comm frame keys:", list(comm_frames[0].keys()))
print("first cam file:", cam_files[0])
# Out:
# len(comm_frames): 100
# len(cam_files): 1114
# first comm frame keys: ['bs_loc', 'ue', 'ue_loc', 'bs']
# first cam file: scenarios/DT31/RGB_images/unit1_cam1/7.png

# %%
len(val_loader)
# Out:
# 1

# %% [markdown]
# # Model generate and also check

# %%
# 배치 하나로 F_in/F_out 자동 확정
ch, img, y = next(iter(train_loader))
F_in  = ch.shape[-1]
F_out = y.shape[-1]
print("Detected:", "F_in=", F_in, "F_out=", F_out)
print("Batch devices:", ch.device, img.device, y.device)

# backbone + finetune model
backbone = multi_modal_lwm().to(device)

model = FinetuneChannelPredictor(
    backbone=backbone,
    F_in=F_in,
    F_out=F_out,
    pool="last",            # "mean"으로 바꿔도 됨
    freeze_image=False,     # 원하면 True (이미지 인코더 고정)
    freeze_backbone=False,  # 원하면 True (proj/head만 학습)
    element_length=16,
    d_model=64
).to(device).double()

# sanity forward
model.eval()
with torch.no_grad():
    # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
    yhat = model(ch.to(device), img.to(device))
print("yhat:", yhat.shape, "y:", y.shape)
# Out:
# Detected: F_in= 2048 F_out= 2048
# Batch devices: cuda:1 cuda:1 cuda:1
# yhat: torch.Size([32, 2048]) y: torch.Size([32, 2048])

# %%
# 1. 모델 생성 (백본 포함)
model = FinetuneChannelPredictor(
    backbone=backbone,
    F_in=F_in,
    F_out=F_out,
    element_length=16,
    d_model=64
).to(device)

# 2. 전체 모델을 Double(float64)로 강제 변환
# 이 한 줄이 실행되어야 'in_proj'와 'head' 가중치가 모두 float64가 됩니다.
model.double() 

# 3. 타입 불일치 확인 (디버깅용)
print(f"Input Type: {ch.dtype}")                # torch.float64 여야 함
print(f"Model weight Type: {model.head.weight.dtype}") # torch.float64 여야 함

# 4. 연산 수행
model.eval()
with torch.no_grad():
    # 데이터와 모델 가중치 타입을 일치시켜서 입력
    # .to(device) 뒤에 .double()을 붙여서 확실히 합니다.
    yhat = model(ch.to(device).double(), img.to(device).double())
# Out:
# Input Type: torch.float64
# Model weight Type: torch.float64

# %% [markdown]
# # Train/ Eval 함수 (grad clip)

# %%
def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        # Dataset이 이미 cuda 텐서를 반환하더라도 안전하게 유지
        ch = ch.to(device, non_blocking=True).double()
        img = img.to(device, non_blocking=True).double()
        y  = y.to(device, non_blocking=True).double()

        optimizer.zero_grad(set_to_none=True)

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)
        
        loss.backward()

        if grad_clip is not None and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        optimizer.step()
        
        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)


@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        ch = ch.to(device, non_blocking=True).double()
        img = img.to(device, non_blocking=True).double()
        y  = y.to(device, non_blocking=True).double()

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

# %% [markdown]
# #  Optiimizer  / Scheduler 설정

# %%
# requires_grad=True인 파라미터만 학습
trainable_params = [p for p in model.parameters() if p.requires_grad]
print("trainable params:", sum(p.numel() for p in trainable_params))

optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# (선택) cosine scheduler
epochs = 600
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
# Out:
# trainable params: 2499120

# %% [markdown]
# # 학습 루프 + checkpoint 저장

# %%
best_val = float("inf")
best_val_nmse = None
best_epoch = None

t_train0 = time.time()  # ✅ 전체 학습 시작 시간

for epoch in range(1, epochs + 1):
    t0 = time.time()

    tr_loss, tr_nmse = train_one_epoch(model, train_loader, optimizer, device=device, grad_clip=1.0)
    va_loss, va_nmse = evaluate(model, val_loader, device=device)

    scheduler.step()
 
    dt = time.time() - t0
    print(
        f"[{epoch:02d}/{epochs}] "
        f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
        f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
        f"{dt:.1f}s"
    )

    if va_loss < best_val:
        best_val = va_loss
        best_val_nmse = va_nmse
        best_epoch = epoch

        torch.save(
            {
                "epoch": epoch,
                "model_state": model.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "F_in": F_in,
                "F_out": F_out,
                "best_val_loss": best_val,
                "best_val_nmse_db": best_val_nmse,
            },
            "best_finetune.pt"
        )
        print(f"  ↳ saved best_finetune.pt | best@{best_epoch}: val loss={best_val:.6f}, val nmse(dB)={best_val_nmse:.4f}")

# ✅ 전체 학습 종료 후 총 시간 출력
total_sec = time.time() - t_train0
h = int(total_sec // 3600)
m = int((total_sec % 3600) // 60)
s = total_sec % 60

print("\n=== Training Summary ===")
print(f"Total time: {total_sec:.1f}s ({h}h {m}m {s:.1f}s)")
print(f"Best epoch: {best_epoch} | best val loss={best_val:.6f}, best val nmse(dB)={best_val_nmse:.4f}")
# Out:
# [01/600] train loss=0.306671, nmse(dB)=122.8298 | val loss=0.236387, nmse(dB)=128.1677 | 87.8s
#   ↳ saved best_finetune.pt | best@1: val loss=0.236387, val nmse(dB)=128.1677
# [02/600] train loss=0.252822, nmse(dB)=121.9922 | val loss=0.206766, nmse(dB)=127.5862 | 90.8s
#   ↳ saved best_finetune.pt | best@2: val loss=0.206766, val nmse(dB)=127.5862
# [03/600] train loss=0.226622, nmse(dB)=121.5226 | val loss=0.186500, nmse(dB)=127.1382 | 86.9s
#   ↳ saved best_finetune.pt | best@3: val loss=0.186500, val nmse(dB)=127.1382
# [04/600] train loss=0.205366, nmse(dB)=121.0883 | val loss=0.169729, nmse(dB)=126.7290 | 89.3s
#   ↳ saved best_finetune.pt | best@4: val loss=0.169729, val nmse(dB)=126.7290
# [05/600] train loss=0.189211, nmse(dB)=120.7317 | val loss=0.154633, nmse(dB)=126.3244 | 90.7s
#   ↳ saved best_finetune.pt | best@5: val loss=0.154633, val nmse(dB)=126.3244
# [06/600] train loss=0.173384, nmse(dB)=120.3508 | val loss=0.141995, nmse(dB)=125.9541 | 90.0s
#   ↳ saved best_finetune.pt | best@6: val loss=0.141995, val nmse(dB)=125.9541
# [07/600] train loss=0.163505, nmse(dB)=120.0975 | val loss=0.130983, nmse(dB)=125.6036 | 87.1s
#   ↳ saved best_finetune.pt | best@7: val loss=0.130983, val nmse(dB)=125.6036
# [08/600] train loss=0.151613, nmse(dB)=119.7607 | val loss=0.121005, nmse(dB)=125.2595 | 87.0s
#   ↳ saved best_finetune.pt | best@8: val loss=0.121005, val nmse(dB)=125.2595
# [09/600] train loss=0.139569, nmse(dB)=119.4035 | val loss=0.111720, nmse(dB)=124.9127 | 88.8s
#   ↳ saved best_finetune.pt | best@9: val loss=0.111720, val nmse(dB)=124.9127
# [10/600] train loss=0.131420, nmse(dB)=119.1474 | val loss=0.103259, nmse(dB)=124.5707 | 89.4s
#   ↳ saved best_finetune.pt | best@10: val loss=0.103259, val nmse(dB)=124.5707
# [11/600] train loss=0.121357, nmse(dB)=118.8031 | val loss=0.095503, nmse(dB)=124.2316 | 89.9s
#   ↳ saved best_finetune.pt | best@11: val loss=0.095503, val nmse(dB)=124.2316
# [12/600] train loss=0.115046, nmse(dB)=118.5606 | val loss=0.088271, nmse(dB)=123.8896 | 91.0s
#   ↳ saved best_finetune.pt | best@12: val loss=0.088271, val nmse(dB)=123.8896
# [13/600] train loss=0.109785, nmse(dB)=118.3550 | val loss=0.081413, nmse(dB)=123.5383 | 89.0s
#   ↳ saved best_finetune.pt | best@13: val loss=0.081413, val nmse(dB)=123.5383
# [14/600] train loss=0.102526, nmse(dB)=118.0490 | val loss=0.074881, nmse(dB)=123.1751 | 89.1s
#   ↳ saved best_finetune.pt | best@14: val loss=0.074881, val nmse(dB)=123.1751
# [15/600] train loss=0.093252, nmse(dB)=117.6342 | val loss=0.068862, nmse(dB)=122.8112 | 88.5s
#   ↳ saved best_finetune.pt | best@15: val loss=0.068862, val nmse(dB)=122.8112
# [16/600] train loss=0.087396, nmse(dB)=117.3553 | val loss=0.063303, nmse(dB)=122.4457 | 90.3s
#   ↳ saved best_finetune.pt | best@16: val loss=0.063303, val nmse(dB)=122.4457
# [17/600] train loss=0.082307, nmse(dB)=117.0800 | val loss=0.058182, nmse(dB)=122.0793 | 88.4s
#   ↳ saved best_finetune.pt | best@17: val loss=0.058182, val nmse(dB)=122.0793
# [18/600] train loss=0.079525, nmse(dB)=116.9337 | val loss=0.053443, nmse(dB)=121.7103 | 90.0s
#   ↳ saved best_finetune.pt | best@18: val loss=0.053443, val nmse(dB)=121.7103
# [19/600] train loss=0.073625, nmse(dB)=116.6015 | val loss=0.048991, nmse(dB)=121.3326 | 90.9s
#   ↳ saved best_finetune.pt | best@19: val loss=0.048991, val nmse(dB)=121.3326
# [20/600] train loss=0.071873, nmse(dB)=116.4963 | val loss=0.044990, nmse(dB)=120.9626 | 90.0s
#   ↳ saved best_finetune.pt | best@20: val loss=0.044990, val nmse(dB)=120.9626
# [21/600] train loss=0.066142, nmse(dB)=116.1223 | val loss=0.041328, nmse(dB)=120.5939 | 90.5s
#   ↳ saved best_finetune.pt | best@21: val loss=0.041328, val nmse(dB)=120.5939
# [22/600] train loss=0.063077, nmse(dB)=115.9295 | val loss=0.037946, nmse(dB)=120.2231 | 87.2s
#   ↳ saved best_finetune.pt | best@22: val loss=0.037946, val nmse(dB)=120.2231
# [23/600] train loss=0.060866, nmse(dB)=115.7537 | val loss=0.034856, nmse(dB)=119.8542 | 88.2s
#   ↳ saved best_finetune.pt | best@23: val loss=0.034856, val nmse(dB)=119.8542
# [24/600] train loss=0.058931, nmse(dB)=115.6064 | val loss=0.032060, nmse(dB)=119.4910 | 90.6s
#   ↳ saved best_finetune.pt | best@24: val loss=0.032060, val nmse(dB)=119.4910
# [25/600] train loss=0.055680, nmse(dB)=115.3422 | val loss=0.029557, nmse(dB)=119.1381 | 91.1s
#   ↳ saved best_finetune.pt | best@25: val loss=0.029557, val nmse(dB)=119.1381
# [26/600] train loss=0.052236, nmse(dB)=115.0576 | val loss=0.027311, nmse(dB)=118.7949 | 91.2s
#   ↳ saved best_finetune.pt | best@26: val loss=0.027311, val nmse(dB)=118.7949
# [27/600] train loss=0.054089, nmse(dB)=115.1839 | val loss=0.025239, nmse(dB)=118.4522 | 91.8s
#   ↳ saved best_finetune.pt | best@27: val loss=0.025239, val nmse(dB)=118.4522
# [28/600] train loss=0.052164, nmse(dB)=115.0528 | val loss=0.023403, nmse(dB)=118.1242 | 90.6s
#   ↳ saved best_finetune.pt | best@28: val loss=0.023403, val nmse(dB)=118.1242
# [29/600] train loss=0.048464, nmse(dB)=114.7528 | val loss=0.021780, nmse(dB)=117.8120 | 92.6s
#   ↳ saved best_finetune.pt | best@29: val loss=0.021780, val nmse(dB)=117.8120
# [30/600] train loss=0.047691, nmse(dB)=114.6461 | val loss=0.020331, nmse(dB)=117.5129 | 90.5s
#   ↳ saved best_finetune.pt | best@30: val loss=0.020331, val nmse(dB)=117.5129
# [31/600] train loss=0.046799, nmse(dB)=114.5829 | val loss=0.019002, nmse(dB)=117.2193 | 91.1s
#   ↳ saved best_finetune.pt | best@31: val loss=0.019002, val nmse(dB)=117.2193
# [32/600] train loss=0.046870, nmse(dB)=114.5396 | val loss=0.017748, nmse(dB)=116.9230 | 90.8s
#   ↳ saved best_finetune.pt | best@32: val loss=0.017748, val nmse(dB)=116.9230
# [33/600] train loss=0.047277, nmse(dB)=114.5965 | val loss=0.016627, nmse(dB)=116.6395 | 88.6s
#   ↳ saved best_finetune.pt | best@33: val loss=0.016627, val nmse(dB)=116.6395
# [34/600] train loss=0.043443, nmse(dB)=114.1999 | val loss=0.015708, nmse(dB)=116.3927 | 87.9s
#   ↳ saved best_finetune.pt | best@34: val loss=0.015708, val nmse(dB)=116.3927
# [35/600] train loss=0.046601, nmse(dB)=114.5512 | val loss=0.014913, nmse(dB)=116.1672 | 86.6s
#   ↳ saved best_finetune.pt | best@35: val loss=0.014913, val nmse(dB)=116.1672
# [36/600] train loss=0.044041, nmse(dB)=114.2714 | val loss=0.014180, nmse(dB)=115.9481 | 90.3s
#   ↳ saved best_finetune.pt | best@36: val loss=0.014180, val nmse(dB)=115.9481
# [37/600] train loss=0.042541, nmse(dB)=114.1072 | val loss=0.013517, nmse(dB)=115.7403 | 90.1s
#   ↳ saved best_finetune.pt | best@37: val loss=0.013517, val nmse(dB)=115.7403
# [38/600] train loss=0.043531, nmse(dB)=114.2066 | val loss=0.012947, nmse(dB)=115.5532 | 91.5s
#   ↳ saved best_finetune.pt | best@38: val loss=0.012947, val nmse(dB)=115.5532
# [39/600] train loss=0.043726, nmse(dB)=114.2160 | val loss=0.012447, nmse(dB)=115.3820 | 91.8s
#   ↳ saved best_finetune.pt | best@39: val loss=0.012447, val nmse(dB)=115.3820
# [40/600] train loss=0.040725, nmse(dB)=113.9040 | val loss=0.011991, nmse(dB)=115.2199 | 89.3s
#   ↳ saved best_finetune.pt | best@40: val loss=0.011991, val nmse(dB)=115.2199
# [41/600] train loss=0.042919, nmse(dB)=114.1522 | val loss=0.011567, nmse(dB)=115.0637 | 91.6s
#   ↳ saved best_finetune.pt | best@41: val loss=0.011567, val nmse(dB)=115.0637
# [42/600] train loss=0.042704, nmse(dB)=114.1550 | val loss=0.011179, nmse(dB)=114.9153 | 89.8s
#   ↳ saved best_finetune.pt | best@42: val loss=0.011179, val nmse(dB)=114.9153
# [43/600] train loss=0.042391, nmse(dB)=114.1097 | val loss=0.010866, nmse(dB)=114.7920 | 91.3s
#   ↳ saved best_finetune.pt | best@43: val loss=0.010866, val nmse(dB)=114.7920
# [44/600] train loss=0.039886, nmse(dB)=113.8152 | val loss=0.010618, nmse(dB)=114.6919 | 91.8s
#   ↳ saved best_finetune.pt | best@44: val loss=0.010618, val nmse(dB)=114.6919
# [45/600] train loss=0.038599, nmse(dB)=113.7124 | val loss=0.010395, nmse(dB)=114.5997 | 91.4s
#   ↳ saved best_finetune.pt | best@45: val loss=0.010395, val nmse(dB)=114.5997
# [46/600] train loss=0.040421, nmse(dB)=113.8992 | val loss=0.010191, nmse(dB)=114.5138 | 90.6s
#   ↳ saved best_finetune.pt | best@46: val loss=0.010191, val nmse(dB)=114.5138
# [47/600] train loss=0.039704, nmse(dB)=113.7754 | val loss=0.010012, nmse(dB)=114.4367 | 88.2s
#   ↳ saved best_finetune.pt | best@47: val loss=0.010012, val nmse(dB)=114.4367
# [48/600] train loss=0.040720, nmse(dB)=113.9204 | val loss=0.009867, nmse(dB)=114.3732 | 89.8s
#   ↳ saved best_finetune.pt | best@48: val loss=0.009867, val nmse(dB)=114.3732
# [49/600] train loss=0.041449, nmse(dB)=113.9816 | val loss=0.009760, nmse(dB)=114.3258 | 88.9s
#   ↳ saved best_finetune.pt | best@49: val loss=0.009760, val nmse(dB)=114.3258
# [50/600] train loss=0.037905, nmse(dB)=113.5866 | val loss=0.009672, nmse(dB)=114.2865 | 88.7s
#   ↳ saved best_finetune.pt | best@50: val loss=0.009672, val nmse(dB)=114.2865
# [51/600] train loss=0.036922, nmse(dB)=113.4266 | val loss=0.009607, nmse(dB)=114.2574 | 87.4s
#   ↳ saved best_finetune.pt | best@51: val loss=0.009607, val nmse(dB)=114.2574
# [52/600] train loss=0.039165, nmse(dB)=113.7556 | val loss=0.009574, nmse(dB)=114.2426 | 87.2s
#   ↳ saved best_finetune.pt | best@52: val loss=0.009574, val nmse(dB)=114.2426
# [53/600] train loss=0.039452, nmse(dB)=113.7252 | val loss=0.009518, nmse(dB)=114.2169 | 88.5s
#   ↳ saved best_finetune.pt | best@53: val loss=0.009518, val nmse(dB)=114.2169
# [54/600] train loss=0.039359, nmse(dB)=113.7442 | val loss=0.009447, nmse(dB)=114.1844 | 89.1s
#   ↳ saved best_finetune.pt | best@54: val loss=0.009447, val nmse(dB)=114.1844
# [55/600] train loss=0.038359, nmse(dB)=113.6384 | val loss=0.009339, nmse(dB)=114.1345 | 90.9s
#   ↳ saved best_finetune.pt | best@55: val loss=0.009339, val nmse(dB)=114.1345
# [56/600] train loss=0.038019, nmse(dB)=113.5723 | val loss=0.009229, nmse(dB)=114.0827 | 90.8s
#   ↳ saved best_finetune.pt | best@56: val loss=0.009229, val nmse(dB)=114.0827
# [57/600] train loss=0.037295, nmse(dB)=113.4703 | val loss=0.009168, nmse(dB)=114.0541 | 89.1s
#   ↳ saved best_finetune.pt | best@57: val loss=0.009168, val nmse(dB)=114.0541
# [58/600] train loss=0.035624, nmse(dB)=113.2923 | val loss=0.009151, nmse(dB)=114.0463 | 89.0s
#   ↳ saved best_finetune.pt | best@58: val loss=0.009151, val nmse(dB)=114.0463
# [59/600] train loss=0.037949, nmse(dB)=113.6227 | val loss=0.009130, nmse(dB)=114.0362 | 90.0s
#   ↳ saved best_finetune.pt | best@59: val loss=0.009130, val nmse(dB)=114.0362
# [60/600] train loss=0.037257, nmse(dB)=113.4974 | val loss=0.009098, nmse(dB)=114.0208 | 90.6s
#   ↳ saved best_finetune.pt | best@60: val loss=0.009098, val nmse(dB)=114.0208
# [61/600] train loss=0.037961, nmse(dB)=113.6570 | val loss=0.009064, nmse(dB)=114.0048 | 90.4s
#   ↳ saved best_finetune.pt | best@61: val loss=0.009064, val nmse(dB)=114.0048
# [62/600] train loss=0.036677, nmse(dB)=113.4451 | val loss=0.009068, nmse(dB)=114.0064 | 90.7s
# [63/600] train loss=0.035400, nmse(dB)=113.3305 | val loss=0.009032, nmse(dB)=113.9893 | 89.4s
#   ↳ saved best_finetune.pt | best@63: val loss=0.009032, val nmse(dB)=113.9893
# [64/600] train loss=0.034828, nmse(dB)=113.2250 | val loss=0.008992, nmse(dB)=113.9700 | 89.3s
#   ↳ saved best_finetune.pt | best@64: val loss=0.008992, val nmse(dB)=113.9700
# [65/600] train loss=0.034527, nmse(dB)=113.1402 | val loss=0.008960, nmse(dB)=113.9546 | 89.6s
#   ↳ saved best_finetune.pt | best@65: val loss=0.008960, val nmse(dB)=113.9546
# [66/600] train loss=0.037215, nmse(dB)=113.4941 | val loss=0.008951, nmse(dB)=113.9503 | 89.1s
#   ↳ saved best_finetune.pt | best@66: val loss=0.008951, val nmse(dB)=113.9503
# [67/600] train loss=0.037617, nmse(dB)=113.5436 | val loss=0.008944, nmse(dB)=113.9465 | 89.8s
#   ↳ saved best_finetune.pt | best@67: val loss=0.008944, val nmse(dB)=113.9465
# [68/600] train loss=0.034870, nmse(dB)=113.1520 | val loss=0.008909, nmse(dB)=113.9299 | 90.5s
#   ↳ saved best_finetune.pt | best@68: val loss=0.008909, val nmse(dB)=113.9299
# [69/600] train loss=0.033283, nmse(dB)=113.0514 | val loss=0.008878, nmse(dB)=113.9147 | 89.3s
#   ↳ saved best_finetune.pt | best@69: val loss=0.008878, val nmse(dB)=113.9147
# [70/600] train loss=0.037284, nmse(dB)=113.5316 | val loss=0.008830, nmse(dB)=113.8911 | 91.4s
#   ↳ saved best_finetune.pt | best@70: val loss=0.008830, val nmse(dB)=113.8911
# [71/600] train loss=0.035094, nmse(dB)=113.2381 | val loss=0.008772, nmse(dB)=113.8625 | 88.5s
#   ↳ saved best_finetune.pt | best@71: val loss=0.008772, val nmse(dB)=113.8625
# [72/600] train loss=0.035893, nmse(dB)=113.3030 | val loss=0.008725, nmse(dB)=113.8392 | 89.7s
#   ↳ saved best_finetune.pt | best@72: val loss=0.008725, val nmse(dB)=113.8392
# [73/600] train loss=0.034152, nmse(dB)=113.1461 | val loss=0.008700, nmse(dB)=113.8265 | 91.1s
#   ↳ saved best_finetune.pt | best@73: val loss=0.008700, val nmse(dB)=113.8265
# [74/600] train loss=0.035113, nmse(dB)=113.2908 | val loss=0.008649, nmse(dB)=113.8012 | 91.5s
#   ↳ saved best_finetune.pt | best@74: val loss=0.008649, val nmse(dB)=113.8012
# [75/600] train loss=0.032203, nmse(dB)=112.8886 | val loss=0.008621, nmse(dB)=113.7872 | 92.5s
#   ↳ saved best_finetune.pt | best@75: val loss=0.008621, val nmse(dB)=113.7872
# [76/600] train loss=0.033945, nmse(dB)=113.1010 | val loss=0.008586, nmse(dB)=113.7692 | 91.9s
#   ↳ saved best_finetune.pt | best@76: val loss=0.008586, val nmse(dB)=113.7692
# [77/600] train loss=0.033461, nmse(dB)=113.0251 | val loss=0.008568, nmse(dB)=113.7600 | 91.0s
#   ↳ saved best_finetune.pt | best@77: val loss=0.008568, val nmse(dB)=113.7600
# [78/600] train loss=0.033656, nmse(dB)=113.0566 | val loss=0.008485, nmse(dB)=113.7181 | 89.9s
#   ↳ saved best_finetune.pt | best@78: val loss=0.008485, val nmse(dB)=113.7181
# [79/600] train loss=0.034124, nmse(dB)=113.1524 | val loss=0.008416, nmse(dB)=113.6823 | 91.0s
#   ↳ saved best_finetune.pt | best@79: val loss=0.008416, val nmse(dB)=113.6823
# [80/600] train loss=0.031516, nmse(dB)=112.7262 | val loss=0.008403, nmse(dB)=113.6758 | 90.2s
#   ↳ saved best_finetune.pt | best@80: val loss=0.008403, val nmse(dB)=113.6758
# [81/600] train loss=0.032775, nmse(dB)=113.0364 | val loss=0.008402, nmse(dB)=113.6754 | 90.6s
#   ↳ saved best_finetune.pt | best@81: val loss=0.008402, val nmse(dB)=113.6754
# [82/600] train loss=0.033319, nmse(dB)=113.0679 | val loss=0.008371, nmse(dB)=113.6592 | 88.9s
#   ↳ saved best_finetune.pt | best@82: val loss=0.008371, val nmse(dB)=113.6592
# [83/600] train loss=0.032767, nmse(dB)=112.9383 | val loss=0.008342, nmse(dB)=113.6442 | 89.8s
#   ↳ saved best_finetune.pt | best@83: val loss=0.008342, val nmse(dB)=113.6442
# [84/600] train loss=0.031853, nmse(dB)=112.8329 | val loss=0.008312, nmse(dB)=113.6285 | 90.5s
#   ↳ saved best_finetune.pt | best@84: val loss=0.008312, val nmse(dB)=113.6285
# [85/600] train loss=0.030442, nmse(dB)=112.6880 | val loss=0.008287, nmse(dB)=113.6154 | 91.3s
#   ↳ saved best_finetune.pt | best@85: val loss=0.008287, val nmse(dB)=113.6154
# [86/600] train loss=0.030945, nmse(dB)=112.7087 | val loss=0.008224, nmse(dB)=113.5824 | 91.2s
#   ↳ saved best_finetune.pt | best@86: val loss=0.008224, val nmse(dB)=113.5824
# [87/600] train loss=0.030303, nmse(dB)=112.6333 | val loss=0.008143, nmse(dB)=113.5391 | 90.0s
#   ↳ saved best_finetune.pt | best@87: val loss=0.008143, val nmse(dB)=113.5391
# [88/600] train loss=0.030598, nmse(dB)=112.6691 | val loss=0.008064, nmse(dB)=113.4967 | 90.3s
#   ↳ saved best_finetune.pt | best@88: val loss=0.008064, val nmse(dB)=113.4967
# [89/600] train loss=0.029050, nmse(dB)=112.4619 | val loss=0.008002, nmse(dB)=113.4634 | 90.8s
#   ↳ saved best_finetune.pt | best@89: val loss=0.008002, val nmse(dB)=113.4634
# [90/600] train loss=0.031156, nmse(dB)=112.7469 | val loss=0.007932, nmse(dB)=113.4254 | 91.4s
#   ↳ saved best_finetune.pt | best@90: val loss=0.007932, val nmse(dB)=113.4254
# [91/600] train loss=0.029270, nmse(dB)=112.4394 | val loss=0.007869, nmse(dB)=113.3905 | 90.3s
#   ↳ saved best_finetune.pt | best@91: val loss=0.007869, val nmse(dB)=113.3905
# [92/600] train loss=0.029861, nmse(dB)=112.5950 | val loss=0.007802, nmse(dB)=113.3533 | 87.1s
#   ↳ saved best_finetune.pt | best@92: val loss=0.007802, val nmse(dB)=113.3533
# [93/600] train loss=0.029778, nmse(dB)=112.5416 | val loss=0.007689, nmse(dB)=113.2901 | 86.1s
#   ↳ saved best_finetune.pt | best@93: val loss=0.007689, val nmse(dB)=113.2901
# [94/600] train loss=0.030127, nmse(dB)=112.5629 | val loss=0.007565, nmse(dB)=113.2197 | 88.3s
#   ↳ saved best_finetune.pt | best@94: val loss=0.007565, val nmse(dB)=113.2197
# [95/600] train loss=0.028638, nmse(dB)=112.3354 | val loss=0.007490, nmse(dB)=113.1762 | 88.3s
#   ↳ saved best_finetune.pt | best@95: val loss=0.007490, val nmse(dB)=113.1762
# [96/600] train loss=0.029188, nmse(dB)=112.4944 | val loss=0.007447, nmse(dB)=113.1515 | 87.5s
#   ↳ saved best_finetune.pt | best@96: val loss=0.007447, val nmse(dB)=113.1515
# [97/600] train loss=0.028748, nmse(dB)=112.3874 | val loss=0.007403, nmse(dB)=113.1252 | 91.3s
#   ↳ saved best_finetune.pt | best@97: val loss=0.007403, val nmse(dB)=113.1252
# [98/600] train loss=0.028443, nmse(dB)=112.3733 | val loss=0.007353, nmse(dB)=113.0962 | 91.4s
#   ↳ saved best_finetune.pt | best@98: val loss=0.007353, val nmse(dB)=113.0962
# [99/600] train loss=0.027460, nmse(dB)=112.1764 | val loss=0.007341, nmse(dB)=113.0891 | 87.6s
#   ↳ saved best_finetune.pt | best@99: val loss=0.007341, val nmse(dB)=113.0891
# [100/600] train loss=0.027242, nmse(dB)=112.1713 | val loss=0.007335, nmse(dB)=113.0853 | 87.1s
#   ↳ saved best_finetune.pt | best@100: val loss=0.007335, val nmse(dB)=113.0853
# [101/600] train loss=0.027723, nmse(dB)=112.2418 | val loss=0.007305, nmse(dB)=113.0675 | 88.3s
#   ↳ saved best_finetune.pt | best@101: val loss=0.007305, val nmse(dB)=113.0675
# [102/600] train loss=0.028060, nmse(dB)=112.3109 | val loss=0.007220, nmse(dB)=113.0168 | 88.3s
#   ↳ saved best_finetune.pt | best@102: val loss=0.007220, val nmse(dB)=113.0168
# [103/600] train loss=0.026945, nmse(dB)=112.1173 | val loss=0.007106, nmse(dB)=112.9479 | 88.0s
#   ↳ saved best_finetune.pt | best@103: val loss=0.007106, val nmse(dB)=112.9479
# [104/600] train loss=0.028040, nmse(dB)=112.2986 | val loss=0.006994, nmse(dB)=112.8784 | 89.5s
#   ↳ saved best_finetune.pt | best@104: val loss=0.006994, val nmse(dB)=112.8784
# [105/600] train loss=0.027303, nmse(dB)=112.1770 | val loss=0.006912, nmse(dB)=112.8276 | 88.2s
#   ↳ saved best_finetune.pt | best@105: val loss=0.006912, val nmse(dB)=112.8276
# [106/600] train loss=0.025770, nmse(dB)=111.9411 | val loss=0.006848, nmse(dB)=112.7870 | 89.5s
#   ↳ saved best_finetune.pt | best@106: val loss=0.006848, val nmse(dB)=112.7870
# [107/600] train loss=0.025598, nmse(dB)=111.9147 | val loss=0.006751, nmse(dB)=112.7254 | 87.5s
#   ↳ saved best_finetune.pt | best@107: val loss=0.006751, val nmse(dB)=112.7254
# [108/600] train loss=0.025435, nmse(dB)=111.8720 | val loss=0.006636, nmse(dB)=112.6505 | 90.3s
#   ↳ saved best_finetune.pt | best@108: val loss=0.006636, val nmse(dB)=112.6505
# [109/600] train loss=0.024988, nmse(dB)=111.7522 | val loss=0.006540, nmse(dB)=112.5870 | 90.6s
#   ↳ saved best_finetune.pt | best@109: val loss=0.006540, val nmse(dB)=112.5870
# [110/600] train loss=0.024021, nmse(dB)=111.6395 | val loss=0.006469, nmse(dB)=112.5395 | 90.7s
#   ↳ saved best_finetune.pt | best@110: val loss=0.006469, val nmse(dB)=112.5395
# [111/600] train loss=0.025312, nmse(dB)=111.8341 | val loss=0.006370, nmse(dB)=112.4730 | 91.2s
#   ↳ saved best_finetune.pt | best@111: val loss=0.006370, val nmse(dB)=112.4730
# [112/600] train loss=0.024132, nmse(dB)=111.6720 | val loss=0.006262, nmse(dB)=112.3984 | 89.8s
#   ↳ saved best_finetune.pt | best@112: val loss=0.006262, val nmse(dB)=112.3984
# [113/600] train loss=0.024573, nmse(dB)=111.7290 | val loss=0.006160, nmse(dB)=112.3273 | 89.2s
#   ↳ saved best_finetune.pt | best@113: val loss=0.006160, val nmse(dB)=112.3273
# [114/600] train loss=0.022586, nmse(dB)=111.3791 | val loss=0.006060, nmse(dB)=112.2560 | 88.3s
#   ↳ saved best_finetune.pt | best@114: val loss=0.006060, val nmse(dB)=112.2560
# [115/600] train loss=0.023774, nmse(dB)=111.5950 | val loss=0.005959, nmse(dB)=112.1835 | 91.8s
#   ↳ saved best_finetune.pt | best@115: val loss=0.005959, val nmse(dB)=112.1835
# [116/600] train loss=0.025170, nmse(dB)=111.8478 | val loss=0.005861, nmse(dB)=112.1110 | 90.3s
#   ↳ saved best_finetune.pt | best@116: val loss=0.005861, val nmse(dB)=112.1110
# [117/600] train loss=0.022851, nmse(dB)=111.4608 | val loss=0.005750, nmse(dB)=112.0284 | 85.7s
#   ↳ saved best_finetune.pt | best@117: val loss=0.005750, val nmse(dB)=112.0284
# [118/600] train loss=0.021162, nmse(dB)=111.1316 | val loss=0.005650, nmse(dB)=111.9519 | 87.6s
#   ↳ saved best_finetune.pt | best@118: val loss=0.005650, val nmse(dB)=111.9519
# [119/600] train loss=0.022478, nmse(dB)=111.3534 | val loss=0.005538, nmse(dB)=111.8646 | 87.5s
#   ↳ saved best_finetune.pt | best@119: val loss=0.005538, val nmse(dB)=111.8646
# [120/600] train loss=0.022920, nmse(dB)=111.3889 | val loss=0.005425, nmse(dB)=111.7752 | 84.7s
#   ↳ saved best_finetune.pt | best@120: val loss=0.005425, val nmse(dB)=111.7752
# [121/600] train loss=0.021306, nmse(dB)=111.1534 | val loss=0.005313, nmse(dB)=111.6850 | 86.8s
#   ↳ saved best_finetune.pt | best@121: val loss=0.005313, val nmse(dB)=111.6850
# [122/600] train loss=0.021404, nmse(dB)=111.1396 | val loss=0.005187, nmse(dB)=111.5802 | 86.8s
#   ↳ saved best_finetune.pt | best@122: val loss=0.005187, val nmse(dB)=111.5802
# [123/600] train loss=0.020754, nmse(dB)=111.0078 | val loss=0.005056, nmse(dB)=111.4692 | 87.1s
#   ↳ saved best_finetune.pt | best@123: val loss=0.005056, val nmse(dB)=111.4692
# [124/600] train loss=0.021446, nmse(dB)=111.1767 | val loss=0.004950, nmse(dB)=111.3772 | 89.4s
#   ↳ saved best_finetune.pt | best@124: val loss=0.004950, val nmse(dB)=111.3772
# [125/600] train loss=0.020462, nmse(dB)=110.9130 | val loss=0.004866, nmse(dB)=111.3033 | 91.3s
#   ↳ saved best_finetune.pt | best@125: val loss=0.004866, val nmse(dB)=111.3033
# [126/600] train loss=0.019434, nmse(dB)=110.7073 | val loss=0.004778, nmse(dB)=111.2238 | 91.8s
#   ↳ saved best_finetune.pt | best@126: val loss=0.004778, val nmse(dB)=111.2238
# [127/600] train loss=0.019014, nmse(dB)=110.6731 | val loss=0.004688, nmse(dB)=111.1411 | 89.9s
#   ↳ saved best_finetune.pt | best@127: val loss=0.004688, val nmse(dB)=111.1411
# [128/600] train loss=0.018642, nmse(dB)=110.4859 | val loss=0.004565, nmse(dB)=111.0258 | 87.9s
#   ↳ saved best_finetune.pt | best@128: val loss=0.004565, val nmse(dB)=111.0258
# [129/600] train loss=0.017933, nmse(dB)=110.3761 | val loss=0.004439, nmse(dB)=110.9043 | 88.7s
#   ↳ saved best_finetune.pt | best@129: val loss=0.004439, val nmse(dB)=110.9043
# [130/600] train loss=0.019372, nmse(dB)=110.6958 | val loss=0.004322, nmse(dB)=110.7884 | 89.0s
#   ↳ saved best_finetune.pt | best@130: val loss=0.004322, val nmse(dB)=110.7884
# [131/600] train loss=0.019130, nmse(dB)=110.6580 | val loss=0.004225, nmse(dB)=110.6900 | 88.5s
#   ↳ saved best_finetune.pt | best@131: val loss=0.004225, val nmse(dB)=110.6900
# [132/600] train loss=0.018605, nmse(dB)=110.5588 | val loss=0.004138, nmse(dB)=110.5993 | 88.1s
#   ↳ saved best_finetune.pt | best@132: val loss=0.004138, val nmse(dB)=110.5993
# [133/600] train loss=0.018313, nmse(dB)=110.4714 | val loss=0.004031, nmse(dB)=110.4857 | 88.8s
#   ↳ saved best_finetune.pt | best@133: val loss=0.004031, val nmse(dB)=110.4857
# [134/600] train loss=0.016890, nmse(dB)=110.1309 | val loss=0.003931, nmse(dB)=110.3767 | 88.7s
#   ↳ saved best_finetune.pt | best@134: val loss=0.003931, val nmse(dB)=110.3767
# [135/600] train loss=0.017734, nmse(dB)=110.3088 | val loss=0.003833, nmse(dB)=110.2664 | 88.7s
#   ↳ saved best_finetune.pt | best@135: val loss=0.003833, val nmse(dB)=110.2664
# [136/600] train loss=0.017010, nmse(dB)=110.1750 | val loss=0.003739, nmse(dB)=110.1585 | 89.1s
#   ↳ saved best_finetune.pt | best@136: val loss=0.003739, val nmse(dB)=110.1585
# [137/600] train loss=0.016106, nmse(dB)=109.9584 | val loss=0.003637, nmse(dB)=110.0390 | 89.6s
#   ↳ saved best_finetune.pt | best@137: val loss=0.003637, val nmse(dB)=110.0390
# [138/600] train loss=0.016997, nmse(dB)=110.1804 | val loss=0.003540, nmse(dB)=109.9213 | 90.0s
#   ↳ saved best_finetune.pt | best@138: val loss=0.003540, val nmse(dB)=109.9213
# [139/600] train loss=0.016821, nmse(dB)=110.1190 | val loss=0.003427, nmse(dB)=109.7809 | 89.8s
#   ↳ saved best_finetune.pt | best@139: val loss=0.003427, val nmse(dB)=109.7809
# [140/600] train loss=0.015804, nmse(dB)=109.8609 | val loss=0.003309, nmse(dB)=109.6285 | 89.8s
#   ↳ saved best_finetune.pt | best@140: val loss=0.003309, val nmse(dB)=109.6285
# [141/600] train loss=0.015337, nmse(dB)=109.7112 | val loss=0.003186, nmse(dB)=109.4642 | 88.9s
#   ↳ saved best_finetune.pt | best@141: val loss=0.003186, val nmse(dB)=109.4642
# [142/600] train loss=0.015019, nmse(dB)=109.6087 | val loss=0.003065, nmse(dB)=109.2958 | 89.4s
#   ↳ saved best_finetune.pt | best@142: val loss=0.003065, val nmse(dB)=109.2958
# [143/600] train loss=0.015019, nmse(dB)=109.6013 | val loss=0.002952, nmse(dB)=109.1325 | 89.8s
#   ↳ saved best_finetune.pt | best@143: val loss=0.002952, val nmse(dB)=109.1325
# [144/600] train loss=0.014310, nmse(dB)=109.3894 | val loss=0.002829, nmse(dB)=108.9479 | 89.5s
#   ↳ saved best_finetune.pt | best@144: val loss=0.002829, val nmse(dB)=108.9479
# [145/600] train loss=0.013229, nmse(dB)=109.0574 | val loss=0.002714, nmse(dB)=108.7675 | 89.9s
#   ↳ saved best_finetune.pt | best@145: val loss=0.002714, val nmse(dB)=108.7675
# [146/600] train loss=0.014748, nmse(dB)=109.5284 | val loss=0.002604, nmse(dB)=108.5886 | 89.8s
#   ↳ saved best_finetune.pt | best@146: val loss=0.002604, val nmse(dB)=108.5886
# [147/600] train loss=0.012531, nmse(dB)=108.8440 | val loss=0.002512, nmse(dB)=108.4320 | 89.3s
#   ↳ saved best_finetune.pt | best@147: val loss=0.002512, val nmse(dB)=108.4320
# [148/600] train loss=0.013136, nmse(dB)=109.0212 | val loss=0.002430, nmse(dB)=108.2879 | 89.9s
#   ↳ saved best_finetune.pt | best@148: val loss=0.002430, val nmse(dB)=108.2879
# [149/600] train loss=0.013472, nmse(dB)=109.1211 | val loss=0.002348, nmse(dB)=108.1389 | 90.9s
#   ↳ saved best_finetune.pt | best@149: val loss=0.002348, val nmse(dB)=108.1389
# [150/600] train loss=0.013052, nmse(dB)=109.0093 | val loss=0.002277, nmse(dB)=108.0046 | 91.6s
#   ↳ saved best_finetune.pt | best@150: val loss=0.002277, val nmse(dB)=108.0046
# [151/600] train loss=0.012508, nmse(dB)=108.7926 | val loss=0.002204, nmse(dB)=107.8632 | 90.5s
#   ↳ saved best_finetune.pt | best@151: val loss=0.002204, val nmse(dB)=107.8632
# [152/600] train loss=0.012313, nmse(dB)=108.7529 | val loss=0.002107, nmse(dB)=107.6683 | 91.3s
#   ↳ saved best_finetune.pt | best@152: val loss=0.002107, val nmse(dB)=107.6683
# [153/600] train loss=0.012283, nmse(dB)=108.7406 | val loss=0.001991, nmse(dB)=107.4225 | 90.0s
#   ↳ saved best_finetune.pt | best@153: val loss=0.001991, val nmse(dB)=107.4225
# [154/600] train loss=0.011313, nmse(dB)=108.3986 | val loss=0.001895, nmse(dB)=107.2079 | 90.9s
#   ↳ saved best_finetune.pt | best@154: val loss=0.001895, val nmse(dB)=107.2079
# [155/600] train loss=0.011847, nmse(dB)=108.5746 | val loss=0.001814, nmse(dB)=107.0179 | 89.5s
#   ↳ saved best_finetune.pt | best@155: val loss=0.001814, val nmse(dB)=107.0179
# [156/600] train loss=0.011734, nmse(dB)=108.5420 | val loss=0.001729, nmse(dB)=106.8094 | 89.6s
#   ↳ saved best_finetune.pt | best@156: val loss=0.001729, val nmse(dB)=106.8094
# [157/600] train loss=0.010528, nmse(dB)=108.0725 | val loss=0.001646, nmse(dB)=106.5949 | 89.1s
#   ↳ saved best_finetune.pt | best@157: val loss=0.001646, val nmse(dB)=106.5949
# [158/600] train loss=0.010643, nmse(dB)=108.1613 | val loss=0.001578, nmse(dB)=106.4118 | 89.6s
#   ↳ saved best_finetune.pt | best@158: val loss=0.001578, val nmse(dB)=106.4118
# [159/600] train loss=0.010083, nmse(dB)=107.9017 | val loss=0.001527, nmse(dB)=106.2696 | 90.6s
#   ↳ saved best_finetune.pt | best@159: val loss=0.001527, val nmse(dB)=106.2696
# [160/600] train loss=0.010133, nmse(dB)=107.8840 | val loss=0.001467, nmse(dB)=106.0966 | 91.3s
#   ↳ saved best_finetune.pt | best@160: val loss=0.001467, val nmse(dB)=106.0966
# [161/600] train loss=0.009726, nmse(dB)=107.7384 | val loss=0.001391, nmse(dB)=105.8632 | 90.9s
#   ↳ saved best_finetune.pt | best@161: val loss=0.001391, val nmse(dB)=105.8632
# [162/600] train loss=0.010110, nmse(dB)=107.9210 | val loss=0.001308, nmse(dB)=105.5986 | 91.1s
#   ↳ saved best_finetune.pt | best@162: val loss=0.001308, val nmse(dB)=105.5986
# [163/600] train loss=0.009506, nmse(dB)=107.6498 | val loss=0.001237, nmse(dB)=105.3568 | 91.2s
#   ↳ saved best_finetune.pt | best@163: val loss=0.001237, val nmse(dB)=105.3568
# [164/600] train loss=0.009439, nmse(dB)=107.6378 | val loss=0.001184, nmse(dB)=105.1664 | 90.5s
#   ↳ saved best_finetune.pt | best@164: val loss=0.001184, val nmse(dB)=105.1664
# [165/600] train loss=0.009256, nmse(dB)=107.5022 | val loss=0.001122, nmse(dB)=104.9329 | 90.8s
#   ↳ saved best_finetune.pt | best@165: val loss=0.001122, val nmse(dB)=104.9329
# [166/600] train loss=0.009314, nmse(dB)=107.5424 | val loss=0.001047, nmse(dB)=104.6329 | 91.1s
#   ↳ saved best_finetune.pt | best@166: val loss=0.001047, val nmse(dB)=104.6329
# [167/600] train loss=0.009131, nmse(dB)=107.4763 | val loss=0.000975, nmse(dB)=104.3200 | 90.4s
#   ↳ saved best_finetune.pt | best@167: val loss=0.000975, val nmse(dB)=104.3200
# [168/600] train loss=0.008374, nmse(dB)=107.1143 | val loss=0.000924, nmse(dB)=104.0865 | 90.6s
#   ↳ saved best_finetune.pt | best@168: val loss=0.000924, val nmse(dB)=104.0865
# [169/600] train loss=0.008869, nmse(dB)=107.3532 | val loss=0.000893, nmse(dB)=103.9413 | 90.7s
#   ↳ saved best_finetune.pt | best@169: val loss=0.000893, val nmse(dB)=103.9413
# [170/600] train loss=0.008315, nmse(dB)=107.0580 | val loss=0.000870, nmse(dB)=103.8258 | 89.5s
#   ↳ saved best_finetune.pt | best@170: val loss=0.000870, val nmse(dB)=103.8258
# [171/600] train loss=0.008409, nmse(dB)=107.1119 | val loss=0.000831, nmse(dB)=103.6290 | 89.9s
#   ↳ saved best_finetune.pt | best@171: val loss=0.000831, val nmse(dB)=103.6290
# [172/600] train loss=0.008164, nmse(dB)=106.9793 | val loss=0.000782, nmse(dB)=103.3631 | 90.3s
#   ↳ saved best_finetune.pt | best@172: val loss=0.000782, val nmse(dB)=103.3631
# [173/600] train loss=0.008076, nmse(dB)=106.9201 | val loss=0.000739, nmse(dB)=103.1157 | 89.4s
#   ↳ saved best_finetune.pt | best@173: val loss=0.000739, val nmse(dB)=103.1157
# [174/600] train loss=0.008057, nmse(dB)=106.9163 | val loss=0.000705, nmse(dB)=102.9117 | 90.0s
#   ↳ saved best_finetune.pt | best@174: val loss=0.000705, val nmse(dB)=102.9117
# [175/600] train loss=0.007715, nmse(dB)=106.7458 | val loss=0.000671, nmse(dB)=102.6997 | 89.5s
#   ↳ saved best_finetune.pt | best@175: val loss=0.000671, val nmse(dB)=102.6997
# [176/600] train loss=0.007690, nmse(dB)=106.7152 | val loss=0.000635, nmse(dB)=102.4598 | 89.5s
#   ↳ saved best_finetune.pt | best@176: val loss=0.000635, val nmse(dB)=102.4598
# [177/600] train loss=0.007272, nmse(dB)=106.5069 | val loss=0.000603, nmse(dB)=102.2380 | 89.4s
#   ↳ saved best_finetune.pt | best@177: val loss=0.000603, val nmse(dB)=102.2380
# [178/600] train loss=0.007240, nmse(dB)=106.4390 | val loss=0.000567, nmse(dB)=101.9711 | 89.8s
#   ↳ saved best_finetune.pt | best@178: val loss=0.000567, val nmse(dB)=101.9711
# [179/600] train loss=0.007056, nmse(dB)=106.3397 | val loss=0.000538, nmse(dB)=101.7400 | 90.6s
#   ↳ saved best_finetune.pt | best@179: val loss=0.000538, val nmse(dB)=101.7400
# [180/600] train loss=0.007153, nmse(dB)=106.4121 | val loss=0.000510, nmse(dB)=101.5036 | 88.7s
#   ↳ saved best_finetune.pt | best@180: val loss=0.000510, val nmse(dB)=101.5036
# [181/600] train loss=0.006718, nmse(dB)=106.1581 | val loss=0.000479, nmse(dB)=101.2364 | 86.9s
#   ↳ saved best_finetune.pt | best@181: val loss=0.000479, val nmse(dB)=101.2364
# [182/600] train loss=0.007185, nmse(dB)=106.4208 | val loss=0.000454, nmse(dB)=101.0060 | 90.3s
#   ↳ saved best_finetune.pt | best@182: val loss=0.000454, val nmse(dB)=101.0060
# [183/600] train loss=0.007043, nmse(dB)=106.3368 | val loss=0.000434, nmse(dB)=100.8091 | 89.6s
#   ↳ saved best_finetune.pt | best@183: val loss=0.000434, val nmse(dB)=100.8091
# [184/600] train loss=0.006872, nmse(dB)=106.2241 | val loss=0.000413, nmse(dB)=100.5940 | 89.5s
#   ↳ saved best_finetune.pt | best@184: val loss=0.000413, val nmse(dB)=100.5940
# [185/600] train loss=0.006820, nmse(dB)=106.1856 | val loss=0.000392, nmse(dB)=100.3623 | 88.4s
#   ↳ saved best_finetune.pt | best@185: val loss=0.000392, val nmse(dB)=100.3623
# [186/600] train loss=0.006746, nmse(dB)=106.1525 | val loss=0.000367, nmse(dB)=100.0767 | 87.7s
#   ↳ saved best_finetune.pt | best@186: val loss=0.000367, val nmse(dB)=100.0767
# [187/600] train loss=0.006193, nmse(dB)=105.7723 | val loss=0.000355, nmse(dB)=99.9386 | 90.1s
#   ↳ saved best_finetune.pt | best@187: val loss=0.000355, val nmse(dB)=99.9386
# [188/600] train loss=0.006441, nmse(dB)=105.9563 | val loss=0.000339, nmse(dB)=99.7282 | 88.4s
#   ↳ saved best_finetune.pt | best@188: val loss=0.000339, val nmse(dB)=99.7282
# [189/600] train loss=0.006445, nmse(dB)=105.9358 | val loss=0.000319, nmse(dB)=99.4658 | 89.7s
#   ↳ saved best_finetune.pt | best@189: val loss=0.000319, val nmse(dB)=99.4658
# [190/600] train loss=0.006283, nmse(dB)=105.8452 | val loss=0.000304, nmse(dB)=99.2666 | 88.8s
#   ↳ saved best_finetune.pt | best@190: val loss=0.000304, val nmse(dB)=99.2666
# [191/600] train loss=0.006054, nmse(dB)=105.7087 | val loss=0.000292, nmse(dB)=99.0844 | 88.4s
#   ↳ saved best_finetune.pt | best@191: val loss=0.000292, val nmse(dB)=99.0844
# [192/600] train loss=0.006235, nmse(dB)=105.7868 | val loss=0.000280, nmse(dB)=98.9069 | 89.6s
#   ↳ saved best_finetune.pt | best@192: val loss=0.000280, val nmse(dB)=98.9069
# [193/600] train loss=0.006022, nmse(dB)=105.6764 | val loss=0.000274, nmse(dB)=98.8119 | 89.7s
#   ↳ saved best_finetune.pt | best@193: val loss=0.000274, val nmse(dB)=98.8119
# [194/600] train loss=0.005771, nmse(dB)=105.4749 | val loss=0.000269, nmse(dB)=98.7329 | 88.5s
#   ↳ saved best_finetune.pt | best@194: val loss=0.000269, val nmse(dB)=98.7329
# [195/600] train loss=0.005871, nmse(dB)=105.5451 | val loss=0.000260, nmse(dB)=98.5746 | 89.0s
#   ↳ saved best_finetune.pt | best@195: val loss=0.000260, val nmse(dB)=98.5746
# [196/600] train loss=0.005830, nmse(dB)=105.5061 | val loss=0.000243, nmse(dB)=98.2898 | 89.6s
#   ↳ saved best_finetune.pt | best@196: val loss=0.000243, val nmse(dB)=98.2898
# [197/600] train loss=0.005733, nmse(dB)=105.4135 | val loss=0.000222, nmse(dB)=97.8982 | 89.4s
#   ↳ saved best_finetune.pt | best@197: val loss=0.000222, val nmse(dB)=97.8982
# [198/600] train loss=0.005571, nmse(dB)=105.3262 | val loss=0.000209, nmse(dB)=97.6268 | 90.4s
#   ↳ saved best_finetune.pt | best@198: val loss=0.000209, val nmse(dB)=97.6268
# [199/600] train loss=0.005571, nmse(dB)=105.3333 | val loss=0.000212, nmse(dB)=97.6879 | 91.6s
# [200/600] train loss=0.005730, nmse(dB)=105.4570 | val loss=0.000213, nmse(dB)=97.7059 | 89.7s
# [201/600] train loss=0.005424, nmse(dB)=105.2108 | val loss=0.000197, nmse(dB)=97.3758 | 90.2s
#   ↳ saved best_finetune.pt | best@201: val loss=0.000197, val nmse(dB)=97.3758
# [202/600] train loss=0.005567, nmse(dB)=105.3343 | val loss=0.000176, nmse(dB)=96.8934 | 90.8s
#   ↳ saved best_finetune.pt | best@202: val loss=0.000176, val nmse(dB)=96.8934
# [203/600] train loss=0.005716, nmse(dB)=105.4417 | val loss=0.000164, nmse(dB)=96.5786 | 90.4s
#   ↳ saved best_finetune.pt | best@203: val loss=0.000164, val nmse(dB)=96.5786
# [204/600] train loss=0.005403, nmse(dB)=105.1936 | val loss=0.000160, nmse(dB)=96.4788 | 89.8s
#   ↳ saved best_finetune.pt | best@204: val loss=0.000160, val nmse(dB)=96.4788
# [205/600] train loss=0.005442, nmse(dB)=105.1545 | val loss=0.000163, nmse(dB)=96.5414 | 90.6s
# [206/600] train loss=0.004977, nmse(dB)=104.8586 | val loss=0.000153, nmse(dB)=96.2692 | 90.1s
#   ↳ saved best_finetune.pt | best@206: val loss=0.000153, val nmse(dB)=96.2692
# [207/600] train loss=0.005057, nmse(dB)=104.9056 | val loss=0.000130, nmse(dB)=95.5729 | 90.2s
#   ↳ saved best_finetune.pt | best@207: val loss=0.000130, val nmse(dB)=95.5729
# [208/600] train loss=0.005082, nmse(dB)=104.8762 | val loss=0.000117, nmse(dB)=95.1021 | 89.2s
#   ↳ saved best_finetune.pt | best@208: val loss=0.000117, val nmse(dB)=95.1021
# [209/600] train loss=0.004860, nmse(dB)=104.7182 | val loss=0.000113, nmse(dB)=94.9524 | 89.3s
#   ↳ saved best_finetune.pt | best@209: val loss=0.000113, val nmse(dB)=94.9524
# [210/600] train loss=0.005058, nmse(dB)=104.9335 | val loss=0.000113, nmse(dB)=94.9699 | 89.8s
# [211/600] train loss=0.005012, nmse(dB)=104.8636 | val loss=0.000118, nmse(dB)=95.1648 | 89.7s
# [212/600] train loss=0.005049, nmse(dB)=104.9113 | val loss=0.000117, nmse(dB)=95.1208 | 89.6s
# [213/600] train loss=0.004964, nmse(dB)=104.8326 | val loss=0.000115, nmse(dB)=95.0449 | 90.3s
# [214/600] train loss=0.005071, nmse(dB)=104.9018 | val loss=0.000116, nmse(dB)=95.0832 | 89.1s
# [215/600] train loss=0.004897, nmse(dB)=104.7539 | val loss=0.000122, nmse(dB)=95.2914 | 89.8s
# [216/600] train loss=0.004890, nmse(dB)=104.7709 | val loss=0.000119, nmse(dB)=95.1994 | 90.8s
# [217/600] train loss=0.004824, nmse(dB)=104.7094 | val loss=0.000119, nmse(dB)=95.1885 | 90.1s
# [218/600] train loss=0.004878, nmse(dB)=104.6892 | val loss=0.000118, nmse(dB)=95.1383 | 90.0s
# [219/600] train loss=0.004639, nmse(dB)=104.4962 | val loss=0.000113, nmse(dB)=94.9562 | 89.4s
# [220/600] train loss=0.004538, nmse(dB)=104.4438 | val loss=0.000102, nmse(dB)=94.5203 | 90.1s
#   ↳ saved best_finetune.pt | best@220: val loss=0.000102, val nmse(dB)=94.5203
# [221/600] train loss=0.004731, nmse(dB)=104.5937 | val loss=0.000082, nmse(dB)=93.5653 | 89.6s
#   ↳ saved best_finetune.pt | best@221: val loss=0.000082, val nmse(dB)=93.5653
# [222/600] train loss=0.004526, nmse(dB)=104.3982 | val loss=0.000075, nmse(dB)=93.1729 | 90.2s
#   ↳ saved best_finetune.pt | best@222: val loss=0.000075, val nmse(dB)=93.1729
# [223/600] train loss=0.004833, nmse(dB)=104.7167 | val loss=0.000077, nmse(dB)=93.3078 | 89.5s
# [224/600] train loss=0.004666, nmse(dB)=104.5527 | val loss=0.000079, nmse(dB)=93.3953 | 90.4s
# [225/600] train loss=0.004704, nmse(dB)=104.5798 | val loss=0.000083, nmse(dB)=93.6379 | 89.9s
# [226/600] train loss=0.004262, nmse(dB)=104.1466 | val loss=0.000084, nmse(dB)=93.6782 | 89.8s
# [227/600] train loss=0.004481, nmse(dB)=104.3714 | val loss=0.000083, nmse(dB)=93.6078 | 90.4s
# [228/600] train loss=0.004254, nmse(dB)=104.1149 | val loss=0.000081, nmse(dB)=93.5317 | 90.2s
# [229/600] train loss=0.004325, nmse(dB)=104.2243 | val loss=0.000074, nmse(dB)=93.1102 | 90.0s
#   ↳ saved best_finetune.pt | best@229: val loss=0.000074, val nmse(dB)=93.1102
# [230/600] train loss=0.004346, nmse(dB)=104.2493 | val loss=0.000064, nmse(dB)=92.5031 | 89.7s
#   ↳ saved best_finetune.pt | best@230: val loss=0.000064, val nmse(dB)=92.5031
# [231/600] train loss=0.004377, nmse(dB)=104.2712 | val loss=0.000059, nmse(dB)=92.1421 | 90.2s
#   ↳ saved best_finetune.pt | best@231: val loss=0.000059, val nmse(dB)=92.1421
# [232/600] train loss=0.004598, nmse(dB)=104.4372 | val loss=0.000058, nmse(dB)=92.0536 | 90.0s
#   ↳ saved best_finetune.pt | best@232: val loss=0.000058, val nmse(dB)=92.0536
# [233/600] train loss=0.004297, nmse(dB)=104.1545 | val loss=0.000060, nmse(dB)=92.2098 | 90.1s
# [234/600] train loss=0.004229, nmse(dB)=104.1627 | val loss=0.000061, nmse(dB)=92.2554 | 89.9s
# [235/600] train loss=0.004374, nmse(dB)=104.3078 | val loss=0.000059, nmse(dB)=92.1114 | 90.4s
# [236/600] train loss=0.004269, nmse(dB)=104.1303 | val loss=0.000055, nmse(dB)=91.8696 | 90.9s
#   ↳ saved best_finetune.pt | best@236: val loss=0.000055, val nmse(dB)=91.8696
# [237/600] train loss=0.004158, nmse(dB)=104.0453 | val loss=0.000051, nmse(dB)=91.5144 | 89.8s
#   ↳ saved best_finetune.pt | best@237: val loss=0.000051, val nmse(dB)=91.5144
# [238/600] train loss=0.004303, nmse(dB)=104.1976 | val loss=0.000049, nmse(dB)=91.3459 | 90.3s
#   ↳ saved best_finetune.pt | best@238: val loss=0.000049, val nmse(dB)=91.3459
# [239/600] train loss=0.004042, nmse(dB)=103.9111 | val loss=0.000050, nmse(dB)=91.4486 | 89.2s
# [240/600] train loss=0.004433, nmse(dB)=104.3138 | val loss=0.000053, nmse(dB)=91.6429 | 89.0s
# [241/600] train loss=0.004174, nmse(dB)=104.0460 | val loss=0.000055, nmse(dB)=91.8167 | 89.6s
# [242/600] train loss=0.004041, nmse(dB)=103.8636 | val loss=0.000059, nmse(dB)=92.1488 | 90.1s
# [243/600] train loss=0.004253, nmse(dB)=104.1573 | val loss=0.000060, nmse(dB)=92.2434 | 90.3s
# [244/600] train loss=0.004235, nmse(dB)=104.0867 | val loss=0.000051, nmse(dB)=91.4658 | 90.9s
# [245/600] train loss=0.004233, nmse(dB)=104.1153 | val loss=0.000045, nmse(dB)=91.0092 | 90.2s
#   ↳ saved best_finetune.pt | best@245: val loss=0.000045, val nmse(dB)=91.0092
# [246/600] train loss=0.004178, nmse(dB)=104.0378 | val loss=0.000045, nmse(dB)=90.9936 | 90.3s
#   ↳ saved best_finetune.pt | best@246: val loss=0.000045, val nmse(dB)=90.9936
# [247/600] train loss=0.004151, nmse(dB)=104.0282 | val loss=0.000047, nmse(dB)=91.1060 | 91.3s
# [248/600] train loss=0.004007, nmse(dB)=103.9042 | val loss=0.000049, nmse(dB)=91.3492 | 90.4s
# [249/600] train loss=0.003947, nmse(dB)=103.7987 | val loss=0.000053, nmse(dB)=91.6803 | 91.1s
# [250/600] train loss=0.003847, nmse(dB)=103.7156 | val loss=0.000050, nmse(dB)=91.4469 | 91.8s
# [251/600] train loss=0.003974, nmse(dB)=103.8248 | val loss=0.000045, nmse(dB)=90.9437 | 90.3s
#   ↳ saved best_finetune.pt | best@251: val loss=0.000045, val nmse(dB)=90.9437
# [252/600] train loss=0.004063, nmse(dB)=103.9600 | val loss=0.000039, nmse(dB)=90.2925 | 90.6s
#   ↳ saved best_finetune.pt | best@252: val loss=0.000039, val nmse(dB)=90.2925
# [253/600] train loss=0.003940, nmse(dB)=103.7716 | val loss=0.000039, nmse(dB)=90.3302 | 91.3s
# [254/600] train loss=0.003921, nmse(dB)=103.7550 | val loss=0.000043, nmse(dB)=90.7766 | 90.2s
# [255/600] train loss=0.003710, nmse(dB)=103.5585 | val loss=0.000048, nmse(dB)=91.2640 | 89.1s
# [256/600] train loss=0.003717, nmse(dB)=103.5189 | val loss=0.000051, nmse(dB)=91.5348 | 88.6s
# [257/600] train loss=0.003997, nmse(dB)=103.8573 | val loss=0.000043, nmse(dB)=90.7659 | 89.6s
# [258/600] train loss=0.003904, nmse(dB)=103.7909 | val loss=0.000040, nmse(dB)=90.4816 | 89.9s
# [259/600] train loss=0.003747, nmse(dB)=103.6192 | val loss=0.000047, nmse(dB)=91.1176 | 90.4s
# [260/600] train loss=0.003952, nmse(dB)=103.8339 | val loss=0.000054, nmse(dB)=91.7383 | 89.7s
# [261/600] train loss=0.003932, nmse(dB)=103.8170 | val loss=0.000054, nmse(dB)=91.7779 | 90.6s
# [262/600] train loss=0.003764, nmse(dB)=103.6124 | val loss=0.000054, nmse(dB)=91.7403 | 90.7s
# [263/600] train loss=0.003733, nmse(dB)=103.5438 | val loss=0.000053, nmse(dB)=91.6850 | 90.2s
# [264/600] train loss=0.003676, nmse(dB)=103.5101 | val loss=0.000054, nmse(dB)=91.7786 | 89.3s
# [265/600] train loss=0.003832, nmse(dB)=103.6721 | val loss=0.000050, nmse(dB)=91.3832 | 90.9s
# [266/600] train loss=0.003741, nmse(dB)=103.5737 | val loss=0.000043, nmse(dB)=90.7475 | 89.5s
# [267/600] train loss=0.003779, nmse(dB)=103.6188 | val loss=0.000030, nmse(dB)=89.2069 | 90.0s
#   ↳ saved best_finetune.pt | best@267: val loss=0.000030, val nmse(dB)=89.2069
# [268/600] train loss=0.003972, nmse(dB)=103.8394 | val loss=0.000027, nmse(dB)=88.6849 | 89.5s
#   ↳ saved best_finetune.pt | best@268: val loss=0.000027, val nmse(dB)=88.6849
# [269/600] train loss=0.003912, nmse(dB)=103.7780 | val loss=0.000039, nmse(dB)=90.2880 | 89.4s
# [270/600] train loss=0.003906, nmse(dB)=103.8008 | val loss=0.000054, nmse(dB)=91.7489 | 89.8s
# [271/600] train loss=0.003890, nmse(dB)=103.7393 | val loss=0.000061, nmse(dB)=92.2796 | 89.5s
# [272/600] train loss=0.003609, nmse(dB)=103.4403 | val loss=0.000056, nmse(dB)=91.9236 | 89.0s
# [273/600] train loss=0.003518, nmse(dB)=103.3337 | val loss=0.000050, nmse(dB)=91.3928 | 89.8s
# [274/600] train loss=0.003700, nmse(dB)=103.5489 | val loss=0.000043, nmse(dB)=90.7759 | 89.6s
# [275/600] train loss=0.003774, nmse(dB)=103.6359 | val loss=0.000040, nmse(dB)=90.4813 | 89.2s
# [276/600] train loss=0.003804, nmse(dB)=103.6774 | val loss=0.000046, nmse(dB)=91.0643 | 89.9s
# [277/600] train loss=0.003674, nmse(dB)=103.5057 | val loss=0.000053, nmse(dB)=91.6428 | 90.6s
# [278/600] train loss=0.003582, nmse(dB)=103.3596 | val loss=0.000050, nmse(dB)=91.3786 | 89.5s
# [279/600] train loss=0.003860, nmse(dB)=103.7312 | val loss=0.000044, nmse(dB)=90.9045 | 89.4s
# [280/600] train loss=0.003607, nmse(dB)=103.4195 | val loss=0.000042, nmse(dB)=90.6399 | 89.5s
# [281/600] train loss=0.003574, nmse(dB)=103.3773 | val loss=0.000038, nmse(dB)=90.2048 | 89.8s
# [282/600] train loss=0.003445, nmse(dB)=103.2060 | val loss=0.000034, nmse(dB)=89.7520 | 90.5s
# [283/600] train loss=0.003563, nmse(dB)=103.3891 | val loss=0.000031, nmse(dB)=89.3768 | 89.4s
# [284/600] train loss=0.003477, nmse(dB)=103.2561 | val loss=0.000035, nmse(dB)=89.9150 | 88.4s
# [285/600] train loss=0.003670, nmse(dB)=103.5129 | val loss=0.000038, nmse(dB)=90.2845 | 89.6s
# [286/600] train loss=0.003506, nmse(dB)=103.3315 | val loss=0.000037, nmse(dB)=90.1223 | 89.8s
# [287/600] train loss=0.003470, nmse(dB)=103.2042 | val loss=0.000038, nmse(dB)=90.1920 | 89.6s
# [288/600] train loss=0.003461, nmse(dB)=103.2665 | val loss=0.000040, nmse(dB)=90.4102 | 89.2s
# [289/600] train loss=0.003563, nmse(dB)=103.3932 | val loss=0.000042, nmse(dB)=90.6640 | 88.6s
# [290/600] train loss=0.003561, nmse(dB)=103.3595 | val loss=0.000040, nmse(dB)=90.4020 | 89.0s
# [291/600] train loss=0.003532, nmse(dB)=103.3553 | val loss=0.000037, nmse(dB)=90.1207 | 89.5s
# [292/600] train loss=0.003621, nmse(dB)=103.4141 | val loss=0.000034, nmse(dB)=89.7443 | 90.3s
# [293/600] train loss=0.003665, nmse(dB)=103.4357 | val loss=0.000032, nmse(dB)=89.5085 | 89.5s
# [294/600] train loss=0.003379, nmse(dB)=103.1517 | val loss=0.000034, nmse(dB)=89.7533 | 90.7s
# [295/600] train loss=0.003462, nmse(dB)=103.2629 | val loss=0.000039, nmse(dB)=90.3427 | 90.9s
# [296/600] train loss=0.003305, nmse(dB)=103.0627 | val loss=0.000038, nmse(dB)=90.1726 | 89.8s
# [297/600] train loss=0.003401, nmse(dB)=103.1606 | val loss=0.000035, nmse(dB)=89.8449 | 88.8s
# [298/600] train loss=0.003434, nmse(dB)=103.2331 | val loss=0.000031, nmse(dB)=89.2905 | 88.6s
# [299/600] train loss=0.003535, nmse(dB)=103.3194 | val loss=0.000030, nmse(dB)=89.1514 | 89.6s
# [300/600] train loss=0.003491, nmse(dB)=103.3101 | val loss=0.000028, nmse(dB)=88.9204 | 89.6s
# [301/600] train loss=0.003330, nmse(dB)=103.0882 | val loss=0.000029, nmse(dB)=89.0899 | 90.1s
# [302/600] train loss=0.003415, nmse(dB)=103.1835 | val loss=0.000029, nmse(dB)=89.1019 | 89.8s
# [303/600] train loss=0.003352, nmse(dB)=103.0984 | val loss=0.000028, nmse(dB)=88.9329 | 89.8s
# [304/600] train loss=0.003398, nmse(dB)=103.1489 | val loss=0.000028, nmse(dB)=88.8872 | 90.5s
# [305/600] train loss=0.003326, nmse(dB)=103.0624 | val loss=0.000030, nmse(dB)=89.2117 | 89.9s
# [306/600] train loss=0.003412, nmse(dB)=103.2025 | val loss=0.000030, nmse(dB)=89.1398 | 90.1s
# [307/600] train loss=0.003340, nmse(dB)=103.0972 | val loss=0.000029, nmse(dB)=89.0253 | 90.1s
# [308/600] train loss=0.003375, nmse(dB)=103.1637 | val loss=0.000031, nmse(dB)=89.2838 | 89.7s
# [309/600] train loss=0.003327, nmse(dB)=103.0805 | val loss=0.000031, nmse(dB)=89.3509 | 88.7s
# [310/600] train loss=0.003288, nmse(dB)=103.0131 | val loss=0.000029, nmse(dB)=89.0453 | 90.5s
# [311/600] train loss=0.003068, nmse(dB)=102.7256 | val loss=0.000030, nmse(dB)=89.1563 | 89.6s
# [312/600] train loss=0.003280, nmse(dB)=103.0510 | val loss=0.000030, nmse(dB)=89.1590 | 89.5s
# [313/600] train loss=0.003329, nmse(dB)=103.0708 | val loss=0.000028, nmse(dB)=88.8806 | 90.2s
# [314/600] train loss=0.003141, nmse(dB)=102.8091 | val loss=0.000031, nmse(dB)=89.2829 | 90.1s
# [315/600] train loss=0.003237, nmse(dB)=102.9597 | val loss=0.000034, nmse(dB)=89.8049 | 89.8s
# [316/600] train loss=0.003194, nmse(dB)=102.9100 | val loss=0.000039, nmse(dB)=90.3145 | 89.5s
# [317/600] train loss=0.003238, nmse(dB)=102.9961 | val loss=0.000038, nmse(dB)=90.1929 | 90.8s
# [318/600] train loss=0.003225, nmse(dB)=102.9398 | val loss=0.000036, nmse(dB)=90.0228 | 90.3s
# [319/600] train loss=0.003244, nmse(dB)=102.9641 | val loss=0.000035, nmse(dB)=89.8265 | 90.7s
# ...
#   ↳ saved best_finetune.pt | best@465: val loss=0.000012, val nmse(dB)=85.3643
# [466/600] train loss=0.002682, nmse(dB)=102.1337 | val loss=0.000012, nmse(dB)=85.1126 | 89.4s
#   ↳ saved best_finetune.pt | best@466: val loss=0.000012, val nmse(dB)=85.1126
# [467/600] train loss=0.002599, nmse(dB)=101.9725 | val loss=0.000011, nmse(dB)=84.8161 | 90.2s
#   ↳ saved best_finetune.pt | best@467: val loss=0.000011, val nmse(dB)=84.8161
# [468/600] train loss=0.002622, nmse(dB)=102.0082 | val loss=0.000011, nmse(dB)=84.6853 | 90.1s
#   ↳ saved best_finetune.pt | best@468: val loss=0.000011, val nmse(dB)=84.6853
# [469/600] train loss=0.002714, nmse(dB)=102.1814 | val loss=0.000011, nmse(dB)=84.6939 | 90.2s
# [470/600] train loss=0.002646, nmse(dB)=102.0568 | val loss=0.000011, nmse(dB)=84.8630 | 90.2s
# [471/600] train loss=0.002610, nmse(dB)=102.0370 | val loss=0.000012, nmse(dB)=85.1963 | 89.5s
# [472/600] train loss=0.002611, nmse(dB)=102.0331 | val loss=0.000013, nmse(dB)=85.5146 | 90.3s
# [473/600] train loss=0.002748, nmse(dB)=102.2193 | val loss=0.000013, nmse(dB)=85.6319 | 90.2s
# [474/600] train loss=0.002721, nmse(dB)=102.2082 | val loss=0.000013, nmse(dB)=85.6443 | 90.2s
# [475/600] train loss=0.002561, nmse(dB)=101.9057 | val loss=0.000013, nmse(dB)=85.6553 | 90.4s
# [476/600] train loss=0.002582, nmse(dB)=101.9807 | val loss=0.000013, nmse(dB)=85.6992 | 90.6s
# [477/600] train loss=0.002694, nmse(dB)=102.1259 | val loss=0.000013, nmse(dB)=85.6682 | 90.6s
# [478/600] train loss=0.002664, nmse(dB)=102.1223 | val loss=0.000013, nmse(dB)=85.6231 | 91.3s
# [479/600] train loss=0.002684, nmse(dB)=102.1527 | val loss=0.000014, nmse(dB)=85.7511 | 90.0s
# [480/600] train loss=0.002548, nmse(dB)=101.9158 | val loss=0.000014, nmse(dB)=85.8003 | 90.7s
# [481/600] train loss=0.002597, nmse(dB)=101.9862 | val loss=0.000013, nmse(dB)=85.6400 | 89.8s
# [482/600] train loss=0.002775, nmse(dB)=102.2630 | val loss=0.000013, nmse(dB)=85.4120 | 89.8s
# [483/600] train loss=0.002576, nmse(dB)=101.9524 | val loss=0.000012, nmse(dB)=85.0675 | 90.4s
# [484/600] train loss=0.002566, nmse(dB)=101.9425 | val loss=0.000011, nmse(dB)=84.7990 | 89.5s
# [485/600] train loss=0.002578, nmse(dB)=101.9804 | val loss=0.000010, nmse(dB)=84.4280 | 90.1s
#   ↳ saved best_finetune.pt | best@485: val loss=0.000010, val nmse(dB)=84.4280
# [486/600] train loss=0.002655, nmse(dB)=102.1029 | val loss=0.000009, nmse(dB)=84.1589 | 90.7s
#   ↳ saved best_finetune.pt | best@486: val loss=0.000009, val nmse(dB)=84.1589
# [487/600] train loss=0.002641, nmse(dB)=102.0188 | val loss=0.000009, nmse(dB)=84.0864 | 89.8s
#   ↳ saved best_finetune.pt | best@487: val loss=0.000009, val nmse(dB)=84.0864
# [488/600] train loss=0.002477, nmse(dB)=101.8040 | val loss=0.000009, nmse(dB)=84.1721 | 88.4s
# [489/600] train loss=0.002555, nmse(dB)=101.9138 | val loss=0.000010, nmse(dB)=84.3781 | 86.6s
# [490/600] train loss=0.002672, nmse(dB)=102.1443 | val loss=0.000010, nmse(dB)=84.6256 | 83.8s
# [491/600] train loss=0.002504, nmse(dB)=101.8363 | val loss=0.000011, nmse(dB)=84.7329 | 85.9s
# [492/600] train loss=0.002462, nmse(dB)=101.7594 | val loss=0.000011, nmse(dB)=84.7904 | 84.5s
# [493/600] train loss=0.002641, nmse(dB)=102.0679 | val loss=0.000011, nmse(dB)=84.9317 | 88.6s
# [494/600] train loss=0.002665, nmse(dB)=102.0706 | val loss=0.000011, nmse(dB)=84.9921 | 90.2s
# [495/600] train loss=0.002566, nmse(dB)=101.9199 | val loss=0.000012, nmse(dB)=85.0487 | 90.6s
# [496/600] train loss=0.002725, nmse(dB)=102.1839 | val loss=0.000012, nmse(dB)=85.1975 | 90.0s
# [497/600] train loss=0.002653, nmse(dB)=102.1136 | val loss=0.000012, nmse(dB)=85.2992 | 90.3s
# [498/600] train loss=0.002655, nmse(dB)=102.0743 | val loss=0.000012, nmse(dB)=85.2831 | 90.0s
# [499/600] train loss=0.002594, nmse(dB)=101.9550 | val loss=0.000012, nmse(dB)=85.3566 | 89.6s
# [500/600] train loss=0.002606, nmse(dB)=101.9717 | val loss=0.000012, nmse(dB)=85.3291 | 90.4s
# [501/600] train loss=0.002732, nmse(dB)=102.1660 | val loss=0.000012, nmse(dB)=85.3117 | 90.2s
# [502/600] train loss=0.002534, nmse(dB)=101.9106 | val loss=0.000012, nmse(dB)=85.2723 | 89.0s
# [503/600] train loss=0.002569, nmse(dB)=101.9466 | val loss=0.000012, nmse(dB)=85.2469 | 90.4s
# [504/600] train loss=0.002560, nmse(dB)=101.8940 | val loss=0.000012, nmse(dB)=85.2465 | 90.9s
# [505/600] train loss=0.002574, nmse(dB)=101.9726 | val loss=0.000012, nmse(dB)=85.3161 | 89.9s
# [506/600] train loss=0.002613, nmse(dB)=102.0392 | val loss=0.000012, nmse(dB)=85.3935 | 89.9s
# [507/600] train loss=0.002552, nmse(dB)=101.8954 | val loss=0.000013, nmse(dB)=85.4602 | 90.7s
# [508/600] train loss=0.002550, nmse(dB)=101.8898 | val loss=0.000013, nmse(dB)=85.4946 | 89.8s
# [509/600] train loss=0.002623, nmse(dB)=102.0437 | val loss=0.000013, nmse(dB)=85.4462 | 90.4s
# [510/600] train loss=0.002497, nmse(dB)=101.8228 | val loss=0.000012, nmse(dB)=85.3774 | 91.1s
# [511/600] train loss=0.002616, nmse(dB)=102.0305 | val loss=0.000012, nmse(dB)=85.3446 | 90.1s
# [512/600] train loss=0.002512, nmse(dB)=101.8535 | val loss=0.000012, nmse(dB)=85.3992 | 90.4s
# [513/600] train loss=0.002647, nmse(dB)=102.0938 | val loss=0.000013, nmse(dB)=85.4666 | 89.6s
# [514/600] train loss=0.002501, nmse(dB)=101.8321 | val loss=0.000013, nmse(dB)=85.5198 | 91.1s
# [515/600] train loss=0.002505, nmse(dB)=101.8485 | val loss=0.000013, nmse(dB)=85.5439 | 91.3s
# [516/600] train loss=0.002559, nmse(dB)=101.9109 | val loss=0.000013, nmse(dB)=85.4960 | 90.8s
# [517/600] train loss=0.002579, nmse(dB)=101.9754 | val loss=0.000013, nmse(dB)=85.4623 | 89.7s
# [518/600] train loss=0.002601, nmse(dB)=101.9640 | val loss=0.000012, nmse(dB)=85.3854 | 90.5s
# [519/600] train loss=0.002554, nmse(dB)=101.9172 | val loss=0.000012, nmse(dB)=85.2810 | 90.6s
# [520/600] train loss=0.002555, nmse(dB)=101.8453 | val loss=0.000012, nmse(dB)=85.1518 | 90.5s
# [521/600] train loss=0.002601, nmse(dB)=101.9631 | val loss=0.000011, nmse(dB)=85.0045 | 90.9s
# [522/600] train loss=0.002671, nmse(dB)=102.1031 | val loss=0.000011, nmse(dB)=84.9171 | 90.1s
# [523/600] train loss=0.002684, nmse(dB)=102.1378 | val loss=0.000011, nmse(dB)=84.7519 | 91.8s
# [524/600] train loss=0.002599, nmse(dB)=101.9991 | val loss=0.000010, nmse(dB)=84.5163 | 90.5s
# [525/600] train loss=0.002483, nmse(dB)=101.8388 | val loss=0.000010, nmse(dB)=84.2419 | 90.9s
# [526/600] train loss=0.002483, nmse(dB)=101.7950 | val loss=0.000009, nmse(dB)=84.0039 | 89.1s
#   ↳ saved best_finetune.pt | best@526: val loss=0.000009, val nmse(dB)=84.0039
# [527/600] train loss=0.002571, nmse(dB)=101.9522 | val loss=0.000009, nmse(dB)=83.8137 | 89.2s
#   ↳ saved best_finetune.pt | best@527: val loss=0.000009, val nmse(dB)=83.8137
# [528/600] train loss=0.002541, nmse(dB)=101.9343 | val loss=0.000008, nmse(dB)=83.6617 | 91.3s
#   ↳ saved best_finetune.pt | best@528: val loss=0.000008, val nmse(dB)=83.6617
# [529/600] train loss=0.002585, nmse(dB)=101.9888 | val loss=0.000008, nmse(dB)=83.5352 | 90.3s
#   ↳ saved best_finetune.pt | best@529: val loss=0.000008, val nmse(dB)=83.5352
# [530/600] train loss=0.002620, nmse(dB)=102.0432 | val loss=0.000008, nmse(dB)=83.4714 | 90.2s
#   ↳ saved best_finetune.pt | best@530: val loss=0.000008, val nmse(dB)=83.4714
# [531/600] train loss=0.002511, nmse(dB)=101.8807 | val loss=0.000008, nmse(dB)=83.4065 | 89.0s
#   ↳ saved best_finetune.pt | best@531: val loss=0.000008, val nmse(dB)=83.4065
# [532/600] train loss=0.002712, nmse(dB)=102.1848 | val loss=0.000008, nmse(dB)=83.3317 | 90.8s
#   ↳ saved best_finetune.pt | best@532: val loss=0.000008, val nmse(dB)=83.3317
# [533/600] train loss=0.002573, nmse(dB)=101.9308 | val loss=0.000008, nmse(dB)=83.2258 | 90.5s
#   ↳ saved best_finetune.pt | best@533: val loss=0.000008, val nmse(dB)=83.2258
# [534/600] train loss=0.002547, nmse(dB)=101.9314 | val loss=0.000007, nmse(dB)=83.1646 | 89.8s
#   ↳ saved best_finetune.pt | best@534: val loss=0.000007, val nmse(dB)=83.1646
# [535/600] train loss=0.002388, nmse(dB)=101.6547 | val loss=0.000007, nmse(dB)=83.1132 | 90.3s
#   ↳ saved best_finetune.pt | best@535: val loss=0.000007, val nmse(dB)=83.1132
# [536/600] train loss=0.002693, nmse(dB)=102.1548 | val loss=0.000007, nmse(dB)=83.0768 | 91.0s
#   ↳ saved best_finetune.pt | best@536: val loss=0.000007, val nmse(dB)=83.0768
# [537/600] train loss=0.002548, nmse(dB)=101.8948 | val loss=0.000007, nmse(dB)=83.0433 | 90.1s
#   ↳ saved best_finetune.pt | best@537: val loss=0.000007, val nmse(dB)=83.0433
# [538/600] train loss=0.002614, nmse(dB)=102.0041 | val loss=0.000007, nmse(dB)=83.0218 | 90.1s
#   ↳ saved best_finetune.pt | best@538: val loss=0.000007, val nmse(dB)=83.0218
# [539/600] train loss=0.002578, nmse(dB)=101.9285 | val loss=0.000007, nmse(dB)=82.9978 | 90.3s
#   ↳ saved best_finetune.pt | best@539: val loss=0.000007, val nmse(dB)=82.9978
# [540/600] train loss=0.002625, nmse(dB)=102.0695 | val loss=0.000007, nmse(dB)=82.9851 | 89.7s
#   ↳ saved best_finetune.pt | best@540: val loss=0.000007, val nmse(dB)=82.9851
# [541/600] train loss=0.002440, nmse(dB)=101.7243 | val loss=0.000007, nmse(dB)=82.9550 | 91.6s
#   ↳ saved best_finetune.pt | best@541: val loss=0.000007, val nmse(dB)=82.9550
# [542/600] train loss=0.002577, nmse(dB)=101.9818 | val loss=0.000007, nmse(dB)=82.9674 | 88.1s
# [543/600] train loss=0.002650, nmse(dB)=102.0341 | val loss=0.000007, nmse(dB)=82.9796 | 88.2s
# [544/600] train loss=0.002511, nmse(dB)=101.8305 | val loss=0.000007, nmse(dB)=82.9908 | 91.8s
# [545/600] train loss=0.002536, nmse(dB)=101.9122 | val loss=0.000007, nmse(dB)=82.9940 | 90.2s
# [546/600] train loss=0.002341, nmse(dB)=101.5608 | val loss=0.000007, nmse(dB)=83.0031 | 91.5s
# [547/600] train loss=0.002555, nmse(dB)=101.9386 | val loss=0.000007, nmse(dB)=83.0013 | 89.9s
# [548/600] train loss=0.002608, nmse(dB)=102.0460 | val loss=0.000007, nmse(dB)=82.9869 | 88.2s
# [549/600] train loss=0.002658, nmse(dB)=102.1062 | val loss=0.000007, nmse(dB)=82.9979 | 90.1s
# [550/600] train loss=0.002655, nmse(dB)=102.0946 | val loss=0.000007, nmse(dB)=83.0250 | 91.0s
# [551/600] train loss=0.002596, nmse(dB)=101.9844 | val loss=0.000007, nmse(dB)=83.0089 | 90.0s
# [552/600] train loss=0.002478, nmse(dB)=101.8071 | val loss=0.000007, nmse(dB)=82.9605 | 89.9s
# [553/600] train loss=0.002544, nmse(dB)=101.8968 | val loss=0.000007, nmse(dB)=82.9191 | 91.5s
#   ↳ saved best_finetune.pt | best@553: val loss=0.000007, val nmse(dB)=82.9191
# [554/600] train loss=0.002495, nmse(dB)=101.8316 | val loss=0.000007, nmse(dB)=82.8562 | 89.6s
#   ↳ saved best_finetune.pt | best@554: val loss=0.000007, val nmse(dB)=82.8562
# [555/600] train loss=0.002571, nmse(dB)=101.9651 | val loss=0.000007, nmse(dB)=82.7823 | 90.0s
#   ↳ saved best_finetune.pt | best@555: val loss=0.000007, val nmse(dB)=82.7823
# [556/600] train loss=0.002556, nmse(dB)=101.8896 | val loss=0.000007, nmse(dB)=82.7196 | 90.7s
#   ↳ saved best_finetune.pt | best@556: val loss=0.000007, val nmse(dB)=82.7196
# [557/600] train loss=0.002721, nmse(dB)=102.1534 | val loss=0.000007, nmse(dB)=82.6870 | 90.3s
#   ↳ saved best_finetune.pt | best@557: val loss=0.000007, val nmse(dB)=82.6870
# [558/600] train loss=0.002527, nmse(dB)=101.8645 | val loss=0.000007, nmse(dB)=82.6668 | 89.8s
#   ↳ saved best_finetune.pt | best@558: val loss=0.000007, val nmse(dB)=82.6668
# [559/600] train loss=0.002535, nmse(dB)=101.8858 | val loss=0.000007, nmse(dB)=82.6389 | 90.9s
#   ↳ saved best_finetune.pt | best@559: val loss=0.000007, val nmse(dB)=82.6389
# [560/600] train loss=0.002504, nmse(dB)=101.8445 | val loss=0.000007, nmse(dB)=82.6071 | 91.0s
#   ↳ saved best_finetune.pt | best@560: val loss=0.000007, val nmse(dB)=82.6071
# [561/600] train loss=0.002589, nmse(dB)=101.9446 | val loss=0.000007, nmse(dB)=82.5833 | 89.9s
#   ↳ saved best_finetune.pt | best@561: val loss=0.000007, val nmse(dB)=82.5833
# [562/600] train loss=0.002511, nmse(dB)=101.8308 | val loss=0.000007, nmse(dB)=82.5728 | 89.0s
#   ↳ saved best_finetune.pt | best@562: val loss=0.000007, val nmse(dB)=82.5728
# [563/600] train loss=0.002669, nmse(dB)=102.1370 | val loss=0.000007, nmse(dB)=82.5657 | 89.4s
#   ↳ saved best_finetune.pt | best@563: val loss=0.000007, val nmse(dB)=82.5657
# [564/600] train loss=0.002576, nmse(dB)=101.9776 | val loss=0.000007, nmse(dB)=82.5676 | 89.1s
# [565/600] train loss=0.002487, nmse(dB)=101.8371 | val loss=0.000007, nmse(dB)=82.5706 | 88.4s
# [566/600] train loss=0.002464, nmse(dB)=101.8035 | val loss=0.000007, nmse(dB)=82.5758 | 90.8s
# [567/600] train loss=0.002599, nmse(dB)=101.9875 | val loss=0.000007, nmse(dB)=82.5819 | 91.4s
# [568/600] train loss=0.002728, nmse(dB)=102.2292 | val loss=0.000007, nmse(dB)=82.5804 | 91.0s
# [569/600] train loss=0.002443, nmse(dB)=101.7410 | val loss=0.000007, nmse(dB)=82.5780 | 89.0s
# [570/600] train loss=0.002625, nmse(dB)=102.0525 | val loss=0.000007, nmse(dB)=82.5762 | 88.5s
# [571/600] train loss=0.002369, nmse(dB)=101.6002 | val loss=0.000007, nmse(dB)=82.5682 | 90.3s
# [572/600] train loss=0.002573, nmse(dB)=101.9108 | val loss=0.000006, nmse(dB)=82.5531 | 90.3s
#   ↳ saved best_finetune.pt | best@572: val loss=0.000006, val nmse(dB)=82.5531
# [573/600] train loss=0.002656, nmse(dB)=102.0562 | val loss=0.000006, nmse(dB)=82.5447 | 89.4s
#   ↳ saved best_finetune.pt | best@573: val loss=0.000006, val nmse(dB)=82.5447
# [574/600] train loss=0.002484, nmse(dB)=101.7630 | val loss=0.000006, nmse(dB)=82.5382 | 90.0s
#   ↳ saved best_finetune.pt | best@574: val loss=0.000006, val nmse(dB)=82.5382
# [575/600] train loss=0.002502, nmse(dB)=101.8717 | val loss=0.000006, nmse(dB)=82.5367 | 89.4s
#   ↳ saved best_finetune.pt | best@575: val loss=0.000006, val nmse(dB)=82.5367
# [576/600] train loss=0.002521, nmse(dB)=101.8766 | val loss=0.000006, nmse(dB)=82.5391 | 89.8s
# [577/600] train loss=0.002581, nmse(dB)=101.9716 | val loss=0.000006, nmse(dB)=82.5444 | 90.2s
# [578/600] train loss=0.002560, nmse(dB)=101.9523 | val loss=0.000006, nmse(dB)=82.5511 | 89.9s
# [579/600] train loss=0.002548, nmse(dB)=101.8854 | val loss=0.000007, nmse(dB)=82.5592 | 89.9s
# [580/600] train loss=0.002550, nmse(dB)=101.9134 | val loss=0.000007, nmse(dB)=82.5608 | 88.4s
# [581/600] train loss=0.002474, nmse(dB)=101.8038 | val loss=0.000006, nmse(dB)=82.5580 | 88.3s
# [582/600] train loss=0.002552, nmse(dB)=101.8812 | val loss=0.000006, nmse(dB)=82.5556 | 90.5s
# [583/600] train loss=0.002630, nmse(dB)=102.0364 | val loss=0.000006, nmse(dB)=82.5527 | 90.1s
# [584/600] train loss=0.002716, nmse(dB)=102.1832 | val loss=0.000006, nmse(dB)=82.5509 | 89.0s
# [585/600] train loss=0.002622, nmse(dB)=102.0393 | val loss=0.000006, nmse(dB)=82.5479 | 89.4s
# [586/600] train loss=0.002526, nmse(dB)=101.8660 | val loss=0.000006, nmse(dB)=82.5474 | 90.0s
# [587/600] train loss=0.002606, nmse(dB)=102.0251 | val loss=0.000006, nmse(dB)=82.5476 | 90.2s
# [588/600] train loss=0.002607, nmse(dB)=102.0133 | val loss=0.000006, nmse(dB)=82.5491 | 89.5s
# [589/600] train loss=0.002517, nmse(dB)=101.8490 | val loss=0.000006, nmse(dB)=82.5497 | 89.9s
# [590/600] train loss=0.002455, nmse(dB)=101.7580 | val loss=0.000006, nmse(dB)=82.5495 | 89.6s
# [591/600] train loss=0.002573, nmse(dB)=101.9888 | val loss=0.000006, nmse(dB)=82.5486 | 90.8s
# [592/600] train loss=0.002490, nmse(dB)=101.8314 | val loss=0.000006, nmse(dB)=82.5478 | 90.8s
# [593/600] train loss=0.002513, nmse(dB)=101.8738 | val loss=0.000006, nmse(dB)=82.5470 | 90.4s
# [594/600] train loss=0.002586, nmse(dB)=101.9805 | val loss=0.000006, nmse(dB)=82.5460 | 90.6s
# [595/600] train loss=0.002598, nmse(dB)=101.9875 | val loss=0.000006, nmse(dB)=82.5454 | 89.9s
# [596/600] train loss=0.002576, nmse(dB)=101.9196 | val loss=0.000006, nmse(dB)=82.5455 | 90.7s
# [597/600] train loss=0.002590, nmse(dB)=101.9653 | val loss=0.000006, nmse(dB)=82.5455 | 91.0s
# [598/600] train loss=0.002475, nmse(dB)=101.7813 | val loss=0.000006, nmse(dB)=82.5455 | 90.7s
# [599/600] train loss=0.002539, nmse(dB)=101.8884 | val loss=0.000006, nmse(dB)=82.5455 | 90.8s
# [600/600] train loss=0.002509, nmse(dB)=101.8421 | val loss=0.000006, nmse(dB)=82.5455 | 89.8s
#
# === Training Summary ===
# Total time: 53888.6s (14h 58m 8.6s)
# Best epoch: 575 | best val loss=0.000006, best val nmse(dB)=82.5367

# %%
ch, img, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# y abs mean: 3.7319182334467466e-07
# y abs max : 1.0209263230780462e-06
# y power   : 1.9176560707382048e-13
# yhat abs mean: 0.0020167769235118066
# yhat abs max : 0.00973586404142266
# yhat power   : 6.4640988089888944e-06

# %% [markdown]
# # 데이터 입력 및 형태

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("N(cam_files)  :", len(cam_files))
print("N(min)        :", min(len(comm_frames), len(cam_files)))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

print("\n=== one batch shapes ===")
ch, img, y = next(iter(train_loader))
print("ch :", tuple(ch.shape), " -> (B,T,F_in)")
print("img:", tuple(img.shape), " -> (B,3,224,224)")
print("y  :", tuple(y.shape), " -> (B,F_out)")
with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat:", tuple(yhat.shape), " -> (B,F_out)")
print("this forward predicted vectors:", yhat.shape[0], "(=B)")
print("each vector predicts elements:", yhat.shape[1], "(=F_out)")
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# N(cam_files)  : 1114
# N(min)        : 100
# past_len      : 16
# len(ds)       : 84
# len(train_ds) : 63
# len(val_ds)   : 21
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B,T,F_in)
# img: (32, 16, 3, 224, 224)  -> (B,3,224,224)
# y  : (32, 2048)  -> (B,F_out)
# yhat: (32, 2048)  -> (B,F_out)
# this forward predicted vectors: 32 (=B)
# each vector predicts elements: 2048 (=F_out)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
