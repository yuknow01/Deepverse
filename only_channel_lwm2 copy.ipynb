# %% [markdown]
# # lwm2
# <br>모델 크기 차이에 따른 성능 차이 비교
# <br> element_length=16, d_model=64
# <br> in_proj: F_in(2048) → 512 → 128 → 16

# %% [markdown]
# # Import

# %%
import os
import sys

import numpy as  np
from lwm_model2 import lwm  # 클래스 import
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import torch.nn as nn   
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Setting
# ### CUDA 몇번 사용하는지 잘 확인하기

# %%
# Scenes 1000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(100))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"현재 사용 중인 장치: {device}")
# Out:
# 현재 사용 중인 장치: cuda:1

# %% [markdown]
# # Generate a dataset

# %%
# scenes / subcarriers는 그대로
param_manager.params["radar"]["enable"] = False

# lidar가 dict로 존재하면 disable
if isinstance(param_manager.params.get("lidar", None), dict):
    param_manager.params["lidar"]["enable"] = False

# position이 dict로 존재하면 disable
if isinstance(param_manager.params.get("position", None), dict):
    param_manager.params["position"]["enable"] = False

# Radar, LiDAR, Position 사용하지 않으므로 False 
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (0.91s)

# %% [markdown]
# # Prerocessing

# %% [markdown]
# #### Channel

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device=device, eps=1e-16):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex64)
    
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(device, dtype=torch.float32)
    return H

# %% [markdown]
# #### image

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class ChannelNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, ue_idx=0, past_len=16, device=device,
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        self.comm_frames = comm_frames
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device

        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = len(self.comm_frames)
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1) Channel Past
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            h = preprocess_channel_coeffs_minmax(
                coeffs_np,
                self.r_min, self.r_max, self.i_min, self.i_max,
                device=self.device
            ).reshape(-1)  # (2048,)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)  # (T, 2048)

        # 2) Target Next
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_minmax(
            coeffs_np_next,
            self.r_min, self.r_max, self.i_min, self.i_max,
            device=self.device
        ).reshape(-1)  # (2048,)

        return channel_past, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)

ds = ChannelNextStepDatasetGPU(
    comm_frames=comm_frames,
    ue_idx=0,
    past_len=16,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   
)
ch, y = next(iter(loader))
print(ch.shape, y.shape)
print(ch.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 2048])
# cuda:1 cuda:1

# %% [markdown]
# # Fine-tuning

# %%
class LWMForecasterNoEdit(nn.Module):
    """
    lwm 코드는 수정하지 않고, encoder(embedding+layers)만 직접 호출해서 forecasting
    Input : ch  (B,T,F_in)
    Output: yhat(B,F_out)
    """
    def __init__(
        self,
        base_lwm: nn.Module,
        F_in: int,
        F_out: int,
        pool: str = "last",
        freeze_backbone: bool = False,
    ):
        super().__init__()
        self.base = base_lwm
        self.pool = pool

        n_dim   = self.base.embedding.element_length  # 16
        d_model = self.base.embedding.d_model         # 64

        self.in_proj = nn.Sequential(
            nn.Linear(F_in, 512),
            nn.GELU(),
            nn.Linear(512, 128),
            nn.GELU(),
            nn.Linear(128, n_dim),
        )

        self.head = nn.Linear(d_model, F_out)

        if freeze_backbone:
            for p in self.base.parameters():
                p.requires_grad = False
            for p in self.in_proj.parameters():
                p.requires_grad = True
            for p in self.head.parameters():
                p.requires_grad = True

    def forward(self, ch):
        x = self.in_proj(ch)          # (B,T,F_in) -> (B,T,16)

        out = self.base.embedding(x)  # (B,T,64)
        for layer in self.base.layers:
            out, _ = layer(out)       # (B,T,64)

        if self.pool == "last":
            z = out[:, -1, :]
        elif self.pool == "mean":
            z = out.mean(dim=1)
        else:
            raise ValueError(f"Unknown pool={self.pool}")

        return self.head(z)           # (B,F_out)

# %% [markdown]
# # NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# %% [markdown]
# # Train/val Split

# %%
# 겹치는 부분이 있는지 확인하는 함수
def used_frames_for_ds_indices(ds, ds_indices):
    used = set()
    for i in ds_indices:
        t = ds.valid_start + i
        # inputs use [t-T+1 .. t], target uses (t+1)
        used.update(range(t - T + 1, t + 2))
    return used

# %%
n_total = len(ds)
T = ds.past_len  # = past_len

# ---- choose k so that train=3k, val=k and NO frame-overlap is possible ----
k_max = (n_total - T) // 4
if k_max <= 0:
    raise ValueError(
        f"Not enough data for strict non-overlap 3:1. "
        f"n_total={n_total}, past_len(T)={T}. "
        f"Try increasing scenes or decreasing past_len."
    )

k = k_max               # use as much data as possible under constraints
n_val = k
n_train = 3 * k

train_idx = list(range(0, n_train))
val_idx   = list(range(n_total - n_val, n_total))

print("n_total:", n_total, "T:", T)
print("train samples:", len(train_idx), "val samples:", len(val_idx), "ratio:", len(train_idx)/len(val_idx))

# ---- min/max ONLY from train (same as your original policy) ----
train_ts = [ds.valid_start + i for i in train_idx]

(real_min, real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_ts, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)

F_in = 2048


overlap = used_frames_for_ds_indices(ds, train_idx).intersection(
          used_frames_for_ds_indices(ds, val_idx))
print("frame-overlap count:", len(overlap))
assert len(overlap) == 0, "Leakage detected: train/val share frames!"

# Verify (channel-only)
ch, y = next(iter(train_loader))   # ✅ img 제거
F_out = y.shape[-1]

print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")

# (선택) ch도 같이 범위 확인하고 싶으면
print(f"ch stats | min: {ch.min().item():.4f}, max: {ch.max().item():.4f}")
# Out:
# n_total: 84 T: 16
# train samples: 51 val samples: 17 ratio: 3.0
# Calculating min/max over training set...
# Done. rmin=-1.0646139639174899e-06, rmax=1.0917989155343993e-06, imin=-1.0719516685941772e-06, imax=1.0643868111374237e-06
# Dataset statistical values set in the dataset.
# frame-overlap count: 0
#
# === Data Check ===
# y stats | min: 0.0000, max: 0.9943
# If scaling worked correctly, values should be within [0, 1].
# ch stats | min: -0.2332, max: 1.2388

# %% [markdown]
# # Train/Eval 함수

# %%
# batch check
ch, y = next(iter(train_loader))
print(ch.shape, y.shape)

def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()
    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, y in loader:
        ch = ch.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        yhat = model(ch)                
        loss = F.mse_loss(yhat, y)
        loss.backward()

        if grad_clip and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        optimizer.step()

        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, y in loader:
        ch = ch.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        yhat = model(ch)                 
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)
# Out:
# torch.Size([32, 16, 2048]) torch.Size([32, 2048])

# %% [markdown]
# # 모델 생성 및 확인

# %%
# 배치 하나로 F_in/F_out 자동 확정
ch, y = next(iter(train_loader))
F_in  = ch.shape[-1]
F_out = y.shape[-1]
print("Detected:", "F_in=", F_in, "F_out=", F_out)
print("Batch devices:", ch.device, y.device)

backbone = lwm().to(device)  
model = LWMForecasterNoEdit(
    base_lwm=backbone,
    F_in=F_in,
    F_out=F_out,
    pool="last",
    freeze_backbone=False,
).to(device)

# sanity forward
model.eval()
with torch.no_grad():
    # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
    yhat = model(ch.to(device))
print("yhat:", yhat.shape, "y:", y.shape)
# Out:
# Detected: F_in= 2048 F_out= 2048
# Batch devices: cuda:1 cuda:1
# yhat: torch.Size([32, 2048]) y: torch.Size([32, 2048])

# %% [markdown]
# # Optimizer/Scheduler 설정

# %%
# requires_grad=True인 파라미터만 학습
trainable_params = [p for p in model.parameters() if p.requires_grad]
print("trainable params:", sum(p.numel() for p in trainable_params))

optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# (선택) cosine scheduler
epochs = 500
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
# Out:
# trainable params: 1853648

# %% [markdown]
# # 학습 루프 및 checkpoint 저장

# %%
import time
import os
import torch

best_val = float("inf")
best_val_nmse = None
best_epoch = None

t_train0 = time.time()  # ✅ 전체 학습 시작 시간

# 어떤 모델을 몇개의 scene으로 학습을 했는지 기록
log_path = "lwm_model2_scene100.txt"

with open(log_path, "w", encoding="utf-8") as f:
    for epoch in range(1, epochs + 1):
        t0 = time.time()

        tr_loss, tr_nmse = train_one_epoch(
            model, train_loader, optimizer, device=device, grad_clip=1.0
        )
        va_loss, va_nmse = evaluate(model, val_loader, device=device)

        scheduler.step()

        dt = time.time() - t0

        # ✅ 1) print에 쓰는 문자열을 변수로 만들기
        line = (
            f"[{epoch:02d}/{epochs}] "
            f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
            f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
            f"{dt:.1f}s"
        )

        # ✅ 2) 콘솔 + 파일에 동시에 기록
        print(line)
        f.write(line + "\n")
        f.flush()

        if va_loss < best_val:
            best_val = va_loss
            best_val_nmse = va_nmse
            best_epoch = epoch

            ckpt_path = "bestc_channel_only_finetune.pt"
            torch.save(
                {
                    "epoch": epoch,
                    "model_state": model.state_dict(),
                    "optimizer_state": optimizer.state_dict(),
                    "F_in": F_in,
                    "F_out": F_out,
                    "best_val_loss": best_val,
                    "best_val_nmse_db": best_val_nmse,
                },
                ckpt_path,
            )

            save_line = (
                f"  ↳ saved {ckpt_path} | best@{best_epoch}: "
                f"val loss={best_val:.6f}, val nmse(dB)={best_val_nmse:.4f}"
            )
            print(save_line)
            f.write(save_line + "\n")
            f.flush()

# ✅ 전체 학습 종료 후 총 시간 출력 + 파일 append
total_sec = time.time() - t_train0
h = int(total_sec // 3600)
m = int((total_sec % 3600) // 60)
s = total_sec % 60

summary1 = "\n=== Training Summary ==="
summary2 = f"Total time: {total_sec:.1f}s ({h}h {m}m {s:.1f}s)"
summary3 = (
    f"Best epoch: {best_epoch} | best val loss={best_val:.6f}, "
    f"best val nmse(dB)={best_val_nmse:.4f}"
)

print(summary1)
print(summary2)
print(summary3)

with open(log_path, "a", encoding="utf-8") as f:
    f.write(summary1 + "\n")
    f.write(summary2 + "\n")
    f.write(summary3 + "\n")

print("Log saved to:", os.path.abspath(log_path))
# Out:
# [01/500] train loss=0.596009, nmse(dB)=3.1390 | val loss=0.521645, nmse(dB)=3.0603 | 0.3s
#   ↳ saved bestc_channel_only_finetune.pt | best@1: val loss=0.521645, val nmse(dB)=3.0603
# [02/500] train loss=0.552775, nmse(dB)=2.8805 | val loss=0.495514, nmse(dB)=2.8371 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@2: val loss=0.495514, val nmse(dB)=2.8371
# [03/500] train loss=0.532788, nmse(dB)=2.6586 | val loss=0.479030, nmse(dB)=2.6902 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@3: val loss=0.479030, val nmse(dB)=2.6902
# [04/500] train loss=0.516064, nmse(dB)=2.5601 | val loss=0.465351, nmse(dB)=2.5643 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@4: val loss=0.465351, val nmse(dB)=2.5643
# [05/500] train loss=0.503356, nmse(dB)=2.4484 | val loss=0.452713, nmse(dB)=2.4447 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@5: val loss=0.452713, val nmse(dB)=2.4447
# [06/500] train loss=0.496345, nmse(dB)=2.3037 | val loss=0.441374, nmse(dB)=2.3345 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@6: val loss=0.441374, val nmse(dB)=2.3345
# [07/500] train loss=0.481029, nmse(dB)=2.2517 | val loss=0.430303, nmse(dB)=2.2242 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@7: val loss=0.430303, val nmse(dB)=2.2242
# [08/500] train loss=0.471291, nmse(dB)=2.1407 | val loss=0.419448, nmse(dB)=2.1132 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@8: val loss=0.419448, val nmse(dB)=2.1132
# [09/500] train loss=0.460267, nmse(dB)=2.0512 | val loss=0.409027, nmse(dB)=2.0039 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@9: val loss=0.409027, val nmse(dB)=2.0039
# [10/500] train loss=0.449638, nmse(dB)=1.9384 | val loss=0.398815, nmse(dB)=1.8940 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@10: val loss=0.398815, val nmse(dB)=1.8940
# [11/500] train loss=0.437258, nmse(dB)=1.8420 | val loss=0.388461, nmse(dB)=1.7797 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@11: val loss=0.388461, val nmse(dB)=1.7797
# [12/500] train loss=0.426650, nmse(dB)=1.7470 | val loss=0.378052, nmse(dB)=1.6617 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@12: val loss=0.378052, val nmse(dB)=1.6617
# [13/500] train loss=0.419446, nmse(dB)=1.6166 | val loss=0.367817, nmse(dB)=1.5425 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@13: val loss=0.367817, val nmse(dB)=1.5425
# [14/500] train loss=0.408250, nmse(dB)=1.5175 | val loss=0.357807, nmse(dB)=1.4226 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@14: val loss=0.357807, val nmse(dB)=1.4226
# [15/500] train loss=0.400668, nmse(dB)=1.4175 | val loss=0.347862, nmse(dB)=1.3001 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@15: val loss=0.347862, val nmse(dB)=1.3001
# [16/500] train loss=0.389395, nmse(dB)=1.3160 | val loss=0.338076, nmse(dB)=1.1762 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@16: val loss=0.338076, val nmse(dB)=1.1762
# [17/500] train loss=0.379278, nmse(dB)=1.2096 | val loss=0.328472, nmse(dB)=1.0509 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@17: val loss=0.328472, val nmse(dB)=1.0509
# [18/500] train loss=0.367913, nmse(dB)=1.0925 | val loss=0.319038, nmse(dB)=0.9243 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@18: val loss=0.319038, val nmse(dB)=0.9243
# [19/500] train loss=0.360716, nmse(dB)=0.9721 | val loss=0.309801, nmse(dB)=0.7967 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@19: val loss=0.309801, val nmse(dB)=0.7967
# [20/500] train loss=0.350066, nmse(dB)=0.8603 | val loss=0.300670, nmse(dB)=0.6666 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@20: val loss=0.300670, val nmse(dB)=0.6666
# [21/500] train loss=0.341072, nmse(dB)=0.7455 | val loss=0.291705, nmse(dB)=0.5351 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@21: val loss=0.291705, val nmse(dB)=0.5351
# [22/500] train loss=0.333478, nmse(dB)=0.6177 | val loss=0.283014, nmse(dB)=0.4036 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@22: val loss=0.283014, val nmse(dB)=0.4036
# [23/500] train loss=0.324778, nmse(dB)=0.5284 | val loss=0.274564, nmse(dB)=0.2719 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@23: val loss=0.274564, val nmse(dB)=0.2719
# [24/500] train loss=0.316357, nmse(dB)=0.4035 | val loss=0.266234, nmse(dB)=0.1380 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@24: val loss=0.266234, val nmse(dB)=0.1380
# [25/500] train loss=0.307407, nmse(dB)=0.3087 | val loss=0.258062, nmse(dB)=0.0025 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@25: val loss=0.258062, val nmse(dB)=0.0025
# [26/500] train loss=0.298912, nmse(dB)=0.1744 | val loss=0.250214, nmse(dB)=-0.1317 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@26: val loss=0.250214, val nmse(dB)=-0.1317
# [27/500] train loss=0.291428, nmse(dB)=0.0411 | val loss=0.242609, nmse(dB)=-0.2659 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@27: val loss=0.242609, val nmse(dB)=-0.2659
# [28/500] train loss=0.283742, nmse(dB)=-0.0615 | val loss=0.235133, nmse(dB)=-0.4020 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@28: val loss=0.235133, val nmse(dB)=-0.4020
# [29/500] train loss=0.280559, nmse(dB)=-0.1973 | val loss=0.227888, nmse(dB)=-0.5380 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@29: val loss=0.227888, val nmse(dB)=-0.5380
# [30/500] train loss=0.271784, nmse(dB)=-0.3206 | val loss=0.220791, nmse(dB)=-0.6756 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@30: val loss=0.220791, val nmse(dB)=-0.6756
# [31/500] train loss=0.259713, nmse(dB)=-0.4094 | val loss=0.213887, nmse(dB)=-0.8137 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@31: val loss=0.213887, val nmse(dB)=-0.8137
# [32/500] train loss=0.256213, nmse(dB)=-0.5225 | val loss=0.207197, nmse(dB)=-0.9519 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@32: val loss=0.207197, val nmse(dB)=-0.9519
# [33/500] train loss=0.249427, nmse(dB)=-0.6488 | val loss=0.200681, nmse(dB)=-1.0909 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@33: val loss=0.200681, val nmse(dB)=-1.0909
# [34/500] train loss=0.244394, nmse(dB)=-0.7857 | val loss=0.194336, nmse(dB)=-1.2306 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@34: val loss=0.194336, val nmse(dB)=-1.2306
# [35/500] train loss=0.236148, nmse(dB)=-0.8576 | val loss=0.188243, nmse(dB)=-1.3692 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@35: val loss=0.188243, val nmse(dB)=-1.3692
# [36/500] train loss=0.231147, nmse(dB)=-0.9819 | val loss=0.182404, nmse(dB)=-1.5063 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@36: val loss=0.182404, val nmse(dB)=-1.5063
# [37/500] train loss=0.223162, nmse(dB)=-1.1108 | val loss=0.176722, nmse(dB)=-1.6439 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@37: val loss=0.176722, val nmse(dB)=-1.6439
# [38/500] train loss=0.219302, nmse(dB)=-1.1917 | val loss=0.171141, nmse(dB)=-1.7835 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@38: val loss=0.171141, val nmse(dB)=-1.7835
# [39/500] train loss=0.215786, nmse(dB)=-1.3311 | val loss=0.165747, nmse(dB)=-1.9229 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@39: val loss=0.165747, val nmse(dB)=-1.9229
# [40/500] train loss=0.207578, nmse(dB)=-1.4173 | val loss=0.160584, nmse(dB)=-2.0606 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@40: val loss=0.160584, val nmse(dB)=-2.0606
# [41/500] train loss=0.203829, nmse(dB)=-1.5360 | val loss=0.155544, nmse(dB)=-2.1994 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@41: val loss=0.155544, val nmse(dB)=-2.1994
# [42/500] train loss=0.201443, nmse(dB)=-1.6521 | val loss=0.150603, nmse(dB)=-2.3400 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@42: val loss=0.150603, val nmse(dB)=-2.3400
# [43/500] train loss=0.194790, nmse(dB)=-1.7246 | val loss=0.145849, nmse(dB)=-2.4796 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@43: val loss=0.145849, val nmse(dB)=-2.4796
# [44/500] train loss=0.188289, nmse(dB)=-1.8701 | val loss=0.141259, nmse(dB)=-2.6189 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@44: val loss=0.141259, val nmse(dB)=-2.6189
# [45/500] train loss=0.185667, nmse(dB)=-1.9635 | val loss=0.136873, nmse(dB)=-2.7563 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@45: val loss=0.136873, val nmse(dB)=-2.7563
# [46/500] train loss=0.177643, nmse(dB)=-2.0722 | val loss=0.132661, nmse(dB)=-2.8925 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@46: val loss=0.132661, val nmse(dB)=-2.8925
# [47/500] train loss=0.173249, nmse(dB)=-2.1810 | val loss=0.128535, nmse(dB)=-3.0301 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@47: val loss=0.128535, val nmse(dB)=-3.0301
# [48/500] train loss=0.171884, nmse(dB)=-2.3159 | val loss=0.124541, nmse(dB)=-3.1677 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@48: val loss=0.124541, val nmse(dB)=-3.1677
# [49/500] train loss=0.168007, nmse(dB)=-2.4169 | val loss=0.120709, nmse(dB)=-3.3040 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@49: val loss=0.120709, val nmse(dB)=-3.3040
# [50/500] train loss=0.163203, nmse(dB)=-2.4765 | val loss=0.116961, nmse(dB)=-3.4415 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@50: val loss=0.116961, val nmse(dB)=-3.4415
# [51/500] train loss=0.159333, nmse(dB)=-2.6247 | val loss=0.113381, nmse(dB)=-3.5771 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@51: val loss=0.113381, val nmse(dB)=-3.5771
# [52/500] train loss=0.155806, nmse(dB)=-2.7084 | val loss=0.109928, nmse(dB)=-3.7121 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@52: val loss=0.109928, val nmse(dB)=-3.7121
# [53/500] train loss=0.153357, nmse(dB)=-2.7995 | val loss=0.106560, nmse(dB)=-3.8479 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@53: val loss=0.106560, val nmse(dB)=-3.8479
# [54/500] train loss=0.149403, nmse(dB)=-2.8727 | val loss=0.103309, nmse(dB)=-3.9832 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@54: val loss=0.103309, val nmse(dB)=-3.9832
# [55/500] train loss=0.146389, nmse(dB)=-2.9722 | val loss=0.100250, nmse(dB)=-4.1144 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@55: val loss=0.100250, val nmse(dB)=-4.1144
# [56/500] train loss=0.144904, nmse(dB)=-3.0868 | val loss=0.097262, nmse(dB)=-4.2466 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@56: val loss=0.097262, val nmse(dB)=-4.2466
# [57/500] train loss=0.142316, nmse(dB)=-3.1687 | val loss=0.094233, nmse(dB)=-4.3849 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@57: val loss=0.094233, val nmse(dB)=-4.3849
# [58/500] train loss=0.137894, nmse(dB)=-3.2704 | val loss=0.091365, nmse(dB)=-4.5200 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@58: val loss=0.091365, val nmse(dB)=-4.5200
# [59/500] train loss=0.134757, nmse(dB)=-3.3686 | val loss=0.088657, nmse(dB)=-4.6516 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@59: val loss=0.088657, val nmse(dB)=-4.6516
# [60/500] train loss=0.132053, nmse(dB)=-3.4647 | val loss=0.086035, nmse(dB)=-4.7830 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@60: val loss=0.086035, val nmse(dB)=-4.7830
# [61/500] train loss=0.128645, nmse(dB)=-3.5863 | val loss=0.083469, nmse(dB)=-4.9156 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@61: val loss=0.083469, val nmse(dB)=-4.9156
# [62/500] train loss=0.127534, nmse(dB)=-3.6268 | val loss=0.081026, nmse(dB)=-5.0456 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@62: val loss=0.081026, val nmse(dB)=-5.0456
# [63/500] train loss=0.122786, nmse(dB)=-3.7491 | val loss=0.078682, nmse(dB)=-5.1743 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@63: val loss=0.078682, val nmse(dB)=-5.1743
# [64/500] train loss=0.121265, nmse(dB)=-3.7767 | val loss=0.076416, nmse(dB)=-5.3024 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@64: val loss=0.076416, val nmse(dB)=-5.3024
# [65/500] train loss=0.118706, nmse(dB)=-3.9194 | val loss=0.074198, nmse(dB)=-5.4317 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@65: val loss=0.074198, val nmse(dB)=-5.4317
# [66/500] train loss=0.116710, nmse(dB)=-3.9945 | val loss=0.072061, nmse(dB)=-5.5600 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@66: val loss=0.072061, val nmse(dB)=-5.5600
# [67/500] train loss=0.113242, nmse(dB)=-4.0765 | val loss=0.069981, nmse(dB)=-5.6887 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@67: val loss=0.069981, val nmse(dB)=-5.6887
# [68/500] train loss=0.114324, nmse(dB)=-4.1158 | val loss=0.067981, nmse(dB)=-5.8162 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@68: val loss=0.067981, val nmse(dB)=-5.8162
# [69/500] train loss=0.110335, nmse(dB)=-4.2059 | val loss=0.066047, nmse(dB)=-5.9432 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@69: val loss=0.066047, val nmse(dB)=-5.9432
# [70/500] train loss=0.109112, nmse(dB)=-4.2945 | val loss=0.064189, nmse(dB)=-6.0688 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@70: val loss=0.064189, val nmse(dB)=-6.0688
# [71/500] train loss=0.107920, nmse(dB)=-4.3975 | val loss=0.062424, nmse(dB)=-6.1916 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@71: val loss=0.062424, val nmse(dB)=-6.1916
# [72/500] train loss=0.105909, nmse(dB)=-4.4835 | val loss=0.060694, nmse(dB)=-6.3156 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@72: val loss=0.060694, val nmse(dB)=-6.3156
# [73/500] train loss=0.104137, nmse(dB)=-4.5040 | val loss=0.059003, nmse(dB)=-6.4404 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@73: val loss=0.059003, val nmse(dB)=-6.4404
# [74/500] train loss=0.103615, nmse(dB)=-4.5984 | val loss=0.057372, nmse(dB)=-6.5643 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@74: val loss=0.057372, val nmse(dB)=-6.5643
# [75/500] train loss=0.101686, nmse(dB)=-4.6801 | val loss=0.055812, nmse(dB)=-6.6862 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@75: val loss=0.055812, val nmse(dB)=-6.6862
# [76/500] train loss=0.100419, nmse(dB)=-4.7308 | val loss=0.054317, nmse(dB)=-6.8064 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@76: val loss=0.054317, val nmse(dB)=-6.8064
# [77/500] train loss=0.099604, nmse(dB)=-4.8190 | val loss=0.052843, nmse(dB)=-6.9282 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@77: val loss=0.052843, val nmse(dB)=-6.9282
# [78/500] train loss=0.096822, nmse(dB)=-4.8787 | val loss=0.051433, nmse(dB)=-7.0481 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@78: val loss=0.051433, val nmse(dB)=-7.0481
# [79/500] train loss=0.093439, nmse(dB)=-5.0335 | val loss=0.050115, nmse(dB)=-7.1634 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@79: val loss=0.050115, val nmse(dB)=-7.1634
# [80/500] train loss=0.092988, nmse(dB)=-5.0606 | val loss=0.048824, nmse(dB)=-7.2796 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@80: val loss=0.048824, val nmse(dB)=-7.2796
# [81/500] train loss=0.093484, nmse(dB)=-5.0688 | val loss=0.047552, nmse(dB)=-7.3974 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@81: val loss=0.047552, val nmse(dB)=-7.3974
# [82/500] train loss=0.091193, nmse(dB)=-5.1356 | val loss=0.046327, nmse(dB)=-7.5139 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@82: val loss=0.046327, val nmse(dB)=-7.5139
# [83/500] train loss=0.087652, nmse(dB)=-5.2464 | val loss=0.045130, nmse(dB)=-7.6309 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@83: val loss=0.045130, val nmse(dB)=-7.6309
# [84/500] train loss=0.088414, nmse(dB)=-5.2798 | val loss=0.043959, nmse(dB)=-7.7486 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@84: val loss=0.043959, val nmse(dB)=-7.7486
# [85/500] train loss=0.089313, nmse(dB)=-5.2775 | val loss=0.042857, nmse(dB)=-7.8624 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@85: val loss=0.042857, val nmse(dB)=-7.8624
# [86/500] train loss=0.087423, nmse(dB)=-5.4093 | val loss=0.041782, nmse(dB)=-7.9762 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@86: val loss=0.041782, val nmse(dB)=-7.9762
# [87/500] train loss=0.085353, nmse(dB)=-5.5087 | val loss=0.040726, nmse(dB)=-8.0912 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@87: val loss=0.040726, val nmse(dB)=-8.0912
# [88/500] train loss=0.083484, nmse(dB)=-5.5687 | val loss=0.039728, nmse(dB)=-8.2028 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@88: val loss=0.039728, val nmse(dB)=-8.2028
# [89/500] train loss=0.084112, nmse(dB)=-5.5370 | val loss=0.038796, nmse(dB)=-8.3101 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@89: val loss=0.038796, val nmse(dB)=-8.3101
# [90/500] train loss=0.083755, nmse(dB)=-5.6322 | val loss=0.037906, nmse(dB)=-8.4150 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@90: val loss=0.037906, val nmse(dB)=-8.4150
# [91/500] train loss=0.082533, nmse(dB)=-5.6394 | val loss=0.037006, nmse(dB)=-8.5238 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@91: val loss=0.037006, val nmse(dB)=-8.5238
# [92/500] train loss=0.079752, nmse(dB)=-5.7354 | val loss=0.036110, nmse(dB)=-8.6352 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@92: val loss=0.036110, val nmse(dB)=-8.6352
# [93/500] train loss=0.078113, nmse(dB)=-5.8636 | val loss=0.035260, nmse(dB)=-8.7437 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@93: val loss=0.035260, val nmse(dB)=-8.7437
# [94/500] train loss=0.078870, nmse(dB)=-5.8118 | val loss=0.034436, nmse(dB)=-8.8516 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@94: val loss=0.034436, val nmse(dB)=-8.8516
# [95/500] train loss=0.076768, nmse(dB)=-5.9746 | val loss=0.033664, nmse(dB)=-8.9553 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@95: val loss=0.033664, val nmse(dB)=-8.9553
# [96/500] train loss=0.076420, nmse(dB)=-5.9973 | val loss=0.032949, nmse(dB)=-9.0537 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@96: val loss=0.032949, val nmse(dB)=-9.0537
# [97/500] train loss=0.075789, nmse(dB)=-5.9942 | val loss=0.032233, nmse(dB)=-9.1546 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@97: val loss=0.032233, val nmse(dB)=-9.1546
# [98/500] train loss=0.076930, nmse(dB)=-5.9906 | val loss=0.031494, nmse(dB)=-9.2610 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@98: val loss=0.031494, val nmse(dB)=-9.2610
# [99/500] train loss=0.072814, nmse(dB)=-6.1471 | val loss=0.030787, nmse(dB)=-9.3657 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@99: val loss=0.030787, val nmse(dB)=-9.3657
# [100/500] train loss=0.073266, nmse(dB)=-6.1437 | val loss=0.030126, nmse(dB)=-9.4661 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@100: val loss=0.030126, val nmse(dB)=-9.4661
# [101/500] train loss=0.073398, nmse(dB)=-6.2377 | val loss=0.029508, nmse(dB)=-9.5625 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@101: val loss=0.029508, val nmse(dB)=-9.5625
# [102/500] train loss=0.072265, nmse(dB)=-6.2025 | val loss=0.028873, nmse(dB)=-9.6638 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@102: val loss=0.028873, val nmse(dB)=-9.6638
# [103/500] train loss=0.072656, nmse(dB)=-6.2798 | val loss=0.028267, nmse(dB)=-9.7628 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@103: val loss=0.028267, val nmse(dB)=-9.7628
# [104/500] train loss=0.070635, nmse(dB)=-6.3974 | val loss=0.027739, nmse(dB)=-9.8511 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@104: val loss=0.027739, val nmse(dB)=-9.8511
# [105/500] train loss=0.071895, nmse(dB)=-6.3394 | val loss=0.027212, nmse(dB)=-9.9416 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@105: val loss=0.027212, val nmse(dB)=-9.9416
# [106/500] train loss=0.069978, nmse(dB)=-6.3586 | val loss=0.026665, nmse(dB)=-10.0377 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@106: val loss=0.026665, val nmse(dB)=-10.0377
# [107/500] train loss=0.070030, nmse(dB)=-6.4391 | val loss=0.026148, nmse(dB)=-10.1306 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@107: val loss=0.026148, val nmse(dB)=-10.1306
# [108/500] train loss=0.070573, nmse(dB)=-6.3848 | val loss=0.025652, nmse(dB)=-10.2221 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@108: val loss=0.025652, val nmse(dB)=-10.2221
# [109/500] train loss=0.069719, nmse(dB)=-6.4858 | val loss=0.025163, nmse(dB)=-10.3139 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@109: val loss=0.025163, val nmse(dB)=-10.3139
# [110/500] train loss=0.068166, nmse(dB)=-6.5537 | val loss=0.024710, nmse(dB)=-10.4007 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@110: val loss=0.024710, val nmse(dB)=-10.4007
# [111/500] train loss=0.068483, nmse(dB)=-6.4952 | val loss=0.024269, nmse(dB)=-10.4871 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@111: val loss=0.024269, val nmse(dB)=-10.4871
# [112/500] train loss=0.066101, nmse(dB)=-6.6577 | val loss=0.023822, nmse(dB)=-10.5763 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@112: val loss=0.023822, val nmse(dB)=-10.5763
# [113/500] train loss=0.067418, nmse(dB)=-6.6025 | val loss=0.023443, nmse(dB)=-10.6538 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@113: val loss=0.023443, val nmse(dB)=-10.6538
# [114/500] train loss=0.064581, nmse(dB)=-6.7340 | val loss=0.023047, nmse(dB)=-10.7367 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@114: val loss=0.023047, val nmse(dB)=-10.7367
# [115/500] train loss=0.064624, nmse(dB)=-6.7541 | val loss=0.022630, nmse(dB)=-10.8261 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@115: val loss=0.022630, val nmse(dB)=-10.8261
# [116/500] train loss=0.065514, nmse(dB)=-6.7615 | val loss=0.022224, nmse(dB)=-10.9149 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@116: val loss=0.022224, val nmse(dB)=-10.9149
# [117/500] train loss=0.063167, nmse(dB)=-6.8751 | val loss=0.021868, nmse(dB)=-10.9949 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@117: val loss=0.021868, val nmse(dB)=-10.9949
# [118/500] train loss=0.064939, nmse(dB)=-6.7972 | val loss=0.021539, nmse(dB)=-11.0703 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@118: val loss=0.021539, val nmse(dB)=-11.0703
# [119/500] train loss=0.065169, nmse(dB)=-6.8037 | val loss=0.021200, nmse(dB)=-11.1494 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@119: val loss=0.021200, val nmse(dB)=-11.1494
# [120/500] train loss=0.063689, nmse(dB)=-6.8890 | val loss=0.020873, nmse(dB)=-11.2268 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@120: val loss=0.020873, val nmse(dB)=-11.2268
# [121/500] train loss=0.064093, nmse(dB)=-6.7889 | val loss=0.020552, nmse(dB)=-11.3040 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@121: val loss=0.020552, val nmse(dB)=-11.3040
# [122/500] train loss=0.062909, nmse(dB)=-6.9006 | val loss=0.020240, nmse(dB)=-11.3803 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@122: val loss=0.020240, val nmse(dB)=-11.3803
# [123/500] train loss=0.063938, nmse(dB)=-6.9019 | val loss=0.019981, nmse(dB)=-11.4448 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@123: val loss=0.019981, val nmse(dB)=-11.4448
# [124/500] train loss=0.062662, nmse(dB)=-6.9289 | val loss=0.019693, nmse(dB)=-11.5188 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@124: val loss=0.019693, val nmse(dB)=-11.5188
# [125/500] train loss=0.061490, nmse(dB)=-7.0188 | val loss=0.019394, nmse(dB)=-11.5974 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@125: val loss=0.019394, val nmse(dB)=-11.5974
# [126/500] train loss=0.060742, nmse(dB)=-7.0993 | val loss=0.019120, nmse(dB)=-11.6708 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@126: val loss=0.019120, val nmse(dB)=-11.6708
# [127/500] train loss=0.063182, nmse(dB)=-6.9676 | val loss=0.018897, nmse(dB)=-11.7317 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@127: val loss=0.018897, val nmse(dB)=-11.7317
# [128/500] train loss=0.060724, nmse(dB)=-7.1041 | val loss=0.018644, nmse(dB)=-11.8015 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@128: val loss=0.018644, val nmse(dB)=-11.8015
# [129/500] train loss=0.061674, nmse(dB)=-7.0590 | val loss=0.018399, nmse(dB)=-11.8704 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@129: val loss=0.018399, val nmse(dB)=-11.8704
# [130/500] train loss=0.060271, nmse(dB)=-7.1134 | val loss=0.018172, nmse(dB)=-11.9355 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@130: val loss=0.018172, val nmse(dB)=-11.9355
# [131/500] train loss=0.058858, nmse(dB)=-7.2334 | val loss=0.017961, nmse(dB)=-11.9970 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@131: val loss=0.017961, val nmse(dB)=-11.9970
# [132/500] train loss=0.060676, nmse(dB)=-7.0986 | val loss=0.017731, nmse(dB)=-12.0655 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@132: val loss=0.017731, val nmse(dB)=-12.0655
# [133/500] train loss=0.058455, nmse(dB)=-7.2359 | val loss=0.017519, nmse(dB)=-12.1304 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@133: val loss=0.017519, val nmse(dB)=-12.1304
# [134/500] train loss=0.057644, nmse(dB)=-7.2899 | val loss=0.017337, nmse(dB)=-12.1873 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@134: val loss=0.017337, val nmse(dB)=-12.1873
# [135/500] train loss=0.060388, nmse(dB)=-7.2007 | val loss=0.017165, nmse(dB)=-12.2419 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@135: val loss=0.017165, val nmse(dB)=-12.2419
# [136/500] train loss=0.060646, nmse(dB)=-7.1729 | val loss=0.016976, nmse(dB)=-12.3023 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@136: val loss=0.016976, val nmse(dB)=-12.3023
# [137/500] train loss=0.059410, nmse(dB)=-7.2272 | val loss=0.016811, nmse(dB)=-12.3562 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@137: val loss=0.016811, val nmse(dB)=-12.3562
# [138/500] train loss=0.060684, nmse(dB)=-7.1801 | val loss=0.016616, nmse(dB)=-12.4200 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@138: val loss=0.016616, val nmse(dB)=-12.4200
# [139/500] train loss=0.060154, nmse(dB)=-7.1654 | val loss=0.016425, nmse(dB)=-12.4835 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@139: val loss=0.016425, val nmse(dB)=-12.4835
# [140/500] train loss=0.059534, nmse(dB)=-7.2024 | val loss=0.016246, nmse(dB)=-12.5439 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@140: val loss=0.016246, val nmse(dB)=-12.5439
# [141/500] train loss=0.058498, nmse(dB)=-7.3149 | val loss=0.016105, nmse(dB)=-12.5916 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@141: val loss=0.016105, val nmse(dB)=-12.5916
# [142/500] train loss=0.056508, nmse(dB)=-7.4205 | val loss=0.015966, nmse(dB)=-12.6394 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@142: val loss=0.015966, val nmse(dB)=-12.6394
# [143/500] train loss=0.057291, nmse(dB)=-7.3803 | val loss=0.015832, nmse(dB)=-12.6860 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@143: val loss=0.015832, val nmse(dB)=-12.6860
# [144/500] train loss=0.058249, nmse(dB)=-7.3578 | val loss=0.015680, nmse(dB)=-12.7403 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@144: val loss=0.015680, val nmse(dB)=-12.7403
# [145/500] train loss=0.059232, nmse(dB)=-7.3461 | val loss=0.015531, nmse(dB)=-12.7952 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@145: val loss=0.015531, val nmse(dB)=-12.7952
# [146/500] train loss=0.056543, nmse(dB)=-7.5019 | val loss=0.015412, nmse(dB)=-12.8402 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@146: val loss=0.015412, val nmse(dB)=-12.8402
# [147/500] train loss=0.057290, nmse(dB)=-7.3656 | val loss=0.015253, nmse(dB)=-12.8996 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@147: val loss=0.015253, val nmse(dB)=-12.8996
# [148/500] train loss=0.058242, nmse(dB)=-7.3778 | val loss=0.015067, nmse(dB)=-12.9714 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@148: val loss=0.015067, val nmse(dB)=-12.9714
# [149/500] train loss=0.057832, nmse(dB)=-7.3482 | val loss=0.014944, nmse(dB)=-13.0205 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@149: val loss=0.014944, val nmse(dB)=-13.0205
# [150/500] train loss=0.057968, nmse(dB)=-7.3332 | val loss=0.014832, nmse(dB)=-13.0654 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@150: val loss=0.014832, val nmse(dB)=-13.0654
# [151/500] train loss=0.058097, nmse(dB)=-7.4184 | val loss=0.014718, nmse(dB)=-13.1116 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@151: val loss=0.014718, val nmse(dB)=-13.1116
# [152/500] train loss=0.055850, nmse(dB)=-7.4920 | val loss=0.014609, nmse(dB)=-13.1567 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@152: val loss=0.014609, val nmse(dB)=-13.1567
# [153/500] train loss=0.057439, nmse(dB)=-7.3789 | val loss=0.014511, nmse(dB)=-13.1979 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@153: val loss=0.014511, val nmse(dB)=-13.1979
# [154/500] train loss=0.056685, nmse(dB)=-7.4884 | val loss=0.014397, nmse(dB)=-13.2451 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@154: val loss=0.014397, val nmse(dB)=-13.2451
# [155/500] train loss=0.056708, nmse(dB)=-7.5294 | val loss=0.014296, nmse(dB)=-13.2865 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@155: val loss=0.014296, val nmse(dB)=-13.2865
# [156/500] train loss=0.056899, nmse(dB)=-7.4709 | val loss=0.014190, nmse(dB)=-13.3305 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@156: val loss=0.014190, val nmse(dB)=-13.3305
# [157/500] train loss=0.057160, nmse(dB)=-7.4135 | val loss=0.014080, nmse(dB)=-13.3774 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@157: val loss=0.014080, val nmse(dB)=-13.3774
# [158/500] train loss=0.057191, nmse(dB)=-7.4959 | val loss=0.014005, nmse(dB)=-13.4110 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@158: val loss=0.014005, val nmse(dB)=-13.4110
# [159/500] train loss=0.058582, nmse(dB)=-7.3719 | val loss=0.013944, nmse(dB)=-13.4384 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@159: val loss=0.013944, val nmse(dB)=-13.4384
# [160/500] train loss=0.056848, nmse(dB)=-7.4964 | val loss=0.013864, nmse(dB)=-13.4730 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@160: val loss=0.013864, val nmse(dB)=-13.4730
# [161/500] train loss=0.057125, nmse(dB)=-7.4537 | val loss=0.013766, nmse(dB)=-13.5155 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@161: val loss=0.013766, val nmse(dB)=-13.5155
# [162/500] train loss=0.055403, nmse(dB)=-7.6098 | val loss=0.013685, nmse(dB)=-13.5521 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@162: val loss=0.013685, val nmse(dB)=-13.5521
# [163/500] train loss=0.056662, nmse(dB)=-7.5205 | val loss=0.013609, nmse(dB)=-13.5881 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@163: val loss=0.013609, val nmse(dB)=-13.5881
# [164/500] train loss=0.056937, nmse(dB)=-7.5069 | val loss=0.013545, nmse(dB)=-13.6207 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@164: val loss=0.013545, val nmse(dB)=-13.6207
# [165/500] train loss=0.057013, nmse(dB)=-7.4401 | val loss=0.013521, nmse(dB)=-13.6343 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@165: val loss=0.013521, val nmse(dB)=-13.6343
# [166/500] train loss=0.056610, nmse(dB)=-7.5080 | val loss=0.013481, nmse(dB)=-13.6552 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@166: val loss=0.013481, val nmse(dB)=-13.6552
# [167/500] train loss=0.055444, nmse(dB)=-7.6102 | val loss=0.013399, nmse(dB)=-13.6961 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@167: val loss=0.013399, val nmse(dB)=-13.6961
# [168/500] train loss=0.058504, nmse(dB)=-7.3834 | val loss=0.013348, nmse(dB)=-13.7205 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@168: val loss=0.013348, val nmse(dB)=-13.7205
# [169/500] train loss=0.056773, nmse(dB)=-7.4925 | val loss=0.013261, nmse(dB)=-13.7616 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@169: val loss=0.013261, val nmse(dB)=-13.7616
# [170/500] train loss=0.055718, nmse(dB)=-7.6219 | val loss=0.013198, nmse(dB)=-13.7908 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@170: val loss=0.013198, val nmse(dB)=-13.7908
# [171/500] train loss=0.054281, nmse(dB)=-7.7241 | val loss=0.013156, nmse(dB)=-13.8098 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@171: val loss=0.013156, val nmse(dB)=-13.8098
# [172/500] train loss=0.054880, nmse(dB)=-7.6040 | val loss=0.013088, nmse(dB)=-13.8435 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@172: val loss=0.013088, val nmse(dB)=-13.8435
# [173/500] train loss=0.055451, nmse(dB)=-7.6097 | val loss=0.013005, nmse(dB)=-13.8863 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@173: val loss=0.013005, val nmse(dB)=-13.8863
# [174/500] train loss=0.055862, nmse(dB)=-7.6033 | val loss=0.012914, nmse(dB)=-13.9338 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@174: val loss=0.012914, val nmse(dB)=-13.9338
# [175/500] train loss=0.054904, nmse(dB)=-7.6355 | val loss=0.012857, nmse(dB)=-13.9643 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@175: val loss=0.012857, val nmse(dB)=-13.9643
# [176/500] train loss=0.053767, nmse(dB)=-7.7740 | val loss=0.012816, nmse(dB)=-13.9878 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@176: val loss=0.012816, val nmse(dB)=-13.9878
# [177/500] train loss=0.054314, nmse(dB)=-7.6960 | val loss=0.012776, nmse(dB)=-14.0100 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@177: val loss=0.012776, val nmse(dB)=-14.0100
# [178/500] train loss=0.055076, nmse(dB)=-7.6770 | val loss=0.012704, nmse(dB)=-14.0481 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@178: val loss=0.012704, val nmse(dB)=-14.0481
# [179/500] train loss=0.053513, nmse(dB)=-7.7897 | val loss=0.012674, nmse(dB)=-14.0633 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@179: val loss=0.012674, val nmse(dB)=-14.0633
# [180/500] train loss=0.056619, nmse(dB)=-7.5697 | val loss=0.012668, nmse(dB)=-14.0656 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@180: val loss=0.012668, val nmse(dB)=-14.0656
# [181/500] train loss=0.055151, nmse(dB)=-7.6500 | val loss=0.012604, nmse(dB)=-14.0993 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@181: val loss=0.012604, val nmse(dB)=-14.0993
# [182/500] train loss=0.052980, nmse(dB)=-7.7305 | val loss=0.012536, nmse(dB)=-14.1378 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@182: val loss=0.012536, val nmse(dB)=-14.1378
# [183/500] train loss=0.054830, nmse(dB)=-7.7148 | val loss=0.012513, nmse(dB)=-14.1537 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@183: val loss=0.012513, val nmse(dB)=-14.1537
# [184/500] train loss=0.055123, nmse(dB)=-7.6333 | val loss=0.012463, nmse(dB)=-14.1853 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@184: val loss=0.012463, val nmse(dB)=-14.1853
# [185/500] train loss=0.056236, nmse(dB)=-7.6155 | val loss=0.012379, nmse(dB)=-14.2360 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@185: val loss=0.012379, val nmse(dB)=-14.2360
# [186/500] train loss=0.051741, nmse(dB)=-7.8963 | val loss=0.012329, nmse(dB)=-14.2668 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@186: val loss=0.012329, val nmse(dB)=-14.2668
# [187/500] train loss=0.054118, nmse(dB)=-7.7525 | val loss=0.012285, nmse(dB)=-14.2914 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@187: val loss=0.012285, val nmse(dB)=-14.2914
# [188/500] train loss=0.053695, nmse(dB)=-7.7288 | val loss=0.012254, nmse(dB)=-14.3066 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@188: val loss=0.012254, val nmse(dB)=-14.3066
# [189/500] train loss=0.053833, nmse(dB)=-7.7073 | val loss=0.012241, nmse(dB)=-14.3125 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@189: val loss=0.012241, val nmse(dB)=-14.3125
# [190/500] train loss=0.053059, nmse(dB)=-7.8162 | val loss=0.012229, nmse(dB)=-14.3195 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@190: val loss=0.012229, val nmse(dB)=-14.3195
# [191/500] train loss=0.052563, nmse(dB)=-7.8975 | val loss=0.012206, nmse(dB)=-14.3333 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@191: val loss=0.012206, val nmse(dB)=-14.3333
# [192/500] train loss=0.054066, nmse(dB)=-7.7228 | val loss=0.012177, nmse(dB)=-14.3523 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@192: val loss=0.012177, val nmse(dB)=-14.3523
# [193/500] train loss=0.053813, nmse(dB)=-7.7773 | val loss=0.012137, nmse(dB)=-14.3767 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@193: val loss=0.012137, val nmse(dB)=-14.3767
# [194/500] train loss=0.054430, nmse(dB)=-7.7233 | val loss=0.012098, nmse(dB)=-14.3990 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@194: val loss=0.012098, val nmse(dB)=-14.3990
# [195/500] train loss=0.054261, nmse(dB)=-7.7263 | val loss=0.012064, nmse(dB)=-14.4177 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@195: val loss=0.012064, val nmse(dB)=-14.4177
# [196/500] train loss=0.054840, nmse(dB)=-7.6568 | val loss=0.012032, nmse(dB)=-14.4379 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@196: val loss=0.012032, val nmse(dB)=-14.4379
# [197/500] train loss=0.054586, nmse(dB)=-7.7307 | val loss=0.011999, nmse(dB)=-14.4600 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@197: val loss=0.011999, val nmse(dB)=-14.4600
# [198/500] train loss=0.052861, nmse(dB)=-7.8120 | val loss=0.011985, nmse(dB)=-14.4712 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@198: val loss=0.011985, val nmse(dB)=-14.4712
# [199/500] train loss=0.052819, nmse(dB)=-7.8280 | val loss=0.012004, nmse(dB)=-14.4596 | 0.1s
# [200/500] train loss=0.052946, nmse(dB)=-7.8515 | val loss=0.011982, nmse(dB)=-14.4708 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@200: val loss=0.011982, val nmse(dB)=-14.4708
# [201/500] train loss=0.052991, nmse(dB)=-7.8535 | val loss=0.011946, nmse(dB)=-14.4906 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@201: val loss=0.011946, val nmse(dB)=-14.4906
# [202/500] train loss=0.052487, nmse(dB)=-7.8649 | val loss=0.011923, nmse(dB)=-14.5041 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@202: val loss=0.011923, val nmse(dB)=-14.5041
# [203/500] train loss=0.054572, nmse(dB)=-7.7329 | val loss=0.011895, nmse(dB)=-14.5227 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@203: val loss=0.011895, val nmse(dB)=-14.5227
# [204/500] train loss=0.053607, nmse(dB)=-7.7976 | val loss=0.011895, nmse(dB)=-14.5262 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@204: val loss=0.011895, val nmse(dB)=-14.5262
# [205/500] train loss=0.052826, nmse(dB)=-7.8795 | val loss=0.011913, nmse(dB)=-14.5172 | 0.1s
# [206/500] train loss=0.053577, nmse(dB)=-7.8000 | val loss=0.011871, nmse(dB)=-14.5413 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@206: val loss=0.011871, val nmse(dB)=-14.5413
# [207/500] train loss=0.053357, nmse(dB)=-7.7913 | val loss=0.011834, nmse(dB)=-14.5604 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@207: val loss=0.011834, val nmse(dB)=-14.5604
# [208/500] train loss=0.055263, nmse(dB)=-7.6491 | val loss=0.011834, nmse(dB)=-14.5580 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@208: val loss=0.011834, val nmse(dB)=-14.5580
# [209/500] train loss=0.054027, nmse(dB)=-7.7833 | val loss=0.011828, nmse(dB)=-14.5624 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@209: val loss=0.011828, val nmse(dB)=-14.5624
# [210/500] train loss=0.053569, nmse(dB)=-7.7791 | val loss=0.011792, nmse(dB)=-14.5870 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@210: val loss=0.011792, val nmse(dB)=-14.5870
# [211/500] train loss=0.051024, nmse(dB)=-7.9670 | val loss=0.011772, nmse(dB)=-14.6029 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@211: val loss=0.011772, val nmse(dB)=-14.6029
# [212/500] train loss=0.053682, nmse(dB)=-7.7490 | val loss=0.011774, nmse(dB)=-14.6056 | 0.1s
# [213/500] train loss=0.053195, nmse(dB)=-7.8152 | val loss=0.011746, nmse(dB)=-14.6263 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@213: val loss=0.011746, val nmse(dB)=-14.6263
# [214/500] train loss=0.053380, nmse(dB)=-7.8437 | val loss=0.011701, nmse(dB)=-14.6542 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@214: val loss=0.011701, val nmse(dB)=-14.6542
# [215/500] train loss=0.053446, nmse(dB)=-7.7797 | val loss=0.011681, nmse(dB)=-14.6642 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@215: val loss=0.011681, val nmse(dB)=-14.6642
# [216/500] train loss=0.052203, nmse(dB)=-7.8746 | val loss=0.011676, nmse(dB)=-14.6663 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@216: val loss=0.011676, val nmse(dB)=-14.6663
# [217/500] train loss=0.052874, nmse(dB)=-7.8376 | val loss=0.011673, nmse(dB)=-14.6677 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@217: val loss=0.011673, val nmse(dB)=-14.6677
# [218/500] train loss=0.051442, nmse(dB)=-7.9649 | val loss=0.011649, nmse(dB)=-14.6845 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@218: val loss=0.011649, val nmse(dB)=-14.6845
# [219/500] train loss=0.053952, nmse(dB)=-7.7776 | val loss=0.011637, nmse(dB)=-14.6936 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@219: val loss=0.011637, val nmse(dB)=-14.6936
# [220/500] train loss=0.053780, nmse(dB)=-7.8184 | val loss=0.011635, nmse(dB)=-14.6967 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@220: val loss=0.011635, val nmse(dB)=-14.6967
# [221/500] train loss=0.054550, nmse(dB)=-7.7311 | val loss=0.011620, nmse(dB)=-14.7072 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@221: val loss=0.011620, val nmse(dB)=-14.7072
# [222/500] train loss=0.052400, nmse(dB)=-7.8650 | val loss=0.011605, nmse(dB)=-14.7176 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@222: val loss=0.011605, val nmse(dB)=-14.7176
# [223/500] train loss=0.053559, nmse(dB)=-7.8296 | val loss=0.011594, nmse(dB)=-14.7243 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@223: val loss=0.011594, val nmse(dB)=-14.7243
# [224/500] train loss=0.052818, nmse(dB)=-7.8406 | val loss=0.011582, nmse(dB)=-14.7314 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@224: val loss=0.011582, val nmse(dB)=-14.7314
# [225/500] train loss=0.053541, nmse(dB)=-7.8430 | val loss=0.011556, nmse(dB)=-14.7486 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@225: val loss=0.011556, val nmse(dB)=-14.7486
# [226/500] train loss=0.051098, nmse(dB)=-7.9718 | val loss=0.011520, nmse(dB)=-14.7753 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@226: val loss=0.011520, val nmse(dB)=-14.7753
# [227/500] train loss=0.051421, nmse(dB)=-7.9915 | val loss=0.011503, nmse(dB)=-14.7897 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@227: val loss=0.011503, val nmse(dB)=-14.7897
# [228/500] train loss=0.052711, nmse(dB)=-7.8118 | val loss=0.011512, nmse(dB)=-14.7864 | 0.1s
# [229/500] train loss=0.053725, nmse(dB)=-7.8085 | val loss=0.011519, nmse(dB)=-14.7833 | 0.1s
# [230/500] train loss=0.053846, nmse(dB)=-7.7654 | val loss=0.011492, nmse(dB)=-14.8028 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@230: val loss=0.011492, val nmse(dB)=-14.8028
# [231/500] train loss=0.051188, nmse(dB)=-8.0086 | val loss=0.011468, nmse(dB)=-14.8192 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@231: val loss=0.011468, val nmse(dB)=-14.8192
# [232/500] train loss=0.051907, nmse(dB)=-7.9682 | val loss=0.011466, nmse(dB)=-14.8184 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@232: val loss=0.011466, val nmse(dB)=-14.8184
# [233/500] train loss=0.051675, nmse(dB)=-7.8783 | val loss=0.011456, nmse(dB)=-14.8259 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@233: val loss=0.011456, val nmse(dB)=-14.8259
# [234/500] train loss=0.052808, nmse(dB)=-7.8555 | val loss=0.011443, nmse(dB)=-14.8362 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@234: val loss=0.011443, val nmse(dB)=-14.8362
# [235/500] train loss=0.052710, nmse(dB)=-7.8643 | val loss=0.011438, nmse(dB)=-14.8405 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@235: val loss=0.011438, val nmse(dB)=-14.8405
# [236/500] train loss=0.050549, nmse(dB)=-8.0196 | val loss=0.011458, nmse(dB)=-14.8257 | 0.1s
# [237/500] train loss=0.052401, nmse(dB)=-7.8750 | val loss=0.011466, nmse(dB)=-14.8195 | 0.1s
# [238/500] train loss=0.052913, nmse(dB)=-7.8887 | val loss=0.011446, nmse(dB)=-14.8323 | 0.1s
# [239/500] train loss=0.051508, nmse(dB)=-7.9716 | val loss=0.011417, nmse(dB)=-14.8510 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@239: val loss=0.011417, val nmse(dB)=-14.8510
# [240/500] train loss=0.050693, nmse(dB)=-7.9644 | val loss=0.011406, nmse(dB)=-14.8569 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@240: val loss=0.011406, val nmse(dB)=-14.8569
# [241/500] train loss=0.051692, nmse(dB)=-7.9554 | val loss=0.011407, nmse(dB)=-14.8561 | 0.1s
# [242/500] train loss=0.053507, nmse(dB)=-7.7993 | val loss=0.011404, nmse(dB)=-14.8605 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@242: val loss=0.011404, val nmse(dB)=-14.8605
# [243/500] train loss=0.053985, nmse(dB)=-7.7873 | val loss=0.011403, nmse(dB)=-14.8633 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@243: val loss=0.011403, val nmse(dB)=-14.8633
# [244/500] train loss=0.052143, nmse(dB)=-7.8794 | val loss=0.011387, nmse(dB)=-14.8749 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@244: val loss=0.011387, val nmse(dB)=-14.8749
# [245/500] train loss=0.052422, nmse(dB)=-7.8830 | val loss=0.011351, nmse(dB)=-14.9010 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@245: val loss=0.011351, val nmse(dB)=-14.9010
# [246/500] train loss=0.054134, nmse(dB)=-7.7715 | val loss=0.011335, nmse(dB)=-14.9130 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@246: val loss=0.011335, val nmse(dB)=-14.9130
# [247/500] train loss=0.052418, nmse(dB)=-7.8929 | val loss=0.011336, nmse(dB)=-14.9125 | 0.1s
# [248/500] train loss=0.051692, nmse(dB)=-7.9804 | val loss=0.011345, nmse(dB)=-14.9073 | 0.1s
# [249/500] train loss=0.051685, nmse(dB)=-7.9415 | val loss=0.011348, nmse(dB)=-14.9083 | 0.1s
# [250/500] train loss=0.052658, nmse(dB)=-7.8369 | val loss=0.011344, nmse(dB)=-14.9134 | 0.1s
# [251/500] train loss=0.052048, nmse(dB)=-7.9148 | val loss=0.011325, nmse(dB)=-14.9274 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@251: val loss=0.011325, val nmse(dB)=-14.9274
# [252/500] train loss=0.052287, nmse(dB)=-7.8715 | val loss=0.011312, nmse(dB)=-14.9366 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@252: val loss=0.011312, val nmse(dB)=-14.9366
# [253/500] train loss=0.054346, nmse(dB)=-7.7724 | val loss=0.011294, nmse(dB)=-14.9487 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@253: val loss=0.011294, val nmse(dB)=-14.9487
# [254/500] train loss=0.051336, nmse(dB)=-8.0264 | val loss=0.011294, nmse(dB)=-14.9470 | 0.1s
# [255/500] train loss=0.053539, nmse(dB)=-7.7716 | val loss=0.011294, nmse(dB)=-14.9460 | 0.1s
# [256/500] train loss=0.053554, nmse(dB)=-7.7844 | val loss=0.011286, nmse(dB)=-14.9522 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@256: val loss=0.011286, val nmse(dB)=-14.9522
# [257/500] train loss=0.052787, nmse(dB)=-7.9076 | val loss=0.011290, nmse(dB)=-14.9500 | 0.1s
# [258/500] train loss=0.053834, nmse(dB)=-7.7937 | val loss=0.011288, nmse(dB)=-14.9502 | 0.1s
# [259/500] train loss=0.052489, nmse(dB)=-7.8901 | val loss=0.011279, nmse(dB)=-14.9550 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@259: val loss=0.011279, val nmse(dB)=-14.9550
# [260/500] train loss=0.053463, nmse(dB)=-7.8732 | val loss=0.011257, nmse(dB)=-14.9686 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@260: val loss=0.011257, val nmse(dB)=-14.9686
# [261/500] train loss=0.053068, nmse(dB)=-7.8556 | val loss=0.011241, nmse(dB)=-14.9780 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@261: val loss=0.011241, val nmse(dB)=-14.9780
# [262/500] train loss=0.050954, nmse(dB)=-7.9835 | val loss=0.011244, nmse(dB)=-14.9760 | 0.1s
# [263/500] train loss=0.051762, nmse(dB)=-7.8719 | val loss=0.011258, nmse(dB)=-14.9675 | 0.1s
# [264/500] train loss=0.051718, nmse(dB)=-7.9037 | val loss=0.011259, nmse(dB)=-14.9693 | 0.1s
# [265/500] train loss=0.052860, nmse(dB)=-7.8758 | val loss=0.011257, nmse(dB)=-14.9735 | 0.1s
# [266/500] train loss=0.052928, nmse(dB)=-7.8789 | val loss=0.011248, nmse(dB)=-14.9828 | 0.1s
# [267/500] train loss=0.050983, nmse(dB)=-8.0681 | val loss=0.011248, nmse(dB)=-14.9840 | 0.1s
# [268/500] train loss=0.053118, nmse(dB)=-7.8668 | val loss=0.011245, nmse(dB)=-14.9871 | 0.1s
# [269/500] train loss=0.052352, nmse(dB)=-7.8779 | val loss=0.011244, nmse(dB)=-14.9877 | 0.1s
# [270/500] train loss=0.052696, nmse(dB)=-7.8931 | val loss=0.011236, nmse(dB)=-14.9910 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@270: val loss=0.011236, val nmse(dB)=-14.9910
# ...
# [341/500] train loss=0.052358, nmse(dB)=-7.8414 | val loss=0.011081, nmse(dB)=-15.1161 | 0.1s
# [342/500] train loss=0.050059, nmse(dB)=-8.0830 | val loss=0.011081, nmse(dB)=-15.1151 | 0.1s
# [343/500] train loss=0.051591, nmse(dB)=-8.0065 | val loss=0.011081, nmse(dB)=-15.1159 | 0.1s
# [344/500] train loss=0.051579, nmse(dB)=-8.0131 | val loss=0.011086, nmse(dB)=-15.1120 | 0.1s
# [345/500] train loss=0.050686, nmse(dB)=-8.0922 | val loss=0.011091, nmse(dB)=-15.1087 | 0.1s
# [346/500] train loss=0.051579, nmse(dB)=-8.0015 | val loss=0.011099, nmse(dB)=-15.1028 | 0.1s
# [347/500] train loss=0.049682, nmse(dB)=-8.0969 | val loss=0.011106, nmse(dB)=-15.0975 | 0.1s
# [348/500] train loss=0.050942, nmse(dB)=-8.0283 | val loss=0.011101, nmse(dB)=-15.1014 | 0.1s
# [349/500] train loss=0.052932, nmse(dB)=-7.8750 | val loss=0.011094, nmse(dB)=-15.1070 | 0.1s
# [350/500] train loss=0.051209, nmse(dB)=-7.9699 | val loss=0.011086, nmse(dB)=-15.1141 | 0.1s
# [351/500] train loss=0.049062, nmse(dB)=-8.2117 | val loss=0.011078, nmse(dB)=-15.1206 | 0.1s
# [352/500] train loss=0.053270, nmse(dB)=-7.8598 | val loss=0.011075, nmse(dB)=-15.1221 | 0.1s
# [353/500] train loss=0.053227, nmse(dB)=-7.9301 | val loss=0.011081, nmse(dB)=-15.1175 | 0.1s
# [354/500] train loss=0.052036, nmse(dB)=-7.9675 | val loss=0.011089, nmse(dB)=-15.1103 | 0.1s
# [355/500] train loss=0.051632, nmse(dB)=-7.9761 | val loss=0.011093, nmse(dB)=-15.1058 | 0.1s
# [356/500] train loss=0.050358, nmse(dB)=-8.1109 | val loss=0.011099, nmse(dB)=-15.1009 | 0.1s
# [357/500] train loss=0.051344, nmse(dB)=-8.0096 | val loss=0.011102, nmse(dB)=-15.0985 | 0.1s
# [358/500] train loss=0.050177, nmse(dB)=-8.1026 | val loss=0.011098, nmse(dB)=-15.1012 | 0.1s
# [359/500] train loss=0.052730, nmse(dB)=-7.9004 | val loss=0.011089, nmse(dB)=-15.1081 | 0.1s
# [360/500] train loss=0.050921, nmse(dB)=-8.0042 | val loss=0.011080, nmse(dB)=-15.1144 | 0.1s
# [361/500] train loss=0.051448, nmse(dB)=-8.0056 | val loss=0.011074, nmse(dB)=-15.1193 | 0.1s
# [362/500] train loss=0.051271, nmse(dB)=-8.0556 | val loss=0.011071, nmse(dB)=-15.1217 | 0.1s
# [363/500] train loss=0.052341, nmse(dB)=-7.9504 | val loss=0.011070, nmse(dB)=-15.1225 | 0.1s
# [364/500] train loss=0.051962, nmse(dB)=-7.9684 | val loss=0.011067, nmse(dB)=-15.1253 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@364: val loss=0.011067, val nmse(dB)=-15.1253
# [365/500] train loss=0.050736, nmse(dB)=-8.0999 | val loss=0.011066, nmse(dB)=-15.1263 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@365: val loss=0.011066, val nmse(dB)=-15.1263
# [366/500] train loss=0.050377, nmse(dB)=-8.0383 | val loss=0.011068, nmse(dB)=-15.1257 | 0.1s
# [367/500] train loss=0.051136, nmse(dB)=-8.0557 | val loss=0.011065, nmse(dB)=-15.1278 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@367: val loss=0.011065, val nmse(dB)=-15.1278
# [368/500] train loss=0.050320, nmse(dB)=-8.1415 | val loss=0.011057, nmse(dB)=-15.1331 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@368: val loss=0.011057, val nmse(dB)=-15.1331
# [369/500] train loss=0.053592, nmse(dB)=-7.8875 | val loss=0.011049, nmse(dB)=-15.1391 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@369: val loss=0.011049, val nmse(dB)=-15.1391
# [370/500] train loss=0.052891, nmse(dB)=-7.9238 | val loss=0.011044, nmse(dB)=-15.1426 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@370: val loss=0.011044, val nmse(dB)=-15.1426
# [371/500] train loss=0.051923, nmse(dB)=-8.0329 | val loss=0.011040, nmse(dB)=-15.1453 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@371: val loss=0.011040, val nmse(dB)=-15.1453
# [372/500] train loss=0.051057, nmse(dB)=-8.0309 | val loss=0.011036, nmse(dB)=-15.1491 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@372: val loss=0.011036, val nmse(dB)=-15.1491
# [373/500] train loss=0.050835, nmse(dB)=-8.1166 | val loss=0.011038, nmse(dB)=-15.1487 | 0.1s
# [374/500] train loss=0.050714, nmse(dB)=-8.0433 | val loss=0.011042, nmse(dB)=-15.1469 | 0.1s
# [375/500] train loss=0.049594, nmse(dB)=-8.1298 | val loss=0.011045, nmse(dB)=-15.1452 | 0.1s
# [376/500] train loss=0.051346, nmse(dB)=-7.9642 | val loss=0.011047, nmse(dB)=-15.1455 | 0.1s
# [377/500] train loss=0.053597, nmse(dB)=-7.9065 | val loss=0.011051, nmse(dB)=-15.1433 | 0.1s
# [378/500] train loss=0.052410, nmse(dB)=-7.9723 | val loss=0.011057, nmse(dB)=-15.1392 | 0.1s
# [379/500] train loss=0.050822, nmse(dB)=-8.0747 | val loss=0.011062, nmse(dB)=-15.1351 | 0.1s
# [380/500] train loss=0.051875, nmse(dB)=-7.9793 | val loss=0.011065, nmse(dB)=-15.1333 | 0.1s
# [381/500] train loss=0.051380, nmse(dB)=-8.0063 | val loss=0.011065, nmse(dB)=-15.1327 | 0.1s
# [382/500] train loss=0.050347, nmse(dB)=-8.0804 | val loss=0.011065, nmse(dB)=-15.1320 | 0.1s
# [383/500] train loss=0.051863, nmse(dB)=-7.9290 | val loss=0.011066, nmse(dB)=-15.1305 | 0.1s
# [384/500] train loss=0.051737, nmse(dB)=-7.9594 | val loss=0.011067, nmse(dB)=-15.1290 | 0.1s
# [385/500] train loss=0.052513, nmse(dB)=-7.9570 | val loss=0.011068, nmse(dB)=-15.1280 | 0.1s
# [386/500] train loss=0.052240, nmse(dB)=-7.9157 | val loss=0.011068, nmse(dB)=-15.1273 | 0.1s
# [387/500] train loss=0.049745, nmse(dB)=-8.1312 | val loss=0.011070, nmse(dB)=-15.1255 | 0.1s
# [388/500] train loss=0.051605, nmse(dB)=-7.9929 | val loss=0.011072, nmse(dB)=-15.1232 | 0.1s
# [389/500] train loss=0.051127, nmse(dB)=-8.0324 | val loss=0.011076, nmse(dB)=-15.1192 | 0.1s
# [390/500] train loss=0.052453, nmse(dB)=-7.9655 | val loss=0.011079, nmse(dB)=-15.1166 | 0.1s
# [391/500] train loss=0.052194, nmse(dB)=-7.9580 | val loss=0.011080, nmse(dB)=-15.1155 | 0.1s
# [392/500] train loss=0.051839, nmse(dB)=-7.9767 | val loss=0.011077, nmse(dB)=-15.1181 | 0.1s
# [393/500] train loss=0.051420, nmse(dB)=-7.9658 | val loss=0.011073, nmse(dB)=-15.1212 | 0.1s
# [394/500] train loss=0.052445, nmse(dB)=-7.9229 | val loss=0.011068, nmse(dB)=-15.1253 | 0.1s
# [395/500] train loss=0.051815, nmse(dB)=-7.9563 | val loss=0.011063, nmse(dB)=-15.1295 | 0.1s
# [396/500] train loss=0.050830, nmse(dB)=-8.0444 | val loss=0.011058, nmse(dB)=-15.1337 | 0.1s
# [397/500] train loss=0.051598, nmse(dB)=-7.9614 | val loss=0.011054, nmse(dB)=-15.1366 | 0.1s
# [398/500] train loss=0.052559, nmse(dB)=-7.9584 | val loss=0.011052, nmse(dB)=-15.1381 | 0.1s
# [399/500] train loss=0.050273, nmse(dB)=-8.1102 | val loss=0.011052, nmse(dB)=-15.1382 | 0.1s
# [400/500] train loss=0.050690, nmse(dB)=-8.1024 | val loss=0.011049, nmse(dB)=-15.1402 | 0.1s
# [401/500] train loss=0.051764, nmse(dB)=-7.9752 | val loss=0.011047, nmse(dB)=-15.1425 | 0.1s
# [402/500] train loss=0.051473, nmse(dB)=-8.0197 | val loss=0.011046, nmse(dB)=-15.1435 | 0.1s
# [403/500] train loss=0.049048, nmse(dB)=-8.2390 | val loss=0.011047, nmse(dB)=-15.1432 | 0.1s
# [404/500] train loss=0.050545, nmse(dB)=-8.0386 | val loss=0.011047, nmse(dB)=-15.1437 | 0.1s
# [405/500] train loss=0.051410, nmse(dB)=-8.0330 | val loss=0.011046, nmse(dB)=-15.1458 | 0.1s
# [406/500] train loss=0.052044, nmse(dB)=-7.9487 | val loss=0.011045, nmse(dB)=-15.1472 | 0.1s
# [407/500] train loss=0.051096, nmse(dB)=-8.0446 | val loss=0.011044, nmse(dB)=-15.1483 | 0.1s
# [408/500] train loss=0.052220, nmse(dB)=-7.9105 | val loss=0.011046, nmse(dB)=-15.1481 | 0.1s
# [409/500] train loss=0.051624, nmse(dB)=-7.9583 | val loss=0.011047, nmse(dB)=-15.1475 | 0.1s
# [410/500] train loss=0.051666, nmse(dB)=-8.0576 | val loss=0.011048, nmse(dB)=-15.1464 | 0.1s
# [411/500] train loss=0.051634, nmse(dB)=-7.9963 | val loss=0.011048, nmse(dB)=-15.1462 | 0.1s
# [412/500] train loss=0.050885, nmse(dB)=-8.0279 | val loss=0.011049, nmse(dB)=-15.1457 | 0.1s
# [413/500] train loss=0.052902, nmse(dB)=-7.9824 | val loss=0.011049, nmse(dB)=-15.1460 | 0.1s
# [414/500] train loss=0.050178, nmse(dB)=-8.1070 | val loss=0.011046, nmse(dB)=-15.1478 | 0.1s
# [415/500] train loss=0.053204, nmse(dB)=-7.8637 | val loss=0.011044, nmse(dB)=-15.1492 | 0.1s
# [416/500] train loss=0.050198, nmse(dB)=-8.0964 | val loss=0.011043, nmse(dB)=-15.1493 | 0.1s
# [417/500] train loss=0.050790, nmse(dB)=-8.0342 | val loss=0.011043, nmse(dB)=-15.1491 | 0.1s
# [418/500] train loss=0.051032, nmse(dB)=-7.9913 | val loss=0.011042, nmse(dB)=-15.1495 | 0.1s
# [419/500] train loss=0.052179, nmse(dB)=-7.9346 | val loss=0.011040, nmse(dB)=-15.1501 | 0.1s
# [420/500] train loss=0.050791, nmse(dB)=-8.0409 | val loss=0.011039, nmse(dB)=-15.1505 | 0.1s
# [421/500] train loss=0.053395, nmse(dB)=-7.9088 | val loss=0.011040, nmse(dB)=-15.1499 | 0.1s
# [422/500] train loss=0.051148, nmse(dB)=-8.0462 | val loss=0.011040, nmse(dB)=-15.1494 | 0.1s
# [423/500] train loss=0.052557, nmse(dB)=-7.8881 | val loss=0.011041, nmse(dB)=-15.1490 | 0.1s
# [424/500] train loss=0.050846, nmse(dB)=-8.0412 | val loss=0.011042, nmse(dB)=-15.1481 | 0.1s
# [425/500] train loss=0.051801, nmse(dB)=-8.0305 | val loss=0.011043, nmse(dB)=-15.1469 | 0.1s
# [426/500] train loss=0.051438, nmse(dB)=-8.0633 | val loss=0.011043, nmse(dB)=-15.1465 | 0.1s
# [427/500] train loss=0.049545, nmse(dB)=-8.1490 | val loss=0.011043, nmse(dB)=-15.1464 | 0.1s
# [428/500] train loss=0.052077, nmse(dB)=-7.9002 | val loss=0.011042, nmse(dB)=-15.1465 | 0.1s
# [429/500] train loss=0.051539, nmse(dB)=-8.0154 | val loss=0.011043, nmse(dB)=-15.1460 | 0.1s
# [430/500] train loss=0.051986, nmse(dB)=-7.9348 | val loss=0.011043, nmse(dB)=-15.1454 | 0.1s
# [431/500] train loss=0.052520, nmse(dB)=-7.9363 | val loss=0.011043, nmse(dB)=-15.1457 | 0.1s
# [432/500] train loss=0.051884, nmse(dB)=-7.9694 | val loss=0.011043, nmse(dB)=-15.1456 | 0.1s
# [433/500] train loss=0.049865, nmse(dB)=-8.1375 | val loss=0.011044, nmse(dB)=-15.1454 | 0.1s
# [434/500] train loss=0.049980, nmse(dB)=-8.1448 | val loss=0.011045, nmse(dB)=-15.1445 | 0.1s
# [435/500] train loss=0.052126, nmse(dB)=-7.9794 | val loss=0.011046, nmse(dB)=-15.1438 | 0.1s
# [436/500] train loss=0.050061, nmse(dB)=-8.1190 | val loss=0.011047, nmse(dB)=-15.1431 | 0.1s
# [437/500] train loss=0.050557, nmse(dB)=-8.0810 | val loss=0.011048, nmse(dB)=-15.1422 | 0.1s
# [438/500] train loss=0.048424, nmse(dB)=-8.2166 | val loss=0.011049, nmse(dB)=-15.1414 | 0.1s
# [439/500] train loss=0.051448, nmse(dB)=-8.0082 | val loss=0.011049, nmse(dB)=-15.1413 | 0.1s
# [440/500] train loss=0.049791, nmse(dB)=-8.1071 | val loss=0.011049, nmse(dB)=-15.1417 | 0.1s
# [441/500] train loss=0.051857, nmse(dB)=-8.0193 | val loss=0.011047, nmse(dB)=-15.1428 | 0.1s
# [442/500] train loss=0.052930, nmse(dB)=-7.9269 | val loss=0.011047, nmse(dB)=-15.1434 | 0.1s
# [443/500] train loss=0.051021, nmse(dB)=-8.0581 | val loss=0.011046, nmse(dB)=-15.1439 | 0.1s
# [444/500] train loss=0.051104, nmse(dB)=-7.9854 | val loss=0.011045, nmse(dB)=-15.1444 | 0.1s
# [445/500] train loss=0.050866, nmse(dB)=-8.0652 | val loss=0.011045, nmse(dB)=-15.1447 | 0.1s
# [446/500] train loss=0.051689, nmse(dB)=-7.9383 | val loss=0.011045, nmse(dB)=-15.1453 | 0.1s
# [447/500] train loss=0.049924, nmse(dB)=-8.1112 | val loss=0.011044, nmse(dB)=-15.1460 | 0.1s
# [448/500] train loss=0.052506, nmse(dB)=-7.9075 | val loss=0.011043, nmse(dB)=-15.1469 | 0.1s
# [449/500] train loss=0.050647, nmse(dB)=-8.0629 | val loss=0.011042, nmse(dB)=-15.1476 | 0.1s
# [450/500] train loss=0.051110, nmse(dB)=-7.9865 | val loss=0.011041, nmse(dB)=-15.1482 | 0.1s
# [451/500] train loss=0.051832, nmse(dB)=-7.9692 | val loss=0.011041, nmse(dB)=-15.1486 | 0.1s
# [452/500] train loss=0.052156, nmse(dB)=-7.9535 | val loss=0.011040, nmse(dB)=-15.1492 | 0.1s
# [453/500] train loss=0.050854, nmse(dB)=-8.0155 | val loss=0.011040, nmse(dB)=-15.1492 | 0.1s
# [454/500] train loss=0.051840, nmse(dB)=-7.9822 | val loss=0.011040, nmse(dB)=-15.1493 | 0.1s
# [455/500] train loss=0.051695, nmse(dB)=-8.0534 | val loss=0.011040, nmse(dB)=-15.1495 | 0.1s
# [456/500] train loss=0.052234, nmse(dB)=-7.8460 | val loss=0.011040, nmse(dB)=-15.1498 | 0.1s
# [457/500] train loss=0.051209, nmse(dB)=-7.9769 | val loss=0.011040, nmse(dB)=-15.1498 | 0.1s
# [458/500] train loss=0.053497, nmse(dB)=-7.8428 | val loss=0.011041, nmse(dB)=-15.1495 | 0.1s
# [459/500] train loss=0.052161, nmse(dB)=-7.8877 | val loss=0.011041, nmse(dB)=-15.1493 | 0.1s
# [460/500] train loss=0.050941, nmse(dB)=-8.0168 | val loss=0.011041, nmse(dB)=-15.1494 | 0.1s
# [461/500] train loss=0.051897, nmse(dB)=-7.9631 | val loss=0.011041, nmse(dB)=-15.1495 | 0.1s
# [462/500] train loss=0.052153, nmse(dB)=-7.9314 | val loss=0.011041, nmse(dB)=-15.1494 | 0.1s
# [463/500] train loss=0.050845, nmse(dB)=-8.0902 | val loss=0.011041, nmse(dB)=-15.1493 | 0.1s
# [464/500] train loss=0.051745, nmse(dB)=-7.9710 | val loss=0.011041, nmse(dB)=-15.1492 | 0.1s
# [465/500] train loss=0.052486, nmse(dB)=-7.9357 | val loss=0.011041, nmse(dB)=-15.1493 | 0.1s
# [466/500] train loss=0.051881, nmse(dB)=-7.9921 | val loss=0.011041, nmse(dB)=-15.1494 | 0.1s
# [467/500] train loss=0.051894, nmse(dB)=-7.9598 | val loss=0.011041, nmse(dB)=-15.1494 | 0.1s
# [468/500] train loss=0.052898, nmse(dB)=-7.8786 | val loss=0.011041, nmse(dB)=-15.1494 | 0.1s
# [469/500] train loss=0.050204, nmse(dB)=-8.0541 | val loss=0.011041, nmse(dB)=-15.1493 | 0.1s
# [470/500] train loss=0.052492, nmse(dB)=-7.9393 | val loss=0.011041, nmse(dB)=-15.1493 | 0.1s
# [471/500] train loss=0.049769, nmse(dB)=-8.1062 | val loss=0.011040, nmse(dB)=-15.1494 | 0.1s
# [472/500] train loss=0.049831, nmse(dB)=-8.1074 | val loss=0.011040, nmse(dB)=-15.1495 | 0.1s
# [473/500] train loss=0.049928, nmse(dB)=-8.1457 | val loss=0.011040, nmse(dB)=-15.1497 | 0.1s
# [474/500] train loss=0.051462, nmse(dB)=-7.9524 | val loss=0.011039, nmse(dB)=-15.1500 | 0.1s
# [475/500] train loss=0.051868, nmse(dB)=-7.9583 | val loss=0.011039, nmse(dB)=-15.1503 | 0.1s
# [476/500] train loss=0.051446, nmse(dB)=-8.0239 | val loss=0.011039, nmse(dB)=-15.1505 | 0.1s
# [477/500] train loss=0.050983, nmse(dB)=-8.0492 | val loss=0.011039, nmse(dB)=-15.1507 | 0.1s
# [478/500] train loss=0.049437, nmse(dB)=-8.1220 | val loss=0.011038, nmse(dB)=-15.1509 | 0.1s
# [479/500] train loss=0.052148, nmse(dB)=-7.8994 | val loss=0.011038, nmse(dB)=-15.1510 | 0.1s
# [480/500] train loss=0.050314, nmse(dB)=-8.0519 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [481/500] train loss=0.050954, nmse(dB)=-7.9881 | val loss=0.011038, nmse(dB)=-15.1512 | 0.1s
# [482/500] train loss=0.050584, nmse(dB)=-8.0755 | val loss=0.011038, nmse(dB)=-15.1512 | 0.1s
# [483/500] train loss=0.050112, nmse(dB)=-8.1558 | val loss=0.011038, nmse(dB)=-15.1512 | 0.1s
# [484/500] train loss=0.050674, nmse(dB)=-8.0483 | val loss=0.011038, nmse(dB)=-15.1512 | 0.1s
# [485/500] train loss=0.052376, nmse(dB)=-7.9399 | val loss=0.011038, nmse(dB)=-15.1512 | 0.1s
# [486/500] train loss=0.050054, nmse(dB)=-8.1392 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [487/500] train loss=0.050978, nmse(dB)=-8.0044 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [488/500] train loss=0.051253, nmse(dB)=-8.0455 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [489/500] train loss=0.050630, nmse(dB)=-8.0396 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [490/500] train loss=0.052766, nmse(dB)=-7.9099 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [491/500] train loss=0.050165, nmse(dB)=-8.0708 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [492/500] train loss=0.053013, nmse(dB)=-7.8357 | val loss=0.011038, nmse(dB)=-15.1510 | 0.1s
# [493/500] train loss=0.052527, nmse(dB)=-7.9507 | val loss=0.011038, nmse(dB)=-15.1510 | 0.1s
# [494/500] train loss=0.052226, nmse(dB)=-7.9759 | val loss=0.011038, nmse(dB)=-15.1510 | 0.1s
# [495/500] train loss=0.051327, nmse(dB)=-7.9661 | val loss=0.011038, nmse(dB)=-15.1510 | 0.1s
# [496/500] train loss=0.051308, nmse(dB)=-8.0210 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [497/500] train loss=0.052404, nmse(dB)=-7.9582 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [498/500] train loss=0.051023, nmse(dB)=-8.0289 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [499/500] train loss=0.049171, nmse(dB)=-8.2042 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
# [500/500] train loss=0.052021, nmse(dB)=-7.9090 | val loss=0.011038, nmse(dB)=-15.1511 | 0.1s
#
# === Training Summary ===
# Total time: 77.5s (0h 1m 17.5s)
# Best epoch: 372 | best val loss=0.011036, best val nmse(dB)=-15.1491
# Log saved to: /mnt/ssd_7t_2/Deepverse/lwm_model2_scene100.txt

# %% [markdown]
# # 런타임 체크

# %%
ch, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model(ch.to(device))   
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# y abs mean: 0.47954413294792175
# y abs max : 1.0
# y power   : 0.280792772769928
# yhat abs mean: 0.4944300651550293
# yhat abs max : 0.634103000164032
# yhat power   : 0.24522088468074799

# %%
y
# Out:
# tensor([[0.7090, 0.7159, 0.7231,  ..., 0.3206, 0.3072, 0.2977],
#         [0.8089, 0.8152, 0.8209,  ..., 0.8547, 0.8500, 0.8445],
#         [0.6920, 0.6924, 0.6915,  ..., 0.5997, 0.5878, 0.5722],
#         ...,
#         [0.2887, 0.2863, 0.2859,  ..., 0.4003, 0.3852, 0.3718],
#         [0.1215, 0.1107, 0.1027,  ..., 0.5635, 0.5779, 0.5905],
#         [0.2820, 0.2798, 0.2786,  ..., 0.6724, 0.6601, 0.6451]],
#        device='cuda:1')

# %%
yhat[0:10, 0:10]
# Out:
# tensor([[0.5597, 0.5647, 0.5659, 0.5623, 0.5656, 0.5576, 0.5701, 0.5650, 0.5533,
#          0.5697],
#         [0.5576, 0.5743, 0.5550, 0.5515, 0.5845, 0.5627, 0.5904, 0.5460, 0.5638,
#          0.5942],
#         [0.5588, 0.5636, 0.5674, 0.5639, 0.5646, 0.5595, 0.5672, 0.5658, 0.5513,
#          0.5703],
#         [0.5596, 0.5665, 0.5691, 0.5653, 0.5696, 0.5617, 0.5710, 0.5660, 0.5522,
#          0.5696],
#         [0.5611, 0.5691, 0.5767, 0.5613, 0.5657, 0.5554, 0.5812, 0.5683, 0.5564,
#          0.5746],
#         [0.5571, 0.5626, 0.5794, 0.5621, 0.5535, 0.5577, 0.5619, 0.5792, 0.5642,
#          0.5478],
#         [0.5645, 0.5629, 0.5760, 0.5643, 0.5681, 0.5529, 0.5792, 0.5645, 0.5548,
#          0.5647],
#         [0.5647, 0.5646, 0.5672, 0.5688, 0.5686, 0.5601, 0.5717, 0.5677, 0.5530,
#          0.5709],
#         [0.5554, 0.5737, 0.5631, 0.5630, 0.5695, 0.5642, 0.5695, 0.5624, 0.5611,
#          0.5792],
#         [0.5595, 0.5643, 0.5697, 0.5600, 0.5613, 0.5544, 0.5709, 0.5637, 0.5536,
#          0.5700]], device='cuda:1')

# %% [markdown]
# # 데이터 입력 형태

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

print("\n=== one batch shapes ===")
ch, y = next(iter(train_loader))
print("ch :", tuple(ch.shape), " -> (B,T,F_in)")
print("y  :", tuple(y.shape), " -> (B,F_out)")
with torch.no_grad():
    yhat = model(ch.to(device))
print("yhat:", tuple(yhat.shape), " -> (B,F_out)")
print("this forward predicted vectors:", yhat.shape[0], "(=B)")
print("each vector predicts elements:", yhat.shape[1], "(=F_out)")
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# past_len      : 16
# len(ds)       : 84
# len(train_ds) : 51
# len(val_ds)   : 17
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B,T,F_in)
# y  : (32, 2048)  -> (B,F_out)
# yhat: (32, 2048)  -> (B,F_out)
# this forward predicted vectors: 32 (=B)
# each vector predicts elements: 2048 (=F_out)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
