# %% [markdown]
# #  Import

# %%
print("hello")
# Out:
# hello

# %%
import os
import sys

import numpy as  np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Settings

# %%
# Scenes 2000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(100))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"현재 사용 중인 장치: {device}")
# Out:
# 현재 사용 중인 장치: cuda:0

# %% [markdown]
# # Generate a dataset

# %%
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (0.94s)
# Generating radar dataset: ⏳ In progress
# Generating radar dataset: ✅ Completed (197.67s)

# %% [markdown]
# # location dataset
#  지금 실험에서는 안쓰임

# %%
# comm = dataset.comm_dataset
# location =  comm

# location = [
#     {
#         "bs_loc": d["bs_loc"],                      # (3,)
#         "ue_loc": np.asarray(d["ue_loc"]).squeeze() # (3,)  (원래 (1,3)이면 squeeze)
#     }
#     for row in comm.data      # row: [dict] 형태
#     for d in row              # d: dict
# ]

# print(ue_location)  #)

# %% [markdown]
# # communication  dataset

# %%
# UE 정보
comm = dataset.comm_dataset
ch = comm.data[0][0]['ue'][0]
print(ch.coeffs.shape)
# Out:
# (1, 16, 64)

# %% [markdown]
# # preprocessing

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device=device, eps=1e-16):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex128)
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(device)
    return H

# %%
# 사용예시
H = preprocess_channel_coeffs_minmax(ch.coeffs, r_min=-0.5, r_max=0.5, i_min=-0.5, i_max=0.5)
print(H.shape)  # (1, 16, 128) 64 subcar
# Out:
# torch.Size([1, 16, 128])

# %% [markdown]
# ### image dataset

# %%
sensor = dataset.camera_dataset.sensors["unit1_cam1"]
path0 = sensor.files[0]
img = Image.open(path0).convert("RGB")
arr = np.array(img)

print("path:", path0)
print("PIL size (W,H):", img.size)
print("np shape:", arr.shape, "dtype:", arr.dtype)  # 보통 (H,W,3), uint8
# Out:
# path: scenarios/DT31/RGB_images/unit1_cam1/7.png
# PIL size (W,H): (1920, 1080)
# np shape: (1080, 1920, 3) dtype: uint8

# %%
IMG_SIZE = 224

def preprocess_img(path, img_size=IMG_SIZE, device=device):
    # 1) load (H,W,3) uint8
    img = Image.open(path).convert("RGB")
    arr = np.array(img)

    # 2) numpy -> torch, (3,H,W), float32
    x = torch.from_numpy(arr).permute(2, 0, 1).contiguous().double()  # (3,H,W), double for ImageNet stats
    x = x / 255.0  # [0,1]

    # 3) add batch dim -> (1,3,H,W)
    x = x.unsqueeze(0)

    # 4) resize -> (1,3,224,224)
    x = F.interpolate(x, size=(img_size, img_size),
                      mode="bilinear", align_corners=False)

    # 5) normalize (ImageNet)
    mean = torch.tensor([0.485, 0.456, 0.406], dtype=x.dtype).view(1, 3, 1, 1)
    std  = torch.tensor([0.229, 0.224, 0.225], dtype=x.dtype).view(1, 3, 1, 1)
    x = (x - mean) / std

    # 6) move to device (GPU)
    x = x.to(device, non_blocking=True)

    return x  # (1,3,224,224) on device

# %%
# 사용예시
cd = dataset.camera_dataset
sensor = cd.sensors['unit1_cam1']
path0 = sensor.files[0]
img = preprocess_img(path0, device=device)
print(img.shape, img.device)  # torch.Size([1,3,224,224]) cuda:0
print(path0)
# Out:
# torch.Size([1, 3, 224, 224]) cuda:0
# scenarios/DT31/RGB_images/unit1_cam1/7.png

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class MultiModalNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, cam_files, ue_idx=0, past_len=15, device=device,
                 # Arguments for statistical values (initialized with default values)
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        
        self.comm_frames = comm_frames
        self.cam_files = list(cam_files)
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device
        
        # Save statistical values
        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = min(len(self.comm_frames), len(self.cam_files))
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2 

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1. Image Past (Apply Preprocessing)
        img_list = []
        for k in range(t - self.past_len + 1, t + 1):
            img_path = self.cam_files[k]
            img_k = preprocess_img(img_path, device=self.device).squeeze(0)
            img_list.append(img_k)
        img = torch.stack(img_list, dim=0)  # Shape: (past_len

        
        # 2. Channel Past (Apply Scaling)
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            # Use the newly defined Min-Max preprocessing function
            h = preprocess_channel_coeffs_minmax(
                coeffs_np, 
                self.r_min, self.r_max, self.i_min, self.i_max, 
                device=self.device
            ).reshape(-1)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)

        # 3. Target (Apply Scaling) - Target must also be scaled for model training!
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_minmax(
            coeffs_np_next, 
            self.r_min, self.r_max, self.i_min, self.i_max, 
            device=self.device
        ).reshape(-1)

        return channel_past, img, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
sensor = dataset.camera_dataset.sensors["unit1_cam1"]

ds = MultiModalNextStepDatasetGPU(
    comm_frames=comm_frames,
    cam_files=sensor.files,
    ue_idx=0,
    past_len=16,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   # ✅ 의미 없음 (이미 GPU)
)

ch, img, y = next(iter(loader))
print(ch.shape, img.shape, y.shape)
print(ch.device, img.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 16, 3, 224, 224]) torch.Size([8, 2048])
# cuda:0 cuda:0 cuda:0

# %% [markdown]
# # GRU/LSTM Early fusion

# %%
class ImgFrameEncoderVec(nn.Module):
    """(B*T,3,224,224) -> (B*T,d_img)"""
    def __init__(self, d_img=128):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, 32, 5, stride=2, padding=2), nn.ReLU(),
            nn.Conv2d(32, 64, 3, stride=2, padding=1), nn.ReLU(),
            nn.Conv2d(64, 128, 3, stride=2, padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((1,1)),
        )
        self.proj = nn.Linear(128, d_img)

    def forward(self, x):
        z = self.conv(x).flatten(1)  # (B*T,128)
        return self.proj(z)          # (B*T,d_img)

class RNN_EarlyFusion_Forecaster(nn.Module):
    """
    ch : (B,T,F_in=2048)
    img: (B,T,3,224,224)
    yhat: (B,F_out)
    """
    def __init__(self, F_in, F_out, rnn_type="gru", hidden=256, num_layers=2, d_img=128, dropout=0.1):
        super().__init__()
        self.img_enc = ImgFrameEncoderVec(d_img=d_img)

        self.in_proj = nn.Sequential(
            nn.Linear(F_in + d_img, hidden),
            nn.GELU(),
        )

        rnn_type = rnn_type.lower()
        if rnn_type == "gru":
            self.rnn = nn.GRU(hidden, hidden, num_layers=num_layers, batch_first=True,
                              dropout=dropout if num_layers > 1 else 0.0)
        elif rnn_type == "lstm":
            self.rnn = nn.LSTM(hidden, hidden, num_layers=num_layers, batch_first=True,
                               dropout=dropout if num_layers > 1 else 0.0)
        else:
            raise ValueError("rnn_type must be 'gru' or 'lstm'")

        self.head = nn.Linear(hidden, F_out)

    def forward(self, ch, img):
        B, T, _ = ch.shape
        img_ = img.view(B*T, *img.shape[2:])             # (B*T,3,224,224)
        img_feat = self.img_enc(img_).view(B, T, -1)     # (B,T,d_img)

        x = torch.cat([ch, img_feat], dim=-1)            # (B,T,F_in+d_img)
        x = self.in_proj(x)                              # (B,T,hidden)

        out, _ = self.rnn(x)                             # (B,T,hidden)
        z = out[:, -1, :]                                # last
        return self.head(z)                              # (B,F_out)

# %% [markdown]
# # Fine-tuning
# data shape 맞추기 위해

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# from lwm_multi_model import multi_modal_lwm  # 너가 올린 backbone

# class FinetuneChannelPredictor(nn.Module):
#     """
#     직접 구현한 lwm_multi_model(channel + image)에 맞는 파인튜닝 모델
#     Input:
#       ch:  (B, T, F_in)  e.g., (B,16,2048) 16: past Length, 2048: feature dim
#       img: (B, 3, 224, 224)
#     Output:
#       yhat: (B, F_out)  e.g., (B,2048)
#     """
#     def __init__(
#         self,
#         backbone: nn.Module,
#         F_in: int,
#         F_out: int,
#         pool: str = "last",          # "last" or "mean"
#         freeze_image: bool = False,
#         freeze_backbone: bool = False,
#         element_length: int = 16,    # 채널 벡터 차원 (backbone 기대값)
#         d_model: int = 64            # backbone 내부 feature dim
#     ):
#         super().__init__()
#         self.backbone = backbone
#         self.pool = pool

#         # backbone이 기대하는 channel feature dim = ELEMENT_LENGTH
#         # (backbone 내부 Channel_Embedding: Linear(ELEMENT_LENGTH -> D_MODEL))
#         if element_length is None:
#             element_length = backbone.channel_embedding.element_length
#         if d_model is None:
#             d_model = backbone.channel_embedding.d_model

#         # 입력 차원 정렬: F_in -> ELEMENT_LENGTH
#         self.in_proj = nn.Sequential(
#             nn.Linear(F_in, 512),
#             nn.GELU(),
#             nn.Linear(512, 128),
#             nn.GELU(),
#             nn.Linear(128, element_length)
#         )

#         # 출력 head: D_MODEL -> F_out
#         self.head = nn.Linear(d_model, F_out)

#         if freeze_image:
#             for p in self.backbone.image_embedding.parameters():
#                 p.requires_grad = False

#         if freeze_backbone:
#             for p in self.backbone.parameters():
#                 p.requires_grad = False
#             # 그래도 projection/head는 학습되게 다시 켜기
#             for p in self.in_proj.parameters():
#                 p.requires_grad = True
#             for p in self.head.parameters():
#                 p.requires_grad = True

#     def forward(self, ch, img):
#         # ch: (B,T,F_in) -> (B,T,ELEMENT_LENGTH)
#         ch = self.in_proj(ch)

#         # backbone: (B,T,D_MODEL)/
#         tokens = self.backbone(ch, img)

#         # pooling -> (B,D_MODEL)
#         if self.pool == "last":
#             z = tokens[:, -1, :]
#         elif self.pool == "mean":
#             z = tokens.mean(dim=1)
#         else:
#             raise ValueError(f"Unknown pool={self.pool}")

#         # head -> (B,F_out)
#         yhat = self.head(z)
#         return yhat

# %% [markdown]
# ## NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# %% [markdown]
# # Train/Val split

# %%
n = len(ds)
n_train = int(0.75 * n)
train_idx = list(range(0, n_train))
val_idx = list(range(n_train, n))

train_ts = [ds.valid_start + i for i in train_idx]

(real_min,  real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_ts, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)
F_in = 2048  # 

# Verify
ch, img, y = next(iter(train_loader))
F_out = y.shape[-1]
print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")
# Out:
# Calculating min/max over training set...
# Done. rmin=-1.0646139639174899e-06, rmax=1.0917989155343993e-06, imin=-1.0719516685941772e-06, imax=1.0643868111374237e-06
# Dataset statistical values set in the dataset.
#
# === Data Check ===
# y stats | min: 0.0318, max: 0.9671
# If scaling worked correctly, values should be within [0, 1].

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
cam_files = list(dataset.camera_dataset.sensors["unit1_cam1"].files)

print("len(comm_frames):", len(comm_frames))
print("len(cam_files):", len(cam_files))
print("first comm frame keys:", list(comm_frames[0].keys()))
print("first cam file:", cam_files[0])
# Out:
# len(comm_frames): 100
# len(cam_files): 1114
# first comm frame keys: ['bs_loc', 'ue', 'ue_loc', 'bs']
# first cam file: scenarios/DT31/RGB_images/unit1_cam1/7.png

# %%
len(val_loader)
# Out:
# 1

# %% [markdown]
# # Model generate and also check

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print("device:", device)

# # 배치 하나로 F_in/F_out 자동 확정
# ch, img, y = next(iter(train_loader))
# F_in  = ch.shape[-1]
# F_out = y.shape[-1]
# print("Detected:", "F_in=", F_in, "F_out=", F_out)
# print("Batch devices:", ch.device, img.device, y.device)

# # backbone + finetune model
# backbone = multi_modal_lwm().to(device)

# model = FinetuneChannelPredictor(
#     backbone=backbone,
#     F_in=F_in,
#     F_out=F_out,
#     pool="last",            # "mean"으로 바꿔도 됨
#     freeze_image=False,     # 원하면 True (이미지 인코더 고정)
#     freeze_backbone=False,  # 원하면 True (proj/head만 학습)
#     element_length=16,
#     d_model=64
# ).to(device)

# # sanity forward
# model.eval()
# with torch.no_grad():
#     # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
#     yhat = model(ch.to(device), img.to(device))
# print("yhat:", yhat.shape, "y:", y.shape)

# %% [markdown]
# # Train/ Eval 함수 (AMP + grad clip)

# %%
def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        # float64(Double) 타입으로 확실하게 캐스팅하여 GPU로 이동
        ch = ch.to(device, dtype=torch.float64, non_blocking=True)
        img = img.to(device, dtype=torch.float64, non_blocking=True)
        y  = y.to(device, dtype=torch.float64, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        # amp.autocast 제거됨
        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)

        # scaler 없이 바로 backward 호출
        loss.backward()

        # scaler.unscale_ 없이 바로 gradient clipping 적용
        if grad_clip is not None and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        # scaler.step 대신 바로 optimizer.step() 호출
        optimizer.step()

        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)


@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        # float64(Double) 타입으로 확실하게 캐스팅
        ch = ch.to(device, dtype=torch.float64, non_blocking=True)
        img = img.to(device, dtype=torch.float64, non_blocking=True)
        y  = y.to(device, dtype=torch.float64, non_blocking=True)

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

# %%
# define fit model GRU/ LSTM
def fit_model(
    model: nn.Module,
    train_loader,
    val_loader,
    device,
    epochs: int,
    ckpt_path: str,
    lr: float = 1e-4,
    weight_decay: float = 1e-4,
    grad_clip: float = 1.0,
):
    trainable_params = [p for p in model.parameters() if p.requires_grad]
    print("trainable params:", sum(p.numel() for p in trainable_params))

    optimizer = torch.optim.AdamW(trainable_params, lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    best_val = float("inf")

    for epoch in range(1, epochs + 1):
        t0 = time.time()

        tr_loss, tr_nmse = train_one_epoch(model, train_loader, optimizer, device=device, grad_clip=grad_clip)
        va_loss, va_nmse = evaluate(model, val_loader, device=device)

        scheduler.step()

        dt = time.time() - t0
        print(
            f"[{epoch:02d}/{epochs}] "
            f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
            f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
            f"{dt:.1f}s"
        )

        if va_loss < best_val:
            best_val = va_loss
            torch.save(
                {
                    "epoch": epoch,
                    "model_state": model.state_dict(),
                    "optimizer_state": optimizer.state_dict(),
                    "best_val": best_val,
                    "F_in": F_in,
                    "F_out": F_out,
                },
                ckpt_path
            )
            print(f"  ↳ saved {ckpt_path}")

    return best_val

# %% [markdown]
# #  Optiimizer  / Scheduler 설정

# %%
# # requires_grad=True인 파라미터만 학습
# trainable_params = [p for p in model.parameters() if p.requires_grad]
# print("trainable params:", sum(p.numel() for p in trainable_params))

# optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# # (선택) cosine scheduler
# epochs = 1000
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

# %% [markdown]
# # 학습 루프 + checkpoint 저장

# %%
epochs = 600

# ===== 1) GRU =====
model_gru = RNN_EarlyFusion_Forecaster(
    F_in=F_in, F_out=F_out,
    rnn_type="gru",
    hidden=256, num_layers=2, d_img=128, dropout=0.1
).double().to(device)

print("\n=== Training: GRU Early Fusion ===")
best_gru = fit_model(
    model=model_gru,
    train_loader=train_loader,
    val_loader=val_loader,
    device=device,
    epochs=epochs,
    ckpt_path="best_gru_earlyfusion.pt",
)

del model_gru
torch.cuda.empty_cache()

# ===== 2) LSTM =====
model_lstm = RNN_EarlyFusion_Forecaster(
    F_in=F_in, F_out=F_out,
    rnn_type="lstm",
    hidden=256, num_layers=2, d_img=128, dropout=0.1
).double().to(device)

print("\n=== Training: LSTM Early Fusion ===")
best_lstm = fit_model(
    model=model_lstm,
    train_loader=train_loader,
    val_loader=val_loader,
    device=device,
    epochs=epochs,
    ckpt_path="best_lstm_earlyfusion.pt",
)

print("\n=== Done ===")
print("Best val loss | GRU :", best_gru)
print("Best val loss | LSTM:", best_lstm)
# Out:
# === Training: GRU Early Fusion ===
# trainable params: 1984448
# [01/600] train loss=0.286804, nmse(dB)=0.0064 | val loss=0.252128, nmse(dB)=-0.1061 | 87.8s
#   ↳ saved best_gru_earlyfusion.pt
# [02/600] train loss=0.278482, nmse(dB)=-0.1242 | val loss=0.243343, nmse(dB)=-0.2603 | 87.3s
#   ↳ saved best_gru_earlyfusion.pt
# [03/600] train loss=0.269351, nmse(dB)=-0.2695 | val loss=0.232067, nmse(dB)=-0.4665 | 87.6s
#   ↳ saved best_gru_earlyfusion.pt
# [04/600] train loss=0.257725, nmse(dB)=-0.4621 | val loss=0.218264, nmse(dB)=-0.7331 | 88.2s
#   ↳ saved best_gru_earlyfusion.pt
# [05/600] train loss=0.244009, nmse(dB)=-0.7003 | val loss=0.202526, nmse(dB)=-1.0585 | 88.4s
#   ↳ saved best_gru_earlyfusion.pt
# [06/600] train loss=0.228301, nmse(dB)=-0.9911 | val loss=0.185723, nmse(dB)=-1.4351 | 87.9s
#   ↳ saved best_gru_earlyfusion.pt
# [07/600] train loss=0.212107, nmse(dB)=-1.3103 | val loss=0.168783, nmse(dB)=-1.8512 | 88.0s
#   ↳ saved best_gru_earlyfusion.pt
# [08/600] train loss=0.195632, nmse(dB)=-1.6621 | val loss=0.152419, nmse(dB)=-2.2950 | 89.2s
#   ↳ saved best_gru_earlyfusion.pt
# [09/600] train loss=0.179624, nmse(dB)=-2.0352 | val loss=0.136869, nmse(dB)=-2.7635 | 88.8s
#   ↳ saved best_gru_earlyfusion.pt
# [10/600] train loss=0.164121, nmse(dB)=-2.4318 | val loss=0.122116, nmse(dB)=-3.2603 | 87.9s
#   ↳ saved best_gru_earlyfusion.pt
# [11/600] train loss=0.149930, nmse(dB)=-2.8331 | val loss=0.108226, nmse(dB)=-3.7867 | 88.5s
#   ↳ saved best_gru_earlyfusion.pt
# [12/600] train loss=0.136409, nmse(dB)=-3.2521 | val loss=0.095343, nmse(dB)=-4.3398 | 88.1s
#   ↳ saved best_gru_earlyfusion.pt
# [13/600] train loss=0.123760, nmse(dB)=-3.6935 | val loss=0.083589, nmse(dB)=-4.9146 | 86.4s
#   ↳ saved best_gru_earlyfusion.pt
# [14/600] train loss=0.112528, nmse(dB)=-4.1184 | val loss=0.072982, nmse(dB)=-5.5086 | 88.1s
#   ↳ saved best_gru_earlyfusion.pt
# [15/600] train loss=0.102296, nmse(dB)=-4.5509 | val loss=0.063523, nmse(dB)=-6.1177 | 86.9s
#   ↳ saved best_gru_earlyfusion.pt
# [16/600] train loss=0.093229, nmse(dB)=-4.9796 | val loss=0.055194, nmse(dB)=-6.7365 | 88.8s
#   ↳ saved best_gru_earlyfusion.pt
# [17/600] train loss=0.085086, nmse(dB)=-5.4135 | val loss=0.047888, nmse(dB)=-7.3646 | 89.0s
#   ↳ saved best_gru_earlyfusion.pt
# [18/600] train loss=0.077910, nmse(dB)=-5.8300 | val loss=0.041556, nmse(dB)=-7.9959 | 88.9s
#   ↳ saved best_gru_earlyfusion.pt
# [19/600] train loss=0.071875, nmse(dB)=-6.2256 | val loss=0.036154, nmse(dB)=-8.6208 | 88.3s
#   ↳ saved best_gru_earlyfusion.pt
# [20/600] train loss=0.066752, nmse(dB)=-6.5923 | val loss=0.031613, nmse(dB)=-9.2297 | 88.6s
#   ↳ saved best_gru_earlyfusion.pt
# [21/600] train loss=0.062359, nmse(dB)=-6.9363 | val loss=0.027834, nmse(dB)=-9.8145 | 88.5s
#   ↳ saved best_gru_earlyfusion.pt
# [22/600] train loss=0.058756, nmse(dB)=-7.2455 | val loss=0.024705, nmse(dB)=-10.3716 | 88.8s
#   ↳ saved best_gru_earlyfusion.pt
# [23/600] train loss=0.055633, nmse(dB)=-7.5385 | val loss=0.022137, nmse(dB)=-10.8947 | 88.7s
#   ↳ saved best_gru_earlyfusion.pt
# [24/600] train loss=0.053116, nmse(dB)=-7.7880 | val loss=0.020055, nmse(dB)=-11.3764 | 89.1s
#   ↳ saved best_gru_earlyfusion.pt
# [25/600] train loss=0.051220, nmse(dB)=-7.9932 | val loss=0.018353, nmse(dB)=-11.8200 | 88.8s
#   ↳ saved best_gru_earlyfusion.pt
# [26/600] train loss=0.049525, nmse(dB)=-8.1857 | val loss=0.016968, nmse(dB)=-12.2246 | 88.1s
#   ↳ saved best_gru_earlyfusion.pt
# [27/600] train loss=0.048234, nmse(dB)=-8.3304 | val loss=0.015886, nmse(dB)=-12.5750 | 87.9s
#   ↳ saved best_gru_earlyfusion.pt
# [28/600] train loss=0.047182, nmse(dB)=-8.4692 | val loss=0.015008, nmse(dB)=-12.8882 | 89.5s
#   ↳ saved best_gru_earlyfusion.pt
# [29/600] train loss=0.046372, nmse(dB)=-8.5770 | val loss=0.014286, nmse(dB)=-13.1679 | 88.4s
#   ↳ saved best_gru_earlyfusion.pt
# [30/600] train loss=0.045592, nmse(dB)=-8.6740 | val loss=0.013700, nmse(dB)=-13.4149 | 89.2s
#   ↳ saved best_gru_earlyfusion.pt
# [31/600] train loss=0.044999, nmse(dB)=-8.7493 | val loss=0.013203, nmse(dB)=-13.6396 | 87.9s
#   ↳ saved best_gru_earlyfusion.pt
# [32/600] train loss=0.044623, nmse(dB)=-8.8072 | val loss=0.012788, nmse(dB)=-13.8402 | 86.6s
#   ↳ saved best_gru_earlyfusion.pt
# [33/600] train loss=0.044209, nmse(dB)=-8.8728 | val loss=0.012452, nmse(dB)=-14.0135 | 87.8s
#   ↳ saved best_gru_earlyfusion.pt
# [34/600] train loss=0.043851, nmse(dB)=-8.9195 | val loss=0.012206, nmse(dB)=-14.1464 | 82.8s
#   ↳ saved best_gru_earlyfusion.pt
# [35/600] train loss=0.043643, nmse(dB)=-8.9478 | val loss=0.012041, nmse(dB)=-14.2383 | 84.6s
#   ↳ saved best_gru_earlyfusion.pt
# [36/600] train loss=0.043183, nmse(dB)=-9.0051 | val loss=0.011830, nmse(dB)=-14.3638 | 83.0s
#   ↳ saved best_gru_earlyfusion.pt
# [37/600] train loss=0.043225, nmse(dB)=-9.0101 | val loss=0.011677, nmse(dB)=-14.4604 | 83.2s
#   ↳ saved best_gru_earlyfusion.pt
# [38/600] train loss=0.043009, nmse(dB)=-9.0339 | val loss=0.011562, nmse(dB)=-14.5362 | 84.1s
#   ↳ saved best_gru_earlyfusion.pt
# [39/600] train loss=0.042828, nmse(dB)=-9.0586 | val loss=0.011464, nmse(dB)=-14.5987 | 87.0s
#   ↳ saved best_gru_earlyfusion.pt
# [40/600] train loss=0.042755, nmse(dB)=-9.0658 | val loss=0.011392, nmse(dB)=-14.6469 | 83.4s
#   ↳ saved best_gru_earlyfusion.pt
# [41/600] train loss=0.042774, nmse(dB)=-9.0711 | val loss=0.011376, nmse(dB)=-14.6555 | 86.4s
#   ↳ saved best_gru_earlyfusion.pt
# [42/600] train loss=0.042587, nmse(dB)=-9.0945 | val loss=0.011345, nmse(dB)=-14.6751 | 85.0s
#   ↳ saved best_gru_earlyfusion.pt
# [43/600] train loss=0.042672, nmse(dB)=-9.0868 | val loss=0.011306, nmse(dB)=-14.7019 | 88.2s
#   ↳ saved best_gru_earlyfusion.pt
# [44/600] train loss=0.042526, nmse(dB)=-9.1068 | val loss=0.011250, nmse(dB)=-14.7451 | 88.1s
#   ↳ saved best_gru_earlyfusion.pt
# [45/600] train loss=0.042574, nmse(dB)=-9.1022 | val loss=0.011220, nmse(dB)=-14.7674 | 87.2s
#   ↳ saved best_gru_earlyfusion.pt
# [46/600] train loss=0.042562, nmse(dB)=-9.1043 | val loss=0.011203, nmse(dB)=-14.7788 | 86.7s
#   ↳ saved best_gru_earlyfusion.pt
# [47/600] train loss=0.042545, nmse(dB)=-9.1060 | val loss=0.011197, nmse(dB)=-14.7820 | 85.6s
#   ↳ saved best_gru_earlyfusion.pt
# [48/600] train loss=0.042664, nmse(dB)=-9.1005 | val loss=0.011168, nmse(dB)=-14.8015 | 85.8s
#   ↳ saved best_gru_earlyfusion.pt
# [49/600] train loss=0.042491, nmse(dB)=-9.1111 | val loss=0.011169, nmse(dB)=-14.8006 | 85.5s
# [50/600] train loss=0.042488, nmse(dB)=-9.1150 | val loss=0.011175, nmse(dB)=-14.8017 | 87.8s
# [51/600] train loss=0.042439, nmse(dB)=-9.1180 | val loss=0.011144, nmse(dB)=-14.8251 | 84.2s
#   ↳ saved best_gru_earlyfusion.pt
# [52/600] train loss=0.042325, nmse(dB)=-9.1321 | val loss=0.011147, nmse(dB)=-14.8209 | 85.9s
# [53/600] train loss=0.042499, nmse(dB)=-9.1171 | val loss=0.011152, nmse(dB)=-14.8171 | 86.6s
# [54/600] train loss=0.042448, nmse(dB)=-9.1174 | val loss=0.011159, nmse(dB)=-14.8098 | 89.0s
# [55/600] train loss=0.042388, nmse(dB)=-9.1230 | val loss=0.011180, nmse(dB)=-14.7953 | 88.2s
# [56/600] train loss=0.042348, nmse(dB)=-9.1241 | val loss=0.011160, nmse(dB)=-14.8132 | 88.9s
# [57/600] train loss=0.042361, nmse(dB)=-9.1227 | val loss=0.011153, nmse(dB)=-14.8184 | 89.1s
# [58/600] train loss=0.042404, nmse(dB)=-9.1204 | val loss=0.011132, nmse(dB)=-14.8370 | 88.5s
#   ↳ saved best_gru_earlyfusion.pt
# [59/600] train loss=0.042347, nmse(dB)=-9.1246 | val loss=0.011141, nmse(dB)=-14.8291 | 88.5s
# [60/600] train loss=0.042386, nmse(dB)=-9.1272 | val loss=0.011158, nmse(dB)=-14.8128 | 88.1s
# [61/600] train loss=0.042427, nmse(dB)=-9.1266 | val loss=0.011145, nmse(dB)=-14.8194 | 88.8s
# [62/600] train loss=0.042381, nmse(dB)=-9.1288 | val loss=0.011131, nmse(dB)=-14.8291 | 88.3s
#   ↳ saved best_gru_earlyfusion.pt
# [63/600] train loss=0.042414, nmse(dB)=-9.1206 | val loss=0.011144, nmse(dB)=-14.8148 | 88.5s
# [64/600] train loss=0.042398, nmse(dB)=-9.1253 | val loss=0.011142, nmse(dB)=-14.8172 | 88.2s
# [65/600] train loss=0.042370, nmse(dB)=-9.1332 | val loss=0.011125, nmse(dB)=-14.8290 | 88.5s
#   ↳ saved best_gru_earlyfusion.pt
# [66/600] train loss=0.042274, nmse(dB)=-9.1380 | val loss=0.011123, nmse(dB)=-14.8341 | 88.9s
# [587/600] train loss=0.035794, nmse(dB)=-9.6133 | val loss=0.011151, nmse(dB)=-14.8165 | 86.9s
# [588/600] train loss=0.035909, nmse(dB)=-9.5985 | val loss=0.011151, nmse(dB)=-14.8163 | 86.1s
# [589/600] train loss=0.035856, nmse(dB)=-9.6137 | val loss=0.011151, nmse(dB)=-14.8163 | 85.8s
# [590/600] train loss=0.035827, nmse(dB)=-9.6099 | val loss=0.011151, nmse(dB)=-14.8161 | 84.5s
# [591/600] train loss=0.035943, nmse(dB)=-9.6055 | val loss=0.011151, nmse(dB)=-14.8161 | 86.8s
# [592/600] train loss=0.035892, nmse(dB)=-9.6053 | val loss=0.011151, nmse(dB)=-14.8160 | 86.2s
# [593/600] train loss=0.035838, nmse(dB)=-9.6097 | val loss=0.011151, nmse(dB)=-14.8160 | 86.4s
# [594/600] train loss=0.035951, nmse(dB)=-9.6040 | val loss=0.011151, nmse(dB)=-14.8160 | 85.5s
# [595/600] train loss=0.035870, nmse(dB)=-9.6080 | val loss=0.011151, nmse(dB)=-14.8160 | 82.6s
# [596/600] train loss=0.035804, nmse(dB)=-9.6140 | val loss=0.011151, nmse(dB)=-14.8160 | 86.8s
# [597/600] train loss=0.035862, nmse(dB)=-9.6115 | val loss=0.011151, nmse(dB)=-14.8160 | 87.4s
# [598/600] train loss=0.035986, nmse(dB)=-9.5990 | val loss=0.011151, nmse(dB)=-14.8160 | 90.1s
# [599/600] train loss=0.035847, nmse(dB)=-9.6056 | val loss=0.011151, nmse(dB)=-14.8160 | 88.2s
# [600/600] train loss=0.035873, nmse(dB)=-9.6072 | val loss=0.011151, nmse(dB)=-14.8160 | 88.1s
#
# === Training: LSTM Early Fusion ===
# trainable params: 2247616
# [01/600] train loss=0.287991, nmse(dB)=0.0260 | val loss=0.257584, nmse(dB)=-0.0131 | 90.8s
#   ↳ saved best_lstm_earlyfusion.pt
# [02/600] train loss=0.284797, nmse(dB)=-0.0243 | val loss=0.253875, nmse(dB)=-0.0761 | 87.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [03/600] train loss=0.280862, nmse(dB)=-0.0853 | val loss=0.248966, nmse(dB)=-0.1610 | 92.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [04/600] train loss=0.275699, nmse(dB)=-0.1682 | val loss=0.242120, nmse(dB)=-0.2822 | 90.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [05/600] train loss=0.268391, nmse(dB)=-0.2850 | val loss=0.232829, nmse(dB)=-0.4523 | 88.8s
#   ↳ saved best_lstm_earlyfusion.pt
# [06/600] train loss=0.258601, nmse(dB)=-0.4480 | val loss=0.220871, nmse(dB)=-0.6815 | 88.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [07/600] train loss=0.246416, nmse(dB)=-0.6609 | val loss=0.206266, nmse(dB)=-0.9789 | 89.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [08/600] train loss=0.231373, nmse(dB)=-0.9381 | val loss=0.189236, nmse(dB)=-1.3536 | 89.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [09/600] train loss=0.214165, nmse(dB)=-1.2765 | val loss=0.170411, nmse(dB)=-1.8094 | 89.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [10/600] train loss=0.195394, nmse(dB)=-1.6807 | val loss=0.150917, nmse(dB)=-2.3380 | 90.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [11/600] train loss=0.176215, nmse(dB)=-2.1366 | val loss=0.132162, nmse(dB)=-2.9158 | 90.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [12/600] train loss=0.158392, nmse(dB)=-2.6025 | val loss=0.115494, nmse(dB)=-3.5033 | 88.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [13/600] train loss=0.142462, nmse(dB)=-3.0682 | val loss=0.101534, nmse(dB)=-4.0652 | 83.8s
#   ↳ saved best_lstm_earlyfusion.pt
# [14/600] train loss=0.129346, nmse(dB)=-3.4915 | val loss=0.089666, nmse(dB)=-4.6081 | 84.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [15/600] train loss=0.117763, nmse(dB)=-3.9072 | val loss=0.078745, nmse(dB)=-5.1764 | 87.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [16/600] train loss=0.107151, nmse(dB)=-4.3308 | val loss=0.068339, nmse(dB)=-5.7980 | 88.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [17/600] train loss=0.097107, nmse(dB)=-4.7850 | val loss=0.058670, nmse(dB)=-6.4692 | 91.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [18/600] train loss=0.087766, nmse(dB)=-5.2609 | val loss=0.050080, nmse(dB)=-7.1691 | 90.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [19/600] train loss=0.079554, nmse(dB)=-5.7254 | val loss=0.042835, nmse(dB)=-7.8644 | 90.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [20/600] train loss=0.072702, nmse(dB)=-6.1710 | val loss=0.036889, nmse(dB)=-8.5350 | 90.2s
#   ↳ saved best_lstm_earlyfusion.pt
# [21/600] train loss=0.066925, nmse(dB)=-6.5844 | val loss=0.032025, nmse(dB)=-9.1764 | 88.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [22/600] train loss=0.062378, nmse(dB)=-6.9350 | val loss=0.027999, nmse(dB)=-9.7942 | 90.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [23/600] train loss=0.058394, nmse(dB)=-7.2740 | val loss=0.024677, nmse(dB)=-10.3848 | 91.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [24/600] train loss=0.055414, nmse(dB)=-7.5528 | val loss=0.021976, nmse(dB)=-10.9381 | 91.8s
#   ↳ saved best_lstm_earlyfusion.pt
# [25/600] train loss=0.052812, nmse(dB)=-7.8132 | val loss=0.019810, nmse(dB)=-11.4461 | 92.2s
#   ↳ saved best_lstm_earlyfusion.pt
# [26/600] train loss=0.050759, nmse(dB)=-8.0332 | val loss=0.018079, nmse(dB)=-11.9066 | 92.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [27/600] train loss=0.049013, nmse(dB)=-8.2333 | val loss=0.016689, nmse(dB)=-12.3224 | 91.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [28/600] train loss=0.047777, nmse(dB)=-8.3929 | val loss=0.015580, nmse(dB)=-12.6934 | 93.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [29/600] train loss=0.046783, nmse(dB)=-8.5151 | val loss=0.014688, nmse(dB)=-13.0237 | 91.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [30/600] train loss=0.045879, nmse(dB)=-8.6354 | val loss=0.013992, nmse(dB)=-13.3069 | 91.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [31/600] train loss=0.045251, nmse(dB)=-8.7155 | val loss=0.013440, nmse(dB)=-13.5508 | 90.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [32/600] train loss=0.044670, nmse(dB)=-8.7932 | val loss=0.012993, nmse(dB)=-13.7622 | 88.2s
#   ↳ saved best_lstm_earlyfusion.pt
# [33/600] train loss=0.044284, nmse(dB)=-8.8484 | val loss=0.012644, nmse(dB)=-13.9383 | 88.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [34/600] train loss=0.043775, nmse(dB)=-8.9201 | val loss=0.012360, nmse(dB)=-14.0878 | 85.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [35/600] train loss=0.043701, nmse(dB)=-8.9341 | val loss=0.012124, nmse(dB)=-14.2161 | 89.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [36/600] train loss=0.043404, nmse(dB)=-8.9805 | val loss=0.011932, nmse(dB)=-14.3259 | 89.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [37/600] train loss=0.043216, nmse(dB)=-9.0101 | val loss=0.011788, nmse(dB)=-14.4094 | 91.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [38/600] train loss=0.042967, nmse(dB)=-9.0393 | val loss=0.011656, nmse(dB)=-14.4919 | 90.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [39/600] train loss=0.042858, nmse(dB)=-9.0516 | val loss=0.011550, nmse(dB)=-14.5581 | 90.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [40/600] train loss=0.042810, nmse(dB)=-9.0628 | val loss=0.011470, nmse(dB)=-14.6081 | 90.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [41/600] train loss=0.042847, nmse(dB)=-9.0722 | val loss=0.011405, nmse(dB)=-14.6506 | 90.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [42/600] train loss=0.042593, nmse(dB)=-9.0941 | val loss=0.011351, nmse(dB)=-14.6873 | 90.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [43/600] train loss=0.042729, nmse(dB)=-9.0866 | val loss=0.011304, nmse(dB)=-14.7169 | 91.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [44/600] train loss=0.042545, nmse(dB)=-9.1076 | val loss=0.011267, nmse(dB)=-14.7398 | 91.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [45/600] train loss=0.042375, nmse(dB)=-9.1194 | val loss=0.011237, nmse(dB)=-14.7622 | 90.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [46/600] train loss=0.042546, nmse(dB)=-9.1029 | val loss=0.011208, nmse(dB)=-14.7803 | 89.2s
#   ↳ saved best_lstm_earlyfusion.pt
# [47/600] train loss=0.042523, nmse(dB)=-9.1069 | val loss=0.011188, nmse(dB)=-14.7953 | 89.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [48/600] train loss=0.042483, nmse(dB)=-9.1158 | val loss=0.011175, nmse(dB)=-14.8036 | 89.7s
#   ↳ saved best_lstm_earlyfusion.pt
# [49/600] train loss=0.042388, nmse(dB)=-9.1244 | val loss=0.011166, nmse(dB)=-14.8117 | 87.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [50/600] train loss=0.042406, nmse(dB)=-9.1192 | val loss=0.011166, nmse(dB)=-14.8099 | 88.7s
# [51/600] train loss=0.042480, nmse(dB)=-9.1160 | val loss=0.011166, nmse(dB)=-14.8107 | 88.3s
# [52/600] train loss=0.042419, nmse(dB)=-9.1207 | val loss=0.011162, nmse(dB)=-14.8140 | 87.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [53/600] train loss=0.042462, nmse(dB)=-9.1190 | val loss=0.011144, nmse(dB)=-14.8246 | 85.7s
#   ↳ saved best_lstm_earlyfusion.pt
# [54/600] train loss=0.042412, nmse(dB)=-9.1222 | val loss=0.011135, nmse(dB)=-14.8284 | 84.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [55/600] train loss=0.042471, nmse(dB)=-9.1195 | val loss=0.011130, nmse(dB)=-14.8299 | 84.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [56/600] train loss=0.042524, nmse(dB)=-9.1185 | val loss=0.011129, nmse(dB)=-14.8305 | 85.7s
#   ↳ saved best_lstm_earlyfusion.pt
# [57/600] train loss=0.042367, nmse(dB)=-9.1292 | val loss=0.011121, nmse(dB)=-14.8385 | 87.2s
#   ↳ saved best_lstm_earlyfusion.pt
# [58/600] train loss=0.042462, nmse(dB)=-9.1186 | val loss=0.011120, nmse(dB)=-14.8387 | 89.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [59/600] train loss=0.042308, nmse(dB)=-9.1389 | val loss=0.011120, nmse(dB)=-14.8397 | 88.1s
# [60/600] train loss=0.042340, nmse(dB)=-9.1321 | val loss=0.011118, nmse(dB)=-14.8417 | 87.0s
#   ↳ saved best_lstm_earlyfusion.pt
#
# [83/600] train loss=0.042211, nmse(dB)=-9.1412 | val loss=0.011120, nmse(dB)=-14.8395 | 86.3s
# [84/600] train loss=0.042252, nmse(dB)=-9.1411 | val loss=0.011118, nmse(dB)=-14.8423 | 88.9s
# [85/600] train loss=0.042303, nmse(dB)=-9.1368 | val loss=0.011113, nmse(dB)=-14.8464 | 90.6s
# [86/600] train loss=0.042257, nmse(dB)=-9.1400 | val loss=0.011107, nmse(dB)=-14.8480 | 89.8s
# [87/600] train loss=0.042223, nmse(dB)=-9.1443 | val loss=0.011110, nmse(dB)=-14.8448 | 90.6s
# [88/600] train loss=0.042232, nmse(dB)=-9.1442 | val loss=0.011114, nmse(dB)=-14.8442 | 90.6s
# [89/600] train loss=0.042287, nmse(dB)=-9.1344 | val loss=0.011111, nmse(dB)=-14.8461 | 90.6s
# [90/600] train loss=0.042353, nmse(dB)=-9.1309 | val loss=0.011105, nmse(dB)=-14.8482 | 90.7s

# %%
print("\n=== Final Check on GRU Model ===")
ch, img, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model_gru(ch.to(device), img.to(device))  # 여기만 변경
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())


print("\n=== LSTM Evaluation on a Batch ===")

ch, img, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model_lstm(ch.to(device), img.to(device))  # 여기만 변경
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# === Final Check on GRU Model ===
# y abs mean: 0.49763021590545353
# y abs max : 1.0
# y power   : 0.29138221609311427
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 8
#       5 print("y power   :", (y**2).mean().item())
#       7 with torch.no_grad():
# ----> 8     yhat = model_gru(ch.to(device), img.to(device))  # 여기만 변경
#       9 print("yhat abs mean:", yhat.abs().mean().item())
#      10 print("yhat abs max :", yhat.abs().max().item())
#
# NameError: name 'model_gru' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 데이터 입력 및 형태

# %%
@torch.no_grad()
def debug_batch_and_forward(loader, device, model=None, name="model", max_print=1):
    """
    - loader에서 배치 하나 뽑아서 shape/device/dtype 확인
    - model이 있으면 forward까지 해서 yhat shape 확인
    - img가 (B,T,3,H,W)인지 (B,3,H,W)인지 자동 판별
    """
    batch = next(iter(loader))

    # (ch, img, y) 형태를 가정
    ch, img, y = batch

    def info(x, label):
        print(f"{label:>4}: shape={tuple(x.shape)} dtype={x.dtype} device={x.device}")

    print("\n=== one batch tensor info ===")
    info(ch, "ch")
    info(img, "img")
    info(y,  "y")

    # img 차원 설명
    if img.dim() == 5:
        print("img format: (B,T,3,H,W)")
    elif img.dim() == 4:
        print("img format: (B,3,H,W)")
    else:
        print(f"img format: unexpected dim={img.dim()}")

    # forward check
    if model is not None:
        model.eval()
        yhat = model(ch.to(device), img.to(device))
        info(yhat, f"{name}_yhat")
        return (ch, img, y, yhat)

    return (ch, img, y)

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("N(cam_files)  :", len(cam_files))
print("N(min)        :", min(len(comm_frames), len(cam_files)))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

# GRU
debug_batch_and_forward(train_loader, device, model_gru, name="GRU")

# LSTM
debug_batch_and_forward(train_loader, device, model_lstm, name="LSTM")
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# N(cam_files)  : 1114
# N(min)        : 100
# past_len      : 16
# len(ds)       : 84
# len(train_ds) : 63
# len(val_ds)   : 21
# len(train_loader): 2
# len(val_loader)  : 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 13
#      10 print("len(val_loader)  :", len(val_loader))
#      12 # GRU
# ---> 13 debug_batch_and_forward(train_loader, device, model_gru, name="GRU")
#      15 # LSTM
#      16 debug_batch_and_forward(train_loader, device, model_lstm, name="LSTM")
#
# NameError: name 'debug_batch_and_forward' is not defined
