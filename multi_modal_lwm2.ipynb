# %% [markdown]
# # multi_model_lwm2
# <br>모델 크기 차이에 따른 성능 차이 비교
# <br> element_length=16, d_model=64
# <br> in_proj: F_in(2048) → 512 → 128 → 16

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # Import

# %%
import os
import sys

import numpy as  np
from lwm_multi_model2 import multi_modal_lwm  # 클래스 import
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import torch.nn as nn   
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Setting
# ### CUDA 몇번 사용하는지 잘 확인하기

# %%
# Scenes 1000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(100))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"현재 사용 중인 장치: {device}")
# Out:
# 현재 사용 중인 장치: cuda:1

# %% [markdown]
# # Generate a dataset

# %%
# scenes / subcarriers는 그대로
param_manager.params["radar"]["enable"] = False

# lidar가 dict로 존재하면 disable
if isinstance(param_manager.params.get("lidar", None), dict):
    param_manager.params["lidar"]["enable"] = False

# position이 dict로 존재하면 disable
if isinstance(param_manager.params.get("position", None), dict):
    param_manager.params["position"]["enable"] = False

# Radar, LiDAR, Position 사용하지 않으므로 False 
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (0.88s)

# %% [markdown]
# # Prerocessing

# %% [markdown]
# #### Channel

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device=device, eps=1e-16):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex64)
    
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(dtype=torch.float32)
    return H

# %% [markdown]
# #### image

# %%
IMG_SIZE = 224
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(1,3,1,1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(1,3,1,1)

def preprocess_img(path, img_size=IMG_SIZE):
    img = Image.open(path).convert("RGB")
    arr = np.array(img)

    x = torch.from_numpy(arr).permute(2, 0, 1).contiguous().float()
    x = x / 255.0
    x = x.unsqueeze(0)

    x = F.interpolate(x, size=(img_size, img_size), mode="bilinear", align_corners=False)

    # mean/std는 전역으로 빼는 게 성능상 좋음 (아래 참고)
    x = (x - IMAGENET_MEAN) / IMAGENET_STD
    return x.squeeze(0)  # (3,224,224) CPU

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class MultiModalNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, cam_files, ue_idx=0, past_len=15, device=device,
                 # Arguments for statistical values (initialized with default values)
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        
        self.comm_frames = comm_frames
        self.cam_files = list(cam_files)
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device
        
        # Save statistical values
        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = min(len(self.comm_frames), len(self.cam_files))
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2 

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1. Image Past (Apply Preprocessing)
        img_list = []
        for k in range(t - self.past_len + 1, t + 1):
            img_path = self.cam_files[k]
            img_k = preprocess_img(img_path).squeeze(0)
            img_list.append(img_k)
        img = torch.stack(img_list, dim=0)  # Shape: (past_len

        
        # 2. Channel Past (Apply Scaling)
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            # Use the newly defined Min-Max preprocessing function
            h = preprocess_channel_coeffs_minmax(
                coeffs_np, 
                self.r_min, self.r_max, self.i_min, self.i_max, 
                device=self.device
            ).reshape(-1)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)

        # 3. Target (Apply Scaling) - Target must also be scaled for model training!
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_minmax(
            coeffs_np_next, 
            self.r_min, self.r_max, self.i_min, self.i_max, 
            device=self.device
        ).reshape(-1)

        return channel_past, img, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
sensor = dataset.camera_dataset.sensors["unit1_cam1"]

ds = MultiModalNextStepDatasetGPU(
    comm_frames=comm_frames,
    cam_files=sensor.files,
    ue_idx=0,
    past_len=16,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=8,     
    pin_memory=True   
)

ch, img, y = next(iter(loader))
print(ch.shape, img.shape, y.shape)
print(ch.device, img.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 16, 3, 224, 224]) torch.Size([8, 2048])
# cpu cpu cpu

# %% [markdown]
# # Fine-tuning

# %%
from lwm_multi_model2 import multi_modal_lwm  # 너가 올린 backbone

class FinetuneChannelPredictor(nn.Module):
    """
    직접 구현한 lwm_multi_model(channel + image)에 맞는 파인튜닝 모델
    Input:
      ch:  (B, T, F_in)  e.g., (B,16,2048) 16: past Length, 2048: feature dim
      img: (B, 3, 224, 224)
    Output:
      yhat: (B, F_out)  e.g., (B,2048)
    """
    def __init__(
        self,
        backbone: nn.Module,
        F_in: int,
        F_out: int,
        pool: str = "last",          # "last" or "mean"
        freeze_image: bool = False,
        freeze_backbone: bool = False,
        element_length: int = 16,    # 채널 벡터 차원 (backbone 기대값)
        d_model: int = 64            # backbone 내부 feature dim
    ):
        super().__init__()
        self.backbone = backbone
        self.pool = pool

        # backbone이 기대하는 channel feature dim = ELEMENT_LENGTH
        # (backbone 내부 Channel_Embedding: Linear(ELEMENT_LENGTH -> D_MODEL))
        if element_length is None:
            element_length = backbone.channel_embedding.element_length
        if d_model is None:
            d_model = backbone.channel_embedding.d_model

        # 입력 차원 정렬: F_in -> ELEMENT_LENGTH
        self.in_proj = nn.Sequential(
            nn.Linear(F_in, 512),
            nn.GELU(),
            nn.Linear(512, 128),
            nn.GELU(),
            nn.Linear(128, element_length)
        )

        # 출력 head: D_MODEL -> F_out
        self.head = nn.Linear(d_model, F_out)

        if freeze_image:
            for p in self.backbone.image_embedding.parameters():
                p.requires_grad = False

        if freeze_backbone:
            for p in self.backbone.parameters():
                p.requires_grad = False
            # 그래도 projection/head는 학습되게 다시 켜기
            for p in self.in_proj.parameters():
                p.requires_grad = True
            for p in self.head.parameters():
                p.requires_grad = True

    def forward(self, ch, img):
        # ch: (B,T,F_in) -> (B,T,ELEMENT_LENGTH)
        ch = self.in_proj(ch)

        # backbone: (B,T,D_MODEL)
        tokens = self.backbone(ch, img)

        # pooling -> (B,D_MODEL)
        if self.pool == "last":
            z = tokens[:, -1, :]
        elif self.pool == "mean":
            z = tokens.mean(dim=1)
        else:
            raise ValueError(f"Unknown pool={self.pool}")

        # head -> (B,F_out)
        yhat = self.head(z)
        return yhat

# %% [markdown]
# # NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# %% [markdown]
# # Train/val Split

# %%
# 겹치는 부분이 있는지 확인하는 함수
def used_frames_for_ds_indices(ds, ds_indices):
    used = set()
    for i in ds_indices:
        t = ds.valid_start + i
        # inputs use [t-T+1 .. t], target uses (t+1)
        used.update(range(t - T + 1, t + 2))
    return used

# %%
n_total = len(ds)
T = ds.past_len  # = past_len

# ---- choose k so that train=3k, val=k and NO frame-overlap is possible ----
k_max = (n_total - T) // 4
if k_max <= 0:
    raise ValueError(
        f"Not enough data for strict non-overlap 3:1. "
        f"n_total={n_total}, past_len(T)={T}. "
        f"Try increasing scenes or decreasing past_len."
    )

k = k_max               # use as much data as possible under constraints
n_val = k
n_train = 3 * k

train_idx = list(range(0, n_train))
val_idx   = list(range(n_total - n_val, n_total))

print("n_total:", n_total, "T:", T)
print("train samples:", len(train_idx), "val samples:", len(val_idx), "ratio:", len(train_idx)/len(val_idx))

# ---- min/max ONLY from train (same as your original policy) ----
train_ts = [ds.valid_start + i for i in train_idx]

(real_min, real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_ts, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=8)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=8)

F_in = 2048


overlap = used_frames_for_ds_indices(ds, train_idx).intersection(
          used_frames_for_ds_indices(ds, val_idx))
print("frame-overlap count:", len(overlap))
assert len(overlap) == 0, "Leakage detected: train/val share frames!"

# Verify
ch, img, y = next(iter(train_loader))
F_out = y.shape[-1]
print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")
# Out:
# n_total: 84 T: 16
# train samples: 51 val samples: 17 ratio: 3.0
# Calculating min/max over training set...
# Done. rmin=-1.0646139639174899e-06, rmax=1.0917989155343993e-06, imin=-1.0719516685941772e-06, imax=1.0643868111374237e-06
# Dataset statistical values set in the dataset.
# frame-overlap count: 0
#
# === Data Check ===
# y stats | min: 0.0000, max: 1.0000
# If scaling worked correctly, values should be within [0, 1].

# %% [markdown]
# # Train/Eval 함수

# %%
def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        # Dataset이 이미 cuda 텐서를 반환하더라도 안전하게 유지
        ch = ch.to(device, non_blocking=True)
        img = img.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)
        
        loss.backward()

        if grad_clip is not None and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        optimizer.step()
        
        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)


@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        ch = ch.to(device, non_blocking=True)
        img = img.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

# %% [markdown]
# # 모델 생성 및 확인

# %%
# 배치 하나로 F_in/F_out 자동 확정
ch, img, y = next(iter(train_loader))
F_in  = ch.shape[-1]
F_out = y.shape[-1]
print("Detected:", "F_in=", F_in, "F_out=", F_out)
print("Batch devices:", ch.device, img.device, y.device)

# backbone + finetune model
backbone = multi_modal_lwm().to(device)

model = FinetuneChannelPredictor(
    backbone=backbone,
    F_in=F_in,
    F_out=F_out,
    pool="last",            # "mean"으로 바꿔도 됨
    freeze_image=False,     # 원하면 True (이미지 인코더 고정)
    freeze_backbone=False,  # 원하면 True (proj/head만 학습)
    element_length=16,
    d_model=64
).to(device)

# sanity forward
model.eval()
with torch.no_grad():
    # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
    yhat = model(ch.to(device), img.to(device))
print("yhat:", yhat.shape, "y:", y.shape)
# Out:
# Detected: F_in= 2048 F_out= 2048
# Batch devices: cpu cpu cpu
# yhat: torch.Size([32, 2048]) y: torch.Size([32, 2048])

# %% [markdown]
# # Optimizer/Scheduler 설정

# %%
# requires_grad=True인 파라미터만 학습
trainable_params = [p for p in model.parameters() if p.requires_grad]
print("trainable params:", sum(p.numel() for p in trainable_params))

optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# (선택) cosine scheduler
epochs = 500
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
# Out:
# trainable params: 2499120

# %% [markdown]
# # 학습 루프 및 checkpoint 저장

# %%
import os
import time
import torch

best_val = float("inf")
best_val_nmse = None
best_epoch = None

t_train0 = time.time()

log_path = "lwm2_multi_modal_scene100.txt"  # ✅ 파일명만 바꿔서 관리

with open(log_path, "w", encoding="utf-8") as f:
    # ✅ (선택) 실험 메타정보 헤더
    header = (
        "=== Experiment Info ===\n"
        f"model=LWM_multi_finetune\n"
        f"scenes=100\n"
        f"epochs={epochs}\n"
        f"F_in={F_in}, F_out={F_out}\n"
        f"start_time={time.strftime('%Y-%m-%d %H:%M:%S')}\n"
        "=======================\n"
    )
    print(header)
    f.write(header + "\n")
    f.flush()

    for epoch in range(1, epochs + 1):
        t0 = time.time()

        tr_loss, tr_nmse = train_one_epoch(model, train_loader, optimizer, device=device, grad_clip=1.0)
        va_loss, va_nmse = evaluate(model, val_loader, device=device)

        scheduler.step()

        dt = time.time() - t0
        line = (
            f"[{epoch:02d}/{epochs}] "
            f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
            f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
            f"{dt:.1f}s"
        )

        print(line)
        f.write(line + "\n")
        f.flush()

        if va_loss < best_val:
            best_val = va_loss
            best_val_nmse = va_nmse
            best_epoch = epoch

            ckpt_path = "best_LWM2_multi_model_finetune_scene100.pt"
            torch.save(
                {
                    "epoch": epoch,
                    "model_state": model.state_dict(),
                    "optimizer_state": optimizer.state_dict(),
                    "F_in": F_in,
                    "F_out": F_out,
                    "best_val_loss": best_val,
                    "best_val_nmse_db": best_val_nmse,
                },
                ckpt_path
            )

            save_line = (
                f"  ↳ saved {ckpt_path} | best@{best_epoch}: "
                f"val loss={best_val:.6f}, val nmse(dB)={best_val_nmse:.6f}"
            )
            print(save_line)
            f.write(save_line + "\n")
            f.flush()

total_sec = time.time() - t_train0
h = int(total_sec // 3600)
m = int((total_sec % 3600) // 60)
s = total_sec % 60

summary1 = "\n=== Training Summary ==="
summary2 = f"Total time: {total_sec:.1f}s ({h}h {m}m {s:.1f}s)"
summary3 = f"Best epoch: {best_epoch} | best val loss={best_val:.6f}, best val nmse(dB)={best_val_nmse:.6f}"

print(summary1); print(summary2); print(summary3)

with open(log_path, "a", encoding="utf-8") as f:
    f.write(summary1 + "\n")
    f.write(summary2 + "\n")
    f.write(summary3 + "\n")

print("Log saved to:", os.path.abspath(log_path))
# Out:
# === Experiment Info ===
# model=LWM_multi_finetune
# scenes=100
# epochs=500
# F_in=2048, F_out=2048
# start_time=2026-03-03 14:21:28
# =======================
#
# [01/500] train loss=0.597698, nmse(dB)=3.1377 | val loss=0.516583, nmse(dB)=3.0179 | 50.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@1: val loss=0.516583, val nmse(dB)=3.017938
# [02/500] train loss=0.556345, nmse(dB)=2.8228 | val loss=0.489134, nmse(dB)=2.7808 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@2: val loss=0.489134, val nmse(dB)=2.780767
# [03/500] train loss=0.523178, nmse(dB)=2.6533 | val loss=0.467977, nmse(dB)=2.5887 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@3: val loss=0.467977, val nmse(dB)=2.588687
# [04/500] train loss=0.508857, nmse(dB)=2.4745 | val loss=0.452769, nmse(dB)=2.4452 | 47.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@4: val loss=0.452769, val nmse(dB)=2.445165
# [05/500] train loss=0.495571, nmse(dB)=2.3574 | val loss=0.440220, nmse(dB)=2.3231 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@5: val loss=0.440220, val nmse(dB)=2.323058
# [06/500] train loss=0.484812, nmse(dB)=2.2006 | val loss=0.428201, nmse(dB)=2.2028 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@6: val loss=0.428201, val nmse(dB)=2.202806
# [07/500] train loss=0.471705, nmse(dB)=2.1064 | val loss=0.416965, nmse(dB)=2.0873 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@7: val loss=0.416965, val nmse(dB)=2.087294
# [08/500] train loss=0.457477, nmse(dB)=2.0300 | val loss=0.406534, nmse(dB)=1.9772 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@8: val loss=0.406534, val nmse(dB)=1.977229
# [09/500] train loss=0.444241, nmse(dB)=1.9277 | val loss=0.396379, nmse(dB)=1.8673 | 49.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@9: val loss=0.396379, val nmse(dB)=1.867331
# [10/500] train loss=0.437235, nmse(dB)=1.8175 | val loss=0.386216, nmse(dB)=1.7545 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@10: val loss=0.386216, val nmse(dB)=1.754487
# [11/500] train loss=0.427042, nmse(dB)=1.6963 | val loss=0.376053, nmse(dB)=1.6386 | 53.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@11: val loss=0.376053, val nmse(dB)=1.638634
# [12/500] train loss=0.419967, nmse(dB)=1.5870 | val loss=0.366010, nmse(dB)=1.5210 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@12: val loss=0.366010, val nmse(dB)=1.521019
# [13/500] train loss=0.405373, nmse(dB)=1.5064 | val loss=0.356295, nmse(dB)=1.4041 | 47.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@13: val loss=0.356295, val nmse(dB)=1.404132
# [14/500] train loss=0.399042, nmse(dB)=1.3693 | val loss=0.346814, nmse(dB)=1.2869 | 47.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@14: val loss=0.346814, val nmse(dB)=1.286947
# [15/500] train loss=0.387846, nmse(dB)=1.2748 | val loss=0.337456, nmse(dB)=1.1681 | 47.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@15: val loss=0.337456, val nmse(dB)=1.168090
# [16/500] train loss=0.380176, nmse(dB)=1.1843 | val loss=0.328251, nmse(dB)=1.0479 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@16: val loss=0.328251, val nmse(dB)=1.047925
# [17/500] train loss=0.365190, nmse(dB)=1.0802 | val loss=0.319267, nmse(dB)=0.9273 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@17: val loss=0.319267, val nmse(dB)=0.927333
# [18/500] train loss=0.360561, nmse(dB)=0.9502 | val loss=0.310483, nmse(dB)=0.8061 | 49.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@18: val loss=0.310483, val nmse(dB)=0.806104
# [19/500] train loss=0.351291, nmse(dB)=0.8437 | val loss=0.301804, nmse(dB)=0.6829 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@19: val loss=0.301804, val nmse(dB)=0.682895
# [20/500] train loss=0.340646, nmse(dB)=0.7444 | val loss=0.293293, nmse(dB)=0.5586 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@20: val loss=0.293293, val nmse(dB)=0.558587
# [21/500] train loss=0.333832, nmse(dB)=0.6400 | val loss=0.285002, nmse(dB)=0.4340 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@21: val loss=0.285002, val nmse(dB)=0.433966
# [22/500] train loss=0.327241, nmse(dB)=0.5106 | val loss=0.276935, nmse(dB)=0.3092 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@22: val loss=0.276935, val nmse(dB)=0.309178
# [23/500] train loss=0.318230, nmse(dB)=0.4172 | val loss=0.269057, nmse(dB)=0.1837 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@23: val loss=0.269057, val nmse(dB)=0.183746
# [24/500] train loss=0.309043, nmse(dB)=0.3065 | val loss=0.261360, nmse(dB)=0.0576 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@24: val loss=0.261360, val nmse(dB)=0.057592
# [25/500] train loss=0.301689, nmse(dB)=0.1855 | val loss=0.253825, nmse(dB)=-0.0696 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@25: val loss=0.253825, val nmse(dB)=-0.069561
# [26/500] train loss=0.295482, nmse(dB)=0.0835 | val loss=0.246444, nmse(dB)=-0.1978 | 49.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@26: val loss=0.246444, val nmse(dB)=-0.197840
# [27/500] train loss=0.289628, nmse(dB)=-0.0314 | val loss=0.239262, nmse(dB)=-0.3264 | 47.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@27: val loss=0.239262, val nmse(dB)=-0.326401
# [28/500] train loss=0.280910, nmse(dB)=-0.1117 | val loss=0.232262, nmse(dB)=-0.4555 | 47.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@28: val loss=0.232262, val nmse(dB)=-0.455488
# [29/500] train loss=0.275047, nmse(dB)=-0.2634 | val loss=0.225468, nmse(dB)=-0.5846 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@29: val loss=0.225468, val nmse(dB)=-0.584554
# [30/500] train loss=0.269263, nmse(dB)=-0.3481 | val loss=0.218866, nmse(dB)=-0.7138 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@30: val loss=0.218866, val nmse(dB)=-0.713784
# [31/500] train loss=0.260598, nmse(dB)=-0.4732 | val loss=0.212449, nmse(dB)=-0.8432 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@31: val loss=0.212449, val nmse(dB)=-0.843178
# [32/500] train loss=0.255361, nmse(dB)=-0.5746 | val loss=0.206169, nmse(dB)=-0.9737 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@32: val loss=0.206169, val nmse(dB)=-0.973655
# [33/500] train loss=0.247112, nmse(dB)=-0.6836 | val loss=0.200030, nmse(dB)=-1.1051 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@33: val loss=0.200030, val nmse(dB)=-1.105108
# [34/500] train loss=0.240109, nmse(dB)=-0.7855 | val loss=0.194050, nmse(dB)=-1.2371 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@34: val loss=0.194050, val nmse(dB)=-1.237131
# [35/500] train loss=0.233951, nmse(dB)=-0.8762 | val loss=0.188255, nmse(dB)=-1.3690 | 49.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@35: val loss=0.188255, val nmse(dB)=-1.369012
# [36/500] train loss=0.231609, nmse(dB)=-1.0373 | val loss=0.182652, nmse(dB)=-1.5004 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@36: val loss=0.182652, val nmse(dB)=-1.500444
# [37/500] train loss=0.222815, nmse(dB)=-1.0888 | val loss=0.177207, nmse(dB)=-1.6321 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@37: val loss=0.177207, val nmse(dB)=-1.632120
# [38/500] train loss=0.218282, nmse(dB)=-1.2404 | val loss=0.171913, nmse(dB)=-1.7641 | 47.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@38: val loss=0.171913, val nmse(dB)=-1.764097
# [39/500] train loss=0.215444, nmse(dB)=-1.3364 | val loss=0.166756, nmse(dB)=-1.8966 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@39: val loss=0.166756, val nmse(dB)=-1.896636
# [40/500] train loss=0.208983, nmse(dB)=-1.4247 | val loss=0.161721, nmse(dB)=-2.0301 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@40: val loss=0.161721, val nmse(dB)=-2.030059
# [41/500] train loss=0.205428, nmse(dB)=-1.5494 | val loss=0.156838, nmse(dB)=-2.1635 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@41: val loss=0.156838, val nmse(dB)=-2.163541
# [42/500] train loss=0.199451, nmse(dB)=-1.6559 | val loss=0.152098, nmse(dB)=-2.2971 | 47.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@42: val loss=0.152098, val nmse(dB)=-2.297126
# [43/500] train loss=0.194212, nmse(dB)=-1.7126 | val loss=0.147500, nmse(dB)=-2.4308 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@43: val loss=0.147500, val nmse(dB)=-2.430772
# [44/500] train loss=0.188005, nmse(dB)=-1.8580 | val loss=0.143060, nmse(dB)=-2.5639 | 49.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@44: val loss=0.143060, val nmse(dB)=-2.563860
# [45/500] train loss=0.186595, nmse(dB)=-1.9538 | val loss=0.138747, nmse(dB)=-2.6972 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@45: val loss=0.138747, val nmse(dB)=-2.697196
# [46/500] train loss=0.181673, nmse(dB)=-2.0624 | val loss=0.134553, nmse(dB)=-2.8309 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@46: val loss=0.134553, val nmse(dB)=-2.830933
# [47/500] train loss=0.176275, nmse(dB)=-2.1588 | val loss=0.130494, nmse(dB)=-2.9644 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@47: val loss=0.130494, val nmse(dB)=-2.964380
# [48/500] train loss=0.170633, nmse(dB)=-2.2674 | val loss=0.126560, nmse(dB)=-3.0978 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@48: val loss=0.126560, val nmse(dB)=-3.097809
# [49/500] train loss=0.167878, nmse(dB)=-2.3685 | val loss=0.122740, nmse(dB)=-3.2314 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@49: val loss=0.122740, val nmse(dB)=-3.231403
# [50/500] train loss=0.164731, nmse(dB)=-2.4906 | val loss=0.119046, nmse(dB)=-3.3647 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@50: val loss=0.119046, val nmse(dB)=-3.364651
# [51/500] train loss=0.159119, nmse(dB)=-2.5768 | val loss=0.115466, nmse(dB)=-3.4978 | 49.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@51: val loss=0.115466, val nmse(dB)=-3.497792
# [52/500] train loss=0.157672, nmse(dB)=-2.6891 | val loss=0.112013, nmse(dB)=-3.6302 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@52: val loss=0.112013, val nmse(dB)=-3.630231
# [53/500] train loss=0.153952, nmse(dB)=-2.8072 | val loss=0.108657, nmse(dB)=-3.7630 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@53: val loss=0.108657, val nmse(dB)=-3.762973
# [54/500] train loss=0.153388, nmse(dB)=-2.8523 | val loss=0.105387, nmse(dB)=-3.8964 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@54: val loss=0.105387, val nmse(dB)=-3.896369
# [55/500] train loss=0.148873, nmse(dB)=-2.9845 | val loss=0.102234, nmse(dB)=-4.0290 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@55: val loss=0.102234, val nmse(dB)=-4.029021
# [56/500] train loss=0.146147, nmse(dB)=-3.0353 | val loss=0.099223, nmse(dB)=-4.1596 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@56: val loss=0.099223, val nmse(dB)=-4.159567
# [57/500] train loss=0.141586, nmse(dB)=-3.1994 | val loss=0.096301, nmse(dB)=-4.2902 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@57: val loss=0.096301, val nmse(dB)=-4.290203
# [58/500] train loss=0.139860, nmse(dB)=-3.2191 | val loss=0.093435, nmse(dB)=-4.4222 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@58: val loss=0.093435, val nmse(dB)=-4.422241
# [59/500] train loss=0.135473, nmse(dB)=-3.3633 | val loss=0.090629, nmse(dB)=-4.5556 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@59: val loss=0.090629, val nmse(dB)=-4.555603
# [60/500] train loss=0.133837, nmse(dB)=-3.4050 | val loss=0.087908, nmse(dB)=-4.6890 | 49.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@60: val loss=0.087908, val nmse(dB)=-4.688976
# [61/500] train loss=0.129870, nmse(dB)=-3.4891 | val loss=0.085304, nmse(dB)=-4.8206 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@61: val loss=0.085304, val nmse(dB)=-4.820566
# [62/500] train loss=0.125316, nmse(dB)=-3.6432 | val loss=0.082811, nmse(dB)=-4.9505 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@62: val loss=0.082811, val nmse(dB)=-4.950459
# [63/500] train loss=0.124842, nmse(dB)=-3.7248 | val loss=0.080405, nmse(dB)=-5.0797 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@63: val loss=0.080405, val nmse(dB)=-5.079666
# [64/500] train loss=0.124977, nmse(dB)=-3.7657 | val loss=0.078064, nmse(dB)=-5.2092 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@64: val loss=0.078064, val nmse(dB)=-5.209153
# [65/500] train loss=0.119282, nmse(dB)=-3.9048 | val loss=0.075824, nmse(dB)=-5.3369 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@65: val loss=0.075824, val nmse(dB)=-5.336880
# [66/500] train loss=0.118429, nmse(dB)=-3.9880 | val loss=0.073660, nmse(dB)=-5.4640 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@66: val loss=0.073660, val nmse(dB)=-5.464007
# [67/500] train loss=0.116874, nmse(dB)=-4.0166 | val loss=0.071553, nmse(dB)=-5.5915 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@67: val loss=0.071553, val nmse(dB)=-5.591492
# [68/500] train loss=0.113103, nmse(dB)=-4.1513 | val loss=0.069504, nmse(dB)=-5.7192 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@68: val loss=0.069504, val nmse(dB)=-5.719238
# [69/500] train loss=0.110251, nmse(dB)=-4.2325 | val loss=0.067499, nmse(dB)=-5.8479 | 49.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@69: val loss=0.067499, val nmse(dB)=-5.847933
# [70/500] train loss=0.109904, nmse(dB)=-4.2979 | val loss=0.065593, nmse(dB)=-5.9739 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@70: val loss=0.065593, val nmse(dB)=-5.973916
# [71/500] train loss=0.108533, nmse(dB)=-4.3415 | val loss=0.063761, nmse(dB)=-6.0986 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@71: val loss=0.063761, val nmse(dB)=-6.098607
# [72/500] train loss=0.106481, nmse(dB)=-4.4483 | val loss=0.061952, nmse(dB)=-6.2254 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@72: val loss=0.061952, val nmse(dB)=-6.225400
# [73/500] train loss=0.104451, nmse(dB)=-4.5509 | val loss=0.060199, nmse(dB)=-6.3521 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@73: val loss=0.060199, val nmse(dB)=-6.352058
# [74/500] train loss=0.103844, nmse(dB)=-4.5861 | val loss=0.058541, nmse(dB)=-6.4754 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@74: val loss=0.058541, val nmse(dB)=-6.475432
# [75/500] train loss=0.101724, nmse(dB)=-4.6609 | val loss=0.056950, nmse(dB)=-6.5974 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@75: val loss=0.056950, val nmse(dB)=-6.597352
# [76/500] train loss=0.099347, nmse(dB)=-4.7561 | val loss=0.055416, nmse(dB)=-6.7183 | 47.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@76: val loss=0.055416, val nmse(dB)=-6.718262
# [77/500] train loss=0.097233, nmse(dB)=-4.7937 | val loss=0.053928, nmse(dB)=-6.8388 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@77: val loss=0.053928, val nmse(dB)=-6.838832
# [78/500] train loss=0.095789, nmse(dB)=-4.9417 | val loss=0.052482, nmse(dB)=-6.9594 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@78: val loss=0.052482, val nmse(dB)=-6.959396
# [79/500] train loss=0.095643, nmse(dB)=-4.9537 | val loss=0.051079, nmse(dB)=-7.0797 | 49.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@79: val loss=0.051079, val nmse(dB)=-7.079698
# [80/500] train loss=0.094221, nmse(dB)=-5.0283 | val loss=0.049727, nmse(dB)=-7.1988 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@80: val loss=0.049727, val nmse(dB)=-7.198827
# [81/500] train loss=0.090593, nmse(dB)=-5.1584 | val loss=0.048419, nmse(dB)=-7.3174 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@81: val loss=0.048419, val nmse(dB)=-7.317359
# [82/500] train loss=0.090305, nmse(dB)=-5.2229 | val loss=0.047174, nmse(dB)=-7.4334 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@82: val loss=0.047174, val nmse(dB)=-7.433440
# [83/500] train loss=0.089674, nmse(dB)=-5.2035 | val loss=0.045966, nmse(dB)=-7.5492 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@83: val loss=0.045966, val nmse(dB)=-7.549236
# [84/500] train loss=0.089665, nmse(dB)=-5.2352 | val loss=0.044772, nmse(dB)=-7.6669 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@84: val loss=0.044772, val nmse(dB)=-7.666946
# [85/500] train loss=0.086612, nmse(dB)=-5.3890 | val loss=0.043611, nmse(dB)=-7.7847 | 47.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@85: val loss=0.043611, val nmse(dB)=-7.784696
# [86/500] train loss=0.085594, nmse(dB)=-5.4129 | val loss=0.042500, nmse(dB)=-7.9006 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@86: val loss=0.042500, val nmse(dB)=-7.900562
# [87/500] train loss=0.083832, nmse(dB)=-5.5332 | val loss=0.041452, nmse(dB)=-8.0127 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@87: val loss=0.041452, val nmse(dB)=-8.012715
# [88/500] train loss=0.082991, nmse(dB)=-5.6005 | val loss=0.040440, nmse(dB)=-8.1241 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@88: val loss=0.040440, val nmse(dB)=-8.124062
# [89/500] train loss=0.083202, nmse(dB)=-5.5636 | val loss=0.039464, nmse(dB)=-8.2342 | 47.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@89: val loss=0.039464, val nmse(dB)=-8.234222
# [90/500] train loss=0.082346, nmse(dB)=-5.6414 | val loss=0.038495, nmse(dB)=-8.3465 | 49.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@90: val loss=0.038495, val nmse(dB)=-8.346535
# [91/500] train loss=0.081320, nmse(dB)=-5.6941 | val loss=0.037557, nmse(dB)=-8.4581 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@91: val loss=0.037557, val nmse(dB)=-8.458149
# [92/500] train loss=0.080605, nmse(dB)=-5.7647 | val loss=0.036680, nmse(dB)=-8.5654 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@92: val loss=0.036680, val nmse(dB)=-8.565390
# [93/500] train loss=0.079332, nmse(dB)=-5.7401 | val loss=0.035818, nmse(dB)=-8.6734 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@93: val loss=0.035818, val nmse(dB)=-8.673373
# [94/500] train loss=0.076117, nmse(dB)=-6.0066 | val loss=0.034976, nmse(dB)=-8.7818 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@94: val loss=0.034976, val nmse(dB)=-8.781775
# [95/500] train loss=0.078469, nmse(dB)=-5.8774 | val loss=0.034170, nmse(dB)=-8.8884 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@95: val loss=0.034170, val nmse(dB)=-8.888368
# [96/500] train loss=0.075059, nmse(dB)=-6.0185 | val loss=0.033395, nmse(dB)=-8.9933 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@96: val loss=0.033395, val nmse(dB)=-8.993300
# [97/500] train loss=0.075358, nmse(dB)=-6.0829 | val loss=0.032659, nmse(dB)=-9.0957 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@97: val loss=0.032659, val nmse(dB)=-9.095655
# [98/500] train loss=0.074636, nmse(dB)=-6.0751 | val loss=0.031939, nmse(dB)=-9.1982 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@98: val loss=0.031939, val nmse(dB)=-9.198197
# [99/500] train loss=0.074507, nmse(dB)=-6.0947 | val loss=0.031264, nmse(dB)=-9.2966 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@99: val loss=0.031264, val nmse(dB)=-9.296609
# [100/500] train loss=0.073524, nmse(dB)=-6.2054 | val loss=0.030608, nmse(dB)=-9.3946 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@100: val loss=0.030608, val nmse(dB)=-9.394578
# [101/500] train loss=0.073193, nmse(dB)=-6.2450 | val loss=0.029941, nmse(dB)=-9.4969 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@101: val loss=0.029941, val nmse(dB)=-9.496868
# [102/500] train loss=0.071982, nmse(dB)=-6.2596 | val loss=0.029292, nmse(dB)=-9.5989 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@102: val loss=0.029292, val nmse(dB)=-9.598869
# [103/500] train loss=0.069214, nmse(dB)=-6.3751 | val loss=0.028670, nmse(dB)=-9.6989 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@103: val loss=0.028670, val nmse(dB)=-9.698949
# [104/500] train loss=0.071127, nmse(dB)=-6.3348 | val loss=0.028078, nmse(dB)=-9.7966 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@104: val loss=0.028078, val nmse(dB)=-9.796569
# [105/500] train loss=0.070002, nmse(dB)=-6.4518 | val loss=0.027506, nmse(dB)=-9.8933 | 49.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@105: val loss=0.027506, val nmse(dB)=-9.893331
# [106/500] train loss=0.068277, nmse(dB)=-6.4795 | val loss=0.026953, nmse(dB)=-9.9893 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@106: val loss=0.026953, val nmse(dB)=-9.989251
# [107/500] train loss=0.067975, nmse(dB)=-6.5305 | val loss=0.026434, nmse(dB)=-10.0811 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@107: val loss=0.026434, val nmse(dB)=-10.081097
# [108/500] train loss=0.067916, nmse(dB)=-6.5286 | val loss=0.025934, nmse(dB)=-10.1716 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@108: val loss=0.025934, val nmse(dB)=-10.171618
# [109/500] train loss=0.067836, nmse(dB)=-6.5377 | val loss=0.025440, nmse(dB)=-10.2635 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@109: val loss=0.025440, val nmse(dB)=-10.263494
# [110/500] train loss=0.068039, nmse(dB)=-6.5496 | val loss=0.024964, nmse(dB)=-10.3538 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@110: val loss=0.024964, val nmse(dB)=-10.353781
# [111/500] train loss=0.067592, nmse(dB)=-6.5790 | val loss=0.024484, nmse(dB)=-10.4470 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@111: val loss=0.024484, val nmse(dB)=-10.446962
# [112/500] train loss=0.066642, nmse(dB)=-6.7092 | val loss=0.024035, nmse(dB)=-10.5362 | 47.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@112: val loss=0.024035, val nmse(dB)=-10.536222
# [113/500] train loss=0.066103, nmse(dB)=-6.6533 | val loss=0.023615, nmse(dB)=-10.6214 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@113: val loss=0.023615, val nmse(dB)=-10.621425
# [114/500] train loss=0.063831, nmse(dB)=-6.7862 | val loss=0.023211, nmse(dB)=-10.7054 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@114: val loss=0.023211, val nmse(dB)=-10.705376
# [115/500] train loss=0.067276, nmse(dB)=-6.6406 | val loss=0.022821, nmse(dB)=-10.7885 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@115: val loss=0.022821, val nmse(dB)=-10.788479
# [116/500] train loss=0.066666, nmse(dB)=-6.6682 | val loss=0.022428, nmse(dB)=-10.8738 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@116: val loss=0.022428, val nmse(dB)=-10.873796
# [117/500] train loss=0.064456, nmse(dB)=-6.7759 | val loss=0.022044, nmse(dB)=-10.9589 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@117: val loss=0.022044, val nmse(dB)=-10.958873
# [118/500] train loss=0.064078, nmse(dB)=-6.8281 | val loss=0.021686, nmse(dB)=-11.0396 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@118: val loss=0.021686, val nmse(dB)=-11.039592
# [119/500] train loss=0.064280, nmse(dB)=-6.8611 | val loss=0.021347, nmse(dB)=-11.1176 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@119: val loss=0.021347, val nmse(dB)=-11.117640
# [120/500] train loss=0.063333, nmse(dB)=-6.9391 | val loss=0.021029, nmse(dB)=-11.1921 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@120: val loss=0.021029, val nmse(dB)=-11.192064
# [121/500] train loss=0.060758, nmse(dB)=-7.0707 | val loss=0.020704, nmse(dB)=-11.2696 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@121: val loss=0.020704, val nmse(dB)=-11.269641
# [122/500] train loss=0.061730, nmse(dB)=-7.0419 | val loss=0.020379, nmse(dB)=-11.3492 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@122: val loss=0.020379, val nmse(dB)=-11.349180
# [123/500] train loss=0.064244, nmse(dB)=-6.8447 | val loss=0.020072, nmse(dB)=-11.4262 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@123: val loss=0.020072, val nmse(dB)=-11.426205
# [124/500] train loss=0.060775, nmse(dB)=-7.1176 | val loss=0.019789, nmse(dB)=-11.4992 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@124: val loss=0.019789, val nmse(dB)=-11.499207
# [125/500] train loss=0.059881, nmse(dB)=-7.1429 | val loss=0.019527, nmse(dB)=-11.5677 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@125: val loss=0.019527, val nmse(dB)=-11.567726
# [126/500] train loss=0.060848, nmse(dB)=-7.0239 | val loss=0.019267, nmse(dB)=-11.6367 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@126: val loss=0.019267, val nmse(dB)=-11.636721
# [127/500] train loss=0.058985, nmse(dB)=-7.2296 | val loss=0.018998, nmse(dB)=-11.7093 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@127: val loss=0.018998, val nmse(dB)=-11.709318
# [128/500] train loss=0.058934, nmse(dB)=-7.2262 | val loss=0.018719, nmse(dB)=-11.7857 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@128: val loss=0.018719, val nmse(dB)=-11.785662
# [129/500] train loss=0.060112, nmse(dB)=-7.1996 | val loss=0.018439, nmse(dB)=-11.8636 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@129: val loss=0.018439, val nmse(dB)=-11.863630
# [130/500] train loss=0.061792, nmse(dB)=-7.1228 | val loss=0.018181, nmse(dB)=-11.9371 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@130: val loss=0.018181, val nmse(dB)=-11.937111
# [131/500] train loss=0.059308, nmse(dB)=-7.2029 | val loss=0.017950, nmse(dB)=-12.0050 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@131: val loss=0.017950, val nmse(dB)=-12.004990
# [132/500] train loss=0.059524, nmse(dB)=-7.2199 | val loss=0.017734, nmse(dB)=-12.0703 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@132: val loss=0.017734, val nmse(dB)=-12.070256
# [133/500] train loss=0.059718, nmse(dB)=-7.2290 | val loss=0.017517, nmse(dB)=-12.1368 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@133: val loss=0.017517, val nmse(dB)=-12.136768
# [134/500] train loss=0.057403, nmse(dB)=-7.3390 | val loss=0.017310, nmse(dB)=-12.2011 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@134: val loss=0.017310, val nmse(dB)=-12.201108
# [135/500] train loss=0.057420, nmse(dB)=-7.3849 | val loss=0.017117, nmse(dB)=-12.2623 | 47.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@135: val loss=0.017117, val nmse(dB)=-12.262317
# [136/500] train loss=0.056794, nmse(dB)=-7.4521 | val loss=0.016925, nmse(dB)=-12.3239 | 47.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@136: val loss=0.016925, val nmse(dB)=-12.323885
# [137/500] train loss=0.058735, nmse(dB)=-7.2610 | val loss=0.016741, nmse(dB)=-12.3837 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@137: val loss=0.016741, val nmse(dB)=-12.383672
# [138/500] train loss=0.057401, nmse(dB)=-7.4012 | val loss=0.016566, nmse(dB)=-12.4413 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@138: val loss=0.016566, val nmse(dB)=-12.441307
# [139/500] train loss=0.058982, nmse(dB)=-7.2336 | val loss=0.016384, nmse(dB)=-12.5019 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@139: val loss=0.016384, val nmse(dB)=-12.501887
# [140/500] train loss=0.057220, nmse(dB)=-7.4070 | val loss=0.016205, nmse(dB)=-12.5630 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@140: val loss=0.016205, val nmse(dB)=-12.563042
# [141/500] train loss=0.058320, nmse(dB)=-7.2860 | val loss=0.016031, nmse(dB)=-12.6234 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@141: val loss=0.016031, val nmse(dB)=-12.623442
# [142/500] train loss=0.057395, nmse(dB)=-7.4039 | val loss=0.015863, nmse(dB)=-12.6828 | 47.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@142: val loss=0.015863, val nmse(dB)=-12.682815
# [143/500] train loss=0.057313, nmse(dB)=-7.4111 | val loss=0.015715, nmse(dB)=-12.7363 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@143: val loss=0.015715, val nmse(dB)=-12.736288
# [144/500] train loss=0.056004, nmse(dB)=-7.5167 | val loss=0.015580, nmse(dB)=-12.7862 | 49.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@144: val loss=0.015580, val nmse(dB)=-12.786246
# [145/500] train loss=0.058837, nmse(dB)=-7.2874 | val loss=0.015430, nmse(dB)=-12.8421 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@145: val loss=0.015430, val nmse(dB)=-12.842052
# [146/500] train loss=0.056145, nmse(dB)=-7.4601 | val loss=0.015294, nmse(dB)=-12.8938 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@146: val loss=0.015294, val nmse(dB)=-12.893754
# [147/500] train loss=0.057639, nmse(dB)=-7.4178 | val loss=0.015165, nmse(dB)=-12.9429 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@147: val loss=0.015165, val nmse(dB)=-12.942869
# [148/500] train loss=0.054726, nmse(dB)=-7.6196 | val loss=0.015041, nmse(dB)=-12.9896 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@148: val loss=0.015041, val nmse(dB)=-12.989649
# [149/500] train loss=0.057491, nmse(dB)=-7.5097 | val loss=0.014929, nmse(dB)=-13.0326 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@149: val loss=0.014929, val nmse(dB)=-13.032631
# [150/500] train loss=0.055716, nmse(dB)=-7.5640 | val loss=0.014808, nmse(dB)=-13.0801 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@150: val loss=0.014808, val nmse(dB)=-13.080091
# [151/500] train loss=0.057007, nmse(dB)=-7.5092 | val loss=0.014679, nmse(dB)=-13.1319 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@151: val loss=0.014679, val nmse(dB)=-13.131919
# [152/500] train loss=0.058033, nmse(dB)=-7.4104 | val loss=0.014560, nmse(dB)=-13.1803 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@152: val loss=0.014560, val nmse(dB)=-13.180290
# [153/500] train loss=0.055131, nmse(dB)=-7.5483 | val loss=0.014456, nmse(dB)=-13.2232 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@153: val loss=0.014456, val nmse(dB)=-13.223237
# [154/500] train loss=0.056951, nmse(dB)=-7.4911 | val loss=0.014338, nmse(dB)=-13.2725 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@154: val loss=0.014338, val nmse(dB)=-13.272451
# [155/500] train loss=0.057037, nmse(dB)=-7.5064 | val loss=0.014236, nmse(dB)=-13.3160 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@155: val loss=0.014236, val nmse(dB)=-13.316006
# [156/500] train loss=0.055623, nmse(dB)=-7.6031 | val loss=0.014133, nmse(dB)=-13.3604 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@156: val loss=0.014133, val nmse(dB)=-13.360420
# [157/500] train loss=0.054812, nmse(dB)=-7.6583 | val loss=0.014039, nmse(dB)=-13.4021 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@157: val loss=0.014039, val nmse(dB)=-13.402107
# [158/500] train loss=0.053500, nmse(dB)=-7.7710 | val loss=0.013952, nmse(dB)=-13.4413 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@158: val loss=0.013952, val nmse(dB)=-13.441333
# [159/500] train loss=0.055362, nmse(dB)=-7.6050 | val loss=0.013854, nmse(dB)=-13.4862 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@159: val loss=0.013854, val nmse(dB)=-13.486206
# [160/500] train loss=0.055841, nmse(dB)=-7.6090 | val loss=0.013751, nmse(dB)=-13.5344 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@160: val loss=0.013751, val nmse(dB)=-13.534357
# [161/500] train loss=0.053956, nmse(dB)=-7.7002 | val loss=0.013660, nmse(dB)=-13.5776 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@161: val loss=0.013660, val nmse(dB)=-13.577639
# [162/500] train loss=0.055606, nmse(dB)=-7.6152 | val loss=0.013584, nmse(dB)=-13.6140 | 47.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@162: val loss=0.013584, val nmse(dB)=-13.613970
# [163/500] train loss=0.054529, nmse(dB)=-7.6706 | val loss=0.013509, nmse(dB)=-13.6491 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@163: val loss=0.013509, val nmse(dB)=-13.649075
# [164/500] train loss=0.053773, nmse(dB)=-7.6788 | val loss=0.013444, nmse(dB)=-13.6790 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@164: val loss=0.013444, val nmse(dB)=-13.679000
# [165/500] train loss=0.054253, nmse(dB)=-7.7209 | val loss=0.013388, nmse(dB)=-13.7054 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@165: val loss=0.013388, val nmse(dB)=-13.705434
# [166/500] train loss=0.054790, nmse(dB)=-7.7336 | val loss=0.013310, nmse(dB)=-13.7435 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@166: val loss=0.013310, val nmse(dB)=-13.743490
# [167/500] train loss=0.055862, nmse(dB)=-7.6285 | val loss=0.013226, nmse(dB)=-13.7850 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@167: val loss=0.013226, val nmse(dB)=-13.784952
# [168/500] train loss=0.053110, nmse(dB)=-7.7403 | val loss=0.013159, nmse(dB)=-13.8195 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@168: val loss=0.013159, val nmse(dB)=-13.819550
# [169/500] train loss=0.054548, nmse(dB)=-7.7456 | val loss=0.013100, nmse(dB)=-13.8498 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@169: val loss=0.013100, val nmse(dB)=-13.849773
# [170/500] train loss=0.056263, nmse(dB)=-7.5751 | val loss=0.013027, nmse(dB)=-13.8885 | 49.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@170: val loss=0.013027, val nmse(dB)=-13.888494
# [171/500] train loss=0.053526, nmse(dB)=-7.8167 | val loss=0.012953, nmse(dB)=-13.9277 | 49.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@171: val loss=0.012953, val nmse(dB)=-13.927725
# [172/500] train loss=0.052898, nmse(dB)=-7.8414 | val loss=0.012892, nmse(dB)=-13.9609 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@172: val loss=0.012892, val nmse(dB)=-13.960930
# [173/500] train loss=0.053455, nmse(dB)=-7.7613 | val loss=0.012845, nmse(dB)=-13.9856 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@173: val loss=0.012845, val nmse(dB)=-13.985625
# [174/500] train loss=0.053523, nmse(dB)=-7.7896 | val loss=0.012814, nmse(dB)=-14.0016 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@174: val loss=0.012814, val nmse(dB)=-14.001587
# [175/500] train loss=0.052987, nmse(dB)=-7.8110 | val loss=0.012769, nmse(dB)=-14.0244 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@175: val loss=0.012769, val nmse(dB)=-14.024361
# [176/500] train loss=0.053953, nmse(dB)=-7.7882 | val loss=0.012712, nmse(dB)=-14.0542 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@176: val loss=0.012712, val nmse(dB)=-14.054239
# [177/500] train loss=0.052978, nmse(dB)=-7.7812 | val loss=0.012646, nmse(dB)=-14.0897 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@177: val loss=0.012646, val nmse(dB)=-14.089704
# [178/500] train loss=0.053897, nmse(dB)=-7.7305 | val loss=0.012595, nmse(dB)=-14.1182 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@178: val loss=0.012595, val nmse(dB)=-14.118187
# [179/500] train loss=0.053562, nmse(dB)=-7.7590 | val loss=0.012546, nmse(dB)=-14.1461 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@179: val loss=0.012546, val nmse(dB)=-14.146103
# [180/500] train loss=0.052468, nmse(dB)=-7.8681 | val loss=0.012498, nmse(dB)=-14.1724 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@180: val loss=0.012498, val nmse(dB)=-14.172394
# [181/500] train loss=0.054070, nmse(dB)=-7.7581 | val loss=0.012458, nmse(dB)=-14.1944 | 49.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@181: val loss=0.012458, val nmse(dB)=-14.194364
# [182/500] train loss=0.052882, nmse(dB)=-7.8006 | val loss=0.012423, nmse(dB)=-14.2149 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@182: val loss=0.012423, val nmse(dB)=-14.214897
# [183/500] train loss=0.056600, nmse(dB)=-7.5584 | val loss=0.012388, nmse(dB)=-14.2360 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@183: val loss=0.012388, val nmse(dB)=-14.236012
# [184/500] train loss=0.053879, nmse(dB)=-7.6887 | val loss=0.012357, nmse(dB)=-14.2547 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@184: val loss=0.012357, val nmse(dB)=-14.254692
# [185/500] train loss=0.053530, nmse(dB)=-7.7410 | val loss=0.012325, nmse(dB)=-14.2738 | 49.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@185: val loss=0.012325, val nmse(dB)=-14.273801
# [186/500] train loss=0.053448, nmse(dB)=-7.8506 | val loss=0.012300, nmse(dB)=-14.2883 | 49.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@186: val loss=0.012300, val nmse(dB)=-14.288341
# [187/500] train loss=0.053752, nmse(dB)=-7.7953 | val loss=0.012280, nmse(dB)=-14.3002 | 49.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@187: val loss=0.012280, val nmse(dB)=-14.300219
# [188/500] train loss=0.051342, nmse(dB)=-7.9652 | val loss=0.012258, nmse(dB)=-14.3127 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@188: val loss=0.012258, val nmse(dB)=-14.312705
# [189/500] train loss=0.053757, nmse(dB)=-7.8591 | val loss=0.012225, nmse(dB)=-14.3320 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@189: val loss=0.012225, val nmse(dB)=-14.332032
# [190/500] train loss=0.052480, nmse(dB)=-7.9367 | val loss=0.012178, nmse(dB)=-14.3594 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@190: val loss=0.012178, val nmse(dB)=-14.359380
# [191/500] train loss=0.053104, nmse(dB)=-7.8250 | val loss=0.012133, nmse(dB)=-14.3865 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@191: val loss=0.012133, val nmse(dB)=-14.386516
# [192/500] train loss=0.053667, nmse(dB)=-7.8832 | val loss=0.012095, nmse(dB)=-14.4090 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@192: val loss=0.012095, val nmse(dB)=-14.409047
# [193/500] train loss=0.052867, nmse(dB)=-7.8848 | val loss=0.012064, nmse(dB)=-14.4273 | 49.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@193: val loss=0.012064, val nmse(dB)=-14.427348
# [194/500] train loss=0.052551, nmse(dB)=-7.8955 | val loss=0.012037, nmse(dB)=-14.4430 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@194: val loss=0.012037, val nmse(dB)=-14.443035
# [195/500] train loss=0.052801, nmse(dB)=-7.8534 | val loss=0.012008, nmse(dB)=-14.4600 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@195: val loss=0.012008, val nmse(dB)=-14.459986
# [196/500] train loss=0.052670, nmse(dB)=-7.8311 | val loss=0.011977, nmse(dB)=-14.4806 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@196: val loss=0.011977, val nmse(dB)=-14.480601
# [197/500] train loss=0.052585, nmse(dB)=-7.8739 | val loss=0.011938, nmse(dB)=-14.5057 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@197: val loss=0.011938, val nmse(dB)=-14.505744
# [198/500] train loss=0.051845, nmse(dB)=-7.9379 | val loss=0.011912, nmse(dB)=-14.5218 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@198: val loss=0.011912, val nmse(dB)=-14.521816
# [199/500] train loss=0.051603, nmse(dB)=-7.8981 | val loss=0.011893, nmse(dB)=-14.5338 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@199: val loss=0.011893, val nmse(dB)=-14.533791
# [200/500] train loss=0.053144, nmse(dB)=-7.8692 | val loss=0.011868, nmse(dB)=-14.5494 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@200: val loss=0.011868, val nmse(dB)=-14.549368
# [201/500] train loss=0.054635, nmse(dB)=-7.7040 | val loss=0.011845, nmse(dB)=-14.5654 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@201: val loss=0.011845, val nmse(dB)=-14.565422
# [202/500] train loss=0.052470, nmse(dB)=-7.9343 | val loss=0.011831, nmse(dB)=-14.5758 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@202: val loss=0.011831, val nmse(dB)=-14.575779
# [203/500] train loss=0.052916, nmse(dB)=-7.8489 | val loss=0.011812, nmse(dB)=-14.5890 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@203: val loss=0.011812, val nmse(dB)=-14.589045
# [204/500] train loss=0.053226, nmse(dB)=-7.8259 | val loss=0.011795, nmse(dB)=-14.6011 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@204: val loss=0.011795, val nmse(dB)=-14.601149
# [205/500] train loss=0.052252, nmse(dB)=-7.9263 | val loss=0.011776, nmse(dB)=-14.6132 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@205: val loss=0.011776, val nmse(dB)=-14.613199
# [206/500] train loss=0.052590, nmse(dB)=-7.8289 | val loss=0.011756, nmse(dB)=-14.6252 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@206: val loss=0.011756, val nmse(dB)=-14.625223
# [207/500] train loss=0.052123, nmse(dB)=-7.9137 | val loss=0.011744, nmse(dB)=-14.6316 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@207: val loss=0.011744, val nmse(dB)=-14.631633
# [208/500] train loss=0.053784, nmse(dB)=-7.7709 | val loss=0.011720, nmse(dB)=-14.6461 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@208: val loss=0.011720, val nmse(dB)=-14.646057
# [209/500] train loss=0.050117, nmse(dB)=-8.0702 | val loss=0.011689, nmse(dB)=-14.6657 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@209: val loss=0.011689, val nmse(dB)=-14.665745
# [210/500] train loss=0.053201, nmse(dB)=-7.7556 | val loss=0.011662, nmse(dB)=-14.6847 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@210: val loss=0.011662, val nmse(dB)=-14.684740
# [211/500] train loss=0.051641, nmse(dB)=-7.9903 | val loss=0.011648, nmse(dB)=-14.6950 | 49.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@211: val loss=0.011648, val nmse(dB)=-14.695043
# [212/500] train loss=0.051961, nmse(dB)=-7.8949 | val loss=0.011632, nmse(dB)=-14.7076 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@212: val loss=0.011632, val nmse(dB)=-14.707579
# [213/500] train loss=0.051563, nmse(dB)=-8.0226 | val loss=0.011613, nmse(dB)=-14.7202 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@213: val loss=0.011613, val nmse(dB)=-14.720177
# [214/500] train loss=0.052446, nmse(dB)=-7.8917 | val loss=0.011588, nmse(dB)=-14.7371 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@214: val loss=0.011588, val nmse(dB)=-14.737128
# [215/500] train loss=0.052561, nmse(dB)=-7.8788 | val loss=0.011562, nmse(dB)=-14.7548 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@215: val loss=0.011562, val nmse(dB)=-14.754766
# [216/500] train loss=0.050861, nmse(dB)=-8.0097 | val loss=0.011540, nmse(dB)=-14.7701 | 50.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@216: val loss=0.011540, val nmse(dB)=-14.770084
# [217/500] train loss=0.052742, nmse(dB)=-7.8736 | val loss=0.011525, nmse(dB)=-14.7816 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@217: val loss=0.011525, val nmse(dB)=-14.781629
# [218/500] train loss=0.051040, nmse(dB)=-8.0389 | val loss=0.011516, nmse(dB)=-14.7910 | 48.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@218: val loss=0.011516, val nmse(dB)=-14.791016
# [219/500] train loss=0.052291, nmse(dB)=-7.8985 | val loss=0.011509, nmse(dB)=-14.7972 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@219: val loss=0.011509, val nmse(dB)=-14.797221
# [220/500] train loss=0.053179, nmse(dB)=-7.8404 | val loss=0.011497, nmse(dB)=-14.8058 | 49.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@220: val loss=0.011497, val nmse(dB)=-14.805830
# [221/500] train loss=0.052652, nmse(dB)=-7.9233 | val loss=0.011482, nmse(dB)=-14.8147 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@221: val loss=0.011482, val nmse(dB)=-14.814724
# [222/500] train loss=0.051782, nmse(dB)=-8.0082 | val loss=0.011465, nmse(dB)=-14.8253 | 49.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@222: val loss=0.011465, val nmse(dB)=-14.825256
# [223/500] train loss=0.053749, nmse(dB)=-7.8098 | val loss=0.011446, nmse(dB)=-14.8377 | 49.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@223: val loss=0.011446, val nmse(dB)=-14.837743
# [224/500] train loss=0.051698, nmse(dB)=-7.9692 | val loss=0.011430, nmse(dB)=-14.8488 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@224: val loss=0.011430, val nmse(dB)=-14.848816
# [225/500] train loss=0.051176, nmse(dB)=-7.9967 | val loss=0.011417, nmse(dB)=-14.8586 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@225: val loss=0.011417, val nmse(dB)=-14.858647
# [226/500] train loss=0.053069, nmse(dB)=-7.8152 | val loss=0.011418, nmse(dB)=-14.8595 | 49.5s
# [227/500] train loss=0.051913, nmse(dB)=-7.9904 | val loss=0.011424, nmse(dB)=-14.8557 | 49.2s
# [228/500] train loss=0.052757, nmse(dB)=-7.9054 | val loss=0.011425, nmse(dB)=-14.8563 | 48.0s
# [229/500] train loss=0.052911, nmse(dB)=-7.8749 | val loss=0.011411, nmse(dB)=-14.8675 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@229: val loss=0.011411, val nmse(dB)=-14.867515
# [230/500] train loss=0.053373, nmse(dB)=-7.8782 | val loss=0.011401, nmse(dB)=-14.8755 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@230: val loss=0.011401, val nmse(dB)=-14.875537
# [231/500] train loss=0.051372, nmse(dB)=-7.9564 | val loss=0.011393, nmse(dB)=-14.8807 | 49.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@231: val loss=0.011393, val nmse(dB)=-14.880742
# [232/500] train loss=0.051906, nmse(dB)=-7.9848 | val loss=0.011385, nmse(dB)=-14.8864 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@232: val loss=0.011385, val nmse(dB)=-14.886432
# [233/500] train loss=0.052880, nmse(dB)=-7.8847 | val loss=0.011374, nmse(dB)=-14.8932 | 49.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@233: val loss=0.011374, val nmse(dB)=-14.893165
# [234/500] train loss=0.051671, nmse(dB)=-7.9569 | val loss=0.011361, nmse(dB)=-14.9004 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@234: val loss=0.011361, val nmse(dB)=-14.900440
# [235/500] train loss=0.050584, nmse(dB)=-8.0415 | val loss=0.011356, nmse(dB)=-14.9029 | 49.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@235: val loss=0.011356, val nmse(dB)=-14.902887
# [236/500] train loss=0.050586, nmse(dB)=-8.0971 | val loss=0.011353, nmse(dB)=-14.9050 | 49.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@236: val loss=0.011353, val nmse(dB)=-14.905044
# [237/500] train loss=0.051859, nmse(dB)=-7.9484 | val loss=0.011351, nmse(dB)=-14.9080 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@237: val loss=0.011351, val nmse(dB)=-14.908048
# [238/500] train loss=0.053914, nmse(dB)=-7.8298 | val loss=0.011350, nmse(dB)=-14.9091 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@238: val loss=0.011350, val nmse(dB)=-14.909139
# [239/500] train loss=0.050738, nmse(dB)=-8.0341 | val loss=0.011350, nmse(dB)=-14.9095 | 49.1s
# [240/500] train loss=0.052258, nmse(dB)=-7.9372 | val loss=0.011342, nmse(dB)=-14.9168 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@240: val loss=0.011342, val nmse(dB)=-14.916821
# ...
# [372/500] train loss=0.050263, nmse(dB)=-8.1168 | val loss=0.011043, nmse(dB)=-15.1501 | 48.7s
# [373/500] train loss=0.049627, nmse(dB)=-8.1344 | val loss=0.011041, nmse(dB)=-15.1525 | 48.4s
# [374/500] train loss=0.051561, nmse(dB)=-7.9478 | val loss=0.011038, nmse(dB)=-15.1549 | 49.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@374: val loss=0.011038, val nmse(dB)=-15.154854
# [375/500] train loss=0.051232, nmse(dB)=-8.0550 | val loss=0.011037, nmse(dB)=-15.1549 | 49.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@375: val loss=0.011037, val nmse(dB)=-15.154904
# [376/500] train loss=0.052843, nmse(dB)=-7.9368 | val loss=0.011036, nmse(dB)=-15.1553 | 47.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@376: val loss=0.011036, val nmse(dB)=-15.155339
# [377/500] train loss=0.050829, nmse(dB)=-8.0360 | val loss=0.011035, nmse(dB)=-15.1559 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@377: val loss=0.011035, val nmse(dB)=-15.155877
# [378/500] train loss=0.051038, nmse(dB)=-8.1064 | val loss=0.011034, nmse(dB)=-15.1558 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@378: val loss=0.011034, val nmse(dB)=-15.155832
# [379/500] train loss=0.050623, nmse(dB)=-8.0821 | val loss=0.011034, nmse(dB)=-15.1557 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@379: val loss=0.011034, val nmse(dB)=-15.155734
# [380/500] train loss=0.052371, nmse(dB)=-7.9870 | val loss=0.011034, nmse(dB)=-15.1556 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@380: val loss=0.011034, val nmse(dB)=-15.155626
# [381/500] train loss=0.051404, nmse(dB)=-8.0088 | val loss=0.011033, nmse(dB)=-15.1564 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@381: val loss=0.011033, val nmse(dB)=-15.156392
# [382/500] train loss=0.051543, nmse(dB)=-8.0835 | val loss=0.011032, nmse(dB)=-15.1572 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@382: val loss=0.011032, val nmse(dB)=-15.157195
# [383/500] train loss=0.050913, nmse(dB)=-8.1028 | val loss=0.011030, nmse(dB)=-15.1584 | 48.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@383: val loss=0.011030, val nmse(dB)=-15.158422
# [384/500] train loss=0.052180, nmse(dB)=-8.0374 | val loss=0.011029, nmse(dB)=-15.1595 | 47.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@384: val loss=0.011029, val nmse(dB)=-15.159503
# [385/500] train loss=0.052087, nmse(dB)=-7.9770 | val loss=0.011028, nmse(dB)=-15.1605 | 49.5s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@385: val loss=0.011028, val nmse(dB)=-15.160514
# [386/500] train loss=0.051479, nmse(dB)=-7.9968 | val loss=0.011028, nmse(dB)=-15.1604 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@386: val loss=0.011028, val nmse(dB)=-15.160423
# [387/500] train loss=0.049833, nmse(dB)=-8.1653 | val loss=0.011028, nmse(dB)=-15.1603 | 48.2s
# [388/500] train loss=0.052372, nmse(dB)=-8.0105 | val loss=0.011027, nmse(dB)=-15.1604 | 48.8s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@388: val loss=0.011027, val nmse(dB)=-15.160399
# [389/500] train loss=0.049832, nmse(dB)=-8.1241 | val loss=0.011028, nmse(dB)=-15.1598 | 49.1s
# [390/500] train loss=0.050142, nmse(dB)=-8.1459 | val loss=0.011029, nmse(dB)=-15.1598 | 48.4s
# [391/500] train loss=0.049529, nmse(dB)=-8.1308 | val loss=0.011027, nmse(dB)=-15.1611 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@391: val loss=0.011027, val nmse(dB)=-15.161125
# [392/500] train loss=0.050898, nmse(dB)=-8.0980 | val loss=0.011026, nmse(dB)=-15.1627 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@392: val loss=0.011026, val nmse(dB)=-15.162651
# [393/500] train loss=0.049868, nmse(dB)=-8.1825 | val loss=0.011024, nmse(dB)=-15.1641 | 49.1s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@393: val loss=0.011024, val nmse(dB)=-15.164107
# [394/500] train loss=0.050041, nmse(dB)=-8.1200 | val loss=0.011024, nmse(dB)=-15.1647 | 49.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@394: val loss=0.011024, val nmse(dB)=-15.164698
# [395/500] train loss=0.049868, nmse(dB)=-8.1739 | val loss=0.011024, nmse(dB)=-15.1642 | 48.4s
# [396/500] train loss=0.052571, nmse(dB)=-7.9862 | val loss=0.011025, nmse(dB)=-15.1642 | 49.0s
# [397/500] train loss=0.051875, nmse(dB)=-7.9975 | val loss=0.011024, nmse(dB)=-15.1652 | 48.7s
# [398/500] train loss=0.050908, nmse(dB)=-8.1225 | val loss=0.011023, nmse(dB)=-15.1665 | 48.7s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@398: val loss=0.011023, val nmse(dB)=-15.166532
# [399/500] train loss=0.050761, nmse(dB)=-8.0769 | val loss=0.011020, nmse(dB)=-15.1682 | 49.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@399: val loss=0.011020, val nmse(dB)=-15.168185
# [400/500] train loss=0.052112, nmse(dB)=-8.0249 | val loss=0.011018, nmse(dB)=-15.1703 | 48.6s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@400: val loss=0.011018, val nmse(dB)=-15.170296
# [401/500] train loss=0.050665, nmse(dB)=-8.0497 | val loss=0.011016, nmse(dB)=-15.1718 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@401: val loss=0.011016, val nmse(dB)=-15.171782
# [402/500] train loss=0.049908, nmse(dB)=-8.1455 | val loss=0.011014, nmse(dB)=-15.1728 | 48.4s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@402: val loss=0.011014, val nmse(dB)=-15.172781
# [403/500] train loss=0.050348, nmse(dB)=-8.0886 | val loss=0.011015, nmse(dB)=-15.1726 | 49.0s
# [404/500] train loss=0.050405, nmse(dB)=-8.1227 | val loss=0.011015, nmse(dB)=-15.1724 | 48.2s
# [405/500] train loss=0.050603, nmse(dB)=-8.0536 | val loss=0.011015, nmse(dB)=-15.1725 | 48.4s
# [406/500] train loss=0.049127, nmse(dB)=-8.2033 | val loss=0.011016, nmse(dB)=-15.1720 | 48.0s
# [407/500] train loss=0.050707, nmse(dB)=-8.0386 | val loss=0.011016, nmse(dB)=-15.1714 | 48.9s
# [408/500] train loss=0.051996, nmse(dB)=-8.0119 | val loss=0.011017, nmse(dB)=-15.1711 | 48.7s
# [409/500] train loss=0.052327, nmse(dB)=-7.8992 | val loss=0.011016, nmse(dB)=-15.1717 | 48.7s
# [410/500] train loss=0.050326, nmse(dB)=-8.1836 | val loss=0.011015, nmse(dB)=-15.1722 | 48.3s
# [411/500] train loss=0.051009, nmse(dB)=-8.0850 | val loss=0.011014, nmse(dB)=-15.1725 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@411: val loss=0.011014, val nmse(dB)=-15.172470
# [412/500] train loss=0.051720, nmse(dB)=-8.0050 | val loss=0.011014, nmse(dB)=-15.1728 | 48.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@412: val loss=0.011014, val nmse(dB)=-15.172849
# [413/500] train loss=0.049626, nmse(dB)=-8.1358 | val loss=0.011014, nmse(dB)=-15.1728 | 48.2s
# [414/500] train loss=0.050474, nmse(dB)=-8.1035 | val loss=0.011015, nmse(dB)=-15.1724 | 49.0s
# [415/500] train loss=0.050042, nmse(dB)=-8.1869 | val loss=0.011015, nmse(dB)=-15.1724 | 48.6s
# [416/500] train loss=0.052358, nmse(dB)=-7.9123 | val loss=0.011015, nmse(dB)=-15.1725 | 48.9s
# [417/500] train loss=0.050784, nmse(dB)=-8.0561 | val loss=0.011015, nmse(dB)=-15.1722 | 48.2s
# [418/500] train loss=0.051670, nmse(dB)=-8.0221 | val loss=0.011016, nmse(dB)=-15.1717 | 49.1s
# [419/500] train loss=0.050322, nmse(dB)=-8.1302 | val loss=0.011016, nmse(dB)=-15.1712 | 48.0s
# [420/500] train loss=0.051807, nmse(dB)=-7.9782 | val loss=0.011016, nmse(dB)=-15.1712 | 48.4s
# [421/500] train loss=0.050758, nmse(dB)=-8.1019 | val loss=0.011016, nmse(dB)=-15.1709 | 48.7s
# [422/500] train loss=0.051108, nmse(dB)=-8.0353 | val loss=0.011016, nmse(dB)=-15.1708 | 48.7s
# [423/500] train loss=0.050647, nmse(dB)=-8.0790 | val loss=0.011016, nmse(dB)=-15.1712 | 49.2s
# [424/500] train loss=0.050558, nmse(dB)=-8.0872 | val loss=0.011015, nmse(dB)=-15.1718 | 48.7s
# [425/500] train loss=0.050193, nmse(dB)=-8.1500 | val loss=0.011014, nmse(dB)=-15.1721 | 48.6s
# [426/500] train loss=0.052202, nmse(dB)=-7.9691 | val loss=0.011013, nmse(dB)=-15.1728 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@426: val loss=0.011013, val nmse(dB)=-15.172789
# [427/500] train loss=0.049264, nmse(dB)=-8.2087 | val loss=0.011013, nmse(dB)=-15.1733 | 49.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@427: val loss=0.011013, val nmse(dB)=-15.173335
# [428/500] train loss=0.051152, nmse(dB)=-8.0141 | val loss=0.011012, nmse(dB)=-15.1739 | 49.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@428: val loss=0.011012, val nmse(dB)=-15.173907
# [429/500] train loss=0.049158, nmse(dB)=-8.2436 | val loss=0.011012, nmse(dB)=-15.1740 | 48.2s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@429: val loss=0.011012, val nmse(dB)=-15.173996
# [430/500] train loss=0.050827, nmse(dB)=-8.0965 | val loss=0.011011, nmse(dB)=-15.1743 | 48.3s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@430: val loss=0.011011, val nmse(dB)=-15.174270
# [431/500] train loss=0.048756, nmse(dB)=-8.1992 | val loss=0.011010, nmse(dB)=-15.1749 | 48.9s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@431: val loss=0.011010, val nmse(dB)=-15.174929
# [432/500] train loss=0.051415, nmse(dB)=-7.9945 | val loss=0.011010, nmse(dB)=-15.1752 | 50.0s
#   ↳ saved best_LWM2_multi_model_finetune_scene100.pt | best@432: val loss=0.011010, val nmse(dB)=-15.175214
# [433/500] train loss=0.050998, nmse(dB)=-8.0878 | val loss=0.011010, nmse(dB)=-15.1752 | 48.7s
# [434/500] train loss=0.050278, nmse(dB)=-8.0995 | val loss=0.011010, nmse(dB)=-15.1753 | 49.5s
# [435/500] train loss=0.048513, nmse(dB)=-8.2227 | val loss=0.011011, nmse(dB)=-15.1753 | 49.0s
# [436/500] train loss=0.050269, nmse(dB)=-8.0921 | val loss=0.011011, nmse(dB)=-15.1755 | 48.7s
# [437/500] train loss=0.051687, nmse(dB)=-7.9960 | val loss=0.011011, nmse(dB)=-15.1756 | 49.7s
# [438/500] train loss=0.052745, nmse(dB)=-7.9695 | val loss=0.011011, nmse(dB)=-15.1755 | 48.7s
# [439/500] train loss=0.051001, nmse(dB)=-8.0587 | val loss=0.011011, nmse(dB)=-15.1756 | 49.0s
# [440/500] train loss=0.050706, nmse(dB)=-8.1135 | val loss=0.011012, nmse(dB)=-15.1753 | 48.8s
# [441/500] train loss=0.051459, nmse(dB)=-8.0461 | val loss=0.011012, nmse(dB)=-15.1752 | 47.9s
# [442/500] train loss=0.051574, nmse(dB)=-8.0159 | val loss=0.011012, nmse(dB)=-15.1751 | 48.1s
# [443/500] train loss=0.050035, nmse(dB)=-8.1693 | val loss=0.011012, nmse(dB)=-15.1751 | 48.7s
# [444/500] train loss=0.050693, nmse(dB)=-8.1372 | val loss=0.011012, nmse(dB)=-15.1750 | 48.7s
# [445/500] train loss=0.052393, nmse(dB)=-7.8971 | val loss=0.011012, nmse(dB)=-15.1751 | 48.6s
# [446/500] train loss=0.049245, nmse(dB)=-8.1658 | val loss=0.011012, nmse(dB)=-15.1749 | 48.6s
# [447/500] train loss=0.049898, nmse(dB)=-8.1431 | val loss=0.011012, nmse(dB)=-15.1747 | 49.2s
# [448/500] train loss=0.049821, nmse(dB)=-8.1301 | val loss=0.011012, nmse(dB)=-15.1746 | 48.5s
# [449/500] train loss=0.049913, nmse(dB)=-8.1644 | val loss=0.011012, nmse(dB)=-15.1746 | 48.4s
# [450/500] train loss=0.050536, nmse(dB)=-8.1036 | val loss=0.011012, nmse(dB)=-15.1746 | 47.9s
# [451/500] train loss=0.050861, nmse(dB)=-8.0561 | val loss=0.011011, nmse(dB)=-15.1746 | 48.4s
# [452/500] train loss=0.052067, nmse(dB)=-7.9478 | val loss=0.011011, nmse(dB)=-15.1745 | 48.4s
# [453/500] train loss=0.051821, nmse(dB)=-7.9609 | val loss=0.011011, nmse(dB)=-15.1745 | 48.3s
# [454/500] train loss=0.050925, nmse(dB)=-8.0857 | val loss=0.011011, nmse(dB)=-15.1744 | 49.2s
# [455/500] train loss=0.051848, nmse(dB)=-8.0012 | val loss=0.011011, nmse(dB)=-15.1742 | 48.2s
# [456/500] train loss=0.052217, nmse(dB)=-7.9866 | val loss=0.011011, nmse(dB)=-15.1743 | 48.4s
# [457/500] train loss=0.049687, nmse(dB)=-8.1100 | val loss=0.011011, nmse(dB)=-15.1745 | 48.5s
# [458/500] train loss=0.050101, nmse(dB)=-8.0844 | val loss=0.011011, nmse(dB)=-15.1745 | 48.7s
# [459/500] train loss=0.051719, nmse(dB)=-8.0672 | val loss=0.011011, nmse(dB)=-15.1745 | 48.6s
# [460/500] train loss=0.051050, nmse(dB)=-8.0627 | val loss=0.011011, nmse(dB)=-15.1747 | 48.8s
# [461/500] train loss=0.052276, nmse(dB)=-7.9968 | val loss=0.011011, nmse(dB)=-15.1749 | 48.7s
# [462/500] train loss=0.050471, nmse(dB)=-8.0958 | val loss=0.011011, nmse(dB)=-15.1749 | 48.4s
# [463/500] train loss=0.050814, nmse(dB)=-8.0996 | val loss=0.011011, nmse(dB)=-15.1749 | 48.4s
# [464/500] train loss=0.048864, nmse(dB)=-8.1662 | val loss=0.011011, nmse(dB)=-15.1750 | 48.9s
# [465/500] train loss=0.050818, nmse(dB)=-8.1027 | val loss=0.011011, nmse(dB)=-15.1749 | 48.6s
# [466/500] train loss=0.052649, nmse(dB)=-7.9149 | val loss=0.011012, nmse(dB)=-15.1748 | 49.0s
# [467/500] train loss=0.049566, nmse(dB)=-8.1720 | val loss=0.011012, nmse(dB)=-15.1748 | 48.6s
# [468/500] train loss=0.050644, nmse(dB)=-8.1013 | val loss=0.011011, nmse(dB)=-15.1750 | 49.3s
# [469/500] train loss=0.051062, nmse(dB)=-8.0399 | val loss=0.011011, nmse(dB)=-15.1752 | 48.8s
# [470/500] train loss=0.052098, nmse(dB)=-8.0162 | val loss=0.011011, nmse(dB)=-15.1754 | 48.5s
# [471/500] train loss=0.051509, nmse(dB)=-7.9945 | val loss=0.011011, nmse(dB)=-15.1756 | 49.3s
# [472/500] train loss=0.051116, nmse(dB)=-8.0382 | val loss=0.011011, nmse(dB)=-15.1757 | 49.2s
# [473/500] train loss=0.048475, nmse(dB)=-8.2385 | val loss=0.011011, nmse(dB)=-15.1758 | 48.6s
# [474/500] train loss=0.049177, nmse(dB)=-8.1913 | val loss=0.011011, nmse(dB)=-15.1759 | 48.4s
# [475/500] train loss=0.051863, nmse(dB)=-8.0260 | val loss=0.011011, nmse(dB)=-15.1761 | 49.4s
# [476/500] train loss=0.052067, nmse(dB)=-7.9523 | val loss=0.011011, nmse(dB)=-15.1761 | 49.0s
# [477/500] train loss=0.050657, nmse(dB)=-8.1433 | val loss=0.011010, nmse(dB)=-15.1762 | 49.2s
# [478/500] train loss=0.051130, nmse(dB)=-8.1035 | val loss=0.011010, nmse(dB)=-15.1762 | 48.8s
# [479/500] train loss=0.052164, nmse(dB)=-7.9670 | val loss=0.011010, nmse(dB)=-15.1762 | 48.2s
# [480/500] train loss=0.052250, nmse(dB)=-7.9580 | val loss=0.011010, nmse(dB)=-15.1763 | 48.5s
# [481/500] train loss=0.052001, nmse(dB)=-7.9668 | val loss=0.011010, nmse(dB)=-15.1763 | 49.1s
# [482/500] train loss=0.050899, nmse(dB)=-8.1345 | val loss=0.011010, nmse(dB)=-15.1763 | 49.4s
# [483/500] train loss=0.051894, nmse(dB)=-7.9923 | val loss=0.011010, nmse(dB)=-15.1763 | 47.9s
# [484/500] train loss=0.049551, nmse(dB)=-8.1963 | val loss=0.011010, nmse(dB)=-15.1763 | 48.8s
# [485/500] train loss=0.051094, nmse(dB)=-8.0463 | val loss=0.011010, nmse(dB)=-15.1764 | 49.3s
# [486/500] train loss=0.051754, nmse(dB)=-8.0017 | val loss=0.011010, nmse(dB)=-15.1764 | 48.8s
# [487/500] train loss=0.049972, nmse(dB)=-8.1335 | val loss=0.011010, nmse(dB)=-15.1764 | 48.5s
# [488/500] train loss=0.050145, nmse(dB)=-8.1052 | val loss=0.011010, nmse(dB)=-15.1764 | 48.4s
# [489/500] train loss=0.050986, nmse(dB)=-8.1090 | val loss=0.011010, nmse(dB)=-15.1764 | 48.4s
# [490/500] train loss=0.052607, nmse(dB)=-7.8970 | val loss=0.011010, nmse(dB)=-15.1764 | 48.0s
# [491/500] train loss=0.052386, nmse(dB)=-7.9373 | val loss=0.011010, nmse(dB)=-15.1764 | 49.0s
# [492/500] train loss=0.051336, nmse(dB)=-8.0216 | val loss=0.011010, nmse(dB)=-15.1765 | 49.8s
# [493/500] train loss=0.051125, nmse(dB)=-8.0432 | val loss=0.011010, nmse(dB)=-15.1765 | 48.8s
# [494/500] train loss=0.051508, nmse(dB)=-8.0907 | val loss=0.011010, nmse(dB)=-15.1765 | 48.4s
# [495/500] train loss=0.051511, nmse(dB)=-7.9764 | val loss=0.011010, nmse(dB)=-15.1765 | 48.4s
# [496/500] train loss=0.052071, nmse(dB)=-8.0490 | val loss=0.011010, nmse(dB)=-15.1765 | 49.4s
# [497/500] train loss=0.053207, nmse(dB)=-7.8752 | val loss=0.011010, nmse(dB)=-15.1765 | 48.8s
# [498/500] train loss=0.051376, nmse(dB)=-8.0807 | val loss=0.011010, nmse(dB)=-15.1765 | 48.3s
# [499/500] train loss=0.050728, nmse(dB)=-8.0882 | val loss=0.011010, nmse(dB)=-15.1765 | 48.7s
# [500/500] train loss=0.050403, nmse(dB)=-8.1158 | val loss=0.011010, nmse(dB)=-15.1765 | 48.1s
#
# === Training Summary ===
# Total time: 24367.9s (6h 46m 7.9s)
# Best epoch: 432 | best val loss=0.011010, best val nmse(dB)=-15.175214
# Log saved to: /mnt/ssd_7t_2/Deepverse/lwm2_multi_modal_scene100.txt

# %% [markdown]
# # 런타임 체크

# %%
ch, img, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# y abs mean: 0.49987226724624634
# y abs max : 0.9942880272865295
# y power   : 0.30005112290382385
# yhat abs mean: 0.4936944246292114
# yhat abs max : 0.5661839246749878
# yhat power   : 0.2443172186613083

# %% [markdown]
# # 데이터 입력 형태

# %%
cam_files=sensor.files
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("N(cam_files)  :", len(cam_files))
print("N(min)        :", min(len(comm_frames), len(cam_files)))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

print("\n=== one batch shapes ===")
ch, img, y = next(iter(train_loader))
print("ch :", tuple(ch.shape), " -> (B,T,F_in)")
print("img:", tuple(img.shape), " -> (B,3,224,224)")
print("y  :", tuple(y.shape), " -> (B,F_out)")
with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat:", tuple(yhat.shape), " -> (B,F_out)")
print("this forward predicted vectors:", yhat.shape[0], "(=B)")
print("each vector predicts elements:", yhat.shape[1], "(=F_out)")
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# N(cam_files)  : 7012
# N(min)        : 100
# past_len      : 16
# len(ds)       : 84
# len(train_ds) : 51
# len(val_ds)   : 17
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B,T,F_in)
# img: (32, 16, 3, 224, 224)  -> (B,3,224,224)
# y  : (32, 2048)  -> (B,F_out)
# yhat: (32, 2048)  -> (B,F_out)
# this forward predicted vectors: 32 (=B)
# each vector predicts elements: 2048 (=F_out)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
