# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# #  Import

# %%
import os
import sys

import numpy as  np
from lwm_multi_model import multi_modal_lwm  # 클래스 import
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Settings

# %%
# Scenes 2000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(1000))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print("현재 사용 중인 장치:", device)
# Out:
# 현재 사용 중인 장치: cuda:1

# %% [markdown]
# # Generate a dataset

# %%
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (8.34s)
# Generating radar dataset: ⏳ In progress
# Generating radar dataset: ✅ Completed (1994.90s)

# %% [markdown]
# # location dataset
#  지금 실험에서는 안쓰임

# %%
# comm = dataset.comm_dataset
# location =  comm

# location = [
#     {
#         "bs_loc": d["bs_loc"],                      # (3,)
#         "ue_loc": np.asarray(d["ue_loc"]).squeeze() # (3,)  (원래 (1,3)이면 squeeze)
#     }
#     for row in comm.data      # row: [dict] 형태
#     for d in row              # d: dict
# ]

# print(ue_location)  #)

# %% [markdown]
# # communication  dataset

# %%
# UE 정보
comm = dataset.comm_dataset
ch = comm.data[0][0]['ue'][0]
print(ch.coeffs.shape)
# Out:
# (1, 16, 64)

# %% [markdown]
# # preprocessing

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, eps=1e-16):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex128)
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1)
    return H

# %%
# 사용예시
H = preprocess_channel_coeffs_minmax(ch.coeffs, r_min=-0.5, r_max=0.5, i_min=-0.5, i_max=0.5)
print(H.shape)  # (1, 16, 128) 64 subcar
# Out:
# torch.Size([1, 16, 128])

# %% [markdown]
# ### image dataset

# %%
sensor = dataset.camera_dataset.sensors["unit1_cam1"]
path0 = sensor.files[0]
img = Image.open(path0).convert("RGB")
arr = np.array(img)

print("path:", path0)
print("PIL size (W,H):", img.size)
print("np shape:", arr.shape, "dtype:", arr.dtype)  # 보통 (H,W,3), uint8
# Out:
# path: scenarios/DT31/RGB_images/unit1_cam1/7.png
# PIL size (W,H): (1920, 1080)
# np shape: (1080, 1920, 3) dtype: uint8

# %%
IMG_SIZE = 224

def preprocess_img(path, img_size=IMG_SIZE):
    # 1) load (H,W,3) uint8
    img = Image.open(path).convert("RGB")
    arr = np.array(img)

    # 2) numpy -> torch, (3,H,W), float64
    x = torch.from_numpy(arr).permute(2, 0, 1).contiguous().double()  # (3,H,W), double for ImageNet stats
    x = x / 255.0  # [0,1]

    # 3) add batch dim -> (1,3,H,W)
    x = x.unsqueeze(0)

    # 4) resize -> (1,3,224,224)
    x = F.interpolate(x, size=(img_size, img_size),
                      mode="bilinear", align_corners=False)

    # 5) normalize (ImageNet)
    mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float64).view(1, 3, 1, 1)
    std  = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float64).view(1, 3, 1, 1)
    x = (x - mean) / std


    return x  # (1,3,224,224) on device

# %%
# 사용예시
cd = dataset.camera_dataset
sensor = cd.sensors['unit1_cam1']
path0 = sensor.files[0]
img = preprocess_img(path0)
print(img.shape, img.device)  # torch.Size([1,3,224,224]) cuda:0
print(path0)
# Out:
# torch.Size([1, 3, 224, 224]) cpu
# scenarios/DT31/RGB_images/unit1_cam1/7.png

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class MultiModalNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, cam_files, ue_idx=0, past_len=16, device=device,
                 # Arguments for statistical values (initialized with default values)
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        
        self.comm_frames = comm_frames
        self.cam_files = list(cam_files)
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device
        
        # Save statistical values
        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = min(len(self.comm_frames), len(self.cam_files))
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2 

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1. Image Past (Apply Preprocessing)
        img_list = []
        for k in range(t - self.past_len + 1, t + 1):
            img_path = self.cam_files[k]
            img_k = preprocess_img(img_path).squeeze(0)
            img_list.append(img_k)
        img = torch.stack(img_list, dim=0)  # Shape: (past_len

        
        # 2. Channel Past (Apply Scaling)
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            # Use the newly defined Min-Max preprocessing function
            h = preprocess_channel_coeffs_minmax(
                coeffs_np, 
                self.r_min, self.r_max, self.i_min, self.i_max
            ).reshape(-1)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)

        # 3. Target (Apply Scaling) - Target must also be scaled for model training!
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_minmax(
            coeffs_np_next, 
            self.r_min, self.r_max, self.i_min, self.i_max
            
        ).reshape(-1)

        return channel_past, img, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
sensor = dataset.camera_dataset.sensors["unit1_cam1"]

ds = MultiModalNextStepDatasetGPU(
    comm_frames=comm_frames,
    cam_files=sensor.files,
    ue_idx=0,
    past_len=16,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   # ✅ 의미 없음 (이미 GPU)
)

ch, img, y = next(iter(loader))
print(ch.shape, img.shape, y.shape)
print(ch.device, img.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 16, 3, 224, 224]) torch.Size([8, 2048])
# cpu cpu cpu

# %% [markdown]
# # Fine-tuning
# data shape 맞추기 위해

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from lwm_multi_model import multi_modal_lwm  # 너가 올린 backbone

class FinetuneChannelPredictor(nn.Module):
    """
    직접 구현한 lwm_multi_model(channel + image)에 맞는 파인튜닝 모델
    Input:
      ch:  (B, T, F_in)  e.g., (B,16,2048) 16: past Length, 2048: feature dim
      img: (B, 3, 224, 224)
    Output:
      yhat: (B, F_out)  e.g., (B,2048)
    """
    def __init__(
        self,
        backbone: nn.Module,
        F_in: int,
        F_out: int,
        pool: str = "last",          # "last" or "mean"
        freeze_image: bool = False,
        freeze_backbone: bool = False,
        element_length: int = 16,    # 채널 벡터 차원 (backbone 기대값)
        d_model: int = 64            # backbone 내부 feature dim
    ):
        super().__init__()
        self.backbone = backbone
        self.pool = pool

        # backbone이 기대하는 channel feature dim = ELEMENT_LENGTH
        # (backbone 내부 Channel_Embedding: Linear(ELEMENT_LENGTH -> D_MODEL))
        if element_length is None:
            element_length = backbone.channel_embedding.element_length
        if d_model is None:
            d_model = backbone.channel_embedding.d_model

        # 입력 차원 정렬: F_in -> ELEMENT_LENGTH
        self.in_proj = nn.Sequential(
            nn.Linear(F_in, 512),
            nn.GELU(),
            nn.Linear(512, 128),
            nn.GELU(),
            nn.Linear(128, element_length)
        )

        # 출력 head: D_MODEL -> F_out
        self.head = nn.Linear(d_model, F_out)

        if freeze_image:
            for p in self.backbone.image_embedding.parameters():
                p.requires_grad = False

        if freeze_backbone:
            for p in self.backbone.parameters():
                p.requires_grad = False
            # 그래도 projection/head는 학습되게 다시 켜기
            for p in self.in_proj.parameters():
                p.requires_grad = True
            for p in self.head.parameters():
                p.requires_grad = True

    def forward(self, ch, img):
        # ch: (B,T,F_in) -> (B,T,ELEMENT_LENGTH)
        ch = self.in_proj(ch)

        # backbone: (B,T,D_MODEL)
        tokens = self.backbone(ch, img)

        # pooling -> (B,D_MODEL)
        if self.pool == "last":
            z = tokens[:, -1, :]
        elif self.pool == "mean":
            z = tokens.mean(dim=1)
        else:
            raise ValueError(f"Unknown pool={self.pool}")

        # head -> (B,F_out)
        yhat = self.head(z)
        return yhat

# %% [markdown]
# ## NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# %% [markdown]
# # Train/Val split

# %%
# ---- (Optional but recommended) hard leakage check ----
def used_frames_for_ds_indices(ds, ds_indices):
    used = set()
    for i in ds_indices:
        t = ds.valid_start + i
        # inputs use [t-T+1 .. t], target uses (t+1)
        used.update(range(t - T + 1, t + 2))
    return used

# %%
n_total = len(ds)
T = ds.past_len  # = past_len

# ---- choose k so that train=3k, val=k and NO frame-overlap is possible ----
k_max = (n_total - T) // 4
if k_max <= 0:
    raise ValueError(
        f"Not enough data for strict non-overlap 3:1. "
        f"n_total={n_total}, past_len(T)={T}. "
        f"Try increasing scenes or decreasing past_len."
    )

k = k_max               # use as much data as possible under constraints
n_val = k
n_train = 3 * k

train_idx = list(range(0, n_train))
val_idx   = list(range(n_total - n_val, n_total))

print("n_total:", n_total, "T:", T)
print("train samples:", len(train_idx), "val samples:", len(val_idx), "ratio:", len(train_idx)/len(val_idx))

# ---- min/max ONLY from train (same as your original policy) ----
train_ts = [ds.valid_start + i for i in train_idx]

(real_min, real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_ts, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=4)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=4)

F_in = 2048


overlap = used_frames_for_ds_indices(ds, train_idx).intersection(
          used_frames_for_ds_indices(ds, val_idx))
print("frame-overlap count:", len(overlap))
assert len(overlap) == 0, "Leakage detected: train/val share frames!"

# Verify
ch, img, y = next(iter(train_loader))
F_out = y.shape[-1]
print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")
# Out:
# n_total: 984 T: 16
# train samples: 726 val samples: 242 ratio: 3.0
# Calculating min/max over training set...
# Done. rmin=-1.599962900128591e-06, rmax=1.5977824378041814e-06, imin=-1.6400732538319291e-06, imax=1.579536450012739e-06
# Dataset statistical values set in the dataset.
# frame-overlap count: 0
# === Data Check ===
# y stats | min: 0.0848, max: 0.9364
# If scaling worked correctly, values should be within [0, 1].

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
cam_files = list(dataset.camera_dataset.sensors["unit1_cam1"].files)

print("len(comm_frames):", len(comm_frames))
print("len(cam_files):", len(cam_files))
print("first comm frame keys:", list(comm_frames[0].keys()))
print("first cam file:", cam_files[0])
# Out:
# len(comm_frames): 1000
# len(cam_files): 1114
# first comm frame keys: ['bs_loc', 'ue', 'ue_loc', 'bs']
# first cam file: scenarios/DT31/RGB_images/unit1_cam1/7.png

# %%
len(val_loader)
# Out:
# 8

# %% [markdown]
# # Model generate and also check

# %%
# 배치 하나로 F_in/F_out 자동 확정
ch, img, y = next(iter(train_loader))
F_in  = ch.shape[-1]
F_out = y.shape[-1]
print("Detected:", "F_in=", F_in, "F_out=", F_out)
print("Batch devices:", ch.device, img.device, y.device)

# backbone + finetune model
backbone = multi_modal_lwm().to(device)

model = FinetuneChannelPredictor(
    backbone=backbone,
    F_in=F_in,
    F_out=F_out,
    pool="last",            # "mean"으로 바꿔도 됨
    freeze_image=False,     # 원하면 True (이미지 인코더 고정)
    freeze_backbone=False,  # 원하면 True (proj/head만 학습)
    element_length=16,
    d_model=64
).to(device).double()

# sanity forward
model.eval()
with torch.no_grad():
    # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
    yhat = model(ch.to(device), img.to(device))
print("yhat:", yhat.shape, "y:", y.shape)
# Out:
# Detected: F_in= 2048 F_out= 2048
# Batch devices: cpu cpu cpu
# yhat: torch.Size([32, 2048]) y: torch.Size([32, 2048])

# %%
# 1. 모델 생성 (백본 포함)
model = FinetuneChannelPredictor(
    backbone=backbone,
    F_in=F_in,
    F_out=F_out,
    element_length=16,
    d_model=64
).to(device)

# 2. 전체 모델을 Double(float64)로 강제 변환
# 이 한 줄이 실행되어야 'in_proj'와 'head' 가중치가 모두 float64가 됩니다.
model.double() 

# 3. 타입 불일치 확인 (디버깅용)
print(f"Input Type: {ch.dtype}")                # torch.float64 여야 함
print(f"Model weight Type: {model.head.weight.dtype}") # torch.float64 여야 함

# 4. 연산 수행
model.eval()
with torch.no_grad():
    # 데이터와 모델 가중치 타입을 일치시켜서 입력
    # .to(device) 뒤에 .double()을 붙여서 확실히 합니다.
    yhat = model(ch.to(device).double(), img.to(device).double())
# Out:
# Input Type: torch.float64
# Model weight Type: torch.float64

# %% [markdown]
# # Train/ Eval 함수 (grad clip)

# %%
def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        # Dataset이 이미 cuda 텐서를 반환하더라도 안전하게 유지
        ch = ch.to(device, non_blocking=True).double()
        img = img.to(device, non_blocking=True).double()
        y  = y.to(device, non_blocking=True).double()

        optimizer.zero_grad(set_to_none=True)

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)
        
        loss.backward()

        if grad_clip is not None and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        optimizer.step()
        
        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)


@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        ch = ch.to(device, non_blocking=True).double()
        img = img.to(device, non_blocking=True).double()
        y  = y.to(device, non_blocking=True).double()

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

# %% [markdown]
# #  Optiimizer  / Scheduler 설정

# %%
# requires_grad=True인 파라미터만 학습
trainable_params = [p for p in model.parameters() if p.requires_grad]
print("trainable params:", sum(p.numel() for p in trainable_params))

optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# (선택) cosine scheduler
epochs = 600
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
# Out:
# trainable params: 2499120

# %% [markdown]
# # 학습 루프 + checkpoint 저장

# %%
best_val = float("inf")
best_val_nmse = None
best_epoch = None

t_train0 = time.time()  # ✅ 전체 학습 시작 시간

for epoch in range(1, epochs + 1):
    t0 = time.time()

    tr_loss, tr_nmse = train_one_epoch(model, train_loader, optimizer, device=device, grad_clip=1.0)
    va_loss, va_nmse = evaluate(model, val_loader, device=device)

    scheduler.step()

    dt = time.time() - t0
    print(
        f"[{epoch:02d}/{epochs}] "
        f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
        f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
        f"{dt:.1f}s"
    )

    if va_loss < best_val:
        best_val = va_loss
        best_val_nmse = va_nmse
        best_epoch = epoch

        torch.save(
            {
                "epoch": epoch,
                "model_state": model.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "F_in": F_in,
                "F_out": F_out,
                "best_val_loss": best_val,
                "best_val_nmse_db": best_val_nmse,
            },
            "best_finetune.pt"
        )
        print(f"  ↳ saved best_finetune.pt | best@{best_epoch}: val loss={best_val:.6f}, val nmse(dB)={best_val_nmse:.4f}")

# ✅ 전체 학습 종료 후 총 시간 출력
total_sec = time.time() - t_train0
h = int(total_sec // 3600)
m = int((total_sec % 3600) // 60)
s = total_sec % 60

print("\n=== Training Summary ===")
print(f"Total time: {total_sec:.1f}s ({h}h {m}m {s:.1f}s)")
print(f"Best epoch: {best_epoch} | best val loss={best_val:.6f}, best val nmse(dB)={best_val_nmse:.4f}")
# Out:
# [01/600] train loss=0.422623, nmse(dB)=1.8920 | val loss=0.312822, nmse(dB)=0.6202 | 531.2s
#   ↳ saved best_finetune.pt | best@1: val loss=0.312822, val nmse(dB)=0.6202
# [02/600] train loss=0.288885, nmse(dB)=0.2658 | val loss=0.229333, nmse(dB)=-0.7371 | 531.9s
#   ↳ saved best_finetune.pt | best@2: val loss=0.229333, val nmse(dB)=-0.7371
# [03/600] train loss=0.231032, nmse(dB)=-0.7020 | val loss=0.186683, nmse(dB)=-1.6388 | 527.1s
#   ↳ saved best_finetune.pt | best@3: val loss=0.186683, val nmse(dB)=-1.6388
# [04/600] train loss=0.186458, nmse(dB)=-1.6374 | val loss=0.147288, nmse(dB)=-2.6806 | 529.8s
#   ↳ saved best_finetune.pt | best@4: val loss=0.147288, val nmse(dB)=-2.6806
# [05/600] train loss=0.143142, nmse(dB)=-2.7971 | val loss=0.109478, nmse(dB)=-3.9939 | 531.5s
#   ↳ saved best_finetune.pt | best@5: val loss=0.109478, val nmse(dB)=-3.9939
# [06/600] train loss=0.104573, nmse(dB)=-4.1861 | val loss=0.077798, nmse(dB)=-5.5287 | 528.5s
#   ↳ saved best_finetune.pt | best@6: val loss=0.077798, val nmse(dB)=-5.5287
# [07/600] train loss=0.074239, nmse(dB)=-5.7045 | val loss=0.054707, nmse(dB)=-7.1547 | 531.3s
#   ↳ saved best_finetune.pt | best@7: val loss=0.054707, val nmse(dB)=-7.1547
# [08/600] train loss=0.053362, nmse(dB)=-7.2043 | val loss=0.039494, nmse(dB)=-8.7350 | 532.5s
#   ↳ saved best_finetune.pt | best@8: val loss=0.039494, val nmse(dB)=-8.7350
# [09/600] train loss=0.039953, nmse(dB)=-8.5382 | val loss=0.030182, nmse(dB)=-10.1433 | 531.2s
#   ↳ saved best_finetune.pt | best@9: val loss=0.030182, val nmse(dB)=-10.1433
# [10/600] train loss=0.031802, nmse(dB)=-9.6606 | val loss=0.024891, nmse(dB)=-11.2623 | 530.9s
#   ↳ saved best_finetune.pt | best@10: val loss=0.024891, val nmse(dB)=-11.2623
# [11/600] train loss=0.027192, nmse(dB)=-10.4610 | val loss=0.022039, nmse(dB)=-12.0628 | 530.6s
#   ↳ saved best_finetune.pt | best@11: val loss=0.022039, val nmse(dB)=-12.0628
# [12/600] train loss=0.024530, nmse(dB)=-11.0258 | val loss=0.020539, nmse(dB)=-12.5840 | 528.8s
#   ↳ saved best_finetune.pt | best@12: val loss=0.020539, val nmse(dB)=-12.5840
# [13/600] train loss=0.023067, nmse(dB)=-11.3763 | val loss=0.019747, nmse(dB)=-12.9049 | 529.4s
#   ↳ saved best_finetune.pt | best@13: val loss=0.019747, val nmse(dB)=-12.9049
# [14/600] train loss=0.022271, nmse(dB)=-11.5674 | val loss=0.019342, nmse(dB)=-13.0861 | 530.4s
#   ↳ saved best_finetune.pt | best@14: val loss=0.019342, val nmse(dB)=-13.0861
# [15/600] train loss=0.021756, nmse(dB)=-11.7095 | val loss=0.019193, nmse(dB)=-13.1603 | 526.7s
#   ↳ saved best_finetune.pt | best@15: val loss=0.019193, val nmse(dB)=-13.1603
# [16/600] train loss=0.021313, nmse(dB)=-11.8423 | val loss=0.019041, nmse(dB)=-13.2340 | 527.3s
#   ↳ saved best_finetune.pt | best@16: val loss=0.019041, val nmse(dB)=-13.2340
# [17/600] train loss=0.020942, nmse(dB)=-11.9486 | val loss=0.019006, nmse(dB)=-13.2543 | 531.0s
#   ↳ saved best_finetune.pt | best@17: val loss=0.019006, val nmse(dB)=-13.2543
# [18/600] train loss=0.020682, nmse(dB)=-12.0341 | val loss=0.018957, nmse(dB)=-13.2736 | 531.3s
#   ↳ saved best_finetune.pt | best@18: val loss=0.018957, val nmse(dB)=-13.2736
# [19/600] train loss=0.020379, nmse(dB)=-12.1060 | val loss=0.018963, nmse(dB)=-13.2707 | 530.0s
# [20/600] train loss=0.020251, nmse(dB)=-12.1625 | val loss=0.018929, nmse(dB)=-13.2937 | 532.4s
#   ↳ saved best_finetune.pt | best@20: val loss=0.018929, val nmse(dB)=-13.2937
# [21/600] train loss=0.019921, nmse(dB)=-12.2516 | val loss=0.018940, nmse(dB)=-13.2853 | 530.5s
# [22/600] train loss=0.019910, nmse(dB)=-12.2577 | val loss=0.018966, nmse(dB)=-13.2725 | 531.0s
# [23/600] train loss=0.019658, nmse(dB)=-12.3519 | val loss=0.018939, nmse(dB)=-13.2804 | 531.2s
# [24/600] train loss=0.019547, nmse(dB)=-12.3861 | val loss=0.018939, nmse(dB)=-13.2866 | 531.4s
# [25/600] train loss=0.019422, nmse(dB)=-12.4193 | val loss=0.018934, nmse(dB)=-13.2884 | 528.0s
# [26/600] train loss=0.019228, nmse(dB)=-12.4885 | val loss=0.018902, nmse(dB)=-13.2979 | 528.2s
#   ↳ saved best_finetune.pt | best@26: val loss=0.018902, val nmse(dB)=-13.2979
# [27/600] train loss=0.019336, nmse(dB)=-12.5044 | val loss=0.018920, nmse(dB)=-13.2924 | 531.3s
# [28/600] train loss=0.019156, nmse(dB)=-12.5198 | val loss=0.018933, nmse(dB)=-13.2846 | 526.6s
# [29/600] train loss=0.019014, nmse(dB)=-12.5566 | val loss=0.018917, nmse(dB)=-13.2960 | 525.2s
# [30/600] train loss=0.018875, nmse(dB)=-12.6130 | val loss=0.018928, nmse(dB)=-13.2883 | 528.1s
# [31/600] train loss=0.018896, nmse(dB)=-12.6299 | val loss=0.018936, nmse(dB)=-13.2818 | 531.8s
# [32/600] train loss=0.018717, nmse(dB)=-12.6688 | val loss=0.018934, nmse(dB)=-13.2896 | 530.6s
# [33/600] train loss=0.018709, nmse(dB)=-12.7001 | val loss=0.018909, nmse(dB)=-13.2956 | 522.5s
# [34/600] train loss=0.018609, nmse(dB)=-12.7418 | val loss=0.018922, nmse(dB)=-13.2974 | 526.9s
# [35/600] train loss=0.018553, nmse(dB)=-12.7594 | val loss=0.018924, nmse(dB)=-13.2967 | 527.0s
# [36/600] train loss=0.018426, nmse(dB)=-12.8096 | val loss=0.018920, nmse(dB)=-13.2890 | 528.1s
# [37/600] train loss=0.018375, nmse(dB)=-12.8240 | val loss=0.018926, nmse(dB)=-13.2908 | 526.3s
# [38/600] train loss=0.018339, nmse(dB)=-12.8243 | val loss=0.018911, nmse(dB)=-13.3000 | 526.0s
# [39/600] train loss=0.018259, nmse(dB)=-12.8639 | val loss=0.018923, nmse(dB)=-13.2930 | 526.7s
# [40/600] train loss=0.018248, nmse(dB)=-12.8993 | val loss=0.018903, nmse(dB)=-13.3038 | 526.8s
# [41/600] train loss=0.018176, nmse(dB)=-12.9092 | val loss=0.018911, nmse(dB)=-13.2986 | 532.3s
# [42/600] train loss=0.018185, nmse(dB)=-12.9098 | val loss=0.018894, nmse(dB)=-13.3091 | 528.3s
#   ↳ saved best_finetune.pt | best@42: val loss=0.018894, val nmse(dB)=-13.3091
# [43/600] train loss=0.018019, nmse(dB)=-12.9601 | val loss=0.018927, nmse(dB)=-13.2955 | 527.8s
# [44/600] train loss=0.018103, nmse(dB)=-12.9388 | val loss=0.018919, nmse(dB)=-13.2953 | 532.1s
# [45/600] train loss=0.018073, nmse(dB)=-12.9591 | val loss=0.018912, nmse(dB)=-13.2994 | 529.9s
# [46/600] train loss=0.018004, nmse(dB)=-12.9891 | val loss=0.018943, nmse(dB)=-13.2859 | 535.3s
# [47/600] train loss=0.017861, nmse(dB)=-13.0222 | val loss=0.018908, nmse(dB)=-13.2990 | 531.5s
# [48/600] train loss=0.017955, nmse(dB)=-13.0215 | val loss=0.018905, nmse(dB)=-13.3018 | 528.7s
# [49/600] train loss=0.017921, nmse(dB)=-13.0147 | val loss=0.018936, nmse(dB)=-13.2885 | 526.7s
# [50/600] train loss=0.017852, nmse(dB)=-13.0417 | val loss=0.018908, nmse(dB)=-13.3018 | 525.2s
# [51/600] train loss=0.017802, nmse(dB)=-13.0584 | val loss=0.018909, nmse(dB)=-13.3007 | 530.6s
# [52/600] train loss=0.017852, nmse(dB)=-13.0653 | val loss=0.018914, nmse(dB)=-13.3013 | 532.7s
# [53/600] train loss=0.017724, nmse(dB)=-13.0979 | val loss=0.018904, nmse(dB)=-13.3026 | 528.4s
# [54/600] train loss=0.017785, nmse(dB)=-13.1022 | val loss=0.018916, nmse(dB)=-13.2974 | 531.0s
# [55/600] train loss=0.017649, nmse(dB)=-13.1173 | val loss=0.018923, nmse(dB)=-13.2958 | 524.0s
# [56/600] train loss=0.017626, nmse(dB)=-13.1353 | val loss=0.018902, nmse(dB)=-13.3036 | 527.2s
# [57/600] train loss=0.017592, nmse(dB)=-13.1570 | val loss=0.018921, nmse(dB)=-13.2999 | 528.0s
# [58/600] train loss=0.017499, nmse(dB)=-13.1766 | val loss=0.018905, nmse(dB)=-13.3034 | 540.0s
# [59/600] train loss=0.017552, nmse(dB)=-13.1968 | val loss=0.018922, nmse(dB)=-13.2979 | 539.3s
# [60/600] train loss=0.017574, nmse(dB)=-13.1609 | val loss=0.018912, nmse(dB)=-13.2952 | 540.7s
# [61/600] train loss=0.017530, nmse(dB)=-13.1786 | val loss=0.018906, nmse(dB)=-13.3009 | 536.7s
# [62/600] train loss=0.017487, nmse(dB)=-13.2126 | val loss=0.018902, nmse(dB)=-13.3057 | 538.3s
# [63/600] train loss=0.017433, nmse(dB)=-13.2234 | val loss=0.018920, nmse(dB)=-13.2932 | 538.4s
# [64/600] train loss=0.017486, nmse(dB)=-13.2136 | val loss=0.018900, nmse(dB)=-13.3071 | 537.2s
# [65/600] train loss=0.017395, nmse(dB)=-13.2454 | val loss=0.018891, nmse(dB)=-13.3079 | 537.4s
#   ↳ saved best_finetune.pt | best@65: val loss=0.018891, val nmse(dB)=-13.3079
# [66/600] train loss=0.017517, nmse(dB)=-13.2354 | val loss=0.018912, nmse(dB)=-13.3035 | 539.5s
# [67/600] train loss=0.017397, nmse(dB)=-13.2582 | val loss=0.018896, nmse(dB)=-13.3025 | 538.7s
# [68/600] train loss=0.017356, nmse(dB)=-13.2602 | val loss=0.018914, nmse(dB)=-13.2987 | 536.2s
# [69/600] train loss=0.017432, nmse(dB)=-13.2573 | val loss=0.018900, nmse(dB)=-13.3056 | 536.0s
# [70/600] train loss=0.017365, nmse(dB)=-13.2826 | val loss=0.018882, nmse(dB)=-13.3119 | 535.7s
#   ↳ saved best_finetune.pt | best@70: val loss=0.018882, val nmse(dB)=-13.3119
# [71/600] train loss=0.017349, nmse(dB)=-13.2744 | val loss=0.018903, nmse(dB)=-13.3012 | 536.1s
# [72/600] train loss=0.017303, nmse(dB)=-13.2805 | val loss=0.018921, nmse(dB)=-13.2973 | 536.2s
# [73/600] train loss=0.017368, nmse(dB)=-13.2778 | val loss=0.018905, nmse(dB)=-13.2987 | 530.6s
# [74/600] train loss=0.017312, nmse(dB)=-13.2851 | val loss=0.018898, nmse(dB)=-13.3030 | 531.4s
# [75/600] train loss=0.017294, nmse(dB)=-13.3189 | val loss=0.018896, nmse(dB)=-13.3010 | 536.9s
# [76/600] train loss=0.017259, nmse(dB)=-13.3120 | val loss=0.018896, nmse(dB)=-13.3036 | 535.0s
# [77/600] train loss=0.017224, nmse(dB)=-13.3458 | val loss=0.018928, nmse(dB)=-13.2944 | 534.3s
# [78/600] train loss=0.017233, nmse(dB)=-13.3291 | val loss=0.018879, nmse(dB)=-13.3125 | 527.9s
#   ↳ saved best_finetune.pt | best@78: val loss=0.018879, val nmse(dB)=-13.3125
# [79/600] train loss=0.017176, nmse(dB)=-13.3426 | val loss=0.018903, nmse(dB)=-13.3053 | 533.7s
# [80/600] train loss=0.017253, nmse(dB)=-13.3181 | val loss=0.018904, nmse(dB)=-13.3029 | 536.1s
# [81/600] train loss=0.017278, nmse(dB)=-13.3336 | val loss=0.018907, nmse(dB)=-13.3014 | 536.4s
# [82/600] train loss=0.017167, nmse(dB)=-13.3547 | val loss=0.018910, nmse(dB)=-13.3010 | 533.2s
# [83/600] train loss=0.017149, nmse(dB)=-13.3720 | val loss=0.018890, nmse(dB)=-13.3090 | 536.0s
# [84/600] train loss=0.017187, nmse(dB)=-13.3683 | val loss=0.018907, nmse(dB)=-13.3047 | 531.5s
# [85/600] train loss=0.017139, nmse(dB)=-13.3717 | val loss=0.018880, nmse(dB)=-13.3086 | 533.5s
# [86/600] train loss=0.017238, nmse(dB)=-13.3604 | val loss=0.018882, nmse(dB)=-13.3102 | 533.2s
# [87/600] train loss=0.017101, nmse(dB)=-13.3939 | val loss=0.018887, nmse(dB)=-13.3109 | 534.1s
# [88/600] train loss=0.017142, nmse(dB)=-13.3723 | val loss=0.018899, nmse(dB)=-13.3052 | 531.3s
# [89/600] train loss=0.017044, nmse(dB)=-13.4060 | val loss=0.018914, nmse(dB)=-13.3026 | 534.3s
# [90/600] train loss=0.017131, nmse(dB)=-13.3896 | val loss=0.018875, nmse(dB)=-13.3151 | 536.8s
#   ↳ saved best_finetune.pt | best@90: val loss=0.018875, val nmse(dB)=-13.3151
# [91/600] train loss=0.017173, nmse(dB)=-13.3864 | val loss=0.018903, nmse(dB)=-13.3045 | 536.3s
# [92/600] train loss=0.017157, nmse(dB)=-13.3897 | val loss=0.018899, nmse(dB)=-13.3002 | 528.0s
# [93/600] train loss=0.017166, nmse(dB)=-13.4013 | val loss=0.018891, nmse(dB)=-13.3074 | 534.0s
# [94/600] train loss=0.017130, nmse(dB)=-13.4023 | val loss=0.018878, nmse(dB)=-13.3111 | 533.2s
# [95/600] train loss=0.017072, nmse(dB)=-13.4096 | val loss=0.018884, nmse(dB)=-13.3086 | 528.0s
# [96/600] train loss=0.017049, nmse(dB)=-13.4167 | val loss=0.018917, nmse(dB)=-13.2970 | 535.2s
# [97/600] train loss=0.017039, nmse(dB)=-13.4186 | val loss=0.018882, nmse(dB)=-13.3088 | 532.0s
# [98/600] train loss=0.017090, nmse(dB)=-13.4139 | val loss=0.018905, nmse(dB)=-13.3027 | 532.3s
# [99/600] train loss=0.017083, nmse(dB)=-13.4189 | val loss=0.018901, nmse(dB)=-13.3038 | 535.3s
# [100/600] train loss=0.017051, nmse(dB)=-13.4318 | val loss=0.018885, nmse(dB)=-13.3121 | 528.2s
# [101/600] train loss=0.017045, nmse(dB)=-13.4423 | val loss=0.018908, nmse(dB)=-13.3032 | 532.3s
# [102/600] train loss=0.017002, nmse(dB)=-13.4406 | val loss=0.018885, nmse(dB)=-13.3126 | 528.5s
# [103/600] train loss=0.016954, nmse(dB)=-13.4546 | val loss=0.018884, nmse(dB)=-13.3119 | 533.4s
# [104/600] train loss=0.017020, nmse(dB)=-13.4451 | val loss=0.018908, nmse(dB)=-13.3025 | 534.6s
# [105/600] train loss=0.017002, nmse(dB)=-13.4511 | val loss=0.018883, nmse(dB)=-13.3073 | 528.4s
# [106/600] train loss=0.017128, nmse(dB)=-13.4148 | val loss=0.018902, nmse(dB)=-13.3024 | 528.5s
# [107/600] train loss=0.017020, nmse(dB)=-13.4433 | val loss=0.018901, nmse(dB)=-13.3021 | 527.8s
# [108/600] train loss=0.017035, nmse(dB)=-13.4374 | val loss=0.018903, nmse(dB)=-13.3045 | 535.3s
# [109/600] train loss=0.017015, nmse(dB)=-13.4558 | val loss=0.018896, nmse(dB)=-13.3069 | 533.4s
# [110/600] train loss=0.017050, nmse(dB)=-13.4477 | val loss=0.018894, nmse(dB)=-13.3120 | 532.3s
# [111/600] train loss=0.016934, nmse(dB)=-13.4735 | val loss=0.018918, nmse(dB)=-13.2995 | 528.9s
# [112/600] train loss=0.017102, nmse(dB)=-13.4445 | val loss=0.018908, nmse(dB)=-13.3000 | 527.8s
# [113/600] train loss=0.017076, nmse(dB)=-13.4648 | val loss=0.018900, nmse(dB)=-13.3041 | 529.9s
# [114/600] train loss=0.016998, nmse(dB)=-13.4559 | val loss=0.018907, nmse(dB)=-13.3047 | 534.2s
# [115/600] train loss=0.017046, nmse(dB)=-13.4623 | val loss=0.018900, nmse(dB)=-13.3044 | 530.9s
# [116/600] train loss=0.016930, nmse(dB)=-13.4886 | val loss=0.018879, nmse(dB)=-13.3085 | 530.0s
# [117/600] train loss=0.016976, nmse(dB)=-13.4849 | val loss=0.018877, nmse(dB)=-13.3136 | 530.8s
# [118/600] train loss=0.016962, nmse(dB)=-13.4752 | val loss=0.018893, nmse(dB)=-13.3071 | 528.7s
# [119/600] train loss=0.017022, nmse(dB)=-13.4666 | val loss=0.018877, nmse(dB)=-13.3153 | 535.0s
# [120/600] train loss=0.016922, nmse(dB)=-13.4996 | val loss=0.018893, nmse(dB)=-13.3078 | 531.8s
# [121/600] train loss=0.016898, nmse(dB)=-13.4879 | val loss=0.018882, nmse(dB)=-13.3130 | 529.5s
# [122/600] train loss=0.016936, nmse(dB)=-13.4947 | val loss=0.018909, nmse(dB)=-13.3019 | 529.4s
# [123/600] train loss=0.016897, nmse(dB)=-13.4957 | val loss=0.018894, nmse(dB)=-13.3069 | 533.9s
# [124/600] train loss=0.016896, nmse(dB)=-13.5080 | val loss=0.018894, nmse(dB)=-13.3102 | 529.0s
# [125/600] train loss=0.016915, nmse(dB)=-13.4976 | val loss=0.018884, nmse(dB)=-13.3111 | 535.7s
# [126/600] train loss=0.017008, nmse(dB)=-13.4850 | val loss=0.018885, nmse(dB)=-13.3136 | 530.4s
# [127/600] train loss=0.016947, nmse(dB)=-13.4849 | val loss=0.018888, nmse(dB)=-13.3074 | 530.2s
# [128/600] train loss=0.016950, nmse(dB)=-13.4868 | val loss=0.018898, nmse(dB)=-13.3123 | 529.3s
# [129/600] train loss=0.016928, nmse(dB)=-13.5045 | val loss=0.018885, nmse(dB)=-13.3135 | 535.0s
# [130/600] train loss=0.016949, nmse(dB)=-13.5012 | val loss=0.018911, nmse(dB)=-13.3003 | 535.5s
# [131/600] train loss=0.016870, nmse(dB)=-13.5145 | val loss=0.018887, nmse(dB)=-13.3102 | 532.3s
# [132/600] train loss=0.016889, nmse(dB)=-13.5042 | val loss=0.018884, nmse(dB)=-13.3067 | 536.1s
# [133/600] train loss=0.016956, nmse(dB)=-13.5007 | val loss=0.018900, nmse(dB)=-13.3045 | 540.2s

# %%
ch, img, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# y abs mean: 0.4955256352418395
# y abs max : 1.0
# y power   : 0.28867590466210136
# yhat abs mean: 0.4940550407560659
# yhat abs max : 0.737765158894013
# yhat power   : 0.24701485682841545
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 데이터 입력 및 형태

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("N(cam_files)  :", len(cam_files))
print("N(min)        :", min(len(comm_frames), len(cam_files)))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

print("\n=== one batch shapes ===")
ch, img, y = next(iter(train_loader))
print("ch :", tuple(ch.shape), " -> (B,T,F_in)")
print("img:", tuple(img.shape), " -> (B,3,224,224)")
print("y  :", tuple(y.shape), " -> (B,F_out)")
with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat:", tuple(yhat.shape), " -> (B,F_out)")
print("this forward predicted vectors:", yhat.shape[0], "(=B)")
print("each vector predicts elements:", yhat.shape[1], "(=F_out)")
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# N(cam_files)  : 7012
# N(min)        : 100
# past_len      : 16
# len(ds)       : 84
# len(train_ds) : 63
# len(val_ds)   : 21
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B,T,F_in)
# img: (32, 16, 3, 224, 224)  -> (B,3,224,224)
# y  : (32, 2048)  -> (B,F_out)
# yhat: (32, 2048)  -> (B,F_out)
# this forward predicted vectors: 32 (=B)
# each vector predicts elements: 2048 (=F_out)
