# %%
# !pip install deepverse
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepverse in /home/dlghdbs200/.local/lib/python3.10/site-packages (0.0.4)
# Requirement already satisfied: matplotlib in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepverse) (3.10.3)
# Requirement already satisfied: pandas in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepverse) (2.3.1)
# Requirement already satisfied: numpy in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepverse) (2.2.6)
# Requirement already satisfied: tqdm in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepverse) (4.67.1)
# Requirement already satisfied: scipy in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepverse) (1.15.3)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from deepverse) (5.4.1)
# Requirement already satisfied: natsort in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepverse) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib->deepverse) (1.3.2)
# Requirement already satisfied: pillow>=8 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib->deepverse) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->deepverse) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib->deepverse) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib->deepverse) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib->deepverse) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepverse) (25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepverse) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from pandas->deepverse) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->deepverse) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->deepverse) (1.16.0)

# %%
import deepverse as dv
config_path = f"scenarios/DT31/param/config.m"
dataset = dv.Dataset(config_path)
# Out:
# Warning: scenarios/DT31/RGB_images/unit1_cam1 does not exist.
# Warning: scenarios/DT31/lidar/unit1_lidar1 does not exist.
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.01s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Processing Scenes:   0%|                                                                        | 0/100 [00:00<?, ?it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:   3%|█▉                                                              | 3/100 [00:00<00:03, 25.57it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:   7%|████▍                                                           | 7/100 [00:00<00:03, 28.87it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  11%|██████▉                                                        | 11/100 [00:00<00:02, 30.54it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  15%|█████████▍                                                     | 15/100 [00:00<00:02, 31.67it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  19%|███████████▉                                                   | 19/100 [00:00<00:02, 32.08it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  23%|██████████████▍                                                | 23/100 [00:00<00:02, 32.41it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  27%|█████████████████                                              | 27/100 [00:00<00:02, 32.05it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  31%|███████████████████▌                                           | 31/100 [00:00<00:02, 32.61it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  35%|██████████████████████                                         | 35/100 [00:01<00:02, 32.33it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  39%|████████████████████████▌                                      | 39/100 [00:01<00:01, 32.90it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  43%|███████████████████████████                                    | 43/100 [00:01<00:01, 32.33it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  47%|█████████████████████████████▌                                 | 47/100 [00:01<00:01, 31.35it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# ...
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Processing Scenes:  99%|██████████████████████████████████████████████████████████████▎| 99/100 [00:03<00:00, 31.18it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-UE channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
#
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1-BS channels:   0%|                                                                 | 0/1 [00:00<?, ?it/s]
# Generating comm dataset: ✅ Completed (3.16s)
# Generating radar dataset: ⏳ In progress
# Processing Scenes:   0%|                                                                        | 0/100 [00:00<?, ?it/s]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:09<00:00,  9.05s/it]
# Processing Scenes:   1%|▋                                                               | 1/100 [00:09<15:06,  9.16s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.30s/it]
# Processing Scenes:   2%|█▎                                                              | 2/100 [00:15<12:15,  7.50s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.57s/it]
# Processing Scenes:   3%|█▉                                                              | 3/100 [00:22<11:28,  7.10s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:08<00:00,  8.05s/it]
# Processing Scenes:   4%|██▌                                                             | 4/100 [00:31<12:55,  8.08s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.33s/it]
# Processing Scenes:   5%|███▏                                                            | 5/100 [00:36<11:03,  6.99s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.34s/it]
# Processing Scenes:   6%|███▊                                                            | 6/100 [00:41<09:34,  6.11s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.68s/it]
# Processing Scenes:   7%|████▍                                                           | 7/100 [00:46<09:16,  5.99s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.02s/it]
# Processing Scenes:   8%|█████                                                           | 8/100 [00:50<08:14,  5.38s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.55s/it]
# Processing Scenes:   9%|█████▊                                                          | 9/100 [00:55<07:46,  5.13s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.75s/it]
# Processing Scenes:  10%|██████▎                                                        | 10/100 [01:00<07:32,  5.03s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.47s/it]
# Processing Scenes:  11%|██████▉                                                        | 11/100 [01:05<07:41,  5.18s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.81s/it]
# Processing Scenes:  12%|███████▌                                                       | 12/100 [01:09<07:00,  4.78s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.89s/it]
# Processing Scenes:  13%|████████▏                                                      | 13/100 [01:13<06:34,  4.53s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.51s/it]
# Processing Scenes:  14%|████████▊                                                      | 14/100 [01:17<06:04,  4.24s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.52s/it]
# Processing Scenes:  15%|█████████▍                                                     | 15/100 [01:22<06:34,  4.64s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.59s/it]
# Processing Scenes:  16%|██████████                                                     | 16/100 [01:26<06:04,  4.34s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.44s/it]
# Processing Scenes:  17%|██████████▋                                                    | 17/100 [01:29<05:39,  4.09s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.32s/it]
# Processing Scenes:  18%|███████████▎                                                   | 18/100 [01:33<05:17,  3.87s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.41s/it]
# Processing Scenes:  19%|███████████▉                                                   | 19/100 [01:36<05:03,  3.74s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]
# Generating BS1 channels: 100%|████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.49s/it]
# Processing Scenes:  20%|████████████▌                                                  | 20/100 [01:40<04:54,  3.68s/it]
# Reading ray-tracing:   0%|                                                                        | 0/1 [00:00<?, ?it/s]
#
# Generating BS1 channels:   0%|                                                                    | 0/1 [00:00<?, ?it/s]

# %%
type(dataset)
# Out:
# deepverse.datasets.dataset.Dataset

# %%
len(dataset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 len(dataset)
#
# TypeError: object of type 'Dataset' has no len()

# %%
print(dataset)
# Out:
# <deepverse.datasets.dataset.Dataset object at 0x7a144c172c50>

# %% [markdown]
# # Data shape
# Deepverse DAtaset
#
# [Root / Scenario]<p>
# - dataset.params['dataset_folder'] = "scenarios" <p>
# - dataset.params['scenario'] = "DT31" <p>
# - dataset.scenario_path = "scenarios/DT31"<p>
# - dataset.scenario = ScenarioManage(...)<p>
#
# [Coverage]<p>
# - dataset.params['scenes'] = [1~100] -> here can change "scenarios/DT31/param/config.m"<p>
# - dataset.params['basestations'] = [1]<p>
#
# [Enabled Modalities (Sub-dataset Handles)]
# - dataset.camera_dataset   = CameraDataset(...) # Camera data
# - dataset.lidar_dataset    = LiDARDataset(...)  # LiDAR data
# - dataset.mobility_dataset = MobilityDataset(...)  # mobility/pose/position data
# - dataset.comm_dataset     = CommunicationDataset(...) # wireless communication (OFDM channel) data
# - dataset.radar_dataset    = RadarDataset(...)  # radar (FMCW) data

# %%
dataset.__dict__
# Out:
# {'param_manager': <deepverse.parameter.parameter_manager.ParameterManager at 0x7a144c1726b0>,
#  'params': {'dataset_folder': 'scenarios',
#   'scenario': 'DT31',
#   'scenes': [np.int64(1),
#    np.int64(2),
#    np.int64(3),
#    np.int64(4),
#    np.int64(5),
#    np.int64(6),
#    np.int64(7),
#    np.int64(8),
#    np.int64(9),
#    np.int64(10),
#    np.int64(11),
#    np.int64(12),
#    np.int64(13),
#    np.int64(14),
#    np.int64(15),
#    np.int64(16),
#    np.int64(17),
#    np.int64(18),
#    np.int64(19),
#    np.int64(20),
#    np.int64(21),
#    np.int64(22),
#    np.int64(23),
#    np.int64(24),
#    np.int64(25),
#    np.int64(26),
#    np.int64(27),
#    np.int64(28),
#    np.int64(29),
#    np.int64(30),
#    np.int64(31),
#    np.int64(32),
#    np.int64(33),
#    np.int64(34),
#    np.int64(35),
#    np.int64(36),
#    np.int64(37),
#    np.int64(38),
#    np.int64(39),
#    np.int64(40),
#    np.int64(41),
#    np.int64(42),
#    np.int64(43),
#    np.int64(44),
#    np.int64(45),
#    np.int64(46),
#    np.int64(47),
#    np.int64(48),
#    np.int64(49),
#    np.int64(50),
#    np.int64(51),
#    np.int64(52),
#    np.int64(53),
#    np.int64(54),
#    np.int64(55),
#    np.int64(56),
#    np.int64(57),
#    np.int64(58),
#    np.int64(59),
#    np.int64(60),
#    np.int64(61),
#    np.int64(62),
#    np.int64(63),
#    np.int64(64),
#    np.int64(65),
#    np.int64(66),
#    np.int64(67),
#    np.int64(68),
#    np.int64(69),
#    np.int64(70),
#    np.int64(71),
#    np.int64(72),
#    np.int64(73),
#    np.int64(74),
#    np.int64(75),
#    np.int64(76),
#    np.int64(77),
#    np.int64(78),
#    np.int64(79),
#    np.int64(80),
#    np.int64(81),
#    np.int64(82),
#    np.int64(83),
#    np.int64(84),
#    np.int64(85),
#    np.int64(86),
#    np.int64(87),
#    np.int64(88),
#    np.int64(89),
#    np.int64(90),
#    np.int64(91),
#    np.int64(92),
#    np.int64(93),
#    np.int64(94),
#    np.int64(95),
#    np.int64(96),
#    np.int64(97),
#    np.int64(98),
#    np.int64(99),
#    np.int64(100)],
#   'basestations': [np.int64(1)],
#   'comm': {'enable': True,
#    'bs_antenna': {'shape': [16, 1],
#     'rotation': array([  0.  ,   0.  , -45.04]),
#     'spacing': 0.5,
#     'FoV': [360, 180]},
#    'ue_antenna': {'shape': [1, 1],
#     'rotation': array([0, 0, 0]),
#     'spacing': 0.5,
#     'FoV': [360, 180]},
#    'OFDM': {'bandwidth': 0.05,
#     'subcarriers': 512,
#     'selected_subcarriers': [np.int64(0),
#      np.int64(1),
#      np.int64(2),
#      np.int64(3),
#      np.int64(4),
#      np.int64(5),
#      np.int64(6),
#      np.int64(7)]},
#    'activate_RX_filter': 0,
#    'generate_OFDM_channels': 1,
#    'num_paths': 25,
#    'enable_Doppler': 1},
#   'radar': {'enable': True,
#    'tx_antenna': {'shape': [1, 1],
#     'rotation': array([  0.  ,   0.  , -45.04]),
#     'spacing': 0.5,
#     'FoV': [180, 180]},
#    'rx_antenna': {'shape': [16, 1],
#     'rotation': array([  0.  ,   0.  , -45.04]),
#     'spacing': 0.5,
#     'FoV': [180, 180]},
#    'FMCW': {'chirp_slope': 8014000000000.0,
#     'Fs': 6200000.0,
#     'n_samples_per_chirp': 256,
#     'n_chirps': 256},
#    'num_paths': 50000},
#   'camera': True,
#   'camera_id': ['unit1_cam1'],
#   'lidar': True,
#   'lidar_id': ['unit1_lidar1'],
#   'position': True},
#  'scenario_path': 'scenarios/DT31',
#  'scenario': <deepverse.scenario.scenario_manager.ScenarioManager at 0x7a13cc373f40>,
#  'camera_dataset': <deepverse.datasets.sensor_datasets.CameraDataset at 0x7a13cb991870>,
#  'lidar_dataset': <deepverse.datasets.sensor_datasets.LiDARDataset at 0x7a13cb9905e0>,
#  'mobility_dataset': <deepverse.datasets.sensor_datasets.MobilityDataset at 0x7a13cb991660>,
#  'comm_dataset': <deepverse.datasets.wireless_datasets.CommunicationDataset at 0x7a13cb9904c0>,
#  'radar_dataset': <deepverse.datasets.wireless_datasets.RadarDataset at 0x7a13cb9903a0>}

# %%
dataset.param_manager

# %%
dataset.camera_dataset.__dict__
# Out:
# {'params': {'dataset_folder': 'scenarios',
#   'scenario': 'DT31',
#   'scenes': [np.int64(1),
#    np.int64(2),
#    np.int64(3),
#    np.int64(4),
#    np.int64(5),
#    np.int64(6),
#    np.int64(7),
#    np.int64(8),
#    np.int64(9),
#    np.int64(10),
#    np.int64(11),
#    np.int64(12),
#    np.int64(13),
#    np.int64(14),
#    np.int64(15),
#    np.int64(16),
#    np.int64(17),
#    np.int64(18),
#    np.int64(19),
#    np.int64(20),
#    np.int64(21),
#    np.int64(22),
#    np.int64(23),
#    np.int64(24),
#    np.int64(25),
#    np.int64(26),
#    np.int64(27),
#    np.int64(28),
#    np.int64(29),
#    np.int64(30),
#    np.int64(31),
#    np.int64(32),
#    np.int64(33),
#    np.int64(34),
#    np.int64(35),
#    np.int64(36),
#    np.int64(37),
#    np.int64(38),
#    np.int64(39),
#    np.int64(40),
#    np.int64(41),
#    np.int64(42),
#    np.int64(43),
#    np.int64(44),
#    np.int64(45),
#    np.int64(46),
#    np.int64(47),
#    np.int64(48),
#    np.int64(49),
#    np.int64(50),
#    np.int64(51),
#    np.int64(52),
#    np.int64(53),
#    np.int64(54),
#    np.int64(55),
#    np.int64(56),
#    np.int64(57),
#    np.int64(58),
#    np.int64(59),
#    np.int64(60),
#    np.int64(61),
#    np.int64(62),
#    np.int64(63),
#    np.int64(64),
#    np.int64(65),
#    np.int64(66),
#    np.int64(67),
#    np.int64(68),
#    np.int64(69),
#    np.int64(70),
#    np.int64(71),
#    np.int64(72),
#    np.int64(73),
#    np.int64(74),
#    np.int64(75),
#    np.int64(76),
#    np.int64(77),
#    np.int64(78),
#    np.int64(79),
#    np.int64(80),
#    np.int64(81),
#    np.int64(82),
#    np.int64(83),
#    np.int64(84),
#    np.int64(85),
#    np.int64(86),
#    np.int64(87),
#    np.int64(88),
#    np.int64(89),
#    np.int64(90),
#    np.int64(91),
#    np.int64(92),
#    np.int64(93),
#    np.int64(94),
#    np.int64(95),
#    np.int64(96),
#    np.int64(97),
#    np.int64(98),
#    np.int64(99),
#    np.int64(100)],
#   'basestations': [np.int64(1)],
#   'comm': {'enable': True,
#    'bs_antenna': {'shape': [16, 1],
#     'rotation': array([  0.  ,   0.  , -45.04]),
#     'spacing': 0.5,
#     'FoV': [360, 180]},
#    'ue_antenna': {'shape': [1, 1],
#     'rotation': array([0, 0, 0]),
#     'spacing': 0.5,
#     'FoV': [360, 180]},
#    'OFDM': {'bandwidth': 0.05,
#     'subcarriers': 512,
#     'selected_subcarriers': [np.int64(0),
#      np.int64(1),
#      np.int64(2),
#      np.int64(3),
#      np.int64(4),
#      np.int64(5),
#      np.int64(6),
#      np.int64(7)]},
#    'activate_RX_filter': 0,
#    'generate_OFDM_channels': 1,
#    'num_paths': 25,
#    'enable_Doppler': 1},
#   'radar': {'enable': True,
#    'tx_antenna': {'shape': [1, 1],
#     'rotation': array([  0.  ,   0.  , -45.04]),
#     'spacing': 0.5,
#     'FoV': [180, 180]},
#    'rx_antenna': {'shape': [16, 1],
#     'rotation': array([  0.  ,   0.  , -45.04]),
#     'spacing': 0.5,
#     'FoV': [180, 180]},
#    'FMCW': {'chirp_slope': 8014000000000.0,
#     'Fs': 6200000.0,
#     'n_samples_per_chirp': 256,
#     'n_chirps': 256},
#    'num_paths': 50000},
#   'camera': True,
#   'camera_id': ['unit1_cam1'],
#   'lidar': True,
#   'lidar_id': ['unit1_lidar1'],
#   'position': True},
#  'device_type': 'Camera',
#  'sensors': {},
#  'sensor_id': [],
#  'num_devices': 0,
#  'visualizer': <deepverse.visualizers.image_visualizer.ImageVisualizer at 0x7a13cb990580>}
