# %% [markdown]
# # GRU scene 100
# <br> trainable params : 2692096

# %%
import re
import matplotlib.pyplot as plt

log_path = "gru_scene100.txt"
exp_name = "GRU Scene 100"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -15.2098 at epoch 209/500

# %% [markdown]
# # GRU scene 1000

# %%
import re
import matplotlib.pyplot as plt

log_path = "gru_scene1000.txt"
exp_name = "GRU Scene 1000"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -13.3046 at epoch 69/500

# %% [markdown]
# # lstm scene 100
# <br> trainable params : 3414016

# %%
import re
import matplotlib.pyplot as plt

log_path = "lstm_scene100 .txt"
exp_name = "LSTM Scene 100"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -15.2946 at epoch 147/500

# %% [markdown]
# # lstm scene 1000

# %%
import re
import matplotlib.pyplot as plt

log_path = "lstm_scene1000.txt"
exp_name = "LSTM Scene 1000"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -13.3146 at epoch 71/500

# %% [markdown]
# # lwm1 multi modal
# <br> lwm1의 경우 모델의 크기를 키운 모델
# <br> element length 64
# <br> d_model 128
# <br> projection도 2048 -> 512 -> 256 -> 64
# <br> trainable params: 6374592

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm1_multi_modal_scene100.txt"
exp_name = "lwm1 multi modal Scene 100"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -10.7282 at epoch 100/100

# %% [markdown]
# # lwm2 multi modal
# <br> lwm2의 경우 기존 lwm foundation에서 제공하는 코드이며 모델 크기가 1에 비해 작다
# <br> element length 16
# <br> d_model 64
# <br> projection도 2048 -> 512 -> 128 -> 16 진행
# <br> trainable params: 2499120

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm2_multi_modal_scene100.txt"
exp_name = "lwm2 multi modal Scene 100"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -3.9812 at epoch 98/100

# %% [markdown]
# # only channel lwm1
# <br> lwm1의 경우 모델의 크기를 키운 모델(멀티모달이 아닌 오직 채널만)
# <br> element length 64
# <br> d_model 128
# <br> projection도 2048 -> 512 -> 256 -> 64

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm_model1_scene100.txt"
exp_name = "lwm model1_scene100"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -15.1933 at epoch 394/500

# %% [markdown]
# # only channel lwm2
# <br> lwm2의 경우 기존 lwm foundation에서 제공하는 코드이며 모델 크기가 1에 비해 작다 (멀티모달이 아닌 채널만)
# <br> element length 16
# <br> d_model 64
# <br> projection도 2048 -> 512 -> 128 -> 16 진행
# <br> trainable params: 2499120

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm_model2_scene100.txt"
exp_name = "lwm model2_scene100"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -15.1512 at epoch 481/500

# %% [markdown]
# # lwm1_multi_modal

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm1_multi_modal_scene100.txt"
exp_name = "lwm1 multi modal Scene 100"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -15.2215 at epoch 278/500

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm1_multi_modal_scene1000.txt"
exp_name = "lwm1 multi modal Scene 1000"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -13.3232 at epoch 265/300

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm1_multi_modal_scene7000.txt"
exp_name = "lwm1 multi modal Scene 7000"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -13.8277 at epoch 90/100

# %% [markdown]
# # lwm2_multi_modal

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm2_multi_modal_scene100.txt"
exp_name = "lwm2 multi modal Scene 100"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -15.1765 at epoch 492/500

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm2_multi_modal_scene1000.txt"
exp_name = "lwm2 multi modal Scene 1000"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -13.3236 at epoch 265/300

# %%
import re
import matplotlib.pyplot as plt

log_path = "lwm2_multi_modal_scene7000.txt"
exp_name = "lwm2 multi modal Scene 7000"

pat = re.compile(
    r"\[(\d+)/(\d+)\]\s*"
    r"train loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)\s*\|\s*"
    r"val loss=([0-9.eE+-]+),\s*nmse\(dB\)=([0-9.eE+-]+)"
)

epochs = []
train_losses, val_losses = [], []
train_nmse_db, val_nmse_db = [], []
total_epochs = None

with open(log_path, "r", encoding="utf-8") as f:
    for line in f:
        m = pat.search(line)
        if not m:
            continue

        ep = int(m.group(1))
        total_epochs = int(m.group(2))
        tr_l = float(m.group(3))
        tr_n = float(m.group(4))
        va_l = float(m.group(5))
        va_n = float(m.group(6))

        epochs.append(ep)
        train_losses.append(tr_l)
        val_losses.append(va_l)
        train_nmse_db.append(tr_n)
        val_nmse_db.append(va_n)

if not epochs:
    raise RuntimeError("로그에서 학습 라인을 하나도 못 찾았어. 포맷이 다른지 확인해줘.")

# ---- Plot 1: Loss ----
plt.figure()
plt.plot(epochs, train_losses, label="train loss")
plt.plot(epochs, val_losses, label="val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"{exp_name} - Train vs Val Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Plot 2: NMSE(dB) ----
plt.figure()
plt.plot(epochs, train_nmse_db, label="train nmse (dB)")
plt.plot(epochs, val_nmse_db, label="val nmse (dB)")
plt.xlabel("Epoch")
plt.ylabel("NMSE (dB)")
plt.title(f"{exp_name} - Train vs Val NMSE (dB)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- Best (lowest) Val NMSE(dB) ----
best_val_nmse = min(val_nmse_db)
best_idx = val_nmse_db.index(best_val_nmse)
best_epoch = epochs[best_idx]

print(f"[BEST] val nmse(dB) = {best_val_nmse:.4f} at epoch {best_epoch}/{total_epochs}")
# Out:
# [BEST] val nmse(dB) = -13.8274 at epoch 91/100
