# %% [markdown]
# #  Import

# %%
print("hello")
# Out:
# hello

# %%
import os
import sys

import numpy as  np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Settings

# %%
# Scenes 2000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(100))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"현재 사용 중인 장치: {device}")
# Out:
# 현재 사용 중인 장치: cuda:0

# %% [markdown]
# # Generate a dataset

# %%
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (0.82s)
# Generating radar dataset: ⏳ In progress
# Generating radar dataset: ✅ Completed (198.52s)

# %% [markdown]
# # location dataset
#  지금 실험에서는 안쓰임

# %%
# comm = dataset.comm_dataset
# location =  comm

# location = [
#     {
#         "bs_loc": d["bs_loc"],                      # (3,)
#         "ue_loc": np.asarray(d["ue_loc"]).squeeze() # (3,)  (원래 (1,3)이면 squeeze)
#     }
#     for row in comm.data      # row: [dict] 형태
#     for d in row              # d: dict
# ]

# print(ue_location)  #)

# %% [markdown]
# # communication  dataset

# %%
# UE 정보
comm = dataset.comm_dataset
ch = comm.data[0][0]['ue'][0]
print(ch.coeffs.shape)
# Out:
# (1, 16, 64)

# %% [markdown]
# # preprocessing

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device=device, eps=1e-16):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex128)
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(device)
    return H

# %%
# 사용예시
H = preprocess_channel_coeffs_minmax(ch.coeffs, r_min=-0.5, r_max=0.5, i_min=-0.5, i_max=0.5)
print(H.shape)  # (1, 16, 128) 64 subcar
# Out:
# torch.Size([1, 16, 128])

# %% [markdown]
# ### image dataset

# %%
sensor = dataset.camera_dataset.sensors["unit1_cam1"]
path0 = sensor.files[0]
img = Image.open(path0).convert("RGB")
arr = np.array(img)

print("path:", path0)
print("PIL size (W,H):", img.size)
print("np shape:", arr.shape, "dtype:", arr.dtype)  # 보통 (H,W,3), uint8
# Out:
# path: scenarios/DT31/RGB_images/unit1_cam1/7.png
# PIL size (W,H): (1920, 1080)
# np shape: (1080, 1920, 3) dtype: uint8

# %%
IMG_SIZE = 224

def preprocess_img(path, img_size=IMG_SIZE, device=device):
    # 1) load (H,W,3) uint8
    img = Image.open(path).convert("RGB")
    arr = np.array(img)

    # 2) numpy -> torch, (3,H,W), float32
    x = torch.from_numpy(arr).permute(2, 0, 1).contiguous().double()  # (3,H,W), double for ImageNet stats
    x = x / 255.0  # [0,1]

    # 3) add batch dim -> (1,3,H,W)
    x = x.unsqueeze(0)

    # 4) resize -> (1,3,224,224)
    x = F.interpolate(x, size=(img_size, img_size),
                      mode="bilinear", align_corners=False)

    # 5) normalize (ImageNet)
    mean = torch.tensor([0.485, 0.456, 0.406], dtype=x.dtype).view(1, 3, 1, 1)
    std  = torch.tensor([0.229, 0.224, 0.225], dtype=x.dtype).view(1, 3, 1, 1)
    x = (x - mean) / std

    # 6) move to device (GPU)
    x = x.to(device, non_blocking=True)

    return x  # (1,3,224,224) on device

# %%
# 사용예시
cd = dataset.camera_dataset
sensor = cd.sensors['unit1_cam1']
path0 = sensor.files[0]
img = preprocess_img(path0, device=device)
print(img.shape, img.device)  # torch.Size([1,3,224,224]) cuda:0
print(path0)
# Out:
# torch.Size([1, 3, 224, 224]) cuda:0
# scenarios/DT31/RGB_images/unit1_cam1/7.png

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class MultiModalNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, cam_files, ue_idx=0, past_len=15, device=device,
                 # Arguments for statistical values (initialized with default values)
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        
        self.comm_frames = comm_frames
        self.cam_files = list(cam_files)
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device
        
        # Save statistical values
        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = min(len(self.comm_frames), len(self.cam_files))
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2 

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1. Image Past (Apply Preprocessing)
        img_list = []
        for k in range(t - self.past_len + 1, t + 1):
            img_path = self.cam_files[k]
            img_k = preprocess_img(img_path, device=self.device).squeeze(0)
            img_list.append(img_k)
        img = torch.stack(img_list, dim=0)  # Shape: (past_len

        
        # 2. Channel Past (Apply Scaling)
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            # Use the newly defined Min-Max preprocessing function
            h = preprocess_channel_coeffs_minmax(
                coeffs_np, 
                self.r_min, self.r_max, self.i_min, self.i_max, 
                device=self.device
            ).reshape(-1)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)

        # 3. Target (Apply Scaling) - Target must also be scaled for model training!
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_minmax(
            coeffs_np_next, 
            self.r_min, self.r_max, self.i_min, self.i_max, 
            device=self.device
        ).reshape(-1)

        return channel_past, img, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
sensor = dataset.camera_dataset.sensors["unit1_cam1"]

ds = MultiModalNextStepDatasetGPU(
    comm_frames=comm_frames,
    cam_files=sensor.files,
    ue_idx=0,
    past_len=16,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   # ✅ 의미 없음 (이미 GPU)
)

ch, img, y = next(iter(loader))
print(ch.shape, img.shape, y.shape)
print(ch.device, img.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 16, 3, 224, 224]) torch.Size([8, 2048])
# cuda:0 cuda:0 cuda:0

# %% [markdown]
# # GRU/LSTM Early fusion

# %%
class ImgFrameEncoderVec(nn.Module):
    """(B*T,3,224,224) -> (B*T,d_img)"""
    def __init__(self, d_img=128):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, 32, 5, stride=2, padding=2), nn.ReLU(),
            nn.Conv2d(32, 64, 3, stride=2, padding=1), nn.ReLU(),
            nn.Conv2d(64, 128, 3, stride=2, padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((1,1)),
        )
        self.proj = nn.Linear(128, d_img)

    def forward(self, x):
        z = self.conv(x).flatten(1)  # (B*T,128)
        return self.proj(z)          # (B*T,d_img)

class RNN_EarlyFusion_Forecaster(nn.Module):
    """
    ch : (B,T,F_in=2048)
    img: (B,T,3,224,224)
    yhat: (B,F_out)
    """
    def __init__(self, F_in, F_out, rnn_type="gru", hidden=256, num_layers=2, d_img=128, dropout=0.1):
        super().__init__()
        self.img_enc = ImgFrameEncoderVec(d_img=d_img)

        self.in_proj = nn.Sequential(
            nn.Linear(F_in + d_img, hidden),
            nn.GELU(),
        )

        rnn_type = rnn_type.lower()
        if rnn_type == "gru":
            self.rnn = nn.GRU(hidden, hidden, num_layers=num_layers, batch_first=True,
                              dropout=dropout if num_layers > 1 else 0.0)
        elif rnn_type == "lstm":
            self.rnn = nn.LSTM(hidden, hidden, num_layers=num_layers, batch_first=True,
                               dropout=dropout if num_layers > 1 else 0.0)
        else:
            raise ValueError("rnn_type must be 'gru' or 'lstm'")

        self.head = nn.Linear(hidden, F_out)

    def forward(self, ch, img):
        B, T, _ = ch.shape
        img_ = img.view(B*T, *img.shape[2:])             # (B*T,3,224,224)
        img_feat = self.img_enc(img_).view(B, T, -1)     # (B,T,d_img)

        x = torch.cat([ch, img_feat], dim=-1)            # (B,T,F_in+d_img)
        x = self.in_proj(x)                              # (B,T,hidden)

        out, _ = self.rnn(x)                             # (B,T,hidden)
        z = out[:, -1, :]                                # last
        return self.head(z)                              # (B,F_out)

# %% [markdown]
# # Fine-tuning
# data shape 맞추기 위해

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# from lwm_multi_model import multi_modal_lwm  # 너가 올린 backbone

# class FinetuneChannelPredictor(nn.Module):
#     """
#     직접 구현한 lwm_multi_model(channel + image)에 맞는 파인튜닝 모델
#     Input:
#       ch:  (B, T, F_in)  e.g., (B,16,2048) 16: past Length, 2048: feature dim
#       img: (B, 3, 224, 224)
#     Output:
#       yhat: (B, F_out)  e.g., (B,2048)
#     """
#     def __init__(
#         self,
#         backbone: nn.Module,
#         F_in: int,
#         F_out: int,
#         pool: str = "last",          # "last" or "mean"
#         freeze_image: bool = False,
#         freeze_backbone: bool = False,
#         element_length: int = 16,    # 채널 벡터 차원 (backbone 기대값)
#         d_model: int = 64            # backbone 내부 feature dim
#     ):
#         super().__init__()
#         self.backbone = backbone
#         self.pool = pool

#         # backbone이 기대하는 channel feature dim = ELEMENT_LENGTH
#         # (backbone 내부 Channel_Embedding: Linear(ELEMENT_LENGTH -> D_MODEL))
#         if element_length is None:
#             element_length = backbone.channel_embedding.element_length
#         if d_model is None:
#             d_model = backbone.channel_embedding.d_model

#         # 입력 차원 정렬: F_in -> ELEMENT_LENGTH
#         self.in_proj = nn.Sequential(
#             nn.Linear(F_in, 512),
#             nn.GELU(),
#             nn.Linear(512, 128),
#             nn.GELU(),
#             nn.Linear(128, element_length)
#         )

#         # 출력 head: D_MODEL -> F_out
#         self.head = nn.Linear(d_model, F_out)

#         if freeze_image:
#             for p in self.backbone.image_embedding.parameters():
#                 p.requires_grad = False

#         if freeze_backbone:
#             for p in self.backbone.parameters():
#                 p.requires_grad = False
#             # 그래도 projection/head는 학습되게 다시 켜기
#             for p in self.in_proj.parameters():
#                 p.requires_grad = True
#             for p in self.head.parameters():
#                 p.requires_grad = True

#     def forward(self, ch, img):
#         # ch: (B,T,F_in) -> (B,T,ELEMENT_LENGTH)
#         ch = self.in_proj(ch)

#         # backbone: (B,T,D_MODEL)/
#         tokens = self.backbone(ch, img)

#         # pooling -> (B,D_MODEL)
#         if self.pool == "last":
#             z = tokens[:, -1, :]
#         elif self.pool == "mean":
#             z = tokens.mean(dim=1)
#         else:
#             raise ValueError(f"Unknown pool={self.pool}")

#         # head -> (B,F_out)
#         yhat = self.head(z)
#         return yhat

# %% [markdown]
# ## NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# %% [markdown]
# # Train/Val split

# %%
# ---- (Optional but recommended) hard leakage check ----
def used_frames_for_ds_indices(ds, ds_indices):
    used = set()
    for i in ds_indices:
        t = ds.valid_start + i
        # inputs use [t-T+1 .. t], target uses (t+1)
        used.update(range(t - T + 1, t + 2))
    return used

# %%
n_total = len(ds)
T = ds.past_len  # = past_len

# ---- choose k so that train=3k, val=k and NO frame-overlap is possible ----
k_max = (n_total - T) // 4
if k_max <= 0:
    raise ValueError(
        f"Not enough data for strict non-overlap 3:1. "
        f"n_total={n_total}, past_len(T)={T}. "
        f"Try increasing scenes or decreasing past_len."
    )

k = k_max               # use as much data as possible under constraints
n_val = k
n_train = 3 * k

train_idx = list(range(0, n_train))
val_idx   = list(range(n_total - n_val, n_total))

print("n_total:", n_total, "T:", T)
print("train samples:", len(train_idx), "val samples:", len(val_idx), "ratio:", len(train_idx)/len(val_idx))

# ---- min/max ONLY from train (same as your original policy) ----
train_ts = [ds.valid_start + i for i in train_idx]

(real_min, real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_ts, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)

F_in = 2048


overlap = used_frames_for_ds_indices(ds, train_idx).intersection(
          used_frames_for_ds_indices(ds, val_idx))
print("frame-overlap count:", len(overlap))
assert len(overlap) == 0, "Leakage detected: train/val share frames!"

# Verify
ch, img, y = next(iter(train_loader))
F_out = y.shape[-1]
print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")
# Out:
# n_total: 84 T: 16
# train samples: 51 val samples: 17 ratio: 3.0
# Calculating min/max over training set...
# Done. rmin=-1.0646139639174899e-06, rmax=1.0917989155343993e-06, imin=-1.0719516685941772e-06, imax=1.0643868111374237e-06
# Dataset statistical values set in the dataset.
# frame-overlap count: 0
#
# === Data Check ===
# y stats | min: 0.0000, max: 1.0000
# If scaling worked correctly, values should be within [0, 1].

# %%
# n = len(ds)
# n_train = int(0.75 * n)
# train_idx = list(range(0, n_train))
# val_idx = list(range(n_train, n))

# train_ts = [ds.valid_start + i for i in train_idx]

# (real_min,  real_max), (imag_min, imag_max) = get_train_min_max_realimag(
#     comm_frames, train_ts, us_idx=0
# )

# ds.r_min = real_min
# ds.r_max = real_max
# ds.i_min = imag_min
# ds.i_max = imag_max

# print("Dataset statistical values set in the dataset.")

# train_ds = Subset(ds, train_idx)
# val_ds   = Subset(ds, val_idx)

# train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
# val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)
# F_in = 2048  # 

# # Verify
# ch, img, y = next(iter(train_loader))
# F_out = y.shape[-1]
# print("\n=== Data Check ===")
# print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
# print("If scaling worked correctly, values should be within [0, 1].")a

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
cam_files = list(dataset.camera_dataset.sensors["unit1_cam1"].files)

print("len(comm_frames):", len(comm_frames))
print("len(cam_files):", len(cam_files))
print("first comm frame keys:", list(comm_frames[0].keys()))
print("first cam file:", cam_files[0])
# Out:
# len(comm_frames): 100
# len(cam_files): 1114
# first comm frame keys: ['bs_loc', 'ue', 'ue_loc', 'bs']
# first cam file: scenarios/DT31/RGB_images/unit1_cam1/7.png

# %%
len(val_loader)
# Out:
# 1

# %% [markdown]
# # Model generate and also check

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print("device:", device)

# # 배치 하나로 F_in/F_out 자동 확정
# ch, img, y = next(iter(train_loader))
# F_in  = ch.shape[-1]
# F_out = y.shape[-1]
# print("Detected:", "F_in=", F_in, "F_out=", F_out)
# print("Batch devices:", ch.device, img.device, y.device)

# # backbone + finetune model
# backbone = multi_modal_lwm().to(device)

# model = FinetuneChannelPredictor(
#     backbone=backbone,
#     F_in=F_in,
#     F_out=F_out,
#     pool="last",            # "mean"으로 바꿔도 됨
#     freeze_image=False,     # 원하면 True (이미지 인코더 고정)
#     freeze_backbone=False,  # 원하면 True (proj/head만 학습)
#     element_length=16,
#     d_model=64
# ).to(device)

# # sanity forward
# model.eval()
# with torch.no_grad():
#     # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
#     yhat = model(ch.to(device), img.to(device))
# print("yhat:", yhat.shape, "y:", y.shape)

# %% [markdown]
# # Train/ Eval 함수 (AMP + grad clip)

# %%
def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        # float64(Double) 타입으로 확실하게 캐스팅하여 GPU로 이동
        ch = ch.to(device, dtype=torch.float64, non_blocking=True)
        img = img.to(device, dtype=torch.float64, non_blocking=True)
        y  = y.to(device, dtype=torch.float64, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        # amp.autocast 제거됨
        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)

        # scaler 없이 바로 backward 호출
        loss.backward()

        # scaler.unscale_ 없이 바로 gradient clipping 적용
        if grad_clip is not None and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        # scaler.step 대신 바로 optimizer.step() 호출
        optimizer.step()

        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)


@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        # float64(Double) 타입으로 확실하게 캐스팅
        ch = ch.to(device, dtype=torch.float64, non_blocking=True)
        img = img.to(device, dtype=torch.float64, non_blocking=True)
        y  = y.to(device, dtype=torch.float64, non_blocking=True)

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

# %%
# define fit model GRU/ LSTM
def fit_model(
    model: nn.Module,
    train_loader,
    val_loader,
    device,
    epochs: int,
    ckpt_path: str,
    lr: float = 1e-4,
    weight_decay: float = 1e-4,
    grad_clip: float = 1.0,
):
    trainable_params = [p for p in model.parameters() if p.requires_grad]
    print("trainable params:", sum(p.numel() for p in trainable_params))

    optimizer = torch.optim.AdamW(trainable_params, lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    best_val = float("inf")

    for epoch in range(1, epochs + 1):
        t0 = time.time()

        tr_loss, tr_nmse = train_one_epoch(model, train_loader, optimizer, device=device, grad_clip=grad_clip)
        va_loss, va_nmse = evaluate(model, val_loader, device=device)

        scheduler.step()

        dt = time.time() - t0
        print(
            f"[{epoch:02d}/{epochs}] "
            f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
            f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
            f"{dt:.1f}s"
        )

        if va_loss < best_val:
            best_val = va_loss
            torch.save(
                {
                    "epoch": epoch,
                    "model_state": model.state_dict(),
                    "optimizer_state": optimizer.state_dict(),
                    "best_val": best_val,
                    "F_in": F_in,
                    "F_out": F_out,
                },
                ckpt_path
            )
            print(f"  ↳ saved {ckpt_path}")

    return best_val

# %% [markdown]
# #  Optiimizer  / Scheduler 설정

# %%
# # requires_grad=True인 파라미터만 학습
# trainable_params = [p for p in model.parameters() if p.requires_grad]
# print("trainable params:", sum(p.numel() for p in trainable_params))

# optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# # (선택) cosine scheduler
# epochs = 1000
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

# %% [markdown]
# # 학습 루프 + checkpoint 저장

# %%
epochs = 400

# ===== 1) GRU =====
model_gru = RNN_EarlyFusion_Forecaster(
    F_in=F_in, F_out=F_out,
    rnn_type="gru",
    hidden=256, num_layers=2, d_img=128, dropout=0.1
).double().to(device)

print("\n=== Training: GRU Early Fusion ===")
best_gru = fit_model(
    model=model_gru,
    train_loader=train_loader,
    val_loader=val_loader,
    device=device,
    epochs=epochs,
    ckpt_path="best_gru_earlyfusion.pt",
)

del model_gru
torch.cuda.empty_cache()

# ===== 2) LSTM =====
model_lstm = RNN_EarlyFusion_Forecaster(
    F_in=F_in, F_out=F_out,
    rnn_type="lstm",
    hidden=256, num_layers=2, d_img=128, dropout=0.1
).double().to(device)

print("\n=== Training: LSTM Early Fusion ===")
best_lstm = fit_model(
    model=model_lstm,
    train_loader=train_loader,
    val_loader=val_loader,
    device=device,
    epochs=epochs,
    ckpt_path="best_lstm_earlyfusion.pt",
)

print("\n=== Done ===")
print("Best val loss | GRU :", best_gru)
print("Best val loss | LSTM:", best_lstm)
# Out:
# === Training: GRU Early Fusion ===
# trainable params: 1984448
# [01/400] train loss=0.289913, nmse(dB)=0.0040 | val loss=0.251436, nmse(dB)=-0.1109 | 72.3s
#   ↳ saved best_gru_earlyfusion.pt
# [02/400] train loss=0.284750, nmse(dB)=-0.1275 | val loss=0.243197, nmse(dB)=-0.2558 | 72.4s
#   ↳ saved best_gru_earlyfusion.pt
# [03/400] train loss=0.275904, nmse(dB)=-0.2636 | val loss=0.232615, nmse(dB)=-0.4492 | 73.2s
#   ↳ saved best_gru_earlyfusion.pt
# [04/400] train loss=0.260403, nmse(dB)=-0.4354 | val loss=0.219388, nmse(dB)=-0.7038 | 72.6s
#   ↳ saved best_gru_earlyfusion.pt
# [05/400] train loss=0.250683, nmse(dB)=-0.6712 | val loss=0.204229, nmse(dB)=-1.0151 | 72.5s
#   ↳ saved best_gru_earlyfusion.pt
# [06/400] train loss=0.235204, nmse(dB)=-0.9371 | val loss=0.188131, nmse(dB)=-1.3723 | 72.2s
#   ↳ saved best_gru_earlyfusion.pt
# [07/400] train loss=0.220895, nmse(dB)=-1.2422 | val loss=0.171997, nmse(dB)=-1.7625 | 72.6s
#   ↳ saved best_gru_earlyfusion.pt
# [08/400] train loss=0.204797, nmse(dB)=-1.5534 | val loss=0.156333, nmse(dB)=-2.1782 | 72.8s
#   ↳ saved best_gru_earlyfusion.pt
# [09/400] train loss=0.189413, nmse(dB)=-1.9262 | val loss=0.141259, nmse(dB)=-2.6198 | 72.7s
#   ↳ saved best_gru_earlyfusion.pt
# [10/400] train loss=0.175284, nmse(dB)=-2.2429 | val loss=0.126839, nmse(dB)=-3.0891 | 72.6s
#   ↳ saved best_gru_earlyfusion.pt
# [11/400] train loss=0.162449, nmse(dB)=-2.6225 | val loss=0.113188, nmse(dB)=-3.5857 | 73.1s
#   ↳ saved best_gru_earlyfusion.pt
# [12/400] train loss=0.146530, nmse(dB)=-3.0292 | val loss=0.100369, nmse(dB)=-4.1106 | 73.6s
#   ↳ saved best_gru_earlyfusion.pt
# [13/400] train loss=0.133742, nmse(dB)=-3.3867 | val loss=0.088467, nmse(dB)=-4.6627 | 74.2s
#   ↳ saved best_gru_earlyfusion.pt
# [14/400] train loss=0.123832, nmse(dB)=-3.8277 | val loss=0.077564, nmse(dB)=-5.2393 | 73.8s
#   ↳ saved best_gru_earlyfusion.pt
# [15/400] train loss=0.113333, nmse(dB)=-4.1980 | val loss=0.067698, nmse(dB)=-5.8373 | 73.3s
#   ↳ saved best_gru_earlyfusion.pt
# [16/400] train loss=0.102972, nmse(dB)=-4.5835 | val loss=0.058884, nmse(dB)=-6.4529 | 73.8s
#   ↳ saved best_gru_earlyfusion.pt
# [17/400] train loss=0.094514, nmse(dB)=-4.9936 | val loss=0.051064, nmse(dB)=-7.0851 | 72.7s
#   ↳ saved best_gru_earlyfusion.pt
# [18/400] train loss=0.087111, nmse(dB)=-5.3273 | val loss=0.044215, nmse(dB)=-7.7285 | 73.2s
#   ↳ saved best_gru_earlyfusion.pt
# [19/400] train loss=0.079365, nmse(dB)=-5.7816 | val loss=0.038303, nmse(dB)=-8.3758 | 73.7s
#   ↳ saved best_gru_earlyfusion.pt
# [20/400] train loss=0.075059, nmse(dB)=-6.0369 | val loss=0.033251, nmse(dB)=-9.0217 | 73.2s
#   ↳ saved best_gru_earlyfusion.pt
# [21/400] train loss=0.070900, nmse(dB)=-6.3950 | val loss=0.029004, nmse(dB)=-9.6558 | 73.2s
#   ↳ saved best_gru_earlyfusion.pt
# [22/400] train loss=0.066979, nmse(dB)=-6.5962 | val loss=0.025504, nmse(dB)=-10.2650 | 73.8s
#   ↳ saved best_gru_earlyfusion.pt
# [23/400] train loss=0.061849, nmse(dB)=-6.9633 | val loss=0.022601, nmse(dB)=-10.8521 | 73.6s
#   ↳ saved best_gru_earlyfusion.pt
# [24/400] train loss=0.060373, nmse(dB)=-7.0821 | val loss=0.020238, nmse(dB)=-11.4051 | 73.4s
#   ↳ saved best_gru_earlyfusion.pt
# [25/400] train loss=0.059334, nmse(dB)=-7.3508 | val loss=0.018374, nmse(dB)=-11.9056 | 73.2s
#   ↳ saved best_gru_earlyfusion.pt
# [26/400] train loss=0.055987, nmse(dB)=-7.4409 | val loss=0.016876, nmse(dB)=-12.3638 | 74.0s
#   ↳ saved best_gru_earlyfusion.pt
# [27/400] train loss=0.054849, nmse(dB)=-7.6488 | val loss=0.015702, nmse(dB)=-12.7683 | 74.5s
#   ↳ saved best_gru_earlyfusion.pt
# [28/400] train loss=0.054717, nmse(dB)=-7.7761 | val loss=0.014757, nmse(dB)=-13.1301 | 74.8s
#   ↳ saved best_gru_earlyfusion.pt
# [29/400] train loss=0.052908, nmse(dB)=-7.8569 | val loss=0.013999, nmse(dB)=-13.4492 | 73.8s
#   ↳ saved best_gru_earlyfusion.pt
# [30/400] train loss=0.051877, nmse(dB)=-7.9650 | val loss=0.013367, nmse(dB)=-13.7391 | 75.3s
#   ↳ saved best_gru_earlyfusion.pt
# [31/400] train loss=0.051149, nmse(dB)=-8.0725 | val loss=0.012860, nmse(dB)=-13.9905 | 73.6s
#   ↳ saved best_gru_earlyfusion.pt
# [32/400] train loss=0.050204, nmse(dB)=-8.1377 | val loss=0.012465, nmse(dB)=-14.2021 | 73.5s
#   ↳ saved best_gru_earlyfusion.pt
# [33/400] train loss=0.051795, nmse(dB)=-7.9857 | val loss=0.012170, nmse(dB)=-14.3692 | 74.4s
#   ↳ saved best_gru_earlyfusion.pt
# [34/400] train loss=0.049481, nmse(dB)=-8.2643 | val loss=0.011900, nmse(dB)=-14.5317 | 73.4s
#   ↳ saved best_gru_earlyfusion.pt
# [35/400] train loss=0.048357, nmse(dB)=-8.2410 | val loss=0.011698, nmse(dB)=-14.6633 | 73.8s
#   ↳ saved best_gru_earlyfusion.pt
# [36/400] train loss=0.048468, nmse(dB)=-8.2580 | val loss=0.011530, nmse(dB)=-14.7779 | 73.1s
#   ↳ saved best_gru_earlyfusion.pt
# [37/400] train loss=0.048917, nmse(dB)=-8.3310 | val loss=0.011410, nmse(dB)=-14.8643 | 73.2s
#   ↳ saved best_gru_earlyfusion.pt
# [38/400] train loss=0.049215, nmse(dB)=-8.3157 | val loss=0.011304, nmse(dB)=-14.9445 | 73.5s
#   ↳ saved best_gru_earlyfusion.pt
# [39/400] train loss=0.050755, nmse(dB)=-8.1035 | val loss=0.011277, nmse(dB)=-14.9707 | 75.2s
#   ↳ saved best_gru_earlyfusion.pt
# [40/400] train loss=0.050958, nmse(dB)=-8.1211 | val loss=0.011242, nmse(dB)=-15.0005 | 75.0s
#   ↳ saved best_gru_earlyfusion.pt
# [41/400] train loss=0.049018, nmse(dB)=-8.2349 | val loss=0.011147, nmse(dB)=-15.0748 | 74.9s
#   ↳ saved best_gru_earlyfusion.pt
# [42/400] train loss=0.050827, nmse(dB)=-8.1242 | val loss=0.011087, nmse(dB)=-15.1203 | 74.7s
#   ↳ saved best_gru_earlyfusion.pt
# [43/400] train loss=0.048768, nmse(dB)=-8.2511 | val loss=0.011107, nmse(dB)=-15.1038 | 74.5s
# [44/400] train loss=0.050624, nmse(dB)=-8.1652 | val loss=0.011069, nmse(dB)=-15.1360 | 75.6s
#   ↳ saved best_gru_earlyfusion.pt
# [45/400] train loss=0.048749, nmse(dB)=-8.3425 | val loss=0.011080, nmse(dB)=-15.1288 | 74.3s
# [46/400] train loss=0.049107, nmse(dB)=-8.2610 | val loss=0.011175, nmse(dB)=-15.0559 | 75.0s
# [47/400] train loss=0.048275, nmse(dB)=-8.3925 | val loss=0.011156, nmse(dB)=-15.0703 | 74.7s
# [48/400] train loss=0.049616, nmse(dB)=-8.1583 | val loss=0.011085, nmse(dB)=-15.1250 | 74.6s
# [49/400] train loss=0.048608, nmse(dB)=-8.2924 | val loss=0.011056, nmse(dB)=-15.1429 | 74.4s
#   ↳ saved best_gru_earlyfusion.pt
# [50/400] train loss=0.049015, nmse(dB)=-8.2491 | val loss=0.011075, nmse(dB)=-15.1244 | 74.8s
# [51/400] train loss=0.049693, nmse(dB)=-8.2050 | val loss=0.011027, nmse(dB)=-15.1648 | 74.9s
#   ↳ saved best_gru_earlyfusion.pt
# [52/400] train loss=0.049576, nmse(dB)=-8.2392 | val loss=0.011025, nmse(dB)=-15.1661 | 73.5s
#   ↳ saved best_gru_earlyfusion.pt
# [53/400] train loss=0.048216, nmse(dB)=-8.3272 | val loss=0.011044, nmse(dB)=-15.1504 | 74.0s
# [54/400] train loss=0.050088, nmse(dB)=-8.2070 | val loss=0.011042, nmse(dB)=-15.1539 | 73.6s
# [55/400] train loss=0.049987, nmse(dB)=-8.2651 | val loss=0.011047, nmse(dB)=-15.1501 | 73.6s
# [56/400] train loss=0.047705, nmse(dB)=-8.3721 | val loss=0.011066, nmse(dB)=-15.1355 | 73.4s
# [57/400] train loss=0.049160, nmse(dB)=-8.2300 | val loss=0.011067, nmse(dB)=-15.1344 | 73.7s
# [58/400] train loss=0.049388, nmse(dB)=-8.2276 | val loss=0.011049, nmse(dB)=-15.1464 | 73.7s
# [59/400] train loss=0.050574, nmse(dB)=-8.1706 | val loss=0.011028, nmse(dB)=-15.1615 | 73.7s
# [60/400] train loss=0.050325, nmse(dB)=-8.1631 | val loss=0.011023, nmse(dB)=-15.1632 | 73.0s
#   ↳ saved best_gru_earlyfusion.pt
# [61/400] train loss=0.047798, nmse(dB)=-8.3528 | val loss=0.011025, nmse(dB)=-15.1602 | 73.2s
# [62/400] train loss=0.049286, nmse(dB)=-8.2662 | val loss=0.011028, nmse(dB)=-15.1585 | 73.3s
# [63/400] train loss=0.049003, nmse(dB)=-8.3234 | val loss=0.011061, nmse(dB)=-15.1334 | 74.6s
# [64/400] train loss=0.047285, nmse(dB)=-8.4281 | val loss=0.011064, nmse(dB)=-15.1333 | 73.3s
# [65/400] train loss=0.047483, nmse(dB)=-8.4047 | val loss=0.011040, nmse(dB)=-15.1554 | 72.7s
# [66/400] train loss=0.049703, nmse(dB)=-8.1435 | val loss=0.011008, nmse(dB)=-15.1830 | 73.6s
#   ↳ saved best_gru_earlyfusion.pt
# [67/400] train loss=0.049040, nmse(dB)=-8.2928 | val loss=0.010993, nmse(dB)=-15.1962 | 74.1s
#   ↳ saved best_gru_earlyfusion.pt
# [68/400] train loss=0.049348, nmse(dB)=-8.2518 | val loss=0.010969, nmse(dB)=-15.2165 | 73.2s
#   ↳ saved best_gru_earlyfusion.pt
# [69/400] train loss=0.048542, nmse(dB)=-8.3122 | val loss=0.010965, nmse(dB)=-15.2209 | 73.5s
#   ↳ saved best_gru_earlyfusion.pt
# [70/400] train loss=0.048972, nmse(dB)=-8.3328 | val loss=0.010993, nmse(dB)=-15.1983 | 72.1s
# [71/400] train loss=0.048496, nmse(dB)=-8.2743 | val loss=0.011052, nmse(dB)=-15.1493 | 72.7s
# [72/400] train loss=0.047469, nmse(dB)=-8.4240 | val loss=0.011009, nmse(dB)=-15.1829 | 72.2s
# [73/400] train loss=0.048554, nmse(dB)=-8.3827 | val loss=0.010996, nmse(dB)=-15.1932 | 73.4s
# [74/400] train loss=0.050385, nmse(dB)=-8.1623 | val loss=0.010997, nmse(dB)=-15.1923 | 73.2s
# [75/400] train loss=0.050156, nmse(dB)=-8.2265 | val loss=0.011003, nmse(dB)=-15.1892 | 72.5s
# [76/400] train loss=0.049783, nmse(dB)=-8.2222 | val loss=0.011015, nmse(dB)=-15.1801 | 73.6s
# [77/400] train loss=0.047612, nmse(dB)=-8.3806 | val loss=0.011020, nmse(dB)=-15.1812 | 72.5s
# [78/400] train loss=0.048343, nmse(dB)=-8.3633 | val loss=0.011001, nmse(dB)=-15.1999 | 72.7s
# [79/400] train loss=0.048515, nmse(dB)=-8.3364 | val loss=0.010987, nmse(dB)=-15.2117 | 73.6s
# [80/400] train loss=0.049876, nmse(dB)=-8.3226 | val loss=0.010975, nmse(dB)=-15.2233 | 72.8s
# [81/400] train loss=0.047733, nmse(dB)=-8.3955 | val loss=0.010990, nmse(dB)=-15.2115 | 73.5s
# [82/400] train loss=0.046977, nmse(dB)=-8.4209 | val loss=0.010996, nmse(dB)=-15.2066 | 72.8s
# [83/400] train loss=0.050681, nmse(dB)=-8.2357 | val loss=0.010945, nmse(dB)=-15.2459 | 72.8s
#   ↳ saved best_gru_earlyfusion.pt
# [84/400] train loss=0.049721, nmse(dB)=-8.2386 | val loss=0.010931, nmse(dB)=-15.2515 | 73.1s
#   ↳ saved best_gru_earlyfusion.pt
# [85/400] train loss=0.049255, nmse(dB)=-8.3124 | val loss=0.010914, nmse(dB)=-15.2610 | 73.3s
#   ↳ saved best_gru_earlyfusion.pt
# [86/400] train loss=0.048961, nmse(dB)=-8.3024 | val loss=0.010924, nmse(dB)=-15.2495 | 73.2s
# [87/400] train loss=0.048492, nmse(dB)=-8.3465 | val loss=0.010926, nmse(dB)=-15.2479 | 75.0s
# [88/400] train loss=0.048464, nmse(dB)=-8.3399 | val loss=0.010949, nmse(dB)=-15.2265 | 74.6s
# [89/400] train loss=0.049393, nmse(dB)=-8.2435 | val loss=0.010976, nmse(dB)=-15.2036 | 73.4s
# [90/400] train loss=0.049008, nmse(dB)=-8.2787 | val loss=0.010952, nmse(dB)=-15.2239 | 73.8s
# [91/400] train loss=0.047551, nmse(dB)=-8.4641 | val loss=0.010945, nmse(dB)=-15.2321 | 74.2s
# [92/400] train loss=0.050141, nmse(dB)=-8.2024 | val loss=0.010945, nmse(dB)=-15.2382 | 74.4s
# [93/400] train loss=0.047186, nmse(dB)=-8.4176 | val loss=0.010969, nmse(dB)=-15.2207 | 74.3s
# [94/400] train loss=0.047867, nmse(dB)=-8.3636 | val loss=0.011007, nmse(dB)=-15.1872 | 73.3s
# [95/400] train loss=0.050096, nmse(dB)=-8.2113 | val loss=0.011012, nmse(dB)=-15.1820 | 74.1s
# [96/400] train loss=0.049253, nmse(dB)=-8.2939 | val loss=0.011001, nmse(dB)=-15.1874 | 74.1s
# [97/400] train loss=0.048252, nmse(dB)=-8.3282 | val loss=0.011010, nmse(dB)=-15.1790 | 74.0s
# [98/400] train loss=0.050592, nmse(dB)=-8.2025 | val loss=0.011029, nmse(dB)=-15.1635 | 73.8s
# [99/400] train loss=0.048732, nmse(dB)=-8.2879 | val loss=0.011057, nmse(dB)=-15.1406 | 73.1s
# [100/400] train loss=0.049745, nmse(dB)=-8.2922 | val loss=0.011091, nmse(dB)=-15.1122 | 73.1s
# [101/400] train loss=0.049280, nmse(dB)=-8.2858 | val loss=0.011071, nmse(dB)=-15.1270 | 73.5s
# [102/400] train loss=0.048447, nmse(dB)=-8.3812 | val loss=0.011048, nmse(dB)=-15.1430 | 73.7s
# [103/400] train loss=0.047921, nmse(dB)=-8.3783 | val loss=0.011032, nmse(dB)=-15.1536 | 73.3s
# [104/400] train loss=0.047997, nmse(dB)=-8.3902 | val loss=0.011022, nmse(dB)=-15.1619 | 73.5s
# [105/400] train loss=0.048059, nmse(dB)=-8.4516 | val loss=0.011029, nmse(dB)=-15.1605 | 73.6s
# [106/400] train loss=0.048211, nmse(dB)=-8.3948 | val loss=0.011053, nmse(dB)=-15.1421 | 73.1s
# [107/400] train loss=0.047353, nmse(dB)=-8.3779 | val loss=0.011028, nmse(dB)=-15.1657 | 72.9s
# [108/400] train loss=0.048082, nmse(dB)=-8.3510 | val loss=0.010984, nmse(dB)=-15.2012 | 74.5s
# [109/400] train loss=0.047500, nmse(dB)=-8.4397 | val loss=0.010959, nmse(dB)=-15.2217 | 74.0s
# [110/400] train loss=0.047492, nmse(dB)=-8.4473 | val loss=0.010942, nmse(dB)=-15.2354 | 73.7s
# [111/400] train loss=0.049437, nmse(dB)=-8.2752 | val loss=0.010955, nmse(dB)=-15.2265 | 73.7s
# [112/400] train loss=0.048859, nmse(dB)=-8.3335 | val loss=0.010974, nmse(dB)=-15.2116 | 73.4s
# [113/400] train loss=0.049144, nmse(dB)=-8.3089 | val loss=0.010959, nmse(dB)=-15.2263 | 73.4s
# [114/400] train loss=0.048222, nmse(dB)=-8.3564 | val loss=0.010939, nmse(dB)=-15.2456 | 73.8s
# [115/400] train loss=0.048761, nmse(dB)=-8.3410 | val loss=0.010940, nmse(dB)=-15.2483 | 73.3s
# [116/400] train loss=0.049234, nmse(dB)=-8.2427 | val loss=0.010961, nmse(dB)=-15.2316 | 73.9s
# [117/400] train loss=0.048730, nmse(dB)=-8.3400 | val loss=0.010982, nmse(dB)=-15.2152 | 73.5s
# [118/400] train loss=0.049703, nmse(dB)=-8.2332 | val loss=0.011018, nmse(dB)=-15.1874 | 74.0s
# [119/400] train loss=0.047297, nmse(dB)=-8.4489 | val loss=0.011029, nmse(dB)=-15.1805 | 73.4s
# [120/400] train loss=0.049639, nmse(dB)=-8.2106 | val loss=0.011013, nmse(dB)=-15.1924 | 73.8s
# [121/400] train loss=0.049322, nmse(dB)=-8.3049 | val loss=0.011030, nmse(dB)=-15.1764 | 73.9s
# [122/400] train loss=0.048239, nmse(dB)=-8.3421 | val loss=0.011043, nmse(dB)=-15.1639 | 74.2s
# [123/400] train loss=0.048511, nmse(dB)=-8.3179 | val loss=0.011044, nmse(dB)=-15.1627 | 73.5s
# [124/400] train loss=0.048738, nmse(dB)=-8.3115 | val loss=0.011025, nmse(dB)=-15.1772 | 74.5s
# [125/400] train loss=0.046871, nmse(dB)=-8.4728 | val loss=0.011030, nmse(dB)=-15.1725 | 73.3s
# [126/400] train loss=0.048798, nmse(dB)=-8.2834 | val loss=0.011022, nmse(dB)=-15.1760 | 73.5s
# [127/400] train loss=0.049045, nmse(dB)=-8.2329 | val loss=0.011013, nmse(dB)=-15.1788 | 73.9s
# [128/400] train loss=0.046552, nmse(dB)=-8.4862 | val loss=0.011016, nmse(dB)=-15.1699 | 73.7s
# [129/400] train loss=0.048607, nmse(dB)=-8.2863 | val loss=0.011029, nmse(dB)=-15.1545 | 73.5s
# [130/400] train loss=0.048078, nmse(dB)=-8.3261 | val loss=0.011067, nmse(dB)=-15.1216 | 73.8s
# [131/400] train loss=0.047418, nmse(dB)=-8.4085 | val loss=0.011071, nmse(dB)=-15.1194 | 74.1s
# [132/400] train loss=0.048542, nmse(dB)=-8.3056 | val loss=0.011047, nmse(dB)=-15.1399 | 73.9s
# [133/400] train loss=0.049650, nmse(dB)=-8.2748 | val loss=0.011037, nmse(dB)=-15.1493 | 74.5s
# [134/400] train loss=0.049882, nmse(dB)=-8.2525 | val loss=0.011023, nmse(dB)=-15.1649 | 73.6s
# [135/400] train loss=0.049500, nmse(dB)=-8.3038 | val loss=0.011028, nmse(dB)=-15.1606 | 73.8s
# [136/400] train loss=0.050117, nmse(dB)=-8.2355 | val loss=0.011036, nmse(dB)=-15.1557 | 73.7s
# [137/400] train loss=0.049862, nmse(dB)=-8.2826 | val loss=0.011041, nmse(dB)=-15.1528 | 73.1s
# [138/400] train loss=0.048173, nmse(dB)=-8.3365 | val loss=0.011041, nmse(dB)=-15.1549 | 73.3s
# [139/400] train loss=0.050958, nmse(dB)=-8.0947 | val loss=0.011022, nmse(dB)=-15.1709 | 73.5s
# [140/400] train loss=0.049296, nmse(dB)=-8.2487 | val loss=0.011004, nmse(dB)=-15.1858 | 74.1s
# [141/400] train loss=0.049422, nmse(dB)=-8.2282 | val loss=0.010998, nmse(dB)=-15.1884 | 74.1s
# [142/400] train loss=0.048310, nmse(dB)=-8.3818 | val loss=0.011007, nmse(dB)=-15.1810 | 74.3s
# [143/400] train loss=0.049797, nmse(dB)=-8.2167 | val loss=0.011065, nmse(dB)=-15.1357 | 74.1s
# [144/400] train loss=0.048132, nmse(dB)=-8.3917 | val loss=0.011120, nmse(dB)=-15.0931 | 73.9s
# [145/400] train loss=0.048332, nmse(dB)=-8.3168 | val loss=0.011140, nmse(dB)=-15.0773 | 73.4s
# [146/400] train loss=0.046252, nmse(dB)=-8.4566 | val loss=0.011083, nmse(dB)=-15.1224 | 74.7s
# [147/400] train loss=0.049078, nmse(dB)=-8.2885 | val loss=0.011062, nmse(dB)=-15.1362 | 74.2s
# [148/400] train loss=0.048804, nmse(dB)=-8.3309 | val loss=0.011032, nmse(dB)=-15.1621 | 74.2s
# [149/400] train loss=0.048724, nmse(dB)=-8.2750 | val loss=0.011049, nmse(dB)=-15.1493 | 74.5s
# [150/400] train loss=0.046963, nmse(dB)=-8.4382 | val loss=0.011096, nmse(dB)=-15.1096 | 75.1s
# [151/400] train loss=0.048371, nmse(dB)=-8.3097 | val loss=0.011071, nmse(dB)=-15.1270 | 74.2s
# [152/400] train loss=0.050065, nmse(dB)=-8.1733 | val loss=0.011034, nmse(dB)=-15.1572 | 73.7s
# [153/400] train loss=0.047521, nmse(dB)=-8.4199 | val loss=0.011001, nmse(dB)=-15.1855 | 74.6s
# [154/400] train loss=0.049222, nmse(dB)=-8.3113 | val loss=0.010995, nmse(dB)=-15.1921 | 74.1s
# [155/400] train loss=0.049035, nmse(dB)=-8.3437 | val loss=0.011032, nmse(dB)=-15.1646 | 73.9s
# [156/400] train loss=0.048255, nmse(dB)=-8.3549 | val loss=0.011112, nmse(dB)=-15.1009 | 73.0s
# [157/400] train loss=0.047391, nmse(dB)=-8.4099 | val loss=0.011098, nmse(dB)=-15.1110 | 72.8s
# [158/400] train loss=0.049365, nmse(dB)=-8.2850 | val loss=0.010993, nmse(dB)=-15.1957 | 73.5s
# [159/400] train loss=0.049162, nmse(dB)=-8.2817 | val loss=0.010940, nmse(dB)=-15.2379 | 73.5s
# [160/400] train loss=0.049997, nmse(dB)=-8.1947 | val loss=0.010918, nmse(dB)=-15.2541 | 73.8s
# [161/400] train loss=0.048964, nmse(dB)=-8.3122 | val loss=0.010912, nmse(dB)=-15.2569 | 73.9s
#   ↳ saved best_gru_earlyfusion.pt
# [162/400] train loss=0.048468, nmse(dB)=-8.3587 | val loss=0.010924, nmse(dB)=-15.2451 | 73.4s
# [163/400] train loss=0.049406, nmse(dB)=-8.3041 | val loss=0.010971, nmse(dB)=-15.2081 | 74.2s
# [164/400] train loss=0.050541, nmse(dB)=-8.1946 | val loss=0.011039, nmse(dB)=-15.1527 | 73.6s
# [165/400] train loss=0.048588, nmse(dB)=-8.3197 | val loss=0.011049, nmse(dB)=-15.1447 | 74.3s
# [166/400] train loss=0.048539, nmse(dB)=-8.3082 | val loss=0.011000, nmse(dB)=-15.1860 | 73.8s
# [167/400] train loss=0.048505, nmse(dB)=-8.2977 | val loss=0.010996, nmse(dB)=-15.1915 | 73.3s
# [168/400] train loss=0.049918, nmse(dB)=-8.2254 | val loss=0.011002, nmse(dB)=-15.1882 | 74.0s
# [169/400] train loss=0.047959, nmse(dB)=-8.3430 | val loss=0.011017, nmse(dB)=-15.1770 | 73.9s
# [170/400] train loss=0.048974, nmse(dB)=-8.2645 | val loss=0.011060, nmse(dB)=-15.1427 | 73.6s
# [171/400] train loss=0.047729, nmse(dB)=-8.3831 | val loss=0.011116, nmse(dB)=-15.0975 | 73.5s
# [172/400] train loss=0.047269, nmse(dB)=-8.4166 | val loss=0.011101, nmse(dB)=-15.1081 | 73.5s
# [173/400] train loss=0.048020, nmse(dB)=-8.3303 | val loss=0.011089, nmse(dB)=-15.1148 | 73.2s
# [174/400] train loss=0.047713, nmse(dB)=-8.3879 | val loss=0.011097, nmse(dB)=-15.1062 | 73.4s
# [175/400] train loss=0.048034, nmse(dB)=-8.3905 | val loss=0.011094, nmse(dB)=-15.1058 | 73.3s
# [176/400] train loss=0.049877, nmse(dB)=-8.1745 | val loss=0.011108, nmse(dB)=-15.0943 | 73.5s
# [177/400] train loss=0.046919, nmse(dB)=-8.4835 | val loss=0.011094, nmse(dB)=-15.1046 | 73.3s
# [178/400] train loss=0.048302, nmse(dB)=-8.3237 | val loss=0.011112, nmse(dB)=-15.0877 | 73.6s
# [179/400] train loss=0.048551, nmse(dB)=-8.3599 | val loss=0.011115, nmse(dB)=-15.0855 | 73.6s
# [180/400] train loss=0.048320, nmse(dB)=-8.4219 | val loss=0.011135, nmse(dB)=-15.0697 | 73.6s
# [181/400] train loss=0.049796, nmse(dB)=-8.2043 | val loss=0.011209, nmse(dB)=-15.0131 | 73.7s
# [182/400] train loss=0.048021, nmse(dB)=-8.3072 | val loss=0.011125, nmse(dB)=-15.0802 | 73.6s
# [183/400] train loss=0.049769, nmse(dB)=-8.3080 | val loss=0.011041, nmse(dB)=-15.1469 | 74.2s
# [184/400] train loss=0.047317, nmse(dB)=-8.4215 | val loss=0.011031, nmse(dB)=-15.1544 | 74.0s
# [185/400] train loss=0.049776, nmse(dB)=-8.2271 | val loss=0.011051, nmse(dB)=-15.1369 | 73.1s
# [186/400] train loss=0.051687, nmse(dB)=-8.0610 | val loss=0.011088, nmse(dB)=-15.1067 | 73.4s
# [187/400] train loss=0.049290, nmse(dB)=-8.3164 | val loss=0.011106, nmse(dB)=-15.0914 | 73.3s
# [188/400] train loss=0.048963, nmse(dB)=-8.3371 | val loss=0.011115, nmse(dB)=-15.0830 | 73.7s
# [189/400] train loss=0.047760, nmse(dB)=-8.3858 | val loss=0.011111, nmse(dB)=-15.0870 | 74.3s
# [190/400] train loss=0.048474, nmse(dB)=-8.3096 | val loss=0.011084, nmse(dB)=-15.1088 | 73.3s
# [191/400] train loss=0.048735, nmse(dB)=-8.3741 | val loss=0.011070, nmse(dB)=-15.1222 | 73.6s
# [192/400] train loss=0.049308, nmse(dB)=-8.2777 | val loss=0.011081, nmse(dB)=-15.1155 | 72.9s
# [193/400] train loss=0.049475, nmse(dB)=-8.2158 | val loss=0.011100, nmse(dB)=-15.1008 | 73.7s
# [194/400] train loss=0.046909, nmse(dB)=-8.4430 | val loss=0.011116, nmse(dB)=-15.0889 | 73.5s
# [195/400] train loss=0.048250, nmse(dB)=-8.3891 | val loss=0.011095, nmse(dB)=-15.1082 | 73.4s
# [196/400] train loss=0.049473, nmse(dB)=-8.2646 | val loss=0.011082, nmse(dB)=-15.1197 | 73.5s
# [197/400] train loss=0.047849, nmse(dB)=-8.3605 | val loss=0.011072, nmse(dB)=-15.1279 | 73.8s
# [198/400] train loss=0.046949, nmse(dB)=-8.4229 | val loss=0.011044, nmse(dB)=-15.1495 | 73.4s
# [199/400] train loss=0.046599, nmse(dB)=-8.4699 | val loss=0.011012, nmse(dB)=-15.1761 | 73.7s
# [200/400] train loss=0.047507, nmse(dB)=-8.3540 | val loss=0.010989, nmse(dB)=-15.1958 | 73.4s
# [201/400] train loss=0.048685, nmse(dB)=-8.3196 | val loss=0.010969, nmse(dB)=-15.2117 | 73.8s
# [202/400] train loss=0.046735, nmse(dB)=-8.5024 | val loss=0.010980, nmse(dB)=-15.2047 | 73.6s
# [203/400] train loss=0.048551, nmse(dB)=-8.3003 | val loss=0.011041, nmse(dB)=-15.1564 | 73.8s
# [204/400] train loss=0.047885, nmse(dB)=-8.4089 | val loss=0.011076, nmse(dB)=-15.1290 | 74.5s
# [205/400] train loss=0.048665, nmse(dB)=-8.3035 | val loss=0.011068, nmse(dB)=-15.1350 | 74.3s
# [206/400] train loss=0.049013, nmse(dB)=-8.2547 | val loss=0.011014, nmse(dB)=-15.1765 | 74.3s
# [207/400] train loss=0.047522, nmse(dB)=-8.4416 | val loss=0.010958, nmse(dB)=-15.2222 | 73.4s
# [208/400] train loss=0.047700, nmse(dB)=-8.3594 | val loss=0.010966, nmse(dB)=-15.2163 | 73.8s
# [209/400] train loss=0.047401, nmse(dB)=-8.3967 | val loss=0.011012, nmse(dB)=-15.1776 | 74.0s
# [210/400] train loss=0.047745, nmse(dB)=-8.4140 | val loss=0.011063, nmse(dB)=-15.1348 | 73.6s
# [211/400] train loss=0.048259, nmse(dB)=-8.3085 | val loss=0.011079, nmse(dB)=-15.1210 | 73.4s
# [212/400] train loss=0.046488, nmse(dB)=-8.5338 | val loss=0.011029, nmse(dB)=-15.1613 | 74.2s
# [213/400] train loss=0.047958, nmse(dB)=-8.4280 | val loss=0.011007, nmse(dB)=-15.1799 | 73.6s
# [214/400] train loss=0.048595, nmse(dB)=-8.3245 | val loss=0.011027, nmse(dB)=-15.1642 | 73.7s
# [215/400] train loss=0.048261, nmse(dB)=-8.3924 | val loss=0.011033, nmse(dB)=-15.1614 | 74.1s
# [216/400] train loss=0.048459, nmse(dB)=-8.3283 | val loss=0.011099, nmse(dB)=-15.1093 | 74.3s
# [217/400] train loss=0.047061, nmse(dB)=-8.4698 | val loss=0.011137, nmse(dB)=-15.0803 | 74.1s
# [218/400] train loss=0.048962, nmse(dB)=-8.3059 | val loss=0.011095, nmse(dB)=-15.1151 | 74.4s
# [219/400] train loss=0.046427, nmse(dB)=-8.4617 | val loss=0.011055, nmse(dB)=-15.1465 | 74.0s
# [220/400] train loss=0.047816, nmse(dB)=-8.3759 | val loss=0.011020, nmse(dB)=-15.1741 | 73.7s
# [221/400] train loss=0.048657, nmse(dB)=-8.3462 | val loss=0.011037, nmse(dB)=-15.1588 | 73.8s
# [222/400] train loss=0.047905, nmse(dB)=-8.4165 | val loss=0.011077, nmse(dB)=-15.1251 | 73.5s
# [223/400] train loss=0.047348, nmse(dB)=-8.4133 | val loss=0.011107, nmse(dB)=-15.0987 | 73.8s
# [224/400] train loss=0.047200, nmse(dB)=-8.4499 | val loss=0.011119, nmse(dB)=-15.0885 | 74.1s
# [225/400] train loss=0.048038, nmse(dB)=-8.3491 | val loss=0.011091, nmse(dB)=-15.1110 | 73.7s
# [226/400] train loss=0.048734, nmse(dB)=-8.2856 | val loss=0.011027, nmse(dB)=-15.1644 | 73.4s
# [227/400] train loss=0.046846, nmse(dB)=-8.5090 | val loss=0.011021, nmse(dB)=-15.1713 | 73.8s
# [228/400] train loss=0.046940, nmse(dB)=-8.3770 | val loss=0.011044, nmse(dB)=-15.1554 | 73.9s
# [229/400] train loss=0.047196, nmse(dB)=-8.4754 | val loss=0.011067, nmse(dB)=-15.1380 | 74.0s
# [230/400] train loss=0.047690, nmse(dB)=-8.3687 | val loss=0.011134, nmse(dB)=-15.0852 | 73.5s
# [231/400] train loss=0.048167, nmse(dB)=-8.3403 | val loss=0.011086, nmse(dB)=-15.1229 | 74.3s
# [232/400] train loss=0.047361, nmse(dB)=-8.4235 | val loss=0.011005, nmse(dB)=-15.1853 | 74.4s
# [233/400] train loss=0.047488, nmse(dB)=-8.3612 | val loss=0.010984, nmse(dB)=-15.2013 | 73.8s
# [234/400] train loss=0.047368, nmse(dB)=-8.4248 | val loss=0.010982, nmse(dB)=-15.2022 | 74.5s
# [235/400] train loss=0.047631, nmse(dB)=-8.3589 | val loss=0.011015, nmse(dB)=-15.1743 | 73.9s
# [236/400] train loss=0.048610, nmse(dB)=-8.3297 | val loss=0.011065, nmse(dB)=-15.1332 | 74.0s
# [237/400] train loss=0.048029, nmse(dB)=-8.3629 | val loss=0.011124, nmse(dB)=-15.0860 | 73.1s
# [238/400] train loss=0.047306, nmse(dB)=-8.4304 | val loss=0.011100, nmse(dB)=-15.1046 | 74.1s
# [239/400] train loss=0.046987, nmse(dB)=-8.4830 | val loss=0.011076, nmse(dB)=-15.1224 | 73.7s
# [240/400] train loss=0.049042, nmse(dB)=-8.2478 | val loss=0.011057, nmse(dB)=-15.1373 | 73.6s
# [241/400] train loss=0.046295, nmse(dB)=-8.5233 | val loss=0.011042, nmse(dB)=-15.1491 | 73.4s
# [242/400] train loss=0.047400, nmse(dB)=-8.4580 | val loss=0.011063, nmse(dB)=-15.1334 | 73.9s
# [243/400] train loss=0.047654, nmse(dB)=-8.3825 | val loss=0.011093, nmse(dB)=-15.1090 | 74.0s
# [244/400] train loss=0.047666, nmse(dB)=-8.3273 | val loss=0.011080, nmse(dB)=-15.1206 | 74.0s
# [245/400] train loss=0.048996, nmse(dB)=-8.2463 | val loss=0.011031, nmse(dB)=-15.1611 | 73.7s
# [246/400] train loss=0.047507, nmse(dB)=-8.4457 | val loss=0.010989, nmse(dB)=-15.1953 | 74.0s
# [247/400] train loss=0.047093, nmse(dB)=-8.4246 | val loss=0.010991, nmse(dB)=-15.1959 | 74.1s
# [248/400] train loss=0.046481, nmse(dB)=-8.4182 | val loss=0.011016, nmse(dB)=-15.1775 | 74.1s
# [249/400] train loss=0.046729, nmse(dB)=-8.4403 | val loss=0.011039, nmse(dB)=-15.1607 | 73.6s
# [250/400] train loss=0.048561, nmse(dB)=-8.3026 | val loss=0.011044, nmse(dB)=-15.1577 | 73.3s
# [251/400] train loss=0.047380, nmse(dB)=-8.3772 | val loss=0.011030, nmse(dB)=-15.1690 | 73.0s
# [252/400] train loss=0.049236, nmse(dB)=-8.2057 | val loss=0.011016, nmse(dB)=-15.1792 | 74.0s
# [253/400] train loss=0.046608, nmse(dB)=-8.4909 | val loss=0.011012, nmse(dB)=-15.1816 | 73.8s
# [254/400] train loss=0.046609, nmse(dB)=-8.4659 | val loss=0.011050, nmse(dB)=-15.1494 | 73.4s
# [255/400] train loss=0.047800, nmse(dB)=-8.3779 | val loss=0.011075, nmse(dB)=-15.1286 | 73.9s
# [256/400] train loss=0.048337, nmse(dB)=-8.3201 | val loss=0.011091, nmse(dB)=-15.1153 | 74.0s
# [257/400] train loss=0.047173, nmse(dB)=-8.4018 | val loss=0.011077, nmse(dB)=-15.1263 | 72.4s
# [258/400] train loss=0.046500, nmse(dB)=-8.4740 | val loss=0.011065, nmse(dB)=-15.1360 | 73.6s
# [259/400] train loss=0.046550, nmse(dB)=-8.4572 | val loss=0.011058, nmse(dB)=-15.1426 | 73.0s
# [260/400] train loss=0.047295, nmse(dB)=-8.4503 | val loss=0.011056, nmse(dB)=-15.1453 | 73.7s
# [261/400] train loss=0.047737, nmse(dB)=-8.3158 | val loss=0.011081, nmse(dB)=-15.1252 | 73.8s
# [262/400] train loss=0.047525, nmse(dB)=-8.3997 | val loss=0.011066, nmse(dB)=-15.1369 | 73.8s
# [263/400] train loss=0.047430, nmse(dB)=-8.4444 | val loss=0.011044, nmse(dB)=-15.1532 | 74.0s
# [264/400] train loss=0.045801, nmse(dB)=-8.5226 | val loss=0.011042, nmse(dB)=-15.1531 | 74.2s
# [265/400] train loss=0.048852, nmse(dB)=-8.3220 | val loss=0.011053, nmse(dB)=-15.1429 | 73.7s
# [266/400] train loss=0.047043, nmse(dB)=-8.4509 | val loss=0.011086, nmse(dB)=-15.1145 | 73.1s
# [267/400] train loss=0.046030, nmse(dB)=-8.4936 | val loss=0.011125, nmse(dB)=-15.0826 | 73.7s
# [268/400] train loss=0.049215, nmse(dB)=-8.2915 | val loss=0.011118, nmse(dB)=-15.0866 | 73.9s
# [269/400] train loss=0.048517, nmse(dB)=-8.3410 | val loss=0.011127, nmse(dB)=-15.0783 | 74.4s
# [270/400] train loss=0.045968, nmse(dB)=-8.5024 | val loss=0.011120, nmse(dB)=-15.0824 | 73.5s
# [271/400] train loss=0.048021, nmse(dB)=-8.3076 | val loss=0.011100, nmse(dB)=-15.0983 | 73.5s
# [272/400] train loss=0.046993, nmse(dB)=-8.4443 | val loss=0.011078, nmse(dB)=-15.1165 | 74.3s
# [273/400] train loss=0.046975, nmse(dB)=-8.3810 | val loss=0.011055, nmse(dB)=-15.1361 | 73.6s
# [274/400] train loss=0.047057, nmse(dB)=-8.4372 | val loss=0.011045, nmse(dB)=-15.1451 | 73.9s
# [275/400] train loss=0.048770, nmse(dB)=-8.2745 | val loss=0.011054, nmse(dB)=-15.1396 | 74.6s
# [276/400] train loss=0.046360, nmse(dB)=-8.4999 | val loss=0.011071, nmse(dB)=-15.1280 | 74.4s
# [277/400] train loss=0.049000, nmse(dB)=-8.3168 | val loss=0.011105, nmse(dB)=-15.1025 | 73.2s
# [278/400] train loss=0.047953, nmse(dB)=-8.3620 | val loss=0.011132, nmse(dB)=-15.0819 | 73.6s
# [279/400] train loss=0.045853, nmse(dB)=-8.4445 | val loss=0.011127, nmse(dB)=-15.0855 | 73.8s
# [280/400] train loss=0.047005, nmse(dB)=-8.3908 | val loss=0.011078, nmse(dB)=-15.1241 | 73.3s
# [281/400] train loss=0.047298, nmse(dB)=-8.4085 | val loss=0.011048, nmse(dB)=-15.1489 | 73.9s
# [282/400] train loss=0.048679, nmse(dB)=-8.2674 | val loss=0.011047, nmse(dB)=-15.1497 | 73.6s
# [283/400] train loss=0.046855, nmse(dB)=-8.4375 | val loss=0.011056, nmse(dB)=-15.1422 | 74.1s
# [284/400] train loss=0.048186, nmse(dB)=-8.3287 | val loss=0.011082, nmse(dB)=-15.1217 | 73.7s
# [285/400] train loss=0.046951, nmse(dB)=-8.3840 | val loss=0.011128, nmse(dB)=-15.0861 | 74.3s
# [286/400] train loss=0.046948, nmse(dB)=-8.4640 | val loss=0.011126, nmse(dB)=-15.0874 | 74.3s
# [287/400] train loss=0.046030, nmse(dB)=-8.5010 | val loss=0.011121, nmse(dB)=-15.0909 | 74.1s
# [288/400] train loss=0.048231, nmse(dB)=-8.3200 | val loss=0.011105, nmse(dB)=-15.1034 | 74.7s
# [289/400] train loss=0.048076, nmse(dB)=-8.3387 | val loss=0.011095, nmse(dB)=-15.1103 | 74.7s
# [290/400] train loss=0.046019, nmse(dB)=-8.5298 | val loss=0.011088, nmse(dB)=-15.1152 | 73.9s
# [291/400] train loss=0.046916, nmse(dB)=-8.4141 | val loss=0.011092, nmse(dB)=-15.1115 | 74.0s
# [292/400] train loss=0.047412, nmse(dB)=-8.3814 | val loss=0.011093, nmse(dB)=-15.1103 | 74.1s
# [293/400] train loss=0.047024, nmse(dB)=-8.4080 | val loss=0.011082, nmse(dB)=-15.1187 | 73.9s
# [294/400] train loss=0.047426, nmse(dB)=-8.4352 | val loss=0.011070, nmse(dB)=-15.1277 | 73.9s
# [295/400] train loss=0.047785, nmse(dB)=-8.3608 | val loss=0.011077, nmse(dB)=-15.1225 | 74.1s
# [296/400] train loss=0.048233, nmse(dB)=-8.2935 | val loss=0.011097, nmse(dB)=-15.1073 | 73.9s
# [297/400] train loss=0.046008, nmse(dB)=-8.4812 | val loss=0.011098, nmse(dB)=-15.1069 | 74.0s
# [298/400] train loss=0.045961, nmse(dB)=-8.4749 | val loss=0.011087, nmse(dB)=-15.1160 | 73.7s
# [299/400] train loss=0.049387, nmse(dB)=-8.3065 | val loss=0.011055, nmse(dB)=-15.1413 | 73.9s
# [300/400] train loss=0.048084, nmse(dB)=-8.3224 | val loss=0.011059, nmse(dB)=-15.1392 | 73.3s
# [301/400] train loss=0.046862, nmse(dB)=-8.4790 | val loss=0.011054, nmse(dB)=-15.1441 | 73.7s
# [302/400] train loss=0.047887, nmse(dB)=-8.3777 | val loss=0.011071, nmse(dB)=-15.1312 | 73.8s
# [303/400] train loss=0.045442, nmse(dB)=-8.5089 | val loss=0.011087, nmse(dB)=-15.1189 | 72.8s
# [304/400] train loss=0.045299, nmse(dB)=-8.6023 | val loss=0.011071, nmse(dB)=-15.1315 | 73.3s
# [305/400] train loss=0.047073, nmse(dB)=-8.3443 | val loss=0.011071, nmse(dB)=-15.1318 | 73.6s
# [306/400] train loss=0.048271, nmse(dB)=-8.3837 | val loss=0.011049, nmse(dB)=-15.1493 | 73.8s
# [307/400] train loss=0.047561, nmse(dB)=-8.4402 | val loss=0.011047, nmse(dB)=-15.1508 | 73.8s
# [308/400] train loss=0.048313, nmse(dB)=-8.3175 | val loss=0.011066, nmse(dB)=-15.1363 | 74.3s
# [309/400] train loss=0.047469, nmse(dB)=-8.3594 | val loss=0.011069, nmse(dB)=-15.1338 | 73.9s
# [310/400] train loss=0.047611, nmse(dB)=-8.3284 | val loss=0.011044, nmse(dB)=-15.1525 | 73.5s
# [311/400] train loss=0.045678, nmse(dB)=-8.5697 | val loss=0.011032, nmse(dB)=-15.1625 | 72.7s
# [312/400] train loss=0.047257, nmse(dB)=-8.3810 | val loss=0.011027, nmse(dB)=-15.1665 | 73.5s
# [313/400] train loss=0.045898, nmse(dB)=-8.4834 | val loss=0.011027, nmse(dB)=-15.1664 | 73.7s
# [314/400] train loss=0.046734, nmse(dB)=-8.4296 | val loss=0.011031, nmse(dB)=-15.1632 | 74.2s
# [315/400] train loss=0.048795, nmse(dB)=-8.3074 | val loss=0.011032, nmse(dB)=-15.1626 | 73.2s
# [316/400] train loss=0.047064, nmse(dB)=-8.3522 | val loss=0.011041, nmse(dB)=-15.1545 | 73.8s
# [317/400] train loss=0.046349, nmse(dB)=-8.4803 | val loss=0.011046, nmse(dB)=-15.1501 | 73.6s
# [318/400] train loss=0.046448, nmse(dB)=-8.5124 | val loss=0.011045, nmse(dB)=-15.1502 | 73.4s
# [319/400] train loss=0.047240, nmse(dB)=-8.3942 | val loss=0.011054, nmse(dB)=-15.1436 | 73.5s
# [320/400] train loss=0.047082, nmse(dB)=-8.4874 | val loss=0.011052, nmse(dB)=-15.1452 | 74.5s
# [321/400] train loss=0.046159, nmse(dB)=-8.5289 | val loss=0.011056, nmse(dB)=-15.1421 | 74.1s
# [322/400] train loss=0.045866, nmse(dB)=-8.5720 | val loss=0.011055, nmse(dB)=-15.1438 | 74.2s
# [323/400] train loss=0.047180, nmse(dB)=-8.4265 | val loss=0.011058, nmse(dB)=-15.1414 | 74.8s
# [324/400] train loss=0.046165, nmse(dB)=-8.4774 | val loss=0.011060, nmse(dB)=-15.1403 | 74.5s
# [325/400] train loss=0.047279, nmse(dB)=-8.4012 | val loss=0.011051, nmse(dB)=-15.1471 | 74.9s
# [326/400] train loss=0.046848, nmse(dB)=-8.3779 | val loss=0.011042, nmse(dB)=-15.1543 | 74.0s
# [327/400] train loss=0.048645, nmse(dB)=-8.2810 | val loss=0.011030, nmse(dB)=-15.1641 | 74.9s
# [328/400] train loss=0.046107, nmse(dB)=-8.5344 | val loss=0.011028, nmse(dB)=-15.1661 | 73.8s
# [329/400] train loss=0.048458, nmse(dB)=-8.3425 | val loss=0.011035, nmse(dB)=-15.1611 | 74.1s
# [330/400] train loss=0.046487, nmse(dB)=-8.5424 | val loss=0.011046, nmse(dB)=-15.1530 | 74.3s
# [331/400] train loss=0.045398, nmse(dB)=-8.5533 | val loss=0.011064, nmse(dB)=-15.1388 | 73.7s
# [332/400] train loss=0.045966, nmse(dB)=-8.4858 | val loss=0.011080, nmse(dB)=-15.1266 | 73.8s
# [333/400] train loss=0.047033, nmse(dB)=-8.4018 | val loss=0.011080, nmse(dB)=-15.1266 | 74.6s
# [334/400] train loss=0.048032, nmse(dB)=-8.3645 | val loss=0.011073, nmse(dB)=-15.1320 | 74.0s
# [335/400] train loss=0.047250, nmse(dB)=-8.4509 | val loss=0.011071, nmse(dB)=-15.1336 | 74.3s
# [336/400] train loss=0.045821, nmse(dB)=-8.4887 | val loss=0.011073, nmse(dB)=-15.1313 | 74.4s
# [337/400] train loss=0.047271, nmse(dB)=-8.3994 | val loss=0.011074, nmse(dB)=-15.1305 | 74.0s
# [338/400] train loss=0.048998, nmse(dB)=-8.2973 | val loss=0.011064, nmse(dB)=-15.1385 | 73.8s
# [339/400] train loss=0.047388, nmse(dB)=-8.4236 | val loss=0.011063, nmse(dB)=-15.1385 | 73.9s
# [340/400] train loss=0.046766, nmse(dB)=-8.4716 | val loss=0.011064, nmse(dB)=-15.1377 | 73.7s
# [341/400] train loss=0.047962, nmse(dB)=-8.3402 | val loss=0.011071, nmse(dB)=-15.1317 | 73.7s
# [342/400] train loss=0.046976, nmse(dB)=-8.4242 | val loss=0.011075, nmse(dB)=-15.1282 | 73.8s
# [343/400] train loss=0.046705, nmse(dB)=-8.4098 | val loss=0.011073, nmse(dB)=-15.1297 | 73.6s
# [344/400] train loss=0.047639, nmse(dB)=-8.3877 | val loss=0.011066, nmse(dB)=-15.1351 | 73.7s
# [345/400] train loss=0.047204, nmse(dB)=-8.3898 | val loss=0.011058, nmse(dB)=-15.1409 | 73.8s
# [346/400] train loss=0.048299, nmse(dB)=-8.3461 | val loss=0.011050, nmse(dB)=-15.1472 | 73.8s
# [347/400] train loss=0.047133, nmse(dB)=-8.3942 | val loss=0.011044, nmse(dB)=-15.1526 | 73.9s
# [348/400] train loss=0.046452, nmse(dB)=-8.5035 | val loss=0.011042, nmse(dB)=-15.1539 | 73.7s
# [349/400] train loss=0.046322, nmse(dB)=-8.5214 | val loss=0.011042, nmse(dB)=-15.1534 | 73.7s
# [350/400] train loss=0.047356, nmse(dB)=-8.3511 | val loss=0.011050, nmse(dB)=-15.1478 | 73.8s
# [351/400] train loss=0.048601, nmse(dB)=-8.3387 | val loss=0.011052, nmse(dB)=-15.1461 | 73.9s
# [352/400] train loss=0.047450, nmse(dB)=-8.4380 | val loss=0.011054, nmse(dB)=-15.1442 | 74.4s
# [353/400] train loss=0.048163, nmse(dB)=-8.2453 | val loss=0.011059, nmse(dB)=-15.1401 | 74.4s
# [354/400] train loss=0.046904, nmse(dB)=-8.4151 | val loss=0.011059, nmse(dB)=-15.1401 | 74.2s
# [355/400] train loss=0.047547, nmse(dB)=-8.3862 | val loss=0.011059, nmse(dB)=-15.1398 | 74.1s
# [356/400] train loss=0.046272, nmse(dB)=-8.4778 | val loss=0.011059, nmse(dB)=-15.1400 | 74.6s
# [357/400] train loss=0.047131, nmse(dB)=-8.4335 | val loss=0.011057, nmse(dB)=-15.1419 | 74.6s
# [358/400] train loss=0.048407, nmse(dB)=-8.3041 | val loss=0.011055, nmse(dB)=-15.1429 | 74.1s
# [359/400] train loss=0.046459, nmse(dB)=-8.4554 | val loss=0.011053, nmse(dB)=-15.1445 | 74.3s
# [360/400] train loss=0.047160, nmse(dB)=-8.4547 | val loss=0.011053, nmse(dB)=-15.1443 | 74.1s
# [361/400] train loss=0.046288, nmse(dB)=-8.4532 | val loss=0.011054, nmse(dB)=-15.1441 | 74.0s
# [362/400] train loss=0.046595, nmse(dB)=-8.4286 | val loss=0.011054, nmse(dB)=-15.1442 | 73.6s
# [363/400] train loss=0.048012, nmse(dB)=-8.2783 | val loss=0.011052, nmse(dB)=-15.1462 | 74.1s
# [364/400] train loss=0.048174, nmse(dB)=-8.3266 | val loss=0.011049, nmse(dB)=-15.1481 | 73.7s
# [365/400] train loss=0.047048, nmse(dB)=-8.3641 | val loss=0.011047, nmse(dB)=-15.1499 | 74.2s
# [366/400] train loss=0.048202, nmse(dB)=-8.2729 | val loss=0.011043, nmse(dB)=-15.1530 | 73.6s
# [367/400] train loss=0.047739, nmse(dB)=-8.3861 | val loss=0.011041, nmse(dB)=-15.1553 | 74.8s
# [368/400] train loss=0.046334, nmse(dB)=-8.5434 | val loss=0.011039, nmse(dB)=-15.1567 | 74.0s
# [369/400] train loss=0.046468, nmse(dB)=-8.4574 | val loss=0.011042, nmse(dB)=-15.1546 | 74.7s
# [370/400] train loss=0.047119, nmse(dB)=-8.4033 | val loss=0.011044, nmse(dB)=-15.1528 | 74.0s
# [371/400] train loss=0.045933, nmse(dB)=-8.5314 | val loss=0.011046, nmse(dB)=-15.1513 | 73.9s
# [372/400] train loss=0.048091, nmse(dB)=-8.3168 | val loss=0.011048, nmse(dB)=-15.1499 | 73.7s
# [373/400] train loss=0.046003, nmse(dB)=-8.5233 | val loss=0.011048, nmse(dB)=-15.1502 | 74.0s
# [374/400] train loss=0.048613, nmse(dB)=-8.2832 | val loss=0.011048, nmse(dB)=-15.1495 | 74.1s
# [375/400] train loss=0.046269, nmse(dB)=-8.5054 | val loss=0.011048, nmse(dB)=-15.1497 | 73.6s
# [376/400] train loss=0.048211, nmse(dB)=-8.3285 | val loss=0.011050, nmse(dB)=-15.1484 | 74.0s
# [377/400] train loss=0.045588, nmse(dB)=-8.4998 | val loss=0.011051, nmse(dB)=-15.1477 | 74.0s
# [378/400] train loss=0.047086, nmse(dB)=-8.3789 | val loss=0.011052, nmse(dB)=-15.1471 | 74.2s
# [379/400] train loss=0.048025, nmse(dB)=-8.3118 | val loss=0.011052, nmse(dB)=-15.1465 | 74.4s
# [380/400] train loss=0.047440, nmse(dB)=-8.3972 | val loss=0.011053, nmse(dB)=-15.1464 | 74.5s
# [381/400] train loss=0.045145, nmse(dB)=-8.5155 | val loss=0.011053, nmse(dB)=-15.1460 | 73.8s
# [382/400] train loss=0.047129, nmse(dB)=-8.4129 | val loss=0.011053, nmse(dB)=-15.1463 | 74.0s
# [383/400] train loss=0.047988, nmse(dB)=-8.3045 | val loss=0.011052, nmse(dB)=-15.1464 | 74.3s
# [384/400] train loss=0.048672, nmse(dB)=-8.2838 | val loss=0.011052, nmse(dB)=-15.1469 | 74.0s
# [385/400] train loss=0.047458, nmse(dB)=-8.3795 | val loss=0.011051, nmse(dB)=-15.1474 | 73.8s
# [386/400] train loss=0.047298, nmse(dB)=-8.3071 | val loss=0.011051, nmse(dB)=-15.1478 | 73.2s
# [387/400] train loss=0.045924, nmse(dB)=-8.4784 | val loss=0.011050, nmse(dB)=-15.1485 | 74.1s
# [388/400] train loss=0.047617, nmse(dB)=-8.4068 | val loss=0.011049, nmse(dB)=-15.1489 | 74.0s
# [389/400] train loss=0.045388, nmse(dB)=-8.5148 | val loss=0.011049, nmse(dB)=-15.1490 | 74.3s
# [390/400] train loss=0.046932, nmse(dB)=-8.4024 | val loss=0.011049, nmse(dB)=-15.1492 | 74.5s
# [391/400] train loss=0.048981, nmse(dB)=-8.2550 | val loss=0.011049, nmse(dB)=-15.1492 | 74.3s
# [392/400] train loss=0.046857, nmse(dB)=-8.3799 | val loss=0.011049, nmse(dB)=-15.1493 | 74.1s
# [393/400] train loss=0.046657, nmse(dB)=-8.4417 | val loss=0.011049, nmse(dB)=-15.1494 | 74.0s
# [394/400] train loss=0.046563, nmse(dB)=-8.4683 | val loss=0.011049, nmse(dB)=-15.1495 | 74.1s
# [395/400] train loss=0.047215, nmse(dB)=-8.4062 | val loss=0.011049, nmse(dB)=-15.1494 | 74.2s
# [396/400] train loss=0.048124, nmse(dB)=-8.3809 | val loss=0.011049, nmse(dB)=-15.1494 | 74.5s
# [397/400] train loss=0.047337, nmse(dB)=-8.4194 | val loss=0.011049, nmse(dB)=-15.1494 | 74.3s
# [398/400] train loss=0.046630, nmse(dB)=-8.4533 | val loss=0.011049, nmse(dB)=-15.1494 | 74.0s
# [399/400] train loss=0.045448, nmse(dB)=-8.5350 | val loss=0.011049, nmse(dB)=-15.1494 | 74.3s
# [400/400] train loss=0.048374, nmse(dB)=-8.2813 | val loss=0.011049, nmse(dB)=-15.1494 | 74.1s
#
# === Training: LSTM Early Fusion ===
# trainable params: 2247616
# [01/400] train loss=0.294219, nmse(dB)=0.0326 | val loss=0.257559, nmse(dB)=-0.0064 | 74.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [02/400] train loss=0.288475, nmse(dB)=-0.0179 | val loss=0.254031, nmse(dB)=-0.0663 | 74.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [03/400] train loss=0.289083, nmse(dB)=-0.0727 | val loss=0.249491, nmse(dB)=-0.1447 | 74.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [04/400] train loss=0.281191, nmse(dB)=-0.1482 | val loss=0.243294, nmse(dB)=-0.2541 | 73.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [05/400] train loss=0.271254, nmse(dB)=-0.2527 | val loss=0.234913, nmse(dB)=-0.4065 | 74.8s
#   ↳ saved best_lstm_earlyfusion.pt
# [06/400] train loss=0.269221, nmse(dB)=-0.3916 | val loss=0.223917, nmse(dB)=-0.6149 | 74.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [07/400] train loss=0.256003, nmse(dB)=-0.5868 | val loss=0.210119, nmse(dB)=-0.8915 | 74.2s
#   ↳ saved best_lstm_earlyfusion.pt
# [08/400] train loss=0.242827, nmse(dB)=-0.8329 | val loss=0.193656, nmse(dB)=-1.2463 | 74.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [09/400] train loss=0.223717, nmse(dB)=-1.1553 | val loss=0.175123, nmse(dB)=-1.6840 | 74.2s
#   ↳ saved best_lstm_earlyfusion.pt
# [10/400] train loss=0.206249, nmse(dB)=-1.5450 | val loss=0.155575, nmse(dB)=-2.1992 | 73.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [11/400] train loss=0.188200, nmse(dB)=-1.9438 | val loss=0.136346, nmse(dB)=-2.7738 | 74.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [12/400] train loss=0.167361, nmse(dB)=-2.4113 | val loss=0.118915, nmse(dB)=-3.3701 | 73.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [13/400] train loss=0.152476, nmse(dB)=-2.8719 | val loss=0.104222, nmse(dB)=-3.9457 | 74.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [14/400] train loss=0.137146, nmse(dB)=-3.2894 | val loss=0.092006, nmse(dB)=-4.4907 | 73.7s
#   ↳ saved best_lstm_earlyfusion.pt
# [15/400] train loss=0.126356, nmse(dB)=-3.6481 | val loss=0.081044, nmse(dB)=-5.0463 | 74.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [16/400] train loss=0.116412, nmse(dB)=-4.0442 | val loss=0.070478, nmse(dB)=-5.6598 | 74.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [17/400] train loss=0.106456, nmse(dB)=-4.4527 | val loss=0.060613, nmse(dB)=-6.3246 | 73.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [18/400] train loss=0.095588, nmse(dB)=-4.9225 | val loss=0.051875, nmse(dB)=-7.0144 | 73.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [19/400] train loss=0.087790, nmse(dB)=-5.2895 | val loss=0.044514, nmse(dB)=-7.6974 | 73.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [20/400] train loss=0.081019, nmse(dB)=-5.7548 | val loss=0.038470, nmse(dB)=-8.3547 | 74.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [21/400] train loss=0.075084, nmse(dB)=-6.1164 | val loss=0.033427, nmse(dB)=-8.9950 | 73.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [22/400] train loss=0.070822, nmse(dB)=-6.3878 | val loss=0.029169, nmse(dB)=-9.6254 | 73.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [23/400] train loss=0.066749, nmse(dB)=-6.6801 | val loss=0.025663, nmse(dB)=-10.2289 | 74.7s
#   ↳ saved best_lstm_earlyfusion.pt
# [24/400] train loss=0.063880, nmse(dB)=-6.9193 | val loss=0.022844, nmse(dB)=-10.7900 | 74.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [25/400] train loss=0.061217, nmse(dB)=-7.2057 | val loss=0.020600, nmse(dB)=-11.3017 | 74.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [26/400] train loss=0.059584, nmse(dB)=-7.2594 | val loss=0.018822, nmse(dB)=-11.7617 | 74.9s
#   ↳ saved best_lstm_earlyfusion.pt
# [27/400] train loss=0.055275, nmse(dB)=-7.6152 | val loss=0.017353, nmse(dB)=-12.1898 | 74.2s
#   ↳ saved best_lstm_earlyfusion.pt
# [28/400] train loss=0.054696, nmse(dB)=-7.6976 | val loss=0.016117, nmse(dB)=-12.5936 | 73.7s
#   ↳ saved best_lstm_earlyfusion.pt
# [29/400] train loss=0.052999, nmse(dB)=-7.7826 | val loss=0.015122, nmse(dB)=-12.9571 | 74.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [30/400] train loss=0.053064, nmse(dB)=-7.8043 | val loss=0.014332, nmse(dB)=-13.2769 | 73.8s
#   ↳ saved best_lstm_earlyfusion.pt
# [31/400] train loss=0.052234, nmse(dB)=-7.9619 | val loss=0.013735, nmse(dB)=-13.5410 | 73.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [32/400] train loss=0.051126, nmse(dB)=-8.0413 | val loss=0.013241, nmse(dB)=-13.7769 | 74.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [33/400] train loss=0.051244, nmse(dB)=-7.9887 | val loss=0.012797, nmse(dB)=-14.0059 | 73.8s
#   ↳ saved best_lstm_earlyfusion.pt
# [34/400] train loss=0.050009, nmse(dB)=-8.1297 | val loss=0.012431, nmse(dB)=-14.2086 | 73.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [35/400] train loss=0.050507, nmse(dB)=-8.1603 | val loss=0.012123, nmse(dB)=-14.3915 | 73.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [36/400] train loss=0.050537, nmse(dB)=-8.1375 | val loss=0.011875, nmse(dB)=-14.5481 | 74.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [37/400] train loss=0.051637, nmse(dB)=-8.0724 | val loss=0.011673, nmse(dB)=-14.6832 | 74.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [38/400] train loss=0.051788, nmse(dB)=-8.0677 | val loss=0.011516, nmse(dB)=-14.7935 | 73.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [39/400] train loss=0.050666, nmse(dB)=-8.1595 | val loss=0.011390, nmse(dB)=-14.8862 | 73.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [40/400] train loss=0.050033, nmse(dB)=-8.1588 | val loss=0.011283, nmse(dB)=-14.9680 | 73.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [41/400] train loss=0.048437, nmse(dB)=-8.3260 | val loss=0.011216, nmse(dB)=-15.0209 | 73.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [42/400] train loss=0.049468, nmse(dB)=-8.2770 | val loss=0.011168, nmse(dB)=-15.0587 | 73.4s
#   ↳ saved best_lstm_earlyfusion.pt
# [43/400] train loss=0.047439, nmse(dB)=-8.4035 | val loss=0.011130, nmse(dB)=-15.0890 | 74.2s
#   ↳ saved best_lstm_earlyfusion.pt
# [44/400] train loss=0.050218, nmse(dB)=-8.2099 | val loss=0.011101, nmse(dB)=-15.1131 | 73.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [45/400] train loss=0.049407, nmse(dB)=-8.2358 | val loss=0.011080, nmse(dB)=-15.1301 | 74.7s
#   ↳ saved best_lstm_earlyfusion.pt
# [46/400] train loss=0.050733, nmse(dB)=-8.1791 | val loss=0.011060, nmse(dB)=-15.1466 | 74.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [47/400] train loss=0.048848, nmse(dB)=-8.2964 | val loss=0.011034, nmse(dB)=-15.1675 | 74.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [48/400] train loss=0.048358, nmse(dB)=-8.2777 | val loss=0.011015, nmse(dB)=-15.1818 | 73.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [49/400] train loss=0.050729, nmse(dB)=-8.1620 | val loss=0.011014, nmse(dB)=-15.1801 | 74.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [50/400] train loss=0.049299, nmse(dB)=-8.2803 | val loss=0.011025, nmse(dB)=-15.1676 | 74.0s
# [51/400] train loss=0.048563, nmse(dB)=-8.2849 | val loss=0.011024, nmse(dB)=-15.1642 | 74.4s
# [52/400] train loss=0.049339, nmse(dB)=-8.2419 | val loss=0.011023, nmse(dB)=-15.1617 | 73.4s
# [53/400] train loss=0.047914, nmse(dB)=-8.3565 | val loss=0.011012, nmse(dB)=-15.1691 | 74.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [54/400] train loss=0.049602, nmse(dB)=-8.3021 | val loss=0.011008, nmse(dB)=-15.1740 | 74.1s
#   ↳ saved best_lstm_earlyfusion.pt
# [55/400] train loss=0.048469, nmse(dB)=-8.3518 | val loss=0.010992, nmse(dB)=-15.1863 | 73.5s
#   ↳ saved best_lstm_earlyfusion.pt
# [56/400] train loss=0.048904, nmse(dB)=-8.3271 | val loss=0.010974, nmse(dB)=-15.2001 | 73.6s
#   ↳ saved best_lstm_earlyfusion.pt
# [57/400] train loss=0.049815, nmse(dB)=-8.2057 | val loss=0.010954, nmse(dB)=-15.2173 | 74.3s
#   ↳ saved best_lstm_earlyfusion.pt
# [58/400] train loss=0.049945, nmse(dB)=-8.1772 | val loss=0.010945, nmse(dB)=-15.2256 | 74.0s
#   ↳ saved best_lstm_earlyfusion.pt
# [59/400] train loss=0.049803, nmse(dB)=-8.2349 | val loss=0.010947, nmse(dB)=-15.2255 | 73.7s
# [60/400] train loss=0.049376, nmse(dB)=-8.2578 | val loss=0.010956, nmse(dB)=-15.2203 | 73.6s
# [61/400] train loss=0.048082, nmse(dB)=-8.3443 | val loss=0.010954, nmse(dB)=-15.2232 | 73.8s
# [62/400] train loss=0.048399, nmse(dB)=-8.3095 | val loss=0.010959, nmse(dB)=-15.2209 | 74.2s
# [63/400] train loss=0.049479, nmse(dB)=-8.2149 | val loss=0.010969, nmse(dB)=-15.2122 | 73.3s
# [64/400] train loss=0.048402, nmse(dB)=-8.3229 | val loss=0.010982, nmse(dB)=-15.2006 | 74.4s
# [65/400] train loss=0.046508, nmse(dB)=-8.4614 | val loss=0.010997, nmse(dB)=-15.1859 | 74.2s
# [66/400] train loss=0.048957, nmse(dB)=-8.2326 | val loss=0.011005, nmse(dB)=-15.1773 | 74.1s
# ...
# [234/400] train loss=0.047127, nmse(dB)=-8.3615 | val loss=0.011023, nmse(dB)=-15.1787 | 71.5s
# [235/400] train loss=0.046606, nmse(dB)=-8.4216 | val loss=0.010954, nmse(dB)=-15.2361 | 71.9s
# [236/400] train loss=0.046155, nmse(dB)=-8.4856 | val loss=0.010947, nmse(dB)=-15.2412 | 72.0s
# [237/400] train loss=0.046767, nmse(dB)=-8.4117 | val loss=0.011023, nmse(dB)=-15.1783 | 72.8s
# [238/400] train loss=0.045854, nmse(dB)=-8.4954 | val loss=0.011134, nmse(dB)=-15.0880 | 71.7s
# [239/400] train loss=0.046884, nmse(dB)=-8.3689 | val loss=0.011116, nmse(dB)=-15.1010 | 71.3s
# [240/400] train loss=0.046063, nmse(dB)=-8.4807 | val loss=0.010983, nmse(dB)=-15.2065 | 71.9s
# [241/400] train loss=0.046966, nmse(dB)=-8.3916 | val loss=0.010964, nmse(dB)=-15.2211 | 71.3s
# [242/400] train loss=0.046650, nmse(dB)=-8.4820 | val loss=0.010987, nmse(dB)=-15.2010 | 72.2s
# [243/400] train loss=0.047869, nmse(dB)=-8.3606 | val loss=0.011093, nmse(dB)=-15.1147 | 73.0s
# [244/400] train loss=0.047409, nmse(dB)=-8.4053 | val loss=0.011247, nmse(dB)=-14.9942 | 72.2s
# [245/400] train loss=0.046295, nmse(dB)=-8.4393 | val loss=0.011239, nmse(dB)=-14.9996 | 71.3s
# [246/400] train loss=0.046218, nmse(dB)=-8.5397 | val loss=0.011066, nmse(dB)=-15.1340 | 71.4s
# [247/400] train loss=0.046867, nmse(dB)=-8.4294 | val loss=0.010980, nmse(dB)=-15.2033 | 71.7s
# [248/400] train loss=0.046527, nmse(dB)=-8.4326 | val loss=0.010966, nmse(dB)=-15.2166 | 71.7s
# [249/400] train loss=0.046708, nmse(dB)=-8.4307 | val loss=0.010964, nmse(dB)=-15.2187 | 71.9s
# [250/400] train loss=0.047401, nmse(dB)=-8.3368 | val loss=0.011030, nmse(dB)=-15.1655 | 71.6s
# [251/400] train loss=0.046061, nmse(dB)=-8.5191 | val loss=0.011077, nmse(dB)=-15.1279 | 71.5s
# [252/400] train loss=0.046987, nmse(dB)=-8.4281 | val loss=0.011097, nmse(dB)=-15.1130 | 72.5s
# [253/400] train loss=0.046255, nmse(dB)=-8.4647 | val loss=0.011044, nmse(dB)=-15.1554 | 71.2s
# [254/400] train loss=0.047032, nmse(dB)=-8.3722 | val loss=0.010989, nmse(dB)=-15.2006 | 73.1s
# [255/400] train loss=0.046070, nmse(dB)=-8.4958 | val loss=0.010970, nmse(dB)=-15.2166 | 71.8s
# [256/400] train loss=0.045861, nmse(dB)=-8.4583 | val loss=0.010995, nmse(dB)=-15.1971 | 71.7s
# [257/400] train loss=0.046494, nmse(dB)=-8.4967 | val loss=0.011042, nmse(dB)=-15.1590 | 72.0s
# [258/400] train loss=0.045125, nmse(dB)=-8.5371 | val loss=0.011129, nmse(dB)=-15.0900 | 71.5s
# [259/400] train loss=0.046221, nmse(dB)=-8.5010 | val loss=0.011122, nmse(dB)=-15.0952 | 71.6s
# [260/400] train loss=0.045652, nmse(dB)=-8.5093 | val loss=0.011047, nmse(dB)=-15.1548 | 71.8s
# [261/400] train loss=0.044957, nmse(dB)=-8.6176 | val loss=0.011024, nmse(dB)=-15.1727 | 71.8s
# [262/400] train loss=0.046515, nmse(dB)=-8.4313 | val loss=0.011064, nmse(dB)=-15.1397 | 71.9s
# [263/400] train loss=0.047876, nmse(dB)=-8.3188 | val loss=0.011074, nmse(dB)=-15.1308 | 71.5s
# [264/400] train loss=0.047142, nmse(dB)=-8.4053 | val loss=0.011055, nmse(dB)=-15.1458 | 71.8s
# [265/400] train loss=0.046703, nmse(dB)=-8.4117 | val loss=0.011056, nmse(dB)=-15.1449 | 71.5s
# [266/400] train loss=0.045437, nmse(dB)=-8.4303 | val loss=0.011052, nmse(dB)=-15.1475 | 71.4s
# [267/400] train loss=0.045606, nmse(dB)=-8.5115 | val loss=0.011041, nmse(dB)=-15.1564 | 71.5s
# [268/400] train loss=0.047369, nmse(dB)=-8.3955 | val loss=0.011029, nmse(dB)=-15.1666 | 72.0s
# [269/400] train loss=0.045989, nmse(dB)=-8.4895 | val loss=0.011044, nmse(dB)=-15.1547 | 71.8s
# [270/400] train loss=0.045101, nmse(dB)=-8.5391 | val loss=0.011135, nmse(dB)=-15.0839 | 72.6s
# [271/400] train loss=0.045125, nmse(dB)=-8.5691 | val loss=0.011124, nmse(dB)=-15.0928 | 71.7s
# [272/400] train loss=0.045522, nmse(dB)=-8.5347 | val loss=0.011057, nmse(dB)=-15.1450 | 71.6s
# [273/400] train loss=0.045047, nmse(dB)=-8.5542 | val loss=0.011008, nmse(dB)=-15.1837 | 71.4s
# [274/400] train loss=0.044177, nmse(dB)=-8.5969 | val loss=0.010989, nmse(dB)=-15.1977 | 71.8s
# [275/400] train loss=0.045586, nmse(dB)=-8.5202 | val loss=0.010994, nmse(dB)=-15.1934 | 71.5s
# [276/400] train loss=0.046124, nmse(dB)=-8.4971 | val loss=0.011028, nmse(dB)=-15.1664 | 71.6s
# [277/400] train loss=0.046897, nmse(dB)=-8.4451 | val loss=0.011067, nmse(dB)=-15.1350 | 72.5s
# [278/400] train loss=0.046614, nmse(dB)=-8.4131 | val loss=0.011078, nmse(dB)=-15.1270 | 72.0s
# [279/400] train loss=0.045249, nmse(dB)=-8.4846 | val loss=0.011033, nmse(dB)=-15.1636 | 71.4s
# [280/400] train loss=0.044961, nmse(dB)=-8.5461 | val loss=0.010985, nmse(dB)=-15.2027 | 71.4s
# [281/400] train loss=0.045891, nmse(dB)=-8.5155 | val loss=0.010995, nmse(dB)=-15.1945 | 71.9s
# [282/400] train loss=0.047354, nmse(dB)=-8.4091 | val loss=0.011024, nmse(dB)=-15.1716 | 71.8s
# [283/400] train loss=0.045235, nmse(dB)=-8.5300 | val loss=0.011042, nmse(dB)=-15.1578 | 71.8s
# [284/400] train loss=0.046370, nmse(dB)=-8.4616 | val loss=0.011047, nmse(dB)=-15.1538 | 71.6s
# [285/400] train loss=0.044351, nmse(dB)=-8.6124 | val loss=0.011053, nmse(dB)=-15.1489 | 71.9s
# [286/400] train loss=0.046060, nmse(dB)=-8.5230 | val loss=0.011036, nmse(dB)=-15.1634 | 71.5s
# [287/400] train loss=0.047124, nmse(dB)=-8.4219 | val loss=0.011027, nmse(dB)=-15.1710 | 71.4s
# [288/400] train loss=0.047853, nmse(dB)=-8.4009 | val loss=0.011055, nmse(dB)=-15.1493 | 71.6s
# [289/400] train loss=0.046528, nmse(dB)=-8.3992 | val loss=0.011093, nmse(dB)=-15.1200 | 71.4s
# [290/400] train loss=0.047467, nmse(dB)=-8.3869 | val loss=0.011101, nmse(dB)=-15.1147 | 71.6s
# [291/400] train loss=0.046064, nmse(dB)=-8.4726 | val loss=0.011093, nmse(dB)=-15.1212 | 71.6s
# [292/400] train loss=0.046201, nmse(dB)=-8.4627 | val loss=0.011078, nmse(dB)=-15.1325 | 71.6s
# [293/400] train loss=0.045557, nmse(dB)=-8.5487 | val loss=0.011044, nmse(dB)=-15.1595 | 71.7s
# [294/400] train loss=0.046395, nmse(dB)=-8.4300 | val loss=0.011029, nmse(dB)=-15.1714 | 71.9s
# [295/400] train loss=0.045262, nmse(dB)=-8.5616 | val loss=0.011033, nmse(dB)=-15.1681 | 71.4s
# [296/400] train loss=0.046195, nmse(dB)=-8.4035 | val loss=0.011049, nmse(dB)=-15.1561 | 71.6s
# [297/400] train loss=0.046386, nmse(dB)=-8.4434 | val loss=0.011044, nmse(dB)=-15.1598 | 71.4s
# [298/400] train loss=0.044521, nmse(dB)=-8.5728 | val loss=0.011036, nmse(dB)=-15.1661 | 71.3s
# [299/400] train loss=0.045783, nmse(dB)=-8.5784 | val loss=0.011035, nmse(dB)=-15.1667 | 71.3s
# [300/400] train loss=0.046582, nmse(dB)=-8.4566 | val loss=0.011074, nmse(dB)=-15.1370 | 71.6s
# [301/400] train loss=0.046132, nmse(dB)=-8.4436 | val loss=0.011104, nmse(dB)=-15.1138 | 71.7s
# [302/400] train loss=0.046259, nmse(dB)=-8.4873 | val loss=0.011080, nmse(dB)=-15.1323 | 71.6s
# [303/400] train loss=0.046342, nmse(dB)=-8.4272 | val loss=0.011074, nmse(dB)=-15.1373 | 71.5s
# [304/400] train loss=0.046021, nmse(dB)=-8.4544 | val loss=0.011060, nmse(dB)=-15.1486 | 71.3s
# [305/400] train loss=0.045456, nmse(dB)=-8.5051 | val loss=0.011049, nmse(dB)=-15.1575 | 71.8s
# [306/400] train loss=0.045670, nmse(dB)=-8.4578 | val loss=0.011042, nmse(dB)=-15.1624 | 71.7s
# [307/400] train loss=0.045208, nmse(dB)=-8.5402 | val loss=0.011040, nmse(dB)=-15.1640 | 71.5s
# [308/400] train loss=0.045875, nmse(dB)=-8.4757 | val loss=0.011039, nmse(dB)=-15.1642 | 71.6s
# [309/400] train loss=0.045980, nmse(dB)=-8.4967 | val loss=0.011033, nmse(dB)=-15.1683 | 71.4s
# [310/400] train loss=0.044879, nmse(dB)=-8.5486 | val loss=0.011039, nmse(dB)=-15.1631 | 71.2s
# [311/400] train loss=0.044767, nmse(dB)=-8.6000 | val loss=0.011041, nmse(dB)=-15.1614 | 71.3s
# [312/400] train loss=0.045735, nmse(dB)=-8.4611 | val loss=0.011060, nmse(dB)=-15.1456 | 71.6s
# [313/400] train loss=0.046417, nmse(dB)=-8.4398 | val loss=0.011066, nmse(dB)=-15.1414 | 71.4s
# [314/400] train loss=0.044888, nmse(dB)=-8.5681 | val loss=0.011048, nmse(dB)=-15.1550 | 71.8s
# [315/400] train loss=0.045067, nmse(dB)=-8.5660 | val loss=0.011040, nmse(dB)=-15.1615 | 71.4s
# [316/400] train loss=0.046745, nmse(dB)=-8.4332 | val loss=0.011044, nmse(dB)=-15.1581 | 71.2s
# [317/400] train loss=0.045687, nmse(dB)=-8.5583 | val loss=0.011045, nmse(dB)=-15.1576 | 71.2s
# [318/400] train loss=0.045688, nmse(dB)=-8.4600 | val loss=0.011049, nmse(dB)=-15.1542 | 71.5s
# [319/400] train loss=0.047216, nmse(dB)=-8.3594 | val loss=0.011046, nmse(dB)=-15.1571 | 72.1s
# [320/400] train loss=0.046705, nmse(dB)=-8.3893 | val loss=0.011033, nmse(dB)=-15.1674 | 71.9s
# [321/400] train loss=0.045000, nmse(dB)=-8.4938 | val loss=0.011014, nmse(dB)=-15.1820 | 71.9s
# [322/400] train loss=0.045267, nmse(dB)=-8.5318 | val loss=0.010995, nmse(dB)=-15.1971 | 71.3s
# [323/400] train loss=0.045586, nmse(dB)=-8.4887 | val loss=0.010986, nmse(dB)=-15.2043 | 72.6s
# [324/400] train loss=0.045437, nmse(dB)=-8.5425 | val loss=0.010987, nmse(dB)=-15.2035 | 72.6s
# [325/400] train loss=0.044894, nmse(dB)=-8.5596 | val loss=0.011006, nmse(dB)=-15.1892 | 72.5s
# [326/400] train loss=0.046029, nmse(dB)=-8.4514 | val loss=0.011038, nmse(dB)=-15.1649 | 72.3s
# [327/400] train loss=0.046091, nmse(dB)=-8.5540 | val loss=0.011064, nmse(dB)=-15.1451 | 71.8s
# [328/400] train loss=0.045472, nmse(dB)=-8.4981 | val loss=0.011090, nmse(dB)=-15.1248 | 71.8s
# [329/400] train loss=0.045005, nmse(dB)=-8.5122 | val loss=0.011085, nmse(dB)=-15.1288 | 71.5s
# [330/400] train loss=0.046785, nmse(dB)=-8.4135 | val loss=0.011058, nmse(dB)=-15.1506 | 72.5s
# [331/400] train loss=0.046029, nmse(dB)=-8.4916 | val loss=0.011026, nmse(dB)=-15.1754 | 72.4s
# [332/400] train loss=0.045654, nmse(dB)=-8.4856 | val loss=0.011003, nmse(dB)=-15.1937 | 71.9s
# [333/400] train loss=0.045531, nmse(dB)=-8.4901 | val loss=0.010989, nmse(dB)=-15.2050 | 71.4s
# [334/400] train loss=0.045943, nmse(dB)=-8.4380 | val loss=0.010982, nmse(dB)=-15.2101 | 71.7s
# [335/400] train loss=0.045113, nmse(dB)=-8.5730 | val loss=0.010976, nmse(dB)=-15.2146 | 71.5s
# [336/400] train loss=0.046223, nmse(dB)=-8.4951 | val loss=0.010979, nmse(dB)=-15.2128 | 71.3s
# [337/400] train loss=0.045909, nmse(dB)=-8.5039 | val loss=0.010995, nmse(dB)=-15.2000 | 71.2s
# [338/400] train loss=0.045337, nmse(dB)=-8.5843 | val loss=0.011010, nmse(dB)=-15.1882 | 71.2s
# [339/400] train loss=0.045427, nmse(dB)=-8.5478 | val loss=0.011028, nmse(dB)=-15.1741 | 71.4s
# [340/400] train loss=0.046309, nmse(dB)=-8.4510 | val loss=0.011032, nmse(dB)=-15.1712 | 71.1s
# [341/400] train loss=0.045021, nmse(dB)=-8.5697 | val loss=0.011036, nmse(dB)=-15.1675 | 71.2s
# [342/400] train loss=0.044204, nmse(dB)=-8.6373 | val loss=0.011038, nmse(dB)=-15.1660 | 71.5s
# [343/400] train loss=0.046178, nmse(dB)=-8.5217 | val loss=0.011031, nmse(dB)=-15.1723 | 72.1s
# [344/400] train loss=0.044551, nmse(dB)=-8.5935 | val loss=0.011032, nmse(dB)=-15.1709 | 71.7s
# [345/400] train loss=0.046014, nmse(dB)=-8.4786 | val loss=0.011033, nmse(dB)=-15.1704 | 71.9s
# [346/400] train loss=0.044921, nmse(dB)=-8.5697 | val loss=0.011034, nmse(dB)=-15.1694 | 72.3s
# [347/400] train loss=0.047162, nmse(dB)=-8.3921 | val loss=0.011034, nmse(dB)=-15.1690 | 71.2s
# [348/400] train loss=0.046171, nmse(dB)=-8.4523 | val loss=0.011036, nmse(dB)=-15.1670 | 71.5s
# [349/400] train loss=0.044835, nmse(dB)=-8.5376 | val loss=0.011032, nmse(dB)=-15.1702 | 71.5s
# [350/400] train loss=0.044964, nmse(dB)=-8.5805 | val loss=0.011031, nmse(dB)=-15.1713 | 71.8s
# [351/400] train loss=0.046205, nmse(dB)=-8.3997 | val loss=0.011027, nmse(dB)=-15.1740 | 71.9s
# [352/400] train loss=0.046203, nmse(dB)=-8.4726 | val loss=0.011026, nmse(dB)=-15.1750 | 71.7s
# [353/400] train loss=0.046680, nmse(dB)=-8.4163 | val loss=0.011022, nmse(dB)=-15.1781 | 72.2s
# [354/400] train loss=0.044629, nmse(dB)=-8.6182 | val loss=0.011015, nmse(dB)=-15.1835 | 71.2s
# [355/400] train loss=0.045818, nmse(dB)=-8.4422 | val loss=0.011013, nmse(dB)=-15.1850 | 72.0s
# [356/400] train loss=0.044016, nmse(dB)=-8.6142 | val loss=0.011006, nmse(dB)=-15.1904 | 71.5s
# [357/400] train loss=0.045083, nmse(dB)=-8.5097 | val loss=0.011000, nmse(dB)=-15.1949 | 71.4s
# [358/400] train loss=0.044578, nmse(dB)=-8.6165 | val loss=0.010999, nmse(dB)=-15.1956 | 72.4s
# [359/400] train loss=0.045882, nmse(dB)=-8.5341 | val loss=0.011001, nmse(dB)=-15.1937 | 72.4s
# [360/400] train loss=0.045934, nmse(dB)=-8.5170 | val loss=0.011006, nmse(dB)=-15.1903 | 72.7s
# [361/400] train loss=0.044493, nmse(dB)=-8.6122 | val loss=0.011012, nmse(dB)=-15.1854 | 72.2s
# [362/400] train loss=0.044146, nmse(dB)=-8.5654 | val loss=0.011021, nmse(dB)=-15.1784 | 71.8s
# [363/400] train loss=0.045272, nmse(dB)=-8.4678 | val loss=0.011027, nmse(dB)=-15.1738 | 71.6s
# [364/400] train loss=0.045222, nmse(dB)=-8.5296 | val loss=0.011029, nmse(dB)=-15.1721 | 71.5s
# [365/400] train loss=0.047435, nmse(dB)=-8.4051 | val loss=0.011032, nmse(dB)=-15.1700 | 71.7s
# [366/400] train loss=0.044239, nmse(dB)=-8.6148 | val loss=0.011036, nmse(dB)=-15.1670 | 71.4s
# [367/400] train loss=0.045184, nmse(dB)=-8.5378 | val loss=0.011039, nmse(dB)=-15.1647 | 71.5s
# [368/400] train loss=0.045748, nmse(dB)=-8.5096 | val loss=0.011040, nmse(dB)=-15.1639 | 71.5s
# [369/400] train loss=0.046702, nmse(dB)=-8.4448 | val loss=0.011037, nmse(dB)=-15.1659 | 71.6s
# [370/400] train loss=0.045058, nmse(dB)=-8.5168 | val loss=0.011035, nmse(dB)=-15.1675 | 70.9s
# [371/400] train loss=0.046287, nmse(dB)=-8.4771 | val loss=0.011032, nmse(dB)=-15.1701 | 71.4s
# [372/400] train loss=0.044595, nmse(dB)=-8.5649 | val loss=0.011031, nmse(dB)=-15.1713 | 72.1s
# [373/400] train loss=0.044646, nmse(dB)=-8.5538 | val loss=0.011029, nmse(dB)=-15.1726 | 72.4s
# [374/400] train loss=0.045225, nmse(dB)=-8.5180 | val loss=0.011028, nmse(dB)=-15.1739 | 70.8s
# [375/400] train loss=0.045871, nmse(dB)=-8.4471 | val loss=0.011027, nmse(dB)=-15.1743 | 71.9s
# [376/400] train loss=0.046905, nmse(dB)=-8.4407 | val loss=0.011025, nmse(dB)=-15.1758 | 73.8s
# [377/400] train loss=0.046235, nmse(dB)=-8.4637 | val loss=0.011023, nmse(dB)=-15.1771 | 73.2s
# [378/400] train loss=0.045383, nmse(dB)=-8.4881 | val loss=0.011023, nmse(dB)=-15.1779 | 75.3s
# [379/400] train loss=0.044015, nmse(dB)=-8.6288 | val loss=0.011022, nmse(dB)=-15.1781 | 73.9s
# [380/400] train loss=0.045909, nmse(dB)=-8.5342 | val loss=0.011023, nmse(dB)=-15.1776 | 74.2s
# [381/400] train loss=0.046147, nmse(dB)=-8.4957 | val loss=0.011024, nmse(dB)=-15.1769 | 74.4s
# [382/400] train loss=0.045625, nmse(dB)=-8.4432 | val loss=0.011025, nmse(dB)=-15.1758 | 73.6s
# [383/400] train loss=0.045729, nmse(dB)=-8.5261 | val loss=0.011026, nmse(dB)=-15.1752 | 73.9s
# [384/400] train loss=0.044324, nmse(dB)=-8.6792 | val loss=0.011026, nmse(dB)=-15.1748 | 73.6s
# [385/400] train loss=0.046121, nmse(dB)=-8.4290 | val loss=0.011027, nmse(dB)=-15.1742 | 72.7s
# [386/400] train loss=0.044110, nmse(dB)=-8.6098 | val loss=0.011028, nmse(dB)=-15.1736 | 73.4s
# [387/400] train loss=0.045023, nmse(dB)=-8.5452 | val loss=0.011028, nmse(dB)=-15.1731 | 73.7s
# [388/400] train loss=0.045467, nmse(dB)=-8.5246 | val loss=0.011029, nmse(dB)=-15.1728 | 73.6s
# [389/400] train loss=0.046098, nmse(dB)=-8.4789 | val loss=0.011029, nmse(dB)=-15.1726 | 73.6s
# [390/400] train loss=0.046603, nmse(dB)=-8.3877 | val loss=0.011029, nmse(dB)=-15.1726 | 73.5s
# [391/400] train loss=0.044898, nmse(dB)=-8.5306 | val loss=0.011029, nmse(dB)=-15.1728 | 73.8s
# [392/400] train loss=0.045966, nmse(dB)=-8.4448 | val loss=0.011029, nmse(dB)=-15.1730 | 73.9s
# [393/400] train loss=0.046337, nmse(dB)=-8.4243 | val loss=0.011028, nmse(dB)=-15.1732 | 73.5s
# [394/400] train loss=0.045794, nmse(dB)=-8.4476 | val loss=0.011028, nmse(dB)=-15.1733 | 73.3s
# [395/400] train loss=0.045964, nmse(dB)=-8.4788 | val loss=0.011028, nmse(dB)=-15.1734 | 73.6s
# [396/400] train loss=0.045082, nmse(dB)=-8.5280 | val loss=0.011028, nmse(dB)=-15.1735 | 74.0s
# [397/400] train loss=0.045375, nmse(dB)=-8.5372 | val loss=0.011028, nmse(dB)=-15.1735 | 74.3s
# [398/400] train loss=0.043882, nmse(dB)=-8.6452 | val loss=0.011028, nmse(dB)=-15.1735 | 73.6s
# [399/400] train loss=0.046679, nmse(dB)=-8.3694 | val loss=0.011028, nmse(dB)=-15.1735 | 74.8s
# [400/400] train loss=0.046477, nmse(dB)=-8.4643 | val loss=0.011028, nmse(dB)=-15.1735 | 75.0s
#
# === Done ===
# Best val loss | GRU : 0.010911658167868134
# Best val loss | LSTM: 0.010917872009924319

# %%
# print("\n=== Final Check on GRU Model ===")
# ch, img, y = next(iter(train_loader))
# print("y abs mean:", y.abs().mean().item())
# print("y abs max :", y.abs().max().item())
# print("y power   :", (y**2).mean().item())

# with torch.no_grad():
#     yhat = model_gru(ch.to(device), img.to(device))  # 여기만 변경
# print("yhat abs mean:", yhat.abs().mean().item())
# print("yhat abs max :", yhat.abs().max().item())
# print("yhat power   :", (yhat**2).mean().item())


print("\n=== LSTM Evaluation on a Batch ===")

ch, img, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model_lstm(ch.to(device), img.to(device))  # 여기만 변경
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# === LSTM Evaluation on a Batch ===
# y abs mean: 0.48763769454948036
# y abs max : 1.0
# y power   : 0.27950477708427485
# yhat abs mean: 0.49422386324122214
# yhat abs max : 0.6795261327782965
# yhat power   : 0.24579659395753894
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 데이터 입력 및 형태

# %%
@torch.no_grad()
def debug_batch_and_forward(loader, device, model=None, name="model", max_print=1):
    """
    - loader에서 배치 하나 뽑아서 shape/device/dtype 확인
    - model이 있으면 forward까지 해서 yhat shape 확인
    - img가 (B,T,3,H,W)인지 (B,3,H,W)인지 자동 판별
    """
    batch = next(iter(loader))

    # (ch, img, y) 형태를 가정
    ch, img, y = batch

    def info(x, label):
        print(f"{label:>4}: shape={tuple(x.shape)} dtype={x.dtype} device={x.device}")

    print("\n=== one batch tensor info ===")
    info(ch, "ch")
    info(img, "img")
    info(y,  "y")

    # img 차원 설명
    if img.dim() == 5:
        print("img format: (B,T,3,H,W)")
    elif img.dim() == 4:
        print("img format: (B,3,H,W)")
    else:
        print(f"img format: unexpected dim={img.dim()}")

    # forward check
    if model is not None:
        model.eval()
        yhat = model(ch.to(device), img.to(device))
        info(yhat, f"{name}_yhat")
        return (ch, img, y, yhat)

    return (ch, img, y)

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("N(cam_files)  :", len(cam_files))
print("N(min)        :", min(len(comm_frames), len(cam_files)))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

# GRU
# debug_batch_and_forward(train_loader, device, model_gru, name="GRU")

# LSTM
debug_batch_and_forward(train_loader, device, model_lstm, name="LSTM")
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# N(cam_files)  : 7012
# N(min)        : 100
# past_len      : 16
# len(ds)       : 84
# len(train_ds) : 63
# len(val_ds)   : 21
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B,T,F_in)
# img: (32, 16, 3, 224, 224)  -> (B,3,224,224)
# y  : (32, 2048)  -> (B,F_out)
# yhat: (32, 2048)  -> (B,F_out)
# this forward predicted vectors: 32 (=B)
# each vector predicts elements: 2048 (=F_out)
