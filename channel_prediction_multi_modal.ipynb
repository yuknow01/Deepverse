# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# #  Import

# %%
import os
import sys

import numpy as  np
from lwm_multi_model import multi_modal_lwm  # 클래스 import
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Settings

# %%
# Scenes 2000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(100))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print("현재 사용 중인 장치:", device)
# Out:
# 현재 사용 중인 장치: cuda:1

# %% [markdown]
# # Generate a dataset

# %%
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (0.78s)
# Generating radar dataset: ⏳ In progress
# Generating radar dataset: ✅ Completed (197.03s)

# %% [markdown]
# # location dataset
#  지금 실험에서는 안쓰임

# %%
# comm = dataset.comm_dataset
# location =  comm

# location = [
#     {
#         "bs_loc": d["bs_loc"],                      # (3,)
#         "ue_loc": np.asarray(d["ue_loc"]).squeeze() # (3,)  (원래 (1,3)이면 squeeze)
#     }
#     for row in comm.data      # row: [dict] 형태
#     for d in row              # d: dict
# ]

# print(ue_location)  #)

# %% [markdown]
# # communication  dataset

# %%
# UE 정보
comm = dataset.comm_dataset
ch = comm.data[0][0]['ue'][0]
print(ch.coeffs.shape)
# Out:
# (1, 16, 64)

# %% [markdown]
# # preprocessing

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device=device, eps=1e-16):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex128)
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(device)
    return H

# %%
# 사용예시
H = preprocess_channel_coeffs_minmax(ch.coeffs, r_min=-0.5, r_max=0.5, i_min=-0.5, i_max=0.5)
print(H.shape)  # (1, 16, 128) 64 subcar
# Out:
# torch.Size([1, 16, 128])

# %% [markdown]
# ### image dataset

# %%
sensor = dataset.camera_dataset.sensors["unit1_cam1"]
path0 = sensor.files[0]
img = Image.open(path0).convert("RGB")
arr = np.array(img)

print("path:", path0)
print("PIL size (W,H):", img.size)
print("np shape:", arr.shape, "dtype:", arr.dtype)  # 보통 (H,W,3), uint8
# Out:
# path: scenarios/DT31/RGB_images/unit1_cam1/7.png
# PIL size (W,H): (1920, 1080)
# np shape: (1080, 1920, 3) dtype: uint8

# %%
IMG_SIZE = 224

def preprocess_img(path, img_size=IMG_SIZE, device=device):
    # 1) load (H,W,3) uint8
    img = Image.open(path).convert("RGB")
    arr = np.array(img)

    # 2) numpy -> torch, (3,H,W), float32
    x = torch.from_numpy(arr).permute(2, 0, 1).contiguous().double()  # (3,H,W), double for ImageNet stats
    x = x / 255.0  # [0,1]

    # 3) add batch dim -> (1,3,H,W)
    x = x.unsqueeze(0)

    # 4) resize -> (1,3,224,224)
    x = F.interpolate(x, size=(img_size, img_size),
                      mode="bilinear", align_corners=False)

    # 5) normalize (ImageNet)
    mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float64).view(1, 3, 1, 1)
    std  = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float64).view(1, 3, 1, 1)
    x = (x - mean) / std

    # 6) move to device (GPU)
    x = x.to(device, non_blocking=True)

    return x  # (1,3,224,224) on device

# %%
# 사용예시
cd = dataset.camera_dataset
sensor = cd.sensors['unit1_cam1']
path0 = sensor.files[0]
img = preprocess_img(path0, device=device)
print(img.shape, img.device)  # torch.Size([1,3,224,224]) cuda:0
print(path0)
# Out:
# torch.Size([1, 3, 224, 224]) cuda:1
# scenarios/DT31/RGB_images/unit1_cam1/7.png

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class MultiModalNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, cam_files, ue_idx=0, past_len=16, device=device,
                 # Arguments for statistical values (initialized with default values)
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        
        self.comm_frames = comm_frames
        self.cam_files = list(cam_files)
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device
        
        # Save statistical values
        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = min(len(self.comm_frames), len(self.cam_files))
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2 

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1. Image Past (Apply Preprocessing)
        img_list = []
        for k in range(t - self.past_len + 1, t + 1):
            img_path = self.cam_files[k]
            img_k = preprocess_img(img_path, device=self.device).squeeze(0)
            img_list.append(img_k)
        img = torch.stack(img_list, dim=0)  # Shape: (past_len

        
        # 2. Channel Past (Apply Scaling)
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            # Use the newly defined Min-Max preprocessing function
            h = preprocess_channel_coeffs_minmax(
                coeffs_np, 
                self.r_min, self.r_max, self.i_min, self.i_max, 
                device=self.device
            ).reshape(-1)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)

        # 3. Target (Apply Scaling) - Target must also be scaled for model training!
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_minmax(
            coeffs_np_next, 
            self.r_min, self.r_max, self.i_min, self.i_max, 
            device=self.device
        ).reshape(-1)

        return channel_past, img, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
sensor = dataset.camera_dataset.sensors["unit1_cam1"]

ds = MultiModalNextStepDatasetGPU(
    comm_frames=comm_frames,
    cam_files=sensor.files,
    ue_idx=0,
    past_len=16,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   # ✅ 의미 없음 (이미 GPU)
)

ch, img, y = next(iter(loader))
print(ch.shape, img.shape, y.shape)
print(ch.device, img.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 16, 3, 224, 224]) torch.Size([8, 2048])
# cuda:1 cuda:1 cuda:1

# %% [markdown]
# # Fine-tuning
# data shape 맞추기 위해

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from lwm_multi_model import multi_modal_lwm  # 너가 올린 backbone

class FinetuneChannelPredictor(nn.Module):
    """
    직접 구현한 lwm_multi_model(channel + image)에 맞는 파인튜닝 모델
    Input:
      ch:  (B, T, F_in)  e.g., (B,16,2048) 16: past Length, 2048: feature dim
      img: (B, 3, 224, 224)
    Output:
      yhat: (B, F_out)  e.g., (B,2048)
    """
    def __init__(
        self,
        backbone: nn.Module,
        F_in: int,
        F_out: int,
        pool: str = "last",          # "last" or "mean"
        freeze_image: bool = False,
        freeze_backbone: bool = False,
        element_length: int = 16,    # 채널 벡터 차원 (backbone 기대값)
        d_model: int = 64            # backbone 내부 feature dim
    ):
        super().__init__()
        self.backbone = backbone
        self.pool = pool

        # backbone이 기대하는 channel feature dim = ELEMENT_LENGTH
        # (backbone 내부 Channel_Embedding: Linear(ELEMENT_LENGTH -> D_MODEL))
        if element_length is None:
            element_length = backbone.channel_embedding.element_length
        if d_model is None:
            d_model = backbone.channel_embedding.d_model

        # 입력 차원 정렬: F_in -> ELEMENT_LENGTH
        self.in_proj = nn.Sequential(
            nn.Linear(F_in, 512),
            nn.GELU(),
            nn.Linear(512, 128),
            nn.GELU(),
            nn.Linear(128, element_length)
        )

        # 출력 head: D_MODEL -> F_out
        self.head = nn.Linear(d_model, F_out)

        if freeze_image:
            for p in self.backbone.image_embedding.parameters():
                p.requires_grad = False

        if freeze_backbone:
            for p in self.backbone.parameters():
                p.requires_grad = False
            # 그래도 projection/head는 학습되게 다시 켜기
            for p in self.in_proj.parameters():
                p.requires_grad = True
            for p in self.head.parameters():
                p.requires_grad = True

    def forward(self, ch, img):
        # ch: (B,T,F_in) -> (B,T,ELEMENT_LENGTH)
        ch = self.in_proj(ch)

        # backbone: (B,T,D_MODEL)
        tokens = self.backbone(ch, img)

        # pooling -> (B,D_MODEL)
        if self.pool == "last":
            z = tokens[:, -1, :]
        elif self.pool == "mean":
            z = tokens.mean(dim=1)
        else:
            raise ValueError(f"Unknown pool={self.pool}")

        # head -> (B,F_out)
        yhat = self.head(z)
        return yhat

# %% [markdown]
# ## NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# %% [markdown]
# # Train/Val split

# %%
n = len(ds)
n_train = int(0.75 * n)
train_idx = list(range(0, n_train))
val_idx = list(range(n_train, n))

train_ts = [ds.valid_start + i for i in train_idx]

(real_min,  real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_ts, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)

# Verify
ch, img, y = next(iter(train_loader))
print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")

print("====")
print("check the type float 32 or float 64?")
print("ch dtype:", ch.dtype, "y dtype:", y.dtype)
# Out:
# Calculating min/max over training set...
# Done. rmin=-1.0646139639174899e-06, rmax=1.0917989155343993e-06, imin=-1.0719516685941772e-06, imax=1.0643868111374237e-06
# Dataset statistical values set in the dataset.
#
# === Data Check ===
# y stats | min: 0.0000, max: 1.0000
# If scaling worked correctly, values should be within [0, 1].
# ====
# check the type float 32 or float 64?
# ch dtype: torch.float64 y dtype: torch.float64

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
cam_files = list(dataset.camera_dataset.sensors["unit1_cam1"].files)

print("len(comm_frames):", len(comm_frames))
print("len(cam_files):", len(cam_files))
print("first comm frame keys:", list(comm_frames[0].keys()))
print("first cam file:", cam_files[0])
# Out:
# len(comm_frames): 100
# len(cam_files): 1114
# first comm frame keys: ['bs_loc', 'ue', 'ue_loc', 'bs']
# first cam file: scenarios/DT31/RGB_images/unit1_cam1/7.png

# %%
len(val_loader)
# Out:
# 1

# %% [markdown]
# # Model generate and also check

# %%
# 배치 하나로 F_in/F_out 자동 확정
ch, img, y = next(iter(train_loader))
F_in  = ch.shape[-1]
F_out = y.shape[-1]
print("Detected:", "F_in=", F_in, "F_out=", F_out)
print("Batch devices:", ch.device, img.device, y.device)

# backbone + finetune model
backbone = multi_modal_lwm().to(device)

model = FinetuneChannelPredictor(
    backbone=backbone,
    F_in=F_in,
    F_out=F_out,
    pool="last",            # "mean"으로 바꿔도 됨
    freeze_image=False,     # 원하면 True (이미지 인코더 고정)
    freeze_backbone=False,  # 원하면 True (proj/head만 학습)
    element_length=16,
    d_model=64
).to(device).double()

# sanity forward
model.eval()
with torch.no_grad():
    # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
    yhat = model(ch.to(device), img.to(device))
print("yhat:", yhat.shape, "y:", y.shape)
# Out:
# Detected: F_in= 2048 F_out= 2048
# Batch devices: cuda:1 cuda:1 cuda:1
# yhat: torch.Size([32, 2048]) y: torch.Size([32, 2048])

# %%
# 1. 모델 생성 (백본 포함)
model = FinetuneChannelPredictor(
    backbone=backbone,
    F_in=F_in,
    F_out=F_out,
    element_length=16,
    d_model=64
).to(device)

# 2. 전체 모델을 Double(float64)로 강제 변환
# 이 한 줄이 실행되어야 'in_proj'와 'head' 가중치가 모두 float64가 됩니다.
model.double() 

# 3. 타입 불일치 확인 (디버깅용)
print(f"Input Type: {ch.dtype}")                # torch.float64 여야 함
print(f"Model weight Type: {model.head.weight.dtype}") # torch.float64 여야 함

# 4. 연산 수행
model.eval()
with torch.no_grad():
    # 데이터와 모델 가중치 타입을 일치시켜서 입력
    # .to(device) 뒤에 .double()을 붙여서 확실히 합니다.
    yhat = model(ch.to(device).double(), img.to(device).double())
# Out:
# Input Type: torch.float64
# Model weight Type: torch.float64

# %% [markdown]
# # Train/ Eval 함수 (grad clip)

# %%
def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        # Dataset이 이미 cuda 텐서를 반환하더라도 안전하게 유지
        ch = ch.to(device, non_blocking=True).double()
        img = img.to(device, non_blocking=True).double()
        y  = y.to(device, non_blocking=True).double()

        optimizer.zero_grad(set_to_none=True)

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)
        
        loss.backward()

        if grad_clip is not None and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        optimizer.step()
        
        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)


@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        ch = ch.to(device, non_blocking=True).double()
        img = img.to(device, non_blocking=True).double()
        y  = y.to(device, non_blocking=True).double()

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

# %% [markdown]
# #  Optiimizer  / Scheduler 설정

# %%
# requires_grad=True인 파라미터만 학습
trainable_params = [p for p in model.parameters() if p.requires_grad]
print("trainable params:", sum(p.numel() for p in trainable_params))

optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# (선택) cosine scheduler
epochs = 600
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
# Out:
# trainable params: 2499120

# %% [markdown]
# # 학습 루프 + checkpoint 저장

# %%
best_val = float("inf")
best_val_nmse = None
best_epoch = None

t_train0 = time.time()  # ✅ 전체 학습 시작 시간

for epoch in range(1, epochs + 1):
    t0 = time.time()

    tr_loss, tr_nmse = train_one_epoch(model, train_loader, optimizer, device=device, grad_clip=1.0)
    va_loss, va_nmse = evaluate(model, val_loader, device=device)

    scheduler.step()

    dt = time.time() - t0
    print(
        f"[{epoch:02d}/{epochs}] "
        f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
        f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
        f"{dt:.1f}s"
    )

    if va_loss < best_val:
        best_val = va_loss
        best_val_nmse = va_nmse
        best_epoch = epoch

        torch.save(
            {
                "epoch": epoch,
                "model_state": model.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "F_in": F_in,
                "F_out": F_out,
                "best_val_loss": best_val,
                "best_val_nmse_db": best_val_nmse,
            },
            "best_finetune.pt"
        )
        print(f"  ↳ saved best_finetune.pt | best@{best_epoch}: val loss={best_val:.6f}, val nmse(dB)={best_val_nmse:.4f}")

# ✅ 전체 학습 종료 후 총 시간 출력
total_sec = time.time() - t_train0
h = int(total_sec // 3600)
m = int((total_sec % 3600) // 60)
s = total_sec % 60

print("\n=== Training Summary ===")
print(f"Total time: {total_sec:.1f}s ({h}h {m}m {s:.1f}s)")
print(f"Best epoch: {best_epoch} | best val loss={best_val:.6f}, best val nmse(dB)={best_val_nmse:.4f}")
# Out:
# [01/600] train loss=0.625214, nmse(dB)=3.4420 | val loss=0.517824, nmse(dB)=3.0209 | 87.5s
#   ↳ saved best_finetune.pt | best@1: val loss=0.517824, val nmse(dB)=3.0209
# [02/600] train loss=0.551493, nmse(dB)=2.8961 | val loss=0.467789, nmse(dB)=2.5794 | 88.0s
#   ↳ saved best_finetune.pt | best@2: val loss=0.467789, val nmse(dB)=2.5794
# [03/600] train loss=0.506863, nmse(dB)=2.5265 | val loss=0.435588, nmse(dB)=2.2696 | 86.4s
#   ↳ saved best_finetune.pt | best@3: val loss=0.435588, val nmse(dB)=2.2696
# [04/600] train loss=0.477545, nmse(dB)=2.2661 | val loss=0.410867, nmse(dB)=2.0157 | 86.7s
#   ↳ saved best_finetune.pt | best@4: val loss=0.410867, val nmse(dB)=2.0157
# [05/600] train loss=0.453732, nmse(dB)=2.0402 | val loss=0.390548, nmse(dB)=1.7954 | 86.4s
#   ↳ saved best_finetune.pt | best@5: val loss=0.390548, val nmse(dB)=1.7954
# [06/600] train loss=0.435980, nmse(dB)=1.8686 | val loss=0.374044, nmse(dB)=1.6078 | 87.3s
#   ↳ saved best_finetune.pt | best@6: val loss=0.374044, val nmse(dB)=1.6078
# [07/600] train loss=0.421796, nmse(dB)=1.7202 | val loss=0.360317, nmse(dB)=1.4453 | 87.2s
#   ↳ saved best_finetune.pt | best@7: val loss=0.360317, val nmse(dB)=1.4453
# [08/600] train loss=0.409542, nmse(dB)=1.5910 | val loss=0.348293, nmse(dB)=1.2978 | 87.2s
#   ↳ saved best_finetune.pt | best@8: val loss=0.348293, val nmse(dB)=1.2978
# [09/600] train loss=0.397670, nmse(dB)=1.4606 | val loss=0.336918, nmse(dB)=1.1536 | 87.3s
#   ↳ saved best_finetune.pt | best@9: val loss=0.336918, val nmse(dB)=1.1536
# [10/600] train loss=0.385036, nmse(dB)=1.3184 | val loss=0.325890, nmse(dB)=1.0089 | 88.1s
#   ↳ saved best_finetune.pt | best@10: val loss=0.325890, val nmse(dB)=1.0089
# [11/600] train loss=0.374782, nmse(dB)=1.2047 | val loss=0.315257, nmse(dB)=0.8648 | 87.7s
#   ↳ saved best_finetune.pt | best@11: val loss=0.315257, val nmse(dB)=0.8648
# [12/600] train loss=0.361927, nmse(dB)=1.0539 | val loss=0.305159, nmse(dB)=0.7233 | 87.1s
#   ↳ saved best_finetune.pt | best@12: val loss=0.305159, val nmse(dB)=0.7233
# [13/600] train loss=0.354083, nmse(dB)=0.9516 | val loss=0.295773, nmse(dB)=0.5876 | 87.6s
#   ↳ saved best_finetune.pt | best@13: val loss=0.295773, val nmse(dB)=0.5876
# [14/600] train loss=0.344847, nmse(dB)=0.8355 | val loss=0.286997, nmse(dB)=0.4567 | 87.3s
#   ↳ saved best_finetune.pt | best@14: val loss=0.286997, val nmse(dB)=0.4567
# [15/600] train loss=0.336350, nmse(dB)=0.7298 | val loss=0.278791, nmse(dB)=0.3306 | 87.9s
#   ↳ saved best_finetune.pt | best@15: val loss=0.278791, val nmse(dB)=0.3306
# [16/600] train loss=0.327358, nmse(dB)=0.6109 | val loss=0.271084, nmse(dB)=0.2088 | 86.9s
#   ↳ saved best_finetune.pt | best@16: val loss=0.271084, val nmse(dB)=0.2088
# [17/600] train loss=0.320983, nmse(dB)=0.5240 | val loss=0.263883, nmse(dB)=0.0918 | 88.3s
#   ↳ saved best_finetune.pt | best@17: val loss=0.263883, val nmse(dB)=0.0918
# [18/600] train loss=0.313566, nmse(dB)=0.4227 | val loss=0.257157, nmse(dB)=-0.0204 | 87.6s
#   ↳ saved best_finetune.pt | best@18: val loss=0.257157, val nmse(dB)=-0.0204
# [19/600] train loss=0.308398, nmse(dB)=0.3458 | val loss=0.250836, nmse(dB)=-0.1286 | 88.1s
#   ↳ saved best_finetune.pt | best@19: val loss=0.250836, val nmse(dB)=-0.1286
# [20/600] train loss=0.300865, nmse(dB)=0.2334 | val loss=0.244956, nmse(dB)=-0.2317 | 87.6s
#   ↳ saved best_finetune.pt | best@20: val loss=0.244956, val nmse(dB)=-0.2317
# [21/600] train loss=0.295979, nmse(dB)=0.1717 | val loss=0.239473, nmse(dB)=-0.3301 | 86.9s
#   ↳ saved best_finetune.pt | best@21: val loss=0.239473, val nmse(dB)=-0.3301
# [22/600] train loss=0.292471, nmse(dB)=0.1128 | val loss=0.234334, nmse(dB)=-0.4244 | 87.8s
#   ↳ saved best_finetune.pt | best@22: val loss=0.234334, val nmse(dB)=-0.4244
# [23/600] train loss=0.286371, nmse(dB)=0.0175 | val loss=0.229426, nmse(dB)=-0.5165 | 87.5s
#   ↳ saved best_finetune.pt | best@23: val loss=0.229426, val nmse(dB)=-0.5165
# [24/600] train loss=0.283818, nmse(dB)=-0.0229 | val loss=0.224765, nmse(dB)=-0.6057 | 87.4s
#   ↳ saved best_finetune.pt | best@24: val loss=0.224765, val nmse(dB)=-0.6057
# [25/600] train loss=0.275941, nmse(dB)=-0.1433 | val loss=0.220421, nmse(dB)=-0.6906 | 87.5s
#   ↳ saved best_finetune.pt | best@25: val loss=0.220421, val nmse(dB)=-0.6906
# [26/600] train loss=0.273228, nmse(dB)=-0.1863 | val loss=0.216315, nmse(dB)=-0.7723 | 87.9s
#   ↳ saved best_finetune.pt | best@26: val loss=0.216315, val nmse(dB)=-0.7723
# [27/600] train loss=0.269876, nmse(dB)=-0.2443 | val loss=0.212467, nmse(dB)=-0.8504 | 88.7s
#   ↳ saved best_finetune.pt | best@27: val loss=0.212467, val nmse(dB)=-0.8504
# [28/600] train loss=0.266678, nmse(dB)=-0.2972 | val loss=0.208800, nmse(dB)=-0.9261 | 87.0s
#   ↳ saved best_finetune.pt | best@28: val loss=0.208800, val nmse(dB)=-0.9261
# [29/600] train loss=0.261218, nmse(dB)=-0.3866 | val loss=0.205284, nmse(dB)=-0.9999 | 87.1s
#   ↳ saved best_finetune.pt | best@29: val loss=0.205284, val nmse(dB)=-0.9999
# [30/600] train loss=0.257210, nmse(dB)=-0.4518 | val loss=0.201859, nmse(dB)=-1.0731 | 88.3s
#   ↳ saved best_finetune.pt | best@30: val loss=0.201859, val nmse(dB)=-1.0731
# [31/600] train loss=0.255597, nmse(dB)=-0.4789 | val loss=0.198508, nmse(dB)=-1.1459 | 87.3s
#   ↳ saved best_finetune.pt | best@31: val loss=0.198508, val nmse(dB)=-1.1459
# [32/600] train loss=0.251056, nmse(dB)=-0.5586 | val loss=0.195252, nmse(dB)=-1.2178 | 89.9s
#   ↳ saved best_finetune.pt | best@32: val loss=0.195252, val nmse(dB)=-1.2178
# [33/600] train loss=0.249203, nmse(dB)=-0.5950 | val loss=0.192089, nmse(dB)=-1.2889 | 86.8s
#   ↳ saved best_finetune.pt | best@33: val loss=0.192089, val nmse(dB)=-1.2889
# [34/600] train loss=0.245965, nmse(dB)=-0.6515 | val loss=0.188889, nmse(dB)=-1.3619 | 87.4s
#   ↳ saved best_finetune.pt | best@34: val loss=0.188889, val nmse(dB)=-1.3619
# [35/600] train loss=0.240956, nmse(dB)=-0.7350 | val loss=0.185550, nmse(dB)=-1.4395 | 90.0s
#   ↳ saved best_finetune.pt | best@35: val loss=0.185550, val nmse(dB)=-1.4395
# [36/600] train loss=0.236630, nmse(dB)=-0.8209 | val loss=0.182184, nmse(dB)=-1.5192 | 87.8s
#   ↳ saved best_finetune.pt | best@36: val loss=0.182184, val nmse(dB)=-1.5192
# [37/600] train loss=0.233068, nmse(dB)=-0.8897 | val loss=0.178866, nmse(dB)=-1.5991 | 89.6s
#   ↳ saved best_finetune.pt | best@37: val loss=0.178866, val nmse(dB)=-1.5991
# [38/600] train loss=0.229809, nmse(dB)=-0.9439 | val loss=0.175586, nmse(dB)=-1.6796 | 87.9s
#   ↳ saved best_finetune.pt | best@38: val loss=0.175586, val nmse(dB)=-1.6796
# [39/600] train loss=0.225181, nmse(dB)=-1.0356 | val loss=0.172284, nmse(dB)=-1.7622 | 89.0s
#   ↳ saved best_finetune.pt | best@39: val loss=0.172284, val nmse(dB)=-1.7622
# [40/600] train loss=0.222489, nmse(dB)=-1.0869 | val loss=0.168948, nmse(dB)=-1.8473 | 87.7s
#   ↳ saved best_finetune.pt | best@40: val loss=0.168948, val nmse(dB)=-1.8473
# [41/600] train loss=0.218118, nmse(dB)=-1.1727 | val loss=0.165652, nmse(dB)=-1.9330 | 87.7s
#   ↳ saved best_finetune.pt | best@41: val loss=0.165652, val nmse(dB)=-1.9330
# [42/600] train loss=0.215667, nmse(dB)=-1.2160 | val loss=0.162410, nmse(dB)=-2.0190 | 87.1s
#   ↳ saved best_finetune.pt | best@42: val loss=0.162410, val nmse(dB)=-2.0190
# [43/600] train loss=0.210648, nmse(dB)=-1.3283 | val loss=0.159234, nmse(dB)=-2.1050 | 87.3s
#   ↳ saved best_finetune.pt | best@43: val loss=0.159234, val nmse(dB)=-2.1050
# [44/600] train loss=0.207774, nmse(dB)=-1.3847 | val loss=0.156045, nmse(dB)=-2.1930 | 89.7s
#   ↳ saved best_finetune.pt | best@44: val loss=0.156045, val nmse(dB)=-2.1930
# [45/600] train loss=0.204753, nmse(dB)=-1.4535 | val loss=0.152807, nmse(dB)=-2.2843 | 87.1s
#   ↳ saved best_finetune.pt | best@45: val loss=0.152807, val nmse(dB)=-2.2843
# [46/600] train loss=0.200084, nmse(dB)=-1.5533 | val loss=0.149511, nmse(dB)=-2.3792 | 87.0s
#   ↳ saved best_finetune.pt | best@46: val loss=0.149511, val nmse(dB)=-2.3792
# [47/600] train loss=0.197066, nmse(dB)=-1.6178 | val loss=0.146165, nmse(dB)=-2.4778 | 89.7s
#   ↳ saved best_finetune.pt | best@47: val loss=0.146165, val nmse(dB)=-2.4778
# [48/600] train loss=0.193349, nmse(dB)=-1.7016 | val loss=0.142790, nmse(dB)=-2.5795 | 86.8s
#   ↳ saved best_finetune.pt | best@48: val loss=0.142790, val nmse(dB)=-2.5795
# [49/600] train loss=0.190818, nmse(dB)=-1.7621 | val loss=0.139424, nmse(dB)=-2.6834 | 87.4s
#   ↳ saved best_finetune.pt | best@49: val loss=0.139424, val nmse(dB)=-2.6834
# [50/600] train loss=0.186414, nmse(dB)=-1.8638 | val loss=0.136128, nmse(dB)=-2.7876 | 87.6s
#   ↳ saved best_finetune.pt | best@50: val loss=0.136128, val nmse(dB)=-2.7876
# [51/600] train loss=0.183380, nmse(dB)=-1.9335 | val loss=0.132880, nmse(dB)=-2.8928 | 88.4s
#   ↳ saved best_finetune.pt | best@51: val loss=0.132880, val nmse(dB)=-2.8928
# [52/600] train loss=0.179668, nmse(dB)=-2.0224 | val loss=0.129652, nmse(dB)=-3.0000 | 87.8s
#   ↳ saved best_finetune.pt | best@52: val loss=0.129652, val nmse(dB)=-3.0000
# [53/600] train loss=0.176159, nmse(dB)=-2.1094 | val loss=0.126436, nmse(dB)=-3.1094 | 87.8s
#   ↳ saved best_finetune.pt | best@53: val loss=0.126436, val nmse(dB)=-3.1094
# [54/600] train loss=0.171949, nmse(dB)=-2.2217 | val loss=0.123230, nmse(dB)=-3.2214 | 87.6s
#   ↳ saved best_finetune.pt | best@54: val loss=0.123230, val nmse(dB)=-3.2214
# [55/600] train loss=0.169290, nmse(dB)=-2.2861 | val loss=0.120028, nmse(dB)=-3.3361 | 88.7s
#   ↳ saved best_finetune.pt | best@55: val loss=0.120028, val nmse(dB)=-3.3361
# [56/600] train loss=0.164397, nmse(dB)=-2.4195 | val loss=0.116862, nmse(dB)=-3.4527 | 87.4s
#   ↳ saved best_finetune.pt | best@56: val loss=0.116862, val nmse(dB)=-3.4527
# [57/600] train loss=0.161329, nmse(dB)=-2.5004 | val loss=0.113738, nmse(dB)=-3.5708 | 87.6s
#   ↳ saved best_finetune.pt | best@57: val loss=0.113738, val nmse(dB)=-3.5708
# [58/600] train loss=0.158355, nmse(dB)=-2.5860 | val loss=0.110608, nmse(dB)=-3.6925 | 87.5s
#   ↳ saved best_finetune.pt | best@58: val loss=0.110608, val nmse(dB)=-3.6925
# [59/600] train loss=0.155391, nmse(dB)=-2.6662 | val loss=0.107513, nmse(dB)=-3.8163 | 87.8s
#   ↳ saved best_finetune.pt | best@59: val loss=0.107513, val nmse(dB)=-3.8163
# [60/600] train loss=0.152428, nmse(dB)=-2.7543 | val loss=0.104457, nmse(dB)=-3.9421 | 87.6s
#   ↳ saved best_finetune.pt | best@60: val loss=0.104457, val nmse(dB)=-3.9421
# [61/600] train loss=0.149863, nmse(dB)=-2.8291 | val loss=0.101476, nmse(dB)=-4.0684 | 87.4s
#   ↳ saved best_finetune.pt | best@61: val loss=0.101476, val nmse(dB)=-4.0684
# [62/600] train loss=0.144383, nmse(dB)=-2.9901 | val loss=0.098595, nmse(dB)=-4.1942 | 87.7s
#   ↳ saved best_finetune.pt | best@62: val loss=0.098595, val nmse(dB)=-4.1942
# [63/600] train loss=0.142891, nmse(dB)=-3.0369 | val loss=0.095731, nmse(dB)=-4.3230 | 86.9s
#   ↳ saved best_finetune.pt | best@63: val loss=0.095731, val nmse(dB)=-4.3230
# [64/600] train loss=0.138704, nmse(dB)=-3.1759 | val loss=0.092878, nmse(dB)=-4.4553 | 88.9s
#   ↳ saved best_finetune.pt | best@64: val loss=0.092878, val nmse(dB)=-4.4553
# [65/600] train loss=0.136294, nmse(dB)=-3.2462 | val loss=0.090078, nmse(dB)=-4.5891 | 87.2s
#   ↳ saved best_finetune.pt | best@65: val loss=0.090078, val nmse(dB)=-4.5891
# [66/600] train loss=0.132654, nmse(dB)=-3.3717 | val loss=0.087333, nmse(dB)=-4.7244 | 87.8s
#   ↳ saved best_finetune.pt | best@66: val loss=0.087333, val nmse(dB)=-4.7244
# [67/600] train loss=0.130855, nmse(dB)=-3.4322 | val loss=0.084631, nmse(dB)=-4.8619 | 87.5s
#   ↳ saved best_finetune.pt | best@67: val loss=0.084631, val nmse(dB)=-4.8619
# [68/600] train loss=0.127701, nmse(dB)=-3.5403 | val loss=0.081989, nmse(dB)=-5.0007 | 91.1s
#   ↳ saved best_finetune.pt | best@68: val loss=0.081989, val nmse(dB)=-5.0007
# [69/600] train loss=0.124686, nmse(dB)=-3.6558 | val loss=0.079395, nmse(dB)=-5.1415 | 86.3s
#   ↳ saved best_finetune.pt | best@69: val loss=0.079395, val nmse(dB)=-5.1415
# [70/600] train loss=0.121911, nmse(dB)=-3.7558 | val loss=0.076844, nmse(dB)=-5.2845 | 90.8s
#   ↳ saved best_finetune.pt | best@70: val loss=0.076844, val nmse(dB)=-5.2845
# [71/600] train loss=0.119292, nmse(dB)=-3.8564 | val loss=0.074354, nmse(dB)=-5.4289 | 89.8s
#   ↳ saved best_finetune.pt | best@71: val loss=0.074354, val nmse(dB)=-5.4289
# [72/600] train loss=0.116098, nmse(dB)=-3.9709 | val loss=0.071923, nmse(dB)=-5.5747 | 87.0s
#   ↳ saved best_finetune.pt | best@72: val loss=0.071923, val nmse(dB)=-5.5747
# [73/600] train loss=0.113628, nmse(dB)=-4.0678 | val loss=0.069562, nmse(dB)=-5.7212 | 87.8s
#   ↳ saved best_finetune.pt | best@73: val loss=0.069562, val nmse(dB)=-5.7212
# [74/600] train loss=0.111886, nmse(dB)=-4.1431 | val loss=0.067296, nmse(dB)=-5.8668 | 87.8s
#   ↳ saved best_finetune.pt | best@74: val loss=0.067296, val nmse(dB)=-5.8668
# [75/600] train loss=0.109230, nmse(dB)=-4.2536 | val loss=0.065090, nmse(dB)=-6.0133 | 90.7s
#   ↳ saved best_finetune.pt | best@75: val loss=0.065090, val nmse(dB)=-6.0133
# [76/600] train loss=0.106475, nmse(dB)=-4.3635 | val loss=0.062973, nmse(dB)=-6.1589 | 89.6s
#   ↳ saved best_finetune.pt | best@76: val loss=0.062973, val nmse(dB)=-6.1589
# [77/600] train loss=0.104310, nmse(dB)=-4.4559 | val loss=0.060911, nmse(dB)=-6.3055 | 87.5s
#   ↳ saved best_finetune.pt | best@77: val loss=0.060911, val nmse(dB)=-6.3055
# [78/600] train loss=0.102387, nmse(dB)=-4.5461 | val loss=0.058891, nmse(dB)=-6.4542 | 90.4s
#   ↳ saved best_finetune.pt | best@78: val loss=0.058891, val nmse(dB)=-6.4542
# [79/600] train loss=0.099355, nmse(dB)=-4.6880 | val loss=0.056903, nmse(dB)=-6.6056 | 87.8s
#   ↳ saved best_finetune.pt | best@79: val loss=0.056903, val nmse(dB)=-6.6056
# [80/600] train loss=0.097980, nmse(dB)=-4.7578 | val loss=0.054936, nmse(dB)=-6.7609 | 87.7s
#   ↳ saved best_finetune.pt | best@80: val loss=0.054936, val nmse(dB)=-6.7609
# [81/600] train loss=0.095491, nmse(dB)=-4.8643 | val loss=0.053059, nmse(dB)=-6.9146 | 90.1s
#   ↳ saved best_finetune.pt | best@81: val loss=0.053059, val nmse(dB)=-6.9146
# [82/600] train loss=0.093629, nmse(dB)=-4.9549 | val loss=0.051290, nmse(dB)=-7.0648 | 91.0s
#   ↳ saved best_finetune.pt | best@82: val loss=0.051290, val nmse(dB)=-7.0648
# [83/600] train loss=0.091727, nmse(dB)=-5.0573 | val loss=0.049602, nmse(dB)=-7.2131 | 91.1s
#   ↳ saved best_finetune.pt | best@83: val loss=0.049602, val nmse(dB)=-7.2131
# [84/600] train loss=0.090056, nmse(dB)=-5.1371 | val loss=0.047953, nmse(dB)=-7.3632 | 90.9s
#   ↳ saved best_finetune.pt | best@84: val loss=0.047953, val nmse(dB)=-7.3632
# [85/600] train loss=0.088230, nmse(dB)=-5.2384 | val loss=0.046330, nmse(dB)=-7.5163 | 88.1s
#   ↳ saved best_finetune.pt | best@85: val loss=0.046330, val nmse(dB)=-7.5163
# [86/600] train loss=0.085973, nmse(dB)=-5.3623 | val loss=0.044774, nmse(dB)=-7.6684 | 87.5s
#   ↳ saved best_finetune.pt | best@86: val loss=0.044774, val nmse(dB)=-7.6684
# [87/600] train loss=0.084701, nmse(dB)=-5.4340 | val loss=0.043310, nmse(dB)=-7.8168 | 87.7s
#   ↳ saved best_finetune.pt | best@87: val loss=0.043310, val nmse(dB)=-7.8168
# [88/600] train loss=0.083081, nmse(dB)=-5.5281 | val loss=0.041849, nmse(dB)=-7.9701 | 86.8s
#   ↳ saved best_finetune.pt | best@88: val loss=0.041849, val nmse(dB)=-7.9701
# [89/600] train loss=0.081852, nmse(dB)=-5.5922 | val loss=0.040416, nmse(dB)=-8.1261 | 86.8s
#   ↳ saved best_finetune.pt | best@89: val loss=0.040416, val nmse(dB)=-8.1261
# [90/600] train loss=0.080254, nmse(dB)=-5.6918 | val loss=0.039060, nmse(dB)=-8.2792 | 87.2s
#   ↳ saved best_finetune.pt | best@90: val loss=0.039060, val nmse(dB)=-8.2792
# [91/600] train loss=0.078251, nmse(dB)=-5.7996 | val loss=0.037799, nmse(dB)=-8.4268 | 88.1s
#   ↳ saved best_finetune.pt | best@91: val loss=0.037799, val nmse(dB)=-8.4268
# [92/600] train loss=0.077164, nmse(dB)=-5.8703 | val loss=0.036591, nmse(dB)=-8.5733 | 87.3s
#   ↳ saved best_finetune.pt | best@92: val loss=0.036591, val nmse(dB)=-8.5733
# [93/600] train loss=0.075820, nmse(dB)=-5.9643 | val loss=0.035407, nmse(dB)=-8.7222 | 87.0s
#   ↳ saved best_finetune.pt | best@93: val loss=0.035407, val nmse(dB)=-8.7222
# [94/600] train loss=0.075098, nmse(dB)=-6.0128 | val loss=0.034257, nmse(dB)=-8.8720 | 86.8s
#   ↳ saved best_finetune.pt | best@94: val loss=0.034257, val nmse(dB)=-8.8720
# [95/600] train loss=0.073711, nmse(dB)=-6.1036 | val loss=0.033173, nmse(dB)=-9.0182 | 87.5s
#   ↳ saved best_finetune.pt | best@95: val loss=0.033173, val nmse(dB)=-9.0182
# [96/600] train loss=0.072119, nmse(dB)=-6.2073 | val loss=0.032164, nmse(dB)=-9.1592 | 88.2s
#   ↳ saved best_finetune.pt | best@96: val loss=0.032164, val nmse(dB)=-9.1592
# [97/600] train loss=0.070860, nmse(dB)=-6.2868 | val loss=0.031209, nmse(dB)=-9.2971 | 87.6s
#   ↳ saved best_finetune.pt | best@97: val loss=0.031209, val nmse(dB)=-9.2971
# [98/600] train loss=0.070246, nmse(dB)=-6.3386 | val loss=0.030291, nmse(dB)=-9.4339 | 86.5s
#   ↳ saved best_finetune.pt | best@98: val loss=0.030291, val nmse(dB)=-9.4339
# [99/600] train loss=0.069607, nmse(dB)=-6.3844 | val loss=0.029379, nmse(dB)=-9.5744 | 87.1s
#   ↳ saved best_finetune.pt | best@99: val loss=0.029379, val nmse(dB)=-9.5744
# [100/600] train loss=0.068032, nmse(dB)=-6.4875 | val loss=0.028480, nmse(dB)=-9.7178 | 87.7s
#   ↳ saved best_finetune.pt | best@100: val loss=0.028480, val nmse(dB)=-9.7178
# [101/600] train loss=0.067053, nmse(dB)=-6.5551 | val loss=0.027617, nmse(dB)=-9.8603 | 90.3s
#   ↳ saved best_finetune.pt | best@101: val loss=0.027617, val nmse(dB)=-9.8603
# [102/600] train loss=0.066251, nmse(dB)=-6.6137 | val loss=0.026813, nmse(dB)=-9.9978 | 87.6s
#   ↳ saved best_finetune.pt | best@102: val loss=0.026813, val nmse(dB)=-9.9978
# [103/600] train loss=0.065483, nmse(dB)=-6.6870 | val loss=0.026057, nmse(dB)=-10.1318 | 87.5s
#   ↳ saved best_finetune.pt | best@103: val loss=0.026057, val nmse(dB)=-10.1318
# [104/600] train loss=0.064035, nmse(dB)=-6.8034 | val loss=0.025333, nmse(dB)=-10.2643 | 87.3s
#   ↳ saved best_finetune.pt | best@104: val loss=0.025333, val nmse(dB)=-10.2643
# [105/600] train loss=0.063591, nmse(dB)=-6.8317 | val loss=0.024640, nmse(dB)=-10.3954 | 87.6s
#   ↳ saved best_finetune.pt | best@105: val loss=0.024640, val nmse(dB)=-10.3954
# [106/600] train loss=0.063092, nmse(dB)=-6.8783 | val loss=0.023991, nmse(dB)=-10.5224 | 88.5s
#   ↳ saved best_finetune.pt | best@106: val loss=0.023991, val nmse(dB)=-10.5224
# [107/600] train loss=0.062357, nmse(dB)=-6.9286 | val loss=0.023375, nmse(dB)=-10.6461 | 86.8s
#   ↳ saved best_finetune.pt | best@107: val loss=0.023375, val nmse(dB)=-10.6461
# [108/600] train loss=0.061237, nmse(dB)=-7.0442 | val loss=0.022800, nmse(dB)=-10.7650 | 87.2s
#   ↳ saved best_finetune.pt | best@108: val loss=0.022800, val nmse(dB)=-10.7650
# [109/600] train loss=0.061017, nmse(dB)=-7.0520 | val loss=0.022247, nmse(dB)=-10.8830 | 86.8s
#   ↳ saved best_finetune.pt | best@109: val loss=0.022247, val nmse(dB)=-10.8830
# [110/600] train loss=0.060442, nmse(dB)=-7.0950 | val loss=0.021702, nmse(dB)=-11.0023 | 86.7s
#   ↳ saved best_finetune.pt | best@110: val loss=0.021702, val nmse(dB)=-11.0023
# [111/600] train loss=0.059532, nmse(dB)=-7.1836 | val loss=0.021170, nmse(dB)=-11.1228 | 87.5s
#   ↳ saved best_finetune.pt | best@111: val loss=0.021170, val nmse(dB)=-11.1228
# [112/600] train loss=0.059035, nmse(dB)=-7.2257 | val loss=0.020681, nmse(dB)=-11.2377 | 87.9s
#   ↳ saved best_finetune.pt | best@112: val loss=0.020681, val nmse(dB)=-11.2377
# [113/600] train loss=0.058721, nmse(dB)=-7.2402 | val loss=0.020227, nmse(dB)=-11.3476 | 87.2s
#   ↳ saved best_finetune.pt | best@113: val loss=0.020227, val nmse(dB)=-11.3476
# [114/600] train loss=0.058229, nmse(dB)=-7.2853 | val loss=0.019798, nmse(dB)=-11.4547 | 87.3s
#   ↳ saved best_finetune.pt | best@114: val loss=0.019798, val nmse(dB)=-11.4547
# [115/600] train loss=0.057860, nmse(dB)=-7.3094 | val loss=0.019383, nmse(dB)=-11.5609 | 87.3s
#   ↳ saved best_finetune.pt | best@115: val loss=0.019383, val nmse(dB)=-11.5609
# [116/600] train loss=0.057503, nmse(dB)=-7.3627 | val loss=0.018990, nmse(dB)=-11.6640 | 86.9s
#   ↳ saved best_finetune.pt | best@116: val loss=0.018990, val nmse(dB)=-11.6640
# [117/600] train loss=0.057201, nmse(dB)=-7.4047 | val loss=0.018604, nmse(dB)=-11.7669 | 87.4s
#   ↳ saved best_finetune.pt | best@117: val loss=0.018604, val nmse(dB)=-11.7669
# [118/600] train loss=0.056933, nmse(dB)=-7.4169 | val loss=0.018224, nmse(dB)=-11.8712 | 87.1s
#   ↳ saved best_finetune.pt | best@118: val loss=0.018224, val nmse(dB)=-11.8712
# [119/600] train loss=0.056242, nmse(dB)=-7.4844 | val loss=0.017848, nmse(dB)=-11.9773 | 89.7s
#   ↳ saved best_finetune.pt | best@119: val loss=0.017848, val nmse(dB)=-11.9773
# [120/600] train loss=0.055724, nmse(dB)=-7.5316 | val loss=0.017511, nmse(dB)=-12.0751 | 87.4s
#   ↳ saved best_finetune.pt | best@120: val loss=0.017511, val nmse(dB)=-12.0751
# [121/600] train loss=0.055466, nmse(dB)=-7.5439 | val loss=0.017226, nmse(dB)=-12.1603 | 87.7s
#   ↳ saved best_finetune.pt | best@121: val loss=0.017226, val nmse(dB)=-12.1603
# [122/600] train loss=0.055075, nmse(dB)=-7.6020 | val loss=0.016952, nmse(dB)=-12.2444 | 87.1s
#   ↳ saved best_finetune.pt | best@122: val loss=0.016952, val nmse(dB)=-12.2444
# [123/600] train loss=0.054689, nmse(dB)=-7.6452 | val loss=0.016678, nmse(dB)=-12.3303 | 87.2s
#   ↳ saved best_finetune.pt | best@123: val loss=0.016678, val nmse(dB)=-12.3303
# [124/600] train loss=0.054170, nmse(dB)=-7.6720 | val loss=0.016424, nmse(dB)=-12.4121 | 86.6s
#   ↳ saved best_finetune.pt | best@124: val loss=0.016424, val nmse(dB)=-12.4121
# [125/600] train loss=0.054086, nmse(dB)=-7.6795 | val loss=0.016175, nmse(dB)=-12.4950 | 87.2s
#   ↳ saved best_finetune.pt | best@125: val loss=0.016175, val nmse(dB)=-12.4950
# [126/600] train loss=0.053675, nmse(dB)=-7.7302 | val loss=0.015933, nmse(dB)=-12.5777 | 86.4s
#   ↳ saved best_finetune.pt | best@126: val loss=0.015933, val nmse(dB)=-12.5777
# [127/600] train loss=0.053718, nmse(dB)=-7.7282 | val loss=0.015703, nmse(dB)=-12.6579 | 87.5s
#   ↳ saved best_finetune.pt | best@127: val loss=0.015703, val nmse(dB)=-12.6579
# [128/600] train loss=0.053286, nmse(dB)=-7.7952 | val loss=0.015492, nmse(dB)=-12.7323 | 87.6s
#   ↳ saved best_finetune.pt | best@128: val loss=0.015492, val nmse(dB)=-12.7323
# [129/600] train loss=0.053198, nmse(dB)=-7.7654 | val loss=0.015275, nmse(dB)=-12.8098 | 87.3s
#   ↳ saved best_finetune.pt | best@129: val loss=0.015275, val nmse(dB)=-12.8098
# [130/600] train loss=0.052777, nmse(dB)=-7.8360 | val loss=0.015068, nmse(dB)=-12.8847 | 90.5s
#   ↳ saved best_finetune.pt | best@130: val loss=0.015068, val nmse(dB)=-12.8847
# [131/600] train loss=0.052000, nmse(dB)=-7.8932 | val loss=0.014865, nmse(dB)=-12.9587 | 87.7s
#   ↳ saved best_finetune.pt | best@131: val loss=0.014865, val nmse(dB)=-12.9587
# [132/600] train loss=0.052101, nmse(dB)=-7.8885 | val loss=0.014681, nmse(dB)=-13.0273 | 86.7s
#   ↳ saved best_finetune.pt | best@132: val loss=0.014681, val nmse(dB)=-13.0273
# [133/600] train loss=0.051965, nmse(dB)=-7.9352 | val loss=0.014518, nmse(dB)=-13.0901 | 87.7s
#   ↳ saved best_finetune.pt | best@133: val loss=0.014518, val nmse(dB)=-13.0901
# [134/600] train loss=0.051724, nmse(dB)=-7.9230 | val loss=0.014377, nmse(dB)=-13.1466 | 88.5s
#   ↳ saved best_finetune.pt | best@134: val loss=0.014377, val nmse(dB)=-13.1466
# [135/600] train loss=0.051538, nmse(dB)=-7.9651 | val loss=0.014231, nmse(dB)=-13.2063 | 88.2s
#   ↳ saved best_finetune.pt | best@135: val loss=0.014231, val nmse(dB)=-13.2063
# [136/600] train loss=0.051311, nmse(dB)=-8.0137 | val loss=0.014084, nmse(dB)=-13.2688 | 87.8s
#   ↳ saved best_finetune.pt | best@136: val loss=0.014084, val nmse(dB)=-13.2688
# [137/600] train loss=0.051363, nmse(dB)=-7.9577 | val loss=0.013932, nmse(dB)=-13.3341 | 90.9s
#   ↳ saved best_finetune.pt | best@137: val loss=0.013932, val nmse(dB)=-13.3341
# [138/600] train loss=0.051082, nmse(dB)=-7.9872 | val loss=0.013799, nmse(dB)=-13.3914 | 88.7s
#   ↳ saved best_finetune.pt | best@138: val loss=0.013799, val nmse(dB)=-13.3914
# [139/600] train loss=0.051140, nmse(dB)=-7.9962 | val loss=0.013690, nmse(dB)=-13.4394 | 87.9s
#   ↳ saved best_finetune.pt | best@139: val loss=0.013690, val nmse(dB)=-13.4394
# [140/600] train loss=0.050476, nmse(dB)=-8.0718 | val loss=0.013579, nmse(dB)=-13.4889 | 90.3s
#   ↳ saved best_finetune.pt | best@140: val loss=0.013579, val nmse(dB)=-13.4889
# [141/600] train loss=0.050331, nmse(dB)=-8.0792 | val loss=0.013459, nmse(dB)=-13.5426 | 86.9s
#   ↳ saved best_finetune.pt | best@141: val loss=0.013459, val nmse(dB)=-13.5426
# [142/600] train loss=0.050571, nmse(dB)=-8.0548 | val loss=0.013351, nmse(dB)=-13.5890 | 86.4s
#   ↳ saved best_finetune.pt | best@142: val loss=0.013351, val nmse(dB)=-13.5890
# [143/600] train loss=0.050174, nmse(dB)=-8.1159 | val loss=0.013250, nmse(dB)=-13.6321 | 87.5s
#   ↳ saved best_finetune.pt | best@143: val loss=0.013250, val nmse(dB)=-13.6321
# [144/600] train loss=0.050216, nmse(dB)=-8.0987 | val loss=0.013154, nmse(dB)=-13.6744 | 87.0s
#   ↳ saved best_finetune.pt | best@144: val loss=0.013154, val nmse(dB)=-13.6744
# [145/600] train loss=0.050288, nmse(dB)=-8.0683 | val loss=0.013057, nmse(dB)=-13.7202 | 86.0s
#   ↳ saved best_finetune.pt | best@145: val loss=0.013057, val nmse(dB)=-13.7202
# [146/600] train loss=0.050047, nmse(dB)=-8.1421 | val loss=0.012959, nmse(dB)=-13.7684 | 86.4s
#   ↳ saved best_finetune.pt | best@146: val loss=0.012959, val nmse(dB)=-13.7684
# [147/600] train loss=0.049681, nmse(dB)=-8.1707 | val loss=0.012882, nmse(dB)=-13.8075 | 90.7s
#   ↳ saved best_finetune.pt | best@147: val loss=0.012882, val nmse(dB)=-13.8075
# [148/600] train loss=0.049868, nmse(dB)=-8.1519 | val loss=0.012818, nmse(dB)=-13.8410 | 87.1s
#   ↳ saved best_finetune.pt | best@148: val loss=0.012818, val nmse(dB)=-13.8410
# [149/600] train loss=0.049840, nmse(dB)=-8.1455 | val loss=0.012768, nmse(dB)=-13.8676 | 87.3s
#   ↳ saved best_finetune.pt | best@149: val loss=0.012768, val nmse(dB)=-13.8676
# [150/600] train loss=0.049438, nmse(dB)=-8.1826 | val loss=0.012710, nmse(dB)=-13.8981 | 87.5s
#   ↳ saved best_finetune.pt | best@150: val loss=0.012710, val nmse(dB)=-13.8981
# [151/600] train loss=0.049680, nmse(dB)=-8.1653 | val loss=0.012629, nmse(dB)=-13.9408 | 86.5s
#   ↳ saved best_finetune.pt | best@151: val loss=0.012629, val nmse(dB)=-13.9408
# [152/600] train loss=0.049261, nmse(dB)=-8.2118 | val loss=0.012546, nmse(dB)=-13.9831 | 88.3s
#   ↳ saved best_finetune.pt | best@152: val loss=0.012546, val nmse(dB)=-13.9831
# [153/600] train loss=0.049640, nmse(dB)=-8.1916 | val loss=0.012489, nmse(dB)=-14.0102 | 87.1s
#   ↳ saved best_finetune.pt | best@153: val loss=0.012489, val nmse(dB)=-14.0102
# [154/600] train loss=0.049096, nmse(dB)=-8.2447 | val loss=0.012453, nmse(dB)=-14.0268 | 87.3s
#   ↳ saved best_finetune.pt | best@154: val loss=0.012453, val nmse(dB)=-14.0268
# [155/600] train loss=0.049236, nmse(dB)=-8.2307 | val loss=0.012398, nmse(dB)=-14.0542 | 87.6s
#   ↳ saved best_finetune.pt | best@155: val loss=0.012398, val nmse(dB)=-14.0542
# [156/600] train loss=0.048921, nmse(dB)=-8.2710 | val loss=0.012328, nmse(dB)=-14.0917 | 87.4s
#   ↳ saved best_finetune.pt | best@156: val loss=0.012328, val nmse(dB)=-14.0917
# [157/600] train loss=0.048877, nmse(dB)=-8.2666 | val loss=0.012268, nmse(dB)=-14.1255 | 87.5s
#   ↳ saved best_finetune.pt | best@157: val loss=0.012268, val nmse(dB)=-14.1255
# [158/600] train loss=0.048569, nmse(dB)=-8.2929 | val loss=0.012213, nmse(dB)=-14.1566 | 87.1s
#   ↳ saved best_finetune.pt | best@158: val loss=0.012213, val nmse(dB)=-14.1566
# [159/600] train loss=0.048358, nmse(dB)=-8.3083 | val loss=0.012167, nmse(dB)=-14.1824 | 86.8s
#   ↳ saved best_finetune.pt | best@159: val loss=0.012167, val nmse(dB)=-14.1824
# [160/600] train loss=0.048552, nmse(dB)=-8.3036 | val loss=0.012125, nmse(dB)=-14.2067 | 87.0s
#   ↳ saved best_finetune.pt | best@160: val loss=0.012125, val nmse(dB)=-14.2067
# [161/600] train loss=0.048340, nmse(dB)=-8.3022 | val loss=0.012080, nmse(dB)=-14.2299 | 87.4s
#   ↳ saved best_finetune.pt | best@161: val loss=0.012080, val nmse(dB)=-14.2299
# [162/600] train loss=0.048331, nmse(dB)=-8.3196 | val loss=0.012043, nmse(dB)=-14.2499 | 87.3s
#   ↳ saved best_finetune.pt | best@162: val loss=0.012043, val nmse(dB)=-14.2499
# [163/600] train loss=0.048638, nmse(dB)=-8.3029 | val loss=0.012005, nmse(dB)=-14.2697 | 88.7s
#   ↳ saved best_finetune.pt | best@163: val loss=0.012005, val nmse(dB)=-14.2697
# [164/600] train loss=0.048286, nmse(dB)=-8.3174 | val loss=0.011975, nmse(dB)=-14.2878 | 88.3s
#   ↳ saved best_finetune.pt | best@164: val loss=0.011975, val nmse(dB)=-14.2878
# [165/600] train loss=0.047945, nmse(dB)=-8.3722 | val loss=0.011944, nmse(dB)=-14.3074 | 86.9s
#   ↳ saved best_finetune.pt | best@165: val loss=0.011944, val nmse(dB)=-14.3074
# [166/600] train loss=0.048318, nmse(dB)=-8.3485 | val loss=0.011911, nmse(dB)=-14.3284 | 87.5s
#   ↳ saved best_finetune.pt | best@166: val loss=0.011911, val nmse(dB)=-14.3284
# [167/600] train loss=0.047885, nmse(dB)=-8.3769 | val loss=0.011878, nmse(dB)=-14.3483 | 87.6s
#   ↳ saved best_finetune.pt | best@167: val loss=0.011878, val nmse(dB)=-14.3483
# [168/600] train loss=0.048187, nmse(dB)=-8.3239 | val loss=0.011841, nmse(dB)=-14.3707 | 86.9s
#   ↳ saved best_finetune.pt | best@168: val loss=0.011841, val nmse(dB)=-14.3707
# [169/600] train loss=0.047783, nmse(dB)=-8.3812 | val loss=0.011808, nmse(dB)=-14.3922 | 87.8s
#   ↳ saved best_finetune.pt | best@169: val loss=0.011808, val nmse(dB)=-14.3922
# [170/600] train loss=0.047756, nmse(dB)=-8.3818 | val loss=0.011785, nmse(dB)=-14.4077 | 86.3s
#   ↳ saved best_finetune.pt | best@170: val loss=0.011785, val nmse(dB)=-14.4077
# [171/600] train loss=0.048133, nmse(dB)=-8.3496 | val loss=0.011767, nmse(dB)=-14.4187 | 87.4s
#   ↳ saved best_finetune.pt | best@171: val loss=0.011767, val nmse(dB)=-14.4187
# [172/600] train loss=0.047800, nmse(dB)=-8.3789 | val loss=0.011734, nmse(dB)=-14.4383 | 87.4s
#   ↳ saved best_finetune.pt | best@172: val loss=0.011734, val nmse(dB)=-14.4383
# [173/600] train loss=0.047520, nmse(dB)=-8.4327 | val loss=0.011704, nmse(dB)=-14.4563 | 86.2s
#   ↳ saved best_finetune.pt | best@173: val loss=0.011704, val nmse(dB)=-14.4563
# [174/600] train loss=0.047966, nmse(dB)=-8.3728 | val loss=0.011680, nmse(dB)=-14.4713 | 88.2s
#   ↳ saved best_finetune.pt | best@174: val loss=0.011680, val nmse(dB)=-14.4713
# [175/600] train loss=0.047938, nmse(dB)=-8.3927 | val loss=0.011664, nmse(dB)=-14.4814 | 87.7s
#   ↳ saved best_finetune.pt | best@175: val loss=0.011664, val nmse(dB)=-14.4814
# [176/600] train loss=0.047372, nmse(dB)=-8.4347 | val loss=0.011651, nmse(dB)=-14.4899 | 86.9s
#   ↳ saved best_finetune.pt | best@176: val loss=0.011651, val nmse(dB)=-14.4899
# [177/600] train loss=0.047545, nmse(dB)=-8.4240 | val loss=0.011626, nmse(dB)=-14.5048 | 87.1s
#   ↳ saved best_finetune.pt | best@177: val loss=0.011626, val nmse(dB)=-14.5048
# [178/600] train loss=0.047727, nmse(dB)=-8.4011 | val loss=0.011606, nmse(dB)=-14.5160 | 88.3s
#   ↳ saved best_finetune.pt | best@178: val loss=0.011606, val nmse(dB)=-14.5160
# [179/600] train loss=0.047619, nmse(dB)=-8.4116 | val loss=0.011598, nmse(dB)=-14.5186 | 87.6s
#   ↳ saved best_finetune.pt | best@179: val loss=0.011598, val nmse(dB)=-14.5186
# [180/600] train loss=0.047253, nmse(dB)=-8.4380 | val loss=0.011586, nmse(dB)=-14.5247 | 87.5s
#   ↳ saved best_finetune.pt | best@180: val loss=0.011586, val nmse(dB)=-14.5247
# [181/600] train loss=0.047743, nmse(dB)=-8.3897 | val loss=0.011570, nmse(dB)=-14.5354 | 86.6s
#   ↳ saved best_finetune.pt | best@181: val loss=0.011570, val nmse(dB)=-14.5354
# [182/600] train loss=0.047346, nmse(dB)=-8.4413 | val loss=0.011540, nmse(dB)=-14.5566 | 87.7s
#   ↳ saved best_finetune.pt | best@182: val loss=0.011540, val nmse(dB)=-14.5566
# [183/600] train loss=0.047376, nmse(dB)=-8.4424 | val loss=0.011528, nmse(dB)=-14.5647 | 87.9s
#   ↳ saved best_finetune.pt | best@183: val loss=0.011528, val nmse(dB)=-14.5647
# [184/600] train loss=0.047798, nmse(dB)=-8.3720 | val loss=0.011514, nmse(dB)=-14.5747 | 90.3s
#   ↳ saved best_finetune.pt | best@184: val loss=0.011514, val nmse(dB)=-14.5747
# [185/600] train loss=0.047701, nmse(dB)=-8.4096 | val loss=0.011503, nmse(dB)=-14.5805 | 86.5s
#   ↳ saved best_finetune.pt | best@185: val loss=0.011503, val nmse(dB)=-14.5805
# [186/600] train loss=0.047340, nmse(dB)=-8.4586 | val loss=0.011499, nmse(dB)=-14.5814 | 87.3s
#   ↳ saved best_finetune.pt | best@186: val loss=0.011499, val nmse(dB)=-14.5814
# [187/600] train loss=0.047195, nmse(dB)=-8.4700 | val loss=0.011487, nmse(dB)=-14.5864 | 87.6s
#   ↳ saved best_finetune.pt | best@187: val loss=0.011487, val nmse(dB)=-14.5864
# [188/600] train loss=0.047690, nmse(dB)=-8.4068 | val loss=0.011473, nmse(dB)=-14.5928 | 87.2s
#   ↳ saved best_finetune.pt | best@188: val loss=0.011473, val nmse(dB)=-14.5928
# [189/600] train loss=0.047072, nmse(dB)=-8.4700 | val loss=0.011453, nmse(dB)=-14.6049 | 87.7s
#   ↳ saved best_finetune.pt | best@189: val loss=0.011453, val nmse(dB)=-14.6049
# [190/600] train loss=0.047056, nmse(dB)=-8.4919 | val loss=0.011429, nmse(dB)=-14.6216 | 86.9s
#   ↳ saved best_finetune.pt | best@190: val loss=0.011429, val nmse(dB)=-14.6216
# [191/600] train loss=0.046903, nmse(dB)=-8.4982 | val loss=0.011419, nmse(dB)=-14.6310 | 90.6s
#   ↳ saved best_finetune.pt | best@191: val loss=0.011419, val nmse(dB)=-14.6310
# [192/600] train loss=0.047083, nmse(dB)=-8.4616 | val loss=0.011420, nmse(dB)=-14.6337 | 87.6s
# [193/600] train loss=0.047091, nmse(dB)=-8.4825 | val loss=0.011412, nmse(dB)=-14.6430 | 86.2s
#   ↳ saved best_finetune.pt | best@193: val loss=0.011412, val nmse(dB)=-14.6430
# [194/600] train loss=0.047176, nmse(dB)=-8.4623 | val loss=0.011397, nmse(dB)=-14.6542 | 87.7s
#   ↳ saved best_finetune.pt | best@194: val loss=0.011397, val nmse(dB)=-14.6542
# [195/600] train loss=0.046634, nmse(dB)=-8.5421 | val loss=0.011387, nmse(dB)=-14.6613 | 86.8s
#   ↳ saved best_finetune.pt | best@195: val loss=0.011387, val nmse(dB)=-14.6613
# [196/600] train loss=0.047201, nmse(dB)=-8.4731 | val loss=0.011368, nmse(dB)=-14.6737 | 89.0s
#   ↳ saved best_finetune.pt | best@196: val loss=0.011368, val nmse(dB)=-14.6737
# [197/600] train loss=0.047071, nmse(dB)=-8.4904 | val loss=0.011352, nmse(dB)=-14.6815 | 89.3s
#   ↳ saved best_finetune.pt | best@197: val loss=0.011352, val nmse(dB)=-14.6815
# [198/600] train loss=0.046908, nmse(dB)=-8.4847 | val loss=0.011345, nmse(dB)=-14.6840 | 87.4s
#   ↳ saved best_finetune.pt | best@198: val loss=0.011345, val nmse(dB)=-14.6840
# [199/600] train loss=0.046912, nmse(dB)=-8.5239 | val loss=0.011338, nmse(dB)=-14.6861 | 87.2s
#   ↳ saved best_finetune.pt | best@199: val loss=0.011338, val nmse(dB)=-14.6861
# [200/600] train loss=0.047018, nmse(dB)=-8.4860 | val loss=0.011340, nmse(dB)=-14.6838 | 87.5s
# [201/600] train loss=0.047181, nmse(dB)=-8.4865 | val loss=0.011340, nmse(dB)=-14.6839 | 87.5s
# [202/600] train loss=0.046703, nmse(dB)=-8.5189 | val loss=0.011340, nmse(dB)=-14.6869 | 86.8s
# [203/600] train loss=0.046791, nmse(dB)=-8.5073 | val loss=0.011346, nmse(dB)=-14.6828 | 88.5s
# [204/600] train loss=0.046883, nmse(dB)=-8.4883 | val loss=0.011339, nmse(dB)=-14.6874 | 87.5s
# [205/600] train loss=0.046800, nmse(dB)=-8.5165 | val loss=0.011315, nmse(dB)=-14.7033 | 87.9s
#   ↳ saved best_finetune.pt | best@205: val loss=0.011315, val nmse(dB)=-14.7033
# [206/600] train loss=0.047048, nmse(dB)=-8.4867 | val loss=0.011309, nmse(dB)=-14.7077 | 89.9s
#   ↳ saved best_finetune.pt | best@206: val loss=0.011309, val nmse(dB)=-14.7077
# [207/600] train loss=0.047003, nmse(dB)=-8.5038 | val loss=0.011306, nmse(dB)=-14.7115 | 87.5s
#   ↳ saved best_finetune.pt | best@207: val loss=0.011306, val nmse(dB)=-14.7115
# [208/600] train loss=0.046598, nmse(dB)=-8.5390 | val loss=0.011299, nmse(dB)=-14.7163 | 87.7s
#   ↳ saved best_finetune.pt | best@208: val loss=0.011299, val nmse(dB)=-14.7163
# [209/600] train loss=0.046487, nmse(dB)=-8.5670 | val loss=0.011290, nmse(dB)=-14.7227 | 87.5s
#   ↳ saved best_finetune.pt | best@209: val loss=0.011290, val nmse(dB)=-14.7227
# [210/600] train loss=0.046915, nmse(dB)=-8.4827 | val loss=0.011280, nmse(dB)=-14.7302 | 87.1s
#   ↳ saved best_finetune.pt | best@210: val loss=0.011280, val nmse(dB)=-14.7302
# [211/600] train loss=0.046465, nmse(dB)=-8.5594 | val loss=0.011273, nmse(dB)=-14.7368 | 87.2s
#   ↳ saved best_finetune.pt | best@211: val loss=0.011273, val nmse(dB)=-14.7368
# [212/600] train loss=0.046664, nmse(dB)=-8.5303 | val loss=0.011269, nmse(dB)=-14.7393 | 87.7s
#   ↳ saved best_finetune.pt | best@212: val loss=0.011269, val nmse(dB)=-14.7393
# [213/600] train loss=0.046813, nmse(dB)=-8.4988 | val loss=0.011266, nmse(dB)=-14.7400 | 87.2s
#   ↳ saved best_finetune.pt | best@213: val loss=0.011266, val nmse(dB)=-14.7400
# [214/600] train loss=0.046330, nmse(dB)=-8.5724 | val loss=0.011265, nmse(dB)=-14.7372 | 87.0s
#   ↳ saved best_finetune.pt | best@214: val loss=0.011265, val nmse(dB)=-14.7372
# [215/600] train loss=0.046737, nmse(dB)=-8.5505 | val loss=0.011257, nmse(dB)=-14.7395 | 86.8s
#   ↳ saved best_finetune.pt | best@215: val loss=0.011257, val nmse(dB)=-14.7395
# [216/600] train loss=0.046429, nmse(dB)=-8.5688 | val loss=0.011250, nmse(dB)=-14.7418 | 86.8s
#   ↳ saved best_finetune.pt | best@216: val loss=0.011250, val nmse(dB)=-14.7418
# [217/600] train loss=0.046448, nmse(dB)=-8.5654 | val loss=0.011254, nmse(dB)=-14.7373 | 86.9s
# [218/600] train loss=0.046351, nmse(dB)=-8.5550 | val loss=0.011255, nmse(dB)=-14.7354 | 87.7s
# [219/600] train loss=0.046444, nmse(dB)=-8.5500 | val loss=0.011240, nmse(dB)=-14.7471 | 88.2s
#   ↳ saved best_finetune.pt | best@219: val loss=0.011240, val nmse(dB)=-14.7471
# [220/600] train loss=0.046690, nmse(dB)=-8.5353 | val loss=0.011232, nmse(dB)=-14.7549 | 89.8s
#   ↳ saved best_finetune.pt | best@220: val loss=0.011232, val nmse(dB)=-14.7549
# [221/600] train loss=0.046514, nmse(dB)=-8.5467 | val loss=0.011236, nmse(dB)=-14.7563 | 87.2s
# [222/600] train loss=0.046538, nmse(dB)=-8.5547 | val loss=0.011237, nmse(dB)=-14.7580 | 88.1s
# [223/600] train loss=0.046437, nmse(dB)=-8.5502 | val loss=0.011228, nmse(dB)=-14.7661 | 87.7s
#   ↳ saved best_finetune.pt | best@223: val loss=0.011228, val nmse(dB)=-14.7661
# [224/600] train loss=0.046149, nmse(dB)=-8.6068 | val loss=0.011220, nmse(dB)=-14.7728 | 90.3s
#   ↳ saved best_finetune.pt | best@224: val loss=0.011220, val nmse(dB)=-14.7728
# [225/600] train loss=0.046170, nmse(dB)=-8.5940 | val loss=0.011218, nmse(dB)=-14.7723 | 87.1s
#   ↳ saved best_finetune.pt | best@225: val loss=0.011218, val nmse(dB)=-14.7723
# [226/600] train loss=0.046376, nmse(dB)=-8.5629 | val loss=0.011220, nmse(dB)=-14.7680 | 86.8s
# [227/600] train loss=0.046365, nmse(dB)=-8.5817 | val loss=0.011221, nmse(dB)=-14.7652 | 87.4s
# [228/600] train loss=0.046448, nmse(dB)=-8.5444 | val loss=0.011209, nmse(dB)=-14.7725 | 87.6s
#   ↳ saved best_finetune.pt | best@228: val loss=0.011209, val nmse(dB)=-14.7725
# [229/600] train loss=0.046355, nmse(dB)=-8.5662 | val loss=0.011202, nmse(dB)=-14.7757 | 87.6s
#   ↳ saved best_finetune.pt | best@229: val loss=0.011202, val nmse(dB)=-14.7757
# [230/600] train loss=0.046190, nmse(dB)=-8.6104 | val loss=0.011208, nmse(dB)=-14.7722 | 87.3s
# [231/600] train loss=0.046382, nmse(dB)=-8.5750 | val loss=0.011214, nmse(dB)=-14.7704 | 87.5s
# [232/600] train loss=0.046538, nmse(dB)=-8.5601 | val loss=0.011225, nmse(dB)=-14.7653 | 88.3s
# [233/600] train loss=0.046026, nmse(dB)=-8.6071 | val loss=0.011221, nmse(dB)=-14.7685 | 86.8s
# [234/600] train loss=0.046301, nmse(dB)=-8.5761 | val loss=0.011216, nmse(dB)=-14.7718 | 86.9s
# [235/600] train loss=0.046281, nmse(dB)=-8.5896 | val loss=0.011217, nmse(dB)=-14.7715 | 86.9s
# [236/600] train loss=0.046141, nmse(dB)=-8.5955 | val loss=0.011211, nmse(dB)=-14.7745 | 86.5s
# [237/600] train loss=0.046205, nmse(dB)=-8.5825 | val loss=0.011204, nmse(dB)=-14.7792 | 86.4s
# [238/600] train loss=0.046198, nmse(dB)=-8.5914 | val loss=0.011195, nmse(dB)=-14.7872 | 87.3s
#   ↳ saved best_finetune.pt | best@238: val loss=0.011195, val nmse(dB)=-14.7872
# [239/600] train loss=0.046029, nmse(dB)=-8.6196 | val loss=0.011188, nmse(dB)=-14.7916 | 87.4s
#   ↳ saved best_finetune.pt | best@239: val loss=0.011188, val nmse(dB)=-14.7916
# [240/600] train loss=0.046023, nmse(dB)=-8.6126 | val loss=0.011188, nmse(dB)=-14.7908 | 86.3s
# [241/600] train loss=0.045881, nmse(dB)=-8.6281 | val loss=0.011198, nmse(dB)=-14.7828 | 88.0s
# [242/600] train loss=0.046282, nmse(dB)=-8.5890 | val loss=0.011200, nmse(dB)=-14.7813 | 87.0s
# [243/600] train loss=0.045980, nmse(dB)=-8.6364 | val loss=0.011199, nmse(dB)=-14.7808 | 87.0s
# [244/600] train loss=0.045968, nmse(dB)=-8.6194 | val loss=0.011196, nmse(dB)=-14.7821 | 87.0s
# [245/600] train loss=0.045899, nmse(dB)=-8.6292 | val loss=0.011193, nmse(dB)=-14.7842 | 87.2s
# [246/600] train loss=0.046077, nmse(dB)=-8.6079 | val loss=0.011188, nmse(dB)=-14.7877 | 86.8s
#   ↳ saved best_finetune.pt | best@246: val loss=0.011188, val nmse(dB)=-14.7877
# [247/600] train loss=0.045839, nmse(dB)=-8.6286 | val loss=0.011186, nmse(dB)=-14.7881 | 87.8s
#   ↳ saved best_finetune.pt | best@247: val loss=0.011186, val nmse(dB)=-14.7881
# [248/600] train loss=0.046142, nmse(dB)=-8.5968 | val loss=0.011183, nmse(dB)=-14.7902 | 86.8s
#   ↳ saved best_finetune.pt | best@248: val loss=0.011183, val nmse(dB)=-14.7902
# [249/600] train loss=0.045983, nmse(dB)=-8.6005 | val loss=0.011181, nmse(dB)=-14.7928 | 86.8s
#   ↳ saved best_finetune.pt | best@249: val loss=0.011181, val nmse(dB)=-14.7928
# [250/600] train loss=0.046113, nmse(dB)=-8.6121 | val loss=0.011177, nmse(dB)=-14.7981 | 87.5s
#   ↳ saved best_finetune.pt | best@250: val loss=0.011177, val nmse(dB)=-14.7981
# [251/600] train loss=0.046068, nmse(dB)=-8.6029 | val loss=0.011177, nmse(dB)=-14.7999 | 87.2s
# [252/600] train loss=0.046027, nmse(dB)=-8.6146 | val loss=0.011177, nmse(dB)=-14.8009 | 87.2s
# [253/600] train loss=0.046014, nmse(dB)=-8.6281 | val loss=0.011181, nmse(dB)=-14.7990 | 86.9s
# [254/600] train loss=0.045910, nmse(dB)=-8.6395 | val loss=0.011184, nmse(dB)=-14.7950 | 86.9s
# [255/600] train loss=0.045963, nmse(dB)=-8.5977 | val loss=0.011186, nmse(dB)=-14.7919 | 90.3s
# [256/600] train loss=0.045817, nmse(dB)=-8.6213 | val loss=0.011174, nmse(dB)=-14.8002 | 90.5s
#   ↳ saved best_finetune.pt | best@256: val loss=0.011174, val nmse(dB)=-14.8002
# [257/600] train loss=0.046057, nmse(dB)=-8.6072 | val loss=0.011166, nmse(dB)=-14.8067 | 89.2s
#   ↳ saved best_finetune.pt | best@257: val loss=0.011166, val nmse(dB)=-14.8067
# [258/600] train loss=0.046151, nmse(dB)=-8.6004 | val loss=0.011160, nmse(dB)=-14.8108 | 86.8s
#   ↳ saved best_finetune.pt | best@258: val loss=0.011160, val nmse(dB)=-14.8108
# [259/600] train loss=0.046006, nmse(dB)=-8.6173 | val loss=0.011156, nmse(dB)=-14.8143 | 87.1s
#   ↳ saved best_finetune.pt | best@259: val loss=0.011156, val nmse(dB)=-14.8143
# [260/600] train loss=0.045645, nmse(dB)=-8.6447 | val loss=0.011157, nmse(dB)=-14.8136 | 89.6s
# [261/600] train loss=0.045913, nmse(dB)=-8.6381 | val loss=0.011158, nmse(dB)=-14.8124 | 87.6s
# [262/600] train loss=0.045793, nmse(dB)=-8.6477 | val loss=0.011166, nmse(dB)=-14.8074 | 87.3s
# [263/600] train loss=0.045661, nmse(dB)=-8.6506 | val loss=0.011178, nmse(dB)=-14.7977 | 87.1s
# [264/600] train loss=0.045741, nmse(dB)=-8.6514 | val loss=0.011187, nmse(dB)=-14.7913 | 87.7s
# [265/600] train loss=0.045787, nmse(dB)=-8.6452 | val loss=0.011181, nmse(dB)=-14.7941 | 87.7s
# [266/600] train loss=0.045613, nmse(dB)=-8.6582 | val loss=0.011177, nmse(dB)=-14.7966 | 87.9s
# [267/600] train loss=0.045904, nmse(dB)=-8.6294 | val loss=0.011175, nmse(dB)=-14.7976 | 86.5s
# [268/600] train loss=0.045698, nmse(dB)=-8.6559 | val loss=0.011178, nmse(dB)=-14.7940 | 86.4s
# [269/600] train loss=0.045860, nmse(dB)=-8.6186 | val loss=0.011175, nmse(dB)=-14.7953 | 87.2s
# [270/600] train loss=0.045682, nmse(dB)=-8.6402 | val loss=0.011163, nmse(dB)=-14.8037 | 87.3s
# [271/600] train loss=0.045603, nmse(dB)=-8.6776 | val loss=0.011152, nmse(dB)=-14.8110 | 87.7s
#   ↳ saved best_finetune.pt | best@271: val loss=0.011152, val nmse(dB)=-14.8110
# [272/600] train loss=0.045788, nmse(dB)=-8.6294 | val loss=0.011150, nmse(dB)=-14.8141 | 87.0s
#   ↳ saved best_finetune.pt | best@272: val loss=0.011150, val nmse(dB)=-14.8141
# [273/600] train loss=0.045393, nmse(dB)=-8.7038 | val loss=0.011153, nmse(dB)=-14.8125 | 87.8s
# [274/600] train loss=0.045643, nmse(dB)=-8.6619 | val loss=0.011161, nmse(dB)=-14.8105 | 87.3s
# [275/600] train loss=0.045869, nmse(dB)=-8.6545 | val loss=0.011166, nmse(dB)=-14.8081 | 87.8s
# [276/600] train loss=0.045647, nmse(dB)=-8.6685 | val loss=0.011165, nmse(dB)=-14.8119 | 87.4s
# [277/600] train loss=0.045818, nmse(dB)=-8.6537 | val loss=0.011159, nmse(dB)=-14.8163 | 87.7s
# [278/600] train loss=0.045648, nmse(dB)=-8.6491 | val loss=0.011156, nmse(dB)=-14.8179 | 87.6s
# [279/600] train loss=0.045633, nmse(dB)=-8.6623 | val loss=0.011153, nmse(dB)=-14.8185 | 87.0s
# [280/600] train loss=0.045723, nmse(dB)=-8.6414 | val loss=0.011156, nmse(dB)=-14.8161 | 87.5s
# [281/600] train loss=0.045841, nmse(dB)=-8.6316 | val loss=0.011162, nmse(dB)=-14.8086 | 88.2s
# [282/600] train loss=0.045426, nmse(dB)=-8.6854 | val loss=0.011171, nmse(dB)=-14.8012 | 90.2s
# [283/600] train loss=0.045453, nmse(dB)=-8.6835 | val loss=0.011171, nmse(dB)=-14.8004 | 89.2s
# [284/600] train loss=0.045502, nmse(dB)=-8.6843 | val loss=0.011166, nmse(dB)=-14.8054 | 88.0s
# [285/600] train loss=0.045627, nmse(dB)=-8.6613 | val loss=0.011159, nmse(dB)=-14.8100 | 87.3s
# [286/600] train loss=0.045704, nmse(dB)=-8.6541 | val loss=0.011152, nmse(dB)=-14.8151 | 87.1s
# [287/600] train loss=0.045674, nmse(dB)=-8.6639 | val loss=0.011145, nmse(dB)=-14.8196 | 88.4s
#   ↳ saved best_finetune.pt | best@287: val loss=0.011145, val nmse(dB)=-14.8196
# [288/600] train loss=0.045573, nmse(dB)=-8.6809 | val loss=0.011148, nmse(dB)=-14.8162 | 88.4s
# [289/600] train loss=0.045506, nmse(dB)=-8.6864 | val loss=0.011153, nmse(dB)=-14.8121 | 86.5s
# [290/600] train loss=0.045585, nmse(dB)=-8.6558 | val loss=0.011155, nmse(dB)=-14.8092 | 86.6s
# [291/600] train loss=0.045411, nmse(dB)=-8.6889 | val loss=0.011152, nmse(dB)=-14.8107 | 87.4s
# [292/600] train loss=0.045659, nmse(dB)=-8.6727 | val loss=0.011146, nmse(dB)=-14.8137 | 87.6s
# [293/600] train loss=0.045392, nmse(dB)=-8.6948 | val loss=0.011146, nmse(dB)=-14.8128 | 88.3s
# [294/600] train loss=0.045404, nmse(dB)=-8.6986 | val loss=0.011150, nmse(dB)=-14.8109 | 88.4s
# [295/600] train loss=0.045559, nmse(dB)=-8.6687 | val loss=0.011161, nmse(dB)=-14.8051 | 87.6s
# [296/600] train loss=0.045652, nmse(dB)=-8.6817 | val loss=0.011164, nmse(dB)=-14.8045 | 87.2s
# [297/600] train loss=0.045557, nmse(dB)=-8.6669 | val loss=0.011160, nmse(dB)=-14.8102 | 87.2s
# [298/600] train loss=0.045402, nmse(dB)=-8.6959 | val loss=0.011158, nmse(dB)=-14.8135 | 87.6s
# [299/600] train loss=0.045589, nmse(dB)=-8.6669 | val loss=0.011152, nmse(dB)=-14.8193 | 87.9s
# [300/600] train loss=0.045439, nmse(dB)=-8.7052 | val loss=0.011145, nmse(dB)=-14.8260 | 87.9s
#   ↳ saved best_finetune.pt | best@300: val loss=0.011145, val nmse(dB)=-14.8260
# [301/600] train loss=0.045305, nmse(dB)=-8.6966 | val loss=0.011144, nmse(dB)=-14.8260 | 87.2s
#   ↳ saved best_finetune.pt | best@301: val loss=0.011144, val nmse(dB)=-14.8260
# [302/600] train loss=0.045416, nmse(dB)=-8.6949 | val loss=0.011146, nmse(dB)=-14.8229 | 88.9s
# [303/600] train loss=0.045588, nmse(dB)=-8.6891 | val loss=0.011150, nmse(dB)=-14.8190 | 87.9s
# [304/600] train loss=0.045520, nmse(dB)=-8.6886 | val loss=0.011153, nmse(dB)=-14.8173 | 86.9s
# [305/600] train loss=0.045532, nmse(dB)=-8.6679 | val loss=0.011151, nmse(dB)=-14.8183 | 88.3s
# [306/600] train loss=0.045360, nmse(dB)=-8.7022 | val loss=0.011149, nmse(dB)=-14.8186 | 88.8s
# [307/600] train loss=0.045408, nmse(dB)=-8.6986 | val loss=0.011150, nmse(dB)=-14.8184 | 87.7s
# [308/600] train loss=0.045452, nmse(dB)=-8.7026 | val loss=0.011152, nmse(dB)=-14.8176 | 87.8s
# [309/600] train loss=0.045372, nmse(dB)=-8.6979 | val loss=0.011158, nmse(dB)=-14.8141 | 87.9s
# [310/600] train loss=0.045470, nmse(dB)=-8.6566 | val loss=0.011158, nmse(dB)=-14.8140 | 87.0s
# [311/600] train loss=0.045303, nmse(dB)=-8.6950 | val loss=0.011155, nmse(dB)=-14.8165 | 87.3s
# [312/600] train loss=0.045587, nmse(dB)=-8.6924 | val loss=0.011144, nmse(dB)=-14.8240 | 87.8s
#   ↳ saved best_finetune.pt | best@312: val loss=0.011144, val nmse(dB)=-14.8240
# [313/600] train loss=0.045480, nmse(dB)=-8.6720 | val loss=0.011141, nmse(dB)=-14.8259 | 87.9s
# ...
# [393/600] train loss=0.044878, nmse(dB)=-8.7652 | val loss=0.011125, nmse(dB)=-14.8351 | 87.4s
# [394/600] train loss=0.044974, nmse(dB)=-8.7523 | val loss=0.011125, nmse(dB)=-14.8357 | 90.1s
# [395/600] train loss=0.045094, nmse(dB)=-8.7454 | val loss=0.011126, nmse(dB)=-14.8348 | 87.5s
# [396/600] train loss=0.045028, nmse(dB)=-8.7446 | val loss=0.011128, nmse(dB)=-14.8332 | 88.9s
# [397/600] train loss=0.045188, nmse(dB)=-8.7356 | val loss=0.011129, nmse(dB)=-14.8318 | 88.9s
# [398/600] train loss=0.044907, nmse(dB)=-8.7665 | val loss=0.011128, nmse(dB)=-14.8316 | 87.6s
# [399/600] train loss=0.044950, nmse(dB)=-8.7684 | val loss=0.011130, nmse(dB)=-14.8301 | 88.1s
# [400/600] train loss=0.044859, nmse(dB)=-8.7486 | val loss=0.011132, nmse(dB)=-14.8284 | 88.2s
# [401/600] train loss=0.044926, nmse(dB)=-8.7540 | val loss=0.011132, nmse(dB)=-14.8283 | 88.0s
# [402/600] train loss=0.044819, nmse(dB)=-8.7697 | val loss=0.011135, nmse(dB)=-14.8264 | 87.6s
# [403/600] train loss=0.044945, nmse(dB)=-8.7501 | val loss=0.011136, nmse(dB)=-14.8256 | 87.6s
# [404/600] train loss=0.044979, nmse(dB)=-8.7663 | val loss=0.011137, nmse(dB)=-14.8251 | 88.2s
# [405/600] train loss=0.044853, nmse(dB)=-8.7880 | val loss=0.011137, nmse(dB)=-14.8260 | 87.8s
# [406/600] train loss=0.044783, nmse(dB)=-8.7746 | val loss=0.011135, nmse(dB)=-14.8283 | 87.7s
# [407/600] train loss=0.044919, nmse(dB)=-8.7449 | val loss=0.011134, nmse(dB)=-14.8298 | 88.9s
# [408/600] train loss=0.044966, nmse(dB)=-8.7409 | val loss=0.011130, nmse(dB)=-14.8329 | 87.1s
# [409/600] train loss=0.045160, nmse(dB)=-8.7444 | val loss=0.011126, nmse(dB)=-14.8353 | 88.4s
# [410/600] train loss=0.044882, nmse(dB)=-8.7584 | val loss=0.011124, nmse(dB)=-14.8369 | 88.1s
#   ↳ saved best_finetune.pt | best@410: val loss=0.011124, val nmse(dB)=-14.8369
# [411/600] train loss=0.044952, nmse(dB)=-8.7489 | val loss=0.011120, nmse(dB)=-14.8383 | 87.3s
#   ↳ saved best_finetune.pt | best@411: val loss=0.011120, val nmse(dB)=-14.8383
# [412/600] train loss=0.044979, nmse(dB)=-8.7517 | val loss=0.011121, nmse(dB)=-14.8365 | 87.7s
# [413/600] train loss=0.044947, nmse(dB)=-8.7609 | val loss=0.011122, nmse(dB)=-14.8349 | 88.5s
# [414/600] train loss=0.044993, nmse(dB)=-8.7466 | val loss=0.011121, nmse(dB)=-14.8355 | 89.0s
# [415/600] train loss=0.044864, nmse(dB)=-8.7709 | val loss=0.011122, nmse(dB)=-14.8349 | 88.5s
# [416/600] train loss=0.044946, nmse(dB)=-8.7682 | val loss=0.011124, nmse(dB)=-14.8345 | 87.6s
# [417/600] train loss=0.044884, nmse(dB)=-8.7793 | val loss=0.011124, nmse(dB)=-14.8340 | 88.2s
# [418/600] train loss=0.044662, nmse(dB)=-8.7915 | val loss=0.011126, nmse(dB)=-14.8330 | 87.5s
# [419/600] train loss=0.045056, nmse(dB)=-8.7667 | val loss=0.011130, nmse(dB)=-14.8308 | 87.2s
# [420/600] train loss=0.045024, nmse(dB)=-8.7543 | val loss=0.011135, nmse(dB)=-14.8283 | 87.7s
# [421/600] train loss=0.044864, nmse(dB)=-8.7602 | val loss=0.011139, nmse(dB)=-14.8255 | 87.5s
# [422/600] train loss=0.044929, nmse(dB)=-8.7559 | val loss=0.011139, nmse(dB)=-14.8258 | 87.9s
# [423/600] train loss=0.044758, nmse(dB)=-8.7818 | val loss=0.011137, nmse(dB)=-14.8277 | 86.9s
# [424/600] train loss=0.044974, nmse(dB)=-8.7480 | val loss=0.011133, nmse(dB)=-14.8294 | 87.3s
# [425/600] train loss=0.045117, nmse(dB)=-8.7383 | val loss=0.011130, nmse(dB)=-14.8319 | 87.2s
# [426/600] train loss=0.044890, nmse(dB)=-8.7564 | val loss=0.011126, nmse(dB)=-14.8338 | 87.8s
# [427/600] train loss=0.045071, nmse(dB)=-8.7429 | val loss=0.011126, nmse(dB)=-14.8347 | 89.0s
# [428/600] train loss=0.044893, nmse(dB)=-8.7637 | val loss=0.011125, nmse(dB)=-14.8355 | 86.5s
# [429/600] train loss=0.044849, nmse(dB)=-8.7766 | val loss=0.011126, nmse(dB)=-14.8350 | 86.9s
# [430/600] train loss=0.045139, nmse(dB)=-8.7300 | val loss=0.011126, nmse(dB)=-14.8348 | 87.1s
# [431/600] train loss=0.044763, nmse(dB)=-8.7840 | val loss=0.011125, nmse(dB)=-14.8353 | 87.3s
# [432/600] train loss=0.044880, nmse(dB)=-8.7735 | val loss=0.011124, nmse(dB)=-14.8366 | 87.3s
# [433/600] train loss=0.044799, nmse(dB)=-8.7821 | val loss=0.011122, nmse(dB)=-14.8375 | 86.9s
# [434/600] train loss=0.045001, nmse(dB)=-8.7501 | val loss=0.011122, nmse(dB)=-14.8375 | 87.3s
# [435/600] train loss=0.044923, nmse(dB)=-8.7538 | val loss=0.011122, nmse(dB)=-14.8382 | 87.5s
# [436/600] train loss=0.045028, nmse(dB)=-8.7571 | val loss=0.011123, nmse(dB)=-14.8376 | 87.0s
# [437/600] train loss=0.044994, nmse(dB)=-8.7547 | val loss=0.011122, nmse(dB)=-14.8375 | 87.4s
# [438/600] train loss=0.044946, nmse(dB)=-8.7541 | val loss=0.011122, nmse(dB)=-14.8375 | 87.0s
# [439/600] train loss=0.044956, nmse(dB)=-8.7557 | val loss=0.011121, nmse(dB)=-14.8383 | 86.7s
# [440/600] train loss=0.044814, nmse(dB)=-8.7704 | val loss=0.011120, nmse(dB)=-14.8385 | 87.1s
#   ↳ saved best_finetune.pt | best@440: val loss=0.011120, val nmse(dB)=-14.8385
# [441/600] train loss=0.044872, nmse(dB)=-8.7639 | val loss=0.011121, nmse(dB)=-14.8378 | 87.7s
# [442/600] train loss=0.044858, nmse(dB)=-8.7732 | val loss=0.011121, nmse(dB)=-14.8375 | 86.4s
# [443/600] train loss=0.045014, nmse(dB)=-8.7547 | val loss=0.011121, nmse(dB)=-14.8367 | 87.9s
# [444/600] train loss=0.045040, nmse(dB)=-8.7504 | val loss=0.011121, nmse(dB)=-14.8360 | 87.0s
# [445/600] train loss=0.044960, nmse(dB)=-8.7758 | val loss=0.011122, nmse(dB)=-14.8350 | 87.5s
# [446/600] train loss=0.044799, nmse(dB)=-8.7804 | val loss=0.011122, nmse(dB)=-14.8349 | 86.6s
# [447/600] train loss=0.044627, nmse(dB)=-8.7835 | val loss=0.011122, nmse(dB)=-14.8349 | 87.6s
# [448/600] train loss=0.044811, nmse(dB)=-8.7805 | val loss=0.011123, nmse(dB)=-14.8349 | 87.8s
# [449/600] train loss=0.044885, nmse(dB)=-8.7697 | val loss=0.011124, nmse(dB)=-14.8340 | 87.1s
# [450/600] train loss=0.045046, nmse(dB)=-8.7441 | val loss=0.011126, nmse(dB)=-14.8329 | 87.2s
# [451/600] train loss=0.044930, nmse(dB)=-8.7798 | val loss=0.011127, nmse(dB)=-14.8326 | 87.4s
# [452/600] train loss=0.045043, nmse(dB)=-8.7520 | val loss=0.011128, nmse(dB)=-14.8319 | 88.1s
# [453/600] train loss=0.044977, nmse(dB)=-8.7586 | val loss=0.011130, nmse(dB)=-14.8311 | 87.4s
# [454/600] train loss=0.044715, nmse(dB)=-8.7940 | val loss=0.011131, nmse(dB)=-14.8302 | 88.7s
# [455/600] train loss=0.044942, nmse(dB)=-8.7683 | val loss=0.011130, nmse(dB)=-14.8306 | 87.9s
# [456/600] train loss=0.044836, nmse(dB)=-8.7544 | val loss=0.011129, nmse(dB)=-14.8308 | 87.3s
# [457/600] train loss=0.044866, nmse(dB)=-8.7664 | val loss=0.011131, nmse(dB)=-14.8294 | 87.4s
# [458/600] train loss=0.044919, nmse(dB)=-8.7702 | val loss=0.011132, nmse(dB)=-14.8287 | 86.9s
# [459/600] train loss=0.044848, nmse(dB)=-8.7653 | val loss=0.011133, nmse(dB)=-14.8286 | 87.5s
# [460/600] train loss=0.044721, nmse(dB)=-8.7820 | val loss=0.011133, nmse(dB)=-14.8290 | 88.5s
# [461/600] train loss=0.044982, nmse(dB)=-8.7603 | val loss=0.011132, nmse(dB)=-14.8294 | 87.7s
# [462/600] train loss=0.044893, nmse(dB)=-8.7748 | val loss=0.011130, nmse(dB)=-14.8314 | 88.9s
# [463/600] train loss=0.045055, nmse(dB)=-8.7467 | val loss=0.011128, nmse(dB)=-14.8327 | 88.2s
# [464/600] train loss=0.044821, nmse(dB)=-8.7707 | val loss=0.011127, nmse(dB)=-14.8334 | 87.3s
# [465/600] train loss=0.044903, nmse(dB)=-8.7624 | val loss=0.011127, nmse(dB)=-14.8340 | 86.9s
# [466/600] train loss=0.044780, nmse(dB)=-8.7879 | val loss=0.011125, nmse(dB)=-14.8351 | 87.3s
# [467/600] train loss=0.044825, nmse(dB)=-8.7707 | val loss=0.011123, nmse(dB)=-14.8361 | 88.3s
# [468/600] train loss=0.044614, nmse(dB)=-8.7801 | val loss=0.011121, nmse(dB)=-14.8368 | 87.9s
# [469/600] train loss=0.044831, nmse(dB)=-8.7820 | val loss=0.011121, nmse(dB)=-14.8366 | 87.6s
# [470/600] train loss=0.044999, nmse(dB)=-8.7527 | val loss=0.011120, nmse(dB)=-14.8366 | 87.5s
# [471/600] train loss=0.044851, nmse(dB)=-8.7690 | val loss=0.011120, nmse(dB)=-14.8364 | 87.5s
#   ↳ saved best_finetune.pt | best@471: val loss=0.011120, val nmse(dB)=-14.8364
# [472/600] train loss=0.044780, nmse(dB)=-8.7816 | val loss=0.011118, nmse(dB)=-14.8374 | 87.2s
#   ↳ saved best_finetune.pt | best@472: val loss=0.011118, val nmse(dB)=-14.8374
# [473/600] train loss=0.044699, nmse(dB)=-8.7942 | val loss=0.011118, nmse(dB)=-14.8375 | 88.1s
# [474/600] train loss=0.044932, nmse(dB)=-8.7455 | val loss=0.011118, nmse(dB)=-14.8381 | 87.1s
#   ↳ saved best_finetune.pt | best@474: val loss=0.011118, val nmse(dB)=-14.8381
# [475/600] train loss=0.044930, nmse(dB)=-8.7764 | val loss=0.011118, nmse(dB)=-14.8381 | 89.4s
# [476/600] train loss=0.044709, nmse(dB)=-8.7930 | val loss=0.011118, nmse(dB)=-14.8381 | 87.9s
# [477/600] train loss=0.044820, nmse(dB)=-8.7931 | val loss=0.011117, nmse(dB)=-14.8386 | 88.7s
#   ↳ saved best_finetune.pt | best@477: val loss=0.011117, val nmse(dB)=-14.8386
# [478/600] train loss=0.044964, nmse(dB)=-8.7638 | val loss=0.011117, nmse(dB)=-14.8387 | 87.6s
#   ↳ saved best_finetune.pt | best@478: val loss=0.011117, val nmse(dB)=-14.8387
# [479/600] train loss=0.044784, nmse(dB)=-8.7788 | val loss=0.011117, nmse(dB)=-14.8385 | 88.1s
# [480/600] train loss=0.044659, nmse(dB)=-8.8122 | val loss=0.011118, nmse(dB)=-14.8378 | 87.0s
# [481/600] train loss=0.044939, nmse(dB)=-8.7559 | val loss=0.011119, nmse(dB)=-14.8372 | 88.5s
# [482/600] train loss=0.044766, nmse(dB)=-8.7791 | val loss=0.011120, nmse(dB)=-14.8373 | 87.2s
# [483/600] train loss=0.044635, nmse(dB)=-8.8003 | val loss=0.011121, nmse(dB)=-14.8368 | 87.8s
# [484/600] train loss=0.044774, nmse(dB)=-8.7888 | val loss=0.011122, nmse(dB)=-14.8361 | 87.0s
# [485/600] train loss=0.044727, nmse(dB)=-8.7871 | val loss=0.011123, nmse(dB)=-14.8354 | 87.8s
# [486/600] train loss=0.044899, nmse(dB)=-8.7643 | val loss=0.011125, nmse(dB)=-14.8342 | 88.8s
# [487/600] train loss=0.045056, nmse(dB)=-8.7459 | val loss=0.011126, nmse(dB)=-14.8330 | 88.2s
# [488/600] train loss=0.044714, nmse(dB)=-8.7915 | val loss=0.011127, nmse(dB)=-14.8324 | 88.2s
# [489/600] train loss=0.044864, nmse(dB)=-8.7713 | val loss=0.011127, nmse(dB)=-14.8325 | 86.8s
# [490/600] train loss=0.044566, nmse(dB)=-8.8011 | val loss=0.011127, nmse(dB)=-14.8321 | 87.5s
# [491/600] train loss=0.044874, nmse(dB)=-8.7685 | val loss=0.011127, nmse(dB)=-14.8319 | 86.8s
# [492/600] train loss=0.044865, nmse(dB)=-8.7859 | val loss=0.011126, nmse(dB)=-14.8323 | 87.6s
# [493/600] train loss=0.044584, nmse(dB)=-8.8052 | val loss=0.011125, nmse(dB)=-14.8325 | 86.7s
# [494/600] train loss=0.044710, nmse(dB)=-8.8063 | val loss=0.011125, nmse(dB)=-14.8328 | 87.5s
# [495/600] train loss=0.044831, nmse(dB)=-8.7782 | val loss=0.011124, nmse(dB)=-14.8330 | 87.9s
# [496/600] train loss=0.044823, nmse(dB)=-8.7789 | val loss=0.011124, nmse(dB)=-14.8333 | 87.5s
# [497/600] train loss=0.044858, nmse(dB)=-8.7616 | val loss=0.011123, nmse(dB)=-14.8344 | 86.5s
# [498/600] train loss=0.044743, nmse(dB)=-8.7750 | val loss=0.011122, nmse(dB)=-14.8350 | 88.3s
# [499/600] train loss=0.044817, nmse(dB)=-8.7827 | val loss=0.011121, nmse(dB)=-14.8354 | 87.4s
# [500/600] train loss=0.044810, nmse(dB)=-8.7688 | val loss=0.011120, nmse(dB)=-14.8360 | 87.1s
# [501/600] train loss=0.044922, nmse(dB)=-8.7656 | val loss=0.011119, nmse(dB)=-14.8368 | 86.8s
# [502/600] train loss=0.044908, nmse(dB)=-8.7612 | val loss=0.011119, nmse(dB)=-14.8373 | 87.6s
# [503/600] train loss=0.044792, nmse(dB)=-8.7899 | val loss=0.011119, nmse(dB)=-14.8375 | 86.5s
# [504/600] train loss=0.044852, nmse(dB)=-8.7561 | val loss=0.011118, nmse(dB)=-14.8377 | 87.9s
# [505/600] train loss=0.044950, nmse(dB)=-8.7652 | val loss=0.011118, nmse(dB)=-14.8382 | 87.1s
# [506/600] train loss=0.045035, nmse(dB)=-8.7593 | val loss=0.011117, nmse(dB)=-14.8387 | 87.8s
#   ↳ saved best_finetune.pt | best@506: val loss=0.011117, val nmse(dB)=-14.8387
# [507/600] train loss=0.044758, nmse(dB)=-8.7882 | val loss=0.011116, nmse(dB)=-14.8392 | 88.7s
#   ↳ saved best_finetune.pt | best@507: val loss=0.011116, val nmse(dB)=-14.8392
# [508/600] train loss=0.044874, nmse(dB)=-8.7643 | val loss=0.011116, nmse(dB)=-14.8395 | 87.4s
#   ↳ saved best_finetune.pt | best@508: val loss=0.011116, val nmse(dB)=-14.8395
# [509/600] train loss=0.044739, nmse(dB)=-8.7796 | val loss=0.011115, nmse(dB)=-14.8399 | 87.7s
#   ↳ saved best_finetune.pt | best@509: val loss=0.011115, val nmse(dB)=-14.8399
# [510/600] train loss=0.044721, nmse(dB)=-8.7665 | val loss=0.011115, nmse(dB)=-14.8400 | 88.9s
#   ↳ saved best_finetune.pt | best@510: val loss=0.011115, val nmse(dB)=-14.8400
# [511/600] train loss=0.044665, nmse(dB)=-8.7951 | val loss=0.011115, nmse(dB)=-14.8402 | 87.6s
#   ↳ saved best_finetune.pt | best@511: val loss=0.011115, val nmse(dB)=-14.8402
# [512/600] train loss=0.044684, nmse(dB)=-8.7943 | val loss=0.011114, nmse(dB)=-14.8404 | 87.2s
#   ↳ saved best_finetune.pt | best@512: val loss=0.011114, val nmse(dB)=-14.8404
# [513/600] train loss=0.044704, nmse(dB)=-8.7877 | val loss=0.011114, nmse(dB)=-14.8405 | 88.3s
#   ↳ saved best_finetune.pt | best@513: val loss=0.011114, val nmse(dB)=-14.8405
# [514/600] train loss=0.044637, nmse(dB)=-8.8146 | val loss=0.011114, nmse(dB)=-14.8407 | 88.5s
#   ↳ saved best_finetune.pt | best@514: val loss=0.011114, val nmse(dB)=-14.8407
# [515/600] train loss=0.044976, nmse(dB)=-8.7544 | val loss=0.011114, nmse(dB)=-14.8409 | 88.4s
#   ↳ saved best_finetune.pt | best@515: val loss=0.011114, val nmse(dB)=-14.8409
# [516/600] train loss=0.044886, nmse(dB)=-8.7737 | val loss=0.011114, nmse(dB)=-14.8409 | 87.5s
# [517/600] train loss=0.044718, nmse(dB)=-8.7833 | val loss=0.011115, nmse(dB)=-14.8408 | 87.6s
# [518/600] train loss=0.044751, nmse(dB)=-8.7910 | val loss=0.011115, nmse(dB)=-14.8406 | 86.3s
# [519/600] train loss=0.044686, nmse(dB)=-8.7981 | val loss=0.011115, nmse(dB)=-14.8405 | 87.3s
# [520/600] train loss=0.044676, nmse(dB)=-8.7922 | val loss=0.011115, nmse(dB)=-14.8403 | 87.4s
# [521/600] train loss=0.044758, nmse(dB)=-8.7848 | val loss=0.011116, nmse(dB)=-14.8401 | 87.6s
# [522/600] train loss=0.044651, nmse(dB)=-8.8014 | val loss=0.011116, nmse(dB)=-14.8400 | 87.7s
# [523/600] train loss=0.044671, nmse(dB)=-8.7987 | val loss=0.011116, nmse(dB)=-14.8397 | 86.9s
# [524/600] train loss=0.044719, nmse(dB)=-8.7904 | val loss=0.011117, nmse(dB)=-14.8394 | 87.5s
# [525/600] train loss=0.044919, nmse(dB)=-8.7693 | val loss=0.011117, nmse(dB)=-14.8392 | 87.6s
# [526/600] train loss=0.044885, nmse(dB)=-8.7673 | val loss=0.011118, nmse(dB)=-14.8388 | 87.2s
# [527/600] train loss=0.044702, nmse(dB)=-8.7856 | val loss=0.011118, nmse(dB)=-14.8385 | 87.6s
# [528/600] train loss=0.044980, nmse(dB)=-8.7489 | val loss=0.011118, nmse(dB)=-14.8385 | 88.0s
# [529/600] train loss=0.044797, nmse(dB)=-8.7732 | val loss=0.011119, nmse(dB)=-14.8384 | 88.4s
# [530/600] train loss=0.044647, nmse(dB)=-8.8035 | val loss=0.011119, nmse(dB)=-14.8383 | 88.1s
# [531/600] train loss=0.044769, nmse(dB)=-8.7973 | val loss=0.011119, nmse(dB)=-14.8385 | 88.6s
# [532/600] train loss=0.044690, nmse(dB)=-8.7849 | val loss=0.011119, nmse(dB)=-14.8387 | 87.2s
# [533/600] train loss=0.044868, nmse(dB)=-8.7767 | val loss=0.011119, nmse(dB)=-14.8388 | 88.0s
# [534/600] train loss=0.044765, nmse(dB)=-8.7917 | val loss=0.011119, nmse(dB)=-14.8388 | 86.7s
# [535/600] train loss=0.044582, nmse(dB)=-8.7987 | val loss=0.011119, nmse(dB)=-14.8388 | 86.7s
# [536/600] train loss=0.044419, nmse(dB)=-8.8141 | val loss=0.011119, nmse(dB)=-14.8387 | 88.5s
# [537/600] train loss=0.045035, nmse(dB)=-8.7395 | val loss=0.011119, nmse(dB)=-14.8387 | 87.7s
# [538/600] train loss=0.044680, nmse(dB)=-8.7739 | val loss=0.011119, nmse(dB)=-14.8387 | 86.9s
# [539/600] train loss=0.044608, nmse(dB)=-8.8109 | val loss=0.011119, nmse(dB)=-14.8387 | 88.7s
# [540/600] train loss=0.044684, nmse(dB)=-8.7783 | val loss=0.011119, nmse(dB)=-14.8388 | 87.9s
# [541/600] train loss=0.044656, nmse(dB)=-8.7898 | val loss=0.011119, nmse(dB)=-14.8389 | 87.4s
# [542/600] train loss=0.044620, nmse(dB)=-8.8010 | val loss=0.011119, nmse(dB)=-14.8389 | 87.5s
# [543/600] train loss=0.044830, nmse(dB)=-8.7691 | val loss=0.011119, nmse(dB)=-14.8389 | 86.2s
# [544/600] train loss=0.044894, nmse(dB)=-8.7557 | val loss=0.011119, nmse(dB)=-14.8390 | 87.9s
# [545/600] train loss=0.044507, nmse(dB)=-8.8011 | val loss=0.011118, nmse(dB)=-14.8392 | 87.6s

# %%
ch, img, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# y abs mean: 0.4955256352418395
# y abs max : 1.0
# y power   : 0.28867590466210136
# yhat abs mean: 0.4940550407560659
# yhat abs max : 0.737765158894013
# yhat power   : 0.24701485682841545
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 데이터 입력 및 형태

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("N(cam_files)  :", len(cam_files))
print("N(min)        :", min(len(comm_frames), len(cam_files)))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

print("\n=== one batch shapes ===")
ch, img, y = next(iter(train_loader))
print("ch :", tuple(ch.shape), " -> (B,T,F_in)")
print("img:", tuple(img.shape), " -> (B,3,224,224)")
print("y  :", tuple(y.shape), " -> (B,F_out)")
with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat:", tuple(yhat.shape), " -> (B,F_out)")
print("this forward predicted vectors:", yhat.shape[0], "(=B)")
print("each vector predicts elements:", yhat.shape[1], "(=F_out)")
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# N(cam_files)  : 7012
# N(min)        : 100
# past_len      : 16
# len(ds)       : 84
# len(train_ds) : 63
# len(val_ds)   : 21
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B,T,F_in)
# img: (32, 16, 3, 224, 224)  -> (B,3,224,224)
# y  : (32, 2048)  -> (B,F_out)
# yhat: (32, 2048)  -> (B,F_out)
# this forward predicted vectors: 32 (=B)
# each vector predicts elements: 2048 (=F_out)
