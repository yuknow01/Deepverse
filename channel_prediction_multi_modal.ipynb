# %% [markdown]
# #  Import

# %%
import os
import sys

import numpy as  np
from lwm_multi_model import multi_modal_lwm  # 클래스 import
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Settings

# %%
# Scenes 2000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(100))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

# %% [markdown]
# # Generate a dataset

# %%
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (1.50s)
# Generating radar dataset: ⏳ In progress
# Generating radar dataset: ✅ Completed (216.90s)

# %% [markdown]
# # location dataset
#  지금 실험에서는 안쓰임

# %%
# comm = dataset.comm_dataset
# location =  comm

# location = [
#     {
#         "bs_loc": d["bs_loc"],                      # (3,)
#         "ue_loc": np.asarray(d["ue_loc"]).squeeze() # (3,)  (원래 (1,3)이면 squeeze)
#     }
#     for row in comm.data      # row: [dict] 형태
#     for d in row              # d: dict
# ]

# print(ue_location)  #)

# %% [markdown]
# # communication  dataset

# %%
# UE 정보
comm = dataset.comm_dataset
ch = comm.data[0][0]['ue'][0]
print(ch.coeffs.shape)
# Out:
# (1, 16, 64)

# %% [markdown]
# # preprocessing

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device="cuda", eps=1e-12):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex64)
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(device)
    return H

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device="cuda", eps=1e-12):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex64)
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(device)
    return H

# %%
# 사용예시
H = preprocess_channel_coeffs_minmax(ch.coeffs, r_min=-0.5, r_max=0.5, i_min=-0.5, i_max=0.5)
print(H.shape)  # (1, 16, 128) 64 subcar
# Out:
# torch.Size([1, 16, 128])

# %% [markdown]
# ### image dataset

# %%
sensor = dataset.camera_dataset.sensors["unit1_cam1"]
path0 = sensor.files[0]
img = Image.open(path0).convert("RGB")
arr = np.array(img)

print("path:", path0)
print("PIL size (W,H):", img.size)
print("np shape:", arr.shape, "dtype:", arr.dtype)  # 보통 (H,W,3), uint8
# Out:
# path: scenarios/DT31/RGB_images/unit1_cam1/0.png
# PIL size (W,H): (1920, 1080)
# np shape: (1080, 1920, 3) dtype: uint8

# %%
IMG_SIZE = 224

def preprocess_img(path, img_size=IMG_SIZE, device="cuda"):
    # 1) load (H,W,3) uint8
    img = Image.open(path).convert("RGB")
    arr = np.array(img)

    # 2) numpy -> torch, (3,H,W), float32
    x = torch.from_numpy(arr).permute(2, 0, 1).contiguous().float()
    x = x / 255.0  # [0,1]

    # 3) add batch dim -> (1,3,H,W)
    x = x.unsqueeze(0)

    # 4) resize -> (1,3,224,224)
    x = F.interpolate(x, size=(img_size, img_size),
                      mode="bilinear", align_corners=False)

    # 5) normalize (ImageNet)
    mean = torch.tensor([0.485, 0.456, 0.406], dtype=x.dtype).view(1, 3, 1, 1)
    std  = torch.tensor([0.229, 0.224, 0.225], dtype=x.dtype).view(1, 3, 1, 1)
    x = (x - mean) / std

    # 6) move to device (GPU)
    x = x.to(device, non_blocking=True)

    return x  # (1,3,224,224) on device

# %%
# 사용예시
cd = dataset.camera_dataset
sensor = cd.sensors['unit1_cam1']
path0 = sensor.files[0]
img = preprocess_img(path0, device="cuda")
print(img.shape, img.device)  # torch.Size([1,3,224,224]) cuda:0
print(path0)
# Out:
# torch.Size([1, 3, 224, 224]) cuda:0
# scenarios/DT31/RGB_images/unit1_cam1/0.png

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class MultiModalNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, cam_files, ue_idx=0, past_len=15, device="cuda",
                 # Arguments for statistical values (initialized with default values)
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        
        self.comm_frames = comm_frames
        self.cam_files = list(cam_files)
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device
        
        # Save statistical values
        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = min(len(self.comm_frames), len(self.cam_files))
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2 

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1. Image Past (Apply Preprocessing)
        img_list = []
        for k in range(t - self.past_len + 1, t + 1):
            img_path = self.cam_files[k]
            img_k = preprocess_img(img_path, device=self.device).squeeze(0)
            img_list.append(img_k)
        img = torch.stack(img_list, dim=0)  # Shape: (past_len

        
        # 2. Channel Past (Apply Scaling)
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            # Use the newly defined Min-Max preprocessing function
            h = preprocess_channel_coeffs_minmax(
                coeffs_np, 
                self.r_min, self.r_max, self.i_min, self.i_max, 
                device=self.device
            ).reshape(-1)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)

        # 3. Target (Apply Scaling) - Target must also be scaled for model training!
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_minmax(
            coeffs_np_next, 
            self.r_min, self.r_max, self.i_min, self.i_max, 
            device=self.device
        ).reshape(-1)

        return channel_past, img, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
sensor = dataset.camera_dataset.sensors["unit1_cam1"]

ds = MultiModalNextStepDatasetGPU(
    comm_frames=comm_frames,
    cam_files=sensor.files,
    ue_idx=0,
    past_len=16,
    device="cuda"
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   # ✅ 의미 없음 (이미 GPU)
)

ch, img, y = next(iter(loader))
print(ch.shape, img.shape, y.shape)
print(ch.device, img.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 16, 3, 224, 224]) torch.Size([8, 2048])
# cuda:0 cuda:0 cuda:0

# %% [markdown]
# # Fine-tuning
# data shape 맞추기 위해

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from lwm_multi_model import multi_modal_lwm  # 너가 올린 backbone

class FinetuneChannelPredictor(nn.Module):
    """
    직접 구현한 lwm_multi_model(channel + image)에 맞는 파인튜닝 모델
    Input:
      ch:  (B, T, F_in)  e.g., (B,16,2048) 16: past Length, 2048: feature dim
      img: (B, 3, 224, 224)
    Output:
      yhat: (B, F_out)  e.g., (B,2048)
    """
    def __init__(
        self,
        backbone: nn.Module,
        F_in: int,
        F_out: int,
        pool: str = "last",          # "last" or "mean"
        freeze_image: bool = False,
        freeze_backbone: bool = False,
        element_length: int = 16,    # 채널 벡터 차원 (backbone 기대값)
        d_model: int = 64            # backbone 내부 feature dim
    ):
        super().__init__()
        self.backbone = backbone
        self.pool = pool

        # backbone이 기대하는 channel feature dim = ELEMENT_LENGTH
        # (backbone 내부 Channel_Embedding: Linear(ELEMENT_LENGTH -> D_MODEL))
        if element_length is None:
            element_length = backbone.channel_embedding.element_length
        if d_model is None:
            d_model = backbone.channel_embedding.d_model

        # 입력 차원 정렬: F_in -> ELEMENT_LENGTH
        self.in_proj = nn.Sequential(
            nn.Linear(F_in, 512),
            nn.GELU(),
            nn.Linear(512, 128),
            nn.GELU(),
            nn.Linear(128, element_length)
        )

        # 출력 head: D_MODEL -> F_out
        self.head = nn.Linear(d_model, F_out)

        if freeze_image:
            for p in self.backbone.image_embedding.parameters():
                p.requires_grad = False

        if freeze_backbone:
            for p in self.backbone.parameters():
                p.requires_grad = False
            # 그래도 projection/head는 학습되게 다시 켜기
            for p in self.in_proj.parameters():
                p.requires_grad = True
            for p in self.head.parameters():
                p.requires_grad = True

    def forward(self, ch, img):
        # ch: (B,T,F_in) -> (B,T,ELEMENT_LENGTH)
        ch = self.in_proj(ch)

        # backbone: (B,T,D_MODEL)
        tokens = self.backbone(ch, img)

        # pooling -> (B,D_MODEL)
        if self.pool == "last":
            z = tokens[:, -1, :]
        elif self.pool == "mean":
            z = tokens.mean(dim=1)
        else:
            raise ValueError(f"Unknown pool={self.pool}")

        # head -> (B,F_out)
        yhat = self.head(z)
        return yhat

# %% [markdown]
# ## NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-12) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# %% [markdown]
# # Train/Val split

# %%
n = len(ds)
n_train = int(0.75 * n)
train_idx = list(range(0, n_train))
val_idx = list(range(n_train, n))

train_ts = [ds.valid_start + i for i in train_idx]

(real_min,  real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_ts, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)

# Verify
ch, img, y = next(iter(train_loader))
print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")
# Out:
# Calculating min/max over training set...
# Done. rmin=-1.0646139668415024e-06, rmax=1.091798991441695e-06, imin=-1.0719515918791155e-06, imax=1.0643867764302909e-06
# Dataset statistical values set in the dataset.
#
# === Data Check ===
# y stats | min: 0.0007, max: 0.9746
# If scaling worked correctly, values should be within [0, 1].

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)
cam_files = list(dataset.camera_dataset.sensors["unit1_cam1"].files)

print("len(comm_frames):", len(comm_frames))
print("len(cam_files):", len(cam_files))
print("first comm frame keys:", list(comm_frames[0].keys()))
print("first cam file:", cam_files[0])
# Out:
# len(comm_frames): 100
# len(cam_files): 7012
# first comm frame keys: ['bs_loc', 'ue', 'ue_loc', 'bs']
# first cam file: scenarios/DT31/RGB_images/unit1_cam1/0.png

# %%
len(val_loader)
# Out:
# 1

# %% [markdown]
# # Model generate and also check

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

# 배치 하나로 F_in/F_out 자동 확정
ch, img, y = next(iter(train_loader))
F_in  = ch.shape[-1]
F_out = y.shape[-1]
print("Detected:", "F_in=", F_in, "F_out=", F_out)
print("Batch devices:", ch.device, img.device, y.device)

# backbone + finetune model
backbone = multi_modal_lwm().to(device)

model = FinetuneChannelPredictor(
    backbone=backbone,
    F_in=F_in,
    F_out=F_out,
    pool="last",            # "mean"으로 바꿔도 됨
    freeze_image=False,     # 원하면 True (이미지 인코더 고정)
    freeze_backbone=False,  # 원하면 True (proj/head만 학습)
    element_length=16,
    d_model=64
).to(device)

# sanity forward
model.eval()
with torch.no_grad():
    # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
    yhat = model(ch.to(device), img.to(device))
print("yhat:", yhat.shape, "y:", y.shape)
# Out:
# device: cuda
# Detected: F_in= 2048 F_out= 2048
# Batch devices: cuda:0 cuda:0 cuda:0
# yhat: torch.Size([32, 2048]) y: torch.Size([32, 2048])

# %% [markdown]
# # Train/ Eval 함수 (AMP + grad clip)

# %%
def train_one_epoch(model, loader, optimizer, device, use_amp=True, grad_clip=1.0):
    model.train()
    scaler = torch.cuda.amp.GradScaler(enabled=use_amp)

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        # Dataset이 이미 cuda 텐서를 반환하더라도 안전하게 유지
        ch = ch.to(device, non_blocking=True)
        img = img.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        with torch.cuda.amp.autocast(enabled=use_amp):
            yhat = model(ch, img)
            loss = F.mse_loss(yhat, y)

        scaler.scale(loss).backward()

        if grad_clip is not None and grad_clip > 0:
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)


@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()

    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, img, y in loader:
        ch = ch.to(device, non_blocking=True)
        img = img.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        yhat = model(ch, img)
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

# %% [markdown]
# #  Optiimizer  / Scheduler 설정

# %%
# requires_grad=True인 파라미터만 학습
trainable_params = [p for p in model.parameters() if p.requires_grad]
print("trainable params:", sum(p.numel() for p in trainable_params))

optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# (선택) cosine scheduler
epochs = 1000
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
# Out:
# trainable params: 2499120

# %% [markdown]
# # 학습 루프 + checkpoint 저장

# %%
best_val = float("inf")

for epoch in range(1, epochs + 1):
    t0 = time.time()

    tr_loss, tr_nmse = train_one_epoch(model, train_loader, optimizer, device=device, use_amp=True, grad_clip=1.0)
    va_loss, va_nmse = evaluate(model, val_loader, device=device)

    scheduler.step()

    dt = time.time() - t0
    print(
        f"[{epoch:02d}/{epochs}] "
        f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
        f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
        f"{dt:.1f}s"
    )

    if va_loss < best_val:
        best_val = va_loss
        torch.save(
            {
                "epoch": epoch,
                "model_state": model.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "F_in": F_in,
                "F_out": F_out,
            },
            "best_finetune.pt"
        )
        print("  ↳ saved best_finetune.pt")
# Out:
# /tmp/ipykernel_9504/900206524.py:3: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# /tmp/ipykernel_9504/900206524.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# [01/1000] train loss=0.592901, nmse(dB)=3.2082 | val loss=0.477058, nmse(dB)=2.6647 | 84.6s
#   ↳ saved best_finetune.pt
# [02/1000] train loss=0.515475, nmse(dB)=2.5984 | val loss=0.436902, nmse(dB)=2.2827 | 83.9s
#   ↳ saved best_finetune.pt
# [03/1000] train loss=0.484834, nmse(dB)=2.3308 | val loss=0.416878, nmse(dB)=2.0789 | 81.5s
#   ↳ saved best_finetune.pt
# [04/1000] train loss=0.463062, nmse(dB)=2.1342 | val loss=0.398489, nmse(dB)=1.8830 | 81.3s
#   ↳ saved best_finetune.pt
# [05/1000] train loss=0.445451, nmse(dB)=1.9630 | val loss=0.381698, nmse(dB)=1.6960 | 83.4s
#   ↳ saved best_finetune.pt
# [06/1000] train loss=0.429579, nmse(dB)=1.8043 | val loss=0.366875, nmse(dB)=1.5239 | 81.0s
#   ↳ saved best_finetune.pt
# [07/1000] train loss=0.412460, nmse(dB)=1.6261 | val loss=0.352936, nmse(dB)=1.3556 | 83.2s
#   ↳ saved best_finetune.pt
# [08/1000] train loss=0.398698, nmse(dB)=1.4735 | val loss=0.339825, nmse(dB)=1.1912 | 80.7s
#   ↳ saved best_finetune.pt
# [09/1000] train loss=0.384732, nmse(dB)=1.3220 | val loss=0.327537, nmse(dB)=1.0311 | 80.4s
#   ↳ saved best_finetune.pt
# [10/1000] train loss=0.376910, nmse(dB)=1.2304 | val loss=0.315932, nmse(dB)=0.8744 | 84.0s
#   ↳ saved best_finetune.pt
# [11/1000] train loss=0.362251, nmse(dB)=1.0550 | val loss=0.305140, nmse(dB)=0.7234 | 80.9s
#   ↳ saved best_finetune.pt
# [12/1000] train loss=0.353268, nmse(dB)=0.9468 | val loss=0.294979, nmse(dB)=0.5762 | 80.4s
#   ↳ saved best_finetune.pt
# [13/1000] train loss=0.342739, nmse(dB)=0.8134 | val loss=0.285405, nmse(dB)=0.4328 | 83.3s
#   ↳ saved best_finetune.pt
# [14/1000] train loss=0.334618, nmse(dB)=0.7052 | val loss=0.276234, nmse(dB)=0.2909 | 80.5s
#   ↳ saved best_finetune.pt
# [15/1000] train loss=0.327119, nmse(dB)=0.6104 | val loss=0.267577, nmse(dB)=0.1525 | 80.5s
#   ↳ saved best_finetune.pt
# [16/1000] train loss=0.317554, nmse(dB)=0.4747 | val loss=0.259627, nmse(dB)=0.0214 | 82.8s
#   ↳ saved best_finetune.pt
# [17/1000] train loss=0.308670, nmse(dB)=0.3518 | val loss=0.252349, nmse(dB)=-0.1021 | 80.2s
#   ↳ saved best_finetune.pt
# [18/1000] train loss=0.304294, nmse(dB)=0.2875 | val loss=0.245601, nmse(dB)=-0.2199 | 83.1s
#   ↳ saved best_finetune.pt
# [19/1000] train loss=0.296938, nmse(dB)=0.1798 | val loss=0.239332, nmse(dB)=-0.3323 | 80.6s
#   ↳ saved best_finetune.pt
# [20/1000] train loss=0.292132, nmse(dB)=0.1065 | val loss=0.233524, nmse(dB)=-0.4391 | 80.6s
#   ↳ saved best_finetune.pt
# [21/1000] train loss=0.286183, nmse(dB)=0.0210 | val loss=0.228188, nmse(dB)=-0.5396 | 83.4s
#   ↳ saved best_finetune.pt
# [22/1000] train loss=0.279941, nmse(dB)=-0.0847 | val loss=0.223269, nmse(dB)=-0.6343 | 81.3s
#   ↳ saved best_finetune.pt
# [23/1000] train loss=0.275903, nmse(dB)=-0.1436 | val loss=0.218786, nmse(dB)=-0.7225 | 80.9s
#   ↳ saved best_finetune.pt
# [24/1000] train loss=0.270907, nmse(dB)=-0.2230 | val loss=0.214609, nmse(dB)=-0.8063 | 84.3s
#   ↳ saved best_finetune.pt
# [25/1000] train loss=0.266042, nmse(dB)=-0.3020 | val loss=0.210678, nmse(dB)=-0.8867 | 81.2s
#   ↳ saved best_finetune.pt
# [26/1000] train loss=0.263488, nmse(dB)=-0.3474 | val loss=0.206949, nmse(dB)=-0.9644 | 80.7s
#   ↳ saved best_finetune.pt
# [27/1000] train loss=0.261293, nmse(dB)=-0.3795 | val loss=0.203403, nmse(dB)=-1.0395 | 83.4s
#   ↳ saved best_finetune.pt
# [28/1000] train loss=0.257863, nmse(dB)=-0.4423 | val loss=0.200002, nmse(dB)=-1.1128 | 81.5s
#   ↳ saved best_finetune.pt
# [29/1000] train loss=0.252725, nmse(dB)=-0.5346 | val loss=0.196683, nmse(dB)=-1.1856 | 84.2s
#   ↳ saved best_finetune.pt
# [30/1000] train loss=0.250374, nmse(dB)=-0.5743 | val loss=0.193478, nmse(dB)=-1.2570 | 81.3s
#   ↳ saved best_finetune.pt
# [31/1000] train loss=0.246877, nmse(dB)=-0.6394 | val loss=0.190381, nmse(dB)=-1.3272 | 81.0s
#   ↳ saved best_finetune.pt
# [32/1000] train loss=0.242888, nmse(dB)=-0.7074 | val loss=0.187342, nmse(dB)=-1.3972 | 83.6s
#   ↳ saved best_finetune.pt
# [33/1000] train loss=0.238141, nmse(dB)=-0.7921 | val loss=0.184261, nmse(dB)=-1.4694 | 80.7s
#   ↳ saved best_finetune.pt
# [34/1000] train loss=0.238309, nmse(dB)=-0.7877 | val loss=0.181046, nmse(dB)=-1.5459 | 81.0s
#   ↳ saved best_finetune.pt
# [35/1000] train loss=0.232350, nmse(dB)=-0.8984 | val loss=0.177844, nmse(dB)=-1.6235 | 83.8s
#   ↳ saved best_finetune.pt
# [36/1000] train loss=0.229636, nmse(dB)=-0.9527 | val loss=0.174698, nmse(dB)=-1.7012 | 80.9s
#   ↳ saved best_finetune.pt
# [37/1000] train loss=0.225266, nmse(dB)=-1.0346 | val loss=0.171509, nmse(dB)=-1.7813 | 81.1s
#   ↳ saved best_finetune.pt
# [38/1000] train loss=0.221427, nmse(dB)=-1.1092 | val loss=0.168359, nmse(dB)=-1.8619 | 83.9s
#   ↳ saved best_finetune.pt
# [39/1000] train loss=0.218796, nmse(dB)=-1.1590 | val loss=0.165246, nmse(dB)=-1.9431 | 80.7s
#   ↳ saved best_finetune.pt
# [40/1000] train loss=0.213502, nmse(dB)=-1.2696 | val loss=0.162124, nmse(dB)=-2.0261 | 84.0s
#   ↳ saved best_finetune.pt
# [41/1000] train loss=0.211351, nmse(dB)=-1.3081 | val loss=0.158942, nmse(dB)=-2.1124 | 80.9s
#   ↳ saved best_finetune.pt
# [42/1000] train loss=0.208966, nmse(dB)=-1.3624 | val loss=0.155751, nmse(dB)=-2.2007 | 81.5s
#   ↳ saved best_finetune.pt
# [43/1000] train loss=0.204350, nmse(dB)=-1.4611 | val loss=0.152603, nmse(dB)=-2.2895 | 83.7s
#   ↳ saved best_finetune.pt
# [44/1000] train loss=0.200717, nmse(dB)=-1.5413 | val loss=0.149435, nmse(dB)=-2.3808 | 81.1s
#   ↳ saved best_finetune.pt
# [45/1000] train loss=0.196758, nmse(dB)=-1.6291 | val loss=0.146248, nmse(dB)=-2.4746 | 83.6s
#   ↳ saved best_finetune.pt
# [46/1000] train loss=0.193479, nmse(dB)=-1.7028 | val loss=0.143130, nmse(dB)=-2.5685 | 81.4s
#   ↳ saved best_finetune.pt
# [47/1000] train loss=0.189705, nmse(dB)=-1.7883 | val loss=0.140041, nmse(dB)=-2.6634 | 80.2s
#   ↳ saved best_finetune.pt
# [48/1000] train loss=0.188618, nmse(dB)=-1.8096 | val loss=0.136947, nmse(dB)=-2.7607 | 83.2s
#   ↳ saved best_finetune.pt
# [49/1000] train loss=0.182577, nmse(dB)=-1.9559 | val loss=0.133851, nmse(dB)=-2.8603 | 80.4s
#   ↳ saved best_finetune.pt
# [50/1000] train loss=0.181427, nmse(dB)=-1.9835 | val loss=0.130765, nmse(dB)=-2.9619 | 80.2s
#   ↳ saved best_finetune.pt
# [51/1000] train loss=0.177565, nmse(dB)=-2.0827 | val loss=0.127684, nmse(dB)=-3.0658 | 83.3s
#   ↳ saved best_finetune.pt
# [52/1000] train loss=0.173886, nmse(dB)=-2.1727 | val loss=0.124613, nmse(dB)=-3.1718 | 80.3s
#   ↳ saved best_finetune.pt
# [53/1000] train loss=0.170111, nmse(dB)=-2.2618 | val loss=0.121605, nmse(dB)=-3.2783 | 80.3s
#   ↳ saved best_finetune.pt
# [54/1000] train loss=0.167143, nmse(dB)=-2.3449 | val loss=0.118611, nmse(dB)=-3.3870 | 83.3s
#   ↳ saved best_finetune.pt
# [55/1000] train loss=0.163885, nmse(dB)=-2.4280 | val loss=0.115611, nmse(dB)=-3.4986 | 80.4s
#   ↳ saved best_finetune.pt
# [56/1000] train loss=0.160730, nmse(dB)=-2.5107 | val loss=0.112638, nmse(dB)=-3.6122 | 80.5s
#   ↳ saved best_finetune.pt
# [57/1000] train loss=0.158685, nmse(dB)=-2.5752 | val loss=0.109693, nmse(dB)=-3.7278 | 83.6s
#   ↳ saved best_finetune.pt
# [58/1000] train loss=0.154822, nmse(dB)=-2.6818 | val loss=0.106783, nmse(dB)=-3.8450 | 80.2s
#   ↳ saved best_finetune.pt
# [59/1000] train loss=0.150985, nmse(dB)=-2.7984 | val loss=0.103902, nmse(dB)=-3.9643 | 80.6s
#   ↳ saved best_finetune.pt
# [60/1000] train loss=0.147879, nmse(dB)=-2.8866 | val loss=0.101060, nmse(dB)=-4.0854 | 83.2s
#   ↳ saved best_finetune.pt
# [61/1000] train loss=0.145176, nmse(dB)=-2.9660 | val loss=0.098304, nmse(dB)=-4.2060 | 80.4s
#   ↳ saved best_finetune.pt
# [62/1000] train loss=0.141518, nmse(dB)=-3.0794 | val loss=0.095608, nmse(dB)=-4.3275 | 80.5s
#   ↳ saved best_finetune.pt
# [63/1000] train loss=0.139908, nmse(dB)=-3.1355 | val loss=0.092939, nmse(dB)=-4.4512 | 83.4s
#   ↳ saved best_finetune.pt
# [64/1000] train loss=0.136976, nmse(dB)=-3.2324 | val loss=0.090308, nmse(dB)=-4.5767 | 80.1s
#   ↳ saved best_finetune.pt
# [65/1000] train loss=0.133241, nmse(dB)=-3.3570 | val loss=0.087700, nmse(dB)=-4.7048 | 80.7s
#   ↳ saved best_finetune.pt
# [66/1000] train loss=0.131540, nmse(dB)=-3.4091 | val loss=0.085151, nmse(dB)=-4.8337 | 83.4s
#   ↳ saved best_finetune.pt
# [67/1000] train loss=0.128223, nmse(dB)=-3.5278 | val loss=0.082688, nmse(dB)=-4.9621 | 80.4s
#   ↳ saved best_finetune.pt
# [68/1000] train loss=0.125302, nmse(dB)=-3.6250 | val loss=0.080291, nmse(dB)=-5.0908 | 80.4s
#   ↳ saved best_finetune.pt
# [69/1000] train loss=0.123804, nmse(dB)=-3.6850 | val loss=0.077944, nmse(dB)=-5.2207 | 83.3s
#   ↳ saved best_finetune.pt
# [70/1000] train loss=0.120310, nmse(dB)=-3.8095 | val loss=0.075632, nmse(dB)=-5.3526 | 80.6s
#   ↳ saved best_finetune.pt
# [71/1000] train loss=0.117453, nmse(dB)=-3.9147 | val loss=0.073330, nmse(dB)=-5.4881 | 80.5s
#   ↳ saved best_finetune.pt
# [72/1000] train loss=0.115643, nmse(dB)=-3.9875 | val loss=0.071085, nmse(dB)=-5.6244 | 80.4s
#   ↳ saved best_finetune.pt
# [73/1000] train loss=0.112357, nmse(dB)=-4.1223 | val loss=0.068931, nmse(dB)=-5.7594 | 83.3s
#   ↳ saved best_finetune.pt
# [74/1000] train loss=0.112063, nmse(dB)=-4.1362 | val loss=0.066830, nmse(dB)=-5.8953 | 80.6s
#   ↳ saved best_finetune.pt
# [75/1000] train loss=0.108659, nmse(dB)=-4.2701 | val loss=0.064774, nmse(dB)=-6.0326 | 80.0s
#   ↳ saved best_finetune.pt
# [76/1000] train loss=0.106027, nmse(dB)=-4.3875 | val loss=0.062758, nmse(dB)=-6.1717 | 83.9s
#   ↳ saved best_finetune.pt
# [77/1000] train loss=0.103709, nmse(dB)=-4.4938 | val loss=0.060797, nmse(dB)=-6.3114 | 80.4s
#   ↳ saved best_finetune.pt
# [78/1000] train loss=0.101252, nmse(dB)=-4.5995 | val loss=0.058907, nmse(dB)=-6.4505 | 80.5s
#   ↳ saved best_finetune.pt
# [79/1000] train loss=0.100546, nmse(dB)=-4.6361 | val loss=0.057096, nmse(dB)=-6.5882 | 84.0s
#   ↳ saved best_finetune.pt
# [80/1000] train loss=0.097837, nmse(dB)=-4.7540 | val loss=0.055334, nmse(dB)=-6.7265 | 80.5s
#   ↳ saved best_finetune.pt
# [81/1000] train loss=0.096379, nmse(dB)=-4.8331 | val loss=0.053584, nmse(dB)=-6.8685 | 80.5s
#   ↳ saved best_finetune.pt
# [82/1000] train loss=0.093694, nmse(dB)=-4.9510 | val loss=0.051905, nmse(dB)=-7.0093 | 84.0s
#   ↳ saved best_finetune.pt
# [83/1000] train loss=0.093378, nmse(dB)=-4.9850 | val loss=0.050267, nmse(dB)=-7.1512 | 80.3s
#   ↳ saved best_finetune.pt
# [84/1000] train loss=0.091207, nmse(dB)=-5.0780 | val loss=0.048673, nmse(dB)=-7.2941 | 80.4s
#   ↳ saved best_finetune.pt
# [85/1000] train loss=0.089135, nmse(dB)=-5.1955 | val loss=0.047146, nmse(dB)=-7.4356 | 80.8s
#   ↳ saved best_finetune.pt
# [86/1000] train loss=0.087123, nmse(dB)=-5.3048 | val loss=0.045684, nmse(dB)=-7.5757 | 83.4s
#   ↳ saved best_finetune.pt
# [87/1000] train loss=0.085434, nmse(dB)=-5.3878 | val loss=0.044274, nmse(dB)=-7.7152 | 80.5s
#   ↳ saved best_finetune.pt
# [88/1000] train loss=0.084037, nmse(dB)=-5.4702 | val loss=0.042900, nmse(dB)=-7.8559 | 80.6s
#   ↳ saved best_finetune.pt
# [89/1000] train loss=0.082905, nmse(dB)=-5.5306 | val loss=0.041558, nmse(dB)=-7.9981 | 83.5s
#   ↳ saved best_finetune.pt
# [90/1000] train loss=0.081599, nmse(dB)=-5.6076 | val loss=0.040265, nmse(dB)=-8.1398 | 80.7s
#   ↳ saved best_finetune.pt
# [91/1000] train loss=0.080092, nmse(dB)=-5.7023 | val loss=0.039026, nmse(dB)=-8.2802 | 79.2s
#   ↳ saved best_finetune.pt
# [92/1000] train loss=0.078984, nmse(dB)=-5.7745 | val loss=0.037805, nmse(dB)=-8.4230 | 85.1s
#   ↳ saved best_finetune.pt
# [93/1000] train loss=0.077445, nmse(dB)=-5.8622 | val loss=0.036620, nmse(dB)=-8.5663 | 80.6s
#   ↳ saved best_finetune.pt
# [94/1000] train loss=0.076213, nmse(dB)=-5.9444 | val loss=0.035494, nmse(dB)=-8.7069 | 80.3s
#   ↳ saved best_finetune.pt
# [95/1000] train loss=0.074998, nmse(dB)=-6.0215 | val loss=0.034426, nmse(dB)=-8.8451 | 82.8s
#   ↳ saved best_finetune.pt
# [96/1000] train loss=0.073966, nmse(dB)=-6.0921 | val loss=0.033408, nmse(dB)=-8.9811 | 80.6s
#   ↳ saved best_finetune.pt
# [97/1000] train loss=0.072200, nmse(dB)=-6.1904 | val loss=0.032428, nmse(dB)=-9.1166 | 80.2s
#   ↳ saved best_finetune.pt
# [98/1000] train loss=0.071455, nmse(dB)=-6.2558 | val loss=0.031491, nmse(dB)=-9.2505 | 83.0s
#   ↳ saved best_finetune.pt
# [99/1000] train loss=0.070747, nmse(dB)=-6.3052 | val loss=0.030597, nmse(dB)=-9.3827 | 80.3s
#   ↳ saved best_finetune.pt
# [100/1000] train loss=0.069483, nmse(dB)=-6.3955 | val loss=0.029726, nmse(dB)=-9.5158 | 80.6s
#   ↳ saved best_finetune.pt
# [101/1000] train loss=0.068523, nmse(dB)=-6.4659 | val loss=0.028866, nmse(dB)=-9.6512 | 82.7s
#   ↳ saved best_finetune.pt
# [102/1000] train loss=0.068009, nmse(dB)=-6.4883 | val loss=0.028038, nmse(dB)=-9.7859 | 80.5s
#   ↳ saved best_finetune.pt
# [103/1000] train loss=0.066344, nmse(dB)=-6.6157 | val loss=0.027279, nmse(dB)=-9.9135 | 83.0s
#   ↳ saved best_finetune.pt
# [104/1000] train loss=0.065679, nmse(dB)=-6.6726 | val loss=0.026567, nmse(dB)=-10.0369 | 80.6s
#   ↳ saved best_finetune.pt
# [105/1000] train loss=0.065470, nmse(dB)=-6.6928 | val loss=0.025865, nmse(dB)=-10.1621 | 80.1s
#   ↳ saved best_finetune.pt
# [106/1000] train loss=0.064330, nmse(dB)=-6.7960 | val loss=0.025168, nmse(dB)=-10.2903 | 83.2s
#   ↳ saved best_finetune.pt
# [107/1000] train loss=0.063665, nmse(dB)=-6.8334 | val loss=0.024513, nmse(dB)=-10.4148 | 80.3s
#   ↳ saved best_finetune.pt
# [108/1000] train loss=0.062899, nmse(dB)=-6.8944 | val loss=0.023901, nmse(dB)=-10.5343 | 80.9s
#   ↳ saved best_finetune.pt
# [109/1000] train loss=0.061982, nmse(dB)=-6.9746 | val loss=0.023307, nmse(dB)=-10.6534 | 82.9s
#   ↳ saved best_finetune.pt
# [110/1000] train loss=0.061492, nmse(dB)=-7.0042 | val loss=0.022720, nmse(dB)=-10.7758 | 80.8s
#   ↳ saved best_finetune.pt
# [111/1000] train loss=0.060781, nmse(dB)=-7.0548 | val loss=0.022176, nmse(dB)=-10.8923 | 80.4s
#   ↳ saved best_finetune.pt
# [112/1000] train loss=0.059926, nmse(dB)=-7.1367 | val loss=0.021660, nmse(dB)=-11.0071 | 83.3s
#   ↳ saved best_finetune.pt
# [113/1000] train loss=0.059707, nmse(dB)=-7.1585 | val loss=0.021178, nmse(dB)=-11.1170 | 80.5s
#   ↳ saved best_finetune.pt
# [114/1000] train loss=0.059386, nmse(dB)=-7.1965 | val loss=0.020712, nmse(dB)=-11.2259 | 80.7s
#   ↳ saved best_finetune.pt
# [115/1000] train loss=0.058751, nmse(dB)=-7.2497 | val loss=0.020256, nmse(dB)=-11.3355 | 83.2s
#   ↳ saved best_finetune.pt
# [116/1000] train loss=0.057925, nmse(dB)=-7.3131 | val loss=0.019797, nmse(dB)=-11.4497 | 80.4s
#   ↳ saved best_finetune.pt
# [117/1000] train loss=0.057556, nmse(dB)=-7.3631 | val loss=0.019363, nmse(dB)=-11.5609 | 80.7s
#   ↳ saved best_finetune.pt
# [118/1000] train loss=0.057131, nmse(dB)=-7.3850 | val loss=0.018969, nmse(dB)=-11.6643 | 83.4s
#   ↳ saved best_finetune.pt
# [119/1000] train loss=0.056276, nmse(dB)=-7.4789 | val loss=0.018597, nmse(dB)=-11.7644 | 80.2s
#   ↳ saved best_finetune.pt
# [120/1000] train loss=0.056162, nmse(dB)=-7.4692 | val loss=0.018247, nmse(dB)=-11.8608 | 80.8s
#   ↳ saved best_finetune.pt
# [121/1000] train loss=0.055801, nmse(dB)=-7.5181 | val loss=0.017897, nmse(dB)=-11.9593 | 83.3s
#   ↳ saved best_finetune.pt
# [122/1000] train loss=0.055605, nmse(dB)=-7.5186 | val loss=0.017560, nmse(dB)=-12.0572 | 80.5s
#   ↳ saved best_finetune.pt
# [123/1000] train loss=0.055032, nmse(dB)=-7.6066 | val loss=0.017264, nmse(dB)=-12.1453 | 80.4s
#   ↳ saved best_finetune.pt
# [124/1000] train loss=0.054751, nmse(dB)=-7.6284 | val loss=0.016995, nmse(dB)=-12.2277 | 83.7s
#   ↳ saved best_finetune.pt
# [125/1000] train loss=0.054816, nmse(dB)=-7.6234 | val loss=0.016743, nmse(dB)=-12.3072 | 80.4s
#   ↳ saved best_finetune.pt
# [126/1000] train loss=0.054433, nmse(dB)=-7.6612 | val loss=0.016481, nmse(dB)=-12.3911 | 80.3s
#   ↳ saved best_finetune.pt
# [127/1000] train loss=0.053746, nmse(dB)=-7.7361 | val loss=0.016197, nmse(dB)=-12.4850 | 84.0s
#   ↳ saved best_finetune.pt
# [128/1000] train loss=0.053374, nmse(dB)=-7.7532 | val loss=0.015939, nmse(dB)=-12.5714 | 80.9s
#   ↳ saved best_finetune.pt
# [129/1000] train loss=0.052910, nmse(dB)=-7.8220 | val loss=0.015699, nmse(dB)=-12.6543 | 80.3s
#   ↳ saved best_finetune.pt
# [130/1000] train loss=0.052854, nmse(dB)=-7.8086 | val loss=0.015486, nmse(dB)=-12.7290 | 83.5s
#   ↳ saved best_finetune.pt
# [131/1000] train loss=0.052618, nmse(dB)=-7.8715 | val loss=0.015284, nmse(dB)=-12.8006 | 80.6s
#   ↳ saved best_finetune.pt
# [132/1000] train loss=0.052202, nmse(dB)=-7.8871 | val loss=0.015090, nmse(dB)=-12.8707 | 80.8s
#   ↳ saved best_finetune.pt
# [133/1000] train loss=0.052130, nmse(dB)=-7.8883 | val loss=0.014900, nmse(dB)=-12.9416 | 82.8s
#   ↳ saved best_finetune.pt
# [134/1000] train loss=0.051959, nmse(dB)=-7.9051 | val loss=0.014732, nmse(dB)=-13.0070 | 80.9s
#   ↳ saved best_finetune.pt
# [135/1000] train loss=0.051781, nmse(dB)=-7.9391 | val loss=0.014567, nmse(dB)=-13.0718 | 80.6s
#   ↳ saved best_finetune.pt
# [136/1000] train loss=0.051384, nmse(dB)=-7.9838 | val loss=0.014407, nmse(dB)=-13.1361 | 83.0s
#   ↳ saved best_finetune.pt
# [137/1000] train loss=0.051388, nmse(dB)=-7.9907 | val loss=0.014254, nmse(dB)=-13.1981 | 80.7s
#   ↳ saved best_finetune.pt
# [138/1000] train loss=0.050643, nmse(dB)=-8.0502 | val loss=0.014106, nmse(dB)=-13.2582 | 80.3s
#   ↳ saved best_finetune.pt
# [139/1000] train loss=0.050973, nmse(dB)=-8.0233 | val loss=0.013965, nmse(dB)=-13.3157 | 83.6s
#   ↳ saved best_finetune.pt
# [140/1000] train loss=0.050841, nmse(dB)=-8.0325 | val loss=0.013815, nmse(dB)=-13.3790 | 80.3s
#   ↳ saved best_finetune.pt
# [141/1000] train loss=0.050415, nmse(dB)=-8.0878 | val loss=0.013684, nmse(dB)=-13.4368 | 80.3s
#   ↳ saved best_finetune.pt
# [142/1000] train loss=0.049968, nmse(dB)=-8.1249 | val loss=0.013564, nmse(dB)=-13.4914 | 83.5s
#   ↳ saved best_finetune.pt
# [143/1000] train loss=0.050093, nmse(dB)=-8.1320 | val loss=0.013444, nmse(dB)=-13.5465 | 80.8s
#   ↳ saved best_finetune.pt
# [144/1000] train loss=0.049995, nmse(dB)=-8.1295 | val loss=0.013339, nmse(dB)=-13.5948 | 81.1s
#   ↳ saved best_finetune.pt
# [145/1000] train loss=0.049748, nmse(dB)=-8.1506 | val loss=0.013246, nmse(dB)=-13.6385 | 83.4s
#   ↳ saved best_finetune.pt
# [146/1000] train loss=0.049889, nmse(dB)=-8.1194 | val loss=0.013141, nmse(dB)=-13.6886 | 80.7s
#   ↳ saved best_finetune.pt
# [147/1000] train loss=0.049898, nmse(dB)=-8.1336 | val loss=0.013041, nmse(dB)=-13.7360 | 80.6s
#   ↳ saved best_finetune.pt
# [148/1000] train loss=0.049594, nmse(dB)=-8.1904 | val loss=0.012952, nmse(dB)=-13.7780 | 83.6s
#   ↳ saved best_finetune.pt
# [149/1000] train loss=0.049062, nmse(dB)=-8.2448 | val loss=0.012871, nmse(dB)=-13.8156 | 80.7s
#   ↳ saved best_finetune.pt
# [150/1000] train loss=0.048815, nmse(dB)=-8.2484 | val loss=0.012820, nmse(dB)=-13.8395 | 80.7s
#   ↳ saved best_finetune.pt
# [151/1000] train loss=0.049341, nmse(dB)=-8.1996 | val loss=0.012767, nmse(dB)=-13.8645 | 83.6s
#   ↳ saved best_finetune.pt
# [152/1000] train loss=0.048812, nmse(dB)=-8.2706 | val loss=0.012683, nmse(dB)=-13.9066 | 80.8s
#   ↳ saved best_finetune.pt
# [153/1000] train loss=0.048876, nmse(dB)=-8.2710 | val loss=0.012585, nmse(dB)=-13.9584 | 80.3s
#   ↳ saved best_finetune.pt
# [154/1000] train loss=0.048867, nmse(dB)=-8.2504 | val loss=0.012496, nmse(dB)=-14.0064 | 83.9s
#   ↳ saved best_finetune.pt
# [155/1000] train loss=0.048608, nmse(dB)=-8.2879 | val loss=0.012436, nmse(dB)=-14.0407 | 80.5s
#   ↳ saved best_finetune.pt
# [156/1000] train loss=0.048620, nmse(dB)=-8.2960 | val loss=0.012382, nmse(dB)=-14.0719 | 80.7s
#   ↳ saved best_finetune.pt
# [157/1000] train loss=0.048271, nmse(dB)=-8.3306 | val loss=0.012314, nmse(dB)=-14.1082 | 83.8s
#   ↳ saved best_finetune.pt
# [158/1000] train loss=0.048457, nmse(dB)=-8.3146 | val loss=0.012262, nmse(dB)=-14.1369 | 80.5s
#   ↳ saved best_finetune.pt
# [159/1000] train loss=0.048351, nmse(dB)=-8.3212 | val loss=0.012226, nmse(dB)=-14.1568 | 80.6s
#   ↳ saved best_finetune.pt
# [160/1000] train loss=0.048421, nmse(dB)=-8.3150 | val loss=0.012185, nmse(dB)=-14.1793 | 83.7s
#   ↳ saved best_finetune.pt
# [161/1000] train loss=0.048089, nmse(dB)=-8.3502 | val loss=0.012144, nmse(dB)=-14.2013 | 80.5s
#   ↳ saved best_finetune.pt
# [162/1000] train loss=0.048026, nmse(dB)=-8.3638 | val loss=0.012098, nmse(dB)=-14.2268 | 80.2s
#   ↳ saved best_finetune.pt
# [163/1000] train loss=0.048073, nmse(dB)=-8.3566 | val loss=0.012045, nmse(dB)=-14.2551 | 80.6s
#   ↳ saved best_finetune.pt
# [164/1000] train loss=0.048206, nmse(dB)=-8.3466 | val loss=0.011999, nmse(dB)=-14.2794 | 83.5s
#   ↳ saved best_finetune.pt
# [165/1000] train loss=0.047960, nmse(dB)=-8.3655 | val loss=0.011975, nmse(dB)=-14.2918 | 80.8s
#   ↳ saved best_finetune.pt
# [166/1000] train loss=0.047609, nmse(dB)=-8.4197 | val loss=0.011935, nmse(dB)=-14.3141 | 80.9s
#   ↳ saved best_finetune.pt
# [167/1000] train loss=0.047796, nmse(dB)=-8.4031 | val loss=0.011895, nmse(dB)=-14.3409 | 82.7s
#   ↳ saved best_finetune.pt
# [168/1000] train loss=0.047687, nmse(dB)=-8.4010 | val loss=0.011838, nmse(dB)=-14.3779 | 81.1s
#   ↳ saved best_finetune.pt
# [169/1000] train loss=0.047739, nmse(dB)=-8.4044 | val loss=0.011798, nmse(dB)=-14.4045 | 80.8s
#   ↳ saved best_finetune.pt
# [170/1000] train loss=0.047491, nmse(dB)=-8.4211 | val loss=0.011776, nmse(dB)=-14.4196 | 83.4s
#   ↳ saved best_finetune.pt
# [171/1000] train loss=0.047419, nmse(dB)=-8.4322 | val loss=0.011755, nmse(dB)=-14.4324 | 80.5s
#   ↳ saved best_finetune.pt
# [172/1000] train loss=0.047511, nmse(dB)=-8.4282 | val loss=0.011726, nmse(dB)=-14.4489 | 80.6s
#   ↳ saved best_finetune.pt
# [173/1000] train loss=0.047464, nmse(dB)=-8.4138 | val loss=0.011700, nmse(dB)=-14.4621 | 83.2s
#   ↳ saved best_finetune.pt
# [174/1000] train loss=0.047533, nmse(dB)=-8.4224 | val loss=0.011701, nmse(dB)=-14.4597 | 80.5s
# [175/1000] train loss=0.047513, nmse(dB)=-8.4420 | val loss=0.011720, nmse(dB)=-14.4452 | 80.3s
# [176/1000] train loss=0.047296, nmse(dB)=-8.4530 | val loss=0.011707, nmse(dB)=-14.4543 | 83.9s
# [177/1000] train loss=0.047082, nmse(dB)=-8.4760 | val loss=0.011665, nmse(dB)=-14.4825 | 80.5s
#   ↳ saved best_finetune.pt
# [178/1000] train loss=0.047280, nmse(dB)=-8.4484 | val loss=0.011623, nmse(dB)=-14.5092 | 80.5s
#   ↳ saved best_finetune.pt
# [179/1000] train loss=0.047093, nmse(dB)=-8.4582 | val loss=0.011586, nmse(dB)=-14.5331 | 83.7s
#   ↳ saved best_finetune.pt
# [180/1000] train loss=0.047144, nmse(dB)=-8.4636 | val loss=0.011568, nmse(dB)=-14.5440 | 80.4s
#   ↳ saved best_finetune.pt
# [181/1000] train loss=0.046781, nmse(dB)=-8.4978 | val loss=0.011547, nmse(dB)=-14.5562 | 80.4s
#   ↳ saved best_finetune.pt
# [182/1000] train loss=0.047085, nmse(dB)=-8.4635 | val loss=0.011516, nmse(dB)=-14.5774 | 84.6s
#   ↳ saved best_finetune.pt
# [183/1000] train loss=0.047285, nmse(dB)=-8.4624 | val loss=0.011487, nmse(dB)=-14.5988 | 80.6s
#   ↳ saved best_finetune.pt
# [184/1000] train loss=0.047115, nmse(dB)=-8.4782 | val loss=0.011483, nmse(dB)=-14.5998 | 80.5s
#   ↳ saved best_finetune.pt
# [185/1000] train loss=0.047031, nmse(dB)=-8.4908 | val loss=0.011481, nmse(dB)=-14.5988 | 83.4s
#   ↳ saved best_finetune.pt
# [186/1000] train loss=0.046981, nmse(dB)=-8.5113 | val loss=0.011471, nmse(dB)=-14.6039 | 80.7s
#   ↳ saved best_finetune.pt
# [187/1000] train loss=0.046852, nmse(dB)=-8.5171 | val loss=0.011459, nmse(dB)=-14.6108 | 80.3s
#   ↳ saved best_finetune.pt
# [188/1000] train loss=0.046810, nmse(dB)=-8.5198 | val loss=0.011440, nmse(dB)=-14.6229 | 80.4s
#   ↳ saved best_finetune.pt
# [189/1000] train loss=0.046617, nmse(dB)=-8.5307 | val loss=0.011415, nmse(dB)=-14.6415 | 83.6s
#   ↳ saved best_finetune.pt
# [190/1000] train loss=0.046509, nmse(dB)=-8.5504 | val loss=0.011400, nmse(dB)=-14.6530 | 80.5s
#   ↳ saved best_finetune.pt
# [191/1000] train loss=0.046774, nmse(dB)=-8.5202 | val loss=0.011389, nmse(dB)=-14.6595 | 80.5s
#   ↳ saved best_finetune.pt
# [192/1000] train loss=0.046604, nmse(dB)=-8.5192 | val loss=0.011392, nmse(dB)=-14.6557 | 84.1s
# [193/1000] train loss=0.046640, nmse(dB)=-8.5523 | val loss=0.011397, nmse(dB)=-14.6506 | 80.5s
# [194/1000] train loss=0.046414, nmse(dB)=-8.5606 | val loss=0.011387, nmse(dB)=-14.6587 | 80.6s
#   ↳ saved best_finetune.pt
# [195/1000] train loss=0.046538, nmse(dB)=-8.5567 | val loss=0.011370, nmse(dB)=-14.6715 | 83.9s
#   ↳ saved best_finetune.pt
# [196/1000] train loss=0.046726, nmse(dB)=-8.5100 | val loss=0.011368, nmse(dB)=-14.6732 | 80.8s
#   ↳ saved best_finetune.pt
# [197/1000] train loss=0.046591, nmse(dB)=-8.5506 | val loss=0.011364, nmse(dB)=-14.6764 | 80.4s
#   ↳ saved best_finetune.pt
# [198/1000] train loss=0.046362, nmse(dB)=-8.5693 | val loss=0.011347, nmse(dB)=-14.6871 | 83.3s
#   ↳ saved best_finetune.pt
# [199/1000] train loss=0.046322, nmse(dB)=-8.5584 | val loss=0.011334, nmse(dB)=-14.6973 | 80.7s
#   ↳ saved best_finetune.pt
# [200/1000] train loss=0.046488, nmse(dB)=-8.5571 | val loss=0.011327, nmse(dB)=-14.7035 | 80.5s
#   ↳ saved best_finetune.pt
# [201/1000] train loss=0.046893, nmse(dB)=-8.5264 | val loss=0.011320, nmse(dB)=-14.7113 | 83.6s
#   ↳ saved best_finetune.pt
# [202/1000] train loss=0.046237, nmse(dB)=-8.5861 | val loss=0.011322, nmse(dB)=-14.7101 | 80.8s
# [203/1000] train loss=0.046419, nmse(dB)=-8.5655 | val loss=0.011318, nmse(dB)=-14.7128 | 81.3s
#   ↳ saved best_finetune.pt
# [204/1000] train loss=0.046314, nmse(dB)=-8.5793 | val loss=0.011302, nmse(dB)=-14.7217 | 80.7s
#   ↳ saved best_finetune.pt
# [205/1000] train loss=0.046317, nmse(dB)=-8.5816 | val loss=0.011288, nmse(dB)=-14.7275 | 84.2s
#   ↳ saved best_finetune.pt
# [206/1000] train loss=0.045960, nmse(dB)=-8.5950 | val loss=0.011285, nmse(dB)=-14.7274 | 80.7s
#   ↳ saved best_finetune.pt
# [207/1000] train loss=0.046299, nmse(dB)=-8.5676 | val loss=0.011281, nmse(dB)=-14.7293 | 80.7s
#   ↳ saved best_finetune.pt
# [208/1000] train loss=0.046150, nmse(dB)=-8.5998 | val loss=0.011273, nmse(dB)=-14.7352 | 84.8s
#   ↳ saved best_finetune.pt
# [209/1000] train loss=0.046255, nmse(dB)=-8.5906 | val loss=0.011261, nmse(dB)=-14.7431 | 80.2s
#   ↳ saved best_finetune.pt
# [210/1000] train loss=0.046056, nmse(dB)=-8.6168 | val loss=0.011254, nmse(dB)=-14.7468 | 80.9s
#   ↳ saved best_finetune.pt
# [211/1000] train loss=0.046226, nmse(dB)=-8.5886 | val loss=0.011245, nmse(dB)=-14.7549 | 83.5s
#   ↳ saved best_finetune.pt
# [212/1000] train loss=0.046205, nmse(dB)=-8.5963 | val loss=0.011246, nmse(dB)=-14.7571 | 80.6s
# [213/1000] train loss=0.045975, nmse(dB)=-8.6157 | val loss=0.011243, nmse(dB)=-14.7603 | 80.7s
#   ↳ saved best_finetune.pt
# [214/1000] train loss=0.046127, nmse(dB)=-8.6165 | val loss=0.011246, nmse(dB)=-14.7583 | 83.8s
# [215/1000] train loss=0.046463, nmse(dB)=-8.5603 | val loss=0.011244, nmse(dB)=-14.7588 | 80.6s
# [216/1000] train loss=0.046095, nmse(dB)=-8.5948 | val loss=0.011252, nmse(dB)=-14.7503 | 80.7s
# [217/1000] train loss=0.046324, nmse(dB)=-8.5840 | val loss=0.011252, nmse(dB)=-14.7475 | 83.8s
# [218/1000] train loss=0.045951, nmse(dB)=-8.6347 | val loss=0.011244, nmse(dB)=-14.7523 | 80.8s
# [219/1000] train loss=0.045756, nmse(dB)=-8.6596 | val loss=0.011245, nmse(dB)=-14.7483 | 81.0s
# [220/1000] train loss=0.045822, nmse(dB)=-8.6337 | val loss=0.011240, nmse(dB)=-14.7504 | 80.9s
#   ↳ saved best_finetune.pt
# [221/1000] train loss=0.045700, nmse(dB)=-8.6561 | val loss=0.011226, nmse(dB)=-14.7622 | 83.7s
#   ↳ saved best_finetune.pt
# [222/1000] train loss=0.045868, nmse(dB)=-8.6351 | val loss=0.011221, nmse(dB)=-14.7683 | 80.3s
#   ↳ saved best_finetune.pt
# [223/1000] train loss=0.046076, nmse(dB)=-8.6094 | val loss=0.011234, nmse(dB)=-14.7627 | 80.5s
# [224/1000] train loss=0.046112, nmse(dB)=-8.6175 | val loss=0.011241, nmse(dB)=-14.7601 | 84.0s
# [225/1000] train loss=0.046137, nmse(dB)=-8.6150 | val loss=0.011235, nmse(dB)=-14.7651 | 80.7s
# [226/1000] train loss=0.045796, nmse(dB)=-8.6275 | val loss=0.011233, nmse(dB)=-14.7654 | 81.0s
# [227/1000] train loss=0.046052, nmse(dB)=-8.6187 | val loss=0.011236, nmse(dB)=-14.7594 | 84.3s
# [228/1000] train loss=0.045785, nmse(dB)=-8.6368 | val loss=0.011233, nmse(dB)=-14.7591 | 80.6s
# [229/1000] train loss=0.045732, nmse(dB)=-8.6664 | val loss=0.011227, nmse(dB)=-14.7627 | 80.6s
# [230/1000] train loss=0.045847, nmse(dB)=-8.6523 | val loss=0.011218, nmse(dB)=-14.7705 | 81.0s
#   ↳ saved best_finetune.pt
# [231/1000] train loss=0.045757, nmse(dB)=-8.6625 | val loss=0.011197, nmse(dB)=-14.7855 | 84.0s
#   ↳ saved best_finetune.pt
# [232/1000] train loss=0.045757, nmse(dB)=-8.6588 | val loss=0.011189, nmse(dB)=-14.7923 | 80.6s
#   ↳ saved best_finetune.pt
# [233/1000] train loss=0.045818, nmse(dB)=-8.6533 | val loss=0.011194, nmse(dB)=-14.7909 | 81.0s
# [234/1000] train loss=0.045708, nmse(dB)=-8.6519 | val loss=0.011212, nmse(dB)=-14.7809 | 84.2s
# [235/1000] train loss=0.045704, nmse(dB)=-8.6532 | val loss=0.011218, nmse(dB)=-14.7728 | 80.8s
# [236/1000] train loss=0.045859, nmse(dB)=-8.6435 | val loss=0.011219, nmse(dB)=-14.7711 | 80.8s
# [237/1000] train loss=0.045639, nmse(dB)=-8.6668 | val loss=0.011222, nmse(dB)=-14.7712 | 84.0s
# [238/1000] train loss=0.045564, nmse(dB)=-8.6789 | val loss=0.011216, nmse(dB)=-14.7752 | 81.4s
# [239/1000] train loss=0.045463, nmse(dB)=-8.6828 | val loss=0.011215, nmse(dB)=-14.7767 | 80.7s
# [240/1000] train loss=0.045707, nmse(dB)=-8.6611 | val loss=0.011197, nmse(dB)=-14.7888 | 81.1s
# [241/1000] train loss=0.045358, nmse(dB)=-8.6978 | val loss=0.011181, nmse(dB)=-14.7968 | 84.0s
#   ↳ saved best_finetune.pt
# [242/1000] train loss=0.045768, nmse(dB)=-8.6476 | val loss=0.011177, nmse(dB)=-14.7978 | 80.6s
#   ↳ saved best_finetune.pt
# [243/1000] train loss=0.045554, nmse(dB)=-8.6669 | val loss=0.011179, nmse(dB)=-14.7956 | 80.7s
# [244/1000] train loss=0.045687, nmse(dB)=-8.6427 | val loss=0.011176, nmse(dB)=-14.7999 | 84.2s
#   ↳ saved best_finetune.pt
# [245/1000] train loss=0.045401, nmse(dB)=-8.7057 | val loss=0.011167, nmse(dB)=-14.8075 | 80.6s
#   ↳ saved best_finetune.pt
# [246/1000] train loss=0.045480, nmse(dB)=-8.6881 | val loss=0.011175, nmse(dB)=-14.8016 | 80.7s
# [247/1000] train loss=0.045404, nmse(dB)=-8.7121 | val loss=0.011193, nmse(dB)=-14.7881 | 84.5s
# [248/1000] train loss=0.045447, nmse(dB)=-8.6847 | val loss=0.011206, nmse(dB)=-14.7796 | 81.2s
# [249/1000] train loss=0.045614, nmse(dB)=-8.6549 | val loss=0.011203, nmse(dB)=-14.7835 | 80.6s
# [250/1000] train loss=0.045551, nmse(dB)=-8.6624 | val loss=0.011192, nmse(dB)=-14.7904 | 80.6s
# [251/1000] train loss=0.045396, nmse(dB)=-8.6996 | val loss=0.011193, nmse(dB)=-14.7896 | 84.1s
# [252/1000] train loss=0.045280, nmse(dB)=-8.7224 | val loss=0.011187, nmse(dB)=-14.7941 | 80.4s
# [253/1000] train loss=0.045383, nmse(dB)=-8.6894 | val loss=0.011181, nmse(dB)=-14.7977 | 81.0s
# [254/1000] train loss=0.045535, nmse(dB)=-8.6938 | val loss=0.011166, nmse(dB)=-14.8074 | 84.7s
#   ↳ saved best_finetune.pt
# [255/1000] train loss=0.045447, nmse(dB)=-8.6867 | val loss=0.011175, nmse(dB)=-14.8003 | 80.9s
# [256/1000] train loss=0.045332, nmse(dB)=-8.7026 | val loss=0.011191, nmse(dB)=-14.7845 | 80.8s
# [257/1000] train loss=0.045432, nmse(dB)=-8.6967 | val loss=0.011188, nmse(dB)=-14.7853 | 84.4s
# [258/1000] train loss=0.045470, nmse(dB)=-8.6949 | val loss=0.011177, nmse(dB)=-14.7926 | 80.6s
# [259/1000] train loss=0.045468, nmse(dB)=-8.6931 | val loss=0.011162, nmse(dB)=-14.8057 | 81.1s
#   ↳ saved best_finetune.pt
# [260/1000] train loss=0.045577, nmse(dB)=-8.6749 | val loss=0.011164, nmse(dB)=-14.8071 | 80.3s
# [261/1000] train loss=0.045509, nmse(dB)=-8.7025 | val loss=0.011174, nmse(dB)=-14.8020 | 84.3s
# [262/1000] train loss=0.045242, nmse(dB)=-8.7306 | val loss=0.011175, nmse(dB)=-14.7997 | 80.9s
# [263/1000] train loss=0.045545, nmse(dB)=-8.6907 | val loss=0.011173, nmse(dB)=-14.7976 | 80.9s
# [264/1000] train loss=0.045141, nmse(dB)=-8.7429 | val loss=0.011177, nmse(dB)=-14.7916 | 84.6s
# [265/1000] train loss=0.045240, nmse(dB)=-8.7180 | val loss=0.011168, nmse(dB)=-14.7982 | 80.7s
# [266/1000] train loss=0.045370, nmse(dB)=-8.7174 | val loss=0.011157, nmse(dB)=-14.8092 | 81.1s
#   ↳ saved best_finetune.pt
# [267/1000] train loss=0.045017, nmse(dB)=-8.7468 | val loss=0.011154, nmse(dB)=-14.8145 | 80.9s
#   ↳ saved best_finetune.pt
# [268/1000] train loss=0.045035, nmse(dB)=-8.7362 | val loss=0.011157, nmse(dB)=-14.8170 | 84.2s
# [269/1000] train loss=0.045217, nmse(dB)=-8.7088 | val loss=0.011151, nmse(dB)=-14.8217 | 81.1s
#   ↳ saved best_finetune.pt
# [270/1000] train loss=0.045159, nmse(dB)=-8.7397 | val loss=0.011153, nmse(dB)=-14.8197 | 80.6s
# [271/1000] train loss=0.045216, nmse(dB)=-8.7144 | val loss=0.011160, nmse(dB)=-14.8119 | 83.9s
# [272/1000] train loss=0.045112, nmse(dB)=-8.7177 | val loss=0.011179, nmse(dB)=-14.7976 | 80.6s
# [273/1000] train loss=0.045192, nmse(dB)=-8.7158 | val loss=0.011196, nmse(dB)=-14.7842 | 80.9s
# [274/1000] train loss=0.045213, nmse(dB)=-8.7082 | val loss=0.011183, nmse(dB)=-14.7934 | 84.4s
# [275/1000] train loss=0.045312, nmse(dB)=-8.7199 | val loss=0.011155, nmse(dB)=-14.8145 | 81.3s
# [276/1000] train loss=0.045020, nmse(dB)=-8.7449 | val loss=0.011149, nmse(dB)=-14.8193 | 80.6s
#   ↳ saved best_finetune.pt
# [277/1000] train loss=0.045117, nmse(dB)=-8.7324 | val loss=0.011151, nmse(dB)=-14.8168 | 80.6s
# [278/1000] train loss=0.045190, nmse(dB)=-8.7233 | val loss=0.011154, nmse(dB)=-14.8129 | 84.2s
# [279/1000] train loss=0.045209, nmse(dB)=-8.7341 | val loss=0.011160, nmse(dB)=-14.8079 | 81.2s
# [280/1000] train loss=0.045079, nmse(dB)=-8.7343 | val loss=0.011158, nmse(dB)=-14.8093 | 80.9s
# [281/1000] train loss=0.045018, nmse(dB)=-8.7415 | val loss=0.011158, nmse(dB)=-14.8098 | 84.1s
# [282/1000] train loss=0.045267, nmse(dB)=-8.7054 | val loss=0.011168, nmse(dB)=-14.8043 | 81.3s
# [283/1000] train loss=0.045077, nmse(dB)=-8.7377 | val loss=0.011176, nmse(dB)=-14.8020 | 81.1s
# [284/1000] train loss=0.045223, nmse(dB)=-8.7132 | val loss=0.011167, nmse(dB)=-14.8076 | 81.2s
# [285/1000] train loss=0.044919, nmse(dB)=-8.7403 | val loss=0.011160, nmse(dB)=-14.8110 | 84.1s
# [286/1000] train loss=0.045298, nmse(dB)=-8.7163 | val loss=0.011154, nmse(dB)=-14.8144 | 80.9s
# [287/1000] train loss=0.045142, nmse(dB)=-8.7452 | val loss=0.011151, nmse(dB)=-14.8151 | 80.7s
# [288/1000] train loss=0.045033, nmse(dB)=-8.7613 | val loss=0.011153, nmse(dB)=-14.8130 | 84.5s
# [289/1000] train loss=0.045154, nmse(dB)=-8.7365 | val loss=0.011153, nmse(dB)=-14.8125 | 81.1s
# [290/1000] train loss=0.044983, nmse(dB)=-8.7536 | val loss=0.011156, nmse(dB)=-14.8110 | 81.2s
# [291/1000] train loss=0.044936, nmse(dB)=-8.7596 | val loss=0.011159, nmse(dB)=-14.8111 | 84.6s
# [292/1000] train loss=0.044858, nmse(dB)=-8.7900 | val loss=0.011163, nmse(dB)=-14.8100 | 81.5s
# [293/1000] train loss=0.044754, nmse(dB)=-8.7771 | val loss=0.011162, nmse(dB)=-14.8113 | 80.8s
# [294/1000] train loss=0.045300, nmse(dB)=-8.7112 | val loss=0.011160, nmse(dB)=-14.8121 | 81.0s
# [295/1000] train loss=0.044780, nmse(dB)=-8.7661 | val loss=0.011156, nmse(dB)=-14.8137 | 84.8s
# [296/1000] train loss=0.044961, nmse(dB)=-8.7535 | val loss=0.011154, nmse(dB)=-14.8148 | 81.4s
# [297/1000] train loss=0.045036, nmse(dB)=-8.7457 | val loss=0.011152, nmse(dB)=-14.8152 | 80.9s
# [298/1000] train loss=0.044846, nmse(dB)=-8.7551 | val loss=0.011146, nmse(dB)=-14.8209 | 84.5s
#   ↳ saved best_finetune.pt
# [299/1000] train loss=0.045006, nmse(dB)=-8.7514 | val loss=0.011142, nmse(dB)=-14.8244 | 81.0s
#   ↳ saved best_finetune.pt
# [300/1000] train loss=0.044767, nmse(dB)=-8.7737 | val loss=0.011148, nmse(dB)=-14.8208 | 80.9s
# [301/1000] train loss=0.044945, nmse(dB)=-8.7613 | val loss=0.011160, nmse(dB)=-14.8129 | 84.2s
# [302/1000] train loss=0.044838, nmse(dB)=-8.7740 | val loss=0.011171, nmse(dB)=-14.8045 | 81.1s
# [303/1000] train loss=0.044723, nmse(dB)=-8.7879 | val loss=0.011170, nmse(dB)=-14.8033 | 80.8s
# [304/1000] train loss=0.044803, nmse(dB)=-8.7674 | val loss=0.011161, nmse(dB)=-14.8089 | 80.6s
# [305/1000] train loss=0.044727, nmse(dB)=-8.7915 | val loss=0.011152, nmse(dB)=-14.8168 | 84.6s
# [306/1000] train loss=0.044638, nmse(dB)=-8.7850 | val loss=0.011146, nmse(dB)=-14.8220 | 80.9s
# [307/1000] train loss=0.045059, nmse(dB)=-8.7471 | val loss=0.011152, nmse(dB)=-14.8171 | 81.0s
# [308/1000] train loss=0.044882, nmse(dB)=-8.7708 | val loss=0.011158, nmse(dB)=-14.8103 | 84.5s
# [309/1000] train loss=0.044711, nmse(dB)=-8.7954 | val loss=0.011163, nmse(dB)=-14.8054 | 80.7s
# [310/1000] train loss=0.044870, nmse(dB)=-8.7742 | val loss=0.011167, nmse(dB)=-14.7996 | 81.1s
# [311/1000] train loss=0.044853, nmse(dB)=-8.7743 | val loss=0.011179, nmse(dB)=-14.7901 | 80.7s
# [312/1000] train loss=0.044845, nmse(dB)=-8.7735 | val loss=0.011177, nmse(dB)=-14.7936 | 84.7s
# [313/1000] train loss=0.044751, nmse(dB)=-8.7755 | val loss=0.011165, nmse(dB)=-14.8058 | 81.7s
# [314/1000] train loss=0.044788, nmse(dB)=-8.7877 | val loss=0.011166, nmse(dB)=-14.8059 | 80.9s
# [315/1000] train loss=0.044611, nmse(dB)=-8.8061 | val loss=0.011164, nmse(dB)=-14.8091 | 84.2s
# [316/1000] train loss=0.044716, nmse(dB)=-8.7766 | val loss=0.011164, nmse(dB)=-14.8073 | 81.2s
# [317/1000] train loss=0.044767, nmse(dB)=-8.7813 | val loss=0.011160, nmse(dB)=-14.8085 | 80.4s
# [318/1000] train loss=0.044638, nmse(dB)=-8.7968 | val loss=0.011153, nmse(dB)=-14.8115 | 80.7s
# [319/1000] train loss=0.044650, nmse(dB)=-8.7938 | val loss=0.011144, nmse(dB)=-14.8168 | 84.2s
# [320/1000] train loss=0.044358, nmse(dB)=-8.8165 | val loss=0.011144, nmse(dB)=-14.8169 | 81.0s
# [321/1000] train loss=0.045076, nmse(dB)=-8.7466 | val loss=0.011154, nmse(dB)=-14.8137 | 80.8s
# [322/1000] train loss=0.045026, nmse(dB)=-8.7487 | val loss=0.011165, nmse(dB)=-14.8105 | 84.5s
# [323/1000] train loss=0.044913, nmse(dB)=-8.7645 | val loss=0.011158, nmse(dB)=-14.8164 | 81.1s
# [324/1000] train loss=0.044679, nmse(dB)=-8.7963 | val loss=0.011149, nmse(dB)=-14.8229 | 80.6s
# [325/1000] train loss=0.044432, nmse(dB)=-8.8249 | val loss=0.011147, nmse(dB)=-14.8203 | 81.0s
# [326/1000] train loss=0.044620, nmse(dB)=-8.8081 | val loss=0.011143, nmse(dB)=-14.8210 | 84.6s
# [327/1000] train loss=0.044561, nmse(dB)=-8.8131 | val loss=0.011144, nmse(dB)=-14.8191 | 80.8s
# [328/1000] train loss=0.044646, nmse(dB)=-8.7864 | val loss=0.011142, nmse(dB)=-14.8200 | 80.9s
# [329/1000] train loss=0.044575, nmse(dB)=-8.8098 | val loss=0.011144, nmse(dB)=-14.8219 | 84.4s
# [330/1000] train loss=0.044585, nmse(dB)=-8.8148 | val loss=0.011139, nmse(dB)=-14.8266 | 81.0s
#   ↳ saved best_finetune.pt
# [331/1000] train loss=0.044458, nmse(dB)=-8.8278 | val loss=0.011146, nmse(dB)=-14.8214 | 81.3s
# [332/1000] train loss=0.044887, nmse(dB)=-8.7636 | val loss=0.011142, nmse(dB)=-14.8201 | 84.7s
# [333/1000] train loss=0.044415, nmse(dB)=-8.8188 | val loss=0.011138, nmse(dB)=-14.8235 | 81.2s
#   ↳ saved best_finetune.pt
# [334/1000] train loss=0.044743, nmse(dB)=-8.7953 | val loss=0.011137, nmse(dB)=-14.8237 | 80.7s
#   ↳ saved best_finetune.pt
# [335/1000] train loss=0.044614, nmse(dB)=-8.8136 | val loss=0.011146, nmse(dB)=-14.8184 | 80.8s
# [336/1000] train loss=0.044527, nmse(dB)=-8.8029 | val loss=0.011149, nmse(dB)=-14.8163 | 85.0s
# [337/1000] train loss=0.044577, nmse(dB)=-8.8101 | val loss=0.011150, nmse(dB)=-14.8164 | 81.2s
# [338/1000] train loss=0.044836, nmse(dB)=-8.7724 | val loss=0.011150, nmse(dB)=-14.8177 | 81.0s
# [339/1000] train loss=0.044575, nmse(dB)=-8.7998 | val loss=0.011158, nmse(dB)=-14.8133 | 84.6s
# [340/1000] train loss=0.044728, nmse(dB)=-8.7965 | val loss=0.011159, nmse(dB)=-14.8100 | 81.6s
# [341/1000] train loss=0.044450, nmse(dB)=-8.8252 | val loss=0.011161, nmse(dB)=-14.8076 | 81.4s
# [342/1000] train loss=0.044671, nmse(dB)=-8.7963 | val loss=0.011153, nmse(dB)=-14.8122 | 81.2s
# [343/1000] train loss=0.044563, nmse(dB)=-8.8166 | val loss=0.011149, nmse(dB)=-14.8139 | 84.7s
# [344/1000] train loss=0.044476, nmse(dB)=-8.8269 | val loss=0.011140, nmse(dB)=-14.8205 | 81.0s
# [345/1000] train loss=0.044464, nmse(dB)=-8.8206 | val loss=0.011134, nmse(dB)=-14.8244 | 80.8s
#   ↳ saved best_finetune.pt
# [346/1000] train loss=0.044579, nmse(dB)=-8.8161 | val loss=0.011131, nmse(dB)=-14.8273 | 84.3s
#   ↳ saved best_finetune.pt
# [347/1000] train loss=0.044660, nmse(dB)=-8.8103 | val loss=0.011135, nmse(dB)=-14.8267 | 80.6s
# [348/1000] train loss=0.044619, nmse(dB)=-8.8053 | val loss=0.011135, nmse(dB)=-14.8276 | 81.4s
# [349/1000] train loss=0.044402, nmse(dB)=-8.8307 | val loss=0.011144, nmse(dB)=-14.8208 | 84.6s
# [350/1000] train loss=0.044527, nmse(dB)=-8.8145 | val loss=0.011150, nmse(dB)=-14.8172 | 80.8s
# [351/1000] train loss=0.044643, nmse(dB)=-8.8044 | val loss=0.011153, nmse(dB)=-14.8166 | 81.0s
# [352/1000] train loss=0.044441, nmse(dB)=-8.8327 | val loss=0.011143, nmse(dB)=-14.8239 | 81.0s
# [353/1000] train loss=0.044356, nmse(dB)=-8.8225 | val loss=0.011141, nmse(dB)=-14.8245 | 84.4s
# [354/1000] train loss=0.044364, nmse(dB)=-8.8452 | val loss=0.011147, nmse(dB)=-14.8195 | 81.0s
# [355/1000] train loss=0.044359, nmse(dB)=-8.8386 | val loss=0.011155, nmse(dB)=-14.8114 | 81.2s
# [356/1000] train loss=0.044378, nmse(dB)=-8.8202 | val loss=0.011151, nmse(dB)=-14.8110 | 84.6s
# [357/1000] train loss=0.044398, nmse(dB)=-8.8305 | val loss=0.011146, nmse(dB)=-14.8131 | 80.8s
# [358/1000] train loss=0.044386, nmse(dB)=-8.8231 | val loss=0.011148, nmse(dB)=-14.8107 | 81.2s
# [359/1000] train loss=0.044354, nmse(dB)=-8.8484 | val loss=0.011150, nmse(dB)=-14.8121 | 80.9s
# [360/1000] train loss=0.044316, nmse(dB)=-8.8304 | val loss=0.011150, nmse(dB)=-14.8159 | 84.7s
# [361/1000] train loss=0.044448, nmse(dB)=-8.8237 | val loss=0.011140, nmse(dB)=-14.8237 | 81.4s
# [362/1000] train loss=0.044407, nmse(dB)=-8.8236 | val loss=0.011137, nmse(dB)=-14.8269 | 80.8s
# [363/1000] train loss=0.044452, nmse(dB)=-8.8270 | val loss=0.011145, nmse(dB)=-14.8220 | 84.7s
# [364/1000] train loss=0.044580, nmse(dB)=-8.8164 | val loss=0.011148, nmse(dB)=-14.8205 | 81.2s
# [365/1000] train loss=0.044520, nmse(dB)=-8.8229 | val loss=0.011146, nmse(dB)=-14.8237 | 81.6s
# [366/1000] train loss=0.044571, nmse(dB)=-8.8132 | val loss=0.011138, nmse(dB)=-14.8301 | 84.8s
# [367/1000] train loss=0.044378, nmse(dB)=-8.8410 | val loss=0.011142, nmse(dB)=-14.8252 | 81.2s
# [368/1000] train loss=0.044347, nmse(dB)=-8.8364 | val loss=0.011153, nmse(dB)=-14.8148 | 81.3s
# [369/1000] train loss=0.044326, nmse(dB)=-8.8368 | val loss=0.011149, nmse(dB)=-14.8150 | 81.1s
# [370/1000] train loss=0.044382, nmse(dB)=-8.8399 | val loss=0.011144, nmse(dB)=-14.8160 | 84.6s
# [371/1000] train loss=0.044460, nmse(dB)=-8.8436 | val loss=0.011145, nmse(dB)=-14.8137 | 81.3s
# [372/1000] train loss=0.044229, nmse(dB)=-8.8559 | val loss=0.011154, nmse(dB)=-14.8073 | 81.7s
# [373/1000] train loss=0.044482, nmse(dB)=-8.8249 | val loss=0.011154, nmse(dB)=-14.8087 | 84.7s
# [374/1000] train loss=0.044245, nmse(dB)=-8.8434 | val loss=0.011147, nmse(dB)=-14.8151 | 81.5s
# [375/1000] train loss=0.044294, nmse(dB)=-8.8457 | val loss=0.011141, nmse(dB)=-14.8216 | 81.4s
# [376/1000] train loss=0.044148, nmse(dB)=-8.8610 | val loss=0.011145, nmse(dB)=-14.8190 | 84.8s
# [377/1000] train loss=0.044471, nmse(dB)=-8.8348 | val loss=0.011158, nmse(dB)=-14.8090 | 80.8s
# [378/1000] train loss=0.044476, nmse(dB)=-8.8343 | val loss=0.011167, nmse(dB)=-14.8022 | 80.9s
# [379/1000] train loss=0.044513, nmse(dB)=-8.8403 | val loss=0.011165, nmse(dB)=-14.8033 | 80.8s
# [380/1000] train loss=0.044236, nmse(dB)=-8.8594 | val loss=0.011152, nmse(dB)=-14.8118 | 84.8s
# [381/1000] train loss=0.044237, nmse(dB)=-8.8558 | val loss=0.011139, nmse(dB)=-14.8233 | 80.8s
# [382/1000] train loss=0.044370, nmse(dB)=-8.8437 | val loss=0.011134, nmse(dB)=-14.8296 | 80.8s
# [383/1000] train loss=0.044440, nmse(dB)=-8.8214 | val loss=0.011137, nmse(dB)=-14.8293 | 84.4s
# [384/1000] train loss=0.044501, nmse(dB)=-8.8070 | val loss=0.011139, nmse(dB)=-14.8266 | 80.8s
# [385/1000] train loss=0.044200, nmse(dB)=-8.8671 | val loss=0.011142, nmse(dB)=-14.8229 | 81.1s
# [386/1000] train loss=0.044282, nmse(dB)=-8.8390 | val loss=0.011148, nmse(dB)=-14.8179 | 81.5s
# [387/1000] train loss=0.044440, nmse(dB)=-8.8390 | val loss=0.011147, nmse(dB)=-14.8171 | 84.5s
# [388/1000] train loss=0.044251, nmse(dB)=-8.8499 | val loss=0.011147, nmse(dB)=-14.8167 | 80.9s
# [389/1000] train loss=0.044333, nmse(dB)=-8.8466 | val loss=0.011147, nmse(dB)=-14.8129 | 80.9s
# [390/1000] train loss=0.044281, nmse(dB)=-8.8397 | val loss=0.011152, nmse(dB)=-14.8093 | 84.8s
# [391/1000] train loss=0.044253, nmse(dB)=-8.8480 | val loss=0.011149, nmse(dB)=-14.8142 | 81.2s
# [392/1000] train loss=0.044397, nmse(dB)=-8.8374 | val loss=0.011150, nmse(dB)=-14.8136 | 80.8s
# [393/1000] train loss=0.044338, nmse(dB)=-8.8543 | val loss=0.011144, nmse(dB)=-14.8197 | 81.5s
# [394/1000] train loss=0.044155, nmse(dB)=-8.8578 | val loss=0.011138, nmse(dB)=-14.8265 | 84.6s
# [395/1000] train loss=0.044194, nmse(dB)=-8.8636 | val loss=0.011136, nmse(dB)=-14.8297 | 81.5s
# [396/1000] train loss=0.044360, nmse(dB)=-8.8336 | val loss=0.011140, nmse(dB)=-14.8257 | 81.5s
# [397/1000] train loss=0.044322, nmse(dB)=-8.8529 | val loss=0.011147, nmse(dB)=-14.8182 | 84.7s
# [398/1000] train loss=0.044129, nmse(dB)=-8.8572 | val loss=0.011149, nmse(dB)=-14.8146 | 81.2s
# [399/1000] train loss=0.044315, nmse(dB)=-8.8404 | val loss=0.011140, nmse(dB)=-14.8197 | 81.3s
# [400/1000] train loss=0.044191, nmse(dB)=-8.8642 | val loss=0.011127, nmse(dB)=-14.8287 | 84.5s
#   ↳ saved best_finetune.pt
# [401/1000] train loss=0.044163, nmse(dB)=-8.8642 | val loss=0.011123, nmse(dB)=-14.8330 | 81.0s
#   ↳ saved best_finetune.pt
# [402/1000] train loss=0.044244, nmse(dB)=-8.8576 | val loss=0.011131, nmse(dB)=-14.8275 | 81.1s
# [403/1000] train loss=0.044112, nmse(dB)=-8.8733 | val loss=0.011137, nmse(dB)=-14.8225 | 81.0s
# [404/1000] train loss=0.044234, nmse(dB)=-8.8517 | val loss=0.011143, nmse(dB)=-14.8188 | 84.5s
# [405/1000] train loss=0.044178, nmse(dB)=-8.8723 | val loss=0.011145, nmse(dB)=-14.8184 | 81.4s
# [406/1000] train loss=0.044214, nmse(dB)=-8.8484 | val loss=0.011143, nmse(dB)=-14.8222 | 81.2s
# [407/1000] train loss=0.044120, nmse(dB)=-8.8793 | val loss=0.011141, nmse(dB)=-14.8261 | 84.5s
# [408/1000] train loss=0.044179, nmse(dB)=-8.8623 | val loss=0.011148, nmse(dB)=-14.8229 | 81.1s
# [409/1000] train loss=0.044377, nmse(dB)=-8.8507 | val loss=0.011153, nmse(dB)=-14.8185 | 80.8s
# [410/1000] train loss=0.044264, nmse(dB)=-8.8581 | val loss=0.011155, nmse(dB)=-14.8161 | 81.1s
# [411/1000] train loss=0.044200, nmse(dB)=-8.8582 | val loss=0.011146, nmse(dB)=-14.8171 | 85.1s
# [412/1000] train loss=0.044210, nmse(dB)=-8.8624 | val loss=0.011152, nmse(dB)=-14.8093 | 80.9s
# [413/1000] train loss=0.044250, nmse(dB)=-8.8671 | val loss=0.011152, nmse(dB)=-14.8088 | 81.0s
# [414/1000] train loss=0.044184, nmse(dB)=-8.8728 | val loss=0.011148, nmse(dB)=-14.8124 | 84.6s
# [415/1000] train loss=0.044070, nmse(dB)=-8.8812 | val loss=0.011140, nmse(dB)=-14.8214 | 81.0s
# [416/1000] train loss=0.044253, nmse(dB)=-8.8532 | val loss=0.011135, nmse(dB)=-14.8273 | 81.1s
# [417/1000] train loss=0.044154, nmse(dB)=-8.8683 | val loss=0.011140, nmse(dB)=-14.8260 | 84.4s
# [418/1000] train loss=0.044177, nmse(dB)=-8.8804 | val loss=0.011142, nmse(dB)=-14.8236 | 81.2s
# [419/1000] train loss=0.044085, nmse(dB)=-8.8745 | val loss=0.011142, nmse(dB)=-14.8230 | 81.1s
# [420/1000] train loss=0.044080, nmse(dB)=-8.8715 | val loss=0.011146, nmse(dB)=-14.8168 | 80.8s
# [421/1000] train loss=0.044151, nmse(dB)=-8.8705 | val loss=0.011153, nmse(dB)=-14.8102 | 83.8s
# [422/1000] train loss=0.044196, nmse(dB)=-8.8690 | val loss=0.011155, nmse(dB)=-14.8119 | 80.2s
# [423/1000] train loss=0.044007, nmse(dB)=-8.8934 | val loss=0.011164, nmse(dB)=-14.8089 | 80.2s
# [424/1000] train loss=0.044240, nmse(dB)=-8.8500 | val loss=0.011166, nmse(dB)=-14.8081 | 80.4s
# [425/1000] train loss=0.044262, nmse(dB)=-8.8647 | val loss=0.011156, nmse(dB)=-14.8178 | 83.9s
# [426/1000] train loss=0.044151, nmse(dB)=-8.8688 | val loss=0.011143, nmse(dB)=-14.8272 | 80.7s
# [427/1000] train loss=0.044037, nmse(dB)=-8.8855 | val loss=0.011138, nmse(dB)=-14.8282 | 80.4s
# [428/1000] train loss=0.044084, nmse(dB)=-8.8724 | val loss=0.011138, nmse(dB)=-14.8260 | 84.0s
# [429/1000] train loss=0.044063, nmse(dB)=-8.8823 | val loss=0.011143, nmse(dB)=-14.8197 | 80.5s
# [430/1000] train loss=0.044084, nmse(dB)=-8.8799 | val loss=0.011140, nmse(dB)=-14.8216 | 80.4s
# [431/1000] train loss=0.043958, nmse(dB)=-8.8969 | val loss=0.011146, nmse(dB)=-14.8173 | 80.4s
# [432/1000] train loss=0.043966, nmse(dB)=-8.8851 | val loss=0.011151, nmse(dB)=-14.8141 | 84.0s
# [433/1000] train loss=0.043930, nmse(dB)=-8.8972 | val loss=0.011144, nmse(dB)=-14.8217 | 80.6s
# ...
# [835/1000] train loss=0.043320, nmse(dB)=-8.9751 | val loss=0.011121, nmse(dB)=-14.8394 | 86.4s
# [836/1000] train loss=0.043276, nmse(dB)=-8.9910 | val loss=0.011121, nmse(dB)=-14.8391 | 83.1s
# [837/1000] train loss=0.043283, nmse(dB)=-8.9836 | val loss=0.011121, nmse(dB)=-14.8388 | 83.2s
# [838/1000] train loss=0.043342, nmse(dB)=-8.9830 | val loss=0.011121, nmse(dB)=-14.8383 | 86.6s
# [839/1000] train loss=0.043349, nmse(dB)=-8.9795 | val loss=0.011120, nmse(dB)=-14.8384 | 82.9s
# [840/1000] train loss=0.043234, nmse(dB)=-8.9833 | val loss=0.011120, nmse(dB)=-14.8384 | 83.0s
# [841/1000] train loss=0.043483, nmse(dB)=-8.9661 | val loss=0.011120, nmse(dB)=-14.8383 | 86.8s
# [842/1000] train loss=0.043409, nmse(dB)=-8.9692 | val loss=0.011120, nmse(dB)=-14.8379 | 82.9s
# [843/1000] train loss=0.043299, nmse(dB)=-8.9887 | val loss=0.011120, nmse(dB)=-14.8381 | 86.7s
# [844/1000] train loss=0.043370, nmse(dB)=-8.9874 | val loss=0.011120, nmse(dB)=-14.8380 | 83.3s
# [845/1000] train loss=0.043480, nmse(dB)=-8.9661 | val loss=0.011121, nmse(dB)=-14.8376 | 83.0s
# [846/1000] train loss=0.043364, nmse(dB)=-8.9728 | val loss=0.011121, nmse(dB)=-14.8376 | 86.7s
# [847/1000] train loss=0.043283, nmse(dB)=-8.9839 | val loss=0.011121, nmse(dB)=-14.8374 | 83.1s
# [848/1000] train loss=0.043276, nmse(dB)=-8.9828 | val loss=0.011121, nmse(dB)=-14.8370 | 83.3s
# [849/1000] train loss=0.043301, nmse(dB)=-8.9901 | val loss=0.011122, nmse(dB)=-14.8365 | 86.8s
# [850/1000] train loss=0.043419, nmse(dB)=-8.9746 | val loss=0.011121, nmse(dB)=-14.8367 | 83.2s
# [851/1000] train loss=0.043273, nmse(dB)=-8.9773 | val loss=0.011121, nmse(dB)=-14.8366 | 83.2s
# [852/1000] train loss=0.043328, nmse(dB)=-8.9883 | val loss=0.011121, nmse(dB)=-14.8371 | 86.6s
# [853/1000] train loss=0.043349, nmse(dB)=-8.9657 | val loss=0.011121, nmse(dB)=-14.8377 | 83.4s
# [854/1000] train loss=0.043423, nmse(dB)=-8.9713 | val loss=0.011120, nmse(dB)=-14.8379 | 83.2s
# [855/1000] train loss=0.043210, nmse(dB)=-8.9968 | val loss=0.011120, nmse(dB)=-14.8378 | 86.7s
# [856/1000] train loss=0.043263, nmse(dB)=-8.9774 | val loss=0.011120, nmse(dB)=-14.8379 | 83.1s
# [857/1000] train loss=0.043363, nmse(dB)=-8.9873 | val loss=0.011120, nmse(dB)=-14.8379 | 86.5s
# [858/1000] train loss=0.043335, nmse(dB)=-8.9776 | val loss=0.011120, nmse(dB)=-14.8378 | 83.0s
# [859/1000] train loss=0.043364, nmse(dB)=-8.9786 | val loss=0.011120, nmse(dB)=-14.8377 | 83.4s
# [860/1000] train loss=0.043208, nmse(dB)=-8.9928 | val loss=0.011120, nmse(dB)=-14.8377 | 86.4s
# [861/1000] train loss=0.043388, nmse(dB)=-8.9741 | val loss=0.011120, nmse(dB)=-14.8381 | 82.8s
# [862/1000] train loss=0.043387, nmse(dB)=-8.9745 | val loss=0.011119, nmse(dB)=-14.8383 | 83.0s
# [863/1000] train loss=0.043294, nmse(dB)=-8.9806 | val loss=0.011119, nmse(dB)=-14.8386 | 86.3s
# [864/1000] train loss=0.043311, nmse(dB)=-8.9720 | val loss=0.011119, nmse(dB)=-14.8384 | 83.3s
# [865/1000] train loss=0.043302, nmse(dB)=-8.9935 | val loss=0.011120, nmse(dB)=-14.8384 | 83.0s
# [866/1000] train loss=0.043312, nmse(dB)=-8.9845 | val loss=0.011120, nmse(dB)=-14.8387 | 86.7s
# [867/1000] train loss=0.043444, nmse(dB)=-8.9637 | val loss=0.011120, nmse(dB)=-14.8386 | 83.3s
# [868/1000] train loss=0.043363, nmse(dB)=-8.9764 | val loss=0.011120, nmse(dB)=-14.8387 | 82.9s
# [869/1000] train loss=0.043305, nmse(dB)=-8.9727 | val loss=0.011121, nmse(dB)=-14.8385 | 86.8s
# [870/1000] train loss=0.043294, nmse(dB)=-8.9866 | val loss=0.011121, nmse(dB)=-14.8387 | 83.2s
# [871/1000] train loss=0.043142, nmse(dB)=-8.9993 | val loss=0.011121, nmse(dB)=-14.8387 | 83.0s
# [872/1000] train loss=0.043305, nmse(dB)=-8.9848 | val loss=0.011121, nmse(dB)=-14.8387 | 86.4s
# [873/1000] train loss=0.043252, nmse(dB)=-8.9826 | val loss=0.011121, nmse(dB)=-14.8385 | 83.1s
# [874/1000] train loss=0.043415, nmse(dB)=-8.9723 | val loss=0.011122, nmse(dB)=-14.8382 | 86.5s
# [875/1000] train loss=0.043314, nmse(dB)=-8.9860 | val loss=0.011122, nmse(dB)=-14.8383 | 83.1s
# [876/1000] train loss=0.043294, nmse(dB)=-8.9896 | val loss=0.011122, nmse(dB)=-14.8380 | 82.8s
# [877/1000] train loss=0.043239, nmse(dB)=-8.9922 | val loss=0.011122, nmse(dB)=-14.8379 | 86.7s
# [878/1000] train loss=0.043224, nmse(dB)=-9.0028 | val loss=0.011122, nmse(dB)=-14.8379 | 83.1s
# [879/1000] train loss=0.043299, nmse(dB)=-8.9867 | val loss=0.011122, nmse(dB)=-14.8381 | 83.0s
# [880/1000] train loss=0.043283, nmse(dB)=-8.9873 | val loss=0.011122, nmse(dB)=-14.8383 | 86.7s
# [881/1000] train loss=0.043358, nmse(dB)=-8.9804 | val loss=0.011122, nmse(dB)=-14.8382 | 83.4s
# [882/1000] train loss=0.043383, nmse(dB)=-8.9752 | val loss=0.011123, nmse(dB)=-14.8381 | 82.8s
# [883/1000] train loss=0.043221, nmse(dB)=-9.0034 | val loss=0.011122, nmse(dB)=-14.8383 | 86.5s
# [884/1000] train loss=0.043324, nmse(dB)=-8.9829 | val loss=0.011122, nmse(dB)=-14.8384 | 83.4s
# [885/1000] train loss=0.043258, nmse(dB)=-9.0017 | val loss=0.011122, nmse(dB)=-14.8388 | 82.8s
# [886/1000] train loss=0.043421, nmse(dB)=-8.9687 | val loss=0.011121, nmse(dB)=-14.8390 | 86.7s
# [887/1000] train loss=0.043500, nmse(dB)=-8.9611 | val loss=0.011121, nmse(dB)=-14.8389 | 83.3s
# [888/1000] train loss=0.043257, nmse(dB)=-8.9919 | val loss=0.011121, nmse(dB)=-14.8390 | 83.0s
# [889/1000] train loss=0.043333, nmse(dB)=-8.9684 | val loss=0.011121, nmse(dB)=-14.8391 | 86.4s
# [890/1000] train loss=0.043350, nmse(dB)=-8.9797 | val loss=0.011121, nmse(dB)=-14.8394 | 83.0s
# [891/1000] train loss=0.043291, nmse(dB)=-8.9812 | val loss=0.011120, nmse(dB)=-14.8395 | 86.6s
# [892/1000] train loss=0.043336, nmse(dB)=-8.9760 | val loss=0.011120, nmse(dB)=-14.8398 | 82.9s
# [893/1000] train loss=0.043307, nmse(dB)=-8.9735 | val loss=0.011120, nmse(dB)=-14.8398 | 82.9s
# [894/1000] train loss=0.043378, nmse(dB)=-8.9759 | val loss=0.011119, nmse(dB)=-14.8400 | 86.8s
# [895/1000] train loss=0.043258, nmse(dB)=-8.9902 | val loss=0.011119, nmse(dB)=-14.8398 | 82.9s
# [896/1000] train loss=0.043188, nmse(dB)=-8.9882 | val loss=0.011119, nmse(dB)=-14.8397 | 82.6s
# [897/1000] train loss=0.043325, nmse(dB)=-8.9789 | val loss=0.011119, nmse(dB)=-14.8398 | 86.4s
# [898/1000] train loss=0.043252, nmse(dB)=-8.9804 | val loss=0.011120, nmse(dB)=-14.8396 | 83.0s
# [899/1000] train loss=0.043343, nmse(dB)=-8.9848 | val loss=0.011120, nmse(dB)=-14.8393 | 82.9s
# [900/1000] train loss=0.043320, nmse(dB)=-8.9819 | val loss=0.011120, nmse(dB)=-14.8393 | 86.5s
# [901/1000] train loss=0.043387, nmse(dB)=-8.9693 | val loss=0.011120, nmse(dB)=-14.8392 | 83.6s
# [902/1000] train loss=0.043324, nmse(dB)=-8.9770 | val loss=0.011120, nmse(dB)=-14.8391 | 83.1s
# [903/1000] train loss=0.043223, nmse(dB)=-8.9916 | val loss=0.011121, nmse(dB)=-14.8390 | 86.4s
# [904/1000] train loss=0.043355, nmse(dB)=-8.9723 | val loss=0.011121, nmse(dB)=-14.8390 | 83.5s
# [905/1000] train loss=0.043408, nmse(dB)=-8.9711 | val loss=0.011121, nmse(dB)=-14.8388 | 83.5s
# [906/1000] train loss=0.043279, nmse(dB)=-8.9870 | val loss=0.011120, nmse(dB)=-14.8388 | 86.4s
# [907/1000] train loss=0.043408, nmse(dB)=-8.9751 | val loss=0.011120, nmse(dB)=-14.8388 | 82.8s
# [908/1000] train loss=0.043346, nmse(dB)=-8.9748 | val loss=0.011120, nmse(dB)=-14.8388 | 83.2s
# [909/1000] train loss=0.043275, nmse(dB)=-8.9912 | val loss=0.011120, nmse(dB)=-14.8387 | 86.6s
# [910/1000] train loss=0.043265, nmse(dB)=-8.9850 | val loss=0.011120, nmse(dB)=-14.8388 | 82.9s
# [911/1000] train loss=0.043343, nmse(dB)=-8.9789 | val loss=0.011120, nmse(dB)=-14.8389 | 86.7s
# [912/1000] train loss=0.043212, nmse(dB)=-8.9904 | val loss=0.011120, nmse(dB)=-14.8388 | 83.2s
# [913/1000] train loss=0.043323, nmse(dB)=-8.9814 | val loss=0.011120, nmse(dB)=-14.8387 | 82.9s
# [914/1000] train loss=0.043366, nmse(dB)=-8.9680 | val loss=0.011120, nmse(dB)=-14.8385 | 86.4s
# [915/1000] train loss=0.043345, nmse(dB)=-8.9906 | val loss=0.011120, nmse(dB)=-14.8385 | 82.9s
# [916/1000] train loss=0.043356, nmse(dB)=-8.9767 | val loss=0.011121, nmse(dB)=-14.8385 | 83.1s
# [917/1000] train loss=0.043340, nmse(dB)=-8.9776 | val loss=0.011121, nmse(dB)=-14.8384 | 86.6s
# [918/1000] train loss=0.043394, nmse(dB)=-8.9731 | val loss=0.011121, nmse(dB)=-14.8384 | 83.5s
# [919/1000] train loss=0.043394, nmse(dB)=-8.9735 | val loss=0.011121, nmse(dB)=-14.8383 | 83.0s
# [920/1000] train loss=0.043243, nmse(dB)=-8.9916 | val loss=0.011121, nmse(dB)=-14.8383 | 86.6s
# [921/1000] train loss=0.043329, nmse(dB)=-8.9768 | val loss=0.011121, nmse(dB)=-14.8383 | 83.2s
# [922/1000] train loss=0.043229, nmse(dB)=-8.9925 | val loss=0.011121, nmse(dB)=-14.8382 | 83.4s
# [923/1000] train loss=0.043243, nmse(dB)=-8.9897 | val loss=0.011121, nmse(dB)=-14.8381 | 86.7s
# [924/1000] train loss=0.043288, nmse(dB)=-8.9801 | val loss=0.011121, nmse(dB)=-14.8381 | 83.2s
# [925/1000] train loss=0.043285, nmse(dB)=-8.9884 | val loss=0.011121, nmse(dB)=-14.8382 | 83.0s
# [926/1000] train loss=0.043474, nmse(dB)=-8.9764 | val loss=0.011121, nmse(dB)=-14.8382 | 86.5s
# [927/1000] train loss=0.043181, nmse(dB)=-9.0012 | val loss=0.011121, nmse(dB)=-14.8382 | 82.9s
# [928/1000] train loss=0.043250, nmse(dB)=-8.9869 | val loss=0.011121, nmse(dB)=-14.8383 | 86.8s
# [929/1000] train loss=0.043112, nmse(dB)=-9.0041 | val loss=0.011121, nmse(dB)=-14.8384 | 83.4s
# [930/1000] train loss=0.043274, nmse(dB)=-8.9942 | val loss=0.011121, nmse(dB)=-14.8384 | 82.9s
# [931/1000] train loss=0.043227, nmse(dB)=-8.9817 | val loss=0.011121, nmse(dB)=-14.8386 | 86.8s
# [932/1000] train loss=0.043351, nmse(dB)=-8.9783 | val loss=0.011121, nmse(dB)=-14.8388 | 82.7s
# [933/1000] train loss=0.043255, nmse(dB)=-8.9866 | val loss=0.011121, nmse(dB)=-14.8389 | 82.9s
# [934/1000] train loss=0.043272, nmse(dB)=-8.9871 | val loss=0.011121, nmse(dB)=-14.8389 | 86.5s
# [935/1000] train loss=0.043431, nmse(dB)=-8.9720 | val loss=0.011121, nmse(dB)=-14.8389 | 83.1s
# [936/1000] train loss=0.043211, nmse(dB)=-8.9963 | val loss=0.011121, nmse(dB)=-14.8388 | 83.1s
# [937/1000] train loss=0.043319, nmse(dB)=-8.9791 | val loss=0.011121, nmse(dB)=-14.8388 | 86.8s
# [938/1000] train loss=0.043208, nmse(dB)=-8.9901 | val loss=0.011121, nmse(dB)=-14.8387 | 82.9s
# [939/1000] train loss=0.043315, nmse(dB)=-8.9824 | val loss=0.011121, nmse(dB)=-14.8388 | 82.7s
# [940/1000] train loss=0.043455, nmse(dB)=-8.9683 | val loss=0.011121, nmse(dB)=-14.8388 | 86.6s
# [941/1000] train loss=0.043316, nmse(dB)=-8.9900 | val loss=0.011121, nmse(dB)=-14.8388 | 83.2s
# [942/1000] train loss=0.043402, nmse(dB)=-8.9645 | val loss=0.011121, nmse(dB)=-14.8389 | 82.9s
# [943/1000] train loss=0.043416, nmse(dB)=-8.9718 | val loss=0.011121, nmse(dB)=-14.8389 | 86.6s
# [944/1000] train loss=0.043306, nmse(dB)=-8.9807 | val loss=0.011121, nmse(dB)=-14.8389 | 83.1s
# [945/1000] train loss=0.043252, nmse(dB)=-8.9897 | val loss=0.011121, nmse(dB)=-14.8389 | 86.8s
# [946/1000] train loss=0.043378, nmse(dB)=-8.9795 | val loss=0.011121, nmse(dB)=-14.8388 | 83.2s
# [947/1000] train loss=0.043388, nmse(dB)=-8.9765 | val loss=0.011121, nmse(dB)=-14.8388 | 83.0s
# [948/1000] train loss=0.043276, nmse(dB)=-8.9738 | val loss=0.011121, nmse(dB)=-14.8388 | 86.5s
# [949/1000] train loss=0.043321, nmse(dB)=-8.9745 | val loss=0.011121, nmse(dB)=-14.8388 | 83.2s
# [950/1000] train loss=0.043336, nmse(dB)=-8.9726 | val loss=0.011121, nmse(dB)=-14.8388 | 83.0s
# [951/1000] train loss=0.043287, nmse(dB)=-8.9840 | val loss=0.011121, nmse(dB)=-14.8388 | 86.7s
# [952/1000] train loss=0.043345, nmse(dB)=-8.9716 | val loss=0.011121, nmse(dB)=-14.8388 | 83.1s
# [953/1000] train loss=0.043241, nmse(dB)=-8.9937 | val loss=0.011121, nmse(dB)=-14.8388 | 83.4s
# [954/1000] train loss=0.043363, nmse(dB)=-8.9859 | val loss=0.011121, nmse(dB)=-14.8388 | 86.5s
# [955/1000] train loss=0.043362, nmse(dB)=-8.9689 | val loss=0.011121, nmse(dB)=-14.8389 | 83.2s
# [956/1000] train loss=0.043195, nmse(dB)=-8.9899 | val loss=0.011121, nmse(dB)=-14.8389 | 83.0s
# [957/1000] train loss=0.043309, nmse(dB)=-8.9784 | val loss=0.011120, nmse(dB)=-14.8390 | 86.5s
# [958/1000] train loss=0.043456, nmse(dB)=-8.9632 | val loss=0.011120, nmse(dB)=-14.8390 | 83.2s
# [959/1000] train loss=0.043339, nmse(dB)=-8.9917 | val loss=0.011120, nmse(dB)=-14.8390 | 87.1s
# [960/1000] train loss=0.043228, nmse(dB)=-8.9885 | val loss=0.011120, nmse(dB)=-14.8390 | 83.2s
# [961/1000] train loss=0.043362, nmse(dB)=-8.9754 | val loss=0.011120, nmse(dB)=-14.8390 | 83.0s
# [962/1000] train loss=0.043190, nmse(dB)=-8.9869 | val loss=0.011120, nmse(dB)=-14.8390 | 86.9s
# [963/1000] train loss=0.043242, nmse(dB)=-8.9992 | val loss=0.011120, nmse(dB)=-14.8390 | 83.0s
# [964/1000] train loss=0.043395, nmse(dB)=-8.9758 | val loss=0.011120, nmse(dB)=-14.8390 | 82.9s
# [965/1000] train loss=0.043143, nmse(dB)=-9.0000 | val loss=0.011120, nmse(dB)=-14.8390 | 86.3s
# [966/1000] train loss=0.043407, nmse(dB)=-8.9727 | val loss=0.011120, nmse(dB)=-14.8390 | 82.9s
# [967/1000] train loss=0.043527, nmse(dB)=-8.9501 | val loss=0.011120, nmse(dB)=-14.8390 | 82.8s
# [968/1000] train loss=0.043176, nmse(dB)=-8.9910 | val loss=0.011120, nmse(dB)=-14.8390 | 86.5s
# [969/1000] train loss=0.043180, nmse(dB)=-8.9897 | val loss=0.011120, nmse(dB)=-14.8390 | 82.9s
# [970/1000] train loss=0.043236, nmse(dB)=-8.9917 | val loss=0.011120, nmse(dB)=-14.8390 | 83.1s
# [971/1000] train loss=0.043277, nmse(dB)=-8.9805 | val loss=0.011120, nmse(dB)=-14.8390 | 86.7s
# [972/1000] train loss=0.043237, nmse(dB)=-8.9835 | val loss=0.011120, nmse(dB)=-14.8390 | 83.0s
# [973/1000] train loss=0.043401, nmse(dB)=-8.9743 | val loss=0.011120, nmse(dB)=-14.8390 | 83.3s
# [974/1000] train loss=0.043386, nmse(dB)=-8.9675 | val loss=0.011120, nmse(dB)=-14.8390 | 86.6s
# [975/1000] train loss=0.043404, nmse(dB)=-8.9672 | val loss=0.011120, nmse(dB)=-14.8391 | 83.4s
# [976/1000] train loss=0.043267, nmse(dB)=-8.9863 | val loss=0.011120, nmse(dB)=-14.8390 | 86.7s
# [977/1000] train loss=0.043324, nmse(dB)=-8.9788 | val loss=0.011120, nmse(dB)=-14.8391 | 83.0s
# [978/1000] train loss=0.043365, nmse(dB)=-8.9756 | val loss=0.011120, nmse(dB)=-14.8391 | 82.8s
# [979/1000] train loss=0.043236, nmse(dB)=-8.9890 | val loss=0.011120, nmse(dB)=-14.8391 | 86.5s
# [980/1000] train loss=0.043538, nmse(dB)=-8.9548 | val loss=0.011120, nmse(dB)=-14.8391 | 82.9s
# [981/1000] train loss=0.043289, nmse(dB)=-9.0009 | val loss=0.011120, nmse(dB)=-14.8391 | 83.3s
# [982/1000] train loss=0.043274, nmse(dB)=-8.9783 | val loss=0.011120, nmse(dB)=-14.8391 | 87.0s
# [983/1000] train loss=0.043376, nmse(dB)=-8.9707 | val loss=0.011120, nmse(dB)=-14.8391 | 83.1s
# [984/1000] train loss=0.043311, nmse(dB)=-8.9860 | val loss=0.011120, nmse(dB)=-14.8391 | 83.1s
# [985/1000] train loss=0.043110, nmse(dB)=-9.0036 | val loss=0.011120, nmse(dB)=-14.8391 | 86.7s
# [986/1000] train loss=0.043319, nmse(dB)=-8.9855 | val loss=0.011120, nmse(dB)=-14.8391 | 82.7s
# [987/1000] train loss=0.043339, nmse(dB)=-8.9792 | val loss=0.011120, nmse(dB)=-14.8391 | 82.9s
# [988/1000] train loss=0.043430, nmse(dB)=-8.9734 | val loss=0.011120, nmse(dB)=-14.8391 | 86.7s
# [989/1000] train loss=0.043264, nmse(dB)=-8.9885 | val loss=0.011120, nmse(dB)=-14.8391 | 83.0s
# [990/1000] train loss=0.043313, nmse(dB)=-8.9789 | val loss=0.011120, nmse(dB)=-14.8391 | 82.9s
# [991/1000] train loss=0.043155, nmse(dB)=-9.0010 | val loss=0.011120, nmse(dB)=-14.8391 | 86.3s
# [992/1000] train loss=0.043291, nmse(dB)=-8.9811 | val loss=0.011120, nmse(dB)=-14.8391 | 82.7s
# [993/1000] train loss=0.043239, nmse(dB)=-8.9862 | val loss=0.011120, nmse(dB)=-14.8391 | 83.2s
# [994/1000] train loss=0.043244, nmse(dB)=-8.9926 | val loss=0.011120, nmse(dB)=-14.8391 | 86.8s
# [995/1000] train loss=0.043410, nmse(dB)=-8.9716 | val loss=0.011120, nmse(dB)=-14.8391 | 83.2s
# [996/1000] train loss=0.043314, nmse(dB)=-8.9896 | val loss=0.011120, nmse(dB)=-14.8391 | 86.5s
# [997/1000] train loss=0.043162, nmse(dB)=-9.0017 | val loss=0.011120, nmse(dB)=-14.8391 | 82.7s
# [998/1000] train loss=0.043274, nmse(dB)=-8.9806 | val loss=0.011120, nmse(dB)=-14.8391 | 83.3s
# [999/1000] train loss=0.043355, nmse(dB)=-8.9796 | val loss=0.011120, nmse(dB)=-14.8391 | 86.8s
# [1000/1000] train loss=0.043355, nmse(dB)=-8.9810 | val loss=0.011120, nmse(dB)=-14.8391 | 83.2s

# %%
ch, img, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# y abs mean: 0.49508270621299744
# y abs max : 1.0
# y power   : 0.2848026752471924
# yhat abs mean: 0.495068222284317
# yhat abs max : 0.5914323925971985
# yhat power   : 0.24561259150505066

# %% [markdown]
# # 데이터 입력 및 형태

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("N(cam_files)  :", len(cam_files))
print("N(min)        :", min(len(comm_frames), len(cam_files)))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

print("\n=== one batch shapes ===")
ch, img, y = next(iter(train_loader))
print("ch :", tuple(ch.shape), " -> (B,T,F_in)")
print("img:", tuple(img.shape), " -> (B,3,224,224)")
print("y  :", tuple(y.shape), " -> (B,F_out)")
with torch.no_grad():
    yhat = model(ch.to(device), img.to(device))
print("yhat:", tuple(yhat.shape), " -> (B,F_out)")
print("this forward predicted vectors:", yhat.shape[0], "(=B)")
print("each vector predicts elements:", yhat.shape[1], "(=F_out)")
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# N(cam_files)  : 7012
# N(min)        : 100
# past_len      : 16
# len(ds)       : 84
# len(train_ds) : 63
# len(val_ds)   : 21
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B,T,F_in)
# img: (32, 16, 3, 224, 224)  -> (B,3,224,224)
# y  : (32, 2048)  -> (B,F_out)
# yhat: (32, 2048)  -> (B,F_out)
# this forward predicted vectors: 32 (=B)
# each vector predicts elements: 2048 (=F_out)
