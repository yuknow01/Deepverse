# %% [markdown]
# # lwm2
# <br>모델 크기 차이에 따른 성능 차이 비교
# <br> element_length=16, d_model=64
# <br> in_proj: F_in(2048) → 512 → 128 → 16

# %% [markdown]
# # Import

# %%
import os
import sys

import numpy as  np
from lwm_model1 import lwm  # 클래스 import
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import torch.nn as nn   
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Setting
# ### CUDA 몇번 사용하는지 잘 확인하기

# %%
# Scenes 1000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(100))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"현재 사용 중인 장치: {device}")
# Out:
# 현재 사용 중인 장치: cuda:0

# %% [markdown]
# # Generate a dataset

# %%
# scenes / subcarriers는 그대로
param_manager.params["radar"]["enable"] = False

# lidar가 dict로 존재하면 disable
if isinstance(param_manager.params.get("lidar", None), dict):
    param_manager.params["lidar"]["enable"] = False

# position이 dict로 존재하면 disable
if isinstance(param_manager.params.get("position", None), dict):
    param_manager.params["position"]["enable"] = False

# Radar, LiDAR, Position 사용하지 않으므로 False 
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (0.85s)

# %% [markdown]
# # Prerocessing

# %% [markdown]
# #### Channel

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device=device, eps=1e-16):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex64)
    
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(device, dtype=torch.float32)
    return H

# %% [markdown]
# #### image

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class ChannelNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, ue_idx=0, past_len=16, device=device,
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        self.comm_frames = comm_frames
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device

        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = len(self.comm_frames)
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1) Channel Past
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            h = preprocess_channel_coeffs_minmax(
                coeffs_np,
                self.r_min, self.r_max, self.i_min, self.i_max,
                device=self.device
            ).reshape(-1)  # (2048,)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)  # (T, 2048)

        # 2) Target Next
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_minmax(
            coeffs_np_next,
            self.r_min, self.r_max, self.i_min, self.i_max,
            device=self.device
        ).reshape(-1)  # (2048,)

        return channel_past, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)

ds = ChannelNextStepDatasetGPU(
    comm_frames=comm_frames,
    ue_idx=0,
    past_len=16,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   
)
ch, y = next(iter(loader))
print(ch.shape, y.shape)
print(ch.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 2048])
# cuda:0 cuda:0

# %% [markdown]
# # Fine-tuning

# %%
class LWMForecasterNoEdit(nn.Module):
    """
    lwm 코드는 수정하지 않고, encoder(embedding+layers)만 직접 호출해서 forecasting
    Input : ch  (B,T,F_in)
    Output: yhat(B,F_out)
    """
    def __init__(
        self,
        base_lwm: nn.Module,
        F_in: int,
        F_out: int,
        pool: str = "last",
        freeze_backbone: bool = False,
    ):
        super().__init__()
        self.base = base_lwm
        self.pool = pool

        n_dim   = self.base.embedding.element_length  # 16
        d_model = self.base.embedding.d_model         # 64

        self.in_proj = nn.Sequential(
            nn.Linear(F_in, 512),
            nn.GELU(),
            nn.Linear(512, 128),
            nn.GELU(),
            nn.Linear(128, n_dim),
        )

        self.head = nn.Linear(d_model, F_out)

        if freeze_backbone:
            for p in self.base.parameters():
                p.requires_grad = False
            for p in self.in_proj.parameters():
                p.requires_grad = True
            for p in self.head.parameters():
                p.requires_grad = True

    def forward(self, ch):
        x = self.in_proj(ch)          # (B,T,F_in) -> (B,T,16)

        out = self.base.embedding(x)  # (B,T,64)
        for layer in self.base.layers:
            out, _ = layer(out)       # (B,T,64)

        if self.pool == "last":
            z = out[:, -1, :]
        elif self.pool == "mean":
            z = out.mean(dim=1)
        else:
            raise ValueError(f"Unknown pool={self.pool}")

        return self.head(z)           # (B,F_out)

# %% [markdown]
# # NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# %% [markdown]
# # Train/val Split

# %%
# 겹치는 부분이 있는지 확인하는 함수
def used_frames_for_ds_indices(ds, ds_indices):
    used = set()
    for i in ds_indices:
        t = ds.valid_start + i
        # inputs use [t-T+1 .. t], target uses (t+1)
        used.update(range(t - T + 1, t + 2))
    return used

# %%
n_total = len(ds)
T = ds.past_len  # = past_len

# ---- choose k so that train=3k, val=k and NO frame-overlap is possible ----
k_max = (n_total - T) // 4
if k_max <= 0:
    raise ValueError(
        f"Not enough data for strict non-overlap 3:1. "
        f"n_total={n_total}, past_len(T)={T}. "
        f"Try increasing scenes or decreasing past_len."
    )

k = k_max               # use as much data as possible under constraints
n_val = k
n_train = 3 * k

train_idx = list(range(0, n_train))
val_idx   = list(range(n_total - n_val, n_total))

print("n_total:", n_total, "T:", T)
print("train samples:", len(train_idx), "val samples:", len(val_idx), "ratio:", len(train_idx)/len(val_idx))

# ---- min/max ONLY from train (same as your original policy) ----
train_ts = [ds.valid_start + i for i in train_idx]

(real_min, real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_ts, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)

F_in = 2048


overlap = used_frames_for_ds_indices(ds, train_idx).intersection(
          used_frames_for_ds_indices(ds, val_idx))
print("frame-overlap count:", len(overlap))
assert len(overlap) == 0, "Leakage detected: train/val share frames!"

# Verify (channel-only)
ch, y = next(iter(train_loader))   # ✅ img 제거
F_out = y.shape[-1]

print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")

# (선택) ch도 같이 범위 확인하고 싶으면
print(f"ch stats | min: {ch.min().item():.4f}, max: {ch.max().item():.4f}")
# Out:
# n_total: 84 T: 16
# train samples: 51 val samples: 17 ratio: 3.0
# Calculating min/max over training set...
# Done. rmin=-1.0646139639174899e-06, rmax=1.0917989155343993e-06, imin=-1.0719516685941772e-06, imax=1.0643868111374237e-06
# Dataset statistical values set in the dataset.
# frame-overlap count: 0
#
# === Data Check ===
# y stats | min: 0.0005, max: 1.0000
# If scaling worked correctly, values should be within [0, 1].
# ch stats | min: -0.2541, max: 1.2434

# %% [markdown]
# # Train/Eval 함수

# %%
# batch check
ch, y = next(iter(train_loader))
print(ch.shape, y.shape)

def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()
    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, y in loader:
        ch = ch.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        yhat = model(ch)                
        loss = F.mse_loss(yhat, y)
        loss.backward()

        if grad_clip and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        optimizer.step()

        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, y in loader:
        ch = ch.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        yhat = model(ch)                 
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)
# Out:
# torch.Size([32, 16, 2048]) torch.Size([32, 2048])

# %% [markdown]
# # 모델 생성 및 확인

# %%
# 배치 하나로 F_in/F_out 자동 확정
ch, y = next(iter(train_loader))
F_in  = ch.shape[-1]
F_out = y.shape[-1]
print("Detected:", "F_in=", F_in, "F_out=", F_out)
print("Batch devices:", ch.device, y.device)

backbone = lwm().to(device)  
model = LWMForecasterNoEdit(
    base_lwm=backbone,
    F_in=F_in,
    F_out=F_out,
    pool="last",
    freeze_backbone=False,
).to(device)

# sanity forward
model.eval()
with torch.no_grad():
    # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
    yhat = model(ch.to(device))
print("yhat:", yhat.shape, "y:", y.shape)
# Out:
# Detected: F_in= 2048 F_out= 2048
# Batch devices: cuda:0 cuda:0
# yhat: torch.Size([32, 2048]) y: torch.Size([32, 2048])

# %% [markdown]
# # Optimizer/Scheduler 설정

# %%
# requires_grad=True인 파라미터만 학습
trainable_params = [p for p in model.parameters() if p.requires_grad]
print("trainable params:", sum(p.numel() for p in trainable_params))

optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# (선택) cosine scheduler
epochs = 500
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
# Out:
# trainable params: 1853648

# %% [markdown]
# # 학습 루프 및 checkpoint 저장

# %%
import time
import os
import torch

best_val = float("inf")
best_val_nmse = None
best_epoch = None

t_train0 = time.time()  # ✅ 전체 학습 시작 시간

# 어떤 모델을 몇개의 scene으로 학습을 했는지 기록
log_path = "lwm_model2_scene100.txt"

with open(log_path, "w", encoding="utf-8") as f:
    for epoch in range(1, epochs + 1):
        t0 = time.time()

        tr_loss, tr_nmse = train_one_epoch(
            model, train_loader, optimizer, device=device, grad_clip=1.0
        )
        va_loss, va_nmse = evaluate(model, val_loader, device=device)

        scheduler.step()

        dt = time.time() - t0

        # ✅ 1) print에 쓰는 문자열을 변수로 만들기
        line = (
            f"[{epoch:02d}/{epochs}] "
            f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
            f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
            f"{dt:.1f}s"
        )

        # ✅ 2) 콘솔 + 파일에 동시에 기록
        print(line)
        f.write(line + "\n")
        f.flush()

        if va_loss < best_val:
            best_val = va_loss
            best_val_nmse = va_nmse
            best_epoch = epoch

            ckpt_path = "bestc_channel_only_finetune.pt"
            torch.save(
                {
                    "epoch": epoch,
                    "model_state": model.state_dict(),
                    "optimizer_state": optimizer.state_dict(),
                    "F_in": F_in,
                    "F_out": F_out,
                    "best_val_loss": best_val,
                    "best_val_nmse_db": best_val_nmse,
                },
                ckpt_path,
            )

            save_line = (
                f"  ↳ saved {ckpt_path} | best@{best_epoch}: "
                f"val loss={best_val:.6f}, val nmse(dB)={best_val_nmse:.4f}"
            )
            print(save_line)
            f.write(save_line + "\n")
            f.flush()

# ✅ 전체 학습 종료 후 총 시간 출력 + 파일 append
total_sec = time.time() - t_train0
h = int(total_sec // 3600)
m = int((total_sec % 3600) // 60)
s = total_sec % 60

summary1 = "\n=== Training Summary ==="
summary2 = f"Total time: {total_sec:.1f}s ({h}h {m}m {s:.1f}s)"
summary3 = (
    f"Best epoch: {best_epoch} | best val loss={best_val:.6f}, "
    f"best val nmse(dB)={best_val_nmse:.4f}"
)

print(summary1)
print(summary2)
print(summary3)

with open(log_path, "a", encoding="utf-8") as f:
    f.write(summary1 + "\n")
    f.write(summary2 + "\n")
    f.write(summary3 + "\n")

print("Log saved to:", os.path.abspath(log_path))
# Out:
# [01/500] train loss=0.592632, nmse(dB)=3.1709 | val loss=0.519588, nmse(dB)=3.0428 | 0.3s
#   ↳ saved best_finetune.pt | best@1: val loss=0.519588, val nmse(dB)=3.0428
# [02/500] train loss=0.550500, nmse(dB)=2.8583 | val loss=0.486600, nmse(dB)=2.7579 | 0.1s
#   ↳ saved best_finetune.pt | best@2: val loss=0.486600, val nmse(dB)=2.7579
# [03/500] train loss=0.528928, nmse(dB)=2.5912 | val loss=0.467641, nmse(dB)=2.5852 | 0.1s
#   ↳ saved best_finetune.pt | best@3: val loss=0.467641, val nmse(dB)=2.5852
# [04/500] train loss=0.506264, nmse(dB)=2.4955 | val loss=0.452706, nmse(dB)=2.4442 | 0.1s
#   ↳ saved best_finetune.pt | best@4: val loss=0.452706, val nmse(dB)=2.4442
# [05/500] train loss=0.494836, nmse(dB)=2.3622 | val loss=0.438826, nmse(dB)=2.3089 | 0.1s
#   ↳ saved best_finetune.pt | best@5: val loss=0.438826, val nmse(dB)=2.3089
# [06/500] train loss=0.481700, nmse(dB)=2.2375 | val loss=0.426249, nmse(dB)=2.1826 | 0.1s
#   ↳ saved best_finetune.pt | best@6: val loss=0.426249, val nmse(dB)=2.1826
# [07/500] train loss=0.468561, nmse(dB)=2.1170 | val loss=0.415018, nmse(dB)=2.0666 | 0.1s
#   ↳ saved best_finetune.pt | best@7: val loss=0.415018, val nmse(dB)=2.0666
# [08/500] train loss=0.455528, nmse(dB)=2.0270 | val loss=0.404237, nmse(dB)=1.9522 | 0.1s
#   ↳ saved best_finetune.pt | best@8: val loss=0.404237, val nmse(dB)=1.9522
# [09/500] train loss=0.444035, nmse(dB)=1.9280 | val loss=0.393560, nmse(dB)=1.8359 | 0.1s
#   ↳ saved best_finetune.pt | best@9: val loss=0.393560, val nmse(dB)=1.8359
# [10/500] train loss=0.436238, nmse(dB)=1.7745 | val loss=0.382936, nmse(dB)=1.7170 | 0.1s
#   ↳ saved best_finetune.pt | best@10: val loss=0.382936, val nmse(dB)=1.7170
# [11/500] train loss=0.423236, nmse(dB)=1.7081 | val loss=0.372747, nmse(dB)=1.5998 | 0.1s
#   ↳ saved best_finetune.pt | best@11: val loss=0.372747, val nmse(dB)=1.5998
# [12/500] train loss=0.414887, nmse(dB)=1.5672 | val loss=0.362853, nmse(dB)=1.4829 | 0.1s
#   ↳ saved best_finetune.pt | best@12: val loss=0.362853, val nmse(dB)=1.4829
# [13/500] train loss=0.402145, nmse(dB)=1.4922 | val loss=0.352811, nmse(dB)=1.3610 | 0.1s
#   ↳ saved best_finetune.pt | best@13: val loss=0.352811, val nmse(dB)=1.3610
# [14/500] train loss=0.392304, nmse(dB)=1.3774 | val loss=0.342906, nmse(dB)=1.2372 | 0.1s
#   ↳ saved best_finetune.pt | best@14: val loss=0.342906, val nmse(dB)=1.2372
# [15/500] train loss=0.382772, nmse(dB)=1.2612 | val loss=0.333203, nmse(dB)=1.1125 | 0.1s
#   ↳ saved best_finetune.pt | best@15: val loss=0.333203, val nmse(dB)=1.1125
# [16/500] train loss=0.376573, nmse(dB)=1.1294 | val loss=0.323616, nmse(dB)=0.9856 | 0.1s
#   ↳ saved best_finetune.pt | best@16: val loss=0.323616, val nmse(dB)=0.9856
# [17/500] train loss=0.361893, nmse(dB)=1.0587 | val loss=0.314226, nmse(dB)=0.8576 | 0.1s
#   ↳ saved best_finetune.pt | best@17: val loss=0.314226, val nmse(dB)=0.8576
# [18/500] train loss=0.355974, nmse(dB)=0.9283 | val loss=0.305051, nmse(dB)=0.7288 | 0.1s
#   ↳ saved best_finetune.pt | best@18: val loss=0.305051, val nmse(dB)=0.7288
# [19/500] train loss=0.347968, nmse(dB)=0.7982 | val loss=0.296140, nmse(dB)=0.6000 | 0.1s
#   ↳ saved best_finetune.pt | best@19: val loss=0.296140, val nmse(dB)=0.6000
# [20/500] train loss=0.340573, nmse(dB)=0.6682 | val loss=0.287520, nmse(dB)=0.4715 | 0.1s
#   ↳ saved best_finetune.pt | best@20: val loss=0.287520, val nmse(dB)=0.4715
# [21/500] train loss=0.331498, nmse(dB)=0.5962 | val loss=0.279056, nmse(dB)=0.3416 | 0.1s
#   ↳ saved best_finetune.pt | best@21: val loss=0.279056, val nmse(dB)=0.3416
# [22/500] train loss=0.322524, nmse(dB)=0.4818 | val loss=0.270721, nmse(dB)=0.2098 | 0.1s
#   ↳ saved best_finetune.pt | best@22: val loss=0.270721, val nmse(dB)=0.2098
# [23/500] train loss=0.312091, nmse(dB)=0.3334 | val loss=0.262559, nmse(dB)=0.0767 | 0.1s
#   ↳ saved best_finetune.pt | best@23: val loss=0.262559, val nmse(dB)=0.0767
# [24/500] train loss=0.306130, nmse(dB)=0.2491 | val loss=0.254571, nmse(dB)=-0.0576 | 0.1s
#   ↳ saved best_finetune.pt | best@24: val loss=0.254571, val nmse(dB)=-0.0576
# [25/500] train loss=0.297456, nmse(dB)=0.1108 | val loss=0.246787, nmse(dB)=-0.1926 | 0.1s
#   ↳ saved best_finetune.pt | best@25: val loss=0.246787, val nmse(dB)=-0.1926
# [26/500] train loss=0.286476, nmse(dB)=0.0197 | val loss=0.239223, nmse(dB)=-0.3280 | 0.1s
#   ↳ saved best_finetune.pt | best@26: val loss=0.239223, val nmse(dB)=-0.3280
# [27/500] train loss=0.282581, nmse(dB)=-0.1245 | val loss=0.231891, nmse(dB)=-0.4633 | 0.1s
#   ↳ saved best_finetune.pt | best@27: val loss=0.231891, val nmse(dB)=-0.4633
# [28/500] train loss=0.276463, nmse(dB)=-0.2207 | val loss=0.224763, nmse(dB)=-0.5991 | 0.1s
#   ↳ saved best_finetune.pt | best@28: val loss=0.224763, val nmse(dB)=-0.5991
# [29/500] train loss=0.266088, nmse(dB)=-0.3517 | val loss=0.217776, nmse(dB)=-0.7364 | 0.1s
#   ↳ saved best_finetune.pt | best@29: val loss=0.217776, val nmse(dB)=-0.7364
# [30/500] train loss=0.265671, nmse(dB)=-0.4772 | val loss=0.210976, nmse(dB)=-0.8744 | 0.1s
#   ↳ saved best_finetune.pt | best@30: val loss=0.210976, val nmse(dB)=-0.8744
# [31/500] train loss=0.256185, nmse(dB)=-0.5565 | val loss=0.204466, nmse(dB)=-1.0108 | 0.1s
#   ↳ saved best_finetune.pt | best@31: val loss=0.204466, val nmse(dB)=-1.0108
# [32/500] train loss=0.249068, nmse(dB)=-0.7003 | val loss=0.198067, nmse(dB)=-1.1491 | 0.1s
#   ↳ saved best_finetune.pt | best@32: val loss=0.198067, val nmse(dB)=-1.1491
# [33/500] train loss=0.241642, nmse(dB)=-0.8002 | val loss=0.191709, nmse(dB)=-1.2910 | 0.1s
#   ↳ saved best_finetune.pt | best@33: val loss=0.191709, val nmse(dB)=-1.2910
# [34/500] train loss=0.234215, nmse(dB)=-0.9285 | val loss=0.185607, nmse(dB)=-1.4317 | 0.1s
#   ↳ saved best_finetune.pt | best@34: val loss=0.185607, val nmse(dB)=-1.4317
# [35/500] train loss=0.231086, nmse(dB)=-1.0329 | val loss=0.179768, nmse(dB)=-1.5708 | 0.1s
#   ↳ saved best_finetune.pt | best@35: val loss=0.179768, val nmse(dB)=-1.5708
# [36/500] train loss=0.222567, nmse(dB)=-1.1156 | val loss=0.174098, nmse(dB)=-1.7103 | 0.1s
#   ↳ saved best_finetune.pt | best@36: val loss=0.174098, val nmse(dB)=-1.7103
# [37/500] train loss=0.215473, nmse(dB)=-1.2457 | val loss=0.168601, nmse(dB)=-1.8500 | 0.1s
#   ↳ saved best_finetune.pt | best@37: val loss=0.168601, val nmse(dB)=-1.8500
# [38/500] train loss=0.212379, nmse(dB)=-1.3695 | val loss=0.163223, nmse(dB)=-1.9911 | 0.1s
#   ↳ saved best_finetune.pt | best@38: val loss=0.163223, val nmse(dB)=-1.9911
# [39/500] train loss=0.207593, nmse(dB)=-1.5029 | val loss=0.157995, nmse(dB)=-2.1328 | 0.1s
#   ↳ saved best_finetune.pt | best@39: val loss=0.157995, val nmse(dB)=-2.1328
# [40/500] train loss=0.201594, nmse(dB)=-1.5944 | val loss=0.152936, nmse(dB)=-2.2746 | 0.1s
#   ↳ saved best_finetune.pt | best@40: val loss=0.152936, val nmse(dB)=-2.2746
# [41/500] train loss=0.196352, nmse(dB)=-1.7204 | val loss=0.148001, nmse(dB)=-2.4174 | 0.1s
#   ↳ saved best_finetune.pt | best@41: val loss=0.148001, val nmse(dB)=-2.4174
# [42/500] train loss=0.191970, nmse(dB)=-1.8066 | val loss=0.143188, nmse(dB)=-2.5614 | 0.1s
#   ↳ saved best_finetune.pt | best@42: val loss=0.143188, val nmse(dB)=-2.5614
# [43/500] train loss=0.185085, nmse(dB)=-1.9260 | val loss=0.138575, nmse(dB)=-2.7041 | 0.1s
#   ↳ saved best_finetune.pt | best@43: val loss=0.138575, val nmse(dB)=-2.7041
# [44/500] train loss=0.185978, nmse(dB)=-2.0079 | val loss=0.134177, nmse(dB)=-2.8447 | 0.1s
#   ↳ saved best_finetune.pt | best@44: val loss=0.134177, val nmse(dB)=-2.8447
# [45/500] train loss=0.177836, nmse(dB)=-2.1563 | val loss=0.129912, nmse(dB)=-2.9855 | 0.1s
#   ↳ saved best_finetune.pt | best@45: val loss=0.129912, val nmse(dB)=-2.9855
# [46/500] train loss=0.173318, nmse(dB)=-2.2561 | val loss=0.125699, nmse(dB)=-3.1292 | 0.1s
#   ↳ saved best_finetune.pt | best@46: val loss=0.125699, val nmse(dB)=-3.1292
# [47/500] train loss=0.169612, nmse(dB)=-2.3490 | val loss=0.121635, nmse(dB)=-3.2726 | 0.1s
#   ↳ saved best_finetune.pt | best@47: val loss=0.121635, val nmse(dB)=-3.2726
# [48/500] train loss=0.166971, nmse(dB)=-2.4564 | val loss=0.117720, nmse(dB)=-3.4153 | 0.1s
#   ↳ saved best_finetune.pt | best@48: val loss=0.117720, val nmse(dB)=-3.4153
# [49/500] train loss=0.161028, nmse(dB)=-2.6048 | val loss=0.113976, nmse(dB)=-3.5563 | 0.1s
#   ↳ saved best_finetune.pt | best@49: val loss=0.113976, val nmse(dB)=-3.5563
# [50/500] train loss=0.159607, nmse(dB)=-2.6837 | val loss=0.110336, nmse(dB)=-3.6979 | 0.1s
#   ↳ saved best_finetune.pt | best@50: val loss=0.110336, val nmse(dB)=-3.6979
# [51/500] train loss=0.153366, nmse(dB)=-2.7394 | val loss=0.106739, nmse(dB)=-3.8426 | 0.1s
#   ↳ saved best_finetune.pt | best@51: val loss=0.106739, val nmse(dB)=-3.8426
# [52/500] train loss=0.150286, nmse(dB)=-2.8901 | val loss=0.103293, nmse(dB)=-3.9860 | 0.1s
#   ↳ saved best_finetune.pt | best@52: val loss=0.103293, val nmse(dB)=-3.9860
# [53/500] train loss=0.147450, nmse(dB)=-2.9613 | val loss=0.099995, nmse(dB)=-4.1278 | 0.1s
#   ↳ saved best_finetune.pt | best@53: val loss=0.099995, val nmse(dB)=-4.1278
# [54/500] train loss=0.143597, nmse(dB)=-3.1046 | val loss=0.096848, nmse(dB)=-4.2676 | 0.1s
#   ↳ saved best_finetune.pt | best@54: val loss=0.096848, val nmse(dB)=-4.2676
# [55/500] train loss=0.141600, nmse(dB)=-3.1901 | val loss=0.093786, nmse(dB)=-4.4082 | 0.1s
#   ↳ saved best_finetune.pt | best@55: val loss=0.093786, val nmse(dB)=-4.4082
# [56/500] train loss=0.136012, nmse(dB)=-3.3120 | val loss=0.090821, nmse(dB)=-4.5487 | 0.1s
#   ↳ saved best_finetune.pt | best@56: val loss=0.090821, val nmse(dB)=-4.5487
# [57/500] train loss=0.134438, nmse(dB)=-3.3638 | val loss=0.087967, nmse(dB)=-4.6885 | 0.1s
#   ↳ saved best_finetune.pt | best@57: val loss=0.087967, val nmse(dB)=-4.6885
# [58/500] train loss=0.132324, nmse(dB)=-3.4895 | val loss=0.085221, nmse(dB)=-4.8273 | 0.1s
#   ↳ saved best_finetune.pt | best@58: val loss=0.085221, val nmse(dB)=-4.8273
# [59/500] train loss=0.128356, nmse(dB)=-3.5707 | val loss=0.082528, nmse(dB)=-4.9680 | 0.1s
#   ↳ saved best_finetune.pt | best@59: val loss=0.082528, val nmse(dB)=-4.9680
# [60/500] train loss=0.126084, nmse(dB)=-3.6476 | val loss=0.079918, nmse(dB)=-5.1089 | 0.1s
#   ↳ saved best_finetune.pt | best@60: val loss=0.079918, val nmse(dB)=-5.1089
# [61/500] train loss=0.124450, nmse(dB)=-3.7482 | val loss=0.077407, nmse(dB)=-5.2489 | 0.1s
#   ↳ saved best_finetune.pt | best@61: val loss=0.077407, val nmse(dB)=-5.2489
# [62/500] train loss=0.122303, nmse(dB)=-3.8176 | val loss=0.074984, nmse(dB)=-5.3886 | 0.1s
#   ↳ saved best_finetune.pt | best@62: val loss=0.074984, val nmse(dB)=-5.3886
# [63/500] train loss=0.120065, nmse(dB)=-3.9263 | val loss=0.072614, nmse(dB)=-5.5297 | 0.1s
#   ↳ saved best_finetune.pt | best@63: val loss=0.072614, val nmse(dB)=-5.5297
# [64/500] train loss=0.117071, nmse(dB)=-4.0359 | val loss=0.070353, nmse(dB)=-5.6687 | 0.1s
#   ↳ saved best_finetune.pt | best@64: val loss=0.070353, val nmse(dB)=-5.6687
# [65/500] train loss=0.114240, nmse(dB)=-4.1601 | val loss=0.068223, nmse(dB)=-5.8039 | 0.1s
#   ↳ saved best_finetune.pt | best@65: val loss=0.068223, val nmse(dB)=-5.8039
# [66/500] train loss=0.112916, nmse(dB)=-4.2091 | val loss=0.066138, nmse(dB)=-5.9405 | 0.1s
#   ↳ saved best_finetune.pt | best@66: val loss=0.066138, val nmse(dB)=-5.9405
# [67/500] train loss=0.112128, nmse(dB)=-4.3053 | val loss=0.064091, nmse(dB)=-6.0790 | 0.1s
#   ↳ saved best_finetune.pt | best@67: val loss=0.064091, val nmse(dB)=-6.0790
# [68/500] train loss=0.107079, nmse(dB)=-4.4212 | val loss=0.062140, nmse(dB)=-6.2153 | 0.1s
#   ↳ saved best_finetune.pt | best@68: val loss=0.062140, val nmse(dB)=-6.2153
# [69/500] train loss=0.106060, nmse(dB)=-4.5031 | val loss=0.060261, nmse(dB)=-6.3508 | 0.1s
#   ↳ saved best_finetune.pt | best@69: val loss=0.060261, val nmse(dB)=-6.3508
# [70/500] train loss=0.103045, nmse(dB)=-4.5801 | val loss=0.058424, nmse(dB)=-6.4878 | 0.1s
#   ↳ saved best_finetune.pt | best@70: val loss=0.058424, val nmse(dB)=-6.4878
# [71/500] train loss=0.101112, nmse(dB)=-4.6715 | val loss=0.056650, nmse(dB)=-6.6243 | 0.1s
#   ↳ saved best_finetune.pt | best@71: val loss=0.056650, val nmse(dB)=-6.6243
# [72/500] train loss=0.100266, nmse(dB)=-4.6974 | val loss=0.054975, nmse(dB)=-6.7572 | 0.1s
#   ↳ saved best_finetune.pt | best@72: val loss=0.054975, val nmse(dB)=-6.7572
# [73/500] train loss=0.097084, nmse(dB)=-4.8372 | val loss=0.053376, nmse(dB)=-6.8880 | 0.1s
#   ↳ saved best_finetune.pt | best@73: val loss=0.053376, val nmse(dB)=-6.8880
# [74/500] train loss=0.097270, nmse(dB)=-4.7992 | val loss=0.051817, nmse(dB)=-7.0195 | 0.1s
#   ↳ saved best_finetune.pt | best@74: val loss=0.051817, val nmse(dB)=-7.0195
# [75/500] train loss=0.095024, nmse(dB)=-4.9342 | val loss=0.050273, nmse(dB)=-7.1539 | 0.1s
#   ↳ saved best_finetune.pt | best@75: val loss=0.050273, val nmse(dB)=-7.1539
# [76/500] train loss=0.092187, nmse(dB)=-5.0736 | val loss=0.048809, nmse(dB)=-7.2854 | 0.1s
#   ↳ saved best_finetune.pt | best@76: val loss=0.048809, val nmse(dB)=-7.2854
# [77/500] train loss=0.091934, nmse(dB)=-5.1053 | val loss=0.047426, nmse(dB)=-7.4136 | 0.1s
#   ↳ saved best_finetune.pt | best@77: val loss=0.047426, val nmse(dB)=-7.4136
# [78/500] train loss=0.089250, nmse(dB)=-5.2125 | val loss=0.046075, nmse(dB)=-7.5426 | 0.1s
#   ↳ saved best_finetune.pt | best@78: val loss=0.046075, val nmse(dB)=-7.5426
# [79/500] train loss=0.089790, nmse(dB)=-5.2330 | val loss=0.044761, nmse(dB)=-7.6719 | 0.1s
#   ↳ saved best_finetune.pt | best@79: val loss=0.044761, val nmse(dB)=-7.6719
# [80/500] train loss=0.089801, nmse(dB)=-5.2711 | val loss=0.043526, nmse(dB)=-7.7971 | 0.1s
#   ↳ saved best_finetune.pt | best@80: val loss=0.043526, val nmse(dB)=-7.7971
# [81/500] train loss=0.084770, nmse(dB)=-5.4326 | val loss=0.042303, nmse(dB)=-7.9251 | 0.1s
#   ↳ saved best_finetune.pt | best@81: val loss=0.042303, val nmse(dB)=-7.9251
# [82/500] train loss=0.086784, nmse(dB)=-5.3357 | val loss=0.041134, nmse(dB)=-8.0513 | 0.1s
#   ↳ saved best_finetune.pt | best@82: val loss=0.041134, val nmse(dB)=-8.0513
# [83/500] train loss=0.085149, nmse(dB)=-5.4854 | val loss=0.040070, nmse(dB)=-8.1694 | 0.1s
#   ↳ saved best_finetune.pt | best@83: val loss=0.040070, val nmse(dB)=-8.1694
# [84/500] train loss=0.083512, nmse(dB)=-5.5677 | val loss=0.038994, nmse(dB)=-8.2922 | 0.1s
#   ↳ saved best_finetune.pt | best@84: val loss=0.038994, val nmse(dB)=-8.2922
# [85/500] train loss=0.083423, nmse(dB)=-5.6148 | val loss=0.037943, nmse(dB)=-8.4158 | 0.1s
#   ↳ saved best_finetune.pt | best@85: val loss=0.037943, val nmse(dB)=-8.4158
# [86/500] train loss=0.082902, nmse(dB)=-5.6509 | val loss=0.036955, nmse(dB)=-8.5353 | 0.1s
#   ↳ saved best_finetune.pt | best@86: val loss=0.036955, val nmse(dB)=-8.5353
# [87/500] train loss=0.080511, nmse(dB)=-5.7548 | val loss=0.035985, nmse(dB)=-8.6562 | 0.1s
#   ↳ saved best_finetune.pt | best@87: val loss=0.035985, val nmse(dB)=-8.6562
# [88/500] train loss=0.076721, nmse(dB)=-5.9382 | val loss=0.035065, nmse(dB)=-8.7741 | 0.1s
#   ↳ saved best_finetune.pt | best@88: val loss=0.035065, val nmse(dB)=-8.7741
# [89/500] train loss=0.077430, nmse(dB)=-5.8832 | val loss=0.034191, nmse(dB)=-8.8893 | 0.1s
#   ↳ saved best_finetune.pt | best@89: val loss=0.034191, val nmse(dB)=-8.8893
# [90/500] train loss=0.077542, nmse(dB)=-5.9011 | val loss=0.033321, nmse(dB)=-9.0073 | 0.1s
#   ↳ saved best_finetune.pt | best@90: val loss=0.033321, val nmse(dB)=-9.0073
# [91/500] train loss=0.076207, nmse(dB)=-6.0189 | val loss=0.032487, nmse(dB)=-9.1239 | 0.1s
#   ↳ saved best_finetune.pt | best@91: val loss=0.032487, val nmse(dB)=-9.1239
# [92/500] train loss=0.076530, nmse(dB)=-5.9725 | val loss=0.031726, nmse(dB)=-9.2333 | 0.1s
#   ↳ saved best_finetune.pt | best@92: val loss=0.031726, val nmse(dB)=-9.2333
# [93/500] train loss=0.073575, nmse(dB)=-6.1309 | val loss=0.030980, nmse(dB)=-9.3434 | 0.1s
#   ↳ saved best_finetune.pt | best@93: val loss=0.030980, val nmse(dB)=-9.3434
# [94/500] train loss=0.074450, nmse(dB)=-6.1529 | val loss=0.030241, nmse(dB)=-9.4555 | 0.1s
#   ↳ saved best_finetune.pt | best@94: val loss=0.030241, val nmse(dB)=-9.4555
# [95/500] train loss=0.073598, nmse(dB)=-6.1601 | val loss=0.029485, nmse(dB)=-9.5732 | 0.1s
#   ↳ saved best_finetune.pt | best@95: val loss=0.029485, val nmse(dB)=-9.5732
# [96/500] train loss=0.073710, nmse(dB)=-6.2117 | val loss=0.028802, nmse(dB)=-9.6822 | 0.1s
#   ↳ saved best_finetune.pt | best@96: val loss=0.028802, val nmse(dB)=-9.6822
# [97/500] train loss=0.072959, nmse(dB)=-6.2805 | val loss=0.028193, nmse(dB)=-9.7821 | 0.1s
#   ↳ saved best_finetune.pt | best@97: val loss=0.028193, val nmse(dB)=-9.7821
# [98/500] train loss=0.072376, nmse(dB)=-6.1842 | val loss=0.027568, nmse(dB)=-9.8874 | 0.1s
#   ↳ saved best_finetune.pt | best@98: val loss=0.027568, val nmse(dB)=-9.8874
# [99/500] train loss=0.070824, nmse(dB)=-6.3442 | val loss=0.026924, nmse(dB)=-9.9988 | 0.1s
#   ↳ saved best_finetune.pt | best@99: val loss=0.026924, val nmse(dB)=-9.9988
# [100/500] train loss=0.071113, nmse(dB)=-6.3253 | val loss=0.026356, nmse(dB)=-10.0996 | 0.1s
#   ↳ saved best_finetune.pt | best@100: val loss=0.026356, val nmse(dB)=-10.0996
# [101/500] train loss=0.070500, nmse(dB)=-6.3716 | val loss=0.025773, nmse(dB)=-10.2058 | 0.1s
#   ↳ saved best_finetune.pt | best@101: val loss=0.025773, val nmse(dB)=-10.2058
# [102/500] train loss=0.069409, nmse(dB)=-6.4459 | val loss=0.025230, nmse(dB)=-10.3074 | 0.1s
#   ↳ saved best_finetune.pt | best@102: val loss=0.025230, val nmse(dB)=-10.3074
# [103/500] train loss=0.069709, nmse(dB)=-6.4199 | val loss=0.024687, nmse(dB)=-10.4119 | 0.1s
#   ↳ saved best_finetune.pt | best@103: val loss=0.024687, val nmse(dB)=-10.4119
# [104/500] train loss=0.068829, nmse(dB)=-6.5201 | val loss=0.024168, nmse(dB)=-10.5143 | 0.1s
#   ↳ saved best_finetune.pt | best@104: val loss=0.024168, val nmse(dB)=-10.5143
# [105/500] train loss=0.065884, nmse(dB)=-6.6806 | val loss=0.023720, nmse(dB)=-10.6048 | 0.1s
#   ↳ saved best_finetune.pt | best@105: val loss=0.023720, val nmse(dB)=-10.6048
# [106/500] train loss=0.067357, nmse(dB)=-6.6578 | val loss=0.023282, nmse(dB)=-10.6953 | 0.1s
#   ↳ saved best_finetune.pt | best@106: val loss=0.023282, val nmse(dB)=-10.6953
# [107/500] train loss=0.064880, nmse(dB)=-6.8008 | val loss=0.022834, nmse(dB)=-10.7900 | 0.1s
#   ↳ saved best_finetune.pt | best@107: val loss=0.022834, val nmse(dB)=-10.7900
# [108/500] train loss=0.064878, nmse(dB)=-6.7405 | val loss=0.022380, nmse(dB)=-10.8878 | 0.1s
#   ↳ saved best_finetune.pt | best@108: val loss=0.022380, val nmse(dB)=-10.8878
# [109/500] train loss=0.065658, nmse(dB)=-6.7024 | val loss=0.021962, nmse(dB)=-10.9805 | 0.1s
#   ↳ saved best_finetune.pt | best@109: val loss=0.021962, val nmse(dB)=-10.9805
# [110/500] train loss=0.064921, nmse(dB)=-6.8089 | val loss=0.021593, nmse(dB)=-11.0644 | 0.1s
#   ↳ saved best_finetune.pt | best@110: val loss=0.021593, val nmse(dB)=-11.0644
# [111/500] train loss=0.064040, nmse(dB)=-6.8726 | val loss=0.021231, nmse(dB)=-11.1488 | 0.1s
#   ↳ saved best_finetune.pt | best@111: val loss=0.021231, val nmse(dB)=-11.1488
# [112/500] train loss=0.064210, nmse(dB)=-6.8041 | val loss=0.020833, nmse(dB)=-11.2435 | 0.1s
#   ↳ saved best_finetune.pt | best@112: val loss=0.020833, val nmse(dB)=-11.2435
# [113/500] train loss=0.063478, nmse(dB)=-6.8377 | val loss=0.020456, nmse(dB)=-11.3351 | 0.1s
#   ↳ saved best_finetune.pt | best@113: val loss=0.020456, val nmse(dB)=-11.3351
# [114/500] train loss=0.064546, nmse(dB)=-6.8896 | val loss=0.020117, nmse(dB)=-11.4195 | 0.1s
#   ↳ saved best_finetune.pt | best@114: val loss=0.020117, val nmse(dB)=-11.4195
# [115/500] train loss=0.066116, nmse(dB)=-6.8060 | val loss=0.019777, nmse(dB)=-11.5064 | 0.1s
#   ↳ saved best_finetune.pt | best@115: val loss=0.019777, val nmse(dB)=-11.5064
# [116/500] train loss=0.061735, nmse(dB)=-7.0203 | val loss=0.019443, nmse(dB)=-11.5937 | 0.1s
#   ↳ saved best_finetune.pt | best@116: val loss=0.019443, val nmse(dB)=-11.5937
# [117/500] train loss=0.060124, nmse(dB)=-7.1009 | val loss=0.019151, nmse(dB)=-11.6719 | 0.1s
#   ↳ saved best_finetune.pt | best@117: val loss=0.019151, val nmse(dB)=-11.6719
# [118/500] train loss=0.063245, nmse(dB)=-6.9200 | val loss=0.018902, nmse(dB)=-11.7401 | 0.1s
#   ↳ saved best_finetune.pt | best@118: val loss=0.018902, val nmse(dB)=-11.7401
# [119/500] train loss=0.062523, nmse(dB)=-6.9434 | val loss=0.018624, nmse(dB)=-11.8162 | 0.1s
#   ↳ saved best_finetune.pt | best@119: val loss=0.018624, val nmse(dB)=-11.8162
# [120/500] train loss=0.061896, nmse(dB)=-7.0173 | val loss=0.018318, nmse(dB)=-11.9016 | 0.1s
#   ↳ saved best_finetune.pt | best@120: val loss=0.018318, val nmse(dB)=-11.9016
# [121/500] train loss=0.060878, nmse(dB)=-7.0941 | val loss=0.018049, nmse(dB)=-11.9782 | 0.1s
#   ↳ saved best_finetune.pt | best@121: val loss=0.018049, val nmse(dB)=-11.9782
# [122/500] train loss=0.060667, nmse(dB)=-7.1378 | val loss=0.017801, nmse(dB)=-12.0509 | 0.1s
#   ↳ saved best_finetune.pt | best@122: val loss=0.017801, val nmse(dB)=-12.0509
# [123/500] train loss=0.059964, nmse(dB)=-7.2369 | val loss=0.017540, nmse(dB)=-12.1295 | 0.1s
#   ↳ saved best_finetune.pt | best@123: val loss=0.017540, val nmse(dB)=-12.1295
# [124/500] train loss=0.061178, nmse(dB)=-7.1473 | val loss=0.017281, nmse(dB)=-12.2098 | 0.1s
#   ↳ saved best_finetune.pt | best@124: val loss=0.017281, val nmse(dB)=-12.2098
# [125/500] train loss=0.058340, nmse(dB)=-7.2381 | val loss=0.017068, nmse(dB)=-12.2773 | 0.1s
#   ↳ saved best_finetune.pt | best@125: val loss=0.017068, val nmse(dB)=-12.2773
# [126/500] train loss=0.061621, nmse(dB)=-7.0855 | val loss=0.016907, nmse(dB)=-12.3300 | 0.1s
#   ↳ saved best_finetune.pt | best@126: val loss=0.016907, val nmse(dB)=-12.3300
# [127/500] train loss=0.060721, nmse(dB)=-7.1503 | val loss=0.016722, nmse(dB)=-12.3912 | 0.1s
#   ↳ saved best_finetune.pt | best@127: val loss=0.016722, val nmse(dB)=-12.3912
# [128/500] train loss=0.060538, nmse(dB)=-7.1854 | val loss=0.016500, nmse(dB)=-12.4652 | 0.1s
#   ↳ saved best_finetune.pt | best@128: val loss=0.016500, val nmse(dB)=-12.4652
# [129/500] train loss=0.060259, nmse(dB)=-7.2266 | val loss=0.016321, nmse(dB)=-12.5250 | 0.1s
#   ↳ saved best_finetune.pt | best@129: val loss=0.016321, val nmse(dB)=-12.5250
# [130/500] train loss=0.057901, nmse(dB)=-7.3143 | val loss=0.016153, nmse(dB)=-12.5816 | 0.1s
#   ↳ saved best_finetune.pt | best@130: val loss=0.016153, val nmse(dB)=-12.5816
# [131/500] train loss=0.057817, nmse(dB)=-7.3627 | val loss=0.015932, nmse(dB)=-12.6573 | 0.1s
#   ↳ saved best_finetune.pt | best@131: val loss=0.015932, val nmse(dB)=-12.6573
# [132/500] train loss=0.058309, nmse(dB)=-7.3351 | val loss=0.015720, nmse(dB)=-12.7325 | 0.1s
#   ↳ saved best_finetune.pt | best@132: val loss=0.015720, val nmse(dB)=-12.7325
# [133/500] train loss=0.059462, nmse(dB)=-7.2624 | val loss=0.015548, nmse(dB)=-12.7957 | 0.1s
#   ↳ saved best_finetune.pt | best@133: val loss=0.015548, val nmse(dB)=-12.7957
# [134/500] train loss=0.058296, nmse(dB)=-7.3900 | val loss=0.015410, nmse(dB)=-12.8477 | 0.1s
#   ↳ saved best_finetune.pt | best@134: val loss=0.015410, val nmse(dB)=-12.8477
# [135/500] train loss=0.059279, nmse(dB)=-7.2698 | val loss=0.015266, nmse(dB)=-12.9030 | 0.1s
#   ↳ saved best_finetune.pt | best@135: val loss=0.015266, val nmse(dB)=-12.9030
# [136/500] train loss=0.056770, nmse(dB)=-7.4441 | val loss=0.015112, nmse(dB)=-12.9628 | 0.1s
#   ↳ saved best_finetune.pt | best@136: val loss=0.015112, val nmse(dB)=-12.9628
# [137/500] train loss=0.057979, nmse(dB)=-7.3674 | val loss=0.014976, nmse(dB)=-13.0162 | 0.1s
#   ↳ saved best_finetune.pt | best@137: val loss=0.014976, val nmse(dB)=-13.0162
# [138/500] train loss=0.057622, nmse(dB)=-7.3887 | val loss=0.014864, nmse(dB)=-13.0594 | 0.1s
#   ↳ saved best_finetune.pt | best@138: val loss=0.014864, val nmse(dB)=-13.0594
# [139/500] train loss=0.056721, nmse(dB)=-7.4845 | val loss=0.014737, nmse(dB)=-13.1096 | 0.1s
#   ↳ saved best_finetune.pt | best@139: val loss=0.014737, val nmse(dB)=-13.1096
# [140/500] train loss=0.055859, nmse(dB)=-7.5374 | val loss=0.014602, nmse(dB)=-13.1648 | 0.1s
#   ↳ saved best_finetune.pt | best@140: val loss=0.014602, val nmse(dB)=-13.1648
# [141/500] train loss=0.055901, nmse(dB)=-7.5094 | val loss=0.014456, nmse(dB)=-13.2252 | 0.1s
#   ↳ saved best_finetune.pt | best@141: val loss=0.014456, val nmse(dB)=-13.2252
# [142/500] train loss=0.056737, nmse(dB)=-7.5375 | val loss=0.014325, nmse(dB)=-13.2803 | 0.1s
#   ↳ saved best_finetune.pt | best@142: val loss=0.014325, val nmse(dB)=-13.2803
# [143/500] train loss=0.056911, nmse(dB)=-7.4623 | val loss=0.014198, nmse(dB)=-13.3342 | 0.1s
#   ↳ saved best_finetune.pt | best@143: val loss=0.014198, val nmse(dB)=-13.3342
# [144/500] train loss=0.057960, nmse(dB)=-7.4159 | val loss=0.014067, nmse(dB)=-13.3904 | 0.1s
#   ↳ saved best_finetune.pt | best@144: val loss=0.014067, val nmse(dB)=-13.3904
# [145/500] train loss=0.058250, nmse(dB)=-7.3711 | val loss=0.013944, nmse(dB)=-13.4445 | 0.1s
#   ↳ saved best_finetune.pt | best@145: val loss=0.013944, val nmse(dB)=-13.4445
# [146/500] train loss=0.055250, nmse(dB)=-7.5486 | val loss=0.013832, nmse(dB)=-13.4950 | 0.1s
#   ↳ saved best_finetune.pt | best@146: val loss=0.013832, val nmse(dB)=-13.4950
# [147/500] train loss=0.055950, nmse(dB)=-7.5418 | val loss=0.013778, nmse(dB)=-13.5204 | 0.1s
#   ↳ saved best_finetune.pt | best@147: val loss=0.013778, val nmse(dB)=-13.5204
# [148/500] train loss=0.054805, nmse(dB)=-7.6643 | val loss=0.013717, nmse(dB)=-13.5490 | 0.1s
#   ↳ saved best_finetune.pt | best@148: val loss=0.013717, val nmse(dB)=-13.5490
# [149/500] train loss=0.056283, nmse(dB)=-7.5065 | val loss=0.013615, nmse(dB)=-13.5962 | 0.1s
#   ↳ saved best_finetune.pt | best@149: val loss=0.013615, val nmse(dB)=-13.5962
# [150/500] train loss=0.055941, nmse(dB)=-7.5754 | val loss=0.013517, nmse(dB)=-13.6421 | 0.1s
#   ↳ saved best_finetune.pt | best@150: val loss=0.013517, val nmse(dB)=-13.6421
# [151/500] train loss=0.056630, nmse(dB)=-7.5173 | val loss=0.013420, nmse(dB)=-13.6870 | 0.1s
#   ↳ saved best_finetune.pt | best@151: val loss=0.013420, val nmse(dB)=-13.6870
# [152/500] train loss=0.056683, nmse(dB)=-7.4948 | val loss=0.013320, nmse(dB)=-13.7338 | 0.1s
#   ↳ saved best_finetune.pt | best@152: val loss=0.013320, val nmse(dB)=-13.7338
# [153/500] train loss=0.056674, nmse(dB)=-7.5251 | val loss=0.013251, nmse(dB)=-13.7670 | 0.1s
#   ↳ saved best_finetune.pt | best@153: val loss=0.013251, val nmse(dB)=-13.7670
# [154/500] train loss=0.055835, nmse(dB)=-7.5545 | val loss=0.013193, nmse(dB)=-13.7957 | 0.1s
#   ↳ saved best_finetune.pt | best@154: val loss=0.013193, val nmse(dB)=-13.7957
# [155/500] train loss=0.055677, nmse(dB)=-7.5392 | val loss=0.013115, nmse(dB)=-13.8350 | 0.1s
#   ↳ saved best_finetune.pt | best@155: val loss=0.013115, val nmse(dB)=-13.8350
# [156/500] train loss=0.055151, nmse(dB)=-7.6300 | val loss=0.013024, nmse(dB)=-13.8821 | 0.1s
#   ↳ saved best_finetune.pt | best@156: val loss=0.013024, val nmse(dB)=-13.8821
# [157/500] train loss=0.055261, nmse(dB)=-7.6069 | val loss=0.012952, nmse(dB)=-13.9206 | 0.1s
#   ↳ saved best_finetune.pt | best@157: val loss=0.012952, val nmse(dB)=-13.9206
# [158/500] train loss=0.053401, nmse(dB)=-7.7508 | val loss=0.012924, nmse(dB)=-13.9371 | 0.1s
#   ↳ saved best_finetune.pt | best@158: val loss=0.012924, val nmse(dB)=-13.9371
# [159/500] train loss=0.054782, nmse(dB)=-7.6288 | val loss=0.012862, nmse(dB)=-13.9699 | 0.1s
#   ↳ saved best_finetune.pt | best@159: val loss=0.012862, val nmse(dB)=-13.9699
# [160/500] train loss=0.055167, nmse(dB)=-7.6184 | val loss=0.012789, nmse(dB)=-14.0074 | 0.1s
#   ↳ saved best_finetune.pt | best@160: val loss=0.012789, val nmse(dB)=-14.0074
# [161/500] train loss=0.053984, nmse(dB)=-7.7246 | val loss=0.012736, nmse(dB)=-14.0341 | 0.1s
#   ↳ saved best_finetune.pt | best@161: val loss=0.012736, val nmse(dB)=-14.0341
# [162/500] train loss=0.054523, nmse(dB)=-7.7093 | val loss=0.012676, nmse(dB)=-14.0641 | 0.1s
#   ↳ saved best_finetune.pt | best@162: val loss=0.012676, val nmse(dB)=-14.0641
# [163/500] train loss=0.052797, nmse(dB)=-7.7945 | val loss=0.012615, nmse(dB)=-14.0975 | 0.1s
#   ↳ saved best_finetune.pt | best@163: val loss=0.012615, val nmse(dB)=-14.0975
# [164/500] train loss=0.052061, nmse(dB)=-7.8570 | val loss=0.012568, nmse(dB)=-14.1267 | 0.1s
#   ↳ saved best_finetune.pt | best@164: val loss=0.012568, val nmse(dB)=-14.1267
# [165/500] train loss=0.054101, nmse(dB)=-7.7381 | val loss=0.012550, nmse(dB)=-14.1391 | 0.1s
#   ↳ saved best_finetune.pt | best@165: val loss=0.012550, val nmse(dB)=-14.1391
# [166/500] train loss=0.054571, nmse(dB)=-7.7381 | val loss=0.012490, nmse(dB)=-14.1727 | 0.1s
#   ↳ saved best_finetune.pt | best@166: val loss=0.012490, val nmse(dB)=-14.1727
# [167/500] train loss=0.053519, nmse(dB)=-7.7371 | val loss=0.012447, nmse(dB)=-14.1968 | 0.1s
#   ↳ saved best_finetune.pt | best@167: val loss=0.012447, val nmse(dB)=-14.1968
# [168/500] train loss=0.053388, nmse(dB)=-7.7321 | val loss=0.012409, nmse(dB)=-14.2188 | 0.1s
#   ↳ saved best_finetune.pt | best@168: val loss=0.012409, val nmse(dB)=-14.2188
# [169/500] train loss=0.054787, nmse(dB)=-7.6857 | val loss=0.012339, nmse(dB)=-14.2611 | 0.1s
#   ↳ saved best_finetune.pt | best@169: val loss=0.012339, val nmse(dB)=-14.2611
# [170/500] train loss=0.053730, nmse(dB)=-7.7854 | val loss=0.012275, nmse(dB)=-14.3000 | 0.1s
#   ↳ saved best_finetune.pt | best@170: val loss=0.012275, val nmse(dB)=-14.3000
# [171/500] train loss=0.054342, nmse(dB)=-7.7895 | val loss=0.012263, nmse(dB)=-14.3062 | 0.1s
#   ↳ saved best_finetune.pt | best@171: val loss=0.012263, val nmse(dB)=-14.3062
# [172/500] train loss=0.055256, nmse(dB)=-7.7304 | val loss=0.012251, nmse(dB)=-14.3124 | 0.1s
#   ↳ saved best_finetune.pt | best@172: val loss=0.012251, val nmse(dB)=-14.3124
# [173/500] train loss=0.054866, nmse(dB)=-7.6911 | val loss=0.012223, nmse(dB)=-14.3276 | 0.1s
#   ↳ saved best_finetune.pt | best@173: val loss=0.012223, val nmse(dB)=-14.3276
# [174/500] train loss=0.056265, nmse(dB)=-7.6112 | val loss=0.012177, nmse(dB)=-14.3536 | 0.1s
#   ↳ saved best_finetune.pt | best@174: val loss=0.012177, val nmse(dB)=-14.3536
# [175/500] train loss=0.054375, nmse(dB)=-7.6621 | val loss=0.012143, nmse(dB)=-14.3749 | 0.1s
#   ↳ saved best_finetune.pt | best@175: val loss=0.012143, val nmse(dB)=-14.3749
# [176/500] train loss=0.053263, nmse(dB)=-7.7455 | val loss=0.012095, nmse(dB)=-14.4054 | 0.1s
#   ↳ saved best_finetune.pt | best@176: val loss=0.012095, val nmse(dB)=-14.4054
# [177/500] train loss=0.054935, nmse(dB)=-7.6497 | val loss=0.012066, nmse(dB)=-14.4242 | 0.1s
#   ↳ saved best_finetune.pt | best@177: val loss=0.012066, val nmse(dB)=-14.4242
# [178/500] train loss=0.054315, nmse(dB)=-7.7508 | val loss=0.012037, nmse(dB)=-14.4427 | 0.1s
#   ↳ saved best_finetune.pt | best@178: val loss=0.012037, val nmse(dB)=-14.4427
# [179/500] train loss=0.053473, nmse(dB)=-7.8179 | val loss=0.011986, nmse(dB)=-14.4738 | 0.1s
#   ↳ saved best_finetune.pt | best@179: val loss=0.011986, val nmse(dB)=-14.4738
# [180/500] train loss=0.053071, nmse(dB)=-7.8357 | val loss=0.011944, nmse(dB)=-14.4998 | 0.1s
#   ↳ saved best_finetune.pt | best@180: val loss=0.011944, val nmse(dB)=-14.4998
# [181/500] train loss=0.052888, nmse(dB)=-7.8299 | val loss=0.011945, nmse(dB)=-14.4995 | 0.1s
# [182/500] train loss=0.053939, nmse(dB)=-7.6795 | val loss=0.011972, nmse(dB)=-14.4842 | 0.1s
# [183/500] train loss=0.054262, nmse(dB)=-7.7316 | val loss=0.011974, nmse(dB)=-14.4822 | 0.1s
# [184/500] train loss=0.053271, nmse(dB)=-7.8674 | val loss=0.011934, nmse(dB)=-14.5065 | 0.1s
#   ↳ saved best_finetune.pt | best@184: val loss=0.011934, val nmse(dB)=-14.5065
# [185/500] train loss=0.053161, nmse(dB)=-7.7987 | val loss=0.011885, nmse(dB)=-14.5368 | 0.1s
#   ↳ saved best_finetune.pt | best@185: val loss=0.011885, val nmse(dB)=-14.5368
# [186/500] train loss=0.054177, nmse(dB)=-7.7803 | val loss=0.011839, nmse(dB)=-14.5673 | 0.1s
#   ↳ saved best_finetune.pt | best@186: val loss=0.011839, val nmse(dB)=-14.5673
# [187/500] train loss=0.053619, nmse(dB)=-7.8025 | val loss=0.011806, nmse(dB)=-14.5903 | 0.1s
#   ↳ saved best_finetune.pt | best@187: val loss=0.011806, val nmse(dB)=-14.5903
# [188/500] train loss=0.052805, nmse(dB)=-7.8310 | val loss=0.011770, nmse(dB)=-14.6160 | 0.1s
#   ↳ saved best_finetune.pt | best@188: val loss=0.011770, val nmse(dB)=-14.6160
# [189/500] train loss=0.052405, nmse(dB)=-7.8919 | val loss=0.011734, nmse(dB)=-14.6425 | 0.1s
#   ↳ saved best_finetune.pt | best@189: val loss=0.011734, val nmse(dB)=-14.6425
# [190/500] train loss=0.053399, nmse(dB)=-7.8437 | val loss=0.011699, nmse(dB)=-14.6691 | 0.1s
#   ↳ saved best_finetune.pt | best@190: val loss=0.011699, val nmse(dB)=-14.6691
# [191/500] train loss=0.054428, nmse(dB)=-7.7411 | val loss=0.011685, nmse(dB)=-14.6816 | 0.1s
#   ↳ saved best_finetune.pt | best@191: val loss=0.011685, val nmse(dB)=-14.6816
# [192/500] train loss=0.054184, nmse(dB)=-7.7274 | val loss=0.011661, nmse(dB)=-14.6986 | 0.1s
#   ↳ saved best_finetune.pt | best@192: val loss=0.011661, val nmse(dB)=-14.6986
# [193/500] train loss=0.052731, nmse(dB)=-7.8903 | val loss=0.011639, nmse(dB)=-14.7119 | 0.1s
#   ↳ saved best_finetune.pt | best@193: val loss=0.011639, val nmse(dB)=-14.7119
# [194/500] train loss=0.053661, nmse(dB)=-7.7580 | val loss=0.011612, nmse(dB)=-14.7277 | 0.1s
#   ↳ saved best_finetune.pt | best@194: val loss=0.011612, val nmse(dB)=-14.7277
# [195/500] train loss=0.053211, nmse(dB)=-7.8647 | val loss=0.011579, nmse(dB)=-14.7483 | 0.1s
#   ↳ saved best_finetune.pt | best@195: val loss=0.011579, val nmse(dB)=-14.7483
# [196/500] train loss=0.052880, nmse(dB)=-7.8304 | val loss=0.011566, nmse(dB)=-14.7563 | 0.1s
#   ↳ saved best_finetune.pt | best@196: val loss=0.011566, val nmse(dB)=-14.7563
# [197/500] train loss=0.052295, nmse(dB)=-7.8945 | val loss=0.011562, nmse(dB)=-14.7589 | 0.1s
#   ↳ saved best_finetune.pt | best@197: val loss=0.011562, val nmse(dB)=-14.7589
# [198/500] train loss=0.053431, nmse(dB)=-7.8782 | val loss=0.011556, nmse(dB)=-14.7621 | 0.1s
#   ↳ saved best_finetune.pt | best@198: val loss=0.011556, val nmse(dB)=-14.7621
# [199/500] train loss=0.053660, nmse(dB)=-7.8061 | val loss=0.011548, nmse(dB)=-14.7650 | 0.1s
#   ↳ saved best_finetune.pt | best@199: val loss=0.011548, val nmse(dB)=-14.7650
# [200/500] train loss=0.054088, nmse(dB)=-7.7763 | val loss=0.011532, nmse(dB)=-14.7739 | 0.1s
#   ↳ saved best_finetune.pt | best@200: val loss=0.011532, val nmse(dB)=-14.7739
# [201/500] train loss=0.051862, nmse(dB)=-7.9938 | val loss=0.011493, nmse(dB)=-14.7996 | 0.1s
#   ↳ saved best_finetune.pt | best@201: val loss=0.011493, val nmse(dB)=-14.7996
# [202/500] train loss=0.052695, nmse(dB)=-7.8396 | val loss=0.011465, nmse(dB)=-14.8193 | 0.1s
#   ↳ saved best_finetune.pt | best@202: val loss=0.011465, val nmse(dB)=-14.8193
# [203/500] train loss=0.052804, nmse(dB)=-7.8806 | val loss=0.011473, nmse(dB)=-14.8147 | 0.1s
# [204/500] train loss=0.053462, nmse(dB)=-7.8284 | val loss=0.011474, nmse(dB)=-14.8166 | 0.1s
# [205/500] train loss=0.052593, nmse(dB)=-7.8547 | val loss=0.011466, nmse(dB)=-14.8242 | 0.1s
# [206/500] train loss=0.052990, nmse(dB)=-7.8745 | val loss=0.011456, nmse(dB)=-14.8328 | 0.1s
#   ↳ saved best_finetune.pt | best@206: val loss=0.011456, val nmse(dB)=-14.8328
# [207/500] train loss=0.053267, nmse(dB)=-7.8031 | val loss=0.011441, nmse(dB)=-14.8444 | 0.1s
#   ↳ saved best_finetune.pt | best@207: val loss=0.011441, val nmse(dB)=-14.8444
# [208/500] train loss=0.054365, nmse(dB)=-7.7000 | val loss=0.011429, nmse(dB)=-14.8548 | 0.1s
#   ↳ saved best_finetune.pt | best@208: val loss=0.011429, val nmse(dB)=-14.8548
# [209/500] train loss=0.052174, nmse(dB)=-7.9383 | val loss=0.011419, nmse(dB)=-14.8640 | 0.1s
#   ↳ saved best_finetune.pt | best@209: val loss=0.011419, val nmse(dB)=-14.8640
# [210/500] train loss=0.051709, nmse(dB)=-7.9454 | val loss=0.011404, nmse(dB)=-14.8767 | 0.1s
#   ↳ saved best_finetune.pt | best@210: val loss=0.011404, val nmse(dB)=-14.8767
# [211/500] train loss=0.054530, nmse(dB)=-7.7122 | val loss=0.011388, nmse(dB)=-14.8894 | 0.1s
#   ↳ saved best_finetune.pt | best@211: val loss=0.011388, val nmse(dB)=-14.8894
# [212/500] train loss=0.055203, nmse(dB)=-7.6913 | val loss=0.011383, nmse(dB)=-14.8919 | 0.1s
#   ↳ saved best_finetune.pt | best@212: val loss=0.011383, val nmse(dB)=-14.8919
# [213/500] train loss=0.050931, nmse(dB)=-8.0455 | val loss=0.011386, nmse(dB)=-14.8888 | 0.1s
# [214/500] train loss=0.052390, nmse(dB)=-7.8222 | val loss=0.011384, nmse(dB)=-14.8912 | 0.1s
# [215/500] train loss=0.052237, nmse(dB)=-7.9638 | val loss=0.011375, nmse(dB)=-14.8972 | 0.1s
#   ↳ saved best_finetune.pt | best@215: val loss=0.011375, val nmse(dB)=-14.8972
# [216/500] train loss=0.052764, nmse(dB)=-7.8566 | val loss=0.011375, nmse(dB)=-14.8972 | 0.1s
#   ↳ saved best_finetune.pt | best@216: val loss=0.011375, val nmse(dB)=-14.8972
# [217/500] train loss=0.055590, nmse(dB)=-7.6307 | val loss=0.011377, nmse(dB)=-14.8944 | 0.1s
# [218/500] train loss=0.053299, nmse(dB)=-7.8350 | val loss=0.011358, nmse(dB)=-14.9082 | 0.1s
#   ↳ saved best_finetune.pt | best@218: val loss=0.011358, val nmse(dB)=-14.9082
# [219/500] train loss=0.052845, nmse(dB)=-7.9256 | val loss=0.011334, nmse(dB)=-14.9234 | 0.1s
#   ↳ saved best_finetune.pt | best@219: val loss=0.011334, val nmse(dB)=-14.9234
# [220/500] train loss=0.051150, nmse(dB)=-7.9475 | val loss=0.011336, nmse(dB)=-14.9189 | 0.1s
# [221/500] train loss=0.051599, nmse(dB)=-7.9306 | val loss=0.011356, nmse(dB)=-14.9027 | 0.1s
# [222/500] train loss=0.053134, nmse(dB)=-7.8793 | val loss=0.011336, nmse(dB)=-14.9170 | 0.1s
# [223/500] train loss=0.053080, nmse(dB)=-7.8242 | val loss=0.011290, nmse(dB)=-14.9503 | 0.1s
#   ↳ saved best_finetune.pt | best@223: val loss=0.011290, val nmse(dB)=-14.9503
# [224/500] train loss=0.051936, nmse(dB)=-7.9463 | val loss=0.011278, nmse(dB)=-14.9615 | 0.1s
#   ↳ saved best_finetune.pt | best@224: val loss=0.011278, val nmse(dB)=-14.9615
# [225/500] train loss=0.053535, nmse(dB)=-7.8315 | val loss=0.011287, nmse(dB)=-14.9583 | 0.1s
# [226/500] train loss=0.052886, nmse(dB)=-7.8486 | val loss=0.011290, nmse(dB)=-14.9589 | 0.1s
# [227/500] train loss=0.050532, nmse(dB)=-7.9619 | val loss=0.011293, nmse(dB)=-14.9585 | 0.1s
# [228/500] train loss=0.053780, nmse(dB)=-7.8235 | val loss=0.011284, nmse(dB)=-14.9641 | 0.1s
# [229/500] train loss=0.053982, nmse(dB)=-7.7998 | val loss=0.011281, nmse(dB)=-14.9641 | 0.1s
# [230/500] train loss=0.052224, nmse(dB)=-7.9163 | val loss=0.011285, nmse(dB)=-14.9605 | 0.1s
# [231/500] train loss=0.054457, nmse(dB)=-7.7566 | val loss=0.011283, nmse(dB)=-14.9616 | 0.1s
# [232/500] train loss=0.052806, nmse(dB)=-7.8663 | val loss=0.011258, nmse(dB)=-14.9806 | 0.1s
#   ↳ saved best_finetune.pt | best@232: val loss=0.011258, val nmse(dB)=-14.9806
# [233/500] train loss=0.053568, nmse(dB)=-7.8149 | val loss=0.011220, nmse(dB)=-15.0093 | 0.1s
#   ↳ saved best_finetune.pt | best@233: val loss=0.011220, val nmse(dB)=-15.0093
# [234/500] train loss=0.051168, nmse(dB)=-7.9721 | val loss=0.011230, nmse(dB)=-15.0026 | 0.1s
# [235/500] train loss=0.055305, nmse(dB)=-7.7350 | val loss=0.011243, nmse(dB)=-14.9938 | 0.1s
# [236/500] train loss=0.053259, nmse(dB)=-7.8675 | val loss=0.011233, nmse(dB)=-15.0026 | 0.1s
# [237/500] train loss=0.053086, nmse(dB)=-7.9234 | val loss=0.011224, nmse(dB)=-15.0111 | 0.1s
# [238/500] train loss=0.053532, nmse(dB)=-7.8349 | val loss=0.011218, nmse(dB)=-15.0153 | 0.1s
#   ↳ saved best_finetune.pt | best@238: val loss=0.011218, val nmse(dB)=-15.0153
# [239/500] train loss=0.053724, nmse(dB)=-7.8183 | val loss=0.011198, nmse(dB)=-15.0276 | 0.1s
#   ↳ saved best_finetune.pt | best@239: val loss=0.011198, val nmse(dB)=-15.0276
# [240/500] train loss=0.052437, nmse(dB)=-7.8874 | val loss=0.011177, nmse(dB)=-15.0405 | 0.1s
#   ↳ saved best_finetune.pt | best@240: val loss=0.011177, val nmse(dB)=-15.0405
# [241/500] train loss=0.053428, nmse(dB)=-7.8164 | val loss=0.011162, nmse(dB)=-15.0491 | 0.1s
#   ↳ saved best_finetune.pt | best@241: val loss=0.011162, val nmse(dB)=-15.0491
# [242/500] train loss=0.053466, nmse(dB)=-7.8580 | val loss=0.011144, nmse(dB)=-15.0635 | 0.1s
#   ↳ saved best_finetune.pt | best@242: val loss=0.011144, val nmse(dB)=-15.0635
# [243/500] train loss=0.051768, nmse(dB)=-7.9674 | val loss=0.011134, nmse(dB)=-15.0736 | 0.1s
#   ↳ saved best_finetune.pt | best@243: val loss=0.011134, val nmse(dB)=-15.0736
# [244/500] train loss=0.051804, nmse(dB)=-7.9246 | val loss=0.011128, nmse(dB)=-15.0803 | 0.1s
#   ↳ saved best_finetune.pt | best@244: val loss=0.011128, val nmse(dB)=-15.0803
# [245/500] train loss=0.053035, nmse(dB)=-7.8806 | val loss=0.011129, nmse(dB)=-15.0813 | 0.1s
# [246/500] train loss=0.054263, nmse(dB)=-7.7535 | val loss=0.011131, nmse(dB)=-15.0821 | 0.1s
# [247/500] train loss=0.052874, nmse(dB)=-7.8743 | val loss=0.011134, nmse(dB)=-15.0827 | 0.1s
# [248/500] train loss=0.051308, nmse(dB)=-7.9327 | val loss=0.011145, nmse(dB)=-15.0745 | 0.1s
# [249/500] train loss=0.051502, nmse(dB)=-7.9580 | val loss=0.011159, nmse(dB)=-15.0630 | 0.1s
# [250/500] train loss=0.051512, nmse(dB)=-7.9444 | val loss=0.011161, nmse(dB)=-15.0595 | 0.1s
# [251/500] train loss=0.053160, nmse(dB)=-7.8738 | val loss=0.011152, nmse(dB)=-15.0631 | 0.1s
# [252/500] train loss=0.053378, nmse(dB)=-7.8887 | val loss=0.011134, nmse(dB)=-15.0740 | 0.1s
# [253/500] train loss=0.053130, nmse(dB)=-7.8527 | val loss=0.011123, nmse(dB)=-15.0805 | 0.1s
#   ↳ saved best_finetune.pt | best@253: val loss=0.011123, val nmse(dB)=-15.0805
# [254/500] train loss=0.052999, nmse(dB)=-7.8492 | val loss=0.011113, nmse(dB)=-15.0868 | 0.1s
#   ↳ saved best_finetune.pt | best@254: val loss=0.011113, val nmse(dB)=-15.0868
# [255/500] train loss=0.051657, nmse(dB)=-7.9444 | val loss=0.011104, nmse(dB)=-15.0939 | 0.1s
#   ↳ saved best_finetune.pt | best@255: val loss=0.011104, val nmse(dB)=-15.0939
# [256/500] train loss=0.052599, nmse(dB)=-7.8965 | val loss=0.011100, nmse(dB)=-15.1002 | 0.1s
#   ↳ saved best_finetune.pt | best@256: val loss=0.011100, val nmse(dB)=-15.1002
# [257/500] train loss=0.050964, nmse(dB)=-7.9824 | val loss=0.011100, nmse(dB)=-15.1028 | 0.1s
# [258/500] train loss=0.052297, nmse(dB)=-7.9681 | val loss=0.011103, nmse(dB)=-15.1022 | 0.1s
# [259/500] train loss=0.051721, nmse(dB)=-7.9623 | val loss=0.011103, nmse(dB)=-15.1014 | 0.1s
# [260/500] train loss=0.053043, nmse(dB)=-7.8462 | val loss=0.011105, nmse(dB)=-15.1011 | 0.1s
# [261/500] train loss=0.051704, nmse(dB)=-7.9587 | val loss=0.011124, nmse(dB)=-15.0892 | 0.1s
# [262/500] train loss=0.051126, nmse(dB)=-8.0015 | val loss=0.011146, nmse(dB)=-15.0736 | 0.1s
# [263/500] train loss=0.052094, nmse(dB)=-7.9483 | val loss=0.011161, nmse(dB)=-15.0623 | 0.1s
# [264/500] train loss=0.051639, nmse(dB)=-7.9477 | val loss=0.011158, nmse(dB)=-15.0634 | 0.1s
# [265/500] train loss=0.051078, nmse(dB)=-8.0481 | val loss=0.011141, nmse(dB)=-15.0759 | 0.1s
# [266/500] train loss=0.051108, nmse(dB)=-8.0096 | val loss=0.011131, nmse(dB)=-15.0845 | 0.1s
# [267/500] train loss=0.052604, nmse(dB)=-7.8691 | val loss=0.011122, nmse(dB)=-15.0921 | 0.1s
# [268/500] train loss=0.051777, nmse(dB)=-7.9781 | val loss=0.011112, nmse(dB)=-15.1013 | 0.1s
# [269/500] train loss=0.053768, nmse(dB)=-7.8419 | val loss=0.011107, nmse(dB)=-15.1055 | 0.1s
# [270/500] train loss=0.050735, nmse(dB)=-8.0535 | val loss=0.011096, nmse(dB)=-15.1128 | 0.1s
#   ↳ saved best_finetune.pt | best@270: val loss=0.011096, val nmse(dB)=-15.1128
# [271/500] train loss=0.051484, nmse(dB)=-8.0082 | val loss=0.011085, nmse(dB)=-15.1185 | 0.1s
#   ↳ saved best_finetune.pt | best@271: val loss=0.011085, val nmse(dB)=-15.1185
# [272/500] train loss=0.052013, nmse(dB)=-7.9313 | val loss=0.011089, nmse(dB)=-15.1134 | 0.1s
# [273/500] train loss=0.050985, nmse(dB)=-8.0286 | val loss=0.011095, nmse(dB)=-15.1081 | 0.1s
# [274/500] train loss=0.051890, nmse(dB)=-7.9793 | val loss=0.011098, nmse(dB)=-15.1053 | 0.1s
# [275/500] train loss=0.051832, nmse(dB)=-8.0286 | val loss=0.011104, nmse(dB)=-15.1003 | 0.1s
# [276/500] train loss=0.051342, nmse(dB)=-7.9253 | val loss=0.011105, nmse(dB)=-15.1007 | 0.1s
# [277/500] train loss=0.052367, nmse(dB)=-7.9431 | val loss=0.011109, nmse(dB)=-15.1011 | 0.1s
# [278/500] train loss=0.053758, nmse(dB)=-7.7989 | val loss=0.011118, nmse(dB)=-15.0968 | 0.1s
# [279/500] train loss=0.052066, nmse(dB)=-7.9504 | val loss=0.011126, nmse(dB)=-15.0906 | 0.1s
# [280/500] train loss=0.051089, nmse(dB)=-8.0103 | val loss=0.011126, nmse(dB)=-15.0886 | 0.1s
# [281/500] train loss=0.053261, nmse(dB)=-7.8202 | val loss=0.011114, nmse(dB)=-15.0953 | 0.1s
# [282/500] train loss=0.053320, nmse(dB)=-7.8729 | val loss=0.011098, nmse(dB)=-15.1046 | 0.1s
# [283/500] train loss=0.051120, nmse(dB)=-8.0261 | val loss=0.011083, nmse(dB)=-15.1153 | 0.1s
#   ↳ saved best_finetune.pt | best@283: val loss=0.011083, val nmse(dB)=-15.1153
# [284/500] train loss=0.051214, nmse(dB)=-8.0210 | val loss=0.011075, nmse(dB)=-15.1221 | 0.1s
#   ↳ saved best_finetune.pt | best@284: val loss=0.011075, val nmse(dB)=-15.1221
# [285/500] train loss=0.051535, nmse(dB)=-7.9802 | val loss=0.011074, nmse(dB)=-15.1241 | 0.1s
#   ↳ saved best_finetune.pt | best@285: val loss=0.011074, val nmse(dB)=-15.1241
# [286/500] train loss=0.052461, nmse(dB)=-7.9126 | val loss=0.011074, nmse(dB)=-15.1256 | 0.1s
# [287/500] train loss=0.050337, nmse(dB)=-8.0836 | val loss=0.011089, nmse(dB)=-15.1136 | 0.1s
# [288/500] train loss=0.054140, nmse(dB)=-7.8357 | val loss=0.011117, nmse(dB)=-15.0916 | 0.1s
# [289/500] train loss=0.050734, nmse(dB)=-8.0594 | val loss=0.011137, nmse(dB)=-15.0764 | 0.1s
# [290/500] train loss=0.051722, nmse(dB)=-7.9447 | val loss=0.011135, nmse(dB)=-15.0798 | 0.1s
# [291/500] train loss=0.051963, nmse(dB)=-7.9681 | val loss=0.011115, nmse(dB)=-15.0967 | 0.1s
# [292/500] train loss=0.052745, nmse(dB)=-7.8945 | val loss=0.011097, nmse(dB)=-15.1115 | 0.1s
# [293/500] train loss=0.053918, nmse(dB)=-7.8341 | val loss=0.011084, nmse(dB)=-15.1208 | 0.1s
# [294/500] train loss=0.053743, nmse(dB)=-7.7721 | val loss=0.011070, nmse(dB)=-15.1304 | 0.1s
#   ↳ saved best_finetune.pt | best@294: val loss=0.011070, val nmse(dB)=-15.1304
# [295/500] train loss=0.052151, nmse(dB)=-7.8984 | val loss=0.011065, nmse(dB)=-15.1338 | 0.1s
#   ↳ saved best_finetune.pt | best@295: val loss=0.011065, val nmse(dB)=-15.1338
# [296/500] train loss=0.052903, nmse(dB)=-7.8811 | val loss=0.011063, nmse(dB)=-15.1342 | 0.1s
#   ↳ saved best_finetune.pt | best@296: val loss=0.011063, val nmse(dB)=-15.1342
# [297/500] train loss=0.052748, nmse(dB)=-7.9056 | val loss=0.011064, nmse(dB)=-15.1322 | 0.1s
# [298/500] train loss=0.052923, nmse(dB)=-7.9456 | val loss=0.011073, nmse(dB)=-15.1245 | 0.1s
# [299/500] train loss=0.051674, nmse(dB)=-8.0239 | val loss=0.011072, nmse(dB)=-15.1229 | 0.1s
# [300/500] train loss=0.051069, nmse(dB)=-8.0757 | val loss=0.011069, nmse(dB)=-15.1243 | 0.1s
# [301/500] train loss=0.051870, nmse(dB)=-7.9926 | val loss=0.011073, nmse(dB)=-15.1192 | 0.1s
# [302/500] train loss=0.050493, nmse(dB)=-8.0519 | val loss=0.011083, nmse(dB)=-15.1111 | 0.1s
# [303/500] train loss=0.050752, nmse(dB)=-8.0686 | val loss=0.011085, nmse(dB)=-15.1096 | 0.1s
# [304/500] train loss=0.050916, nmse(dB)=-8.0834 | val loss=0.011087, nmse(dB)=-15.1098 | 0.1s
# [305/500] train loss=0.053422, nmse(dB)=-7.8453 | val loss=0.011081, nmse(dB)=-15.1169 | 0.1s
# [306/500] train loss=0.050916, nmse(dB)=-8.0526 | val loss=0.011074, nmse(dB)=-15.1254 | 0.1s
# [307/500] train loss=0.051739, nmse(dB)=-7.9503 | val loss=0.011068, nmse(dB)=-15.1324 | 0.1s
# [308/500] train loss=0.052425, nmse(dB)=-7.9112 | val loss=0.011062, nmse(dB)=-15.1384 | 0.1s
#   ↳ saved best_finetune.pt | best@308: val loss=0.011062, val nmse(dB)=-15.1384
# [309/500] train loss=0.053015, nmse(dB)=-7.9049 | val loss=0.011060, nmse(dB)=-15.1406 | 0.1s
#   ↳ saved best_finetune.pt | best@309: val loss=0.011060, val nmse(dB)=-15.1406
# [310/500] train loss=0.051553, nmse(dB)=-7.9650 | val loss=0.011055, nmse(dB)=-15.1447 | 0.1s
#   ↳ saved best_finetune.pt | best@310: val loss=0.011055, val nmse(dB)=-15.1447
# [311/500] train loss=0.052413, nmse(dB)=-7.9112 | val loss=0.011049, nmse(dB)=-15.1495 | 0.1s
#   ↳ saved best_finetune.pt | best@311: val loss=0.011049, val nmse(dB)=-15.1495
# [312/500] train loss=0.051494, nmse(dB)=-7.9937 | val loss=0.011045, nmse(dB)=-15.1516 | 0.1s
#   ↳ saved best_finetune.pt | best@312: val loss=0.011045, val nmse(dB)=-15.1516
# [313/500] train loss=0.051804, nmse(dB)=-7.9875 | val loss=0.011050, nmse(dB)=-15.1478 | 0.1s
# ...
# [352/500] train loss=0.052653, nmse(dB)=-7.9223 | val loss=0.011052, nmse(dB)=-15.1466 | 0.1s
# [353/500] train loss=0.052675, nmse(dB)=-7.8644 | val loss=0.011055, nmse(dB)=-15.1440 | 0.1s
# [354/500] train loss=0.051343, nmse(dB)=-7.9860 | val loss=0.011060, nmse(dB)=-15.1407 | 0.1s
# [355/500] train loss=0.050117, nmse(dB)=-8.0511 | val loss=0.011064, nmse(dB)=-15.1368 | 0.1s
# [356/500] train loss=0.051790, nmse(dB)=-7.9305 | val loss=0.011062, nmse(dB)=-15.1382 | 0.1s
# [357/500] train loss=0.053421, nmse(dB)=-7.8697 | val loss=0.011057, nmse(dB)=-15.1421 | 0.1s
# [358/500] train loss=0.050536, nmse(dB)=-8.1115 | val loss=0.011052, nmse(dB)=-15.1464 | 0.1s
# [359/500] train loss=0.051365, nmse(dB)=-7.9893 | val loss=0.011045, nmse(dB)=-15.1521 | 0.1s
# [360/500] train loss=0.051873, nmse(dB)=-8.0000 | val loss=0.011045, nmse(dB)=-15.1520 | 0.1s
# [361/500] train loss=0.051386, nmse(dB)=-7.9911 | val loss=0.011047, nmse(dB)=-15.1515 | 0.1s
# [362/500] train loss=0.051559, nmse(dB)=-8.0594 | val loss=0.011048, nmse(dB)=-15.1510 | 0.1s
# [363/500] train loss=0.051359, nmse(dB)=-7.9997 | val loss=0.011046, nmse(dB)=-15.1519 | 0.1s
# [364/500] train loss=0.052531, nmse(dB)=-7.9429 | val loss=0.011046, nmse(dB)=-15.1520 | 0.1s
# [365/500] train loss=0.053484, nmse(dB)=-7.8290 | val loss=0.011045, nmse(dB)=-15.1522 | 0.1s
# [366/500] train loss=0.051876, nmse(dB)=-7.9507 | val loss=0.011046, nmse(dB)=-15.1510 | 0.1s
# [367/500] train loss=0.051989, nmse(dB)=-7.9302 | val loss=0.011049, nmse(dB)=-15.1485 | 0.1s
# [368/500] train loss=0.049010, nmse(dB)=-8.1624 | val loss=0.011053, nmse(dB)=-15.1458 | 0.1s
# [369/500] train loss=0.051633, nmse(dB)=-7.9780 | val loss=0.011055, nmse(dB)=-15.1453 | 0.1s
# [370/500] train loss=0.052557, nmse(dB)=-7.9320 | val loss=0.011053, nmse(dB)=-15.1475 | 0.1s
# [371/500] train loss=0.052831, nmse(dB)=-7.8499 | val loss=0.011052, nmse(dB)=-15.1496 | 0.1s
# [372/500] train loss=0.052657, nmse(dB)=-7.8547 | val loss=0.011052, nmse(dB)=-15.1499 | 0.1s
# [373/500] train loss=0.051503, nmse(dB)=-8.0392 | val loss=0.011053, nmse(dB)=-15.1494 | 0.1s
# [374/500] train loss=0.051391, nmse(dB)=-7.9945 | val loss=0.011054, nmse(dB)=-15.1495 | 0.1s
# [375/500] train loss=0.051011, nmse(dB)=-8.0651 | val loss=0.011051, nmse(dB)=-15.1521 | 0.1s
# [376/500] train loss=0.052213, nmse(dB)=-8.0181 | val loss=0.011045, nmse(dB)=-15.1568 | 0.1s
# [377/500] train loss=0.052687, nmse(dB)=-7.9274 | val loss=0.011037, nmse(dB)=-15.1610 | 0.1s
# [378/500] train loss=0.051518, nmse(dB)=-8.0375 | val loss=0.011032, nmse(dB)=-15.1635 | 0.1s
#   ↳ saved best_finetune.pt | best@378: val loss=0.011032, val nmse(dB)=-15.1635
# [379/500] train loss=0.052922, nmse(dB)=-7.8851 | val loss=0.011028, nmse(dB)=-15.1658 | 0.1s
#   ↳ saved best_finetune.pt | best@379: val loss=0.011028, val nmse(dB)=-15.1658
# [380/500] train loss=0.051455, nmse(dB)=-7.9641 | val loss=0.011025, nmse(dB)=-15.1679 | 0.1s
#   ↳ saved best_finetune.pt | best@380: val loss=0.011025, val nmse(dB)=-15.1679
# [381/500] train loss=0.052139, nmse(dB)=-7.9781 | val loss=0.011026, nmse(dB)=-15.1678 | 0.1s
# [382/500] train loss=0.050699, nmse(dB)=-8.0834 | val loss=0.011026, nmse(dB)=-15.1681 | 0.1s
# [383/500] train loss=0.051734, nmse(dB)=-7.9652 | val loss=0.011028, nmse(dB)=-15.1677 | 0.1s
# [384/500] train loss=0.053100, nmse(dB)=-7.8451 | val loss=0.011032, nmse(dB)=-15.1652 | 0.1s
# [385/500] train loss=0.052778, nmse(dB)=-7.8937 | val loss=0.011036, nmse(dB)=-15.1628 | 0.1s
# [386/500] train loss=0.051995, nmse(dB)=-7.9219 | val loss=0.011038, nmse(dB)=-15.1615 | 0.1s
# [387/500] train loss=0.050717, nmse(dB)=-7.9794 | val loss=0.011040, nmse(dB)=-15.1601 | 0.1s
# [388/500] train loss=0.051416, nmse(dB)=-7.9953 | val loss=0.011040, nmse(dB)=-15.1600 | 0.1s
# [389/500] train loss=0.051894, nmse(dB)=-7.9576 | val loss=0.011041, nmse(dB)=-15.1585 | 0.1s
# [390/500] train loss=0.052339, nmse(dB)=-7.9474 | val loss=0.011041, nmse(dB)=-15.1580 | 0.1s
# [391/500] train loss=0.051027, nmse(dB)=-8.0487 | val loss=0.011040, nmse(dB)=-15.1588 | 0.1s
# [392/500] train loss=0.052572, nmse(dB)=-7.8300 | val loss=0.011038, nmse(dB)=-15.1598 | 0.1s
# [393/500] train loss=0.050004, nmse(dB)=-8.1040 | val loss=0.011039, nmse(dB)=-15.1590 | 0.1s
# [394/500] train loss=0.052259, nmse(dB)=-7.9778 | val loss=0.011041, nmse(dB)=-15.1571 | 0.1s
# [395/500] train loss=0.049832, nmse(dB)=-8.0887 | val loss=0.011043, nmse(dB)=-15.1552 | 0.1s
# [396/500] train loss=0.052587, nmse(dB)=-7.8682 | val loss=0.011044, nmse(dB)=-15.1540 | 0.1s
# [397/500] train loss=0.050190, nmse(dB)=-8.1245 | val loss=0.011044, nmse(dB)=-15.1541 | 0.1s
# [398/500] train loss=0.050675, nmse(dB)=-8.0268 | val loss=0.011041, nmse(dB)=-15.1556 | 0.1s
# [399/500] train loss=0.052094, nmse(dB)=-7.9613 | val loss=0.011038, nmse(dB)=-15.1575 | 0.1s
# [400/500] train loss=0.052420, nmse(dB)=-7.9282 | val loss=0.011036, nmse(dB)=-15.1588 | 0.1s
# [401/500] train loss=0.052951, nmse(dB)=-7.9295 | val loss=0.011035, nmse(dB)=-15.1595 | 0.1s
# [402/500] train loss=0.049957, nmse(dB)=-8.0903 | val loss=0.011034, nmse(dB)=-15.1600 | 0.1s
# [403/500] train loss=0.051837, nmse(dB)=-7.9850 | val loss=0.011033, nmse(dB)=-15.1604 | 0.1s
# [404/500] train loss=0.050544, nmse(dB)=-8.1013 | val loss=0.011033, nmse(dB)=-15.1604 | 0.1s
# [405/500] train loss=0.052430, nmse(dB)=-7.9077 | val loss=0.011032, nmse(dB)=-15.1608 | 0.1s
# [406/500] train loss=0.051836, nmse(dB)=-7.9450 | val loss=0.011031, nmse(dB)=-15.1615 | 0.1s
# [407/500] train loss=0.053417, nmse(dB)=-7.8960 | val loss=0.011030, nmse(dB)=-15.1626 | 0.1s
# [408/500] train loss=0.052499, nmse(dB)=-7.9025 | val loss=0.011029, nmse(dB)=-15.1632 | 0.1s
# [409/500] train loss=0.053527, nmse(dB)=-7.8492 | val loss=0.011030, nmse(dB)=-15.1631 | 0.1s
# [410/500] train loss=0.050084, nmse(dB)=-8.0478 | val loss=0.011030, nmse(dB)=-15.1630 | 0.1s
# [411/500] train loss=0.050124, nmse(dB)=-8.0666 | val loss=0.011031, nmse(dB)=-15.1620 | 0.1s
# [412/500] train loss=0.049999, nmse(dB)=-8.1419 | val loss=0.011033, nmse(dB)=-15.1602 | 0.1s
# [413/500] train loss=0.052706, nmse(dB)=-7.9035 | val loss=0.011033, nmse(dB)=-15.1594 | 0.1s
# [414/500] train loss=0.051994, nmse(dB)=-7.9520 | val loss=0.011033, nmse(dB)=-15.1589 | 0.1s
# [415/500] train loss=0.051132, nmse(dB)=-7.9878 | val loss=0.011033, nmse(dB)=-15.1588 | 0.1s
# [416/500] train loss=0.052453, nmse(dB)=-7.9430 | val loss=0.011032, nmse(dB)=-15.1594 | 0.1s
# [417/500] train loss=0.052976, nmse(dB)=-7.9304 | val loss=0.011031, nmse(dB)=-15.1603 | 0.1s
# [418/500] train loss=0.051575, nmse(dB)=-8.0030 | val loss=0.011030, nmse(dB)=-15.1615 | 0.1s
# [419/500] train loss=0.052936, nmse(dB)=-7.9600 | val loss=0.011028, nmse(dB)=-15.1634 | 0.1s
# [420/500] train loss=0.052013, nmse(dB)=-7.9215 | val loss=0.011028, nmse(dB)=-15.1643 | 0.1s
# [421/500] train loss=0.051891, nmse(dB)=-8.0365 | val loss=0.011029, nmse(dB)=-15.1641 | 0.1s
# [422/500] train loss=0.050921, nmse(dB)=-8.0079 | val loss=0.011030, nmse(dB)=-15.1640 | 0.1s
# [423/500] train loss=0.051629, nmse(dB)=-8.0147 | val loss=0.011032, nmse(dB)=-15.1638 | 0.1s
# [424/500] train loss=0.049330, nmse(dB)=-8.1317 | val loss=0.011031, nmse(dB)=-15.1645 | 0.1s
# [425/500] train loss=0.052690, nmse(dB)=-7.9149 | val loss=0.011030, nmse(dB)=-15.1651 | 0.1s
# [426/500] train loss=0.053559, nmse(dB)=-7.8302 | val loss=0.011030, nmse(dB)=-15.1653 | 0.1s
# [427/500] train loss=0.051062, nmse(dB)=-7.9954 | val loss=0.011030, nmse(dB)=-15.1652 | 0.1s
# [428/500] train loss=0.051152, nmse(dB)=-8.0175 | val loss=0.011031, nmse(dB)=-15.1643 | 0.1s
# [429/500] train loss=0.050490, nmse(dB)=-8.0875 | val loss=0.011031, nmse(dB)=-15.1632 | 0.1s
# [430/500] train loss=0.052621, nmse(dB)=-7.8771 | val loss=0.011032, nmse(dB)=-15.1619 | 0.1s
# [431/500] train loss=0.050610, nmse(dB)=-7.9939 | val loss=0.011032, nmse(dB)=-15.1611 | 0.1s
# [432/500] train loss=0.051694, nmse(dB)=-7.9756 | val loss=0.011033, nmse(dB)=-15.1604 | 0.1s
# [433/500] train loss=0.051449, nmse(dB)=-7.9852 | val loss=0.011033, nmse(dB)=-15.1601 | 0.1s
# [434/500] train loss=0.051302, nmse(dB)=-8.0564 | val loss=0.011033, nmse(dB)=-15.1603 | 0.1s
# [435/500] train loss=0.052135, nmse(dB)=-7.9556 | val loss=0.011032, nmse(dB)=-15.1611 | 0.1s
# [436/500] train loss=0.052977, nmse(dB)=-7.9557 | val loss=0.011031, nmse(dB)=-15.1621 | 0.1s
# [437/500] train loss=0.051642, nmse(dB)=-7.9827 | val loss=0.011030, nmse(dB)=-15.1631 | 0.1s
# [438/500] train loss=0.049900, nmse(dB)=-8.0922 | val loss=0.011029, nmse(dB)=-15.1640 | 0.1s
# [439/500] train loss=0.053498, nmse(dB)=-7.8736 | val loss=0.011028, nmse(dB)=-15.1649 | 0.1s
# [440/500] train loss=0.050391, nmse(dB)=-8.0503 | val loss=0.011027, nmse(dB)=-15.1659 | 0.1s
# [441/500] train loss=0.051342, nmse(dB)=-7.9839 | val loss=0.011026, nmse(dB)=-15.1665 | 0.1s
# [442/500] train loss=0.050835, nmse(dB)=-8.0561 | val loss=0.011026, nmse(dB)=-15.1671 | 0.1s
# [443/500] train loss=0.052822, nmse(dB)=-7.8859 | val loss=0.011025, nmse(dB)=-15.1681 | 0.1s
#   ↳ saved best_finetune.pt | best@443: val loss=0.011025, val nmse(dB)=-15.1681
# [444/500] train loss=0.050350, nmse(dB)=-8.0623 | val loss=0.011024, nmse(dB)=-15.1691 | 0.1s
#   ↳ saved best_finetune.pt | best@444: val loss=0.011024, val nmse(dB)=-15.1691
# [445/500] train loss=0.050879, nmse(dB)=-7.9948 | val loss=0.011023, nmse(dB)=-15.1700 | 0.1s
#   ↳ saved best_finetune.pt | best@445: val loss=0.011023, val nmse(dB)=-15.1700
# [446/500] train loss=0.051709, nmse(dB)=-8.0270 | val loss=0.011022, nmse(dB)=-15.1708 | 0.1s
#   ↳ saved best_finetune.pt | best@446: val loss=0.011022, val nmse(dB)=-15.1708
# [447/500] train loss=0.051872, nmse(dB)=-7.9675 | val loss=0.011021, nmse(dB)=-15.1716 | 0.1s
#   ↳ saved best_finetune.pt | best@447: val loss=0.011021, val nmse(dB)=-15.1716
# [448/500] train loss=0.052121, nmse(dB)=-7.9423 | val loss=0.011020, nmse(dB)=-15.1723 | 0.1s
#   ↳ saved best_finetune.pt | best@448: val loss=0.011020, val nmse(dB)=-15.1723
# [449/500] train loss=0.053198, nmse(dB)=-7.9181 | val loss=0.011020, nmse(dB)=-15.1724 | 0.1s
#   ↳ saved best_finetune.pt | best@449: val loss=0.011020, val nmse(dB)=-15.1724
# [450/500] train loss=0.050140, nmse(dB)=-8.1249 | val loss=0.011020, nmse(dB)=-15.1724 | 0.1s
#   ↳ saved best_finetune.pt | best@450: val loss=0.011020, val nmse(dB)=-15.1724
# [451/500] train loss=0.051416, nmse(dB)=-8.0064 | val loss=0.011019, nmse(dB)=-15.1723 | 0.1s
#   ↳ saved best_finetune.pt | best@451: val loss=0.011019, val nmse(dB)=-15.1723
# [452/500] train loss=0.051003, nmse(dB)=-8.0426 | val loss=0.011019, nmse(dB)=-15.1723 | 0.1s
#   ↳ saved best_finetune.pt | best@452: val loss=0.011019, val nmse(dB)=-15.1723
# [453/500] train loss=0.052068, nmse(dB)=-7.9810 | val loss=0.011019, nmse(dB)=-15.1723 | 0.1s
#   ↳ saved best_finetune.pt | best@453: val loss=0.011019, val nmse(dB)=-15.1723
# [454/500] train loss=0.052196, nmse(dB)=-7.9853 | val loss=0.011018, nmse(dB)=-15.1724 | 0.1s
#   ↳ saved best_finetune.pt | best@454: val loss=0.011018, val nmse(dB)=-15.1724
# [455/500] train loss=0.050224, nmse(dB)=-8.0585 | val loss=0.011018, nmse(dB)=-15.1725 | 0.1s
#   ↳ saved best_finetune.pt | best@455: val loss=0.011018, val nmse(dB)=-15.1725
# [456/500] train loss=0.049640, nmse(dB)=-8.1009 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
#   ↳ saved best_finetune.pt | best@456: val loss=0.011018, val nmse(dB)=-15.1728
# [457/500] train loss=0.050439, nmse(dB)=-8.0487 | val loss=0.011018, nmse(dB)=-15.1731 | 0.1s
#   ↳ saved best_finetune.pt | best@457: val loss=0.011018, val nmse(dB)=-15.1731
# [458/500] train loss=0.053430, nmse(dB)=-7.8826 | val loss=0.011017, nmse(dB)=-15.1732 | 0.1s
#   ↳ saved best_finetune.pt | best@458: val loss=0.011017, val nmse(dB)=-15.1732
# [459/500] train loss=0.051801, nmse(dB)=-7.9667 | val loss=0.011017, nmse(dB)=-15.1734 | 0.1s
#   ↳ saved best_finetune.pt | best@459: val loss=0.011017, val nmse(dB)=-15.1734
# [460/500] train loss=0.051428, nmse(dB)=-7.9919 | val loss=0.011017, nmse(dB)=-15.1736 | 0.1s
#   ↳ saved best_finetune.pt | best@460: val loss=0.011017, val nmse(dB)=-15.1736
# [461/500] train loss=0.051915, nmse(dB)=-7.9375 | val loss=0.011017, nmse(dB)=-15.1735 | 0.1s
# [462/500] train loss=0.052277, nmse(dB)=-7.9768 | val loss=0.011017, nmse(dB)=-15.1735 | 0.1s
# [463/500] train loss=0.051447, nmse(dB)=-7.9771 | val loss=0.011017, nmse(dB)=-15.1735 | 0.1s
# [464/500] train loss=0.051160, nmse(dB)=-8.0821 | val loss=0.011017, nmse(dB)=-15.1735 | 0.1s
#   ↳ saved best_finetune.pt | best@464: val loss=0.011017, val nmse(dB)=-15.1735
# [465/500] train loss=0.051057, nmse(dB)=-8.0007 | val loss=0.011017, nmse(dB)=-15.1735 | 0.1s
#   ↳ saved best_finetune.pt | best@465: val loss=0.011017, val nmse(dB)=-15.1735
# [466/500] train loss=0.049767, nmse(dB)=-8.0839 | val loss=0.011017, nmse(dB)=-15.1735 | 0.1s
# [467/500] train loss=0.052523, nmse(dB)=-7.8891 | val loss=0.011017, nmse(dB)=-15.1735 | 0.1s
# [468/500] train loss=0.050521, nmse(dB)=-8.0649 | val loss=0.011017, nmse(dB)=-15.1734 | 0.1s
# [469/500] train loss=0.052083, nmse(dB)=-8.0043 | val loss=0.011017, nmse(dB)=-15.1733 | 0.1s
# [470/500] train loss=0.051347, nmse(dB)=-8.0572 | val loss=0.011017, nmse(dB)=-15.1731 | 0.1s
# [471/500] train loss=0.051913, nmse(dB)=-7.9938 | val loss=0.011018, nmse(dB)=-15.1731 | 0.1s
# [472/500] train loss=0.051683, nmse(dB)=-8.0160 | val loss=0.011018, nmse(dB)=-15.1730 | 0.1s
# [473/500] train loss=0.052320, nmse(dB)=-7.9247 | val loss=0.011018, nmse(dB)=-15.1731 | 0.1s
# [474/500] train loss=0.049901, nmse(dB)=-8.1315 | val loss=0.011018, nmse(dB)=-15.1731 | 0.1s
# [475/500] train loss=0.050902, nmse(dB)=-8.0638 | val loss=0.011018, nmse(dB)=-15.1730 | 0.1s
# [476/500] train loss=0.051622, nmse(dB)=-8.0087 | val loss=0.011018, nmse(dB)=-15.1729 | 0.1s
# [477/500] train loss=0.052530, nmse(dB)=-7.8702 | val loss=0.011018, nmse(dB)=-15.1729 | 0.1s
# [478/500] train loss=0.050510, nmse(dB)=-8.0694 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [479/500] train loss=0.051046, nmse(dB)=-8.0767 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [480/500] train loss=0.051318, nmse(dB)=-7.9524 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [481/500] train loss=0.052398, nmse(dB)=-7.8843 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [482/500] train loss=0.052152, nmse(dB)=-8.0001 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [483/500] train loss=0.050777, nmse(dB)=-8.0650 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [484/500] train loss=0.050616, nmse(dB)=-8.0600 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [485/500] train loss=0.052222, nmse(dB)=-7.9521 | val loss=0.011018, nmse(dB)=-15.1729 | 0.1s
# [486/500] train loss=0.053207, nmse(dB)=-7.8712 | val loss=0.011018, nmse(dB)=-15.1729 | 0.1s
# [487/500] train loss=0.050228, nmse(dB)=-8.1205 | val loss=0.011018, nmse(dB)=-15.1729 | 0.1s
# [488/500] train loss=0.052473, nmse(dB)=-7.9510 | val loss=0.011018, nmse(dB)=-15.1729 | 0.1s
# [489/500] train loss=0.051498, nmse(dB)=-7.9704 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [490/500] train loss=0.052115, nmse(dB)=-7.9495 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [491/500] train loss=0.049742, nmse(dB)=-8.1000 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [492/500] train loss=0.051710, nmse(dB)=-8.0079 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [493/500] train loss=0.049872, nmse(dB)=-8.0812 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [494/500] train loss=0.050285, nmse(dB)=-8.0543 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [495/500] train loss=0.051557, nmse(dB)=-7.9796 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [496/500] train loss=0.052126, nmse(dB)=-7.9164 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [497/500] train loss=0.051942, nmse(dB)=-7.9711 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [498/500] train loss=0.051508, nmse(dB)=-7.9916 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [499/500] train loss=0.052209, nmse(dB)=-7.9337 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
# [500/500] train loss=0.051213, nmse(dB)=-7.9779 | val loss=0.011018, nmse(dB)=-15.1728 | 0.1s
#
# === Training Summary ===
# Total time: 75.1s (0h 1m 15.1s)
# Best epoch: 465 | best val loss=0.011017, best val nmse(dB)=-15.1735

# %% [markdown]
# # 런타임 체크

# %%
ch, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model(ch.to(device))   
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# y abs mean: 0.49936503171920776
# y abs max : 1.0
# y power   : 0.2998412549495697
# yhat abs mean: 0.4945213794708252
# yhat abs max : 0.5738277435302734
# yhat power   : 0.24514177441596985

# %%
y
# Out:
# tensor([[0.7090, 0.7159, 0.7231,  ..., 0.3206, 0.3072, 0.2977],
#         [0.9300, 0.9405, 0.9473,  ..., 0.3734, 0.3941, 0.4135],
#         [0.3173, 0.2997, 0.2824,  ..., 0.9147, 0.9237, 0.9295],
#         ...,
#         [0.5688, 0.5617, 0.5533,  ..., 0.2597, 0.2638, 0.2657],
#         [0.7167, 0.7191, 0.7228,  ..., 0.3115, 0.3246, 0.3410],
#         [0.1897, 0.1977, 0.2072,  ..., 0.2411, 0.2543, 0.2662]],
#        device='cuda:0')

# %%
yhat[0:10, 0:10]
# Out:
# tensor([[0.5586, 0.5610, 0.5718, 0.5665, 0.5626, 0.5610, 0.5725, 0.5653, 0.5600,
#          0.5585],
#         [0.5574, 0.5603, 0.5732, 0.5667, 0.5643, 0.5616, 0.5729, 0.5652, 0.5607,
#          0.5608],
#         [0.5596, 0.5609, 0.5707, 0.5662, 0.5618, 0.5614, 0.5734, 0.5654, 0.5590,
#          0.5575],
#         [0.5586, 0.5608, 0.5720, 0.5665, 0.5624, 0.5610, 0.5726, 0.5653, 0.5601,
#          0.5583],
#         [0.5586, 0.5612, 0.5717, 0.5666, 0.5627, 0.5608, 0.5723, 0.5653, 0.5604,
#          0.5585],
#         [0.5586, 0.5611, 0.5719, 0.5665, 0.5626, 0.5608, 0.5723, 0.5652, 0.5603,
#          0.5585],
#         [0.5585, 0.5604, 0.5726, 0.5665, 0.5640, 0.5609, 0.5727, 0.5653, 0.5610,
#          0.5596],
#         [0.5584, 0.5608, 0.5720, 0.5666, 0.5626, 0.5610, 0.5727, 0.5652, 0.5601,
#          0.5584],
#         [0.5592, 0.5602, 0.5714, 0.5660, 0.5623, 0.5612, 0.5736, 0.5653, 0.5594,
#          0.5582],
#         [0.5587, 0.5611, 0.5715, 0.5661, 0.5624, 0.5611, 0.5738, 0.5655, 0.5594,
#          0.5596]], device='cuda:0')

# %% [markdown]
# # 데이터 입력 형태

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

print("\n=== one batch shapes ===")
ch, y = next(iter(train_loader))
print("ch :", tuple(ch.shape), " -> (B,T,F_in)")
print("y  :", tuple(y.shape), " -> (B,F_out)")
with torch.no_grad():
    yhat = model(ch.to(device))
print("yhat:", tuple(yhat.shape), " -> (B,F_out)")
print("this forward predicted vectors:", yhat.shape[0], "(=B)")
print("each vector predicts elements:", yhat.shape[1], "(=F_out)")
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# past_len      : 16
# len(ds)       : 84
# len(train_ds) : 51
# len(val_ds)   : 17
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B,T,F_in)
# y  : (32, 2048)  -> (B,F_out)
# yhat: (32, 2048)  -> (B,F_out)
# this forward predicted vectors: 32 (=B)
# each vector predicts elements: 2048 (=F_out)
