# %% [markdown]
# # lwm2
# <br>모델 크기 차이에 따른 성능 차이 비교
# <br> element_length=16, d_model=64
# <br> in_proj: F_in(2048) → 512 → 128 → 16

# %% [markdown]
# # Import

# %%
import os
import sys

import numpy as  np
from lwm_model2 import lwm  # 클래스 import
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import torch.nn as nn   
import time

from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Setting
# ### CUDA 몇번 사용하는지 잘 확인하기

# %%
# Scenes 1000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(101))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"현재 사용 중인 장치: {device}")
# Out:
# 현재 사용 중인 장치: cuda:1

# %% [markdown]
# # Generate a dataset

# %%
# scenes / subcarriers는 그대로
param_manager.params["radar"]["enable"] = False

# lidar가 dict로 존재하면 disable
if isinstance(param_manager.params.get("lidar", None), dict):
    param_manager.params["lidar"]["enable"] = False

# position이 dict로 존재하면 disable
if isinstance(param_manager.params.get("position", None), dict):
    param_manager.params["position"]["enable"] = False

# Radar, LiDAR, Position 사용하지 않으므로 False 
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (0.94s)

# %% [markdown]
# # Prerocessing

# %% [markdown]
# #### Channel

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device=device, eps=1e-16):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex64)
    
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(device, dtype=torch.float32)
    return H

# %% [markdown]
# #### image

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class ChannelNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, ue_idx=0, past_len=16, device=device,
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        self.comm_frames = comm_frames
        self.ue_idx = ue_idx
        self.past_len = past_len
        self.device = device

        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = len(self.comm_frames)
        self.valid_start = past_len - 1
        self.valid_end = self.N - 2

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1) Channel Past
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            h = preprocess_channel_coeffs_minmax(
                coeffs_np,
                self.r_min, self.r_max, self.i_min, self.i_max,
                device=self.device
            ).reshape(-1)  # (2048,)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)  # (T, 2048)

        # 2) Target Next
        coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + 1], ue_idx=self.ue_idx)
        target = preprocess_channel_coeffs_minmax(
            coeffs_np_next,
            self.r_min, self.r_max, self.i_min, self.i_max,
            device=self.device
        ).reshape(-1)  # (2048,)

        return channel_past, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)

ds = ChannelNextStepDatasetGPU(
    comm_frames=comm_frames,
    ue_idx=0,
    past_len=16,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   
)
ch, y = next(iter(loader))
print(ch.shape, y.shape)
print(ch.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 2048])
# cuda:1 cuda:1

# %% [markdown]
# # Fine-tuning

# %%
class LWMForecasterNoEdit(nn.Module):
    """
    lwm 코드는 수정하지 않고, encoder(embedding+layers)만 직접 호출해서 forecasting
    Input : ch  (B,T,F_in)
    Output: yhat(B,F_out)
    """
    def __init__(
        self,
        base_lwm: nn.Module,
        F_in: int,
        F_out: int,
        pool: str = "last",
        freeze_backbone: bool = False,
    ):
        super().__init__()
        self.base = base_lwm
        self.pool = pool

        n_dim   = self.base.embedding.element_length  # 16
        d_model = self.base.embedding.d_model         # 64

        self.in_proj = nn.Sequential(
            nn.Linear(F_in, 512),
            nn.GELU(),
            nn.Linear(512, 128),
            nn.GELU(),
            nn.Linear(128, n_dim),
        )

        self.head = nn.Linear(d_model, F_out)

        if freeze_backbone:
            for p in self.base.parameters():
                p.requires_grad = False
            for p in self.in_proj.parameters():
                p.requires_grad = True
            for p in self.head.parameters():
                p.requires_grad = True

    def forward(self, ch):
        x = self.in_proj(ch)          # (B,T,F_in) -> (B,T,16)

        out = self.base.embedding(x)  # (B,T,64)
        for layer in self.base.layers:
            out, _ = layer(out)       # (B,T,64)

        if self.pool == "last":
            z = out[:, -1, :]
        elif self.pool == "mean":
            z = out.mean(dim=1)
        else:
            raise ValueError(f"Unknown pool={self.pool}")

        return self.head(z)           # (B,F_out)

# %% [markdown]
# # NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B,F)
    num = torch.sum((yhat - y) ** 2, dim=1)
    den = torch.sum(y ** 2, dim=1).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse.clamp_min(eps)).mean()

# 아래는 샘플에 대한 NMSE 계산이 아니라, batch 전체에 대한 NMSE 계산
# @torch.no_grad()
# def nmse_db_global(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
#     # yhat, y: (B,F)
#     num = torch.sum((yhat - y) ** 2).clamp_min(eps)  # batch 전체 합
#     den = torch.sum(y ** 2).clamp_min(eps)
#     nmse = num / den
#     return 10.0 * torch.log10(nmse)

# %% [markdown]
# # Train/val Split

# %%
# 겹치는 부분이 있는지 확인하는 함수
def used_frames_for_ds_indices(ds, ds_indices):
    used = set()
    for i in ds_indices:
        t = ds.valid_start + i
        # inputs use [t-T+1 .. t], target uses (t+1)
        used.update(range(t - T + 1, t + 2))
    return used

# %%
n_total = len(ds)
T = ds.past_len  # = past_len

# ---- choose k so that train=3k, val=k and NO frame-overlap is possible ----
k_max = (n_total - T) // 4
if k_max <= 0:
    raise ValueError(
        f"Not enough data for strict non-overlap 3:1. "
        f"n_total={n_total}, past_len(T)={T}. "
        f"Try increasing scenes or decreasing past_len."
    )

k = k_max               # use as much data as possible under constraints
n_val = k
n_train = 3 * k

train_idx = list(range(0, n_train))
val_idx   = list(range(n_total - n_val, n_total))

print("n_total:", n_total, "T:", T)
print("train samples:", len(train_idx), "val samples:", len(val_idx), "ratio:", len(train_idx)/len(val_idx))

# ---- min/max ONLY from train (same as your original policy) ----
train_ts = [ds.valid_start + i for i in train_idx]

(real_min, real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_ts, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset.")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)

F_in = 2048


overlap = used_frames_for_ds_indices(ds, train_idx).intersection(
          used_frames_for_ds_indices(ds, val_idx))
print("frame-overlap count:", len(overlap))
assert len(overlap) == 0, "Leakage detected: train/val share frames!"

# Verify (channel-only)
ch, y = next(iter(train_loader))   # ✅ img 제거
F_out = y.shape[-1]

print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")

# (선택) ch도 같이 범위 확인하고 싶으면
print(f"ch stats | min: {ch.min().item():.4f}, max: {ch.max().item():.4f}")
# Out:
# n_total: 85 T: 16
# train samples: 51 val samples: 17 ratio: 3.0
# Calculating min/max over training set...
# Done. rmin=-1.0646139639174899e-06, rmax=1.0917989155343993e-06, imin=-1.0719516685941772e-06, imax=1.0643868111374237e-06
# Dataset statistical values set in the dataset.
# frame-overlap count: 0
#
# === Data Check ===
# y stats | min: 0.0005, max: 0.9943
# If scaling worked correctly, values should be within [0, 1].
# ch stats | min: -0.2332, max: 1.2388

# %% [markdown]
# # Train/Eval 함수

# %%
# batch check
ch, y = next(iter(train_loader))
print(ch.shape, y.shape)

def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()
    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, y in loader:
        ch = ch.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        yhat = model(ch)                
        loss = F.mse_loss(yhat, y)
        loss.backward()

        if grad_clip and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        optimizer.step()

        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, y in loader:
        ch = ch.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        yhat = model(ch)                 
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)
# Out:
# torch.Size([32, 16, 2048]) torch.Size([32, 2048])

# %% [markdown]
# # 모델 생성 및 확인

# %%
# 배치 하나로 F_in/F_out 자동 확정
ch, y = next(iter(train_loader))
F_in  = ch.shape[-1]
F_out = y.shape[-1]
print("Detected:", "F_in=", F_in, "F_out=", F_out)
print("Batch devices:", ch.device, y.device)

backbone = lwm().to(device)  
model = LWMForecasterNoEdit(
    base_lwm=backbone,
    F_in=F_in,
    F_out=F_out,
    pool="last",
    freeze_backbone=False,
).to(device)

# sanity forward
model.eval()
with torch.no_grad():
    # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
    yhat = model(ch.to(device))
print("yhat:", yhat.shape, "y:", y.shape)
# Out:
# Detected: F_in= 2048 F_out= 2048
# Batch devices: cuda:1 cuda:1
# yhat: torch.Size([32, 2048]) y: torch.Size([32, 2048])

# %% [markdown]
# # Optimizer/Scheduler 설정

# %%
# requires_grad=True인 파라미터만 학습
trainable_params = [p for p in model.parameters() if p.requires_grad]
print("trainable params:", sum(p.numel() for p in trainable_params))

optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# (선택) cosine scheduler
epochs = 500
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
# Out:
# trainable params: 1853648

# %% [markdown]
# # 학습 루프 및 checkpoint 저장

# %%
import time
import os
import torch

best_val = float("inf")
best_val_nmse = None
best_epoch = None

t_train0 = time.time()  # ✅ 전체 학습 시작 시간

# 어떤 모델을 몇개의 scene으로 학습을 했는지 기록
log_path = "lwm_model2_scene101_1.txt"

with open(log_path, "w", encoding="utf-8") as f:
    for epoch in range(1, epochs + 1):
        t0 = time.time()

        tr_loss, tr_nmse = train_one_epoch(
            model, train_loader, optimizer, device=device, grad_clip=1.0
        )
        va_loss, va_nmse = evaluate(model, val_loader, device=device)

        scheduler.step()

        dt = time.time() - t0

        # ✅ 1) print에 쓰는 문자열을 변수로 만들기
        line = (
            f"[{epoch:02d}/{epochs}] "
            f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
            f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
            f"{dt:.1f}s"
        )

        # ✅ 2) 콘솔 + 파일에 동시에 기록
        print(line)
        f.write(line + "\n")
        f.flush()

        if va_loss < best_val:
            best_val = va_loss
            best_val_nmse = va_nmse
            best_epoch = epoch

            ckpt_path = "bestc_channel_only_finetune.pt"
            torch.save(
                {
                    "epoch": epoch,
                    "model_state": model.state_dict(),
                    "optimizer_state": optimizer.state_dict(),
                    "F_in": F_in,
                    "F_out": F_out,
                    "best_val_loss": best_val,
                    "best_val_nmse_db": best_val_nmse,
                },
                ckpt_path,
            )

            save_line = (
                f"  ↳ saved {ckpt_path} | best@{best_epoch}: "
                f"val loss={best_val:.6f}, val nmse(dB)={best_val_nmse:.4f}"
            )
            print(save_line)
            f.write(save_line + "\n")
            f.flush()

# ✅ 전체 학습 종료 후 총 시간 출력 + 파일 append
total_sec = time.time() - t_train0
h = int(total_sec // 3600)
m = int((total_sec % 3600) // 60)
s = total_sec % 60

summary1 = "\n=== Training Summary ==="
summary2 = f"Total time: {total_sec:.1f}s ({h}h {m}m {s:.1f}s)"
summary3 = (
    f"Best epoch: {best_epoch} | best val loss={best_val:.6f}, "
    f"best val nmse(dB)={best_val_nmse:.4f}"
)

print(summary1)
print(summary2)
print(summary3)

with open(log_path, "a", encoding="utf-8") as f:
    f.write(summary1 + "\n")
    f.write(summary2 + "\n")
    f.write(summary3 + "\n")

print("Log saved to:", os.path.abspath(log_path))
# Out:
# [01/500] train loss=0.612464, nmse(dB)=3.3078 | val loss=0.537381, nmse(dB)=3.1883 | 0.3s
#   ↳ saved bestc_channel_only_finetune.pt | best@1: val loss=0.537381, val nmse(dB)=3.1883
# [02/500] train loss=0.563818, nmse(dB)=2.9601 | val loss=0.495053, nmse(dB)=2.8319 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@2: val loss=0.495053, val nmse(dB)=2.8319
# [03/500] train loss=0.532247, nmse(dB)=2.6319 | val loss=0.467101, nmse(dB)=2.5794 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@3: val loss=0.467101, val nmse(dB)=2.5794
# [04/500] train loss=0.509525, nmse(dB)=2.4124 | val loss=0.447287, nmse(dB)=2.3911 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@4: val loss=0.447287, val nmse(dB)=2.3911
# [05/500] train loss=0.489487, nmse(dB)=2.2811 | val loss=0.432023, nmse(dB)=2.2402 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@5: val loss=0.432023, val nmse(dB)=2.2402
# [06/500] train loss=0.474128, nmse(dB)=2.1676 | val loss=0.418712, nmse(dB)=2.1043 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@6: val loss=0.418712, val nmse(dB)=2.1043
# [07/500] train loss=0.462118, nmse(dB)=2.0430 | val loss=0.406214, nmse(dB)=1.9726 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@7: val loss=0.406214, val nmse(dB)=1.9726
# [08/500] train loss=0.451204, nmse(dB)=1.9158 | val loss=0.394969, nmse(dB)=1.8507 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@8: val loss=0.394969, val nmse(dB)=1.8507
# [09/500] train loss=0.439676, nmse(dB)=1.8054 | val loss=0.384705, nmse(dB)=1.7363 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@9: val loss=0.384705, val nmse(dB)=1.7363
# [10/500] train loss=0.428190, nmse(dB)=1.7125 | val loss=0.374816, nmse(dB)=1.6232 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@10: val loss=0.374816, val nmse(dB)=1.6232
# [11/500] train loss=0.416261, nmse(dB)=1.6360 | val loss=0.364912, nmse(dB)=1.5068 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@11: val loss=0.364912, val nmse(dB)=1.5068
# [12/500] train loss=0.407588, nmse(dB)=1.5152 | val loss=0.354862, nmse(dB)=1.3855 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@12: val loss=0.354862, val nmse(dB)=1.3855
# [13/500] train loss=0.398011, nmse(dB)=1.3764 | val loss=0.344724, nmse(dB)=1.2595 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@13: val loss=0.344724, val nmse(dB)=1.2595
# [14/500] train loss=0.387811, nmse(dB)=1.2700 | val loss=0.334804, nmse(dB)=1.1327 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@14: val loss=0.334804, val nmse(dB)=1.1327
# [15/500] train loss=0.376047, nmse(dB)=1.1950 | val loss=0.325278, nmse(dB)=1.0072 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@15: val loss=0.325278, val nmse(dB)=1.0072
# [16/500] train loss=0.370807, nmse(dB)=1.0686 | val loss=0.316080, nmse(dB)=0.8826 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@16: val loss=0.316080, val nmse(dB)=0.8826
# [17/500] train loss=0.358520, nmse(dB)=0.9509 | val loss=0.307025, nmse(dB)=0.7563 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@17: val loss=0.307025, val nmse(dB)=0.7563
# [18/500] train loss=0.348119, nmse(dB)=0.8184 | val loss=0.298225, nmse(dB)=0.6299 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@18: val loss=0.298225, val nmse(dB)=0.6299
# [19/500] train loss=0.342927, nmse(dB)=0.7260 | val loss=0.289658, nmse(dB)=0.5032 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@19: val loss=0.289658, val nmse(dB)=0.5032
# [20/500] train loss=0.330934, nmse(dB)=0.6039 | val loss=0.281252, nmse(dB)=0.3752 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@20: val loss=0.281252, val nmse(dB)=0.3752
# [21/500] train loss=0.326016, nmse(dB)=0.4865 | val loss=0.272996, nmse(dB)=0.2457 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@21: val loss=0.272996, val nmse(dB)=0.2457
# [22/500] train loss=0.315826, nmse(dB)=0.3927 | val loss=0.264883, nmse(dB)=0.1146 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@22: val loss=0.264883, val nmse(dB)=0.1146
# [23/500] train loss=0.308615, nmse(dB)=0.2746 | val loss=0.256956, nmse(dB)=-0.0175 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@23: val loss=0.256956, val nmse(dB)=-0.0175
# [24/500] train loss=0.300807, nmse(dB)=0.1579 | val loss=0.249218, nmse(dB)=-0.1504 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@24: val loss=0.249218, val nmse(dB)=-0.1504
# [25/500] train loss=0.294204, nmse(dB)=0.0292 | val loss=0.241679, nmse(dB)=-0.2839 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@25: val loss=0.241679, val nmse(dB)=-0.2839
# [26/500] train loss=0.282991, nmse(dB)=-0.0500 | val loss=0.234309, nmse(dB)=-0.4185 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@26: val loss=0.234309, val nmse(dB)=-0.4185
# [27/500] train loss=0.278877, nmse(dB)=-0.1919 | val loss=0.227130, nmse(dB)=-0.5538 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@27: val loss=0.227130, val nmse(dB)=-0.5538
# [28/500] train loss=0.269538, nmse(dB)=-0.2747 | val loss=0.220189, nmse(dB)=-0.6887 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@28: val loss=0.220189, val nmse(dB)=-0.6887
# [29/500] train loss=0.266209, nmse(dB)=-0.4183 | val loss=0.213502, nmse(dB)=-0.8229 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@29: val loss=0.213502, val nmse(dB)=-0.8229
# [30/500] train loss=0.256468, nmse(dB)=-0.5178 | val loss=0.206941, nmse(dB)=-0.9586 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@30: val loss=0.206941, val nmse(dB)=-0.9586
# [31/500] train loss=0.250483, nmse(dB)=-0.6072 | val loss=0.200521, nmse(dB)=-1.0956 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@31: val loss=0.200521, val nmse(dB)=-1.0956
# [32/500] train loss=0.242360, nmse(dB)=-0.7522 | val loss=0.194307, nmse(dB)=-1.2326 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@32: val loss=0.194307, val nmse(dB)=-1.2326
# [33/500] train loss=0.237063, nmse(dB)=-0.8575 | val loss=0.188347, nmse(dB)=-1.3681 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@33: val loss=0.188347, val nmse(dB)=-1.3681
# [34/500] train loss=0.229926, nmse(dB)=-0.9520 | val loss=0.182543, nmse(dB)=-1.5043 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@34: val loss=0.182543, val nmse(dB)=-1.5043
# [35/500] train loss=0.226669, nmse(dB)=-1.1016 | val loss=0.176845, nmse(dB)=-1.6422 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@35: val loss=0.176845, val nmse(dB)=-1.6422
# [36/500] train loss=0.219448, nmse(dB)=-1.2012 | val loss=0.171309, nmse(dB)=-1.7806 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@36: val loss=0.171309, val nmse(dB)=-1.7806
# [37/500] train loss=0.215549, nmse(dB)=-1.3252 | val loss=0.166011, nmse(dB)=-1.9173 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@37: val loss=0.166011, val nmse(dB)=-1.9173
# [38/500] train loss=0.208418, nmse(dB)=-1.4373 | val loss=0.160876, nmse(dB)=-2.0541 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@38: val loss=0.160876, val nmse(dB)=-2.0541
# [39/500] train loss=0.204330, nmse(dB)=-1.5255 | val loss=0.155870, nmse(dB)=-2.1917 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@39: val loss=0.155870, val nmse(dB)=-2.1917
# [40/500] train loss=0.197309, nmse(dB)=-1.6415 | val loss=0.150968, nmse(dB)=-2.3308 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@40: val loss=0.150968, val nmse(dB)=-2.3308
# [41/500] train loss=0.194642, nmse(dB)=-1.7414 | val loss=0.146224, nmse(dB)=-2.4698 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@41: val loss=0.146224, val nmse(dB)=-2.4698
# [42/500] train loss=0.192397, nmse(dB)=-1.8437 | val loss=0.141650, nmse(dB)=-2.6082 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@42: val loss=0.141650, val nmse(dB)=-2.6082
# [43/500] train loss=0.187129, nmse(dB)=-1.9896 | val loss=0.137244, nmse(dB)=-2.7459 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@43: val loss=0.137244, val nmse(dB)=-2.7459
# [44/500] train loss=0.181311, nmse(dB)=-2.0944 | val loss=0.133024, nmse(dB)=-2.8820 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@44: val loss=0.133024, val nmse(dB)=-2.8820
# [45/500] train loss=0.177133, nmse(dB)=-2.1907 | val loss=0.128900, nmse(dB)=-3.0192 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@45: val loss=0.128900, val nmse(dB)=-3.0192
# [46/500] train loss=0.173552, nmse(dB)=-2.2837 | val loss=0.124845, nmse(dB)=-3.1585 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@46: val loss=0.124845, val nmse(dB)=-3.1585
# [47/500] train loss=0.168094, nmse(dB)=-2.3757 | val loss=0.120887, nmse(dB)=-3.2989 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@47: val loss=0.120887, val nmse(dB)=-3.2989
# [48/500] train loss=0.162342, nmse(dB)=-2.5018 | val loss=0.117122, nmse(dB)=-3.4369 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@48: val loss=0.117122, val nmse(dB)=-3.4369
# [49/500] train loss=0.159650, nmse(dB)=-2.5713 | val loss=0.113514, nmse(dB)=-3.5734 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@49: val loss=0.113514, val nmse(dB)=-3.5734
# [50/500] train loss=0.156374, nmse(dB)=-2.7164 | val loss=0.110023, nmse(dB)=-3.7097 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@50: val loss=0.110023, val nmse(dB)=-3.7097
# [51/500] train loss=0.153479, nmse(dB)=-2.8077 | val loss=0.106624, nmse(dB)=-3.8467 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@51: val loss=0.106624, val nmse(dB)=-3.8467
# [52/500] train loss=0.149167, nmse(dB)=-2.8562 | val loss=0.103335, nmse(dB)=-3.9835 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@52: val loss=0.103335, val nmse(dB)=-3.9835
# [53/500] train loss=0.145840, nmse(dB)=-3.0371 | val loss=0.100187, nmse(dB)=-4.1186 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@53: val loss=0.100187, val nmse(dB)=-4.1186
# [54/500] train loss=0.143104, nmse(dB)=-3.0905 | val loss=0.097134, nmse(dB)=-4.2538 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@54: val loss=0.097134, val nmse(dB)=-4.2538
# [55/500] train loss=0.139680, nmse(dB)=-3.1572 | val loss=0.094131, nmse(dB)=-4.3910 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@55: val loss=0.094131, val nmse(dB)=-4.3910
# [56/500] train loss=0.138164, nmse(dB)=-3.2612 | val loss=0.091277, nmse(dB)=-4.5256 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@56: val loss=0.091277, val nmse(dB)=-4.5256
# [57/500] train loss=0.135506, nmse(dB)=-3.3249 | val loss=0.088547, nmse(dB)=-4.6585 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@57: val loss=0.088547, val nmse(dB)=-4.6585
# [58/500] train loss=0.131541, nmse(dB)=-3.4615 | val loss=0.085885, nmse(dB)=-4.7921 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@58: val loss=0.085885, val nmse(dB)=-4.7921
# [59/500] train loss=0.128864, nmse(dB)=-3.5313 | val loss=0.083338, nmse(dB)=-4.9239 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@59: val loss=0.083338, val nmse(dB)=-4.9239
# [60/500] train loss=0.126227, nmse(dB)=-3.6694 | val loss=0.080897, nmse(dB)=-5.0541 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@60: val loss=0.080897, val nmse(dB)=-5.0541
# [61/500] train loss=0.123660, nmse(dB)=-3.8044 | val loss=0.078449, nmse(dB)=-5.1887 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@61: val loss=0.078449, val nmse(dB)=-5.1887
# [62/500] train loss=0.120565, nmse(dB)=-3.8122 | val loss=0.076096, nmse(dB)=-5.3223 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@62: val loss=0.076096, val nmse(dB)=-5.3223
# [63/500] train loss=0.118702, nmse(dB)=-3.9350 | val loss=0.073859, nmse(dB)=-5.4533 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@63: val loss=0.073859, val nmse(dB)=-5.4533
# [64/500] train loss=0.118460, nmse(dB)=-4.0164 | val loss=0.071669, nmse(dB)=-5.5855 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@64: val loss=0.071669, val nmse(dB)=-5.5855
# [65/500] train loss=0.114253, nmse(dB)=-4.1083 | val loss=0.069549, nmse(dB)=-5.7175 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@65: val loss=0.069549, val nmse(dB)=-5.7175
# [66/500] train loss=0.111524, nmse(dB)=-4.2098 | val loss=0.067506, nmse(dB)=-5.8486 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@66: val loss=0.067506, val nmse(dB)=-5.8486
# [67/500] train loss=0.112668, nmse(dB)=-4.2130 | val loss=0.065542, nmse(dB)=-5.9785 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@67: val loss=0.065542, val nmse(dB)=-5.9785
# [68/500] train loss=0.107958, nmse(dB)=-4.3526 | val loss=0.063682, nmse(dB)=-6.1052 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@68: val loss=0.063682, val nmse(dB)=-6.1052
# [69/500] train loss=0.104764, nmse(dB)=-4.4374 | val loss=0.061896, nmse(dB)=-6.2306 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@69: val loss=0.061896, val nmse(dB)=-6.2306
# [70/500] train loss=0.104043, nmse(dB)=-4.5104 | val loss=0.060125, nmse(dB)=-6.3587 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@70: val loss=0.060125, val nmse(dB)=-6.3587
# [71/500] train loss=0.103467, nmse(dB)=-4.5761 | val loss=0.058408, nmse(dB)=-6.4866 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@71: val loss=0.058408, val nmse(dB)=-6.4866
# [72/500] train loss=0.101939, nmse(dB)=-4.6069 | val loss=0.056775, nmse(dB)=-6.6119 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@72: val loss=0.056775, val nmse(dB)=-6.6119
# [73/500] train loss=0.100966, nmse(dB)=-4.7036 | val loss=0.055212, nmse(dB)=-6.7356 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@73: val loss=0.055212, val nmse(dB)=-6.7356
# [74/500] train loss=0.098458, nmse(dB)=-4.8085 | val loss=0.053666, nmse(dB)=-6.8613 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@74: val loss=0.053666, val nmse(dB)=-6.8613
# [75/500] train loss=0.096816, nmse(dB)=-4.8762 | val loss=0.052209, nmse(dB)=-6.9834 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@75: val loss=0.052209, val nmse(dB)=-6.9834
# [76/500] train loss=0.096177, nmse(dB)=-4.9021 | val loss=0.050794, nmse(dB)=-7.1054 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@76: val loss=0.050794, val nmse(dB)=-7.1054
# [77/500] train loss=0.093200, nmse(dB)=-5.0025 | val loss=0.049410, nmse(dB)=-7.2282 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@77: val loss=0.049410, val nmse(dB)=-7.2282
# [78/500] train loss=0.091582, nmse(dB)=-5.0940 | val loss=0.048069, nmse(dB)=-7.3506 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@78: val loss=0.048069, val nmse(dB)=-7.3506
# [79/500] train loss=0.091224, nmse(dB)=-5.1468 | val loss=0.046788, nmse(dB)=-7.4710 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@79: val loss=0.046788, val nmse(dB)=-7.4710
# [80/500] train loss=0.090712, nmse(dB)=-5.2132 | val loss=0.045574, nmse(dB)=-7.5884 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@80: val loss=0.045574, val nmse(dB)=-7.5884
# [81/500] train loss=0.087300, nmse(dB)=-5.3182 | val loss=0.044424, nmse(dB)=-7.7026 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@81: val loss=0.044424, val nmse(dB)=-7.7026
# [82/500] train loss=0.086742, nmse(dB)=-5.3757 | val loss=0.043319, nmse(dB)=-7.8153 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@82: val loss=0.043319, val nmse(dB)=-7.8153
# [83/500] train loss=0.085650, nmse(dB)=-5.4349 | val loss=0.042181, nmse(dB)=-7.9346 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@83: val loss=0.042181, val nmse(dB)=-7.9346
# [84/500] train loss=0.084529, nmse(dB)=-5.4912 | val loss=0.041080, nmse(dB)=-8.0536 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@84: val loss=0.041080, val nmse(dB)=-8.0536
# [85/500] train loss=0.082680, nmse(dB)=-5.5596 | val loss=0.040079, nmse(dB)=-8.1647 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@85: val loss=0.040079, val nmse(dB)=-8.1647
# [86/500] train loss=0.082379, nmse(dB)=-5.6199 | val loss=0.039117, nmse(dB)=-8.2744 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@86: val loss=0.039117, val nmse(dB)=-8.2744
# [87/500] train loss=0.081354, nmse(dB)=-5.6114 | val loss=0.038141, nmse(dB)=-8.3887 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@87: val loss=0.038141, val nmse(dB)=-8.3887
# [88/500] train loss=0.080806, nmse(dB)=-5.7067 | val loss=0.037197, nmse(dB)=-8.5022 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@88: val loss=0.037197, val nmse(dB)=-8.5022
# [89/500] train loss=0.081490, nmse(dB)=-5.6537 | val loss=0.036344, nmse(dB)=-8.6074 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@89: val loss=0.036344, val nmse(dB)=-8.6074
# [90/500] train loss=0.077964, nmse(dB)=-5.8762 | val loss=0.035535, nmse(dB)=-8.7097 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@90: val loss=0.035535, val nmse(dB)=-8.7097
# [91/500] train loss=0.079248, nmse(dB)=-5.7655 | val loss=0.034705, nmse(dB)=-8.8172 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@91: val loss=0.034705, val nmse(dB)=-8.8172
# [92/500] train loss=0.077395, nmse(dB)=-5.9508 | val loss=0.033895, nmse(dB)=-8.9250 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@92: val loss=0.033895, val nmse(dB)=-8.9250
# [93/500] train loss=0.077532, nmse(dB)=-5.9502 | val loss=0.033142, nmse(dB)=-9.0279 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@93: val loss=0.033142, val nmse(dB)=-9.0279
# [94/500] train loss=0.076760, nmse(dB)=-5.9572 | val loss=0.032422, nmse(dB)=-9.1288 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@94: val loss=0.032422, val nmse(dB)=-9.1288
# [95/500] train loss=0.074449, nmse(dB)=-6.0739 | val loss=0.031681, nmse(dB)=-9.2352 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@95: val loss=0.031681, val nmse(dB)=-9.2352
# [96/500] train loss=0.075060, nmse(dB)=-6.0462 | val loss=0.030965, nmse(dB)=-9.3405 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@96: val loss=0.030965, val nmse(dB)=-9.3405
# [97/500] train loss=0.073596, nmse(dB)=-6.1062 | val loss=0.030301, nmse(dB)=-9.4405 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@97: val loss=0.030301, val nmse(dB)=-9.4405
# [98/500] train loss=0.072122, nmse(dB)=-6.2433 | val loss=0.029680, nmse(dB)=-9.5363 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@98: val loss=0.029680, val nmse(dB)=-9.5363
# [99/500] train loss=0.072830, nmse(dB)=-6.2249 | val loss=0.029057, nmse(dB)=-9.6351 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@99: val loss=0.029057, val nmse(dB)=-9.6351
# [100/500] train loss=0.072294, nmse(dB)=-6.2612 | val loss=0.028435, nmse(dB)=-9.7364 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@100: val loss=0.028435, val nmse(dB)=-9.7364
# [101/500] train loss=0.071717, nmse(dB)=-6.2722 | val loss=0.027846, nmse(dB)=-9.8348 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@101: val loss=0.027846, val nmse(dB)=-9.8348
# [102/500] train loss=0.070185, nmse(dB)=-6.3640 | val loss=0.027292, nmse(dB)=-9.9296 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@102: val loss=0.027292, val nmse(dB)=-9.9296
# [103/500] train loss=0.069537, nmse(dB)=-6.4173 | val loss=0.026770, nmse(dB)=-10.0206 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@103: val loss=0.026770, val nmse(dB)=-10.0206
# [104/500] train loss=0.067557, nmse(dB)=-6.5389 | val loss=0.026241, nmse(dB)=-10.1148 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@104: val loss=0.026241, val nmse(dB)=-10.1148
# [105/500] train loss=0.068560, nmse(dB)=-6.5538 | val loss=0.025725, nmse(dB)=-10.2088 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@105: val loss=0.025725, val nmse(dB)=-10.2088
# [106/500] train loss=0.068354, nmse(dB)=-6.5144 | val loss=0.025241, nmse(dB)=-10.2987 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@106: val loss=0.025241, val nmse(dB)=-10.2987
# [107/500] train loss=0.068730, nmse(dB)=-6.5275 | val loss=0.024777, nmse(dB)=-10.3871 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@107: val loss=0.024777, val nmse(dB)=-10.3871
# [108/500] train loss=0.067720, nmse(dB)=-6.5747 | val loss=0.024319, nmse(dB)=-10.4767 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@108: val loss=0.024319, val nmse(dB)=-10.4767
# [109/500] train loss=0.068374, nmse(dB)=-6.5419 | val loss=0.023888, nmse(dB)=-10.5632 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@109: val loss=0.023888, val nmse(dB)=-10.5632
# [110/500] train loss=0.065688, nmse(dB)=-6.7626 | val loss=0.023483, nmse(dB)=-10.6462 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@110: val loss=0.023483, val nmse(dB)=-10.6462
# [111/500] train loss=0.066154, nmse(dB)=-6.6448 | val loss=0.023063, nmse(dB)=-10.7340 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@111: val loss=0.023063, val nmse(dB)=-10.7340
# [112/500] train loss=0.067009, nmse(dB)=-6.6534 | val loss=0.022643, nmse(dB)=-10.8239 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@112: val loss=0.022643, val nmse(dB)=-10.8239
# [113/500] train loss=0.067817, nmse(dB)=-6.6288 | val loss=0.022263, nmse(dB)=-10.9068 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@113: val loss=0.022263, val nmse(dB)=-10.9068
# [114/500] train loss=0.065243, nmse(dB)=-6.7986 | val loss=0.021917, nmse(dB)=-10.9837 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@114: val loss=0.021917, val nmse(dB)=-10.9837
# [115/500] train loss=0.063554, nmse(dB)=-6.8111 | val loss=0.021580, nmse(dB)=-11.0602 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@115: val loss=0.021580, val nmse(dB)=-11.0602
# [116/500] train loss=0.066518, nmse(dB)=-6.7439 | val loss=0.021243, nmse(dB)=-11.1386 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@116: val loss=0.021243, val nmse(dB)=-11.1386
# [117/500] train loss=0.064556, nmse(dB)=-6.8378 | val loss=0.020921, nmse(dB)=-11.2150 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@117: val loss=0.020921, val nmse(dB)=-11.2150
# [118/500] train loss=0.062665, nmse(dB)=-6.9487 | val loss=0.020625, nmse(dB)=-11.2864 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@118: val loss=0.020625, val nmse(dB)=-11.2864
# [119/500] train loss=0.063143, nmse(dB)=-6.9229 | val loss=0.020340, nmse(dB)=-11.3563 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@119: val loss=0.020340, val nmse(dB)=-11.3563
# [120/500] train loss=0.063229, nmse(dB)=-6.9672 | val loss=0.020043, nmse(dB)=-11.4304 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@120: val loss=0.020043, val nmse(dB)=-11.4304
# [121/500] train loss=0.064515, nmse(dB)=-6.9187 | val loss=0.019743, nmse(dB)=-11.5067 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@121: val loss=0.019743, val nmse(dB)=-11.5067
# [122/500] train loss=0.062548, nmse(dB)=-7.0410 | val loss=0.019435, nmse(dB)=-11.5871 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@122: val loss=0.019435, val nmse(dB)=-11.5871
# [123/500] train loss=0.063089, nmse(dB)=-7.0045 | val loss=0.019182, nmse(dB)=-11.6545 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@123: val loss=0.019182, val nmse(dB)=-11.6545
# [124/500] train loss=0.060415, nmse(dB)=-7.0821 | val loss=0.018929, nmse(dB)=-11.7237 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@124: val loss=0.018929, val nmse(dB)=-11.7237
# [125/500] train loss=0.060110, nmse(dB)=-7.1703 | val loss=0.018660, nmse(dB)=-11.7977 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@125: val loss=0.018660, val nmse(dB)=-11.7977
# [126/500] train loss=0.063052, nmse(dB)=-6.9463 | val loss=0.018425, nmse(dB)=-11.8643 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@126: val loss=0.018425, val nmse(dB)=-11.8643
# [127/500] train loss=0.061709, nmse(dB)=-7.0720 | val loss=0.018223, nmse(dB)=-11.9220 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@127: val loss=0.018223, val nmse(dB)=-11.9220
# [128/500] train loss=0.059808, nmse(dB)=-7.1629 | val loss=0.018011, nmse(dB)=-11.9835 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@128: val loss=0.018011, val nmse(dB)=-11.9835
# [129/500] train loss=0.059937, nmse(dB)=-7.2175 | val loss=0.017785, nmse(dB)=-12.0497 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@129: val loss=0.017785, val nmse(dB)=-12.0497
# [130/500] train loss=0.060084, nmse(dB)=-7.1365 | val loss=0.017580, nmse(dB)=-12.1110 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@130: val loss=0.017580, val nmse(dB)=-12.1110
# [131/500] train loss=0.058775, nmse(dB)=-7.2593 | val loss=0.017362, nmse(dB)=-12.1775 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@131: val loss=0.017362, val nmse(dB)=-12.1775
# [132/500] train loss=0.060036, nmse(dB)=-7.2013 | val loss=0.017149, nmse(dB)=-12.2443 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@132: val loss=0.017149, val nmse(dB)=-12.2443
# [133/500] train loss=0.059506, nmse(dB)=-7.1981 | val loss=0.016962, nmse(dB)=-12.3046 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@133: val loss=0.016962, val nmse(dB)=-12.3046
# [134/500] train loss=0.058592, nmse(dB)=-7.2891 | val loss=0.016807, nmse(dB)=-12.3552 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@134: val loss=0.016807, val nmse(dB)=-12.3552
# [135/500] train loss=0.061122, nmse(dB)=-7.1605 | val loss=0.016642, nmse(dB)=-12.4090 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@135: val loss=0.016642, val nmse(dB)=-12.4090
# [136/500] train loss=0.057778, nmse(dB)=-7.3485 | val loss=0.016450, nmse(dB)=-12.4727 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@136: val loss=0.016450, val nmse(dB)=-12.4727
# [137/500] train loss=0.059156, nmse(dB)=-7.2658 | val loss=0.016272, nmse(dB)=-12.5324 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@137: val loss=0.016272, val nmse(dB)=-12.5324
# [138/500] train loss=0.058154, nmse(dB)=-7.3328 | val loss=0.016116, nmse(dB)=-12.5858 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@138: val loss=0.016116, val nmse(dB)=-12.5858
# [139/500] train loss=0.058839, nmse(dB)=-7.2263 | val loss=0.015974, nmse(dB)=-12.6344 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@139: val loss=0.015974, val nmse(dB)=-12.6344
# [140/500] train loss=0.058130, nmse(dB)=-7.3270 | val loss=0.015840, nmse(dB)=-12.6816 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@140: val loss=0.015840, val nmse(dB)=-12.6816
# [141/500] train loss=0.057129, nmse(dB)=-7.3930 | val loss=0.015701, nmse(dB)=-12.7314 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@141: val loss=0.015701, val nmse(dB)=-12.7314
# [142/500] train loss=0.058291, nmse(dB)=-7.3787 | val loss=0.015551, nmse(dB)=-12.7863 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@142: val loss=0.015551, val nmse(dB)=-12.7863
# [143/500] train loss=0.057911, nmse(dB)=-7.4437 | val loss=0.015423, nmse(dB)=-12.8343 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@143: val loss=0.015423, val nmse(dB)=-12.8343
# [144/500] train loss=0.058008, nmse(dB)=-7.3870 | val loss=0.015301, nmse(dB)=-12.8807 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@144: val loss=0.015301, val nmse(dB)=-12.8807
# [145/500] train loss=0.056767, nmse(dB)=-7.4757 | val loss=0.015163, nmse(dB)=-12.9329 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@145: val loss=0.015163, val nmse(dB)=-12.9329
# [146/500] train loss=0.055922, nmse(dB)=-7.4622 | val loss=0.015021, nmse(dB)=-12.9878 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@146: val loss=0.015021, val nmse(dB)=-12.9878
# [147/500] train loss=0.058384, nmse(dB)=-7.3526 | val loss=0.014893, nmse(dB)=-13.0388 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@147: val loss=0.014893, val nmse(dB)=-13.0388
# [148/500] train loss=0.057277, nmse(dB)=-7.4788 | val loss=0.014805, nmse(dB)=-13.0752 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@148: val loss=0.014805, val nmse(dB)=-13.0752
# [149/500] train loss=0.056522, nmse(dB)=-7.4860 | val loss=0.014725, nmse(dB)=-13.1078 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@149: val loss=0.014725, val nmse(dB)=-13.1078
# [150/500] train loss=0.055329, nmse(dB)=-7.6174 | val loss=0.014651, nmse(dB)=-13.1379 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@150: val loss=0.014651, val nmse(dB)=-13.1379
# [151/500] train loss=0.058887, nmse(dB)=-7.3862 | val loss=0.014551, nmse(dB)=-13.1780 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@151: val loss=0.014551, val nmse(dB)=-13.1780
# [152/500] train loss=0.056366, nmse(dB)=-7.4662 | val loss=0.014461, nmse(dB)=-13.2142 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@152: val loss=0.014461, val nmse(dB)=-13.2142
# [153/500] train loss=0.057823, nmse(dB)=-7.4655 | val loss=0.014375, nmse(dB)=-13.2490 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@153: val loss=0.014375, val nmse(dB)=-13.2490
# [154/500] train loss=0.055311, nmse(dB)=-7.6174 | val loss=0.014261, nmse(dB)=-13.2970 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@154: val loss=0.014261, val nmse(dB)=-13.2970
# [155/500] train loss=0.056617, nmse(dB)=-7.4892 | val loss=0.014161, nmse(dB)=-13.3400 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@155: val loss=0.014161, val nmse(dB)=-13.3400
# [156/500] train loss=0.057403, nmse(dB)=-7.4775 | val loss=0.014088, nmse(dB)=-13.3722 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@156: val loss=0.014088, val nmse(dB)=-13.3722
# [157/500] train loss=0.057436, nmse(dB)=-7.4830 | val loss=0.013977, nmse(dB)=-13.4208 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@157: val loss=0.013977, val nmse(dB)=-13.4208
# [158/500] train loss=0.055181, nmse(dB)=-7.5601 | val loss=0.013882, nmse(dB)=-13.4632 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@158: val loss=0.013882, val nmse(dB)=-13.4632
# [159/500] train loss=0.057248, nmse(dB)=-7.4519 | val loss=0.013799, nmse(dB)=-13.5010 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@159: val loss=0.013799, val nmse(dB)=-13.5010
# [160/500] train loss=0.054984, nmse(dB)=-7.5727 | val loss=0.013736, nmse(dB)=-13.5304 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@160: val loss=0.013736, val nmse(dB)=-13.5304
# [161/500] train loss=0.058419, nmse(dB)=-7.4404 | val loss=0.013658, nmse(dB)=-13.5666 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@161: val loss=0.013658, val nmse(dB)=-13.5666
# [162/500] train loss=0.054892, nmse(dB)=-7.6263 | val loss=0.013569, nmse(dB)=-13.6083 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@162: val loss=0.013569, val nmse(dB)=-13.6083
# [163/500] train loss=0.054820, nmse(dB)=-7.6244 | val loss=0.013492, nmse(dB)=-13.6448 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@163: val loss=0.013492, val nmse(dB)=-13.6448
# [164/500] train loss=0.056227, nmse(dB)=-7.5439 | val loss=0.013435, nmse(dB)=-13.6728 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@164: val loss=0.013435, val nmse(dB)=-13.6728
# [165/500] train loss=0.056071, nmse(dB)=-7.6448 | val loss=0.013379, nmse(dB)=-13.7006 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@165: val loss=0.013379, val nmse(dB)=-13.7006
# [166/500] train loss=0.057443, nmse(dB)=-7.4100 | val loss=0.013306, nmse(dB)=-13.7375 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@166: val loss=0.013306, val nmse(dB)=-13.7375
# [167/500] train loss=0.058229, nmse(dB)=-7.4581 | val loss=0.013247, nmse(dB)=-13.7674 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@167: val loss=0.013247, val nmse(dB)=-13.7674
# [168/500] train loss=0.056542, nmse(dB)=-7.5348 | val loss=0.013202, nmse(dB)=-13.7910 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@168: val loss=0.013202, val nmse(dB)=-13.7910
# [169/500] train loss=0.054370, nmse(dB)=-7.7051 | val loss=0.013144, nmse(dB)=-13.8209 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@169: val loss=0.013144, val nmse(dB)=-13.8209
# [170/500] train loss=0.054479, nmse(dB)=-7.6979 | val loss=0.013082, nmse(dB)=-13.8521 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@170: val loss=0.013082, val nmse(dB)=-13.8521
# [171/500] train loss=0.055018, nmse(dB)=-7.6526 | val loss=0.013018, nmse(dB)=-13.8840 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@171: val loss=0.013018, val nmse(dB)=-13.8840
# [172/500] train loss=0.056084, nmse(dB)=-7.6220 | val loss=0.012955, nmse(dB)=-13.9156 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@172: val loss=0.012955, val nmse(dB)=-13.9156
# [173/500] train loss=0.054776, nmse(dB)=-7.6698 | val loss=0.012890, nmse(dB)=-13.9485 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@173: val loss=0.012890, val nmse(dB)=-13.9485
# [174/500] train loss=0.055229, nmse(dB)=-7.6323 | val loss=0.012838, nmse(dB)=-13.9754 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@174: val loss=0.012838, val nmse(dB)=-13.9754
# [175/500] train loss=0.053706, nmse(dB)=-7.7521 | val loss=0.012788, nmse(dB)=-14.0022 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@175: val loss=0.012788, val nmse(dB)=-14.0022
# [176/500] train loss=0.054084, nmse(dB)=-7.7646 | val loss=0.012741, nmse(dB)=-14.0267 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@176: val loss=0.012741, val nmse(dB)=-14.0267
# [177/500] train loss=0.056290, nmse(dB)=-7.5820 | val loss=0.012707, nmse(dB)=-14.0448 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@177: val loss=0.012707, val nmse(dB)=-14.0448
# [178/500] train loss=0.055278, nmse(dB)=-7.6043 | val loss=0.012676, nmse(dB)=-14.0622 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@178: val loss=0.012676, val nmse(dB)=-14.0622
# [179/500] train loss=0.054345, nmse(dB)=-7.6878 | val loss=0.012631, nmse(dB)=-14.0879 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@179: val loss=0.012631, val nmse(dB)=-14.0879
# [180/500] train loss=0.055168, nmse(dB)=-7.6146 | val loss=0.012565, nmse(dB)=-14.1254 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@180: val loss=0.012565, val nmse(dB)=-14.1254
# [181/500] train loss=0.054506, nmse(dB)=-7.7115 | val loss=0.012510, nmse(dB)=-14.1566 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@181: val loss=0.012510, val nmse(dB)=-14.1566
# [182/500] train loss=0.056362, nmse(dB)=-7.5677 | val loss=0.012472, nmse(dB)=-14.1787 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@182: val loss=0.012472, val nmse(dB)=-14.1787
# [183/500] train loss=0.052444, nmse(dB)=-7.8363 | val loss=0.012448, nmse(dB)=-14.1920 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@183: val loss=0.012448, val nmse(dB)=-14.1920
# [184/500] train loss=0.054733, nmse(dB)=-7.6465 | val loss=0.012433, nmse(dB)=-14.2005 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@184: val loss=0.012433, val nmse(dB)=-14.2005
# [185/500] train loss=0.054371, nmse(dB)=-7.6954 | val loss=0.012422, nmse(dB)=-14.2070 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@185: val loss=0.012422, val nmse(dB)=-14.2070
# [186/500] train loss=0.054032, nmse(dB)=-7.7574 | val loss=0.012394, nmse(dB)=-14.2230 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@186: val loss=0.012394, val nmse(dB)=-14.2230
# [187/500] train loss=0.055111, nmse(dB)=-7.7089 | val loss=0.012358, nmse(dB)=-14.2437 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@187: val loss=0.012358, val nmse(dB)=-14.2437
# [188/500] train loss=0.055114, nmse(dB)=-7.7092 | val loss=0.012331, nmse(dB)=-14.2600 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@188: val loss=0.012331, val nmse(dB)=-14.2600
# [189/500] train loss=0.052900, nmse(dB)=-7.8443 | val loss=0.012305, nmse(dB)=-14.2755 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@189: val loss=0.012305, val nmse(dB)=-14.2755
# [190/500] train loss=0.053078, nmse(dB)=-7.7728 | val loss=0.012267, nmse(dB)=-14.2970 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@190: val loss=0.012267, val nmse(dB)=-14.2970
# [191/500] train loss=0.053795, nmse(dB)=-7.7895 | val loss=0.012219, nmse(dB)=-14.3251 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@191: val loss=0.012219, val nmse(dB)=-14.3251
# [192/500] train loss=0.053576, nmse(dB)=-7.7621 | val loss=0.012178, nmse(dB)=-14.3483 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@192: val loss=0.012178, val nmse(dB)=-14.3483
# [193/500] train loss=0.055743, nmse(dB)=-7.6584 | val loss=0.012152, nmse(dB)=-14.3635 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@193: val loss=0.012152, val nmse(dB)=-14.3635
# [194/500] train loss=0.053212, nmse(dB)=-7.7767 | val loss=0.012127, nmse(dB)=-14.3787 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@194: val loss=0.012127, val nmse(dB)=-14.3787
# [195/500] train loss=0.054002, nmse(dB)=-7.7586 | val loss=0.012095, nmse(dB)=-14.3988 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@195: val loss=0.012095, val nmse(dB)=-14.3988
# [196/500] train loss=0.054541, nmse(dB)=-7.7118 | val loss=0.012065, nmse(dB)=-14.4173 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@196: val loss=0.012065, val nmse(dB)=-14.4173
# [197/500] train loss=0.054646, nmse(dB)=-7.7622 | val loss=0.012032, nmse(dB)=-14.4373 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@197: val loss=0.012032, val nmse(dB)=-14.4373
# [198/500] train loss=0.053273, nmse(dB)=-7.8007 | val loss=0.011992, nmse(dB)=-14.4614 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@198: val loss=0.011992, val nmse(dB)=-14.4614
# [199/500] train loss=0.051607, nmse(dB)=-7.9541 | val loss=0.011957, nmse(dB)=-14.4821 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@199: val loss=0.011957, val nmse(dB)=-14.4821
# [200/500] train loss=0.053754, nmse(dB)=-7.7489 | val loss=0.011938, nmse(dB)=-14.4932 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@200: val loss=0.011938, val nmse(dB)=-14.4932
# [201/500] train loss=0.053308, nmse(dB)=-7.7358 | val loss=0.011926, nmse(dB)=-14.5006 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@201: val loss=0.011926, val nmse(dB)=-14.5006
# [202/500] train loss=0.053326, nmse(dB)=-7.8260 | val loss=0.011907, nmse(dB)=-14.5141 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@202: val loss=0.011907, val nmse(dB)=-14.5141
# [203/500] train loss=0.053217, nmse(dB)=-7.8256 | val loss=0.011895, nmse(dB)=-14.5232 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@203: val loss=0.011895, val nmse(dB)=-14.5232
# [204/500] train loss=0.053102, nmse(dB)=-7.8338 | val loss=0.011874, nmse(dB)=-14.5383 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@204: val loss=0.011874, val nmse(dB)=-14.5383
# [205/500] train loss=0.053039, nmse(dB)=-7.8715 | val loss=0.011842, nmse(dB)=-14.5598 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@205: val loss=0.011842, val nmse(dB)=-14.5598
# [206/500] train loss=0.054563, nmse(dB)=-7.7245 | val loss=0.011826, nmse(dB)=-14.5705 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@206: val loss=0.011826, val nmse(dB)=-14.5705
# [207/500] train loss=0.053434, nmse(dB)=-7.7813 | val loss=0.011812, nmse(dB)=-14.5793 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@207: val loss=0.011812, val nmse(dB)=-14.5793
# [208/500] train loss=0.052555, nmse(dB)=-7.9179 | val loss=0.011788, nmse(dB)=-14.5946 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@208: val loss=0.011788, val nmse(dB)=-14.5946
# [209/500] train loss=0.051992, nmse(dB)=-7.9403 | val loss=0.011784, nmse(dB)=-14.5969 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@209: val loss=0.011784, val nmse(dB)=-14.5969
# [210/500] train loss=0.051674, nmse(dB)=-7.9954 | val loss=0.011783, nmse(dB)=-14.5964 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@210: val loss=0.011783, val nmse(dB)=-14.5964
# [211/500] train loss=0.053065, nmse(dB)=-7.8183 | val loss=0.011765, nmse(dB)=-14.6074 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@211: val loss=0.011765, val nmse(dB)=-14.6074
# [212/500] train loss=0.053128, nmse(dB)=-7.8588 | val loss=0.011751, nmse(dB)=-14.6163 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@212: val loss=0.011751, val nmse(dB)=-14.6163
# [213/500] train loss=0.052566, nmse(dB)=-7.9081 | val loss=0.011734, nmse(dB)=-14.6288 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@213: val loss=0.011734, val nmse(dB)=-14.6288
# [214/500] train loss=0.053408, nmse(dB)=-7.8541 | val loss=0.011719, nmse(dB)=-14.6399 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@214: val loss=0.011719, val nmse(dB)=-14.6399
# [215/500] train loss=0.054278, nmse(dB)=-7.7143 | val loss=0.011698, nmse(dB)=-14.6548 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@215: val loss=0.011698, val nmse(dB)=-14.6548
# [216/500] train loss=0.051396, nmse(dB)=-7.9259 | val loss=0.011678, nmse(dB)=-14.6692 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@216: val loss=0.011678, val nmse(dB)=-14.6692
# [217/500] train loss=0.053629, nmse(dB)=-7.7869 | val loss=0.011673, nmse(dB)=-14.6740 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@217: val loss=0.011673, val nmse(dB)=-14.6740
# [218/500] train loss=0.052195, nmse(dB)=-7.9155 | val loss=0.011672, nmse(dB)=-14.6756 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@218: val loss=0.011672, val nmse(dB)=-14.6756
# [219/500] train loss=0.054469, nmse(dB)=-7.7251 | val loss=0.011660, nmse(dB)=-14.6849 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@219: val loss=0.011660, val nmse(dB)=-14.6849
# [220/500] train loss=0.052404, nmse(dB)=-7.9241 | val loss=0.011639, nmse(dB)=-14.6997 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@220: val loss=0.011639, val nmse(dB)=-14.6997
# [221/500] train loss=0.052286, nmse(dB)=-7.8861 | val loss=0.011621, nmse(dB)=-14.7122 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@221: val loss=0.011621, val nmse(dB)=-14.7122
# [222/500] train loss=0.052943, nmse(dB)=-7.8196 | val loss=0.011608, nmse(dB)=-14.7223 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@222: val loss=0.011608, val nmse(dB)=-14.7223
# [223/500] train loss=0.053345, nmse(dB)=-7.7910 | val loss=0.011592, nmse(dB)=-14.7343 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@223: val loss=0.011592, val nmse(dB)=-14.7343
# [224/500] train loss=0.051876, nmse(dB)=-7.9231 | val loss=0.011593, nmse(dB)=-14.7343 | 0.1s
# [225/500] train loss=0.053012, nmse(dB)=-7.8759 | val loss=0.011609, nmse(dB)=-14.7235 | 0.1s
# [226/500] train loss=0.054264, nmse(dB)=-7.7275 | val loss=0.011582, nmse(dB)=-14.7417 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@226: val loss=0.011582, val nmse(dB)=-14.7417
# [227/500] train loss=0.051989, nmse(dB)=-7.9515 | val loss=0.011553, nmse(dB)=-14.7603 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@227: val loss=0.011553, val nmse(dB)=-14.7603
# [228/500] train loss=0.052624, nmse(dB)=-7.8229 | val loss=0.011533, nmse(dB)=-14.7733 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@228: val loss=0.011533, val nmse(dB)=-14.7733
# [229/500] train loss=0.053234, nmse(dB)=-7.8534 | val loss=0.011520, nmse(dB)=-14.7826 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@229: val loss=0.011520, val nmse(dB)=-14.7826
# [230/500] train loss=0.053656, nmse(dB)=-7.7979 | val loss=0.011515, nmse(dB)=-14.7869 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@230: val loss=0.011515, val nmse(dB)=-14.7869
# [231/500] train loss=0.052250, nmse(dB)=-7.9166 | val loss=0.011515, nmse(dB)=-14.7870 | 0.1s
# [232/500] train loss=0.053120, nmse(dB)=-7.8317 | val loss=0.011511, nmse(dB)=-14.7903 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@232: val loss=0.011511, val nmse(dB)=-14.7903
# [233/500] train loss=0.053845, nmse(dB)=-7.8165 | val loss=0.011515, nmse(dB)=-14.7859 | 0.1s
# [234/500] train loss=0.051710, nmse(dB)=-7.9502 | val loss=0.011511, nmse(dB)=-14.7871 | 0.1s
# [235/500] train loss=0.053379, nmse(dB)=-7.8562 | val loss=0.011489, nmse(dB)=-14.8009 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@235: val loss=0.011489, val nmse(dB)=-14.8009
# [236/500] train loss=0.052494, nmse(dB)=-7.9058 | val loss=0.011472, nmse(dB)=-14.8109 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@236: val loss=0.011472, val nmse(dB)=-14.8109
# [237/500] train loss=0.050499, nmse(dB)=-7.9856 | val loss=0.011466, nmse(dB)=-14.8157 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@237: val loss=0.011466, val nmse(dB)=-14.8157
# [238/500] train loss=0.051588, nmse(dB)=-7.8771 | val loss=0.011458, nmse(dB)=-14.8225 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@238: val loss=0.011458, val nmse(dB)=-14.8225
# [239/500] train loss=0.052212, nmse(dB)=-7.8637 | val loss=0.011463, nmse(dB)=-14.8215 | 0.1s
# [240/500] train loss=0.052362, nmse(dB)=-7.8976 | val loss=0.011466, nmse(dB)=-14.8213 | 0.1s
# [241/500] train loss=0.052851, nmse(dB)=-7.8803 | val loss=0.011463, nmse(dB)=-14.8248 | 0.1s
# [242/500] train loss=0.052526, nmse(dB)=-7.8305 | val loss=0.011447, nmse(dB)=-14.8375 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@242: val loss=0.011447, val nmse(dB)=-14.8375
# [243/500] train loss=0.050902, nmse(dB)=-8.0110 | val loss=0.011427, nmse(dB)=-14.8524 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@243: val loss=0.011427, val nmse(dB)=-14.8524
# [244/500] train loss=0.053353, nmse(dB)=-7.8521 | val loss=0.011414, nmse(dB)=-14.8617 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@244: val loss=0.011414, val nmse(dB)=-14.8617
# [245/500] train loss=0.052576, nmse(dB)=-7.9055 | val loss=0.011422, nmse(dB)=-14.8548 | 0.1s
# [246/500] train loss=0.053815, nmse(dB)=-7.7511 | val loss=0.011422, nmse(dB)=-14.8522 | 0.1s
# [247/500] train loss=0.054168, nmse(dB)=-7.8011 | val loss=0.011412, nmse(dB)=-14.8582 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@247: val loss=0.011412, val nmse(dB)=-14.8582
# [248/500] train loss=0.052988, nmse(dB)=-7.8375 | val loss=0.011403, nmse(dB)=-14.8641 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@248: val loss=0.011403, val nmse(dB)=-14.8641
# [249/500] train loss=0.052180, nmse(dB)=-7.8549 | val loss=0.011390, nmse(dB)=-14.8731 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@249: val loss=0.011390, val nmse(dB)=-14.8731
# [250/500] train loss=0.053695, nmse(dB)=-7.7879 | val loss=0.011382, nmse(dB)=-14.8799 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@250: val loss=0.011382, val nmse(dB)=-14.8799
# [251/500] train loss=0.052357, nmse(dB)=-7.9267 | val loss=0.011384, nmse(dB)=-14.8797 | 0.1s
# [252/500] train loss=0.051165, nmse(dB)=-7.9840 | val loss=0.011384, nmse(dB)=-14.8819 | 0.1s
# [253/500] train loss=0.052455, nmse(dB)=-7.8415 | val loss=0.011384, nmse(dB)=-14.8853 | 0.1s
# [254/500] train loss=0.053168, nmse(dB)=-7.9047 | val loss=0.011384, nmse(dB)=-14.8863 | 0.1s
# [255/500] train loss=0.052565, nmse(dB)=-7.8688 | val loss=0.011383, nmse(dB)=-14.8870 | 0.1s
# [256/500] train loss=0.053011, nmse(dB)=-7.9028 | val loss=0.011363, nmse(dB)=-14.9011 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@256: val loss=0.011363, val nmse(dB)=-14.9011
# [257/500] train loss=0.051318, nmse(dB)=-7.9907 | val loss=0.011333, nmse(dB)=-14.9240 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@257: val loss=0.011333, val nmse(dB)=-14.9240
# [258/500] train loss=0.053115, nmse(dB)=-7.8383 | val loss=0.011311, nmse(dB)=-14.9406 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@258: val loss=0.011311, val nmse(dB)=-14.9406
# [259/500] train loss=0.051196, nmse(dB)=-7.9818 | val loss=0.011297, nmse(dB)=-14.9509 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@259: val loss=0.011297, val nmse(dB)=-14.9509
# [260/500] train loss=0.052189, nmse(dB)=-7.9364 | val loss=0.011292, nmse(dB)=-14.9523 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@260: val loss=0.011292, val nmse(dB)=-14.9523
# [261/500] train loss=0.053525, nmse(dB)=-7.7656 | val loss=0.011296, nmse(dB)=-14.9478 | 0.1s
# [262/500] train loss=0.051682, nmse(dB)=-7.9783 | val loss=0.011297, nmse(dB)=-14.9461 | 0.1s
# [263/500] train loss=0.051363, nmse(dB)=-7.9900 | val loss=0.011290, nmse(dB)=-14.9512 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@263: val loss=0.011290, val nmse(dB)=-14.9512
# [264/500] train loss=0.053557, nmse(dB)=-7.8134 | val loss=0.011289, nmse(dB)=-14.9532 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@264: val loss=0.011289, val nmse(dB)=-14.9532
# [265/500] train loss=0.052373, nmse(dB)=-7.8633 | val loss=0.011285, nmse(dB)=-14.9573 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@265: val loss=0.011285, val nmse(dB)=-14.9573
# [266/500] train loss=0.053197, nmse(dB)=-7.8277 | val loss=0.011280, nmse(dB)=-14.9621 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@266: val loss=0.011280, val nmse(dB)=-14.9621
# ...
# [369/500] train loss=0.051572, nmse(dB)=-8.0432 | val loss=0.011104, nmse(dB)=-15.1042 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@369: val loss=0.011104, val nmse(dB)=-15.1042
# [370/500] train loss=0.052230, nmse(dB)=-7.9801 | val loss=0.011101, nmse(dB)=-15.1069 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@370: val loss=0.011101, val nmse(dB)=-15.1069
# [371/500] train loss=0.050735, nmse(dB)=-8.0599 | val loss=0.011096, nmse(dB)=-15.1104 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@371: val loss=0.011096, val nmse(dB)=-15.1104
# [372/500] train loss=0.051604, nmse(dB)=-8.0125 | val loss=0.011092, nmse(dB)=-15.1127 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@372: val loss=0.011092, val nmse(dB)=-15.1127
# [373/500] train loss=0.052247, nmse(dB)=-7.9605 | val loss=0.011092, nmse(dB)=-15.1128 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@373: val loss=0.011092, val nmse(dB)=-15.1128
# [374/500] train loss=0.051231, nmse(dB)=-7.9695 | val loss=0.011090, nmse(dB)=-15.1137 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@374: val loss=0.011090, val nmse(dB)=-15.1137
# [375/500] train loss=0.052041, nmse(dB)=-7.9818 | val loss=0.011092, nmse(dB)=-15.1124 | 0.1s
# [376/500] train loss=0.051558, nmse(dB)=-7.9990 | val loss=0.011092, nmse(dB)=-15.1123 | 0.1s
# [377/500] train loss=0.051938, nmse(dB)=-7.9369 | val loss=0.011090, nmse(dB)=-15.1139 | 0.1s
# [378/500] train loss=0.050663, nmse(dB)=-8.0482 | val loss=0.011088, nmse(dB)=-15.1156 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@378: val loss=0.011088, val nmse(dB)=-15.1156
# [379/500] train loss=0.049934, nmse(dB)=-8.0853 | val loss=0.011089, nmse(dB)=-15.1150 | 0.1s
# [380/500] train loss=0.053583, nmse(dB)=-7.8444 | val loss=0.011092, nmse(dB)=-15.1127 | 0.1s
# [381/500] train loss=0.052364, nmse(dB)=-7.9635 | val loss=0.011092, nmse(dB)=-15.1120 | 0.1s
# [382/500] train loss=0.050267, nmse(dB)=-8.0914 | val loss=0.011090, nmse(dB)=-15.1136 | 0.1s
# [383/500] train loss=0.053642, nmse(dB)=-7.8296 | val loss=0.011089, nmse(dB)=-15.1152 | 0.1s
# [384/500] train loss=0.052253, nmse(dB)=-7.8852 | val loss=0.011088, nmse(dB)=-15.1157 | 0.1s
# [385/500] train loss=0.051656, nmse(dB)=-7.9340 | val loss=0.011090, nmse(dB)=-15.1149 | 0.1s
# [386/500] train loss=0.052984, nmse(dB)=-7.8833 | val loss=0.011093, nmse(dB)=-15.1134 | 0.1s
# [387/500] train loss=0.052725, nmse(dB)=-7.9231 | val loss=0.011097, nmse(dB)=-15.1108 | 0.1s
# [388/500] train loss=0.053261, nmse(dB)=-7.8788 | val loss=0.011098, nmse(dB)=-15.1102 | 0.1s
# [389/500] train loss=0.050322, nmse(dB)=-8.0944 | val loss=0.011098, nmse(dB)=-15.1113 | 0.1s
# [390/500] train loss=0.051613, nmse(dB)=-8.0083 | val loss=0.011097, nmse(dB)=-15.1121 | 0.1s
# [391/500] train loss=0.050879, nmse(dB)=-8.0321 | val loss=0.011097, nmse(dB)=-15.1119 | 0.1s
# [392/500] train loss=0.052775, nmse(dB)=-7.8644 | val loss=0.011097, nmse(dB)=-15.1125 | 0.1s
# [393/500] train loss=0.052348, nmse(dB)=-7.8537 | val loss=0.011097, nmse(dB)=-15.1125 | 0.1s
# [394/500] train loss=0.050679, nmse(dB)=-8.0070 | val loss=0.011097, nmse(dB)=-15.1120 | 0.1s
# [395/500] train loss=0.050608, nmse(dB)=-8.0547 | val loss=0.011099, nmse(dB)=-15.1107 | 0.1s
# [396/500] train loss=0.050990, nmse(dB)=-7.9747 | val loss=0.011101, nmse(dB)=-15.1092 | 0.1s
# [397/500] train loss=0.053797, nmse(dB)=-7.8660 | val loss=0.011102, nmse(dB)=-15.1081 | 0.1s
# [398/500] train loss=0.053262, nmse(dB)=-7.8273 | val loss=0.011103, nmse(dB)=-15.1072 | 0.1s
# [399/500] train loss=0.051532, nmse(dB)=-7.9555 | val loss=0.011105, nmse(dB)=-15.1062 | 0.1s
# [400/500] train loss=0.053489, nmse(dB)=-7.8626 | val loss=0.011104, nmse(dB)=-15.1063 | 0.1s
# [401/500] train loss=0.051458, nmse(dB)=-7.9959 | val loss=0.011102, nmse(dB)=-15.1074 | 0.1s
# [402/500] train loss=0.052445, nmse(dB)=-7.9692 | val loss=0.011101, nmse(dB)=-15.1078 | 0.1s
# [403/500] train loss=0.054741, nmse(dB)=-7.7392 | val loss=0.011101, nmse(dB)=-15.1072 | 0.1s
# [404/500] train loss=0.051942, nmse(dB)=-7.9431 | val loss=0.011102, nmse(dB)=-15.1067 | 0.1s
# [405/500] train loss=0.053492, nmse(dB)=-7.8555 | val loss=0.011102, nmse(dB)=-15.1064 | 0.1s
# [406/500] train loss=0.051448, nmse(dB)=-8.0544 | val loss=0.011104, nmse(dB)=-15.1041 | 0.1s
# [407/500] train loss=0.052683, nmse(dB)=-7.9056 | val loss=0.011106, nmse(dB)=-15.1023 | 0.1s
# [408/500] train loss=0.051583, nmse(dB)=-7.9671 | val loss=0.011107, nmse(dB)=-15.1014 | 0.1s
# [409/500] train loss=0.052402, nmse(dB)=-7.9548 | val loss=0.011108, nmse(dB)=-15.1012 | 0.1s
# [410/500] train loss=0.053330, nmse(dB)=-7.9259 | val loss=0.011106, nmse(dB)=-15.1025 | 0.1s
# [411/500] train loss=0.052513, nmse(dB)=-7.8654 | val loss=0.011105, nmse(dB)=-15.1036 | 0.1s
# [412/500] train loss=0.051021, nmse(dB)=-8.0790 | val loss=0.011103, nmse(dB)=-15.1051 | 0.1s
# [413/500] train loss=0.051314, nmse(dB)=-7.9976 | val loss=0.011101, nmse(dB)=-15.1069 | 0.1s
# [414/500] train loss=0.050443, nmse(dB)=-8.0594 | val loss=0.011100, nmse(dB)=-15.1085 | 0.1s
# [415/500] train loss=0.052255, nmse(dB)=-7.9234 | val loss=0.011097, nmse(dB)=-15.1103 | 0.1s
# [416/500] train loss=0.051346, nmse(dB)=-8.0146 | val loss=0.011096, nmse(dB)=-15.1116 | 0.1s
# [417/500] train loss=0.051874, nmse(dB)=-7.9726 | val loss=0.011095, nmse(dB)=-15.1125 | 0.1s
# [418/500] train loss=0.050003, nmse(dB)=-8.0972 | val loss=0.011094, nmse(dB)=-15.1134 | 0.1s
# [419/500] train loss=0.051660, nmse(dB)=-7.9673 | val loss=0.011093, nmse(dB)=-15.1142 | 0.1s
# [420/500] train loss=0.052130, nmse(dB)=-8.0256 | val loss=0.011093, nmse(dB)=-15.1141 | 0.1s
# [421/500] train loss=0.051382, nmse(dB)=-8.0376 | val loss=0.011094, nmse(dB)=-15.1137 | 0.1s
# [422/500] train loss=0.050935, nmse(dB)=-8.0283 | val loss=0.011093, nmse(dB)=-15.1141 | 0.1s
# [423/500] train loss=0.053049, nmse(dB)=-7.8764 | val loss=0.011092, nmse(dB)=-15.1151 | 0.1s
# [424/500] train loss=0.051381, nmse(dB)=-7.9717 | val loss=0.011090, nmse(dB)=-15.1166 | 0.1s
# [425/500] train loss=0.051652, nmse(dB)=-7.9703 | val loss=0.011089, nmse(dB)=-15.1177 | 0.1s
# [426/500] train loss=0.051780, nmse(dB)=-7.9833 | val loss=0.011088, nmse(dB)=-15.1182 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@426: val loss=0.011088, val nmse(dB)=-15.1182
# [427/500] train loss=0.052064, nmse(dB)=-7.9543 | val loss=0.011088, nmse(dB)=-15.1177 | 0.1s
# [428/500] train loss=0.051486, nmse(dB)=-7.9886 | val loss=0.011089, nmse(dB)=-15.1169 | 0.1s
# [429/500] train loss=0.050725, nmse(dB)=-8.0952 | val loss=0.011090, nmse(dB)=-15.1163 | 0.1s
# [430/500] train loss=0.053766, nmse(dB)=-7.8144 | val loss=0.011090, nmse(dB)=-15.1164 | 0.1s
# [431/500] train loss=0.051484, nmse(dB)=-7.9837 | val loss=0.011089, nmse(dB)=-15.1167 | 0.1s
# [432/500] train loss=0.052785, nmse(dB)=-7.9432 | val loss=0.011089, nmse(dB)=-15.1170 | 0.1s
# [433/500] train loss=0.052143, nmse(dB)=-7.9268 | val loss=0.011089, nmse(dB)=-15.1175 | 0.1s
# [434/500] train loss=0.051805, nmse(dB)=-7.9074 | val loss=0.011088, nmse(dB)=-15.1182 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@434: val loss=0.011088, val nmse(dB)=-15.1182
# [435/500] train loss=0.050754, nmse(dB)=-8.0870 | val loss=0.011087, nmse(dB)=-15.1189 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@435: val loss=0.011087, val nmse(dB)=-15.1189
# [436/500] train loss=0.051426, nmse(dB)=-8.0288 | val loss=0.011086, nmse(dB)=-15.1201 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@436: val loss=0.011086, val nmse(dB)=-15.1201
# [437/500] train loss=0.052491, nmse(dB)=-7.9168 | val loss=0.011085, nmse(dB)=-15.1208 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@437: val loss=0.011085, val nmse(dB)=-15.1208
# [438/500] train loss=0.051625, nmse(dB)=-7.9474 | val loss=0.011084, nmse(dB)=-15.1216 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@438: val loss=0.011084, val nmse(dB)=-15.1216
# [439/500] train loss=0.050817, nmse(dB)=-8.0344 | val loss=0.011084, nmse(dB)=-15.1214 | 0.1s
# [440/500] train loss=0.052094, nmse(dB)=-7.9461 | val loss=0.011084, nmse(dB)=-15.1215 | 0.1s
# [441/500] train loss=0.052004, nmse(dB)=-7.9942 | val loss=0.011084, nmse(dB)=-15.1217 | 0.1s
# [442/500] train loss=0.050631, nmse(dB)=-8.0301 | val loss=0.011084, nmse(dB)=-15.1217 | 0.1s
# [443/500] train loss=0.050680, nmse(dB)=-8.0542 | val loss=0.011084, nmse(dB)=-15.1216 | 0.1s
# [444/500] train loss=0.051629, nmse(dB)=-7.9991 | val loss=0.011084, nmse(dB)=-15.1218 | 0.1s
# [445/500] train loss=0.053579, nmse(dB)=-7.8274 | val loss=0.011084, nmse(dB)=-15.1217 | 0.1s
# [446/500] train loss=0.052231, nmse(dB)=-7.9836 | val loss=0.011084, nmse(dB)=-15.1214 | 0.1s
# [447/500] train loss=0.054172, nmse(dB)=-7.8295 | val loss=0.011084, nmse(dB)=-15.1214 | 0.1s
# [448/500] train loss=0.050936, nmse(dB)=-8.0375 | val loss=0.011084, nmse(dB)=-15.1213 | 0.1s
# [449/500] train loss=0.052575, nmse(dB)=-7.9891 | val loss=0.011084, nmse(dB)=-15.1214 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@449: val loss=0.011084, val nmse(dB)=-15.1214
# [450/500] train loss=0.052636, nmse(dB)=-7.9223 | val loss=0.011083, nmse(dB)=-15.1217 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@450: val loss=0.011083, val nmse(dB)=-15.1217
# [451/500] train loss=0.051241, nmse(dB)=-7.9889 | val loss=0.011083, nmse(dB)=-15.1222 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@451: val loss=0.011083, val nmse(dB)=-15.1222
# [452/500] train loss=0.051010, nmse(dB)=-8.0552 | val loss=0.011082, nmse(dB)=-15.1225 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@452: val loss=0.011082, val nmse(dB)=-15.1225
# [453/500] train loss=0.051144, nmse(dB)=-8.0692 | val loss=0.011082, nmse(dB)=-15.1226 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@453: val loss=0.011082, val nmse(dB)=-15.1226
# [454/500] train loss=0.051716, nmse(dB)=-7.9805 | val loss=0.011082, nmse(dB)=-15.1227 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@454: val loss=0.011082, val nmse(dB)=-15.1227
# [455/500] train loss=0.051961, nmse(dB)=-7.9777 | val loss=0.011081, nmse(dB)=-15.1227 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@455: val loss=0.011081, val nmse(dB)=-15.1227
# [456/500] train loss=0.053589, nmse(dB)=-7.8032 | val loss=0.011081, nmse(dB)=-15.1229 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@456: val loss=0.011081, val nmse(dB)=-15.1229
# [457/500] train loss=0.053435, nmse(dB)=-7.8591 | val loss=0.011081, nmse(dB)=-15.1230 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@457: val loss=0.011081, val nmse(dB)=-15.1230
# [458/500] train loss=0.050328, nmse(dB)=-8.0964 | val loss=0.011081, nmse(dB)=-15.1231 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@458: val loss=0.011081, val nmse(dB)=-15.1231
# [459/500] train loss=0.050448, nmse(dB)=-8.0684 | val loss=0.011081, nmse(dB)=-15.1233 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@459: val loss=0.011081, val nmse(dB)=-15.1233
# [460/500] train loss=0.053169, nmse(dB)=-7.8553 | val loss=0.011080, nmse(dB)=-15.1236 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@460: val loss=0.011080, val nmse(dB)=-15.1236
# [461/500] train loss=0.050481, nmse(dB)=-8.0551 | val loss=0.011080, nmse(dB)=-15.1239 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@461: val loss=0.011080, val nmse(dB)=-15.1239
# [462/500] train loss=0.050665, nmse(dB)=-8.0563 | val loss=0.011080, nmse(dB)=-15.1241 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@462: val loss=0.011080, val nmse(dB)=-15.1241
# [463/500] train loss=0.049952, nmse(dB)=-8.0897 | val loss=0.011079, nmse(dB)=-15.1243 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@463: val loss=0.011079, val nmse(dB)=-15.1243
# [464/500] train loss=0.051249, nmse(dB)=-8.0061 | val loss=0.011079, nmse(dB)=-15.1245 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@464: val loss=0.011079, val nmse(dB)=-15.1245
# [465/500] train loss=0.052885, nmse(dB)=-7.9781 | val loss=0.011079, nmse(dB)=-15.1246 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@465: val loss=0.011079, val nmse(dB)=-15.1246
# [466/500] train loss=0.051173, nmse(dB)=-7.9819 | val loss=0.011079, nmse(dB)=-15.1247 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@466: val loss=0.011079, val nmse(dB)=-15.1247
# [467/500] train loss=0.051518, nmse(dB)=-7.9884 | val loss=0.011079, nmse(dB)=-15.1247 | 0.1s
# [468/500] train loss=0.052187, nmse(dB)=-7.8972 | val loss=0.011079, nmse(dB)=-15.1247 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@468: val loss=0.011079, val nmse(dB)=-15.1247
# [469/500] train loss=0.050263, nmse(dB)=-8.0961 | val loss=0.011079, nmse(dB)=-15.1248 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@469: val loss=0.011079, val nmse(dB)=-15.1248
# [470/500] train loss=0.050986, nmse(dB)=-8.0148 | val loss=0.011079, nmse(dB)=-15.1248 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@470: val loss=0.011079, val nmse(dB)=-15.1248
# [471/500] train loss=0.051564, nmse(dB)=-8.0134 | val loss=0.011079, nmse(dB)=-15.1248 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@471: val loss=0.011079, val nmse(dB)=-15.1248
# [472/500] train loss=0.051822, nmse(dB)=-8.0025 | val loss=0.011079, nmse(dB)=-15.1249 | 0.1s
#   ↳ saved bestc_channel_only_finetune.pt | best@472: val loss=0.011079, val nmse(dB)=-15.1249
# [473/500] train loss=0.052301, nmse(dB)=-7.9559 | val loss=0.011079, nmse(dB)=-15.1249 | 0.1s
# [474/500] train loss=0.051634, nmse(dB)=-7.9913 | val loss=0.011079, nmse(dB)=-15.1248 | 0.1s
# [475/500] train loss=0.051756, nmse(dB)=-7.9381 | val loss=0.011079, nmse(dB)=-15.1247 | 0.1s
# [476/500] train loss=0.051521, nmse(dB)=-7.9823 | val loss=0.011079, nmse(dB)=-15.1247 | 0.1s
# [477/500] train loss=0.049773, nmse(dB)=-8.1454 | val loss=0.011079, nmse(dB)=-15.1246 | 0.1s
# [478/500] train loss=0.051983, nmse(dB)=-7.8933 | val loss=0.011079, nmse(dB)=-15.1246 | 0.1s
# [479/500] train loss=0.053507, nmse(dB)=-7.8469 | val loss=0.011079, nmse(dB)=-15.1246 | 0.1s
# [480/500] train loss=0.051710, nmse(dB)=-7.9803 | val loss=0.011079, nmse(dB)=-15.1246 | 0.1s
# [481/500] train loss=0.052696, nmse(dB)=-7.9057 | val loss=0.011079, nmse(dB)=-15.1245 | 0.1s
# [482/500] train loss=0.052546, nmse(dB)=-7.9335 | val loss=0.011079, nmse(dB)=-15.1245 | 0.1s
# [483/500] train loss=0.052706, nmse(dB)=-7.9290 | val loss=0.011079, nmse(dB)=-15.1245 | 0.1s
# [484/500] train loss=0.051457, nmse(dB)=-8.0025 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [485/500] train loss=0.051418, nmse(dB)=-7.9957 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [486/500] train loss=0.052298, nmse(dB)=-7.8922 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [487/500] train loss=0.052053, nmse(dB)=-7.9165 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [488/500] train loss=0.054028, nmse(dB)=-7.8446 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [489/500] train loss=0.053125, nmse(dB)=-7.8229 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [490/500] train loss=0.051221, nmse(dB)=-7.9987 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [491/500] train loss=0.050467, nmse(dB)=-8.1049 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [492/500] train loss=0.051584, nmse(dB)=-8.0104 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [493/500] train loss=0.053524, nmse(dB)=-7.8522 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [494/500] train loss=0.051730, nmse(dB)=-7.9893 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [495/500] train loss=0.050713, nmse(dB)=-8.0451 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [496/500] train loss=0.053327, nmse(dB)=-7.8353 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [497/500] train loss=0.050345, nmse(dB)=-8.0764 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [498/500] train loss=0.052519, nmse(dB)=-7.9136 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [499/500] train loss=0.049904, nmse(dB)=-8.1322 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
# [500/500] train loss=0.051470, nmse(dB)=-7.9395 | val loss=0.011079, nmse(dB)=-15.1244 | 0.1s
#
# === Training Summary ===
# Total time: 85.9s (0h 1m 25.9s)
# Best epoch: 472 | best val loss=0.011079, best val nmse(dB)=-15.1249
# Log saved to: /mnt/ssd_7t_2/Deepverse/lwm_model2_scene101_1.txt

# %% [markdown]
# # 런타임 체크

# %%
ch, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model(ch.to(device))   
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# y abs mean: 0.49504685401916504
# y abs max : 0.9746403694152832
# y power   : 0.29220959544181824
# yhat abs mean: 0.4936506152153015
# yhat abs max : 0.578630805015564
# yhat power   : 0.2443271428346634

# %%
y
# Out:
# tensor([[0.5688, 0.5617, 0.5533,  ..., 0.2597, 0.2638, 0.2657],
#         [0.1854, 0.1761, 0.1672,  ..., 0.4462, 0.4248, 0.4031],
#         [0.3995, 0.3835, 0.3678,  ..., 0.9678, 0.9600, 0.9489],
#         ...,
#         [0.4504, 0.4602, 0.4715,  ..., 0.4261, 0.4091, 0.3911],
#         [0.6039, 0.5822, 0.5604,  ..., 0.2329, 0.2328, 0.2335],
#         [0.3173, 0.2997, 0.2824,  ..., 0.9147, 0.9237, 0.9295]],
#        device='cuda:1')

# %%
yhat[0:10, 0:10]
# Out:
# tensor([[0.5580, 0.5640, 0.5593, 0.5596, 0.5633, 0.5603, 0.5559, 0.5620, 0.5628,
#          0.5615],
#         [0.5629, 0.5564, 0.5669, 0.5555, 0.5515, 0.5680, 0.5650, 0.5569, 0.5596,
#          0.5598],
#         [0.5634, 0.5624, 0.5538, 0.5546, 0.5619, 0.5595, 0.5579, 0.5555, 0.5620,
#          0.5575],
#         [0.5606, 0.5633, 0.5616, 0.5601, 0.5602, 0.5619, 0.5594, 0.5614, 0.5624,
#          0.5622],
#         [0.5618, 0.5616, 0.5640, 0.5584, 0.5596, 0.5662, 0.5610, 0.5637, 0.5642,
#          0.5622],
#         [0.5609, 0.5625, 0.5611, 0.5598, 0.5617, 0.5618, 0.5595, 0.5612, 0.5632,
#          0.5616],
#         [0.5665, 0.5585, 0.5642, 0.5593, 0.5585, 0.5702, 0.5601, 0.5650, 0.5658,
#          0.5574],
#         [0.5599, 0.5646, 0.5548, 0.5602, 0.5772, 0.5517, 0.5561, 0.5619, 0.5638,
#          0.5599],
#         [0.5590, 0.5631, 0.5632, 0.5593, 0.5602, 0.5618, 0.5597, 0.5613, 0.5615,
#          0.5628],
#         [0.5607, 0.5627, 0.5607, 0.5600, 0.5604, 0.5619, 0.5591, 0.5617, 0.5631,
#          0.5622]], device='cuda:1')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 데이터 입력 형태

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("past_len      :", ds.past_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

print("\n=== one batch shapes ===")
ch, y = next(iter(train_loader))
print("ch :", tuple(ch.shape), " -> (B,T,F_in)")
print("y  :", tuple(y.shape), " -> (B,F_out)")
with torch.no_grad():
    yhat = model(ch.to(device))
print("yhat:", tuple(yhat.shape), " -> (B,F_out)")
print("this forward predicted vectors:", yhat.shape[0], "(=B)")
print("each vector predicts elements:", yhat.shape[1], "(=F_out)")
# Out:
# === dataset sizes ===
# N(comm_frames): 101
# past_len      : 16
# len(ds)       : 85
# len(train_ds) : 51
# len(val_ds)   : 17
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B,T,F_in)
# y  : (32, 2048)  -> (B,F_out)
# yhat: (32, 2048)  -> (B,F_out)
# this forward predicted vectors: 32 (=B)
# each vector predicts elements: 2048 (=F_out)
