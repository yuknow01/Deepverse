# %% [markdown]
# # 주의사항
# <br> 1. 실행 전 사용할 수 있는 gpu 확인하기
# <br> 2. scene 몇개로 설정한것인지 정하기
# <br> 3. 결과를 저장하는 log path 이름 잘 바꾸기

# %% [markdown]
# # lwm1
# <br>모델 크기 차이에 따른 성능 차이 비교
# <br> element_length=64, d_model=128
# <br> in_proj: F_in(2048) → 512 → 256 → 64

# %% [markdown]
# # Import

# %%
import os
import sys

import numpy as  np
from transformer1 import CSIFormer
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset as TorchDataset, DataLoader, Subset
import torch.nn as nn   
import time



from PIL import Image
import numpy as np

from deepverse import ParameterManager
from deepverse.scenario import ScenarioManager
from deepverse import Dataset

from deepverse.visualizers import ImageVisualizer, LidarVisualizer

# %% [markdown]
# # Setting
# ### CUDA 몇번 사용하는지 잘 확인하기

# %%
# Scenes 1000
## Subcarriers 64

scenarios_name = "DT31"
config_path = f"scenarios/{scenarios_name}/param/config.m"
param_manager = ParameterManager(config_path)

params = param_manager.get_params()

param_manager.params["scenes"] =list(range(100))
param_manager.params["comm"]["OFDM"]["selected_subcarriers"] = list(range(64))

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"현재 사용 중인 장치: {device}")
# Out:
# 현재 사용 중인 장치: cuda:0

# %% [markdown]
# # Generate a dataset

# %%
# scenes / subcarriers는 그대로
param_manager.params["radar"]["enable"] = False

# lidar가 dict로 존재하면 disable
if isinstance(param_manager.params.get("lidar", None), dict):
    param_manager.params["lidar"]["enable"] = False

# position이 dict로 존재하면 disable
if isinstance(param_manager.params.get("position", None), dict):
    param_manager.params["position"]["enable"] = False

# Radar, LiDAR, Position 사용하지 않으므로 False 
dataset = Dataset(param_manager)
# Out:
# Generating camera dataset: ⏳ In progress
# Generating camera dataset: ✅ Completed (0.00s)
# Generating LiDAR dataset: ⏳ In progress
# Generating LiDAR dataset: ✅ Completed (0.00s)
# Generating mobility dataset: ⏳ In progress
# Generating mobility dataset: ✅ Completed (0.00s)
# Generating comm dataset: ⏳ In progress
# Generating comm dataset: ✅ Completed (0.81s)

# %% [markdown]
# # Prerocessing

# %% [markdown]
# #### Channel

# %%
def get_coeffs_from_frame(frame, ue_idx=0):
    ue_obj = frame["ue"]

    # 케이스1) list/tuple이면 ue_idx로 선택
    if isinstance(ue_obj, (list, tuple)):
        ch_obj = ue_obj[ue_idx]
    else:
        # 케이스2) 단일 OFDMChannel이면 그대로 사용
        ch_obj = ue_obj

    # coeffs는 dict key가 아니라 attribute일 확률이 매우 큼
    if hasattr(ch_obj, "coeffs"):
        return ch_obj.coeffs

    # 혹시 dict라면 마지막 보험
    if isinstance(ch_obj, dict) and "coeffs" in ch_obj:
        return ch_obj["coeffs"]

    raise TypeError(f"Cannot get coeffs. ue type={type(ue_obj)}, ch type={type(ch_obj)}")

# %%
def get_train_min_max_realimag(frames, train_idx, us_idx=0):

    rmin, rmax =  float('inf'), float('-inf')
    imin, imax =  float('inf'), float('-inf')

    print("Calculating min/max over training set...")

    for t  in train_idx:
        frame  = frames[t]
        cooeffs  = get_coeffs_from_frame(frame, us_idx)  # (N_subcarriers, )

        rmin = min(rmin, float(cooeffs.real.min()))
        rmax = max(rmax, float(cooeffs.real.max()))
        imin = min(imin, float(cooeffs.imag.min()))
        imax = max(imax, float(cooeffs.imag.max()))

    print(f"Done. rmin={rmin}, rmax={rmax}, imin={imin}, imax={imax}")
    return (rmin, rmax), (imin, imax)

# %%
def preprocess_channel_coeffs_minmax(coeffs_np, r_min, r_max, i_min, i_max, device=device, eps=1e-16):
    # Convert Numpy to Tensor
    coeffs = torch.from_numpy(coeffs_np).to(torch.complex64)
    
    
    r = coeffs.real
    i = coeffs.imag
    
    # Min-Max Scaling [0, 1]
    # Add eps to denominator to prevent division by zero
    r_scaled = (r - r_min) / max(r_max - r_min, eps)
    i_scaled = (i - i_min) / max(i_max - i_min, eps)
    
    # Concat (Maintains shape like (..., 2*subcarriers))
    H = torch.cat([r_scaled, i_scaled], dim=-1).to(device, dtype=torch.float32)
    return H

# %% [markdown]
# #### image

# %% [markdown]
# # Dataset 구현

# %%
def flatten_comm_frames(comm):
    frames = []
    for row in comm.data:
        for d in row:
            frames.append(d)
    return frames

class ChannelNextStepDatasetGPU(TorchDataset):
    def __init__(self, comm_frames, ue_idx=0, past_len=16, pre_len=4, device=device,
                 r_min=0.0, r_max=1.0, i_min=0.0, i_max=1.0):
        self.comm_frames = comm_frames
        self.ue_idx = ue_idx
        self.past_len = past_len
        # ✅ pre_len 추가 
        self.pre_len = pre_len 
        self.device = device

        self.r_min, self.r_max = r_min, r_max
        self.i_min, self.i_max = i_min, i_max

        self.N = len(self.comm_frames)
        self.valid_start = past_len - 1
        # ✅ t + pre_len 까지 필요
        self.valid_end = self.N - self.pre_len - 1

    def __len__(self):
        return self.valid_end - self.valid_start + 1

    def __getitem__(self, idx):
        t = self.valid_start + idx

        # 1) Channel Past: (T, 2048)
        ch_list = []
        for k in range(t - self.past_len + 1, t + 1):
            coeffs_np = get_coeffs_from_frame(self.comm_frames[k], ue_idx=self.ue_idx)
            h = preprocess_channel_coeffs_minmax(
                coeffs_np,
                self.r_min, self.r_max, self.i_min, self.i_max,
                device=self.device
            ).reshape(-1)  # (2048,)
            ch_list.append(h)
        channel_past = torch.stack(ch_list, dim=0)  # (past_len, 2048)

        # 2) Target Next 4: flatten -> (4*2048,)
        # target이 1이 아닌 4인 점 주의 
        tgt_list = []
        for j in range(1, self.pre_len + 1):
            coeffs_np_next = get_coeffs_from_frame(self.comm_frames[t + j], ue_idx=self.ue_idx)
            hj = preprocess_channel_coeffs_minmax(
                coeffs_np_next,
                self.r_min, self.r_max, self.i_min, self.i_max,
                device=self.device
            ).reshape(-1)  # (2048,)
            tgt_list.append(hj)

        target = torch.stack(tgt_list, dim=0)  # (pre_len, 2048)

        return channel_past, target

# %% [markdown]
# # DataLoader 구현

# %%
comm_frames = flatten_comm_frames(dataset.comm_dataset)

ds = ChannelNextStepDatasetGPU(
    comm_frames=comm_frames,
    ue_idx=0,
    past_len=16,
    pre_len=4,
    device=device
)

loader = DataLoader(
    ds,
    batch_size=8,
    shuffle=True,
    num_workers=0,     
    pin_memory=False   
)
ch, y = next(iter(loader))
print(ch.shape, y.shape)
print(ch.device, y.device)
# Out:
# torch.Size([8, 16, 2048]) torch.Size([8, 4, 2048])
# cuda:0 cuda:0

# %% [markdown]
# # Fine-tuning

# %%
import torch
import torch.nn as nn

class CSIFormerForecaster(nn.Module):
    """
    Input : ch   (B,T,F_in=2048)   where T=16
    Output: yhat (B,K,F_out=2048)  where K=out_steps (e.g., 4)

    encoder: uses past channels (T tokens)
    decoder: uses K query tokens (either repeated last token or learned queries)
    """
    def __init__(
        self,
        base,
        F_in: int,
        F_out: int,
        out_steps: int = 4,
        dec_mode: str = "learned_queries",  # "learned_queries" | "repeat_last"
        return_flat: bool = False,          # True -> (B, K*F_out)
    ):
        super().__init__()
        self.base = base
        self.out_steps = out_steps
        self.dec_mode = dec_mode
        self.return_flat = return_flat

        n_dim   = base.element_length   # 64
        d_model = base.d_model          # 128

        self.in_proj = nn.Sequential(
            nn.Linear(F_in, 512), nn.GELU(),
            nn.Linear(512, 256),  nn.GELU(),
            nn.Linear(256, n_dim),
        )

        # (B, K, d_model) -> (B, K, F_out)
        self.head = nn.Linear(d_model, F_out)

        # 쿼리를 학습시키는 방식(권장): step별로 다른 query를 줘서 K-step 출력이 서로 달라지게 만듦
        if dec_mode == "learned_queries":
            self.query = nn.Parameter(torch.randn(out_steps, n_dim))  # (K, 64)

    def forward(self, ch):
        """
        ch: (B,T,F_in)
        return:
          - if return_flat=False: (B,K,F_out)
          - else: (B,K*F_out)
        """
        B = ch.size(0)

        x = self.in_proj(ch)  # (B,T,64)

        # encoder
        enc = self.base.enc_embed(x)
        for layer in self.base.enc_layers:
            enc, _ = layer(enc)

        # decoder input (B,K,64)
        if self.dec_mode == "repeat_last":
            # last token을 K번 복제 (base.dec_embed에 positional이 있어야 step 구분 가능)
            dec_in = x[:, -1:, :].expand(B, self.out_steps, x.size(-1)).contiguous()
        elif self.dec_mode == "learned_queries":
            dec_in = self.query.unsqueeze(0).expand(B, -1, -1).contiguous()
        else:
            raise ValueError(f"Unknown dec_mode: {self.dec_mode}")

        dec = self.base.dec_embed(dec_in)
        for layer in self.base.dec_layers:
            dec, _ = layer(dec, enc)  # (B,K,d_model)

        yhat = self.head(dec)  # (B,K,F_out)

        if self.return_flat:
            return yhat.reshape(B, -1)  # (B,K*F_out)
        return yhat

# %% [markdown]
# # NMSE(dB)

# %%
@torch.no_grad()
def nmse_db(yhat: torch.Tensor, y: torch.Tensor, eps: float = 1e-16) -> torch.Tensor:
    # yhat, y: (B, pre_len, F_step)
    num = torch.sum((yhat - y) ** 2).clamp_min(eps)  # batch 전체 합
    den = torch.sum(y ** 2).clamp_min(eps)
    nmse = num / den
    return 10.0 * torch.log10(nmse)

# %% [markdown]
# # Train/val Split

# %%
# 겹치는 부분이 있는지 확인하는 함수
# Target이 1일 때만 아래 코드 작성
# def used_frames_for_ds_indices(ds, ds_indices):
#     used = set()
#     for i in ds_indices:
#         t = ds.valid_start + i
#         # inputs use [t-T+1 .. t], target uses (t+1)
#         used.update(range(t - T + 1, t + 2))
#     return used

def used_frames_for_ds_indices(ds, ds_indices):
    used = set()
    T = ds.past_len
    P = ds.pre_len
    for i in ds_indices:
        t = ds.valid_start + i
        used.update(range(t - T + 1, t + P + 1))  # [t-15 .. t+4]
    return used

# %%
n_total = len(ds)
T = ds.past_len  # = past_len
P = ds.pre_len
# ---- choose k so that train=3k, val=k and NO frame-overlap is possible ----
k_max = (n_total - (T + P - 1)) // 4
if k_max <= 0:
    raise ValueError(
        f"Not enough data for strict non-overlap 3:1. "
        f"n_total={n_total}, past_len(T)={T}. "
        f"Try increasing scenes or decreasing past_len."
    )

k = k_max               # use as much data as possible under constraints
n_val = k
n_train = 3 * k

train_idx = list(range(0, n_train))
val_idx   = list(range(n_total - n_val, n_total))

print("n_total:", n_total, "T:", T)
print("train samples:", len(train_idx), "val samples:", len(val_idx), "ratio:", len(train_idx)/len(val_idx))

# ---- min/max ONLY from train (same as your original policy) ----

# (4,2048) 이 되므로 아래 min/max 계산도 바꿔서
# ---- min/max ONLY from train, but using ALL frames used by train samples ----
train_used_frames = sorted(used_frames_for_ds_indices(ds, train_idx))  # <-- 핵심

(real_min, real_max), (imag_min, imag_max) = get_train_min_max_realimag(
    comm_frames, train_used_frames, us_idx=0
)

ds.r_min = real_min
ds.r_max = real_max
ds.i_min = imag_min
ds.i_max = imag_max

print("Dataset statistical values set in the dataset (from all train-used frames).")

train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=0)

F_in = 2048


overlap = used_frames_for_ds_indices(ds, train_idx).intersection(
          used_frames_for_ds_indices(ds, val_idx))
print("frame-overlap count:", len(overlap))
assert len(overlap) == 0, "Leakage detected: train/val share frames!"

# Verify (channel-only)
ch, y = next(iter(train_loader))
assert y.ndim == 3, f"Expected (B, pre_len, F_step), got {y.shape}"

pre_len = y.shape[1]
F_step  = y.shape[2]
F_out_total = pre_len * F_step

print("\n=== Data Check ===")
print(f"y stats | min: {y.min().item():.4f}, max: {y.max().item():.4f}")
print("If scaling worked correctly, values should be within [0, 1].")

# (선택) ch도 같이 범위 확인하고 싶으면
print(f"ch stats | min: {ch.min().item():.4f}, max: {ch.max().item():.4f}")
# Out:
# n_total: 81 T: 16
# train samples: 45 val samples: 15 ratio: 3.0
# Calculating min/max over training set...
# Done. rmin=-1.6025904539973852e-06, rmax=1.6123052658255991e-06, imin=-1.6147482377856819e-06, imax=1.5844537584687652e-06
# Dataset statistical values set in the dataset (from all train-used frames).
# frame-overlap count: 0
#
# === Data Check ===
# y stats | min: 0.1673, max: 0.8381
# If scaling worked correctly, values should be within [0, 1].
# ch stats | min: 0.0109, max: 0.9969

# %% [markdown]
# # Train/Eval 함수

# %%
# batch check
ch, y = next(iter(train_loader))
print(ch.shape, y.shape)

def train_one_epoch(model, loader, optimizer, device, grad_clip=1.0):
    model.train()
    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, y in loader:
        ch = ch.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        yhat = model(ch)                
        loss = F.mse_loss(yhat, y)
        loss.backward()

        if grad_clip and grad_clip > 0:
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        optimizer.step()

        total_loss += loss.item()
        total_nmse += nmse_db(yhat.detach(), y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)

@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.0
    total_nmse = 0.0
    n = 0

    for ch, y in loader:
        ch = ch.to(device, non_blocking=True)
        y  = y.to(device, non_blocking=True)

        yhat = model(ch)                 
        loss = F.mse_loss(yhat, y)

        total_loss += loss.item()
        total_nmse += nmse_db(yhat, y).item()
        n += 1

    return total_loss / max(n, 1), total_nmse / max(n, 1)
# Out:
# torch.Size([32, 16, 2048]) torch.Size([32, 4, 2048])

# %% [markdown]
# # 모델 생성 및 확인

# %%
# 배치 하나로 F_in/F_out 자동 확정
ch, y = next(iter(train_loader))
F_in  = ch.shape[-1]
F_out = y.shape[-1]
print("Detected:", "F_in=", F_in, "F_out=", F_out)
print("Batch devices:", ch.device, y.device)

backbone = CSIFormer().to(device)

model = CSIFormerForecaster(
    base=backbone,
    F_in=F_in,
    F_out=F_out,
    out_steps=ds.pre_len,          # = 4
    dec_mode="learned_queries",
    return_flat=False
).to(device)

# sanity forward
model.eval()
with torch.no_grad():
    # ds가 이미 cuda 텐서 반환이면 아래 .to(device) 생략 가능
    yhat = model(ch.to(device))
print("yhat:", yhat.shape, "y:", y.shape)
# Out:
# Detected: F_in= 2048 F_out= 2048
# Batch devices: cuda:0 cuda:0
# yhat: torch.Size([32, 4, 2048]) y: torch.Size([32, 4, 2048])

# %% [markdown]
# # Optimizer/Scheduler 설정

# %%
# requires_grad=True인 파라미터만 학습
trainable_params = [p for p in model.parameters() if p.requires_grad]
print("trainable params:", sum(p.numel() for p in trainable_params))

optimizer = torch.optim.AdamW(trainable_params, lr=1e-4, weight_decay=1e-4)

# (선택) cosine scheduler
epochs = 500
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
# Out:
# trainable params: 7073920

# %% [markdown]
# # 학습 루프 및 checkpoint 저장

# %%
import time
import os
import torch

best_val = float("inf")
best_val_nmse = None
best_epoch = None

t_train0 = time.time()

log_path = "transformer1_scene100_v1.txt"

with open(log_path, "w", encoding="utf-8") as f:
    for epoch in range(1, epochs + 1):
        t0 = time.time()

        tr_loss, tr_nmse = train_one_epoch(
            model, train_loader, optimizer, device=device, grad_clip=1.0
        )
        va_loss, va_nmse = evaluate(model, val_loader, device=device)

        scheduler.step()
        dt = time.time() - t0

        line = (
            f"[{epoch:02d}/{epochs}] "
            f"train loss={tr_loss:.6f}, nmse(dB)={tr_nmse:.4f} | "
            f"val loss={va_loss:.6f}, nmse(dB)={va_nmse:.4f} | "
            f"{dt:.1f}s"
        )
        print(line)
        f.write(line + "\n")
        f.flush()

        if va_loss < best_val:
            best_val = va_loss
            best_val_nmse = va_nmse
            best_epoch = epoch

            ckpt_path = "bestc_channel_only_finetune.pt"
            torch.save(
                {
                    "epoch": epoch,
                    "model_state": model.state_dict(),
                    "optimizer_state": optimizer.state_dict(),

                    "F_in": F_in,
                    "pre_len": pre_len,
                    "F_step": F_step,
                    "F_out_total": pre_len * F_step,

                    "best_val_loss": best_val,
                    "best_val_nmse_db": best_val_nmse,
                },
                ckpt_path,
            )

            save_line = (
                f"  ↳ saved {ckpt_path} | best@{best_epoch}: "
                f"val loss={best_val:.6f}, val nmse(dB)={best_val_nmse:.4f}"
            )
            print(save_line)
            f.write(save_line + "\n")
            f.flush()

total_sec = time.time() - t_train0
h = int(total_sec // 3600)
m = int((total_sec % 3600) // 60)
s = total_sec % 60

summary1 = "\n=== Training Summary ==="
summary2 = f"Total time: {total_sec:.1f}s ({h}h {m}m {s:.1f}s)"
summary3 = (
    f"Best epoch: {best_epoch} | best val loss={best_val:.6f}, "
    f"best val nmse(dB)={best_val_nmse:.4f}"
)

print(summary1)
print(summary2)
print(summary3)

with open(log_path, "a", encoding="utf-8") as f:
    f.write(summary1 + "\n")
    f.write(summary2 + "\n")
    f.write(summary3 + "\n")

print("Log saved to:", os.path.abspath(log_path))
# Out:
# [01/500] train loss=0.561487, nmse(dB)=3.1595 | val loss=0.464829, nmse(dB)=2.5912 | 0.4s
#   ↳ saved bestc_channel_only_finetune.pt | best@1: val loss=0.464829, val nmse(dB)=2.5912
# [02/500] train loss=0.478744, nmse(dB)=2.4548 | val loss=0.422143, nmse(dB)=2.1729 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@2: val loss=0.422143, val nmse(dB)=2.1729
# [03/500] train loss=0.437684, nmse(dB)=2.1329 | val loss=0.394395, nmse(dB)=1.8776 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@3: val loss=0.394395, val nmse(dB)=1.8776
# [04/500] train loss=0.413338, nmse(dB)=1.8524 | val loss=0.371953, nmse(dB)=1.6232 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@4: val loss=0.371953, val nmse(dB)=1.6232
# [05/500] train loss=0.392008, nmse(dB)=1.6104 | val loss=0.351899, nmse(dB)=1.3825 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@5: val loss=0.351899, val nmse(dB)=1.3825
# [06/500] train loss=0.371990, nmse(dB)=1.4067 | val loss=0.333274, nmse(dB)=1.1463 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@6: val loss=0.333274, val nmse(dB)=1.1463
# [07/500] train loss=0.353911, nmse(dB)=1.1735 | val loss=0.315684, nmse(dB)=0.9108 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@7: val loss=0.315684, val nmse(dB)=0.9108
# [08/500] train loss=0.336361, nmse(dB)=0.9628 | val loss=0.298639, nmse(dB)=0.6698 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@8: val loss=0.298639, val nmse(dB)=0.6698
# [09/500] train loss=0.318870, nmse(dB)=0.7304 | val loss=0.281964, nmse(dB)=0.4202 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@9: val loss=0.281964, val nmse(dB)=0.4202
# [10/500] train loss=0.302465, nmse(dB)=0.5088 | val loss=0.265779, nmse(dB)=0.1635 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@10: val loss=0.265779, val nmse(dB)=0.1635
# [11/500] train loss=0.286903, nmse(dB)=0.2737 | val loss=0.250194, nmse(dB)=-0.0990 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@11: val loss=0.250194, val nmse(dB)=-0.0990
# [12/500] train loss=0.272288, nmse(dB)=0.0179 | val loss=0.235262, nmse(dB)=-0.3662 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@12: val loss=0.235262, val nmse(dB)=-0.3662
# [13/500] train loss=0.256941, nmse(dB)=-0.2332 | val loss=0.221012, nmse(dB)=-0.6376 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@13: val loss=0.221012, val nmse(dB)=-0.6376
# [14/500] train loss=0.242402, nmse(dB)=-0.4478 | val loss=0.207460, nmse(dB)=-0.9124 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@14: val loss=0.207460, val nmse(dB)=-0.9124
# [15/500] train loss=0.230254, nmse(dB)=-0.7020 | val loss=0.194596, nmse(dB)=-1.1904 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@15: val loss=0.194596, val nmse(dB)=-1.1904
# [16/500] train loss=0.217248, nmse(dB)=-0.9467 | val loss=0.182312, nmse(dB)=-1.4736 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@16: val loss=0.182312, val nmse(dB)=-1.4736
# [17/500] train loss=0.205763, nmse(dB)=-1.2061 | val loss=0.170592, nmse(dB)=-1.7621 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@17: val loss=0.170592, val nmse(dB)=-1.7621
# [18/500] train loss=0.192471, nmse(dB)=-1.4475 | val loss=0.159484, nmse(dB)=-2.0545 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@18: val loss=0.159484, val nmse(dB)=-2.0545
# [19/500] train loss=0.182675, nmse(dB)=-1.6981 | val loss=0.148973, nmse(dB)=-2.3507 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@19: val loss=0.148973, val nmse(dB)=-2.3507
# [20/500] train loss=0.171957, nmse(dB)=-1.9803 | val loss=0.139048, nmse(dB)=-2.6501 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@20: val loss=0.139048, val nmse(dB)=-2.6501
# [21/500] train loss=0.161508, nmse(dB)=-2.2094 | val loss=0.129677, nmse(dB)=-2.9531 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@21: val loss=0.129677, val nmse(dB)=-2.9531
# [22/500] train loss=0.153115, nmse(dB)=-2.4697 | val loss=0.120900, nmse(dB)=-3.2574 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@22: val loss=0.120900, val nmse(dB)=-3.2574
# [23/500] train loss=0.144339, nmse(dB)=-2.7248 | val loss=0.112688, nmse(dB)=-3.5629 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@23: val loss=0.112688, val nmse(dB)=-3.5629
# [24/500] train loss=0.135887, nmse(dB)=-2.9903 | val loss=0.104927, nmse(dB)=-3.8729 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@24: val loss=0.104927, val nmse(dB)=-3.8729
# [25/500] train loss=0.127353, nmse(dB)=-3.2612 | val loss=0.097628, nmse(dB)=-4.1860 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@25: val loss=0.097628, val nmse(dB)=-4.1860
# [26/500] train loss=0.122413, nmse(dB)=-3.4659 | val loss=0.090845, nmse(dB)=-4.4987 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@26: val loss=0.090845, val nmse(dB)=-4.4987
# [27/500] train loss=0.113635, nmse(dB)=-3.7381 | val loss=0.084479, nmse(dB)=-4.8142 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@27: val loss=0.084479, val nmse(dB)=-4.8142
# [28/500] train loss=0.107684, nmse(dB)=-3.9884 | val loss=0.078527, nmse(dB)=-5.1315 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@28: val loss=0.078527, val nmse(dB)=-5.1315
# [29/500] train loss=0.103089, nmse(dB)=-4.1867 | val loss=0.073021, nmse(dB)=-5.4472 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@29: val loss=0.073021, val nmse(dB)=-5.4472
# [30/500] train loss=0.097498, nmse(dB)=-4.4425 | val loss=0.067877, nmse(dB)=-5.7645 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@30: val loss=0.067877, val nmse(dB)=-5.7645
# [31/500] train loss=0.091695, nmse(dB)=-4.6947 | val loss=0.063092, nmse(dB)=-6.0820 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@31: val loss=0.063092, val nmse(dB)=-6.0820
# [32/500] train loss=0.086598, nmse(dB)=-4.9493 | val loss=0.058617, nmse(dB)=-6.4015 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@32: val loss=0.058617, val nmse(dB)=-6.4015
# [33/500] train loss=0.082073, nmse(dB)=-5.1722 | val loss=0.054445, nmse(dB)=-6.7222 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@33: val loss=0.054445, val nmse(dB)=-6.7222
# [34/500] train loss=0.078084, nmse(dB)=-5.3725 | val loss=0.050599, nmse(dB)=-7.0403 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@34: val loss=0.050599, val nmse(dB)=-7.0403
# [35/500] train loss=0.074924, nmse(dB)=-5.5789 | val loss=0.047029, nmse(dB)=-7.3580 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@35: val loss=0.047029, val nmse(dB)=-7.3580
# [36/500] train loss=0.071945, nmse(dB)=-5.7589 | val loss=0.043712, nmse(dB)=-7.6757 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@36: val loss=0.043712, val nmse(dB)=-7.6757
# [37/500] train loss=0.067723, nmse(dB)=-6.0193 | val loss=0.040608, nmse(dB)=-7.9956 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@37: val loss=0.040608, val nmse(dB)=-7.9956
# [38/500] train loss=0.066152, nmse(dB)=-6.1356 | val loss=0.037756, nmse(dB)=-8.3118 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@38: val loss=0.037756, val nmse(dB)=-8.3118
# [39/500] train loss=0.061710, nmse(dB)=-6.4092 | val loss=0.035114, nmse(dB)=-8.6269 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@39: val loss=0.035114, val nmse(dB)=-8.6269
# [40/500] train loss=0.058536, nmse(dB)=-6.6112 | val loss=0.032662, nmse(dB)=-8.9413 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@40: val loss=0.032662, val nmse(dB)=-8.9413
# [41/500] train loss=0.057140, nmse(dB)=-6.7642 | val loss=0.030418, nmse(dB)=-9.2505 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@41: val loss=0.030418, val nmse(dB)=-9.2505
# [42/500] train loss=0.054876, nmse(dB)=-6.9301 | val loss=0.028343, nmse(dB)=-9.5573 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@42: val loss=0.028343, val nmse(dB)=-9.5573
# [43/500] train loss=0.052986, nmse(dB)=-7.1105 | val loss=0.026407, nmse(dB)=-9.8645 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@43: val loss=0.026407, val nmse(dB)=-9.8645
# [44/500] train loss=0.050927, nmse(dB)=-7.2762 | val loss=0.024636, nmse(dB)=-10.1659 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@44: val loss=0.024636, val nmse(dB)=-10.1659
# [45/500] train loss=0.049263, nmse(dB)=-7.4141 | val loss=0.022992, nmse(dB)=-10.4659 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@45: val loss=0.022992, val nmse(dB)=-10.4659
# [46/500] train loss=0.047492, nmse(dB)=-7.5721 | val loss=0.021463, nmse(dB)=-10.7649 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@46: val loss=0.021463, val nmse(dB)=-10.7649
# [47/500] train loss=0.045791, nmse(dB)=-7.7531 | val loss=0.020073, nmse(dB)=-11.0557 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@47: val loss=0.020073, val nmse(dB)=-11.0557
# [48/500] train loss=0.043981, nmse(dB)=-7.8918 | val loss=0.018794, nmse(dB)=-11.3415 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@48: val loss=0.018794, val nmse(dB)=-11.3415
# [49/500] train loss=0.043859, nmse(dB)=-7.9325 | val loss=0.017617, nmse(dB)=-11.6223 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@49: val loss=0.017617, val nmse(dB)=-11.6223
# [50/500] train loss=0.040873, nmse(dB)=-8.2012 | val loss=0.016540, nmse(dB)=-11.8963 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@50: val loss=0.016540, val nmse(dB)=-11.8963
# [51/500] train loss=0.040354, nmse(dB)=-8.2347 | val loss=0.015536, nmse(dB)=-12.1682 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@51: val loss=0.015536, val nmse(dB)=-12.1682
# [52/500] train loss=0.038940, nmse(dB)=-8.4062 | val loss=0.014626, nmse(dB)=-12.4304 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@52: val loss=0.014626, val nmse(dB)=-12.4304
# [53/500] train loss=0.037894, nmse(dB)=-8.5330 | val loss=0.013779, nmse(dB)=-12.6895 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@53: val loss=0.013779, val nmse(dB)=-12.6895
# [54/500] train loss=0.036332, nmse(dB)=-8.7333 | val loss=0.013007, nmse(dB)=-12.9399 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@54: val loss=0.013007, val nmse(dB)=-12.9399
# [55/500] train loss=0.036042, nmse(dB)=-8.7399 | val loss=0.012308, nmse(dB)=-13.1799 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@55: val loss=0.012308, val nmse(dB)=-13.1799
# [56/500] train loss=0.035254, nmse(dB)=-8.8325 | val loss=0.011651, nmse(dB)=-13.4179 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@56: val loss=0.011651, val nmse(dB)=-13.4179
# [57/500] train loss=0.035592, nmse(dB)=-8.7993 | val loss=0.011028, nmse(dB)=-13.6566 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@57: val loss=0.011028, val nmse(dB)=-13.6566
# [58/500] train loss=0.033729, nmse(dB)=-9.0295 | val loss=0.010501, nmse(dB)=-13.8693 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@58: val loss=0.010501, val nmse(dB)=-13.8693
# [59/500] train loss=0.034204, nmse(dB)=-8.9619 | val loss=0.010012, nmse(dB)=-14.0766 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@59: val loss=0.010012, val nmse(dB)=-14.0766
# [60/500] train loss=0.032945, nmse(dB)=-9.1258 | val loss=0.009555, nmse(dB)=-14.2795 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@60: val loss=0.009555, val nmse(dB)=-14.2795
# [61/500] train loss=0.031167, nmse(dB)=-9.3882 | val loss=0.009150, nmse(dB)=-14.4677 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@61: val loss=0.009150, val nmse(dB)=-14.4677
# [62/500] train loss=0.032812, nmse(dB)=-9.1886 | val loss=0.008751, nmse(dB)=-14.6613 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@62: val loss=0.008751, val nmse(dB)=-14.6613
# [63/500] train loss=0.032882, nmse(dB)=-9.2011 | val loss=0.008387, nmse(dB)=-14.8457 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@63: val loss=0.008387, val nmse(dB)=-14.8457
# [64/500] train loss=0.030864, nmse(dB)=-9.3912 | val loss=0.008069, nmse(dB)=-15.0138 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@64: val loss=0.008069, val nmse(dB)=-15.0138
# [65/500] train loss=0.031700, nmse(dB)=-9.3242 | val loss=0.007807, nmse(dB)=-15.1570 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@65: val loss=0.007807, val nmse(dB)=-15.1570
# [66/500] train loss=0.029197, nmse(dB)=-9.6664 | val loss=0.007532, nmse(dB)=-15.3128 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@66: val loss=0.007532, val nmse(dB)=-15.3128
# [67/500] train loss=0.030894, nmse(dB)=-9.4199 | val loss=0.007271, nmse(dB)=-15.4659 | 0.3s
#   ↳ saved bestc_channel_only_finetune.pt | best@67: val loss=0.007271, val nmse(dB)=-15.4659
# [68/500] train loss=0.029637, nmse(dB)=-9.6071 | val loss=0.007066, nmse(dB)=-15.5898 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@68: val loss=0.007066, val nmse(dB)=-15.5898
# [69/500] train loss=0.030630, nmse(dB)=-9.4547 | val loss=0.006831, nmse(dB)=-15.7370 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@69: val loss=0.006831, val nmse(dB)=-15.7370
# [70/500] train loss=0.029365, nmse(dB)=-9.6317 | val loss=0.006669, nmse(dB)=-15.8411 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@70: val loss=0.006669, val nmse(dB)=-15.8411
# [71/500] train loss=0.028797, nmse(dB)=-9.7104 | val loss=0.006478, nmse(dB)=-15.9674 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@71: val loss=0.006478, val nmse(dB)=-15.9674
# [72/500] train loss=0.028499, nmse(dB)=-9.7618 | val loss=0.006327, nmse(dB)=-16.0697 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@72: val loss=0.006327, val nmse(dB)=-16.0697
# [73/500] train loss=0.029556, nmse(dB)=-9.5981 | val loss=0.006202, nmse(dB)=-16.1563 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@73: val loss=0.006202, val nmse(dB)=-16.1563
# [74/500] train loss=0.028723, nmse(dB)=-9.7221 | val loss=0.006077, nmse(dB)=-16.2449 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@74: val loss=0.006077, val nmse(dB)=-16.2449
# [75/500] train loss=0.028500, nmse(dB)=-9.7679 | val loss=0.005979, nmse(dB)=-16.3151 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@75: val loss=0.005979, val nmse(dB)=-16.3151
# [76/500] train loss=0.029242, nmse(dB)=-9.6679 | val loss=0.005874, nmse(dB)=-16.3927 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@76: val loss=0.005874, val nmse(dB)=-16.3927
# [77/500] train loss=0.028908, nmse(dB)=-9.7149 | val loss=0.005782, nmse(dB)=-16.4607 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@77: val loss=0.005782, val nmse(dB)=-16.4607
# [78/500] train loss=0.028766, nmse(dB)=-9.7139 | val loss=0.005698, nmse(dB)=-16.5245 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@78: val loss=0.005698, val nmse(dB)=-16.5245
# [79/500] train loss=0.028361, nmse(dB)=-9.8012 | val loss=0.005616, nmse(dB)=-16.5876 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@79: val loss=0.005616, val nmse(dB)=-16.5876
# [80/500] train loss=0.027777, nmse(dB)=-9.8785 | val loss=0.005556, nmse(dB)=-16.6344 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@80: val loss=0.005556, val nmse(dB)=-16.6344
# [81/500] train loss=0.028062, nmse(dB)=-9.7990 | val loss=0.005479, nmse(dB)=-16.6950 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@81: val loss=0.005479, val nmse(dB)=-16.6950
# [82/500] train loss=0.026925, nmse(dB)=-10.0281 | val loss=0.005424, nmse(dB)=-16.7384 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@82: val loss=0.005424, val nmse(dB)=-16.7384
# [83/500] train loss=0.029051, nmse(dB)=-9.7353 | val loss=0.005383, nmse(dB)=-16.7714 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@83: val loss=0.005383, val nmse(dB)=-16.7714
# [84/500] train loss=0.028845, nmse(dB)=-9.7636 | val loss=0.005320, nmse(dB)=-16.8222 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@84: val loss=0.005320, val nmse(dB)=-16.8222
# [85/500] train loss=0.027669, nmse(dB)=-9.8915 | val loss=0.005269, nmse(dB)=-16.8645 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@85: val loss=0.005269, val nmse(dB)=-16.8645
# [86/500] train loss=0.026461, nmse(dB)=-10.0835 | val loss=0.005249, nmse(dB)=-16.8806 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@86: val loss=0.005249, val nmse(dB)=-16.8806
# [87/500] train loss=0.027843, nmse(dB)=-9.8619 | val loss=0.005213, nmse(dB)=-16.9110 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@87: val loss=0.005213, val nmse(dB)=-16.9110
# [88/500] train loss=0.028208, nmse(dB)=-9.8483 | val loss=0.005182, nmse(dB)=-16.9372 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@88: val loss=0.005182, val nmse(dB)=-16.9372
# [89/500] train loss=0.027693, nmse(dB)=-9.9255 | val loss=0.005163, nmse(dB)=-16.9524 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@89: val loss=0.005163, val nmse(dB)=-16.9524
# [90/500] train loss=0.025644, nmse(dB)=-10.2722 | val loss=0.005104, nmse(dB)=-17.0023 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@90: val loss=0.005104, val nmse(dB)=-17.0023
# [91/500] train loss=0.028144, nmse(dB)=-9.8416 | val loss=0.005092, nmse(dB)=-17.0128 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@91: val loss=0.005092, val nmse(dB)=-17.0128
# [92/500] train loss=0.028340, nmse(dB)=-9.8433 | val loss=0.005082, nmse(dB)=-17.0210 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@92: val loss=0.005082, val nmse(dB)=-17.0210
# [93/500] train loss=0.026851, nmse(dB)=-10.0186 | val loss=0.005077, nmse(dB)=-17.0259 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@93: val loss=0.005077, val nmse(dB)=-17.0259
# [94/500] train loss=0.026338, nmse(dB)=-10.1214 | val loss=0.005037, nmse(dB)=-17.0604 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@94: val loss=0.005037, val nmse(dB)=-17.0604
# [95/500] train loss=0.026757, nmse(dB)=-10.0355 | val loss=0.005014, nmse(dB)=-17.0800 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@95: val loss=0.005014, val nmse(dB)=-17.0800
# [96/500] train loss=0.028862, nmse(dB)=-9.7576 | val loss=0.005031, nmse(dB)=-17.0651 | 0.2s
# [97/500] train loss=0.028080, nmse(dB)=-9.8822 | val loss=0.005009, nmse(dB)=-17.0846 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@97: val loss=0.005009, val nmse(dB)=-17.0846
# [98/500] train loss=0.025960, nmse(dB)=-10.1838 | val loss=0.004978, nmse(dB)=-17.1113 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@98: val loss=0.004978, val nmse(dB)=-17.1113
# [99/500] train loss=0.026982, nmse(dB)=-10.0270 | val loss=0.004959, nmse(dB)=-17.1274 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@99: val loss=0.004959, val nmse(dB)=-17.1274
# [100/500] train loss=0.025659, nmse(dB)=-10.2466 | val loss=0.004944, nmse(dB)=-17.1406 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@100: val loss=0.004944, val nmse(dB)=-17.1406
# [101/500] train loss=0.026363, nmse(dB)=-10.1186 | val loss=0.004969, nmse(dB)=-17.1193 | 0.2s
# [102/500] train loss=0.026741, nmse(dB)=-10.0669 | val loss=0.004961, nmse(dB)=-17.1260 | 0.2s
# [103/500] train loss=0.027261, nmse(dB)=-9.9484 | val loss=0.004952, nmse(dB)=-17.1341 | 0.2s
# [104/500] train loss=0.026417, nmse(dB)=-10.0982 | val loss=0.004904, nmse(dB)=-17.1763 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@104: val loss=0.004904, val nmse(dB)=-17.1763
# [105/500] train loss=0.025424, nmse(dB)=-10.2798 | val loss=0.004922, nmse(dB)=-17.1604 | 0.2s
# [106/500] train loss=0.025757, nmse(dB)=-10.2149 | val loss=0.004906, nmse(dB)=-17.1740 | 0.2s
# [107/500] train loss=0.026094, nmse(dB)=-10.1675 | val loss=0.004894, nmse(dB)=-17.1854 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@107: val loss=0.004894, val nmse(dB)=-17.1854
# [108/500] train loss=0.025572, nmse(dB)=-10.2207 | val loss=0.004881, nmse(dB)=-17.1969 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@108: val loss=0.004881, val nmse(dB)=-17.1969
# [109/500] train loss=0.026327, nmse(dB)=-10.1138 | val loss=0.004895, nmse(dB)=-17.1845 | 0.2s
# [110/500] train loss=0.027400, nmse(dB)=-9.9939 | val loss=0.004863, nmse(dB)=-17.2126 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@110: val loss=0.004863, val nmse(dB)=-17.2126
# [111/500] train loss=0.026180, nmse(dB)=-10.1097 | val loss=0.004883, nmse(dB)=-17.1949 | 0.2s
# [112/500] train loss=0.025576, nmse(dB)=-10.2383 | val loss=0.004894, nmse(dB)=-17.1848 | 0.2s
# [113/500] train loss=0.027033, nmse(dB)=-10.0278 | val loss=0.004927, nmse(dB)=-17.1563 | 0.2s
# [114/500] train loss=0.026931, nmse(dB)=-10.0101 | val loss=0.004901, nmse(dB)=-17.1791 | 0.2s
# [115/500] train loss=0.026932, nmse(dB)=-10.0166 | val loss=0.004888, nmse(dB)=-17.1906 | 0.2s
# [116/500] train loss=0.026031, nmse(dB)=-10.1823 | val loss=0.004865, nmse(dB)=-17.2106 | 0.2s
# [117/500] train loss=0.025441, nmse(dB)=-10.2524 | val loss=0.004852, nmse(dB)=-17.2224 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@117: val loss=0.004852, val nmse(dB)=-17.2224
# [118/500] train loss=0.026831, nmse(dB)=-10.0842 | val loss=0.004861, nmse(dB)=-17.2142 | 0.2s
# [119/500] train loss=0.027192, nmse(dB)=-10.0165 | val loss=0.004844, nmse(dB)=-17.2299 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@119: val loss=0.004844, val nmse(dB)=-17.2299
# [120/500] train loss=0.025158, nmse(dB)=-10.3136 | val loss=0.004864, nmse(dB)=-17.2121 | 0.2s
# [121/500] train loss=0.025693, nmse(dB)=-10.2253 | val loss=0.004844, nmse(dB)=-17.2295 | 0.2s
# [122/500] train loss=0.026459, nmse(dB)=-10.0387 | val loss=0.004836, nmse(dB)=-17.2373 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@122: val loss=0.004836, val nmse(dB)=-17.2373
# [123/500] train loss=0.026430, nmse(dB)=-10.1141 | val loss=0.004847, nmse(dB)=-17.2272 | 0.2s
# [124/500] train loss=0.025798, nmse(dB)=-10.2033 | val loss=0.004861, nmse(dB)=-17.2146 | 0.2s
# [125/500] train loss=0.026600, nmse(dB)=-10.0614 | val loss=0.004872, nmse(dB)=-17.2050 | 0.2s
# [126/500] train loss=0.026079, nmse(dB)=-10.1626 | val loss=0.004865, nmse(dB)=-17.2105 | 0.2s
# [127/500] train loss=0.024929, nmse(dB)=-10.3469 | val loss=0.004858, nmse(dB)=-17.2172 | 0.2s
# [128/500] train loss=0.026508, nmse(dB)=-10.1108 | val loss=0.004836, nmse(dB)=-17.2370 | 0.2s
# [129/500] train loss=0.024727, nmse(dB)=-10.3936 | val loss=0.004853, nmse(dB)=-17.2214 | 0.2s
# [130/500] train loss=0.025361, nmse(dB)=-10.2808 | val loss=0.004854, nmse(dB)=-17.2206 | 0.2s
# [131/500] train loss=0.026315, nmse(dB)=-10.1225 | val loss=0.004844, nmse(dB)=-17.2298 | 0.2s
# [132/500] train loss=0.026059, nmse(dB)=-10.1541 | val loss=0.004834, nmse(dB)=-17.2390 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@132: val loss=0.004834, val nmse(dB)=-17.2390
# [133/500] train loss=0.025277, nmse(dB)=-10.2812 | val loss=0.004851, nmse(dB)=-17.2232 | 0.2s
# [134/500] train loss=0.024800, nmse(dB)=-10.3645 | val loss=0.004869, nmse(dB)=-17.2070 | 0.2s
# [135/500] train loss=0.025953, nmse(dB)=-10.1895 | val loss=0.004843, nmse(dB)=-17.2307 | 0.2s
# [136/500] train loss=0.026223, nmse(dB)=-10.1170 | val loss=0.004850, nmse(dB)=-17.2239 | 0.2s
# [137/500] train loss=0.025513, nmse(dB)=-10.2492 | val loss=0.004850, nmse(dB)=-17.2244 | 0.2s
# [138/500] train loss=0.026906, nmse(dB)=-10.0535 | val loss=0.004855, nmse(dB)=-17.2198 | 0.2s
# [139/500] train loss=0.026476, nmse(dB)=-10.0938 | val loss=0.004868, nmse(dB)=-17.2080 | 0.2s
# [140/500] train loss=0.026632, nmse(dB)=-10.0542 | val loss=0.004854, nmse(dB)=-17.2204 | 0.2s
# [141/500] train loss=0.026701, nmse(dB)=-10.0929 | val loss=0.004835, nmse(dB)=-17.2377 | 0.2s
# [142/500] train loss=0.026578, nmse(dB)=-10.0745 | val loss=0.004858, nmse(dB)=-17.2167 | 0.2s
# [143/500] train loss=0.024617, nmse(dB)=-10.4145 | val loss=0.004866, nmse(dB)=-17.2096 | 0.2s
# [144/500] train loss=0.025037, nmse(dB)=-10.3331 | val loss=0.004885, nmse(dB)=-17.1930 | 0.2s
# [145/500] train loss=0.027270, nmse(dB)=-9.9824 | val loss=0.004864, nmse(dB)=-17.2119 | 0.2s
# [146/500] train loss=0.026126, nmse(dB)=-10.1369 | val loss=0.004846, nmse(dB)=-17.2277 | 0.2s
# [147/500] train loss=0.024599, nmse(dB)=-10.4266 | val loss=0.004855, nmse(dB)=-17.2203 | 0.2s
# [148/500] train loss=0.024941, nmse(dB)=-10.3479 | val loss=0.004876, nmse(dB)=-17.2010 | 0.2s
# [149/500] train loss=0.025618, nmse(dB)=-10.2475 | val loss=0.004863, nmse(dB)=-17.2123 | 0.2s
# [150/500] train loss=0.026472, nmse(dB)=-10.1040 | val loss=0.004866, nmse(dB)=-17.2101 | 0.2s
# [151/500] train loss=0.025137, nmse(dB)=-10.3018 | val loss=0.004862, nmse(dB)=-17.2139 | 0.2s
# [152/500] train loss=0.025583, nmse(dB)=-10.2173 | val loss=0.004873, nmse(dB)=-17.2036 | 0.2s
# [153/500] train loss=0.025716, nmse(dB)=-10.1960 | val loss=0.004869, nmse(dB)=-17.2072 | 0.2s
# [154/500] train loss=0.026131, nmse(dB)=-10.1582 | val loss=0.004851, nmse(dB)=-17.2230 | 0.2s
# [155/500] train loss=0.025634, nmse(dB)=-10.2360 | val loss=0.004889, nmse(dB)=-17.1899 | 0.2s
# [156/500] train loss=0.024976, nmse(dB)=-10.3260 | val loss=0.004842, nmse(dB)=-17.2317 | 0.2s
# [157/500] train loss=0.026077, nmse(dB)=-10.1201 | val loss=0.004845, nmse(dB)=-17.2288 | 0.2s
# [158/500] train loss=0.025233, nmse(dB)=-10.2901 | val loss=0.004883, nmse(dB)=-17.1949 | 0.2s
# [159/500] train loss=0.025784, nmse(dB)=-10.2045 | val loss=0.004872, nmse(dB)=-17.2047 | 0.2s
# [160/500] train loss=0.025594, nmse(dB)=-10.2540 | val loss=0.004869, nmse(dB)=-17.2073 | 0.2s
# [161/500] train loss=0.025716, nmse(dB)=-10.2245 | val loss=0.004864, nmse(dB)=-17.2121 | 0.2s
# [162/500] train loss=0.025057, nmse(dB)=-10.3385 | val loss=0.004897, nmse(dB)=-17.1820 | 0.2s
# [163/500] train loss=0.025100, nmse(dB)=-10.3057 | val loss=0.004865, nmse(dB)=-17.2112 | 0.2s
# [164/500] train loss=0.024985, nmse(dB)=-10.3118 | val loss=0.004833, nmse(dB)=-17.2397 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@164: val loss=0.004833, val nmse(dB)=-17.2397
# [165/500] train loss=0.024973, nmse(dB)=-10.3481 | val loss=0.004861, nmse(dB)=-17.2142 | 0.2s
# [166/500] train loss=0.026061, nmse(dB)=-10.1809 | val loss=0.004891, nmse(dB)=-17.1881 | 0.2s
# [167/500] train loss=0.024782, nmse(dB)=-10.3591 | val loss=0.004865, nmse(dB)=-17.2107 | 0.2s
# [168/500] train loss=0.025692, nmse(dB)=-10.2341 | val loss=0.004834, nmse(dB)=-17.2390 | 0.2s
# [169/500] train loss=0.025288, nmse(dB)=-10.2997 | val loss=0.004839, nmse(dB)=-17.2340 | 0.2s
# [170/500] train loss=0.025109, nmse(dB)=-10.3084 | val loss=0.004840, nmse(dB)=-17.2331 | 0.2s
# [171/500] train loss=0.025108, nmse(dB)=-10.3137 | val loss=0.004868, nmse(dB)=-17.2082 | 0.2s
# [172/500] train loss=0.025661, nmse(dB)=-10.2202 | val loss=0.004855, nmse(dB)=-17.2197 | 0.2s
# [173/500] train loss=0.024948, nmse(dB)=-10.3442 | val loss=0.004857, nmse(dB)=-17.2183 | 0.2s
# [174/500] train loss=0.024729, nmse(dB)=-10.3562 | val loss=0.004845, nmse(dB)=-17.2287 | 0.2s
# [175/500] train loss=0.024166, nmse(dB)=-10.4980 | val loss=0.004857, nmse(dB)=-17.2181 | 0.2s
# [176/500] train loss=0.025121, nmse(dB)=-10.2924 | val loss=0.004849, nmse(dB)=-17.2249 | 0.2s
# [177/500] train loss=0.023593, nmse(dB)=-10.6352 | val loss=0.004851, nmse(dB)=-17.2236 | 0.2s
# [178/500] train loss=0.023930, nmse(dB)=-10.5443 | val loss=0.004863, nmse(dB)=-17.2122 | 0.2s
# [179/500] train loss=0.026237, nmse(dB)=-10.1409 | val loss=0.004828, nmse(dB)=-17.2442 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@179: val loss=0.004828, val nmse(dB)=-17.2442
# [180/500] train loss=0.025554, nmse(dB)=-10.2280 | val loss=0.004850, nmse(dB)=-17.2242 | 0.2s
# [181/500] train loss=0.025785, nmse(dB)=-10.1726 | val loss=0.004858, nmse(dB)=-17.2175 | 0.2s
# [182/500] train loss=0.025889, nmse(dB)=-10.2054 | val loss=0.004876, nmse(dB)=-17.2008 | 0.2s
# [183/500] train loss=0.026681, nmse(dB)=-10.1033 | val loss=0.004915, nmse(dB)=-17.1662 | 0.2s
# [184/500] train loss=0.027434, nmse(dB)=-10.0251 | val loss=0.004882, nmse(dB)=-17.1957 | 0.2s
# [185/500] train loss=0.025938, nmse(dB)=-10.1883 | val loss=0.004867, nmse(dB)=-17.2089 | 0.2s
# [186/500] train loss=0.025240, nmse(dB)=-10.2776 | val loss=0.004877, nmse(dB)=-17.2004 | 0.2s
# [187/500] train loss=0.024778, nmse(dB)=-10.3817 | val loss=0.004876, nmse(dB)=-17.2010 | 0.2s
# [188/500] train loss=0.025431, nmse(dB)=-10.2301 | val loss=0.004867, nmse(dB)=-17.2093 | 0.2s
# [189/500] train loss=0.024803, nmse(dB)=-10.3754 | val loss=0.004889, nmse(dB)=-17.1892 | 0.2s
# [190/500] train loss=0.023895, nmse(dB)=-10.5669 | val loss=0.004889, nmse(dB)=-17.1896 | 0.2s
# [191/500] train loss=0.025875, nmse(dB)=-10.2075 | val loss=0.004861, nmse(dB)=-17.2143 | 0.2s
# [192/500] train loss=0.025896, nmse(dB)=-10.1732 | val loss=0.004864, nmse(dB)=-17.2119 | 0.2s
# [193/500] train loss=0.023982, nmse(dB)=-10.5103 | val loss=0.004855, nmse(dB)=-17.2195 | 0.2s
# [194/500] train loss=0.024311, nmse(dB)=-10.4586 | val loss=0.004841, nmse(dB)=-17.2323 | 0.2s
# [195/500] train loss=0.025041, nmse(dB)=-10.3377 | val loss=0.004831, nmse(dB)=-17.2411 | 0.2s
# [196/500] train loss=0.024818, nmse(dB)=-10.3490 | val loss=0.004837, nmse(dB)=-17.2363 | 0.2s
# [197/500] train loss=0.024126, nmse(dB)=-10.4673 | val loss=0.004841, nmse(dB)=-17.2326 | 0.2s
# [198/500] train loss=0.024447, nmse(dB)=-10.4420 | val loss=0.004842, nmse(dB)=-17.2318 | 0.2s
# [199/500] train loss=0.025135, nmse(dB)=-10.3113 | val loss=0.004830, nmse(dB)=-17.2426 | 0.2s
# [200/500] train loss=0.024905, nmse(dB)=-10.3641 | val loss=0.004856, nmse(dB)=-17.2185 | 0.2s
# [201/500] train loss=0.026150, nmse(dB)=-10.1799 | val loss=0.004862, nmse(dB)=-17.2140 | 0.2s
# [202/500] train loss=0.024304, nmse(dB)=-10.4838 | val loss=0.004853, nmse(dB)=-17.2216 | 0.2s
# [203/500] train loss=0.024900, nmse(dB)=-10.3448 | val loss=0.004837, nmse(dB)=-17.2364 | 0.2s
# [204/500] train loss=0.025526, nmse(dB)=-10.2380 | val loss=0.004865, nmse(dB)=-17.2107 | 0.2s
# [205/500] train loss=0.025037, nmse(dB)=-10.3306 | val loss=0.004868, nmse(dB)=-17.2078 | 0.2s
# [206/500] train loss=0.024608, nmse(dB)=-10.4201 | val loss=0.004859, nmse(dB)=-17.2161 | 0.2s
# [207/500] train loss=0.024365, nmse(dB)=-10.4410 | val loss=0.004870, nmse(dB)=-17.2064 | 0.2s
# [208/500] train loss=0.024781, nmse(dB)=-10.3631 | val loss=0.004857, nmse(dB)=-17.2184 | 0.2s
# [209/500] train loss=0.025129, nmse(dB)=-10.3154 | val loss=0.004856, nmse(dB)=-17.2188 | 0.2s
# [210/500] train loss=0.024807, nmse(dB)=-10.3724 | val loss=0.004871, nmse(dB)=-17.2059 | 0.2s
# [211/500] train loss=0.025724, nmse(dB)=-10.2295 | val loss=0.004838, nmse(dB)=-17.2351 | 0.2s
# [212/500] train loss=0.025803, nmse(dB)=-10.2444 | val loss=0.004851, nmse(dB)=-17.2238 | 0.2s
# [213/500] train loss=0.025631, nmse(dB)=-10.2591 | val loss=0.004842, nmse(dB)=-17.2311 | 0.2s
# [214/500] train loss=0.025164, nmse(dB)=-10.3244 | val loss=0.004843, nmse(dB)=-17.2303 | 0.2s
# [215/500] train loss=0.025428, nmse(dB)=-10.2645 | val loss=0.004839, nmse(dB)=-17.2346 | 0.2s
# [216/500] train loss=0.024991, nmse(dB)=-10.3561 | val loss=0.004842, nmse(dB)=-17.2318 | 0.2s
# [217/500] train loss=0.025110, nmse(dB)=-10.3137 | val loss=0.004829, nmse(dB)=-17.2435 | 0.2s
# [218/500] train loss=0.025765, nmse(dB)=-10.2428 | val loss=0.004833, nmse(dB)=-17.2392 | 0.2s
# [219/500] train loss=0.024657, nmse(dB)=-10.3801 | val loss=0.004834, nmse(dB)=-17.2386 | 0.2s
# [220/500] train loss=0.022787, nmse(dB)=-10.8091 | val loss=0.004827, nmse(dB)=-17.2449 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@220: val loss=0.004827, val nmse(dB)=-17.2449
# [221/500] train loss=0.023365, nmse(dB)=-10.6512 | val loss=0.004820, nmse(dB)=-17.2512 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@221: val loss=0.004820, val nmse(dB)=-17.2512
# [222/500] train loss=0.024738, nmse(dB)=-10.3553 | val loss=0.004820, nmse(dB)=-17.2508 | 0.2s
# [223/500] train loss=0.023800, nmse(dB)=-10.5895 | val loss=0.004832, nmse(dB)=-17.2405 | 0.2s
# [224/500] train loss=0.025393, nmse(dB)=-10.2423 | val loss=0.004828, nmse(dB)=-17.2437 | 0.2s
# [225/500] train loss=0.024519, nmse(dB)=-10.4087 | val loss=0.004835, nmse(dB)=-17.2379 | 0.2s
# [226/500] train loss=0.025145, nmse(dB)=-10.3334 | val loss=0.004823, nmse(dB)=-17.2488 | 0.2s
# [227/500] train loss=0.025092, nmse(dB)=-10.2972 | val loss=0.004838, nmse(dB)=-17.2351 | 0.2s
# [228/500] train loss=0.024740, nmse(dB)=-10.4026 | val loss=0.004844, nmse(dB)=-17.2293 | 0.2s
# [229/500] train loss=0.024644, nmse(dB)=-10.4020 | val loss=0.004832, nmse(dB)=-17.2408 | 0.2s
# [230/500] train loss=0.024113, nmse(dB)=-10.4970 | val loss=0.004849, nmse(dB)=-17.2248 | 0.2s
# [231/500] train loss=0.025393, nmse(dB)=-10.2997 | val loss=0.004818, nmse(dB)=-17.2533 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@231: val loss=0.004818, val nmse(dB)=-17.2533
# [232/500] train loss=0.024874, nmse(dB)=-10.3574 | val loss=0.004821, nmse(dB)=-17.2506 | 0.2s
# [233/500] train loss=0.024675, nmse(dB)=-10.3611 | val loss=0.004826, nmse(dB)=-17.2461 | 0.2s
# [234/500] train loss=0.024408, nmse(dB)=-10.4590 | val loss=0.004812, nmse(dB)=-17.2583 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@234: val loss=0.004812, val nmse(dB)=-17.2583
# [235/500] train loss=0.024347, nmse(dB)=-10.4524 | val loss=0.004842, nmse(dB)=-17.2316 | 0.2s
# [236/500] train loss=0.025743, nmse(dB)=-10.2313 | val loss=0.004849, nmse(dB)=-17.2256 | 0.2s
# [237/500] train loss=0.024929, nmse(dB)=-10.3401 | val loss=0.004845, nmse(dB)=-17.2287 | 0.2s
# [238/500] train loss=0.024223, nmse(dB)=-10.4623 | val loss=0.004855, nmse(dB)=-17.2196 | 0.2s
# [239/500] train loss=0.025168, nmse(dB)=-10.3047 | val loss=0.004822, nmse(dB)=-17.2495 | 0.2s
# [240/500] train loss=0.023929, nmse(dB)=-10.5507 | val loss=0.004865, nmse(dB)=-17.2112 | 0.2s
# [241/500] train loss=0.024317, nmse(dB)=-10.4401 | val loss=0.004852, nmse(dB)=-17.2224 | 0.2s
# [242/500] train loss=0.024402, nmse(dB)=-10.4469 | val loss=0.004840, nmse(dB)=-17.2330 | 0.2s
# [243/500] train loss=0.026001, nmse(dB)=-10.2227 | val loss=0.004866, nmse(dB)=-17.2098 | 0.2s
# [244/500] train loss=0.025523, nmse(dB)=-10.2844 | val loss=0.004843, nmse(dB)=-17.2304 | 0.2s
# [245/500] train loss=0.025503, nmse(dB)=-10.2515 | val loss=0.004852, nmse(dB)=-17.2227 | 0.2s
# [246/500] train loss=0.024485, nmse(dB)=-10.4246 | val loss=0.004861, nmse(dB)=-17.2145 | 0.2s
# [247/500] train loss=0.024560, nmse(dB)=-10.4015 | val loss=0.004841, nmse(dB)=-17.2324 | 0.2s
# [248/500] train loss=0.025285, nmse(dB)=-10.2981 | val loss=0.004848, nmse(dB)=-17.2257 | 0.2s
# [249/500] train loss=0.025750, nmse(dB)=-10.1935 | val loss=0.004843, nmse(dB)=-17.2307 | 0.2s
# [250/500] train loss=0.023914, nmse(dB)=-10.5325 | val loss=0.004837, nmse(dB)=-17.2361 | 0.2s
# [251/500] train loss=0.024307, nmse(dB)=-10.4437 | val loss=0.004859, nmse(dB)=-17.2164 | 0.2s
# [252/500] train loss=0.023492, nmse(dB)=-10.6374 | val loss=0.004850, nmse(dB)=-17.2247 | 0.2s
# [253/500] train loss=0.024646, nmse(dB)=-10.3678 | val loss=0.004833, nmse(dB)=-17.2397 | 0.2s
# [254/500] train loss=0.024627, nmse(dB)=-10.3870 | val loss=0.004856, nmse(dB)=-17.2193 | 0.2s
# [255/500] train loss=0.024835, nmse(dB)=-10.3664 | val loss=0.004841, nmse(dB)=-17.2327 | 0.2s
# [256/500] train loss=0.025275, nmse(dB)=-10.3196 | val loss=0.004847, nmse(dB)=-17.2266 | 0.2s
# [257/500] train loss=0.026309, nmse(dB)=-10.1929 | val loss=0.004863, nmse(dB)=-17.2124 | 0.2s
# [258/500] train loss=0.025536, nmse(dB)=-10.2818 | val loss=0.004854, nmse(dB)=-17.2210 | 0.2s
# [259/500] train loss=0.024645, nmse(dB)=-10.4003 | val loss=0.004838, nmse(dB)=-17.2349 | 0.2s
# [260/500] train loss=0.025355, nmse(dB)=-10.3030 | val loss=0.004821, nmse(dB)=-17.2507 | 0.2s
# [261/500] train loss=0.025393, nmse(dB)=-10.2930 | val loss=0.004822, nmse(dB)=-17.2494 | 0.2s
# [262/500] train loss=0.024573, nmse(dB)=-10.4208 | val loss=0.004827, nmse(dB)=-17.2446 | 0.2s
# [263/500] train loss=0.024564, nmse(dB)=-10.4404 | val loss=0.004833, nmse(dB)=-17.2399 | 0.2s
# [264/500] train loss=0.024879, nmse(dB)=-10.3493 | val loss=0.004837, nmse(dB)=-17.2363 | 0.2s
# [265/500] train loss=0.024129, nmse(dB)=-10.4653 | val loss=0.004828, nmse(dB)=-17.2444 | 0.2s
# [266/500] train loss=0.025492, nmse(dB)=-10.3030 | val loss=0.004824, nmse(dB)=-17.2475 | 0.2s
# [267/500] train loss=0.024752, nmse(dB)=-10.3797 | val loss=0.004819, nmse(dB)=-17.2521 | 0.2s
# [268/500] train loss=0.023234, nmse(dB)=-10.6776 | val loss=0.004812, nmse(dB)=-17.2584 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@268: val loss=0.004812, val nmse(dB)=-17.2584
# [269/500] train loss=0.025127, nmse(dB)=-10.3079 | val loss=0.004814, nmse(dB)=-17.2568 | 0.2s
# [270/500] train loss=0.024914, nmse(dB)=-10.3922 | val loss=0.004811, nmse(dB)=-17.2595 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@270: val loss=0.004811, val nmse(dB)=-17.2595
# [271/500] train loss=0.024918, nmse(dB)=-10.3687 | val loss=0.004818, nmse(dB)=-17.2528 | 0.2s
# [272/500] train loss=0.024400, nmse(dB)=-10.4388 | val loss=0.004806, nmse(dB)=-17.2636 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@272: val loss=0.004806, val nmse(dB)=-17.2636
# [273/500] train loss=0.023459, nmse(dB)=-10.6023 | val loss=0.004796, nmse(dB)=-17.2727 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@273: val loss=0.004796, val nmse(dB)=-17.2727
# [274/500] train loss=0.025241, nmse(dB)=-10.3150 | val loss=0.004814, nmse(dB)=-17.2570 | 0.2s
# [275/500] train loss=0.025232, nmse(dB)=-10.3118 | val loss=0.004823, nmse(dB)=-17.2485 | 0.2s
# [276/500] train loss=0.024751, nmse(dB)=-10.3867 | val loss=0.004831, nmse(dB)=-17.2416 | 0.2s
# [277/500] train loss=0.025349, nmse(dB)=-10.2915 | val loss=0.004811, nmse(dB)=-17.2597 | 0.2s
# [278/500] train loss=0.024684, nmse(dB)=-10.4203 | val loss=0.004804, nmse(dB)=-17.2654 | 0.2s
# [279/500] train loss=0.024175, nmse(dB)=-10.4545 | val loss=0.004816, nmse(dB)=-17.2553 | 0.2s
# [280/500] train loss=0.023061, nmse(dB)=-10.6967 | val loss=0.004812, nmse(dB)=-17.2583 | 0.2s
# [281/500] train loss=0.024128, nmse(dB)=-10.4857 | val loss=0.004823, nmse(dB)=-17.2485 | 0.2s
# [282/500] train loss=0.024764, nmse(dB)=-10.3670 | val loss=0.004826, nmse(dB)=-17.2454 | 0.2s
# [283/500] train loss=0.024100, nmse(dB)=-10.5203 | val loss=0.004837, nmse(dB)=-17.2359 | 0.2s
# [284/500] train loss=0.023394, nmse(dB)=-10.6427 | val loss=0.004842, nmse(dB)=-17.2317 | 0.2s
# [285/500] train loss=0.024570, nmse(dB)=-10.3899 | val loss=0.004813, nmse(dB)=-17.2578 | 0.2s
# [286/500] train loss=0.024329, nmse(dB)=-10.4450 | val loss=0.004813, nmse(dB)=-17.2575 | 0.2s
# [287/500] train loss=0.024200, nmse(dB)=-10.4775 | val loss=0.004825, nmse(dB)=-17.2468 | 0.2s
# [288/500] train loss=0.024529, nmse(dB)=-10.4455 | val loss=0.004819, nmse(dB)=-17.2525 | 0.2s
# [289/500] train loss=0.024781, nmse(dB)=-10.3883 | val loss=0.004827, nmse(dB)=-17.2450 | 0.2s
# [290/500] train loss=0.023131, nmse(dB)=-10.6967 | val loss=0.004817, nmse(dB)=-17.2536 | 0.2s
# [291/500] train loss=0.023993, nmse(dB)=-10.5206 | val loss=0.004823, nmse(dB)=-17.2488 | 0.2s
# [292/500] train loss=0.024387, nmse(dB)=-10.4678 | val loss=0.004820, nmse(dB)=-17.2508 | 0.2s
# [293/500] train loss=0.024525, nmse(dB)=-10.4232 | val loss=0.004805, nmse(dB)=-17.2649 | 0.2s
# [294/500] train loss=0.025033, nmse(dB)=-10.3194 | val loss=0.004813, nmse(dB)=-17.2578 | 0.2s
# [295/500] train loss=0.023662, nmse(dB)=-10.5716 | val loss=0.004796, nmse(dB)=-17.2730 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@295: val loss=0.004796, val nmse(dB)=-17.2730
# [296/500] train loss=0.025145, nmse(dB)=-10.3235 | val loss=0.004798, nmse(dB)=-17.2709 | 0.2s
# [297/500] train loss=0.024220, nmse(dB)=-10.4703 | val loss=0.004815, nmse(dB)=-17.2561 | 0.2s
# [298/500] train loss=0.023760, nmse(dB)=-10.5758 | val loss=0.004810, nmse(dB)=-17.2603 | 0.2s
# [299/500] train loss=0.025745, nmse(dB)=-10.2769 | val loss=0.004795, nmse(dB)=-17.2741 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@299: val loss=0.004795, val nmse(dB)=-17.2741
# [300/500] train loss=0.023523, nmse(dB)=-10.6284 | val loss=0.004794, nmse(dB)=-17.2748 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@300: val loss=0.004794, val nmse(dB)=-17.2748
# [301/500] train loss=0.023707, nmse(dB)=-10.5892 | val loss=0.004808, nmse(dB)=-17.2616 | 0.2s
# [302/500] train loss=0.023678, nmse(dB)=-10.5675 | val loss=0.004808, nmse(dB)=-17.2624 | 0.2s
# [303/500] train loss=0.024855, nmse(dB)=-10.3349 | val loss=0.004810, nmse(dB)=-17.2605 | 0.2s
# [304/500] train loss=0.023714, nmse(dB)=-10.5542 | val loss=0.004801, nmse(dB)=-17.2682 | 0.2s
# [305/500] train loss=0.024319, nmse(dB)=-10.4627 | val loss=0.004805, nmse(dB)=-17.2648 | 0.2s
# [306/500] train loss=0.024775, nmse(dB)=-10.3722 | val loss=0.004814, nmse(dB)=-17.2563 | 0.2s
# [307/500] train loss=0.024348, nmse(dB)=-10.4649 | val loss=0.004811, nmse(dB)=-17.2596 | 0.2s
# [308/500] train loss=0.023466, nmse(dB)=-10.6174 | val loss=0.004812, nmse(dB)=-17.2581 | 0.2s
# [309/500] train loss=0.024044, nmse(dB)=-10.5122 | val loss=0.004827, nmse(dB)=-17.2451 | 0.2s
# [310/500] train loss=0.023663, nmse(dB)=-10.5915 | val loss=0.004820, nmse(dB)=-17.2512 | 0.2s
# [311/500] train loss=0.025277, nmse(dB)=-10.3243 | val loss=0.004803, nmse(dB)=-17.2666 | 0.2s
# [312/500] train loss=0.024391, nmse(dB)=-10.4634 | val loss=0.004807, nmse(dB)=-17.2628 | 0.2s
# [313/500] train loss=0.024036, nmse(dB)=-10.5175 | val loss=0.004798, nmse(dB)=-17.2711 | 0.2s
# [314/500] train loss=0.024834, nmse(dB)=-10.3920 | val loss=0.004796, nmse(dB)=-17.2726 | 0.2s
# [315/500] train loss=0.026013, nmse(dB)=-10.2368 | val loss=0.004805, nmse(dB)=-17.2644 | 0.2s
# [316/500] train loss=0.023908, nmse(dB)=-10.5306 | val loss=0.004807, nmse(dB)=-17.2625 | 0.2s
# [317/500] train loss=0.025825, nmse(dB)=-10.2041 | val loss=0.004799, nmse(dB)=-17.2698 | 0.2s
# [318/500] train loss=0.025023, nmse(dB)=-10.3595 | val loss=0.004802, nmse(dB)=-17.2671 | 0.2s
# [319/500] train loss=0.025360, nmse(dB)=-10.3290 | val loss=0.004807, nmse(dB)=-17.2627 | 0.2s
# [320/500] train loss=0.024145, nmse(dB)=-10.4824 | val loss=0.004805, nmse(dB)=-17.2645 | 0.2s
# [321/500] train loss=0.023701, nmse(dB)=-10.5635 | val loss=0.004809, nmse(dB)=-17.2609 | 0.2s
# [322/500] train loss=0.024360, nmse(dB)=-10.4343 | val loss=0.004805, nmse(dB)=-17.2651 | 0.2s
# [323/500] train loss=0.025237, nmse(dB)=-10.2978 | val loss=0.004804, nmse(dB)=-17.2656 | 0.2s
# [324/500] train loss=0.023651, nmse(dB)=-10.5686 | val loss=0.004809, nmse(dB)=-17.2608 | 0.2s
# [325/500] train loss=0.024828, nmse(dB)=-10.3855 | val loss=0.004809, nmse(dB)=-17.2614 | 0.2s
# [326/500] train loss=0.025297, nmse(dB)=-10.2894 | val loss=0.004806, nmse(dB)=-17.2638 | 0.2s
# [327/500] train loss=0.023839, nmse(dB)=-10.5241 | val loss=0.004806, nmse(dB)=-17.2643 | 0.2s
# [328/500] train loss=0.024139, nmse(dB)=-10.4949 | val loss=0.004807, nmse(dB)=-17.2629 | 0.2s
# [329/500] train loss=0.024546, nmse(dB)=-10.4026 | val loss=0.004811, nmse(dB)=-17.2597 | 0.2s
# [330/500] train loss=0.024494, nmse(dB)=-10.4295 | val loss=0.004809, nmse(dB)=-17.2611 | 0.2s
# [331/500] train loss=0.024162, nmse(dB)=-10.5023 | val loss=0.004807, nmse(dB)=-17.2627 | 0.2s
# [332/500] train loss=0.023081, nmse(dB)=-10.7075 | val loss=0.004808, nmse(dB)=-17.2618 | 0.2s
# [333/500] train loss=0.025381, nmse(dB)=-10.3096 | val loss=0.004815, nmse(dB)=-17.2560 | 0.2s
# [334/500] train loss=0.023638, nmse(dB)=-10.5887 | val loss=0.004825, nmse(dB)=-17.2467 | 0.2s
# [335/500] train loss=0.023849, nmse(dB)=-10.5080 | val loss=0.004821, nmse(dB)=-17.2500 | 0.2s
# [336/500] train loss=0.024294, nmse(dB)=-10.4681 | val loss=0.004816, nmse(dB)=-17.2552 | 0.2s
# [337/500] train loss=0.024868, nmse(dB)=-10.3584 | val loss=0.004815, nmse(dB)=-17.2561 | 0.2s
# [338/500] train loss=0.024741, nmse(dB)=-10.3828 | val loss=0.004820, nmse(dB)=-17.2509 | 0.2s
# [339/500] train loss=0.024129, nmse(dB)=-10.5138 | val loss=0.004820, nmse(dB)=-17.2511 | 0.2s
# [340/500] train loss=0.024546, nmse(dB)=-10.4401 | val loss=0.004814, nmse(dB)=-17.2571 | 0.2s
# [341/500] train loss=0.024405, nmse(dB)=-10.4416 | val loss=0.004815, nmse(dB)=-17.2561 | 0.2s
# [342/500] train loss=0.023649, nmse(dB)=-10.5497 | val loss=0.004821, nmse(dB)=-17.2508 | 0.2s
# [343/500] train loss=0.024835, nmse(dB)=-10.3717 | val loss=0.004818, nmse(dB)=-17.2534 | 0.2s
# [344/500] train loss=0.024429, nmse(dB)=-10.4550 | val loss=0.004809, nmse(dB)=-17.2614 | 0.2s
# [345/500] train loss=0.024636, nmse(dB)=-10.4174 | val loss=0.004807, nmse(dB)=-17.2630 | 0.2s
# [346/500] train loss=0.025173, nmse(dB)=-10.3333 | val loss=0.004807, nmse(dB)=-17.2632 | 0.2s
# [347/500] train loss=0.025224, nmse(dB)=-10.3269 | val loss=0.004801, nmse(dB)=-17.2682 | 0.2s
# [348/500] train loss=0.025134, nmse(dB)=-10.3583 | val loss=0.004791, nmse(dB)=-17.2775 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@348: val loss=0.004791, val nmse(dB)=-17.2775
# [349/500] train loss=0.023968, nmse(dB)=-10.5400 | val loss=0.004792, nmse(dB)=-17.2768 | 0.2s
# [350/500] train loss=0.024454, nmse(dB)=-10.4279 | val loss=0.004798, nmse(dB)=-17.2713 | 0.2s
# [351/500] train loss=0.024233, nmse(dB)=-10.4685 | val loss=0.004798, nmse(dB)=-17.2707 | 0.2s
# [352/500] train loss=0.024373, nmse(dB)=-10.4421 | val loss=0.004796, nmse(dB)=-17.2732 | 0.2s
# [353/500] train loss=0.025124, nmse(dB)=-10.3261 | val loss=0.004799, nmse(dB)=-17.2701 | 0.2s
# [354/500] train loss=0.023399, nmse(dB)=-10.6249 | val loss=0.004800, nmse(dB)=-17.2696 | 0.2s
# [355/500] train loss=0.023813, nmse(dB)=-10.5321 | val loss=0.004790, nmse(dB)=-17.2783 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@355: val loss=0.004790, val nmse(dB)=-17.2783
# [356/500] train loss=0.023429, nmse(dB)=-10.6297 | val loss=0.004782, nmse(dB)=-17.2855 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@356: val loss=0.004782, val nmse(dB)=-17.2855
# [357/500] train loss=0.023504, nmse(dB)=-10.6057 | val loss=0.004784, nmse(dB)=-17.2838 | 0.2s
# [358/500] train loss=0.024970, nmse(dB)=-10.3719 | val loss=0.004789, nmse(dB)=-17.2795 | 0.2s
# [359/500] train loss=0.023624, nmse(dB)=-10.5615 | val loss=0.004788, nmse(dB)=-17.2799 | 0.2s
# [360/500] train loss=0.024261, nmse(dB)=-10.4343 | val loss=0.004791, nmse(dB)=-17.2778 | 0.2s
# [361/500] train loss=0.024397, nmse(dB)=-10.4362 | val loss=0.004797, nmse(dB)=-17.2717 | 0.2s
# [362/500] train loss=0.024824, nmse(dB)=-10.3925 | val loss=0.004806, nmse(dB)=-17.2636 | 0.2s
# [363/500] train loss=0.024779, nmse(dB)=-10.4166 | val loss=0.004805, nmse(dB)=-17.2646 | 0.2s
# [364/500] train loss=0.024569, nmse(dB)=-10.4397 | val loss=0.004799, nmse(dB)=-17.2706 | 0.2s
# [365/500] train loss=0.023934, nmse(dB)=-10.5499 | val loss=0.004798, nmse(dB)=-17.2712 | 0.2s
# [366/500] train loss=0.023373, nmse(dB)=-10.6333 | val loss=0.004797, nmse(dB)=-17.2721 | 0.2s
# [367/500] train loss=0.023602, nmse(dB)=-10.5806 | val loss=0.004794, nmse(dB)=-17.2751 | 0.2s
# [368/500] train loss=0.025073, nmse(dB)=-10.3375 | val loss=0.004792, nmse(dB)=-17.2766 | 0.2s
# [369/500] train loss=0.023768, nmse(dB)=-10.5397 | val loss=0.004796, nmse(dB)=-17.2732 | 0.2s
# [370/500] train loss=0.023256, nmse(dB)=-10.6649 | val loss=0.004806, nmse(dB)=-17.2636 | 0.2s
# [371/500] train loss=0.024976, nmse(dB)=-10.3797 | val loss=0.004805, nmse(dB)=-17.2645 | 0.2s
# [372/500] train loss=0.024060, nmse(dB)=-10.5291 | val loss=0.004799, nmse(dB)=-17.2706 | 0.2s
# [373/500] train loss=0.023391, nmse(dB)=-10.6511 | val loss=0.004797, nmse(dB)=-17.2721 | 0.2s
# [374/500] train loss=0.024527, nmse(dB)=-10.3959 | val loss=0.004796, nmse(dB)=-17.2734 | 0.2s
# [375/500] train loss=0.024188, nmse(dB)=-10.4682 | val loss=0.004795, nmse(dB)=-17.2739 | 0.2s
# [376/500] train loss=0.024568, nmse(dB)=-10.4300 | val loss=0.004794, nmse(dB)=-17.2744 | 0.2s
# [377/500] train loss=0.024619, nmse(dB)=-10.4184 | val loss=0.004797, nmse(dB)=-17.2717 | 0.2s
# [378/500] train loss=0.022459, nmse(dB)=-10.8644 | val loss=0.004798, nmse(dB)=-17.2707 | 0.2s
# [379/500] train loss=0.024272, nmse(dB)=-10.4887 | val loss=0.004794, nmse(dB)=-17.2752 | 0.2s
# [380/500] train loss=0.024769, nmse(dB)=-10.3971 | val loss=0.004787, nmse(dB)=-17.2815 | 0.2s
# [381/500] train loss=0.025019, nmse(dB)=-10.3628 | val loss=0.004780, nmse(dB)=-17.2874 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@381: val loss=0.004780, val nmse(dB)=-17.2874
# [382/500] train loss=0.024724, nmse(dB)=-10.4076 | val loss=0.004777, nmse(dB)=-17.2900 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@382: val loss=0.004777, val nmse(dB)=-17.2900
# [383/500] train loss=0.024989, nmse(dB)=-10.3700 | val loss=0.004779, nmse(dB)=-17.2882 | 0.2s
# [384/500] train loss=0.024611, nmse(dB)=-10.3999 | val loss=0.004782, nmse(dB)=-17.2852 | 0.2s
# [385/500] train loss=0.025416, nmse(dB)=-10.2883 | val loss=0.004785, nmse(dB)=-17.2831 | 0.2s
# [386/500] train loss=0.024183, nmse(dB)=-10.4968 | val loss=0.004789, nmse(dB)=-17.2794 | 0.2s
# [387/500] train loss=0.023867, nmse(dB)=-10.5361 | val loss=0.004792, nmse(dB)=-17.2768 | 0.2s
# [388/500] train loss=0.023613, nmse(dB)=-10.5993 | val loss=0.004791, nmse(dB)=-17.2776 | 0.2s
# [389/500] train loss=0.024444, nmse(dB)=-10.4671 | val loss=0.004786, nmse(dB)=-17.2817 | 0.2s
# [390/500] train loss=0.023087, nmse(dB)=-10.7088 | val loss=0.004781, nmse(dB)=-17.2869 | 0.2s
# [391/500] train loss=0.024251, nmse(dB)=-10.4836 | val loss=0.004775, nmse(dB)=-17.2921 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@391: val loss=0.004775, val nmse(dB)=-17.2921
# [392/500] train loss=0.024698, nmse(dB)=-10.4276 | val loss=0.004772, nmse(dB)=-17.2943 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@392: val loss=0.004772, val nmse(dB)=-17.2943
# [393/500] train loss=0.024148, nmse(dB)=-10.4995 | val loss=0.004774, nmse(dB)=-17.2933 | 0.2s
# [394/500] train loss=0.024937, nmse(dB)=-10.3980 | val loss=0.004773, nmse(dB)=-17.2940 | 0.2s
# [395/500] train loss=0.024712, nmse(dB)=-10.3467 | val loss=0.004772, nmse(dB)=-17.2945 | 0.2s
#   ↳ saved bestc_channel_only_finetune.pt | best@395: val loss=0.004772, val nmse(dB)=-17.2945
# [396/500] train loss=0.024300, nmse(dB)=-10.4467 | val loss=0.004776, nmse(dB)=-17.2913 | 0.2s
# [397/500] train loss=0.023811, nmse(dB)=-10.5608 | val loss=0.004781, nmse(dB)=-17.2862 | 0.2s
# [398/500] train loss=0.023945, nmse(dB)=-10.5387 | val loss=0.004785, nmse(dB)=-17.2825 | 0.2s
# [399/500] train loss=0.023201, nmse(dB)=-10.6354 | val loss=0.004787, nmse(dB)=-17.2807 | 0.2s
# [400/500] train loss=0.023919, nmse(dB)=-10.5381 | val loss=0.004790, nmse(dB)=-17.2785 | 0.2s
# [401/500] train loss=0.024561, nmse(dB)=-10.4024 | val loss=0.004791, nmse(dB)=-17.2775 | 0.2s
# [402/500] train loss=0.023737, nmse(dB)=-10.5751 | val loss=0.004790, nmse(dB)=-17.2784 | 0.2s
# [403/500] train loss=0.023606, nmse(dB)=-10.6065 | val loss=0.004786, nmse(dB)=-17.2818 | 0.2s
# [404/500] train loss=0.023377, nmse(dB)=-10.6406 | val loss=0.004783, nmse(dB)=-17.2843 | 0.2s
# [405/500] train loss=0.023680, nmse(dB)=-10.5545 | val loss=0.004783, nmse(dB)=-17.2851 | 0.2s
# [406/500] train loss=0.024629, nmse(dB)=-10.4391 | val loss=0.004782, nmse(dB)=-17.2853 | 0.2s
# [407/500] train loss=0.024124, nmse(dB)=-10.5068 | val loss=0.004783, nmse(dB)=-17.2848 | 0.2s
# [408/500] train loss=0.025618, nmse(dB)=-10.3154 | val loss=0.004783, nmse(dB)=-17.2845 | 0.2s
# [409/500] train loss=0.025421, nmse(dB)=-10.3131 | val loss=0.004785, nmse(dB)=-17.2825 | 0.2s
# [410/500] train loss=0.025938, nmse(dB)=-10.2516 | val loss=0.004788, nmse(dB)=-17.2804 | 0.2s
# [411/500] train loss=0.023710, nmse(dB)=-10.5874 | val loss=0.004789, nmse(dB)=-17.2793 | 0.2s
# [412/500] train loss=0.024930, nmse(dB)=-10.3547 | val loss=0.004789, nmse(dB)=-17.2796 | 0.2s
# [413/500] train loss=0.024000, nmse(dB)=-10.5173 | val loss=0.004788, nmse(dB)=-17.2805 | 0.2s
# [414/500] train loss=0.023859, nmse(dB)=-10.5419 | val loss=0.004785, nmse(dB)=-17.2826 | 0.2s
# [415/500] train loss=0.024533, nmse(dB)=-10.4238 | val loss=0.004784, nmse(dB)=-17.2839 | 0.2s
# [416/500] train loss=0.025206, nmse(dB)=-10.3052 | val loss=0.004783, nmse(dB)=-17.2851 | 0.2s
# [417/500] train loss=0.024707, nmse(dB)=-10.4012 | val loss=0.004781, nmse(dB)=-17.2865 | 0.2s
# [418/500] train loss=0.023932, nmse(dB)=-10.5150 | val loss=0.004781, nmse(dB)=-17.2870 | 0.2s
# [419/500] train loss=0.023237, nmse(dB)=-10.6693 | val loss=0.004781, nmse(dB)=-17.2870 | 0.2s
# [420/500] train loss=0.025421, nmse(dB)=-10.2840 | val loss=0.004781, nmse(dB)=-17.2862 | 0.2s
# [421/500] train loss=0.024436, nmse(dB)=-10.4690 | val loss=0.004783, nmse(dB)=-17.2847 | 0.2s
# [422/500] train loss=0.023886, nmse(dB)=-10.4953 | val loss=0.004783, nmse(dB)=-17.2848 | 0.2s
# [423/500] train loss=0.025482, nmse(dB)=-10.3302 | val loss=0.004783, nmse(dB)=-17.2846 | 0.2s
# [424/500] train loss=0.023605, nmse(dB)=-10.5903 | val loss=0.004783, nmse(dB)=-17.2846 | 0.2s
# [425/500] train loss=0.023922, nmse(dB)=-10.5503 | val loss=0.004784, nmse(dB)=-17.2841 | 0.2s
# [426/500] train loss=0.022678, nmse(dB)=-10.8197 | val loss=0.004784, nmse(dB)=-17.2834 | 0.2s
# [427/500] train loss=0.024674, nmse(dB)=-10.3907 | val loss=0.004784, nmse(dB)=-17.2836 | 0.2s
# [428/500] train loss=0.024353, nmse(dB)=-10.4735 | val loss=0.004785, nmse(dB)=-17.2833 | 0.2s
# [429/500] train loss=0.024044, nmse(dB)=-10.4881 | val loss=0.004785, nmse(dB)=-17.2833 | 0.2s
# [430/500] train loss=0.024115, nmse(dB)=-10.5236 | val loss=0.004784, nmse(dB)=-17.2837 | 0.2s
# [431/500] train loss=0.024985, nmse(dB)=-10.3761 | val loss=0.004783, nmse(dB)=-17.2844 | 0.2s
# [432/500] train loss=0.024721, nmse(dB)=-10.4378 | val loss=0.004782, nmse(dB)=-17.2854 | 0.2s
# [433/500] train loss=0.024362, nmse(dB)=-10.4439 | val loss=0.004782, nmse(dB)=-17.2859 | 0.2s
# [434/500] train loss=0.024345, nmse(dB)=-10.4569 | val loss=0.004781, nmse(dB)=-17.2866 | 0.2s
# [435/500] train loss=0.024853, nmse(dB)=-10.4112 | val loss=0.004780, nmse(dB)=-17.2876 | 0.2s
# [436/500] train loss=0.025598, nmse(dB)=-10.2717 | val loss=0.004779, nmse(dB)=-17.2881 | 0.2s
# [437/500] train loss=0.024734, nmse(dB)=-10.3622 | val loss=0.004780, nmse(dB)=-17.2875 | 0.2s
# [438/500] train loss=0.025497, nmse(dB)=-10.2985 | val loss=0.004781, nmse(dB)=-17.2866 | 0.2s
# [439/500] train loss=0.024545, nmse(dB)=-10.4278 | val loss=0.004782, nmse(dB)=-17.2854 | 0.2s
# [440/500] train loss=0.023915, nmse(dB)=-10.5134 | val loss=0.004783, nmse(dB)=-17.2846 | 0.2s
# [441/500] train loss=0.024106, nmse(dB)=-10.4978 | val loss=0.004783, nmse(dB)=-17.2848 | 0.2s
# [442/500] train loss=0.025942, nmse(dB)=-10.2410 | val loss=0.004782, nmse(dB)=-17.2857 | 0.2s
# [443/500] train loss=0.024430, nmse(dB)=-10.4486 | val loss=0.004781, nmse(dB)=-17.2864 | 0.2s
# [444/500] train loss=0.024035, nmse(dB)=-10.5030 | val loss=0.004781, nmse(dB)=-17.2868 | 0.2s
# [445/500] train loss=0.023814, nmse(dB)=-10.5588 | val loss=0.004780, nmse(dB)=-17.2872 | 0.2s
# [446/500] train loss=0.025257, nmse(dB)=-10.3042 | val loss=0.004780, nmse(dB)=-17.2874 | 0.2s
# [447/500] train loss=0.023984, nmse(dB)=-10.5302 | val loss=0.004780, nmse(dB)=-17.2872 | 0.2s
# [448/500] train loss=0.023824, nmse(dB)=-10.5577 | val loss=0.004780, nmse(dB)=-17.2871 | 0.2s
# [449/500] train loss=0.024242, nmse(dB)=-10.4969 | val loss=0.004780, nmse(dB)=-17.2873 | 0.2s
# [450/500] train loss=0.024169, nmse(dB)=-10.4880 | val loss=0.004780, nmse(dB)=-17.2870 | 0.2s
# [451/500] train loss=0.024316, nmse(dB)=-10.4665 | val loss=0.004782, nmse(dB)=-17.2858 | 0.2s
# [452/500] train loss=0.023092, nmse(dB)=-10.7150 | val loss=0.004783, nmse(dB)=-17.2851 | 0.2s
# [453/500] train loss=0.024459, nmse(dB)=-10.4373 | val loss=0.004783, nmse(dB)=-17.2848 | 0.2s
# [454/500] train loss=0.024650, nmse(dB)=-10.4075 | val loss=0.004783, nmse(dB)=-17.2848 | 0.2s
# [455/500] train loss=0.024344, nmse(dB)=-10.4542 | val loss=0.004782, nmse(dB)=-17.2857 | 0.2s
# [456/500] train loss=0.025279, nmse(dB)=-10.3004 | val loss=0.004781, nmse(dB)=-17.2866 | 0.2s
# [457/500] train loss=0.023634, nmse(dB)=-10.5743 | val loss=0.004780, nmse(dB)=-17.2871 | 0.2s
# [458/500] train loss=0.024300, nmse(dB)=-10.4851 | val loss=0.004780, nmse(dB)=-17.2873 | 0.2s
# [459/500] train loss=0.024066, nmse(dB)=-10.4718 | val loss=0.004780, nmse(dB)=-17.2873 | 0.2s
# [460/500] train loss=0.024611, nmse(dB)=-10.4244 | val loss=0.004780, nmse(dB)=-17.2874 | 0.2s
# [461/500] train loss=0.025781, nmse(dB)=-10.2509 | val loss=0.004780, nmse(dB)=-17.2875 | 0.2s
# [462/500] train loss=0.024240, nmse(dB)=-10.4449 | val loss=0.004780, nmse(dB)=-17.2874 | 0.2s
# [463/500] train loss=0.024650, nmse(dB)=-10.3926 | val loss=0.004780, nmse(dB)=-17.2873 | 0.2s
# [464/500] train loss=0.025635, nmse(dB)=-10.2857 | val loss=0.004780, nmse(dB)=-17.2873 | 0.2s
# [465/500] train loss=0.025033, nmse(dB)=-10.3473 | val loss=0.004780, nmse(dB)=-17.2873 | 0.2s
# [466/500] train loss=0.023176, nmse(dB)=-10.6732 | val loss=0.004780, nmse(dB)=-17.2874 | 0.2s
# [467/500] train loss=0.025636, nmse(dB)=-10.3140 | val loss=0.004780, nmse(dB)=-17.2874 | 0.2s
# [468/500] train loss=0.024414, nmse(dB)=-10.4335 | val loss=0.004780, nmse(dB)=-17.2874 | 0.2s
# [469/500] train loss=0.025865, nmse(dB)=-10.2471 | val loss=0.004780, nmse(dB)=-17.2873 | 0.2s
# [470/500] train loss=0.024628, nmse(dB)=-10.4375 | val loss=0.004780, nmse(dB)=-17.2873 | 0.2s
# [471/500] train loss=0.023660, nmse(dB)=-10.5484 | val loss=0.004780, nmse(dB)=-17.2875 | 0.2s
# [472/500] train loss=0.024669, nmse(dB)=-10.4057 | val loss=0.004780, nmse(dB)=-17.2876 | 0.2s
# [473/500] train loss=0.025250, nmse(dB)=-10.2996 | val loss=0.004780, nmse(dB)=-17.2877 | 0.2s
# [474/500] train loss=0.024742, nmse(dB)=-10.3602 | val loss=0.004780, nmse(dB)=-17.2877 | 0.2s
# [475/500] train loss=0.024156, nmse(dB)=-10.5134 | val loss=0.004780, nmse(dB)=-17.2878 | 0.2s
# [476/500] train loss=0.024912, nmse(dB)=-10.3535 | val loss=0.004779, nmse(dB)=-17.2879 | 0.2s
# [477/500] train loss=0.024203, nmse(dB)=-10.4788 | val loss=0.004779, nmse(dB)=-17.2881 | 0.2s
# [478/500] train loss=0.024004, nmse(dB)=-10.5200 | val loss=0.004779, nmse(dB)=-17.2883 | 0.2s
# [479/500] train loss=0.024826, nmse(dB)=-10.3749 | val loss=0.004779, nmse(dB)=-17.2884 | 0.2s
# [480/500] train loss=0.024204, nmse(dB)=-10.4447 | val loss=0.004779, nmse(dB)=-17.2885 | 0.2s
# [481/500] train loss=0.023988, nmse(dB)=-10.5043 | val loss=0.004779, nmse(dB)=-17.2885 | 0.2s
# [482/500] train loss=0.025012, nmse(dB)=-10.3645 | val loss=0.004779, nmse(dB)=-17.2885 | 0.2s
# [483/500] train loss=0.024119, nmse(dB)=-10.4947 | val loss=0.004779, nmse(dB)=-17.2885 | 0.2s
# [484/500] train loss=0.022860, nmse(dB)=-10.7426 | val loss=0.004779, nmse(dB)=-17.2885 | 0.2s
# [485/500] train loss=0.023663, nmse(dB)=-10.5754 | val loss=0.004779, nmse(dB)=-17.2885 | 0.2s
# [486/500] train loss=0.024358, nmse(dB)=-10.4515 | val loss=0.004779, nmse(dB)=-17.2885 | 0.2s
# [487/500] train loss=0.023453, nmse(dB)=-10.6071 | val loss=0.004779, nmse(dB)=-17.2885 | 0.2s
# [488/500] train loss=0.024080, nmse(dB)=-10.4887 | val loss=0.004779, nmse(dB)=-17.2885 | 0.2s
# [489/500] train loss=0.024345, nmse(dB)=-10.4800 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [490/500] train loss=0.024025, nmse(dB)=-10.4868 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [491/500] train loss=0.024124, nmse(dB)=-10.4792 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [492/500] train loss=0.022418, nmse(dB)=-10.8829 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [493/500] train loss=0.023660, nmse(dB)=-10.6032 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [494/500] train loss=0.024210, nmse(dB)=-10.4934 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [495/500] train loss=0.024409, nmse(dB)=-10.4181 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [496/500] train loss=0.024191, nmse(dB)=-10.4904 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [497/500] train loss=0.024126, nmse(dB)=-10.5036 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [498/500] train loss=0.024333, nmse(dB)=-10.4701 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [499/500] train loss=0.024757, nmse(dB)=-10.3510 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
# [500/500] train loss=0.024762, nmse(dB)=-10.3595 | val loss=0.004779, nmse(dB)=-17.2886 | 0.2s
#
# === Training Summary ===
# Total time: 123.8s (0h 2m 3.8s)
# Best epoch: 395 | best val loss=0.004772, best val nmse(dB)=-17.2945
# Log saved to: /mnt/ssd_7t_2/Deepverse/transformer1_scene100_v1.txt

# %% [markdown]
# # 런타임 체크

# %%
ch, y = next(iter(train_loader))
print("y abs mean:", y.abs().mean().item())
print("y abs max :", y.abs().max().item())
print("y power   :", (y**2).mean().item())

with torch.no_grad():
    yhat = model(ch.to(device))   
print("yhat abs mean:", yhat.abs().mean().item())
print("yhat abs max :", yhat.abs().max().item())
print("yhat power   :", (yhat**2).mean().item())
# Out:
# y abs mean: 0.4975219666957855
# y abs max : 0.8380954265594482
# y power   : 0.2712644338607788
# yhat abs mean: 0.49919193983078003
# yhat abs max : 0.5578693151473999
# yhat power   : 0.24956271052360535

# %%
import torch

# 소수점 10자리까지 출력하도록 설정
torch.set_printoptions(precision=10)

# 예시 텐서 출력
# 이제 0.5735... 대신 0.5735123456 형식으로 보일 것입니다.

# %%
y
# Out:
# tensor([[[0.2726370096, 0.2719238400, 0.2712586522,  ..., 0.7109267712,
#           0.7131308913, 0.7159176469],
#          [0.6410344839, 0.6335957646, 0.6261961460,  ..., 0.3530763984,
#           0.3629694581, 0.3737199903],
#          [0.6166480184, 0.6213119030, 0.6243001819,  ..., 0.2880276144,
#           0.2801501751, 0.2736692429],
#          [0.7365172505, 0.7366368771, 0.7365543246,  ..., 0.4260006547,
#           0.4356493056, 0.4448266029]],
#
#         [[0.5263138413, 0.5376093984, 0.5473425984,  ..., 0.6097067595,
#           0.5990135670, 0.5872631073],
#          [0.6094953418, 0.6032900810, 0.5959033966,  ..., 0.3187474012,
#           0.3253245056, 0.3312207460],
#          [0.6192798615, 0.6314886808, 0.6428202987,  ..., 0.3333683312,
#           0.3285699785, 0.3228191733],
#          [0.4805482328, 0.4874705374, 0.4943218827,  ..., 0.4458550513,
#           0.4341624081, 0.4239472449]],
#
#         [[0.5586451292, 0.5687823892, 0.5796951056,  ..., 0.6582331657,
#           0.6709513664, 0.6817041039],
#          [0.6315074563, 0.6318022013, 0.6311377883,  ..., 0.5701466799,
#           0.5621866584, 0.5517556071],
#          [0.5918706656, 0.5840516686, 0.5779775977,  ..., 0.4747622609,
#           0.4650453925, 0.4555617273],
#          [0.3959485292, 0.4080581665, 0.4229540229,  ..., 0.6623135805,
#           0.6669886112, 0.6714127660]],
#
#         ...,
#
#         [[0.5445491076, 0.5328724980, 0.5210327506,  ..., 0.6732162833,
#           0.6741508842, 0.6735556722],
#          [0.3609667122, 0.3593590260, 0.3591372669,  ..., 0.4369894564,
#           0.4268918037, 0.4179659188],
#          [0.5268595815, 0.5292013288, 0.5329610705,  ..., 0.4839976728,
#           0.4914947748, 0.5018051863],
#          [0.6295176148, 0.6233088374, 0.6188088059,  ..., 0.6291764975,
#           0.6283138394, 0.6283851862]],
#
#         [[0.6192798615, 0.6314886808, 0.6428202987,  ..., 0.3333683312,
#           0.3285699785, 0.3228191733],
#          [0.4805482328, 0.4874705374, 0.4943218827,  ..., 0.4458550513,
#           0.4341624081, 0.4239472449],
#          [0.6480854750, 0.6496848464, 0.6521918178,  ..., 0.3776528835,
#           0.3864552081, 0.3973567188],
#          [0.4093382359, 0.4188594520, 0.4262953997,  ..., 0.3594920337,
#           0.3487368524, 0.3372988999]],
#
#         [[0.5942364335, 0.5859391093, 0.5771930218,  ..., 0.4175636172,
#           0.4125449359, 0.4062548280],
#          [0.5488938093, 0.5441219807, 0.5384852290,  ..., 0.3431005776,
#           0.3458208144, 0.3471170962],
#          [0.5263138413, 0.5376093984, 0.5473425984,  ..., 0.6097067595,
#           0.5990135670, 0.5872631073],
#          [0.5263138413, 0.5376093984, 0.5473425984,  ..., 0.6097067595,
#           0.5990135670, 0.5872631073]]], device='cuda:0')

# %%
yhat
# Out:
# tensor([[[0.5439525843, 0.5479392409, 0.5517869592,  ..., 0.5137568116,
#           0.5083538890, 0.5166218281],
#          [0.5441859961, 0.5433759689, 0.5549557209,  ..., 0.5154049397,
#           0.5083299875, 0.5137678981],
#          [0.5445019603, 0.5440957546, 0.5541030169,  ..., 0.5129399300,
#           0.5132591724, 0.5145431757],
#          [0.5435259342, 0.5443031192, 0.5519988537,  ..., 0.5144376755,
#           0.5098484159, 0.5147202015]],
#
#         [[0.5438827872, 0.5480228066, 0.5515351892,  ..., 0.5135678053,
#           0.5080305934, 0.5163185596],
#          [0.5441166759, 0.5434711576, 0.5547004342,  ..., 0.5152173638,
#           0.5080053210, 0.5134608150],
#          [0.5444328189, 0.5441762805, 0.5538565516,  ..., 0.5127511024,
#           0.5129376650, 0.5142396092],
#          [0.5434563160, 0.5443947315, 0.5517461300,  ..., 0.5142487288,
#           0.5095232725, 0.5144163966]],
#
#         [[0.5436266661, 0.5481127501, 0.5516440272,  ..., 0.5135871768,
#           0.5082614422, 0.5164678097],
#          [0.5438588858, 0.5435634851, 0.5548067689,  ..., 0.5152418613,
#           0.5082331300, 0.5136104226],
#          [0.5441780686, 0.5442678332, 0.5539593697,  ..., 0.5127724409,
#           0.5131707191, 0.5143883228],
#          [0.5432008505, 0.5444835424, 0.5518466830,  ..., 0.5142738819,
#           0.5097607970, 0.5145645738]],
#
#         ...,
#
#         [[0.5436240435, 0.5481318831, 0.5516802073,  ..., 0.5135960579,
#           0.5082427263, 0.5164945722],
#          [0.5438584089, 0.5435838103, 0.5548410416,  ..., 0.5152482986,
#           0.5082111955, 0.5136349201],
#          [0.5441755056, 0.5442867279, 0.5539941788,  ..., 0.5127794147,
#           0.5131502748, 0.5144138932],
#          [0.5431983471, 0.5445022583, 0.5518818498,  ..., 0.5142803788,
#           0.5097402334, 0.5145900846]],
#
#         [[0.5439149141, 0.5481091738, 0.5515271425,  ..., 0.5135850310,
#           0.5082317591, 0.5163739324],
#          [0.5441489816, 0.5435524583, 0.5546907187,  ..., 0.5152345300,
#           0.5082047582, 0.5135167837],
#          [0.5444653034, 0.5442634225, 0.5538458228,  ..., 0.5127684474,
#           0.5131381750, 0.5142943859],
#          [0.5434875488, 0.5444759727, 0.5517389178,  ..., 0.5142643452,
#           0.5097232461, 0.5144717097]],
#
#         [[0.5439333916, 0.5479868650, 0.5514370799,  ..., 0.5134337544,
#           0.5079768896, 0.5162866712],
#          [0.5441677570, 0.5434330702, 0.5545995831,  ..., 0.5150833726,
#           0.5079495907, 0.5134309530],
#          [0.5444830656, 0.5441380739, 0.5537583232,  ..., 0.5126153231,
#           0.5128837228, 0.5142064691],
#          [0.5435074568, 0.5443546176, 0.5516498089,  ..., 0.5141126513,
#           0.5094677806, 0.5143841505]]], device='cuda:0')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 데이터 입력 형태

# %%
print("=== dataset sizes ===")
print("N(comm_frames):", len(comm_frames))
print("past_len      :", ds.past_len)
print("pre_len       :", ds.pre_len)
print("len(ds)       :", len(ds))
print("len(train_ds) :", len(train_ds))
print("len(val_ds)   :", len(val_ds))
print("len(train_loader):", len(train_loader))
print("len(val_loader)  :", len(val_loader))

print("\n=== one batch shapes ===")
ch, y = next(iter(train_loader))

print("ch :", tuple(ch.shape), " -> (B, T, F_in)")
print("y  :", tuple(y.shape),  " -> (B, pre_len, F_step)")

with torch.no_grad():
    yhat = model(ch.to(device))

print("yhat:", tuple(yhat.shape), " -> (B, pre_len, F_step)")

# ✅ sanity: shape 일치 확인
assert yhat.shape == y.shape, f"shape mismatch: yhat={yhat.shape}, y={y.shape}"

B, P, F = yhat.shape
print("this forward predicted samples:", B, "(=B)")
print("each sample predicts steps    :", P, "(=pre_len)")
print("each step predicts elements   :", F, "(=F_step)")

# (선택) 첫 샘플의 1-step 일부 값 확인
print("\n=== sample preview ===")
print("y[0,0,:10]   :", y[0,0,:10].detach().cpu())
print("yhat[0,0,:10]:", yhat[0,0,:10].detach().cpu())
# Out:
# === dataset sizes ===
# N(comm_frames): 100
# past_len      : 16
# pre_len       : 4
# len(ds)       : 81
# len(train_ds) : 45
# len(val_ds)   : 15
# len(train_loader): 2
# len(val_loader)  : 1
#
# === one batch shapes ===
# ch : (32, 16, 2048)  -> (B, T, F_in)
# y  : (32, 4, 2048)  -> (B, pre_len, F_step)
# yhat: (32, 4, 2048)  -> (B, pre_len, F_step)
# this forward predicted samples: 32 (=B)
# each sample predicts steps    : 4 (=pre_len)
# each step predicts elements   : 2048 (=F_step)
#
# === sample preview ===
# y[0,0,:10]   : tensor([0.2726, 0.2719, 0.2713, 0.2715, 0.2732, 0.2763, 0.2805, 0.2853, 0.2903,
#         0.2955])
# yhat[0,0,:10]: tensor([0.5440, 0.5479, 0.5518, 0.5429, 0.5549, 0.5462, 0.5494, 0.5535, 0.5463,
#         0.5505])
